# %% [markdown]
# ## 1. Import Library
# ___

# %%
import os
import sys
import pickle
import random
import gc
import ctypes
import copy

from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns
from colorama import Fore

from PIL import Image
import cv2

import torch

from sklearn.model_selection import KFold, GroupKFold, StratifiedKFold

import warnings
warnings.filterwarnings('ignore')

print(f'{Fore.GREEN}=> Installed Necessary Library')
# Out:
# => Installed Necessary Library

# %% [markdown]
# ### Configuration

# %%
class CFG:
    debug = False
    output_dir = 'runs/detect'
    seed = 42
    train_ds = 'gastroscopy_train'

    img_size = [256,256]
    input_format = 'BGR'
    imgdir = '/kaggle/input/gastroscopy-256x256-resized-png'
    mapper_type = 'albu' # 'detectron2'

    split_mode = 'valid20'
    max_iter = 5_000 # default 40_000
    ims_per_batch = 8 
    num_workers = 4 
    
    lr_scheduler_name = 'WarmupCosineLR' # WarmupMultiStepLR
    base_lr = 1e-2 # default: 1e-3
    base_lr_end = 1e-9 # default: 0
    weight_decay = 1e-4 # default 1e-4
    warmup_factor = 1e-4 # default: 1e-3
    warmup_iters = max_iter // 20 # default: 1_000
    eval_period = max_iter * 10
    amp = True # Auto Mixed Precision
    
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

os.makedirs(CFG.output_dir, exist_ok=True)

# %% [markdown]
# ### Reproducibility

# %%
def seed_everything(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark= False

    os.environ['PYTHONHASHSEED'] = str(seed)

seed_everything(CFG.seed)

# %% [markdown]
# ### Clean_Memory

# %%
def clean_memory():
    ctypes.CDLL('libc.so.6').malloc_trim(0)
    gc.collect()
    
clean_memory()

# %% [markdown]
# ### Install Detectron Library

# %%
print(f'=> {Fore.GREEN}Installing Detectron2 Library...' )
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'

## Or, to install it from a local clone:
# !git clone https://github.com/facebookresearch/detectron2.git
# !python -m pip install -e detectron2
# Out:
# => Installing Detectron2 Library...
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.9 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done

# %% [markdown]
# ## 2. Build Dataset_Dicts
# ___
#
# - **궤양**: `ulcer(label: 0)`
#
# - **용종**: `polyp(label: 1)`
#
# - **암**: `cancer(label: 2)`

# %%
meta_data = pd.read_csv('/kaggle/input/gastroscopy-meta/gastroscopy_data2.csv')
print('Shape of DataFrame: ', meta_data.shape)
meta_data.head()
# Out:
# Shape of DataFrame:  (2915, 14)
#         image_id  height  width        organ  lesion_label  location  \
# 0  1_1_00011.png    2048   2048  gastroscopy             0         1
# 1  1_1_00011.png    2048   2048  gastroscopy             0         1
# 2  1_1_00014.png    2048   2048  gastroscopy             0         1
# 3  1_1_00017.png    2048   2048  gastroscopy             0         1
# 4  1_1_00018.png    2048   2048  gastroscopy             0         1
#
#   shape_type_polygon                                       polygon_mask  \
# 0            polygon  1257.45,738.30;1212.77,748.94;1168.09,748.94;1...
# 1            polygon  1421.28,955.32;1387.23,985.11;1368.09,1025.53;...
# 2            polygon  1065.96,1110.64;1040.43,1148.94;1010.64,1182.9...
# 3            polygon  1246.30,514.89;1197.36,508.51;1154.81,502.13;1...
# 4            polygon  1397.36,389.36;1352.68,382.98;1314.38,404.26;1...
#
#   bounding_box_shape        x_min       y_min        x_max        y_max lesion
# 0          rectangle   763.829787  365.957447  1304.255319   748.936170  ulcer
# 1          rectangle  1148.936170  897.872340  1421.276596  1082.978723  ulcer
# 2          rectangle   521.276596  561.702128  1078.723404  1225.531915  ulcer
# 3          rectangle   884.595745  502.127660  1376.085106   753.191489  ulcer
# 4          rectangle  1161.191489  382.978723  1654.808511  1074.468085  ulcer

# %%
thing_classes = [
    'Ulcer',
    'Polyp',
    'Cancer',
]

category_id_to_name = {index: class_name for index,class_name in enumerate(thing_classes) }

meta_data['lesion'] = meta_data['lesion_label'].map(category_id_to_name)

# %%
train_id = [x.split('/')[-1] for x in glob('/kaggle/input/gastroscopy-256x256-resized-png/train/*.png')] 
test_id = [x.split('/')[-1] for x in glob('/kaggle/input/gastroscopy-256x256-resized-png/test/*.png')] 

train_df = meta_data[meta_data['image_id'].isin(train_id)].reset_index(drop=True)
test_df = meta_data[meta_data['image_id'].isin(test_id)].reset_index(drop=True)

print('=> Number of Unique Image_id in Train: ', train_df.image_id.nunique())
print('=> Number of Unique Image_id in Test: ', test_df.image_id.nunique())
# Out:
# => Number of Unique Image_id in Train:  1597
# => Number of Unique Image_id in Test:  400

# %% [markdown]
# ### Dectectron2 Library Dataset Format
#
# ![image.png](attachment:642bd6d2-f1b9-4598-84e2-85040eb9fac1.png)

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 15px; font-size:100%;">
#
#
# 📌 **`dataset_dicts`**: Metadata of Image, in Detectron2 Dataset Format
#
# To define custom datasets, we need to create list of dict(`dataset_dicts`) where each dict contains following:
#
# - `file_name`: file name of the image
# - `image_id`: id of the image, index is used here.
# - `height`: height of the image
# - `width`: width of the image
# - `annotation`: This the ground truth annotation data for object detection, which contains following:
#   - `bbox`: bounding box pixel location with shape(n_boxes, 4)
#   - `bbox_mode`: BoxMode.XYXY_ABS meaning that absolute value of (xmin, ymin, xmax, ymax)
#   - `category_id`: class label id for each bounding box, with shape(n_boxes,)

# %% [markdown]
# ### Define Dataset_dicts

# %%
from detectron2.structures import BoxMode

def get_gastroscopy_dicts(
    imgdir: str, 
    df,
    mode: str = 'train',
    use_cache: bool = True, 
    debug: bool = True,
    target_indices: list = None
): 
    debug_str = f"_debug{int(debug)}"
    cache_path = f'/kaggle/working/dataset_dicts_cache_{mode}{debug_str}.pkl'

    if not use_cache or not os.path.exists(cache_path):
       print(f'{Fore.BLUE}#'* 25)
       print(f'### Creating {mode} Data...')
       print('#' * 25)

       meta_df = pd.read_csv(f'/kaggle/input/gastroscopy-256x256-resized-png/{mode}_meta.csv')
        
       if debug:
           meta_df = meta_df[:500]

       image_id = meta_df.loc[0,'image_id']
       image_path = os.path.join(imgdir,mode, image_id)
       image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
       resized_height, resized_width, channel = image.shape
       print(f'=> Height of Image: {resized_height}')
       print(f'=> Width of Image: {resized_width}')

       dataset_dicts = []
       for _, (image_id, height, width) in tqdm(meta_df.iterrows(), total=len(meta_df), desc='Build Dataset Dict'):
           record = {}
           record['file_name'] = os.path.join(imgdir,'train',image_id)
           record['image_id'] = image_id
           record['height'] = resized_height
           record['width'] = resized_width

           if mode != 'test':
              objs = []
              for _, row in df[df.image_id == image_id].iterrows():
                  class_id = row['lesion_label']

                  h_ratio = resized_height / height
                  w_ratio = resized_width / width

                  bbox_resized = [
                      row['x_min'] * w_ratio,
                      row['y_min'] * h_ratio,
                      row['x_max'] * w_ratio,
                      row['y_max'] * h_ratio,
                  ]

                  obj = {
                     'bbox': bbox_resized,
                     'bbox_mode': BoxMode.XYXY_ABS,
                     'category_id': class_id,
                  }
                  objs.append(obj)
              record['annotations'] = objs
              dataset_dicts.append(record)
           else: 
              dataset_dicts.append(record)
       with open(cache_path, mode='wb') as f:
           pickle.dump(dataset_dicts, f)
    with open(cache_path, mode='rb') as f:
        dataset_dicts = pickle.load(f)

    if target_indices is not None:
        dataset_dicts = [dataset_dicts[i] for i in target_indices]

    return dataset_dicts

# %% [markdown]
# ### Load Dataset_dicts

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog

if CFG.split_mode == 'valid20':
    n_dataset = len(
        get_gastroscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug)
        )
    
    n_train = int(n_dataset * 0.8)
    n_valid = n_dataset - n_train
    rs = np.random.RandomState(CFG.seed)
    inds = rs.permutation(n_dataset)
    train_inds, valid_inds = inds[:n_train], inds[n_train:]

    print(f'n_train: {len(train_inds)} n_valid: {len(valid_inds)}')

    DatasetCatalog.register(
        'gastroscopy_train',
        lambda: get_gastroscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = train_inds
        )
    )
    MetadataCatalog.get('gastroscopy_train').set(thing_classes = thing_classes)

    DatasetCatalog.register(
        'gastroscopy_valid',
        lambda: get_gastroscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = valid_inds
        )
    )

    MetadataCatalog.get('gastroscopy_valid').set(thing_classes = thing_classes)
# Out:
# #########################
# ### Creating train Data...
# #########################
# => Height of Image: 256
# => Width of Image: 256
# Build Dataset Dict: 100%|██████████| 1597/1597 [00:01<00:00, 1305.91it/s]
# n_train: 1277 n_valid: 320

# %%
dataset_dicts = get_gastroscopy_dicts(CFG.imgdir, train_df, mode='train', debug=CFG.debug)

clean_memory();

# %% [markdown]
# ## 3. Build DatasetMapper
# ___
#
# **`DatasetMapper`**:
#
# => **Load images**
#
# => **transform images and annotations**
#
# => **convert annotations to Instances**
#
# **`Dectecron2 Image Augmentation System`**
#
# ![image.png](attachment:826227e3-3110-4be2-b891-e1d9570aaf0d.png)

# %% [markdown]
# ### 📌 Albumentations DatasetMapper
#
# But this notebook, I'm gonna use `Albumentations` not use Detectron2 Image Augmentation System

# %%
def get_train_transform():
    return A.Compose(
               [
                A.HorizontalFlip(p=0.5),

                ## CLAHE
                A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0),

               
                ### Channel Transform
                A.OneOf([
                    A.ChannelShuffle(p=1.0),
                    A.ChannelDropout(p=1.0),
                    A.ToGray(p=1.0),
                    A.RGBShift(r_shift_limit=[-5,5], g_shift_limit=[-5,5], b_shift_limit=[-5,5], p=1.0)],
                    p=0.5),

                ### Dropout Transform   
                A.OneOf([
                    A.XYMasking(
                        num_masks_x=[1,1],
                        num_masks_y=[1,1],
                        mask_x_length = [int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],
                        mask_y_length = [int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        p=1.0),
                    A.CoarseDropout(
                        num_holes_range=[2,4],
                        hole_height_range=[int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        hole_width_range=[int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],p=1.0),
                    A.BBoxSafeRandomCrop(
                        height=int(CFG.img_size[0] * 0.8),  # 높이 계산
                         width=int(CFG.img_size[1] * 0.8), p=1.0),],
                    p=0.25),

                ## Noisy Transform
                A.OneOf([
                    A.RandomGravel(number_of_patches=1, p=1.0),
                    A.RandomSnow(brightness_coeff=1.1, p=1.0),
                ],
                    p=0.25
                       ), 
                
                A.Resize(*CFG.img_size, p=1.0),
                ],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    ) 
        
def get_valid_transform():
    return A.Compose(
                [A.Resize(*CFG.img_size, p=1.0),],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    )

# %%
import albumentations as A
import detectron2.data.transforms as T
from detectron2.data import detection_utils as utils

class AlbumentationsMapper:
    def __init__(self, is_train: bool=True, mixup_prob: float=0.1, mosaic_prob: float=0.25):
        self.is_train = is_train
        self.mixup_prob = mixup_prob
        self.mosaic_prob = mosaic_prob
        
        if self.is_train:
            self.transform = get_train_transform()
        else:
            self.transform = get_valid_transform()
            

        mode='training' if self.is_train else 'inference'
        print(f'{Fore.GREEN}[AlbumentationsMapper]{Fore.BLACK} Augmentations used in {mode}: {self.transform}')

    def datadict_sampler(self, ds_name=CFG.train_ds, n=3):
        ds = DatasetCatalog.get(ds_name)

        indices = np.random.randint(0, len(ds) - 1, n)
        return [copy.deepcopy(ds[idx]) for idx in indices]

    def __mixup_transform(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        mu_dict = self.datadict_sampler(n=1)[0]

        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        mu_image = utils.read_image(mu_dict['file_name'], format=CFG.input_format)

        lam = np.random.beta(2.0, 2.0)
        image = (lam * image + (1 - lam) * mu_image).astype(np.uint8)
        
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        image = transform(image=image)['image']
        dataset_dict['image'] = image
        dataset_dict['annotations'] += mu_dict['annotations']
            
        return dataset_dict

    def __mosaic_transform(self, dataset_dict):
        dataset_dict= copy.deepcopy(dataset_dict)
        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        im_h, im_w = image.shape[:2]
        resized_w = random.randint(int(CFG.img_size[0]*0.75), int(CFG.img_size[0]*1.25))
        resized_h = random.randint(int(CFG.img_size[1]*0.75), int(CFG.img_size[1]*1.25))
        image = cv2.resize(image, (resized_w, resized_h))
        boxes = np.array([anno['bbox'] for anno in dataset_dict['annotations']]) 
        boxes[:,[0,2]] *= resized_w / im_w
        boxes[:,[1,3]] *= resized_h / im_h
        
        mo_items = self.datadict_sampler(n=3)
        mo_images = []
        mo_boxes = []
        
        resize_list = [
            [(im_w*2-resized_w),resized_h], [resized_w,(im_h*2-resized_h)], [(im_w*2-resized_w),(im_h*2-resized_h)],
        ]
        
        for i, mo_dict in enumerate(mo_items):
            mo_image = utils.read_image(mo_dict['file_name'],format=CFG.input_format)
            mo_h, mo_w = mo_image.shape[:2]
            mo_image = cv2.resize(mo_image, (resize_list[i][0], resize_list[i][1]))
            mo_images.append(mo_image)
            mo_bbox = np.array([
                 anno['bbox'] for anno in mo_dict['annotations']
            ])
            mo_bbox[:,[0,2]] *= resize_list[i][0] / mo_w
            mo_bbox[:,[1,3]] *= resize_list[i][1] / mo_h
            mo_boxes.append(mo_bbox)
             
        
            dataset_dict['annotations'] += mo_dict['annotations']
        
        images = [image] + mo_images
        boxes = [boxes] + mo_boxes

        
        heights = [i.shape[0] for i in images] 
        widths =  [i.shape[1] for i in images]

        ch = max(heights[0], heights[1])
        cw = max(widths[0], widths[2]) 
        h = (max(heights[0], heights[1]) + 
             max(heights[2], heights[3]))
        w = (max(widths[0], widths[2]) +
             max(widths[1], widths[3]))
        
        # pad or start coordinates 
        y0, x0 = ch - heights[0], cw - widths[0] # Height: 0,  Width: 0 
        y1, x1 = ch - heights[1], cw # Height: 0, Width: 256 
        y2, x2 = ch, cw - widths[2] # Height: 256, Width: 0
        y3, x3 = ch, cw # Height: 256, Width: 256
        x_pads = [x0, x1, x2, x3]
        y_pads = [y0, y1, y2, y3]

        output = np.zeros((h,w,3)).astype(np.uint8)
        for i, img in enumerate(images):
            output[y_pads[i]: y_pads[i] + heights[i],
                   x_pads[i]: x_pads[i] + widths[i],
                   :] = img
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        output = transform(image=output)['image']
        dataset_dict['image'] = output

        for i, bbox in enumerate(boxes):
            bbox += np.array([x_pads[i], y_pads[i], x_pads[i], y_pads[i]])
            
        boxes = np.vstack(boxes)

        for i, box in enumerate(boxes):
            dataset_dict['annotations'][i]['bbox'] = box
        
        return dataset_dict
        
    def __call__(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)

        if self.is_train:
            if np.random.rand() <= self.mosaic_prob:
               dataset_dict = self.__mosaic_transform(dataset_dict)

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict
            elif np.random.rand() <= self.mixup_prob:
               dataset_dict = self.__mixup_transform(dataset_dict)
    

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict

        
        image = utils.read_image(dataset_dict['file_name'], format=CFG.input_format)

        ### Bounding Box
        bboxes = np.array([obj['bbox'] for obj in dataset_dict['annotations']], dtype=np.float32)
        annotation_id = np.arange(len(dataset_dict['annotations']))

        ### Applying Augmentation
        transformed = self.transform(image=image, bboxes=bboxes, category_ids=annotation_id)
        dataset_dict['image'] = transformed['image']
        
        for i in transformed['category_ids']:
            dataset_dict['annotations'][i]['bbox'] = transformed['bboxes'][i] 
        

        image_shape = dataset_dict['image'].shape[:2] # height, width
        dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

        instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
        dataset_dict['instances'] = utils.filter_empty_instances(instances)

        ## Remove annotations for convert to instances
        dataset_dict.pop('annotations', None)

        return dataset_dict

# %% [markdown]
# ## 4. Build Detectron2 Custom Trainer
# ___

# %%
import detectron2
from detectron2 import model_zoo # model library
from detectron2.config import get_cfg # Get a copy of the default config

from detectron2.data.dataset_mapper import DatasetMapper
from detectron2.data import build_detection_train_loader, build_detection_test_loader

from detectron2.engine import DefaultPredictor, DefaultTrainer

from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.solver.build import get_default_optimizer_params, maybe_add_gradient_clipping

from detectron2.evaluation import COCOEvaluator
from detectron2.evaluation import PascalVOCDetectionEvaluator

from detectron2.utils.logger import setup_logger
from detectron2.utils.visualizer import Visualizer, ColorMode

setup_logger() # Initialize the detectron2 logger and set its verbosity level to 'debug'

class MyTrainer(DefaultTrainer):

    @classmethod
    def build_train_loader(cls, cfg, sampler=None):
        return build_detection_train_loader(
            cfg, mapper=AlbumentationsMapper(is_train = True), sampler=sampler
        )

    @classmethod
    def build_test_loader(cls, cfg, dataset_name):
        return build_detection_test_loader(
            cfg, dataset_name, mapper=AlbumentationsMapper(is_train = False)
        )

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, 'inference')
        
        return COCOEvaluator(
            dataset_name = dataset_name, # name of the dataset to be evaluated
            tasks = ("bbox",), 
            distributed = False, # only evalute the results in the current process
            output_dir=output_folder)

            ## Results predicted on the dataset
            ### instances_predictions.pth
            ### coco_instances_results.json: json file in COCO's result format

# %% [markdown]
# ## 5. Visualization Gastroscopy Augmentation
# ___

# %%
gastroscopy_metadata = MetadataCatalog.get('gastroscopy_train')
print(gastroscopy_metadata)
# Out:
# Metadata(name='gastroscopy_train', thing_classes=['Ulcer', 'Polyp', 'Cancer'])

# %%
mapper = AlbumentationsMapper(is_train=True)

plt.figure(figsize=(12,8))

for i in range(8):
    plt.subplot(4,4,2*i+1)
    plt.title('Before Augmentation')
    d = dataset_dicts[i]
    img = Image.open(d['file_name']).convert('RGB')
    img = np.array(img)
    visualizer = Visualizer(img, metadata=gastroscopy_metadata, scale=0.8)
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image())
    plt.axis('off')
    
    plt.subplot(4,4, 2*i+2)
    plt.title('After Augmentation')
    mapped_d = mapper(d)
    img_arr = mapped_d['image'].cpu().permute(1,2,0).numpy()
    # img_arr[:,:,::-1] # BGR -> RGB
    visualizer = Visualizer(img_arr[:,:,::-1], metadata=gastroscopy_metadata, scale=0.8)
    target_fields = mapped_d['instances'].get_fields()
    labels = [gastroscopy_metadata.thing_classes[i] for i in target_fields['gt_classes']]

    out = visualizer.overlay_instances(
        labels = labels,
        boxes = target_fields.get('gt_boxes',None),
        masks = target_fields.get('gt_masks',None),
        keypoints = target_fields.get('gt_keypoints', None)
    )
     
    plt.imshow(out.get_image())
    plt.axis('off')

    del out, visualizer, labels
    
plt.tight_layout()
plt.show()

del mapper; clean_memory()
# Out:
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(12, 25), mask_y_length=(12, 25), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(12, 25), hole_width_range=(12, 25)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)

# %% [markdown]
# ## 6. Setting Detectron2 Model Config
# ___
#
# 📌 [**Detectron2's Default CfgNode**](https://github.com/facebookresearch/detectron2/blob/main/detectron2/config/defaults.pyall)

# %%
from detectron2.config import CfgNode as CN

cfg = get_cfg()
cfg.OUTPUT_DIR = CFG.output_dir

## R_50_FPN_1x, R_50_FPN_3x, R_101_FPN_3x, X_101_32x8d_FPN_3x 

config_name = "COCO-Detection/faster_rcnn_R_50_FPN_1x.yaml"
cfg.merge_from_file(model_zoo.get_config_file(config_name))

cfg.INPUT.F0RMAT = CFG.input_format
cfg.DATASETS.TRAIN = ('gastroscopy_train',)
cfg.DATASETS.TEST = ('gastroscopy_valid',)
cfg.TEST.EVAL_PREIOD = CFG.eval_period
cfg.DATALOADER.NUM_WORKERS = CFG.num_workers

cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(config_name)
cfg.MODEL.BACKBONE.FREEZE_AT = 2

cfg.MODEL.FPN.IN_FEATURES = ['res2','res3','res4','res5']
cfg.MODEL.FPN.OUT_CHANNELS = 256
cfg.MODEL.FPN.FUSE_TYPE = 'sum'
cfg.MODEL.FPN.NORM = ""

cfg.MODEL.ANCHOR_GENERATOR.SIZES = [[32, 64, 128, 256, 512]]
cfg.MODEL.ANCHOR_GENERATOR.ASPECT_RATIOS = [[0.5, 1.0, 2.0]]
cfg.MODEL.ANCHOR_GENERATOR.OFFSET = 0.5

## RPN Options
cfg.MODEL.RPN.IN_FEATURES = ["p2", "p3", "p4", "p5", "p6"]
cfg.MODEL.RPN.IOU_THRESHOLDS = [0.3, 0.7]
cfg.MODEL.RPN.BATCH_SIZE_PER_IMAGE = 256
cfg.MODEL.RPN.BBOX_REG_LOSS_TYPE = 'smooth_l1'
cfg.MODEL.RPN.BBOX_REG_LOSS_WEIGHT = 1.0
cfg.MODEL.RPN.POSITIVE_FRACTION = 0.5
cfg.MODEL.RPN.PRE_NMS_TOPK_TRAIN = 2000 # Per FPN Levels
cfg.MODEL.RPN.PRE_NMS_TOPK_TEST = 1000 # Per FPN Levels
cfg.MODEL.RPN.POST_NMS_TOPK = 1000 # Total
cfg.MODEL.RPN.POST_NMS_TOPK_TEST = 500

## ROI Options
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.IN_FEATURES = ['p2','p3','p4','p5']
cfg.MODEL.ROI_HEADS.POSITIVE_FRACTION = 0.25
cfg.MODEL.ROI_HEADS.IOU_THRESHOLDS = [0.5]
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(thing_classes)
cfg.MODEL.ROI_BOX_HEAD.POOLR_TYPE = 'ROIAlignV2'
cfg.MODEL.ROI_BOX_HEAD.BBOX_RGE_LOSS_TYPE = 'smooth_l1'
cfg.MODEL.ROI_BOX_HEAD.BBOX_REG_LOSS_WEIGHT = 1.0
cfg.MODEL.ROI_BOX_HEAD.POOLER_RESOLUTION = 14

## Solver(Optimizer and Scheduler Builders)
cfg.SOLVER.IMS_PER_BATCH = CFG.ims_per_batch
cfg.SOLVER.LR_SCHEDULER_NAME = CFG.lr_scheduler_name
cfg.SOLVER.BASE_LR = CFG.base_lr
cfg.SOLVER.AMP.ENABLED = CFG.amp
cfg.SOLVER.WEIGHT_DECAY = CFG.weight_decay
cfg.SOLVER.MAX_ITER = CFG.max_iter
cfg.SOLVER.WARMUP_ITERS = CFG.warmup_iters
cfg.SOLVER.WARMUP_FACTOR = CFG.warmup_factor
cfg.SOLVER.CHECKPOINT_PREIOD = CFG.eval_period

## Post Processing
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.00 # No More Penalty for adding lower box
cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.5
cfg.TEST.DETECTIONS_PER_IMAGE = 100 # 200, 300, 400, 500

print(f"{Fore.BLUE}=> Completed Setting Detectron2's Model Config !")
# Out:
# => Completed Setting Detectron2's Model Config !

# %% [markdown]
# ### Save Config Yaml

# %%
import yaml

with open(os.path.join(CFG.output_dir, 'config.yaml'), mode='w') as f:
    yaml.dump(cfg.dump(), f, default_flow_style=False, sort_keys=False, indent=4)

print(f'{Fore.BLUE}=> Yaml File Completely Saved !')
# Out:
# => Yaml File Completely Saved !

# %%
SHOW = False

if SHOW:
   with open(os.path.join(CFG.output_dir, 'config.yaml'), mode='r') as f:
       print(yaml.safe_load(f))

# %% [markdown]
# ## 7. Training
# ___

# %%
trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False) # load last checkpoint or MODEL.WEIGHTS

trainer.train()

torch.cuda.empty_cache()
clean_memory(); del trainer
# Out:
# [02/01 03:20:52 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 15, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 60, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=50176, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#   )
# )
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(12, 25), mask_y_length=(12, 25), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(12, 25), hole_width_range=(12, 25)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [02/01 03:20:52 d2.data.build]: Removed 0 images with no usable annotations. 1277 images left.
# [02/01 03:20:52 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 467          |   Polyp    | 603          |   Cancer   | 743          |
# |            |              |            |              |            |              |
# |   total    | 1813         |            |              |            |              |
# [02/01 03:20:52 d2.data.build]: Using training sampler TrainingSampler
# [02/01 03:20:52 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/01 03:20:52 d2.data.common]: Serializing 1277 elements to byte tensors and concatenating them all ...
# [02/01 03:20:52 d2.data.common]: Serialized dataset takes 0.38 MiB
# [02/01 03:20:52 d2.data.build]: Making batched data loader with batch_size=8
# [02/01 03:20:52 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_1x/137257794/model_final_b275ba.pkl ...
# model_final_b275ba.pkl: 167MB [00:00, 198MB/s]
# [02/01 03:20:53 d2.engine.train_loop]: Starting training from iteration 0
# [02/01 03:21:10 d2.utils.events]:  eta: 0:57:11  iter: 19  total_loss: 2.285  loss_cls: 1.197  loss_box_reg: 0.1611  loss_rpn_cls: 0.6592  loss_rpn_loc: 0.2657    time: 0.6541  last_time: 0.5286  data_time: 0.0309  last_data_time: 0.0265   lr: 0.00075625  max_mem: 3197M
# [02/01 03:21:35 d2.utils.events]:  eta: 0:57:10  iter: 39  total_loss: 1.221  loss_cls: 0.3277  loss_box_reg: 0.2765  loss_rpn_cls: 0.408  loss_rpn_loc: 0.2028    time: 0.6673  last_time: 0.7032  data_time: 0.0212  last_data_time: 0.0295   lr: 0.0015512  max_mem: 3197M
# [02/01 03:21:49 d2.utils.events]:  eta: 0:56:53  iter: 59  total_loss: 0.9935  loss_cls: 0.2932  loss_box_reg: 0.301  loss_rpn_cls: 0.2494  loss_rpn_loc: 0.1829    time: 0.6731  last_time: 0.7456  data_time: 0.0386  last_data_time: 0.0209   lr: 0.0023462  max_mem: 3197M
# [02/01 03:22:02 d2.utils.events]:  eta: 0:56:39  iter: 79  total_loss: 0.9627  loss_cls: 0.2595  loss_box_reg: 0.2904  loss_rpn_cls: 0.1972  loss_rpn_loc: 0.1755    time: 0.6741  last_time: 0.7126  data_time: 0.0241  last_data_time: 0.0284   lr: 0.0031412  max_mem: 3197M
# [02/01 03:22:16 d2.utils.events]:  eta: 0:56:39  iter: 99  total_loss: 1.053  loss_cls: 0.2677  loss_box_reg: 0.384  loss_rpn_cls: 0.1889  loss_rpn_loc: 0.2049    time: 0.6795  last_time: 0.6939  data_time: 0.0247  last_data_time: 0.0228   lr: 0.0039362  max_mem: 3197M
# [02/01 03:22:30 d2.utils.events]:  eta: 0:56:28  iter: 119  total_loss: 1.023  loss_cls: 0.2959  loss_box_reg: 0.3603  loss_rpn_cls: 0.1707  loss_rpn_loc: 0.1872    time: 0.6797  last_time: 0.7004  data_time: 0.0263  last_data_time: 0.0321   lr: 0.0047312  max_mem: 3197M
# [02/01 03:22:44 d2.utils.events]:  eta: 0:56:22  iter: 139  total_loss: 0.9247  loss_cls: 0.2491  loss_box_reg: 0.3132  loss_rpn_cls: 0.1415  loss_rpn_loc: 0.1742    time: 0.6814  last_time: 0.6968  data_time: 0.0275  last_data_time: 0.0210   lr: 0.0055262  max_mem: 3197M
# [02/01 03:22:57 d2.utils.events]:  eta: 0:56:08  iter: 159  total_loss: 0.952  loss_cls: 0.2709  loss_box_reg: 0.3156  loss_rpn_cls: 0.1781  loss_rpn_loc: 0.1932    time: 0.6803  last_time: 0.7049  data_time: 0.0248  last_data_time: 0.0271   lr: 0.0063212  max_mem: 3197M
# [02/01 03:23:11 d2.utils.events]:  eta: 0:55:56  iter: 179  total_loss: 0.8684  loss_cls: 0.2461  loss_box_reg: 0.33  loss_rpn_cls: 0.1413  loss_rpn_loc: 0.1662    time: 0.6822  last_time: 0.7032  data_time: 0.0329  last_data_time: 0.0253   lr: 0.0071162  max_mem: 3197M
# [02/01 03:23:25 d2.utils.events]:  eta: 0:55:47  iter: 199  total_loss: 0.9175  loss_cls: 0.2646  loss_box_reg: 0.3088  loss_rpn_cls: 0.1476  loss_rpn_loc: 0.1649    time: 0.6849  last_time: 0.6948  data_time: 0.0435  last_data_time: 0.0302   lr: 0.0079112  max_mem: 3197M
# [02/01 03:23:39 d2.utils.events]:  eta: 0:55:34  iter: 219  total_loss: 0.844  loss_cls: 0.2415  loss_box_reg: 0.3327  loss_rpn_cls: 0.1116  loss_rpn_loc: 0.1599    time: 0.6847  last_time: 0.7167  data_time: 0.0308  last_data_time: 0.0338   lr: 0.0087062  max_mem: 3197M
# [02/01 03:23:53 d2.utils.events]:  eta: 0:55:24  iter: 239  total_loss: 0.8746  loss_cls: 0.2338  loss_box_reg: 0.2882  loss_rpn_cls: 0.1389  loss_rpn_loc: 0.1598    time: 0.6851  last_time: 0.6975  data_time: 0.0322  last_data_time: 0.0319   lr: 0.0095012  max_mem: 3197M
# [02/01 03:24:07 d2.utils.events]:  eta: 0:55:10  iter: 259  total_loss: 0.8987  loss_cls: 0.2544  loss_box_reg: 0.314  loss_rpn_cls: 0.1506  loss_rpn_loc: 0.1809    time: 0.6856  last_time: 0.7241  data_time: 0.0406  last_data_time: 0.0366   lr: 0.0099339  max_mem: 3197M
# [02/01 03:24:20 d2.utils.events]:  eta: 0:54:57  iter: 279  total_loss: 0.8868  loss_cls: 0.2589  loss_box_reg: 0.3215  loss_rpn_cls: 0.1139  loss_rpn_loc: 0.176    time: 0.6855  last_time: 0.6965  data_time: 0.0289  last_data_time: 0.0297   lr: 0.0099234  max_mem: 3197M
# [02/01 03:24:34 d2.utils.events]:  eta: 0:54:43  iter: 299  total_loss: 0.903  loss_cls: 0.2284  loss_box_reg: 0.3269  loss_rpn_cls: 0.1311  loss_rpn_loc: 0.1664    time: 0.6843  last_time: 0.6966  data_time: 0.0302  last_data_time: 0.0331   lr: 0.009912  max_mem: 3213M
# [02/01 03:24:48 d2.utils.events]:  eta: 0:54:31  iter: 319  total_loss: 0.8946  loss_cls: 0.2396  loss_box_reg: 0.3299  loss_rpn_cls: 0.1412  loss_rpn_loc: 0.1729    time: 0.6850  last_time: 0.6939  data_time: 0.0316  last_data_time: 0.0339   lr: 0.0098999  max_mem: 3213M
# [02/01 03:25:01 d2.utils.events]:  eta: 0:54:15  iter: 339  total_loss: 0.8069  loss_cls: 0.2517  loss_box_reg: 0.2863  loss_rpn_cls: 0.1187  loss_rpn_loc: 0.1572    time: 0.6842  last_time: 0.5098  data_time: 0.0312  last_data_time: 0.0313   lr: 0.009887  max_mem: 3213M
# [02/01 03:25:15 d2.utils.events]:  eta: 0:54:03  iter: 359  total_loss: 0.7546  loss_cls: 0.2177  loss_box_reg: 0.2981  loss_rpn_cls: 0.1057  loss_rpn_loc: 0.1469    time: 0.6849  last_time: 0.5389  data_time: 0.0425  last_data_time: 0.0395   lr: 0.0098733  max_mem: 3213M
# [02/01 03:25:28 d2.utils.events]:  eta: 0:53:49  iter: 379  total_loss: 0.8732  loss_cls: 0.2381  loss_box_reg: 0.3441  loss_rpn_cls: 0.09247  loss_rpn_loc: 0.1584    time: 0.6844  last_time: 0.6964  data_time: 0.0313  last_data_time: 0.0408   lr: 0.0098589  max_mem: 3213M
# [02/01 03:25:42 d2.utils.events]:  eta: 0:53:35  iter: 399  total_loss: 0.7894  loss_cls: 0.2209  loss_box_reg: 0.3033  loss_rpn_cls: 0.1052  loss_rpn_loc: 0.1337    time: 0.6853  last_time: 0.6983  data_time: 0.0313  last_data_time: 0.0377   lr: 0.0098437  max_mem: 3213M
# [02/01 03:25:56 d2.utils.events]:  eta: 0:53:22  iter: 419  total_loss: 0.8231  loss_cls: 0.2405  loss_box_reg: 0.305  loss_rpn_cls: 0.1129  loss_rpn_loc: 0.1672    time: 0.6858  last_time: 0.6961  data_time: 0.0327  last_data_time: 0.0289   lr: 0.0098277  max_mem: 3213M
# [02/01 03:26:11 d2.utils.events]:  eta: 0:53:09  iter: 439  total_loss: 0.814  loss_cls: 0.2387  loss_box_reg: 0.311  loss_rpn_cls: 0.1148  loss_rpn_loc: 0.1429    time: 0.6868  last_time: 0.7188  data_time: 0.0327  last_data_time: 0.0337   lr: 0.009811  max_mem: 3213M
# [02/01 03:26:24 d2.utils.events]:  eta: 0:52:56  iter: 459  total_loss: 0.785  loss_cls: 0.2358  loss_box_reg: 0.305  loss_rpn_cls: 0.09146  loss_rpn_loc: 0.1373    time: 0.6868  last_time: 0.7115  data_time: 0.0320  last_data_time: 0.0360   lr: 0.0097935  max_mem: 3213M
# [02/01 03:26:38 d2.utils.events]:  eta: 0:52:43  iter: 479  total_loss: 0.792  loss_cls: 0.2349  loss_box_reg: 0.3292  loss_rpn_cls: 0.09852  loss_rpn_loc: 0.1661    time: 0.6873  last_time: 0.7093  data_time: 0.0434  last_data_time: 0.0295   lr: 0.0097753  max_mem: 3213M
# [02/01 03:26:53 d2.utils.events]:  eta: 0:52:30  iter: 499  total_loss: 0.8023  loss_cls: 0.2214  loss_box_reg: 0.3272  loss_rpn_cls: 0.1082  loss_rpn_loc: 0.1526    time: 0.6881  last_time: 0.7106  data_time: 0.0408  last_data_time: 0.0362   lr: 0.0097563  max_mem: 3213M
# [02/01 03:27:06 d2.utils.events]:  eta: 0:52:16  iter: 519  total_loss: 0.8061  loss_cls: 0.2101  loss_box_reg: 0.3313  loss_rpn_cls: 0.09071  loss_rpn_loc: 0.1348    time: 0.6883  last_time: 0.6977  data_time: 0.0404  last_data_time: 0.0289   lr: 0.0097365  max_mem: 3213M
# [02/01 03:27:20 d2.utils.events]:  eta: 0:52:02  iter: 539  total_loss: 0.8007  loss_cls: 0.2368  loss_box_reg: 0.2931  loss_rpn_cls: 0.1104  loss_rpn_loc: 0.1479    time: 0.6887  last_time: 0.7122  data_time: 0.0404  last_data_time: 0.0426   lr: 0.009716  max_mem: 3213M
# [02/01 03:27:34 d2.utils.events]:  eta: 0:51:50  iter: 559  total_loss: 0.7459  loss_cls: 0.2003  loss_box_reg: 0.2966  loss_rpn_cls: 0.09174  loss_rpn_loc: 0.1539    time: 0.6893  last_time: 0.7033  data_time: 0.0297  last_data_time: 0.0256   lr: 0.0096948  max_mem: 3234M
# [02/01 03:27:49 d2.utils.events]:  eta: 0:51:36  iter: 579  total_loss: 0.7294  loss_cls: 0.2207  loss_box_reg: 0.3144  loss_rpn_cls: 0.07712  loss_rpn_loc: 0.1319    time: 0.6898  last_time: 0.6806  data_time: 0.0397  last_data_time: 0.0195   lr: 0.0096728  max_mem: 3234M
# [02/01 03:28:02 d2.utils.events]:  eta: 0:51:22  iter: 599  total_loss: 0.7536  loss_cls: 0.21  loss_box_reg: 0.3305  loss_rpn_cls: 0.07533  loss_rpn_loc: 0.1319    time: 0.6899  last_time: 0.6886  data_time: 0.0331  last_data_time: 0.0271   lr: 0.00965  max_mem: 3234M
# [02/01 03:28:16 d2.utils.events]:  eta: 0:51:07  iter: 619  total_loss: 0.7177  loss_cls: 0.2332  loss_box_reg: 0.3116  loss_rpn_cls: 0.08102  loss_rpn_loc: 0.1191    time: 0.6902  last_time: 0.6994  data_time: 0.0391  last_data_time: 0.0274   lr: 0.0096266  max_mem: 3234M
# [02/01 03:28:30 d2.utils.events]:  eta: 0:50:53  iter: 639  total_loss: 0.6603  loss_cls: 0.1715  loss_box_reg: 0.2786  loss_rpn_cls: 0.0754  loss_rpn_loc: 0.1299    time: 0.6902  last_time: 0.6892  data_time: 0.0309  last_data_time: 0.0327   lr: 0.0096024  max_mem: 3271M
# [02/01 03:28:44 d2.utils.events]:  eta: 0:50:38  iter: 659  total_loss: 0.6975  loss_cls: 0.181  loss_box_reg: 0.2806  loss_rpn_cls: 0.0661  loss_rpn_loc: 0.1315    time: 0.6904  last_time: 0.6957  data_time: 0.0320  last_data_time: 0.0309   lr: 0.0095775  max_mem: 3271M
# [02/01 03:28:58 d2.utils.events]:  eta: 0:50:24  iter: 679  total_loss: 0.7196  loss_cls: 0.1992  loss_box_reg: 0.2822  loss_rpn_cls: 0.07697  loss_rpn_loc: 0.1389    time: 0.6906  last_time: 0.6982  data_time: 0.0315  last_data_time: 0.0326   lr: 0.0095518  max_mem: 3271M
# [02/01 03:29:12 d2.utils.events]:  eta: 0:50:10  iter: 699  total_loss: 0.739  loss_cls: 0.2023  loss_box_reg: 0.307  loss_rpn_cls: 0.0907  loss_rpn_loc: 0.152    time: 0.6907  last_time: 0.6944  data_time: 0.0302  last_data_time: 0.0299   lr: 0.0095255  max_mem: 3271M
# [02/01 03:29:27 d2.utils.events]:  eta: 0:49:57  iter: 719  total_loss: 0.8315  loss_cls: 0.2353  loss_box_reg: 0.3312  loss_rpn_cls: 0.0881  loss_rpn_loc: 0.1505    time: 0.6916  last_time: 0.7284  data_time: 0.0543  last_data_time: 0.0413   lr: 0.0094984  max_mem: 3271M
# [02/01 03:29:40 d2.utils.events]:  eta: 0:49:44  iter: 739  total_loss: 0.7543  loss_cls: 0.2198  loss_box_reg: 0.2921  loss_rpn_cls: 0.08632  loss_rpn_loc: 0.1322    time: 0.6917  last_time: 0.7203  data_time: 0.0410  last_data_time: 0.0373   lr: 0.0094706  max_mem: 3271M
# [02/01 03:29:54 d2.utils.events]:  eta: 0:49:30  iter: 759  total_loss: 0.7505  loss_cls: 0.1933  loss_box_reg: 0.2989  loss_rpn_cls: 0.09866  loss_rpn_loc: 0.1432    time: 0.6919  last_time: 0.5227  data_time: 0.0400  last_data_time: 0.0326   lr: 0.0094421  max_mem: 3271M
# [02/01 03:30:08 d2.utils.events]:  eta: 0:49:16  iter: 779  total_loss: 0.749  loss_cls: 0.2056  loss_box_reg: 0.2896  loss_rpn_cls: 0.08355  loss_rpn_loc: 0.1316    time: 0.6913  last_time: 0.6972  data_time: 0.0331  last_data_time: 0.0275   lr: 0.0094129  max_mem: 3271M
# [02/01 03:30:22 d2.utils.events]:  eta: 0:49:04  iter: 799  total_loss: 0.6936  loss_cls: 0.1983  loss_box_reg: 0.2885  loss_rpn_cls: 0.06759  loss_rpn_loc: 0.1249    time: 0.6915  last_time: 0.7101  data_time: 0.0304  last_data_time: 0.0353   lr: 0.009383  max_mem: 3271M
# [02/01 03:30:36 d2.utils.events]:  eta: 0:48:50  iter: 819  total_loss: 0.7152  loss_cls: 0.2197  loss_box_reg: 0.2939  loss_rpn_cls: 0.07048  loss_rpn_loc: 0.1158    time: 0.6915  last_time: 0.6983  data_time: 0.0319  last_data_time: 0.0317   lr: 0.0093525  max_mem: 3271M
# [02/01 03:30:50 d2.utils.events]:  eta: 0:48:36  iter: 839  total_loss: 0.6906  loss_cls: 0.1976  loss_box_reg: 0.2994  loss_rpn_cls: 0.08043  loss_rpn_loc: 0.1115    time: 0.6919  last_time: 0.6949  data_time: 0.0627  last_data_time: 0.0288   lr: 0.0093212  max_mem: 3271M
# [02/01 03:31:03 d2.utils.events]:  eta: 0:48:22  iter: 859  total_loss: 0.6593  loss_cls: 0.1711  loss_box_reg: 0.2787  loss_rpn_cls: 0.05475  loss_rpn_loc: 0.1269    time: 0.6914  last_time: 0.7091  data_time: 0.0294  last_data_time: 0.0382   lr: 0.0092892  max_mem: 3271M
# [02/01 03:31:17 d2.utils.events]:  eta: 0:48:08  iter: 879  total_loss: 0.7385  loss_cls: 0.2046  loss_box_reg: 0.3217  loss_rpn_cls: 0.05896  loss_rpn_loc: 0.1401    time: 0.6913  last_time: 0.7018  data_time: 0.0305  last_data_time: 0.0300   lr: 0.0092566  max_mem: 3271M
# [02/01 03:31:31 d2.utils.events]:  eta: 0:47:54  iter: 899  total_loss: 0.7189  loss_cls: 0.2007  loss_box_reg: 0.286  loss_rpn_cls: 0.07568  loss_rpn_loc: 0.1278    time: 0.6912  last_time: 0.7134  data_time: 0.0316  last_data_time: 0.0345   lr: 0.0092233  max_mem: 3271M
# [02/01 03:31:45 d2.utils.events]:  eta: 0:47:40  iter: 919  total_loss: 0.6491  loss_cls: 0.1824  loss_box_reg: 0.2623  loss_rpn_cls: 0.07837  loss_rpn_loc: 0.1137    time: 0.6914  last_time: 0.6948  data_time: 0.0278  last_data_time: 0.0223   lr: 0.0091894  max_mem: 3271M
# [02/01 03:31:59 d2.utils.events]:  eta: 0:47:26  iter: 939  total_loss: 0.6222  loss_cls: 0.1748  loss_box_reg: 0.2691  loss_rpn_cls: 0.07789  loss_rpn_loc: 0.1229    time: 0.6917  last_time: 0.7018  data_time: 0.0416  last_data_time: 0.0306   lr: 0.0091547  max_mem: 3290M
# [02/01 03:32:13 d2.utils.events]:  eta: 0:47:12  iter: 959  total_loss: 0.6852  loss_cls: 0.1773  loss_box_reg: 0.2832  loss_rpn_cls: 0.07202  loss_rpn_loc: 0.132    time: 0.6917  last_time: 0.7078  data_time: 0.0448  last_data_time: 0.0376   lr: 0.0091194  max_mem: 3290M
# [02/01 03:32:26 d2.utils.events]:  eta: 0:46:58  iter: 979  total_loss: 0.6873  loss_cls: 0.1799  loss_box_reg: 0.2703  loss_rpn_cls: 0.06654  loss_rpn_loc: 0.1237    time: 0.6916  last_time: 0.7026  data_time: 0.0414  last_data_time: 0.0324   lr: 0.0090835  max_mem: 3290M
# [02/01 03:32:41 d2.utils.events]:  eta: 0:46:45  iter: 999  total_loss: 0.7076  loss_cls: 0.2039  loss_box_reg: 0.3148  loss_rpn_cls: 0.06911  loss_rpn_loc: 0.1297    time: 0.6920  last_time: 0.7027  data_time: 0.0348  last_data_time: 0.0348   lr: 0.0090469  max_mem: 3290M
# [02/01 03:32:55 d2.utils.events]:  eta: 0:46:32  iter: 1019  total_loss: 0.6524  loss_cls: 0.2012  loss_box_reg: 0.2991  loss_rpn_cls: 0.05921  loss_rpn_loc: 0.1152    time: 0.6921  last_time: 0.7311  data_time: 0.0399  last_data_time: 0.0335   lr: 0.0090097  max_mem: 3290M
# [02/01 03:33:08 d2.utils.events]:  eta: 0:46:18  iter: 1039  total_loss: 0.6925  loss_cls: 0.1808  loss_box_reg: 0.2831  loss_rpn_cls: 0.08196  loss_rpn_loc: 0.111    time: 0.6917  last_time: 0.5233  data_time: 0.0288  last_data_time: 0.0314   lr: 0.0089719  max_mem: 3290M
# [02/01 03:33:22 d2.utils.events]:  eta: 0:46:05  iter: 1059  total_loss: 0.7025  loss_cls: 0.1919  loss_box_reg: 0.3091  loss_rpn_cls: 0.06603  loss_rpn_loc: 0.1085    time: 0.6921  last_time: 0.9556  data_time: 0.0422  last_data_time: 0.2788   lr: 0.0089334  max_mem: 3290M
# [02/01 03:33:36 d2.utils.events]:  eta: 0:45:53  iter: 1079  total_loss: 0.6643  loss_cls: 0.1921  loss_box_reg: 0.2671  loss_rpn_cls: 0.08517  loss_rpn_loc: 0.1072    time: 0.6919  last_time: 0.6998  data_time: 0.0314  last_data_time: 0.0261   lr: 0.0088943  max_mem: 3290M
# [02/01 03:33:50 d2.utils.events]:  eta: 0:45:39  iter: 1099  total_loss: 0.6386  loss_cls: 0.165  loss_box_reg: 0.2689  loss_rpn_cls: 0.06874  loss_rpn_loc: 0.1188    time: 0.6916  last_time: 0.7066  data_time: 0.0307  last_data_time: 0.0233   lr: 0.0088546  max_mem: 3290M
# [02/01 03:34:04 d2.utils.events]:  eta: 0:45:26  iter: 1119  total_loss: 0.7049  loss_cls: 0.2109  loss_box_reg: 0.3035  loss_rpn_cls: 0.06626  loss_rpn_loc: 0.1159    time: 0.6921  last_time: 0.7184  data_time: 0.0433  last_data_time: 0.0330   lr: 0.0088142  max_mem: 3290M
# [02/01 03:34:18 d2.utils.events]:  eta: 0:45:12  iter: 1139  total_loss: 0.656  loss_cls: 0.1941  loss_box_reg: 0.2928  loss_rpn_cls: 0.05613  loss_rpn_loc: 0.1021    time: 0.6922  last_time: 0.9167  data_time: 0.0433  last_data_time: 0.2456   lr: 0.0087733  max_mem: 3290M
# [02/01 03:34:32 d2.utils.events]:  eta: 0:44:58  iter: 1159  total_loss: 0.662  loss_cls: 0.1719  loss_box_reg: 0.3039  loss_rpn_cls: 0.05412  loss_rpn_loc: 0.1189    time: 0.6920  last_time: 0.7045  data_time: 0.0306  last_data_time: 0.0284   lr: 0.0087318  max_mem: 3290M
# [02/01 03:34:46 d2.utils.events]:  eta: 0:44:44  iter: 1179  total_loss: 0.6212  loss_cls: 0.1774  loss_box_reg: 0.2914  loss_rpn_cls: 0.05026  loss_rpn_loc: 0.1061    time: 0.6922  last_time: 0.6986  data_time: 0.0413  last_data_time: 0.0253   lr: 0.0086897  max_mem: 3290M
# [02/01 03:34:59 d2.utils.events]:  eta: 0:44:30  iter: 1199  total_loss: 0.573  loss_cls: 0.1481  loss_box_reg: 0.2376  loss_rpn_cls: 0.0606  loss_rpn_loc: 0.1087    time: 0.6922  last_time: 0.6909  data_time: 0.0307  last_data_time: 0.0332   lr: 0.008647  max_mem: 3290M
# [02/01 03:35:14 d2.utils.events]:  eta: 0:44:16  iter: 1219  total_loss: 0.5926  loss_cls: 0.1775  loss_box_reg: 0.2667  loss_rpn_cls: 0.05369  loss_rpn_loc: 0.1064    time: 0.6924  last_time: 0.5238  data_time: 0.0442  last_data_time: 0.0353   lr: 0.0086037  max_mem: 3290M
# [02/01 03:35:27 d2.utils.events]:  eta: 0:44:01  iter: 1239  total_loss: 0.6619  loss_cls: 0.1734  loss_box_reg: 0.2841  loss_rpn_cls: 0.05771  loss_rpn_loc: 0.1146    time: 0.6923  last_time: 0.6922  data_time: 0.0309  last_data_time: 0.0227   lr: 0.0085599  max_mem: 3310M
# [02/01 03:35:40 d2.utils.events]:  eta: 0:43:47  iter: 1259  total_loss: 0.5853  loss_cls: 0.1597  loss_box_reg: 0.2542  loss_rpn_cls: 0.05435  loss_rpn_loc: 0.1024    time: 0.6917  last_time: 0.6987  data_time: 0.0310  last_data_time: 0.0239   lr: 0.0085155  max_mem: 3310M
# [02/01 03:35:54 d2.utils.events]:  eta: 0:43:33  iter: 1279  total_loss: 0.6236  loss_cls: 0.1581  loss_box_reg: 0.2968  loss_rpn_cls: 0.05984  loss_rpn_loc: 0.1094    time: 0.6918  last_time: 0.6936  data_time: 0.0436  last_data_time: 0.0272   lr: 0.0084705  max_mem: 3310M
# [02/01 03:36:08 d2.utils.events]:  eta: 0:43:19  iter: 1299  total_loss: 0.603  loss_cls: 0.1675  loss_box_reg: 0.256  loss_rpn_cls: 0.05503  loss_rpn_loc: 0.1011    time: 0.6913  last_time: 0.7044  data_time: 0.0321  last_data_time: 0.0325   lr: 0.008425  max_mem: 3310M
# [02/01 03:36:21 d2.utils.events]:  eta: 0:43:04  iter: 1319  total_loss: 0.6312  loss_cls: 0.1695  loss_box_reg: 0.2607  loss_rpn_cls: 0.04556  loss_rpn_loc: 0.1182    time: 0.6913  last_time: 0.6950  data_time: 0.0305  last_data_time: 0.0327   lr: 0.008379  max_mem: 3310M
# [02/01 03:36:35 d2.utils.events]:  eta: 0:42:51  iter: 1339  total_loss: 0.5904  loss_cls: 0.1612  loss_box_reg: 0.269  loss_rpn_cls: 0.05516  loss_rpn_loc: 0.11    time: 0.6914  last_time: 0.7062  data_time: 0.0341  last_data_time: 0.0368   lr: 0.0083324  max_mem: 3310M
# [02/01 03:36:50 d2.utils.events]:  eta: 0:42:37  iter: 1359  total_loss: 0.599  loss_cls: 0.1754  loss_box_reg: 0.2726  loss_rpn_cls: 0.06243  loss_rpn_loc: 0.1009    time: 0.6917  last_time: 0.7046  data_time: 0.0432  last_data_time: 0.0300   lr: 0.0082853  max_mem: 3310M
# [02/01 03:37:04 d2.utils.events]:  eta: 0:42:23  iter: 1379  total_loss: 0.5647  loss_cls: 0.1465  loss_box_reg: 0.2568  loss_rpn_cls: 0.05468  loss_rpn_loc: 0.1094    time: 0.6918  last_time: 0.6987  data_time: 0.0532  last_data_time: 0.0403   lr: 0.0082377  max_mem: 3310M
# [02/01 03:37:17 d2.utils.events]:  eta: 0:42:09  iter: 1399  total_loss: 0.5667  loss_cls: 0.1569  loss_box_reg: 0.2579  loss_rpn_cls: 0.04259  loss_rpn_loc: 0.1132    time: 0.6917  last_time: 0.7013  data_time: 0.0306  last_data_time: 0.0279   lr: 0.0081895  max_mem: 3310M
# [02/01 03:37:31 d2.utils.events]:  eta: 0:41:54  iter: 1419  total_loss: 0.5496  loss_cls: 0.1441  loss_box_reg: 0.2475  loss_rpn_cls: 0.05893  loss_rpn_loc: 0.106    time: 0.6914  last_time: 0.5374  data_time: 0.0310  last_data_time: 0.0274   lr: 0.0081409  max_mem: 3310M
# [02/01 03:37:44 d2.utils.events]:  eta: 0:41:39  iter: 1439  total_loss: 0.5749  loss_cls: 0.1465  loss_box_reg: 0.2399  loss_rpn_cls: 0.06176  loss_rpn_loc: 0.1114    time: 0.6912  last_time: 0.6906  data_time: 0.0284  last_data_time: 0.0297   lr: 0.0080918  max_mem: 3310M
# [02/01 03:37:58 d2.utils.events]:  eta: 0:41:25  iter: 1459  total_loss: 0.6057  loss_cls: 0.1548  loss_box_reg: 0.2601  loss_rpn_cls: 0.05439  loss_rpn_loc: 0.1056    time: 0.6912  last_time: 0.7063  data_time: 0.0331  last_data_time: 0.0342   lr: 0.0080421  max_mem: 3310M
# [02/01 03:38:12 d2.utils.events]:  eta: 0:41:10  iter: 1479  total_loss: 0.5565  loss_cls: 0.1426  loss_box_reg: 0.2496  loss_rpn_cls: 0.0496  loss_rpn_loc: 0.1054    time: 0.6912  last_time: 0.7159  data_time: 0.0321  last_data_time: 0.0348   lr: 0.007992  max_mem: 3310M
# [02/01 03:38:26 d2.utils.events]:  eta: 0:40:56  iter: 1499  total_loss: 0.6056  loss_cls: 0.1522  loss_box_reg: 0.2797  loss_rpn_cls: 0.05024  loss_rpn_loc: 0.1192    time: 0.6913  last_time: 0.7042  data_time: 0.0379  last_data_time: 0.0317   lr: 0.0079415  max_mem: 3310M
# [02/01 03:38:40 d2.utils.events]:  eta: 0:40:42  iter: 1519  total_loss: 0.4949  loss_cls: 0.1355  loss_box_reg: 0.2255  loss_rpn_cls: 0.05004  loss_rpn_loc: 0.08636    time: 0.6912  last_time: 0.7032  data_time: 0.0306  last_data_time: 0.0336   lr: 0.0078904  max_mem: 3310M
# [02/01 03:38:54 d2.utils.events]:  eta: 0:40:28  iter: 1539  total_loss: 0.5664  loss_cls: 0.1489  loss_box_reg: 0.2542  loss_rpn_cls: 0.05151  loss_rpn_loc: 0.09656    time: 0.6912  last_time: 0.6992  data_time: 0.0334  last_data_time: 0.0339   lr: 0.0078389  max_mem: 3310M
# [02/01 03:39:07 d2.utils.events]:  eta: 0:40:13  iter: 1559  total_loss: 0.6061  loss_cls: 0.1655  loss_box_reg: 0.2659  loss_rpn_cls: 0.06162  loss_rpn_loc: 0.1007    time: 0.6912  last_time: 0.7050  data_time: 0.0305  last_data_time: 0.0285   lr: 0.007787  max_mem: 3310M
# [02/01 03:39:21 d2.utils.events]:  eta: 0:39:59  iter: 1579  total_loss: 0.5368  loss_cls: 0.1585  loss_box_reg: 0.2489  loss_rpn_cls: 0.04672  loss_rpn_loc: 0.09565    time: 0.6911  last_time: 0.6973  data_time: 0.0304  last_data_time: 0.0327   lr: 0.0077346  max_mem: 3310M
# [02/01 03:39:34 d2.utils.events]:  eta: 0:39:45  iter: 1599  total_loss: 0.5699  loss_cls: 0.1602  loss_box_reg: 0.2632  loss_rpn_cls: 0.06183  loss_rpn_loc: 0.09957    time: 0.6908  last_time: 0.7025  data_time: 0.0316  last_data_time: 0.0227   lr: 0.0076818  max_mem: 3310M
# [02/01 03:39:48 d2.utils.events]:  eta: 0:39:31  iter: 1619  total_loss: 0.537  loss_cls: 0.1295  loss_box_reg: 0.2414  loss_rpn_cls: 0.03927  loss_rpn_loc: 0.09799    time: 0.6906  last_time: 0.7001  data_time: 0.0305  last_data_time: 0.0350   lr: 0.0076285  max_mem: 3310M
# [02/01 03:40:02 d2.utils.events]:  eta: 0:39:17  iter: 1639  total_loss: 0.533  loss_cls: 0.1543  loss_box_reg: 0.2335  loss_rpn_cls: 0.04161  loss_rpn_loc: 0.1034    time: 0.6907  last_time: 0.7002  data_time: 0.0313  last_data_time: 0.0312   lr: 0.0075749  max_mem: 3310M
# [02/01 03:40:15 d2.utils.events]:  eta: 0:39:03  iter: 1659  total_loss: 0.4943  loss_cls: 0.1282  loss_box_reg: 0.2298  loss_rpn_cls: 0.03991  loss_rpn_loc: 0.08733    time: 0.6904  last_time: 0.5153  data_time: 0.0398  last_data_time: 0.0351   lr: 0.0075208  max_mem: 3310M
# [02/01 03:40:29 d2.utils.events]:  eta: 0:38:50  iter: 1679  total_loss: 0.5833  loss_cls: 0.1706  loss_box_reg: 0.246  loss_rpn_cls: 0.04418  loss_rpn_loc: 0.09634    time: 0.6906  last_time: 0.7185  data_time: 0.0333  last_data_time: 0.0409   lr: 0.0074664  max_mem: 3310M
# [02/01 03:40:43 d2.utils.events]:  eta: 0:38:35  iter: 1699  total_loss: 0.5439  loss_cls: 0.1449  loss_box_reg: 0.237  loss_rpn_cls: 0.05334  loss_rpn_loc: 0.09931    time: 0.6905  last_time: 0.6818  data_time: 0.0316  last_data_time: 0.0197   lr: 0.0074115  max_mem: 3310M
# [02/01 03:40:57 d2.utils.events]:  eta: 0:38:20  iter: 1719  total_loss: 0.5467  loss_cls: 0.1409  loss_box_reg: 0.2361  loss_rpn_cls: 0.04975  loss_rpn_loc: 0.09188    time: 0.6906  last_time: 0.6992  data_time: 0.0316  last_data_time: 0.0315   lr: 0.0073563  max_mem: 3310M
# [02/01 03:41:10 d2.utils.events]:  eta: 0:38:06  iter: 1739  total_loss: 0.5619  loss_cls: 0.1463  loss_box_reg: 0.2513  loss_rpn_cls: 0.05139  loss_rpn_loc: 0.0942    time: 0.6903  last_time: 0.5202  data_time: 0.0294  last_data_time: 0.0366   lr: 0.0073007  max_mem: 3310M
# [02/01 03:41:23 d2.utils.events]:  eta: 0:37:51  iter: 1759  total_loss: 0.5614  loss_cls: 0.145  loss_box_reg: 0.2435  loss_rpn_cls: 0.06261  loss_rpn_loc: 0.1083    time: 0.6900  last_time: 0.5062  data_time: 0.0457  last_data_time: 0.0329   lr: 0.0072447  max_mem: 3310M
# [02/01 03:41:37 d2.utils.events]:  eta: 0:37:37  iter: 1779  total_loss: 0.5286  loss_cls: 0.16  loss_box_reg: 0.2461  loss_rpn_cls: 0.04542  loss_rpn_loc: 0.09409    time: 0.6900  last_time: 0.7014  data_time: 0.0324  last_data_time: 0.0326   lr: 0.0071884  max_mem: 3310M
# [02/01 03:41:52 d2.utils.events]:  eta: 0:37:23  iter: 1799  total_loss: 0.5001  loss_cls: 0.1288  loss_box_reg: 0.2347  loss_rpn_cls: 0.05072  loss_rpn_loc: 0.0918    time: 0.6903  last_time: 0.7053  data_time: 0.0432  last_data_time: 0.0353   lr: 0.0071317  max_mem: 3310M
# [02/01 03:42:06 d2.utils.events]:  eta: 0:37:09  iter: 1819  total_loss: 0.562  loss_cls: 0.1519  loss_box_reg: 0.2595  loss_rpn_cls: 0.04298  loss_rpn_loc: 0.09381    time: 0.6904  last_time: 0.6931  data_time: 0.0305  last_data_time: 0.0249   lr: 0.0070747  max_mem: 3310M
# [02/01 03:42:19 d2.utils.events]:  eta: 0:36:54  iter: 1839  total_loss: 0.5115  loss_cls: 0.1354  loss_box_reg: 0.2128  loss_rpn_cls: 0.04879  loss_rpn_loc: 0.08274    time: 0.6902  last_time: 0.6981  data_time: 0.0397  last_data_time: 0.0249   lr: 0.0070174  max_mem: 3310M
# [02/01 03:42:33 d2.utils.events]:  eta: 0:36:41  iter: 1859  total_loss: 0.529  loss_cls: 0.1417  loss_box_reg: 0.2607  loss_rpn_cls: 0.04389  loss_rpn_loc: 0.09977    time: 0.6903  last_time: 0.7202  data_time: 0.0339  last_data_time: 0.0437   lr: 0.0069598  max_mem: 3310M
# [02/01 03:42:47 d2.utils.events]:  eta: 0:36:26  iter: 1879  total_loss: 0.4892  loss_cls: 0.126  loss_box_reg: 0.2161  loss_rpn_cls: 0.04285  loss_rpn_loc: 0.09708    time: 0.6901  last_time: 0.6931  data_time: 0.0303  last_data_time: 0.0321   lr: 0.0069018  max_mem: 3310M
# [02/01 03:43:00 d2.utils.events]:  eta: 0:36:11  iter: 1899  total_loss: 0.5421  loss_cls: 0.1592  loss_box_reg: 0.2462  loss_rpn_cls: 0.0389  loss_rpn_loc: 0.1022    time: 0.6901  last_time: 0.6935  data_time: 0.0397  last_data_time: 0.0285   lr: 0.0068435  max_mem: 3310M
# [02/01 03:43:14 d2.utils.events]:  eta: 0:35:57  iter: 1919  total_loss: 0.5576  loss_cls: 0.1574  loss_box_reg: 0.2276  loss_rpn_cls: 0.05388  loss_rpn_loc: 0.1067    time: 0.6899  last_time: 0.6916  data_time: 0.0324  last_data_time: 0.0215   lr: 0.006785  max_mem: 3310M
# [02/01 03:43:27 d2.utils.events]:  eta: 0:35:43  iter: 1939  total_loss: 0.5094  loss_cls: 0.1293  loss_box_reg: 0.2273  loss_rpn_cls: 0.04095  loss_rpn_loc: 0.09352    time: 0.6897  last_time: 0.7074  data_time: 0.0316  last_data_time: 0.0339   lr: 0.0067262  max_mem: 3310M
# [02/01 03:43:41 d2.utils.events]:  eta: 0:35:29  iter: 1959  total_loss: 0.5038  loss_cls: 0.1354  loss_box_reg: 0.2384  loss_rpn_cls: 0.04444  loss_rpn_loc: 0.08972    time: 0.6897  last_time: 0.7025  data_time: 0.0334  last_data_time: 0.0325   lr: 0.0066671  max_mem: 3310M
# [02/01 03:43:54 d2.utils.events]:  eta: 0:35:14  iter: 1979  total_loss: 0.5627  loss_cls: 0.1342  loss_box_reg: 0.2382  loss_rpn_cls: 0.04874  loss_rpn_loc: 0.08758    time: 0.6894  last_time: 0.6884  data_time: 0.0311  last_data_time: 0.0248   lr: 0.0066077  max_mem: 3310M
# [02/01 03:44:08 d2.utils.events]:  eta: 0:34:59  iter: 1999  total_loss: 0.5231  loss_cls: 0.1389  loss_box_reg: 0.2265  loss_rpn_cls: 0.04213  loss_rpn_loc: 0.08038    time: 0.6893  last_time: 0.5136  data_time: 0.0317  last_data_time: 0.0295   lr: 0.0065481  max_mem: 3310M
# [02/01 03:44:22 d2.utils.events]:  eta: 0:34:45  iter: 2019  total_loss: 0.4785  loss_cls: 0.1236  loss_box_reg: 0.2228  loss_rpn_cls: 0.03816  loss_rpn_loc: 0.0884    time: 0.6896  last_time: 0.7077  data_time: 0.0408  last_data_time: 0.0328   lr: 0.0064882  max_mem: 3346M
# [02/01 03:44:36 d2.utils.events]:  eta: 0:34:31  iter: 2039  total_loss: 0.5035  loss_cls: 0.1257  loss_box_reg: 0.2371  loss_rpn_cls: 0.04109  loss_rpn_loc: 0.08733    time: 0.6894  last_time: 0.6966  data_time: 0.0298  last_data_time: 0.0272   lr: 0.0064281  max_mem: 3346M
# [02/01 03:44:49 d2.utils.events]:  eta: 0:34:17  iter: 2059  total_loss: 0.4644  loss_cls: 0.119  loss_box_reg: 0.2126  loss_rpn_cls: 0.03675  loss_rpn_loc: 0.08237    time: 0.6892  last_time: 0.6958  data_time: 0.0340  last_data_time: 0.0335   lr: 0.0063678  max_mem: 3346M
# [02/01 03:45:03 d2.utils.events]:  eta: 0:34:02  iter: 2079  total_loss: 0.5189  loss_cls: 0.1357  loss_box_reg: 0.2382  loss_rpn_cls: 0.03629  loss_rpn_loc: 0.09354    time: 0.6893  last_time: 0.6791  data_time: 0.0403  last_data_time: 0.0191   lr: 0.0063072  max_mem: 3346M
# [02/01 03:45:17 d2.utils.events]:  eta: 0:33:48  iter: 2099  total_loss: 0.4776  loss_cls: 0.1227  loss_box_reg: 0.2294  loss_rpn_cls: 0.03621  loss_rpn_loc: 0.0815    time: 0.6894  last_time: 0.6870  data_time: 0.0315  last_data_time: 0.0303   lr: 0.0062465  max_mem: 3346M
# [02/01 03:45:31 d2.utils.events]:  eta: 0:33:33  iter: 2119  total_loss: 0.4579  loss_cls: 0.1183  loss_box_reg: 0.2189  loss_rpn_cls: 0.03699  loss_rpn_loc: 0.08949    time: 0.6893  last_time: 0.6862  data_time: 0.0310  last_data_time: 0.0209   lr: 0.0061855  max_mem: 3346M
# [02/01 03:45:45 d2.utils.events]:  eta: 0:33:19  iter: 2139  total_loss: 0.4743  loss_cls: 0.1269  loss_box_reg: 0.2334  loss_rpn_cls: 0.03212  loss_rpn_loc: 0.0834    time: 0.6895  last_time: 0.6915  data_time: 0.0415  last_data_time: 0.0277   lr: 0.0061244  max_mem: 3346M
# [02/01 03:45:59 d2.utils.events]:  eta: 0:33:05  iter: 2159  total_loss: 0.4751  loss_cls: 0.1265  loss_box_reg: 0.2237  loss_rpn_cls: 0.03869  loss_rpn_loc: 0.07767    time: 0.6895  last_time: 0.7126  data_time: 0.0306  last_data_time: 0.0305   lr: 0.0060631  max_mem: 3346M
# [02/01 03:46:12 d2.utils.events]:  eta: 0:32:51  iter: 2179  total_loss: 0.4837  loss_cls: 0.1382  loss_box_reg: 0.2204  loss_rpn_cls: 0.03697  loss_rpn_loc: 0.08487    time: 0.6893  last_time: 0.5439  data_time: 0.0331  last_data_time: 0.0516   lr: 0.0060016  max_mem: 3346M
# [02/01 03:46:26 d2.utils.events]:  eta: 0:32:37  iter: 2199  total_loss: 0.4728  loss_cls: 0.1397  loss_box_reg: 0.2168  loss_rpn_cls: 0.03444  loss_rpn_loc: 0.08002    time: 0.6894  last_time: 0.7096  data_time: 0.0298  last_data_time: 0.0235   lr: 0.00594  max_mem: 3346M
# [02/01 03:46:39 d2.utils.events]:  eta: 0:32:23  iter: 2219  total_loss: 0.482  loss_cls: 0.121  loss_box_reg: 0.2139  loss_rpn_cls: 0.03666  loss_rpn_loc: 0.08214    time: 0.6892  last_time: 0.6918  data_time: 0.0320  last_data_time: 0.0213   lr: 0.0058782  max_mem: 3346M
# [02/01 03:46:53 d2.utils.events]:  eta: 0:32:09  iter: 2239  total_loss: 0.5284  loss_cls: 0.1471  loss_box_reg: 0.2405  loss_rpn_cls: 0.04219  loss_rpn_loc: 0.0861    time: 0.6893  last_time: 0.5076  data_time: 0.0339  last_data_time: 0.0260   lr: 0.0058163  max_mem: 3346M
# [02/01 03:47:07 d2.utils.events]:  eta: 0:31:55  iter: 2259  total_loss: 0.41  loss_cls: 0.106  loss_box_reg: 0.1954  loss_rpn_cls: 0.02936  loss_rpn_loc: 0.07701    time: 0.6891  last_time: 0.6928  data_time: 0.0308  last_data_time: 0.0325   lr: 0.0057542  max_mem: 3346M
# [02/01 03:47:21 d2.utils.events]:  eta: 0:31:41  iter: 2279  total_loss: 0.4773  loss_cls: 0.1365  loss_box_reg: 0.2227  loss_rpn_cls: 0.04239  loss_rpn_loc: 0.08195    time: 0.6891  last_time: 0.6934  data_time: 0.0433  last_data_time: 0.0361   lr: 0.0056921  max_mem: 3346M
# [02/01 03:47:34 d2.utils.events]:  eta: 0:31:27  iter: 2299  total_loss: 0.4538  loss_cls: 0.1286  loss_box_reg: 0.2165  loss_rpn_cls: 0.02829  loss_rpn_loc: 0.08885    time: 0.6891  last_time: 0.5225  data_time: 0.0324  last_data_time: 0.0371   lr: 0.0056298  max_mem: 3346M
# [02/01 03:47:48 d2.utils.events]:  eta: 0:31:13  iter: 2319  total_loss: 0.5061  loss_cls: 0.1283  loss_box_reg: 0.2369  loss_rpn_cls: 0.04124  loss_rpn_loc: 0.08572    time: 0.6890  last_time: 0.7179  data_time: 0.0423  last_data_time: 0.0392   lr: 0.0055674  max_mem: 3346M
# [02/01 03:48:02 d2.utils.events]:  eta: 0:30:59  iter: 2339  total_loss: 0.4776  loss_cls: 0.1225  loss_box_reg: 0.2058  loss_rpn_cls: 0.03805  loss_rpn_loc: 0.08599    time: 0.6891  last_time: 0.7103  data_time: 0.0494  last_data_time: 0.2166   lr: 0.0055049  max_mem: 3346M
# [02/01 03:48:16 d2.utils.events]:  eta: 0:30:44  iter: 2359  total_loss: 0.4762  loss_cls: 0.1218  loss_box_reg: 0.2289  loss_rpn_cls: 0.03325  loss_rpn_loc: 0.08918    time: 0.6891  last_time: 0.6834  data_time: 0.0305  last_data_time: 0.0225   lr: 0.0054424  max_mem: 3346M
# [02/01 03:48:30 d2.utils.events]:  eta: 0:30:31  iter: 2379  total_loss: 0.4583  loss_cls: 0.125  loss_box_reg: 0.2136  loss_rpn_cls: 0.04077  loss_rpn_loc: 0.08252    time: 0.6892  last_time: 0.7098  data_time: 0.0401  last_data_time: 0.0421   lr: 0.0053798  max_mem: 3346M
# ...
# [02/01 04:09:55 d2.utils.events]:  eta: 0:08:34  iter: 4259  total_loss: 0.2452  loss_cls: 0.0609  loss_box_reg: 0.1244  loss_rpn_cls: 0.01918  loss_rpn_loc: 0.04441    time: 0.6865  last_time: 0.5092  data_time: 0.0426  last_data_time: 0.0315   lr: 0.0005322  max_mem: 3353M
# [02/01 04:10:09 d2.utils.events]:  eta: 0:08:20  iter: 4279  total_loss: 0.3114  loss_cls: 0.06774  loss_box_reg: 0.1538  loss_rpn_cls: 0.02082  loss_rpn_loc: 0.05411    time: 0.6865  last_time: 0.5161  data_time: 0.0320  last_data_time: 0.0355   lr: 0.00050435  max_mem: 3353M
# [02/01 04:10:22 d2.utils.events]:  eta: 0:08:06  iter: 4299  total_loss: 0.3058  loss_cls: 0.07933  loss_box_reg: 0.1448  loss_rpn_cls: 0.01884  loss_rpn_loc: 0.05059    time: 0.6864  last_time: 0.6960  data_time: 0.0321  last_data_time: 0.0387   lr: 0.0004772  max_mem: 3353M
# [02/01 04:10:36 d2.utils.events]:  eta: 0:07:52  iter: 4319  total_loss: 0.2717  loss_cls: 0.06364  loss_box_reg: 0.1373  loss_rpn_cls: 0.01715  loss_rpn_loc: 0.04631    time: 0.6864  last_time: 0.7062  data_time: 0.0297  last_data_time: 0.0342   lr: 0.00045077  max_mem: 3353M
# [02/01 04:10:50 d2.utils.events]:  eta: 0:07:38  iter: 4339  total_loss: 0.2983  loss_cls: 0.07742  loss_box_reg: 0.1448  loss_rpn_cls: 0.01719  loss_rpn_loc: 0.05295    time: 0.6864  last_time: 0.6911  data_time: 0.0307  last_data_time: 0.0256   lr: 0.00042506  max_mem: 3353M
# [02/01 04:11:04 d2.utils.events]:  eta: 0:07:24  iter: 4359  total_loss: 0.2664  loss_cls: 0.07329  loss_box_reg: 0.1344  loss_rpn_cls: 0.01719  loss_rpn_loc: 0.04585    time: 0.6865  last_time: 0.6840  data_time: 0.0435  last_data_time: 0.0268   lr: 0.00040007  max_mem: 3353M
# [02/01 04:11:17 d2.utils.events]:  eta: 0:07:11  iter: 4379  total_loss: 0.2909  loss_cls: 0.07916  loss_box_reg: 0.1406  loss_rpn_cls: 0.01788  loss_rpn_loc: 0.05237    time: 0.6865  last_time: 0.6827  data_time: 0.0404  last_data_time: 0.0228   lr: 0.00037581  max_mem: 3353M
# [02/01 04:11:31 d2.utils.events]:  eta: 0:06:57  iter: 4399  total_loss: 0.3174  loss_cls: 0.08348  loss_box_reg: 0.1551  loss_rpn_cls: 0.0189  loss_rpn_loc: 0.05502    time: 0.6865  last_time: 0.7078  data_time: 0.0314  last_data_time: 0.0380   lr: 0.00035227  max_mem: 3353M
# [02/01 04:11:45 d2.utils.events]:  eta: 0:06:43  iter: 4419  total_loss: 0.3252  loss_cls: 0.07836  loss_box_reg: 0.1509  loss_rpn_cls: 0.02323  loss_rpn_loc: 0.04942    time: 0.6864  last_time: 0.5209  data_time: 0.0303  last_data_time: 0.0299   lr: 0.00032948  max_mem: 3353M
# [02/01 04:11:58 d2.utils.events]:  eta: 0:06:29  iter: 4439  total_loss: 0.2831  loss_cls: 0.07074  loss_box_reg: 0.1442  loss_rpn_cls: 0.021  loss_rpn_loc: 0.0473    time: 0.6864  last_time: 0.6935  data_time: 0.0405  last_data_time: 0.0272   lr: 0.00030741  max_mem: 3353M
# [02/01 04:12:12 d2.utils.events]:  eta: 0:06:15  iter: 4459  total_loss: 0.2866  loss_cls: 0.06697  loss_box_reg: 0.1415  loss_rpn_cls: 0.01685  loss_rpn_loc: 0.04903    time: 0.6864  last_time: 0.6839  data_time: 0.0306  last_data_time: 0.0207   lr: 0.00028609  max_mem: 3353M
# [02/01 04:12:26 d2.utils.events]:  eta: 0:06:01  iter: 4479  total_loss: 0.2836  loss_cls: 0.06997  loss_box_reg: 0.1415  loss_rpn_cls: 0.01983  loss_rpn_loc: 0.0462    time: 0.6864  last_time: 0.7195  data_time: 0.0297  last_data_time: 0.0358   lr: 0.00026552  max_mem: 3353M
# [02/01 04:12:39 d2.utils.events]:  eta: 0:05:47  iter: 4499  total_loss: 0.29  loss_cls: 0.07283  loss_box_reg: 0.1459  loss_rpn_cls: 0.01716  loss_rpn_loc: 0.04658    time: 0.6864  last_time: 0.6912  data_time: 0.0315  last_data_time: 0.0328   lr: 0.00024569  max_mem: 3353M
# [02/01 04:12:53 d2.utils.events]:  eta: 0:05:33  iter: 4519  total_loss: 0.286  loss_cls: 0.0759  loss_box_reg: 0.1408  loss_rpn_cls: 0.0196  loss_rpn_loc: 0.05053    time: 0.6863  last_time: 0.6870  data_time: 0.0297  last_data_time: 0.0294   lr: 0.00022661  max_mem: 3353M
# [02/01 04:13:07 d2.utils.events]:  eta: 0:05:20  iter: 4539  total_loss: 0.272  loss_cls: 0.06044  loss_box_reg: 0.1338  loss_rpn_cls: 0.01555  loss_rpn_loc: 0.05333    time: 0.6863  last_time: 0.6980  data_time: 0.0331  last_data_time: 0.0353   lr: 0.00020829  max_mem: 3353M
# [02/01 04:13:20 d2.utils.events]:  eta: 0:05:06  iter: 4559  total_loss: 0.2853  loss_cls: 0.07038  loss_box_reg: 0.1389  loss_rpn_cls: 0.02021  loss_rpn_loc: 0.0519    time: 0.6863  last_time: 0.9065  data_time: 0.0409  last_data_time: 0.2446   lr: 0.00019072  max_mem: 3353M
# [02/01 04:13:34 d2.utils.events]:  eta: 0:04:52  iter: 4579  total_loss: 0.2648  loss_cls: 0.07506  loss_box_reg: 0.1338  loss_rpn_cls: 0.01851  loss_rpn_loc: 0.04609    time: 0.6864  last_time: 0.6970  data_time: 0.0324  last_data_time: 0.0385   lr: 0.00017391  max_mem: 3353M
# [02/01 04:13:48 d2.utils.events]:  eta: 0:04:38  iter: 4599  total_loss: 0.3027  loss_cls: 0.07624  loss_box_reg: 0.1441  loss_rpn_cls: 0.02012  loss_rpn_loc: 0.0464    time: 0.6863  last_time: 0.7063  data_time: 0.0325  last_data_time: 0.0358   lr: 0.00015787  max_mem: 3353M
# [02/01 04:14:02 d2.utils.events]:  eta: 0:04:24  iter: 4619  total_loss: 0.2862  loss_cls: 0.07135  loss_box_reg: 0.1412  loss_rpn_cls: 0.01772  loss_rpn_loc: 0.04853    time: 0.6863  last_time: 0.7281  data_time: 0.0304  last_data_time: 0.0434   lr: 0.00014259  max_mem: 3353M
# [02/01 04:14:15 d2.utils.events]:  eta: 0:04:10  iter: 4639  total_loss: 0.2824  loss_cls: 0.06149  loss_box_reg: 0.1396  loss_rpn_cls: 0.01806  loss_rpn_loc: 0.04963    time: 0.6863  last_time: 0.6888  data_time: 0.0312  last_data_time: 0.0279   lr: 0.00012807  max_mem: 3353M
# [02/01 04:14:29 d2.utils.events]:  eta: 0:03:56  iter: 4659  total_loss: 0.3099  loss_cls: 0.07606  loss_box_reg: 0.1457  loss_rpn_cls: 0.02025  loss_rpn_loc: 0.0509    time: 0.6863  last_time: 0.6826  data_time: 0.0292  last_data_time: 0.0205   lr: 0.00011433  max_mem: 3353M
# [02/01 04:14:43 d2.utils.events]:  eta: 0:03:42  iter: 4679  total_loss: 0.3033  loss_cls: 0.07751  loss_box_reg: 0.1527  loss_rpn_cls: 0.02473  loss_rpn_loc: 0.05384    time: 0.6864  last_time: 0.7020  data_time: 0.0418  last_data_time: 0.0279   lr: 0.00010135  max_mem: 3353M
# [02/01 04:14:56 d2.utils.events]:  eta: 0:03:28  iter: 4699  total_loss: 0.2819  loss_cls: 0.07308  loss_box_reg: 0.144  loss_rpn_cls: 0.01823  loss_rpn_loc: 0.04553    time: 0.6863  last_time: 0.6932  data_time: 0.0290  last_data_time: 0.0300   lr: 8.9153e-05  max_mem: 3353M
# [02/01 04:15:10 d2.utils.events]:  eta: 0:03:14  iter: 4719  total_loss: 0.2555  loss_cls: 0.06361  loss_box_reg: 0.1305  loss_rpn_cls: 0.01972  loss_rpn_loc: 0.04294    time: 0.6862  last_time: 0.6844  data_time: 0.0296  last_data_time: 0.0297   lr: 7.7729e-05  max_mem: 3353M
# [02/01 04:15:23 d2.utils.events]:  eta: 0:03:00  iter: 4739  total_loss: 0.2779  loss_cls: 0.06838  loss_box_reg: 0.1297  loss_rpn_cls: 0.02103  loss_rpn_loc: 0.04319    time: 0.6861  last_time: 0.6990  data_time: 0.0311  last_data_time: 0.0327   lr: 6.7082e-05  max_mem: 3353M
# [02/01 04:15:37 d2.utils.events]:  eta: 0:02:46  iter: 4759  total_loss: 0.3246  loss_cls: 0.07715  loss_box_reg: 0.1498  loss_rpn_cls: 0.01684  loss_rpn_loc: 0.05679    time: 0.6861  last_time: 0.6998  data_time: 0.0325  last_data_time: 0.0343   lr: 5.7214e-05  max_mem: 3353M
# [02/01 04:15:50 d2.utils.events]:  eta: 0:02:33  iter: 4779  total_loss: 0.3123  loss_cls: 0.07273  loss_box_reg: 0.1492  loss_rpn_cls: 0.02141  loss_rpn_loc: 0.04945    time: 0.6861  last_time: 0.5188  data_time: 0.0294  last_data_time: 0.0320   lr: 4.8127e-05  max_mem: 3353M
# [02/01 04:16:04 d2.utils.events]:  eta: 0:02:19  iter: 4799  total_loss: 0.2712  loss_cls: 0.06184  loss_box_reg: 0.1288  loss_rpn_cls: 0.0176  loss_rpn_loc: 0.05089    time: 0.6861  last_time: 0.6925  data_time: 0.0302  last_data_time: 0.0333   lr: 3.9821e-05  max_mem: 3353M
# [02/01 04:16:18 d2.utils.events]:  eta: 0:02:05  iter: 4819  total_loss: 0.3156  loss_cls: 0.06828  loss_box_reg: 0.1457  loss_rpn_cls: 0.02261  loss_rpn_loc: 0.05662    time: 0.6861  last_time: 0.6933  data_time: 0.0415  last_data_time: 0.0239   lr: 3.2299e-05  max_mem: 3353M
# [02/01 04:16:31 d2.utils.events]:  eta: 0:01:51  iter: 4839  total_loss: 0.2858  loss_cls: 0.07576  loss_box_reg: 0.1398  loss_rpn_cls: 0.0209  loss_rpn_loc: 0.04546    time: 0.6860  last_time: 0.7145  data_time: 0.0307  last_data_time: 0.0437   lr: 2.5561e-05  max_mem: 3353M
# [02/01 04:16:45 d2.utils.events]:  eta: 0:01:37  iter: 4859  total_loss: 0.3037  loss_cls: 0.07227  loss_box_reg: 0.1359  loss_rpn_cls: 0.01893  loss_rpn_loc: 0.05584    time: 0.6861  last_time: 0.6997  data_time: 0.0423  last_data_time: 0.0326   lr: 1.9609e-05  max_mem: 3353M
# [02/01 04:16:59 d2.utils.events]:  eta: 0:01:23  iter: 4879  total_loss: 0.2521  loss_cls: 0.06297  loss_box_reg: 0.1263  loss_rpn_cls: 0.01711  loss_rpn_loc: 0.04725    time: 0.6861  last_time: 0.6942  data_time: 0.0309  last_data_time: 0.0220   lr: 1.4443e-05  max_mem: 3353M
# [02/01 04:17:13 d2.utils.events]:  eta: 0:01:09  iter: 4899  total_loss: 0.301  loss_cls: 0.08213  loss_box_reg: 0.1444  loss_rpn_cls: 0.01346  loss_rpn_loc: 0.04342    time: 0.6861  last_time: 0.6902  data_time: 0.0313  last_data_time: 0.0247   lr: 1.0065e-05  max_mem: 3353M
# [02/01 04:17:26 d2.utils.events]:  eta: 0:00:55  iter: 4919  total_loss: 0.2393  loss_cls: 0.05583  loss_box_reg: 0.1262  loss_rpn_cls: 0.01614  loss_rpn_loc: 0.04163    time: 0.6860  last_time: 0.6876  data_time: 0.0322  last_data_time: 0.0215   lr: 6.474e-06  max_mem: 3353M
# [02/01 04:17:40 d2.utils.events]:  eta: 0:00:41  iter: 4939  total_loss: 0.2865  loss_cls: 0.07691  loss_box_reg: 0.1393  loss_rpn_cls: 0.02205  loss_rpn_loc: 0.05192    time: 0.6861  last_time: 0.5286  data_time: 0.0509  last_data_time: 0.0361   lr: 3.672e-06  max_mem: 3353M
# [02/01 04:17:54 d2.utils.events]:  eta: 0:00:27  iter: 4959  total_loss: 0.2788  loss_cls: 0.07227  loss_box_reg: 0.1397  loss_rpn_cls: 0.01716  loss_rpn_loc: 0.04886    time: 0.6861  last_time: 0.6937  data_time: 0.0318  last_data_time: 0.0278   lr: 1.659e-06  max_mem: 3353M
# [02/01 04:18:08 d2.utils.events]:  eta: 0:00:13  iter: 4979  total_loss: 0.3006  loss_cls: 0.07113  loss_box_reg: 0.1385  loss_rpn_cls: 0.0185  loss_rpn_loc: 0.04822    time: 0.6861  last_time: 0.5214  data_time: 0.0288  last_data_time: 0.0341   lr: 4.3524e-07  max_mem: 3353M
# [02/01 04:18:24 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 0.2692  loss_cls: 0.0732  loss_box_reg: 0.1316  loss_rpn_cls: 0.01779  loss_rpn_loc: 0.04247    time: 0.6860  last_time: 0.6858  data_time: 0.0331  last_data_time: 0.0241   lr: 9.8696e-10  max_mem: 3353M
# [02/01 04:18:24 d2.engine.hooks]: Overall training speed: 4998 iterations in 0:57:08 (0.6860 s / it)
# [02/01 04:18:24 d2.engine.hooks]: Total training time: 0:57:25 (0:00:16 on hooks)
# [AlbumentationsMapper] Augmentations used in inference: Compose([
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [02/01 04:18:24 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 109          |   Polyp    | 148          |   Cancer   | 194          |
# |            |              |            |              |            |              |
# |   total    | 451          |            |              |            |              |
# [02/01 04:18:24 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/01 04:18:24 d2.data.common]: Serializing 320 elements to byte tensors and concatenating them all ...
# [02/01 04:18:24 d2.data.common]: Serialized dataset takes 0.10 MiB
# [02/01 04:18:24 d2.evaluation.coco_evaluation]: Trying to convert 'gastroscopy_valid' to COCO format ...
# [02/01 04:18:24 d2.data.datasets.coco]: Converting annotations of dataset 'gastroscopy_valid' to COCO format ...)
# [02/01 04:18:24 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [02/01 04:18:24 d2.data.datasets.coco]: Conversion finished, #images: 320, #annotations: 451
# [02/01 04:18:24 d2.data.datasets.coco]: Caching COCO format annotations at 'runs/detect/inference/gastroscopy_valid_coco_format.json' ...
# [02/01 04:18:24 d2.evaluation.evaluator]: Start inference on 320 batches
# [02/01 04:18:24 d2.evaluation.evaluator]: Inference done 11/320. Dataloading: 0.0016 s/iter. Inference: 0.0445 s/iter. Eval: 0.0004 s/iter. Total: 0.0464 s/iter. ETA=0:00:14
# [02/01 04:18:29 d2.evaluation.evaluator]: Inference done 119/320. Dataloading: 0.0023 s/iter. Inference: 0.0439 s/iter. Eval: 0.0004 s/iter. Total: 0.0466 s/iter. ETA=0:00:09
# [02/01 04:18:35 d2.evaluation.evaluator]: Inference done 227/320. Dataloading: 0.0023 s/iter. Inference: 0.0439 s/iter. Eval: 0.0004 s/iter. Total: 0.0466 s/iter. ETA=0:00:04
# [02/01 04:18:39 d2.evaluation.evaluator]: Total inference time: 0:00:14.842153 (0.047118 s / iter per device, on 1 devices)
# [02/01 04:18:39 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:13 (0.044120 s / iter per device, on 1 devices)
# [02/01 04:18:39 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/01 04:18:39 d2.evaluation.coco_evaluation]: Saving results to runs/detect/inference/coco_instances_results.json
# [02/01 04:18:39 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.48s)
# creating index...
# index created!
# [02/01 04:18:40 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/01 04:18:40 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.17 seconds.
# [02/01 04:18:40 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/01 04:18:40 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.07 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.483
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.390
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.508
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.619
# [02/01 04:18:40 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 34.712 | 66.636 | 31.036 | 15.406 | 28.932 | 42.532 |
# [02/01 04:18:40 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Ulcer      | 20.020 | Polyp      | 38.025 | Cancer     | 46.090 |
# [02/01 04:18:40 d2.engine.defaults]: Evaluation results for gastroscopy_valid in csv format:
# [02/01 04:18:40 d2.evaluation.testing]: copypaste: Task: bbox
# [02/01 04:18:40 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/01 04:18:40 d2.evaluation.testing]: copypaste: 34.7120,66.6364,31.0365,15.4058,28.9318,42.5324

# %% [markdown]
# ### Visualize Train Metrics

# %%
metrics = pd.read_json(os.path.join(CFG.output_dir, 'metrics.json'), orient='records', lines=True)
metrics = metrics.sort_values(by=['iteration'])

print('Shape of Metrics: ',metrics.shape)
metrics.head()
# Out:
# Shape of Metrics:  (251, 27)
#    data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0   0.018746  3431.008079                0.945068                  1.000000
# 1   0.019051  3430.674599                0.930054                  1.000000
# 2   0.021883  3413.738657                0.924561                  1.000000
# 3   0.023987  3399.917853                0.926758                  1.000000
# 4   0.022398  3399.217279                0.908081                  0.832605
#
#    fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_rpn_cls  \
# 0                   0.000000         19      0.161071  1.197148      0.659220
# 1                   0.000000         39      0.276508  0.327691      0.407969
# 2                   0.000000         59      0.300985  0.293161      0.249416
# 3                   0.000000         79      0.290390  0.259502      0.197243
# 4                   0.148242         99      0.383984  0.267652      0.188860
#
#    loss_rpn_loc  ...  total_loss  bbox/AP  bbox/AP-Cancer  bbox/AP-Polyp  \
# 0      0.265664  ...    2.284998      NaN             NaN            NaN
# 1      0.202775  ...    1.220682      NaN             NaN            NaN
# 2      0.182853  ...    0.993468      NaN             NaN            NaN
# 3      0.175489  ...    0.962745      NaN             NaN            NaN
# 4      0.204904  ...    1.052683      NaN             NaN            NaN
#
#    bbox/AP-Ulcer  bbox/AP50  bbox/AP75  bbox/APl  bbox/APm  bbox/APs
# 0            NaN        NaN        NaN       NaN       NaN       NaN
# 1            NaN        NaN        NaN       NaN       NaN       NaN
# 2            NaN        NaN        NaN       NaN       NaN       NaN
# 3            NaN        NaN        NaN       NaN       NaN       NaN
# 4            NaN        NaN        NaN       NaN       NaN       NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# - #### Scheduler Graph

# %%
print('Scheduler Type is :', CFG.lr_scheduler_name)
print('Base Learning Rate is :', CFG.base_lr)
print('Iteration is: ', CFG.max_iter)
print('Warmup Iteration is: ', CFG.warmup_iters)

plt.style.use('default')
plt.figure(figsize=(12,6))
plt.title(CFG.lr_scheduler_name, size=10)

tmp = metrics[~metrics['lr'].isna()]

plt.plot(tmp['iteration'], tmp['lr'])
plt.xlabel('iterations')
plt.ylabel('Learning Rate')

plt.show()
# Out:
# Scheduler Type is : WarmupCosineLR
# Base Learning Rate is : 0.01
# Iteration is:  5000
# Warmup Iteration is:  250

# %% [markdown]
# - #### Foreground & Background Fraction in RPN & ROI

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('RPN Fraction Ratio')
tmp = metrics[~metrics['rpn/num_neg_anchors'].isna()]
tmp = tmp[~tmp['rpn/num_pos_anchors'].isna()]
plt.plot(tmp['iteration'], tmp['rpn/num_neg_anchors'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_neg_anchors'].mean(), tmp['rpn/num_neg_anchors'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['rpn/num_pos_anchors'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_pos_anchors'].mean(),tmp['rpn/num_pos_anchors'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title('ROI Head Fraction Ratio')
tmp = metrics[~metrics['roi_head/num_bg_samples'].isna()]
tmp = tmp[~tmp['roi_head/num_fg_samples'].isna()]
plt.plot(tmp['iteration'], tmp['roi_head/num_bg_samples'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_bg_samples'].mean(), tmp['roi_head/num_bg_samples'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['roi_head/num_fg_samples'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_fg_samples'].mean(),tmp['roi_head/num_fg_samples'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# - #### Loss: rpn_loc, rpn_cls, box_reg, box_cls

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(2,2,1)
tmp1 = metrics[~metrics['loss_box_reg'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_box_reg'], color='red', label='box_reg')
plt.grid(True); plt.legend()

final_iter = tmp1['iteration'].iloc[-1]
final_loss = tmp1['loss_box_reg'].iloc[-1]

# 그래프에 텍스트 추가
plt.text(final_iter, final_loss, f'Final Loss: {final_loss:.4f}', 
         verticalalignment='bottom', horizontalalignment='right',
         fontsize=10, color='black', fontweight='bold')

plt.subplot(2,2,2)
tmp2 = metrics[~metrics['loss_cls'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_cls'], color='orange', label='box_cls')
plt.grid(True); plt.legend()

final_iter = tmp2['iteration'].iloc[-1]
final_loss = tmp2['loss_cls'].iloc[-1]

# 그래프에 텍스트 추가
plt.text(final_iter, final_loss, f'Final Loss: {final_loss:.4f}', 
         verticalalignment='bottom', horizontalalignment='right',
         fontsize=10, color='black', fontweight='bold')

plt.subplot(2,2,3)
tmp3 = metrics[~metrics['loss_rpn_cls'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_cls'], color='green', label='rpn_cls')
plt.grid(True); plt.legend()

final_iter = tmp3['iteration'].iloc[-1]
final_loss = tmp3['loss_rpn_cls'].iloc[-1]

# 그래프에 텍스트 추가
plt.text(final_iter, final_loss, f'Final Loss: {final_loss:.4f}', 
         verticalalignment='bottom', horizontalalignment='right',
         fontsize=10, color='black', fontweight='bold')

plt.subplot(2,2,4)
tmp4 = metrics[~metrics['loss_rpn_loc'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_loc'], color='skyblue', label='rpn_loc')
plt.grid(True); plt.legend()

final_iter = tmp4['iteration'].iloc[-1]
final_loss = tmp4['loss_rpn_cls'].iloc[-1]

# 그래프에 텍스트 추가
plt.text(final_iter, final_loss + 0.2, f'Final Loss: {final_loss:.4f}', 
         verticalalignment='bottom', horizontalalignment='right',
         fontsize=10, color='black', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualize Valid Metric

# %%
# !pip -q install palettable
import palettable.colorbrewer.qualitative as pbq

bbox_tmp = metrics[['bbox/AP','bbox/AP50', 'bbox/AP50', 'bbox/APl', 'bbox/APm', 'bbox/APs']]

plt.title('Bbox AP in Valid Dataset', size=10)
ax = plt.barh(y=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'],
        width=[metrics.iloc[-1]['bbox/AP'], metrics.iloc[-1]['bbox/AP50'], metrics.iloc[-1]['bbox/AP75'], metrics.iloc[-1]['bbox/APl'],
           metrics.iloc[-1]['bbox/APm'], metrics.iloc[-1]['bbox/APm'],], 
        color=pbq.Pastel1_7.hex_colors, edgecolor='white',
        label=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'])

for rect in ax.patches:
    x = rect.get_width()
    y = rect.get_y() + rect.get_height()/2.0
    plt.text(x, y, f'{x:.2f}', ha='left', va='center', size=10, color='blue')

plt.legend()
plt.show()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 8.0 MB/s eta 0:00:00

# %% [markdown]
# - #### AP by class

# %%
plt.style.use('default')
plt.figure(figsize=(12,6))

bbox_tmp = metrics[[f'bbox/AP-{col}' for col in thing_classes]]

plt.title('AP by Class', size=10)
ax = plt.bar(
    x=[f'bbox/AP-{col}' for col in thing_classes],
    height=[metrics.iloc[-1][f'bbox/AP-{col}'] for col in thing_classes],
    color=pbq.Pastel1_7.hex_colors,
    edgecolor='white',
    label=[f'bbox/AP-{col}' for col in thing_classes]
)

# 막대 위에 텍스트 추가
for rect in ax.patches:
    x = rect.get_x() + rect.get_width() / 2.0  # 막대 중앙 x좌표
    y = rect.get_height()  # 막대 길이
    plt.text(x, y, f'{y:.2f}', ha='center', va='bottom', size=10, color='gray')  # 텍스트 위치 조정


plt.legend()
plt.xticks(rotation=60)
plt.show()
