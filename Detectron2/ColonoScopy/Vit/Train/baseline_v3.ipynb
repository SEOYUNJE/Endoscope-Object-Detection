# %% [markdown]
# ## 1. Import Library
# ___

# %%
import os
import sys
import pickle
import random
import gc
import ctypes
import copy

from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from colorama import Fore

from PIL import Image
import cv2

import torch
import torch.nn as nn

from sklearn.model_selection import GroupKFold
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Configuration

# %%
class CFG:
    debug = False
    output_dir = 'runs/detect'
    seed = 42
    train_ds = 'colonoscopy_train' ##DatasetDictSampler
    
    model_name = 'MViTv2_S' ## Cascade Tiny Version
    img_size = [256,256]
    input_format = 'RGB' ## VitDet 
    imgdir = '/kaggle/input/colonoscopy-256x256-resized-png'

    split_mode = 'valid20'
    max_iter = 5_000
    ims_per_batch = 8
    num_workers = 4

    lr_scheduler_name = "CosineParamScheduler" ## MultiStepParamScheduler
    base_lr = 1e-4
    base_lr_end = base_lr * 1e-12
    weight_decay = 1e-2
    eval_period = max_iter * 10 ## In Training
    log_period = 20
    amp = True

    device = 'cuda' if torch.cuda.is_available() else 'cpu'

os.makedirs(CFG.output_dir, exist_ok=True)

# %% [markdown]
# #### Reproducibility

# %%
def seed_everything(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark= False

    os.environ['PYTHONHASHSEED'] = str(seed)

seed_everything(CFG.seed)

# %% [markdown]
# #### Clean_memory

# %%
def clean_memory():
    ctypes.CDLL('libc.so.6').malloc_trim(0)
    gc.collect()
    
clean_memory()

# %% [markdown]
# #### Install Detectron2 Library

# %%
print(f'=> {Fore.GREEN}Installing Detectron2 Library...' )
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# => Installing Detectron2 Library...
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.4 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done

# %% [markdown]
# ## 2. Build Dataset_Dicts
# ___
#
# - **궤양**: `ulcer(label: 0)`
#
# - **용종**: `polyp(label: 1)`
#
# - **암**: `cancer(label: 2)`

# %%
meta_data = pd.read_csv('/kaggle/input/metadataset/colonoscopy_data2.csv')
print('Shape of DataFrame: ', meta_data.shape)
meta_data.head()
# Out:
# Shape of DataFrame:  (2496, 14)
#         image_id  height  width        organ  lesion_label  location  \
# 0  2_1_00001.png    2048   2048  colonoscopy             0         1
# 1  2_1_00001.png    2048   2048  colonoscopy             0         1
# 2  2_1_00002.png    2048   2048  colonoscopy             0         1
# 3  2_1_00002.png    2048   2048  colonoscopy             0         1
# 4  2_1_00002.png    2048   2048  colonoscopy             0         1
#
#   shape_type_polygon                                       polygon_mask  \
# 0            polygon  1484.52,775.16;1516.82,710.56;1519.30,640.99;1...
# 1            polygon  1663.40,1478.26;1653.47,1426.09;1616.20,1388.8...
# 2            polygon  687.01,223.60;687.01,273.29;704.40,337.89;726....
# 3            polygon  826.14,1200.00;878.31,1207.45;932.97,1187.58;9...
# 4            polygon  575.20,1038.51;520.55,1050.93;468.37,1050.93;4...
#
#   bounding_box_shape        x_min        y_min        x_max        y_max  \
# 0          rectangle   838.559006   149.068323  1519.304348   807.453416
# 1          rectangle  1310.608696  1324.223602  1663.403727  1868.322981
# 2          rectangle   687.006211   168.944099  1591.354037  1465.838509
# 3          rectangle   488.248447   434.782609  1007.503106  1207.453416
# 4          rectangle   212.472050   725.465839   607.503106  1050.931677
#
#   lesion
# 0  ulcer
# 1  ulcer
# 2  ulcer
# 3  ulcer
# 4  ulcer

# %%
thing_classes = [
    'Ulcer',
    'Polyp',
    'Cancer',
]

category_id_to_name = {index: class_name for index,class_name in enumerate(thing_classes) }

meta_data['lesion'] = meta_data['lesion_label'].map(category_id_to_name)

# %%
train_id = [x.split('/')[-1] for x in glob('/kaggle/input/colonoscopy-256x256-resized-png/train/*.png')] 
test_id = [x.split('/')[-1] for x in glob('/kaggle/input/colonoscopy-256x256-resized-png/test/*.png')] 

train_df = meta_data[meta_data['image_id'].isin(train_id)].reset_index(drop=True)
test_df = meta_data[meta_data['image_id'].isin(test_id)].reset_index(drop=True)

print('=> Number of Unique Image_id in Train: ', train_df.image_id.nunique())
print('=> Number of Unique Image_id in Test: ', test_df.image_id.nunique())
# Out:
# => Number of Unique Image_id in Train:  1596
# => Number of Unique Image_id in Test:  400

# %%
from detectron2.structures import BoxMode

def get_colonoscopy_dicts(
    imgdir: str, 
    df,
    mode: str = 'train',
    use_cache: bool = True, 
    debug: bool = True,
    target_indices: list = None
): 
    debug_str = f"_debug{int(debug)}"
    cache_path = f'/kaggle/working/dataset_dicts_cache_{mode}{debug_str}.pkl'

    if not use_cache or not os.path.exists(cache_path):
       print(f'{Fore.BLUE}#'* 25)
       print(f'### Creating {mode} Data...')
       print('#' * 25)

       meta_df = pd.read_csv(f'/kaggle/input/colonoscopy-256x256-resized-png/{mode}_meta.csv')
        
       if debug:
           meta_df = meta_df[:500]

       image_id = meta_df.loc[0,'image_id']
       image_path = os.path.join(imgdir,mode, image_id)
       image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
       resized_height, resized_width, channel = image.shape
       print(f'=> Height of Image: {resized_height}')
       print(f'=> Width of Image: {resized_width}')

       dataset_dicts = []
       for _, (image_id, height, width) in tqdm(meta_df.iterrows(), total=len(meta_df), desc='Build Dataset Dict'):
           record = {}
           record['file_name'] = os.path.join(imgdir,'train',image_id)
           record['image_id'] = image_id
           record['height'] = resized_height
           record['width'] = resized_width

           if mode != 'test':
              objs = []
              for _, row in df[df.image_id == image_id].iterrows():
                  class_id = row['lesion_label']

                  h_ratio = resized_height / height
                  w_ratio = resized_width / width

                  bbox_resized = [
                      row['x_min'] * w_ratio,
                      row['y_min'] * h_ratio,
                      row['x_max'] * w_ratio,
                      row['y_max'] * h_ratio,
                  ]

                  obj = {
                     'bbox': bbox_resized,
                     'bbox_mode': BoxMode.XYXY_ABS,
                     'category_id': class_id,
                  }
                  objs.append(obj)
              record['annotations'] = objs
              dataset_dicts.append(record)
           else: 
              dataset_dicts.append(record)
       with open(cache_path, mode='wb') as f:
           pickle.dump(dataset_dicts, f)
    with open(cache_path, mode='rb') as f:
        dataset_dicts = pickle.load(f)

    if target_indices is not None:
        dataset_dicts = [dataset_dicts[i] for i in target_indices]

    return dataset_dicts

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog

if CFG.split_mode == 'valid20':
    n_dataset = len(
        get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug)
        )
    
    n_train = int(n_dataset * 0.8)
    n_valid = n_dataset - n_train
    rs = np.random.RandomState(CFG.seed)
    inds = rs.permutation(n_dataset)
    train_inds, valid_inds = inds[:n_train], inds[n_train:]

    print(f'n_train: {len(train_inds)} n_valid: {len(valid_inds)}')

    DatasetCatalog.register(
        'colonoscopy_train',
        lambda: get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = train_inds
        )
    )
    MetadataCatalog.get('colonoscopy_train').set(thing_classes = thing_classes)

    DatasetCatalog.register(
        'colonoscopy_valid',
        lambda: get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = valid_inds
        )
    )

    MetadataCatalog.get('colonoscopy_valid').set(thing_classes = thing_classes)
# Out:
# #########################
# ### Creating train Data...
# #########################
# => Height of Image: 256
# => Width of Image: 256
# Build Dataset Dict: 100%|██████████| 1596/1596 [00:01<00:00, 1377.33it/s]
# n_train: 1276 n_valid: 320

# %%
dataset_dicts = get_colonoscopy_dicts(CFG.imgdir, train_df, mode='train', debug=CFG.debug)

clean_memory()

# %% [markdown]
# ## 3. Build Albumentation Mapper
# ___

# %%
def get_train_transform():
    return A.Compose(
               [
                A.HorizontalFlip(p=0.5),

                ## CLAHE
                A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0),

               
                ### Channel Transform
                A.OneOf([
                    A.ChannelShuffle(p=1.0),
                    A.ChannelDropout(p=1.0),
                    A.ToGray(p=1.0),
                    A.RGBShift(r_shift_limit=[-5,5], g_shift_limit=[-5,5], b_shift_limit=[-5,5], p=1.0)],
                    p=0.5),

                ### Dropout Transform   
                A.OneOf([
                    A.XYMasking(
                        num_masks_x=[1,1],
                        num_masks_y=[1,1],
                        mask_x_length = [int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],
                        mask_y_length = [int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        p=1.0),
                    A.CoarseDropout(
                        num_holes_range=[2,4],
                        hole_height_range=[int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        hole_width_range=[int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],p=1.0),
                    A.BBoxSafeRandomCrop(
                        height=int(CFG.img_size[0] * 0.8),  # 높이 계산
                         width=int(CFG.img_size[1] * 0.8), p=1.0),],
                    p=0.25),

                ## Noisy Transform
                A.OneOf([
                    A.RandomGravel(number_of_patches=1, p=1.0),
                    A.RandomSnow(brightness_coeff=1.1, p=1.0),
                ],
                    p=0.25
                       ), 
                
                A.Resize(*CFG.img_size, p=1.0),
                ],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    ) 
        
def get_valid_transform():
    return A.Compose(
                [A.Resize(*CFG.img_size, p=1.0),],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    )

# %%
import albumentations as A
import detectron2.data.transforms as T
from detectron2.data import detection_utils as utils

class AlbumentationsMapper:
    def __init__(self, is_train: bool=True, mixup_prob: float=0.1, mosaic_prob: float=0.25):
        self.is_train = is_train
        self.mixup_prob = mixup_prob
        self.mosaic_prob = mosaic_prob
        
        if self.is_train:
            self.transform = get_train_transform()
        else:
            self.transform = get_valid_transform()
            

        mode='training' if self.is_train else 'inference'
        print(f'{Fore.GREEN}[AlbumentationsMapper]{Fore.BLACK} Augmentations used in {mode}: {self.transform}')

    def datadict_sampler(self, ds_name=CFG.train_ds, n=3):
        ds = DatasetCatalog.get(ds_name)

        indices = np.random.randint(0, len(ds) - 1, n)
        return [copy.deepcopy(ds[idx]) for idx in indices]

    def __mixup_transform(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        mu_dict = self.datadict_sampler(n=1)[0]

        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        mu_image = utils.read_image(mu_dict['file_name'], format=CFG.input_format)

        lam = np.random.beta(2.0, 2.0)
        image = (lam * image + (1 - lam) * mu_image).astype(np.uint8)
        
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        image = transform(image=image)['image']
        dataset_dict['image'] = image
        dataset_dict['annotations'] += mu_dict['annotations']
            
        return dataset_dict

    def __mosaic_transform(self, dataset_dict):
        dataset_dict= copy.deepcopy(dataset_dict)
        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        im_h, im_w = image.shape[:2]
        resized_w = random.randint(int(im_w*0.75), int(im_w*1.25))
        resized_h = random.randint(int(im_h*0.75), int(im_h*1.25))
        image = cv2.resize(image, (resized_w, resized_h))
        boxes = np.array([anno['bbox'] for anno in dataset_dict['annotations']]) 
        boxes[:,[0,2]] *= resized_w / im_w
        boxes[:,[1,3]] *= resized_h / im_h
        
        mo_items = self.datadict_sampler(n=3)
        mo_images = []
        mo_boxes = []
        
        resize_list = [
            [(im_w*2-resized_w),resized_h], [resized_w,(im_h*2-resized_h)], [(im_w*2-resized_w),(im_h*2-resized_h)],
        ]
        
        for i, mo_dict in enumerate(mo_items):
            mo_image = utils.read_image(mo_dict['file_name'],format=CFG.input_format)
            mo_h, mo_w = mo_image.shape[:2]
            mo_image = cv2.resize(mo_image, (resize_list[i][0], resize_list[i][1]))
            mo_images.append(mo_image)
            mo_bbox = np.array([
                 anno['bbox'] for anno in mo_dict['annotations']
            ])
            mo_bbox[:,[0,2]] *= resize_list[i][0] / mo_w
            mo_bbox[:,[1,3]] *= resize_list[i][1] / mo_h
            mo_boxes.append(mo_bbox)
             
        
            dataset_dict['annotations'] += mo_dict['annotations']
        
        images = [image] + mo_images
        boxes = [boxes] + mo_boxes

        
        heights = [i.shape[0] for i in images] 
        widths =  [i.shape[1] for i in images]

        ch = max(heights[0], heights[1])
        cw = max(widths[0], widths[2]) 
        h = (max(heights[0], heights[1]) + 
             max(heights[2], heights[3]))
        w = (max(widths[0], widths[2]) +
             max(widths[1], widths[3]))
        
        # pad or start coordinates 
        y0, x0 = ch - heights[0], cw - widths[0] # Height: 0,  Width: 0 
        y1, x1 = ch - heights[1], cw # Height: 0, Width: 256 
        y2, x2 = ch, cw - widths[2] # Height: 256, Width: 0
        y3, x3 = ch, cw # Height: 256, Width: 256
        x_pads = [x0, x1, x2, x3]
        y_pads = [y0, y1, y2, y3]

        output = np.zeros((h,w,3)).astype(np.uint8)
        for i, img in enumerate(images):
            output[y_pads[i]: y_pads[i] + heights[i],
                   x_pads[i]: x_pads[i] + widths[i],
                   :] = img
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        output = transform(image=output)['image']
        dataset_dict['image'] = output

        for i, bbox in enumerate(boxes):
            bbox += np.array([x_pads[i], y_pads[i], x_pads[i], y_pads[i]])
            
        boxes = np.vstack(boxes)

        for i, box in enumerate(boxes):
            dataset_dict['annotations'][i]['bbox'] = box
        
        return dataset_dict
        
    def __call__(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)

        if self.is_train:
            if np.random.rand() <= self.mosaic_prob:
               dataset_dict = self.__mosaic_transform(dataset_dict)

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict
            elif np.random.rand() <= self.mixup_prob:
               dataset_dict = self.__mixup_transform(dataset_dict)
    

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict

        
        image = utils.read_image(dataset_dict['file_name'], format=CFG.input_format)

        ### Bounding Box
        bboxes = np.array([obj['bbox'] for obj in dataset_dict['annotations']], dtype=np.float32)
        annotation_id = np.arange(len(dataset_dict['annotations']))

        ### Applying Augmentation
        transformed = self.transform(image=image, bboxes=bboxes, category_ids=annotation_id)
        dataset_dict['image'] = transformed['image']
        
        for i in transformed['category_ids']:
            dataset_dict['annotations'][i]['bbox'] = transformed['bboxes'][i] 
        

        image_shape = (CFG.img_size[1], CFG.img_size[0]) # height, width
        dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

        instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
        dataset_dict['instances'] = utils.filter_empty_instances(instances)

        ## Remove annotations for convert to instances
        dataset_dict.pop('annotations', None)

        return dataset_dict

# %% [markdown]
# ## 4. Visualize ColonoScopy Augmentation
# ___

# %%
colonoscopy_metadata = MetadataCatalog.get('colonoscopy_train')
print(colonoscopy_metadata)
# Out:
# Metadata(name='colonoscopy_train', thing_classes=['Ulcer', 'Polyp', 'Cancer'])

# %%
import detectron2
from detectron2.utils.visualizer import Visualizer, ColorMode

mapper = AlbumentationsMapper(is_train=True)

plt.figure(figsize=(12,8))

for i in range(8):
    plt.subplot(4,4,2*i+1)
    plt.title('Before Augmentation')
    d = dataset_dicts[i]
    img = Image.open(d['file_name'])
    img = np.array(img)
    img = cv2.resize(img, tuple(CFG.img_size))
    visualizer = Visualizer(img, metadata=colonoscopy_metadata, scale=1.0)
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image())
    plt.axis('off')
    
    plt.subplot(4,4, 2*i+2)
    plt.title('After Augmentation')
    mapped_d = mapper(d)
    img_arr = mapped_d['image'].cpu().permute(1,2,0).numpy()
    # img_arr[:,:,::-1] # BGR -> RGB
    # VitModel's Input Format: RGB
    visualizer = Visualizer(img_arr, metadata=colonoscopy_metadata, scale=1.0)
    target_fields = mapped_d['instances'].get_fields()
    labels = [colonoscopy_metadata.thing_classes[i] for i in target_fields['gt_classes']]

    out = visualizer.overlay_instances(
        labels = labels,
        boxes = target_fields.get('gt_boxes',None),
        masks = target_fields.get('gt_masks',None),
        keypoints = target_fields.get('gt_keypoints', None)
    )
     
    plt.imshow(out.get_image())
    plt.axis('off')

    del out, visualizer, labels
    
plt.tight_layout()
plt.show()

del mapper; clean_memory()
# Out:
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(12, 25), mask_y_length=(12, 25), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(12, 25), hole_width_range=(12, 25)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)

# %% [markdown]
# ## 5. Lazyconfing Train Net
# ___
#
# 1) DefaultTrainer is limited to yacs configs. So, for using LazyConfig file, we should use `SimpleTrainer` or `AMPTrainer`
#
# 2) LazyConfig is an alternative, non-intrusive config system that can be used with detectron2 or potentially any other complex projects.
#
# ![image.png](attachment:41883ae9-a20e-45de-a56d-09184cd02ac0.png)

# %%
import logging
from functools import partial
from fvcore.common.param_scheduler import MultiStepParamScheduler, CosineParamScheduler

from omegaconf import OmegaConf

from detectron2.layers import ShapeSpec
from detectron2.layers.batch_norm import NaiveSyncBatchNorm

from detectron2 import model_zoo 
from detectron2.config import get_cfg, LazyConfig, instantiate
from detectron2.config import LazyCall as L

from detectron2.data import (
    build_detection_train_loader, 
    build_detection_test_loader,
    DatasetMapper,
    get_detection_dataset_dicts)

from detectron2.evaluation import (
     COCOEvaluator,
     inference_on_dataset, 
     print_csv_format)

from detectron2.engine import (
     create_ddp_model,
     AMPTrainer, SimpleTrainer,
     default_argument_parser, default_setup, default_writers,
     hooks, launch ## DDP 
)
from detectron2.modeling.meta_arch import GeneralizedRCNN
from detectron2.modeling.anchor_generator import DefaultAnchorGenerator
from detectron2.modeling.backbone.fpn import LastLevelMaxPool
from detectron2.modeling.backbone import BasicStem, FPN, ResNet
from detectron2.modeling.box_regression import Box2BoxTransform
from detectron2.modeling.matcher import Matcher
from detectron2.modeling.poolers import ROIPooler
from detectron2.modeling.proposal_generator import RPN, StandardRPNHead
from detectron2.modeling.roi_heads import (
    StandardROIHeads,
    FastRCNNOutputLayers,
    MaskRCNNConvUpsampleHead,
    FastRCNNConvFCHead,
    CascadeROIHeads
)

from detectron2.solver import WarmupParamScheduler
from detectron2.checkpoint import DetectionCheckpointer
from detectron2.modeling import MViT

from detectron2.utils import comm
from detectron2.utils.logger import setup_logger

setup_logger()
# Out:
# <_Logger detectron2 (DEBUG)>

# %% [markdown]
# #### Setting LazyConfig File

# %%
def setup():
    """DataLoader LazyConfig"""
    dataloader = OmegaConf.create()

    dataloader.train = L(build_detection_train_loader)(
        dataset=L(get_detection_dataset_dicts)(names='colonoscopy_train'),
        mapper=L(AlbumentationsMapper)(is_train=True),
        total_batch_size=CFG.ims_per_batch,
        num_workers=CFG.num_workers
    )

    """Train LazyConfig"""
    train = model_zoo.get_config("common/train.py").train
    train.amp.enabled = True
    train.ddp.fp16_compression = True
    train.init_checkpoint =  "detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth"
    train.output_dir = CFG.output_dir
    train.max_iter = CFG.max_iter
    train.eval_period = CFG.eval_period
    train.checkpointer.period = CFG.eval_period
    train.log_period = CFG.log_period
    train.device = CFG.device

    """Scheduler LazyConfig"""
    lr_multiplier = L(WarmupParamScheduler)(
        scheduler=L(CosineParamScheduler)(
            start_value=1,
            end_value=CFG.base_lr_end / CFG.base_lr
        ),
        warmup_length=0,
        warmup_factor=0,
        warmup_method='linear'
    )

    """Optimizer LazyConfig"""
    optimizer = model_zoo.get_config("common/optim.py").AdamW  # or SGD
    optimizer.params.overrides = {
        "pos_embed": {"weight_decay": 0.0},
        "rel_pos_h": {"weight_decay": 0.0},
        "rel_pos_w": {"weight_decay": 0.0},
    }
    
    optimizer.lr = CFG.base_lr
    optimizer.weight_decay = CFG.weight_decay

    """Model LazyConfig"""
    model = model_zoo.get_config("common/models/mask_rcnn_fpn.py").model
    constants = model_zoo.get_config("common/data/constants.py").constants
    model.input_format = CFG.input_format
    model.pixel_mean = constants.imagenet_rgb256_mean
    model.pixel_std = constants.imagenet_rgb256_std

    model.backbone.bottom_up = L(MViT)(
    img_size = CFG.img_size[0],
    patch_kernel=(7, 7), 
    patch_stride=(4, 4), 
    patch_padding=(3, 3),
    embed_dim=96,
    depth=16, # Depth of MViT
    num_heads=1, # Number of base attention heads in each MViT block
    last_block_indexes=(0, 2, 13, 15),
    residual_pooling=True,
    drop_path_rate=0.0,
    norm_layer=partial(nn.LayerNorm, eps=1e-6),
    pretrain_img_size=CFG.img_size[0],
    pretrain_use_cls_token=True,
    out_features=("scale2", "scale3", "scale4", "scale5"),
    )
    model.backbone.in_features = "${.bottom_up.out_features}"
    model.backbone.out_channels = 256
   

    """RPN 설정"""
    model.proposal_generator.in_features=["p2", "p3", "p4", "p5", "p6"]
    model.proposal_generator.head=L(StandardRPNHead)(in_channels=256, num_anchors=4)
    model.proposal_generator.head.conv_dims = [-1, -1]
    model.proposal_generator.anchor_generator = L(DefaultAnchorGenerator)(
        sizes=[[32], [64], [128], [256], [512]],
        aspect_ratios=[0.5, 1.0, 2.0, 2.5],
        strides=[4, 8, 16, 32, 64],
        offset=0.5
    )
    model.proposal_generator.anchor_matcher = L(Matcher)(
        thresholds=[0.3, 0.7], labels=[0, -1, 1], allow_low_quality_matches=True
    )
    model.proposal_generator.box2box_transform = L(Box2BoxTransform)(weights=[1.0, 1.0, 1.0, 1.0])
    model.proposal_generator.batch_size_per_image = 256
    model.proposal_generator.positive_fraction = 0.5
    model.proposal_generator.pre_nms_topk = (2000, 1000)
    model.proposal_generator.post_nms_topk = (1000, 1000)
    model.proposal_generator.nms_thresh = 0.7

    """ROI 설정"""
    model.roi_heads.num_classes = len(thing_classes)
    model.roi_heads.batch_size_per_image = 256
    model.roi_heads.positive_fraction = 0.25
    model.roi_heads.box_in_features = ["p2", "p3", "p4", "p5"]
    model.roi_heads.box_pooler = L(ROIPooler)(
        output_size=7,
        scales=(1.0 / 4, 1.0 / 8, 1.0 / 16, 1.0 / 32),
        sampling_ratio=0,
        pooler_type="ROIAlignV2"
    )
    model.roi_heads.box_head = L(FastRCNNConvFCHead)(
        input_shape=ShapeSpec(channels=256, height=7, width=7),
        conv_dims=[],
        fc_dims=[1024, 1024]
    )
    model.roi_heads.box_predictor = L(FastRCNNOutputLayers)(
        input_shape=ShapeSpec(channels=1024),
        test_score_thresh=0.00,
        box2box_transform=L(Box2BoxTransform)(weights=(10, 10, 5, 5)),
        num_classes="${..num_classes}"
    )

    """Cascade ROI Parts"""
    model.roi_heads.update(
    _target_=CascadeROIHeads,
    box_heads=[
        L(FastRCNNConvFCHead)(
            input_shape=ShapeSpec(channels=256, height=7, width=7),
            conv_dims=[256, 256, 256, 256],
            fc_dims=[1024],
            conv_norm=lambda c: NaiveSyncBatchNorm(c, stats_mode="N"),
        )
        for _ in range(3)
    ],
    box_predictors=[
        L(FastRCNNOutputLayers)(
            input_shape=ShapeSpec(channels=1024),
            test_score_thresh=0.00,
            box2box_transform=L(Box2BoxTransform)(weights=(w1, w1, w2, w2)),
            cls_agnostic_bbox_reg=True,
            num_classes="${...num_classes}",
        )
        for (w1, w2) in [(10, 5), (20, 10), (30, 15)]
    ],
    proposal_matchers=[
        L(Matcher)(thresholds=[th], labels=[0, 1], allow_low_quality_matches=True)
        for th in [0.5, 0.6, 0.7]
    ],
   )


    """Config 저장"""
    cfg = OmegaConf.create()
    cfg.model = model
    cfg.dataloader = dataloader
    cfg.train = train
    cfg.optimizer = optimizer
    cfg.lr_multiplier = lr_multiplier

    """Mask-RCNN에서 Faster-RCNN으로 변경"""
    del cfg.model.roi_heads.mask_in_features
    del cfg.model.roi_heads.mask_pooler
    del cfg.model.roi_heads.mask_head
    del cfg.model.roi_heads.box_predictor
    del cfg.model.roi_heads.box_head
    del cfg.model.roi_heads.proposal_matcher
  
    return cfg

# %% [markdown]
# #### train_net.py

# %%
def do_train(resume, cfg):
    model = instantiate(cfg.model)
    logger = logging.getLogger('detectron2')
    logger.info("Model:\n{}".format(model))
    model.to(cfg.train.device)

    cfg.optimizer.params.model = model
    optim = instantiate(cfg.optimizer)

    train_loader = instantiate(cfg.dataloader.train)

    model = create_ddp_model(model, **cfg.train.ddp)
    trainer = (AMPTrainer if cfg.train.amp.enabled else SimpleTrainer)(model, train_loader, optim)

    checkpointer = DetectionCheckpointer(
        model, cfg.train.output_dir, trainer=trainer
    )

    ## including timing 
    ## including checkpointing
    ## including lr scheduling
    ## including writing events
    trainer.register_hooks(
        [
            hooks.IterationTimer(),
            hooks.LRScheduler(scheduler=instantiate(cfg.lr_multiplier)),
            hooks.PeriodicCheckpointer(checkpointer, **cfg.train.checkpointer)
            if comm.is_main_process() else None,
            hooks.PeriodicWriter(
                default_writers(cfg.train.output_dir, cfg.train.max_iter),
                period = cfg.train.log_period,
            )
            if comm.is_main_process() else None,
        ]
     )

    checkpointer.resume_or_load(cfg.train.init_checkpoint, resume=resume)
    if resume and checkpointer.has_checkpoint():
        start_iter = trainer.iter + 1
    else:
        start_iter = 0
    trainer.train(start_iter, cfg.train.max_iter)

# %% [markdown]
# #### save lazy config file

# %%
config_file = LazyConfig.to_py(setup())

with open(f'{CFG.output_dir}/mvit_config.py', 'w') as f:
    f.write(config_file)

# %%
SHOW = True

if SHOW:
    with open(f'{CFG.output_dir}/mvit_config.py', 'r') as f:
        print(f.read())
# Out:
# cfg.dataloader.train=detectron2.data.build_detection_train_loader(dataset=detectron2.data.get_detection_dataset_dicts(names='colonoscopy_train'), mapper=__main__.AlbumentationsMapper(is_train=True), num_workers=4, total_batch_size=8)
# cfg.lr_multiplier=detectron2.solver.WarmupParamScheduler(scheduler=fvcore.common.param_scheduler.CosineParamScheduler(end_value=1e-12, start_value=1), warmup_factor=0, warmup_length=0, warmup_method='linear')
# cfg.model=detectron2.modeling.GeneralizedRCNN(backbone=detectron2.modeling.FPN(bottom_up=detectron2.modeling.MViT(depth=16, drop_path_rate=0.0, embed_dim=96, img_size=256, last_block_indexes=[0,2,13,15], norm_layer=functools.partial(<class 'torch.nn.modules.normalization.LayerNorm'>, eps=1e-06), num_heads=1, out_features=['scale2','scale3','scale4','scale5'], patch_kernel=[7,7], patch_padding=[3,3], patch_stride=[4,4], pretrain_img_size=256, pretrain_use_cls_token=True, residual_pooling=True), in_features=['scale2','scale3','scale4','scale5'], out_channels=256, top_block=detectron2.modeling.backbone.fpn.LastLevelMaxPool()), input_format='RGB', pixel_mean=[123.675,116.28,103.53], pixel_std=[58.395,57.12,57.375], proposal_generator=detectron2.modeling.proposal_generator.RPN(anchor_generator=detectron2.modeling.anchor_generator.DefaultAnchorGenerator(aspect_ratios=[0.5,1.0,2.0,2.5], offset=0.5, sizes=[[32],[64],[128],[256],[512]], strides=[4,8,16,32,64]), anchor_matcher=detectron2.modeling.matcher.Matcher(allow_low_quality_matches=True, labels=[0,-1,1], thresholds=[0.3,0.7]), batch_size_per_image=256, box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[1.0,1.0,1.0,1.0]), head=detectron2.modeling.proposal_generator.StandardRPNHead(conv_dims=[-1,-1], in_channels=256, num_anchors=4), in_features=['p2','p3','p4','p5','p6'], nms_thresh=0.7, positive_fraction=0.5, post_nms_topk=[1000,1000], pre_nms_topk=[2000,1000]), roi_heads=detectron2.modeling.roi_heads.CascadeROIHeads(batch_size_per_image=256, box_heads=[detectron2.modeling.roi_heads.FastRCNNConvFCHead(conv_dims=[256,256,256,256], conv_norm=<function setup.<locals>.<listcomp>.<lambda> at 0x7cf65caae440>, fc_dims=[1024], input_shape={'channels': 256,'height': 7,'stride': None,'width': 7}),detectron2.modeling.roi_heads.FastRCNNConvFCHead(conv_dims=[256,256,256,256], conv_norm=<function setup.<locals>.<listcomp>.<lambda> at 0x7cf657d804c0>, fc_dims=[1024], input_shape={'channels': 256,'height': 7,'stride': None,'width': 7}),detectron2.modeling.roi_heads.FastRCNNConvFCHead(conv_dims=[256,256,256,256], conv_norm=<function setup.<locals>.<listcomp>.<lambda> at 0x7cf657d82b00>, fc_dims=[1024], input_shape={'channels': 256,'height': 7,'stride': None,'width': 7})], box_in_features=['p2','p3','p4','p5'], box_pooler=detectron2.modeling.poolers.ROIPooler(output_size=7, pooler_type='ROIAlignV2', sampling_ratio=0, scales=[0.25,0.125,0.0625,0.03125]), box_predictors=[detectron2.modeling.FastRCNNOutputLayers(box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[10,10,5,5]), cls_agnostic_bbox_reg=True, input_shape={'channels': 1024,'height': None,'stride': None,'width': None}, num_classes=3, test_score_thresh=0.0),detectron2.modeling.FastRCNNOutputLayers(box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[20,20,10,10]), cls_agnostic_bbox_reg=True, input_shape={'channels': 1024,'height': None,'stride': None,'width': None}, num_classes=3, test_score_thresh=0.0),detectron2.modeling.FastRCNNOutputLayers(box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[30,30,15,15]), cls_agnostic_bbox_reg=True, input_shape={'channels': 1024,'height': None,'stride': None,'width': None}, num_classes=3, test_score_thresh=0.0)], num_classes=3, positive_fraction=0.25, proposal_matchers=[detectron2.modeling.matcher.Matcher(allow_low_quality_matches=True, labels=[0,1], thresholds=[0.5]),detectron2.modeling.matcher.Matcher(allow_low_quality_matches=True, labels=[0,1], thresholds=[0.6]),detectron2.modeling.matcher.Matcher(allow_low_quality_matches=True, labels=[0,1], thresholds=[0.7])]))
# cfg.optimizer=torch.optim.AdamW(betas=[0.9,0.999], lr=0.0001, params=detectron2.solver.get_default_optimizer_params(base_lr=0.0001, overrides={'pos_embed': {'weight_decay': 0.0},'rel_pos_h': {'weight_decay': 0.0},'rel_pos_w': {'weight_decay': 0.0}}, weight_decay_norm=0.0), weight_decay=0.01)
# cfg.train.amp.enabled=True
# cfg.train.checkpointer.max_to_keep=100
# cfg.train.checkpointer.period=50000
# cfg.train.ddp.broadcast_buffers=False
# cfg.train.ddp.find_unused_parameters=False
# cfg.train.ddp.fp16_compression=True
# cfg.train.device='cuda'
# cfg.train.eval_period=50000
# cfg.train.init_checkpoint='detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth'
# cfg.train.log_period=20
# cfg.train.max_iter=5000
# cfg.train.output_dir='runs/detect'

# %% [markdown]
# ## 6. Training MultiScale VisionTransformer Detection Model
# ___

# %%
do_train(resume=False, cfg=setup())
# Out:
# [03/05 02:11:40 detectron2]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): MViT(
#       (patch_embed): PatchEmbed(
#         (proj): Conv2d(3, 96, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#       )
#       (blocks): ModuleList(
#         (0): MultiScaleBlock(
#           (norm1): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=96, out_features=288, bias=True)
#             (proj): Linear(in_features=96, out_features=96, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): MultiScaleBlock(
#           (norm1): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=96, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=96, out_features=192, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (2): MultiScaleBlock(
#           (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): MultiScaleBlock(
#           (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=192, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=192, out_features=384, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (4-12): 9 x MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=2304, bias=True)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=384, out_features=768, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (15): MultiScaleBlock(
#           (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (scale2_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#       (scale3_norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (scale4_norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (scale5_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Sequential(
#         (conv0): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#           (activation): ReLU()
#         )
#         (conv1): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#           (activation): ReLU()
#         )
#       )
#       (objectness_logits): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): CascadeROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): ModuleList(
#       (0-2): 3 x FastRCNNConvFCHead(
#         (conv1): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): NaiveSyncBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): NaiveSyncBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#         (conv3): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): NaiveSyncBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#         (conv4): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): NaiveSyncBatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#         )
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#       )
#     )
#     (box_predictor): ModuleList(
#       (0-2): 3 x FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#     )
#   )
# )
# [03/05 02:11:40 d2.data.build]: Removed 0 images with no usable annotations. 1276 images left.
# [03/05 02:11:40 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 630          |   Polyp    | 352          |   Cancer   | 627          |
# |            |              |            |              |            |              |
# |   total    | 1609         |            |              |            |              |
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(12, 25), mask_y_length=(12, 25), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(12, 25), hole_width_range=(12, 25)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [03/05 02:11:40 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/05 02:11:40 d2.data.common]: Serializing 1276 elements to byte tensors and concatenating them all ...
# [03/05 02:11:40 d2.data.common]: Serialized dataset takes 0.37 MiB
# [03/05 02:11:40 d2.data.build]: Making batched data loader with batch_size=8
# [03/05 02:11:40 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth ...
# MViTv2_T_in1k.pyth: 290MB [00:08, 33.8MB/s]
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.0.attn.rel_pos_h in checkpoint is torch.Size([111, 96]), while shape of backbone.bottom_up.blocks.0.attn.rel_pos_h in model is torch.Size([127, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.0.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.0.attn.rel_pos_w in checkpoint is torch.Size([111, 96]), while shape of backbone.bottom_up.blocks.0.attn.rel_pos_w in model is torch.Size([127, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.0.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.1.attn.rel_pos_h in checkpoint is torch.Size([55, 96]), while shape of backbone.bottom_up.blocks.1.attn.rel_pos_h in model is torch.Size([63, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.1.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.1.attn.rel_pos_w in checkpoint is torch.Size([55, 96]), while shape of backbone.bottom_up.blocks.1.attn.rel_pos_w in model is torch.Size([63, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.1.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.2.attn.rel_pos_h in checkpoint is torch.Size([55, 96]), while shape of backbone.bottom_up.blocks.2.attn.rel_pos_h in model is torch.Size([63, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.2.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.2.attn.rel_pos_w in checkpoint is torch.Size([55, 96]), while shape of backbone.bottom_up.blocks.2.attn.rel_pos_w in model is torch.Size([63, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.2.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.3.attn.rel_pos_h in checkpoint is torch.Size([55, 96]), while shape of backbone.bottom_up.blocks.3.attn.rel_pos_h in model is torch.Size([63, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.3.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.3.attn.rel_pos_w in checkpoint is torch.Size([55, 96]), while shape of backbone.bottom_up.blocks.3.attn.rel_pos_w in model is torch.Size([63, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.3.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.4.attn.rel_pos_h in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.4.attn.rel_pos_h in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.4.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.4.attn.rel_pos_w in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.4.attn.rel_pos_w in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.4.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.5.attn.rel_pos_h in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.5.attn.rel_pos_h in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.5.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.5.attn.rel_pos_w in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.5.attn.rel_pos_w in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.5.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.6.attn.rel_pos_h in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.6.attn.rel_pos_h in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.6.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.6.attn.rel_pos_w in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.6.attn.rel_pos_w in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.6.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.7.attn.rel_pos_h in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.7.attn.rel_pos_h in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.7.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.7.attn.rel_pos_w in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.7.attn.rel_pos_w in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.7.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.attn.proj.bias in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.8.attn.proj.bias in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.attn.proj.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.attn.proj.weight in checkpoint is torch.Size([768, 768]), while shape of backbone.bottom_up.blocks.8.attn.proj.weight in model is torch.Size([384, 384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.attn.proj.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.attn.qkv.bias in checkpoint is torch.Size([2304]), while shape of backbone.bottom_up.blocks.8.attn.qkv.bias in model is torch.Size([1152]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.attn.qkv.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.attn.qkv.weight in checkpoint is torch.Size([2304, 384]), while shape of backbone.bottom_up.blocks.8.attn.qkv.weight in model is torch.Size([1152, 384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.attn.qkv.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.attn.rel_pos_h in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.8.attn.rel_pos_h in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.attn.rel_pos_w in checkpoint is torch.Size([27, 96]), while shape of backbone.bottom_up.blocks.8.attn.rel_pos_w in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.mlp.fc1.bias in checkpoint is torch.Size([3072]), while shape of backbone.bottom_up.blocks.8.mlp.fc1.bias in model is torch.Size([1536]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.mlp.fc1.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.mlp.fc1.weight in checkpoint is torch.Size([3072, 768]), while shape of backbone.bottom_up.blocks.8.mlp.fc1.weight in model is torch.Size([1536, 384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.mlp.fc1.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.mlp.fc2.bias in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.8.mlp.fc2.bias in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.mlp.fc2.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.mlp.fc2.weight in checkpoint is torch.Size([768, 3072]), while shape of backbone.bottom_up.blocks.8.mlp.fc2.weight in model is torch.Size([384, 1536]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.mlp.fc2.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.norm2.bias in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.8.norm2.bias in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.norm2.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.8.norm2.weight in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.8.norm2.weight in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.8.norm2.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.attn.proj.bias in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.9.attn.proj.bias in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.attn.proj.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.attn.proj.weight in checkpoint is torch.Size([768, 768]), while shape of backbone.bottom_up.blocks.9.attn.proj.weight in model is torch.Size([384, 384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.attn.proj.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.attn.qkv.bias in checkpoint is torch.Size([2304]), while shape of backbone.bottom_up.blocks.9.attn.qkv.bias in model is torch.Size([1152]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.attn.qkv.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.attn.qkv.weight in checkpoint is torch.Size([2304, 768]), while shape of backbone.bottom_up.blocks.9.attn.qkv.weight in model is torch.Size([1152, 384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.attn.qkv.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.attn.rel_pos_h in checkpoint is torch.Size([13, 96]), while shape of backbone.bottom_up.blocks.9.attn.rel_pos_h in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.attn.rel_pos_h will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.attn.rel_pos_w in checkpoint is torch.Size([13, 96]), while shape of backbone.bottom_up.blocks.9.attn.rel_pos_w in model is torch.Size([31, 96]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.attn.rel_pos_w will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.mlp.fc1.bias in checkpoint is torch.Size([3072]), while shape of backbone.bottom_up.blocks.9.mlp.fc1.bias in model is torch.Size([1536]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.mlp.fc1.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.mlp.fc1.weight in checkpoint is torch.Size([3072, 768]), while shape of backbone.bottom_up.blocks.9.mlp.fc1.weight in model is torch.Size([1536, 384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.mlp.fc1.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.mlp.fc2.bias in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.9.mlp.fc2.bias in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.mlp.fc2.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.mlp.fc2.weight in checkpoint is torch.Size([768, 3072]), while shape of backbone.bottom_up.blocks.9.mlp.fc2.weight in model is torch.Size([384, 1536]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.mlp.fc2.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.norm1.bias in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.9.norm1.bias in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.norm1.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.norm1.weight in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.9.norm1.weight in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.norm1.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.norm2.bias in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.9.norm2.bias in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.norm2.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of blocks.9.norm2.weight in checkpoint is torch.Size([768]), while shape of backbone.bottom_up.blocks.9.norm2.weight in model is torch.Size([384]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: blocks.9.norm2.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv1.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv1.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv2.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv2.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv3.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv3.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv4.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.0.conv4.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv1.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv1.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv2.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv2.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv3.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv3.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv4.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.1.conv4.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv1.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv1.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv2.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv2.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv3.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv3.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.bias in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv4.norm.bias in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.bias will not be loaded. Please double check and see if this is desired.
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Shape of norm.weight in checkpoint is torch.Size([768]), while shape of roi_heads.box_head.2.conv4.norm.weight in model is torch.Size([256]).
# WARNING [03/05 02:11:49 d2.checkpoint.c2_model_loading]: norm.weight will not be loaded. Please double check and see if this is desired.
# [03/05 02:11:49 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 112
# [03/05 02:11:49 d2.engine.train_loop]: Starting training from iteration 0
# [03/05 02:12:24 d2.utils.events]:  eta: 2:11:13  iter: 19  total_loss: 1.144  loss_cls_stage0: 0.2904  loss_box_reg_stage0: 0.2092  loss_cls_stage1: 0.1713  loss_box_reg_stage1: 0.08991  loss_cls_stage2: 0.1174  loss_box_reg_stage2: 0.0321  loss_rpn_cls: 0.1651  loss_rpn_loc: 0.02175    time: 1.5832  last_time: 1.5884  data_time: 0.0319  last_data_time: 0.0175   lr: 9.9996e-05  max_mem: 11500M
# [03/05 02:13:05 d2.utils.events]:  eta: 2:11:18  iter: 39  total_loss: 1.225  loss_cls_stage0: 0.3491  loss_box_reg_stage0: 0.3266  loss_cls_stage1: 0.1716  loss_box_reg_stage1: 0.1531  loss_cls_stage2: 0.08548  loss_box_reg_stage2: 0.0398  loss_rpn_cls: 0.0708  loss_rpn_loc: 0.01653    time: 1.5472  last_time: 1.5801  data_time: 0.0232  last_data_time: 0.0231   lr: 9.9985e-05  max_mem: 11500M
# [03/05 02:13:36 d2.utils.events]:  eta: 2:10:47  iter: 59  total_loss: 1.253  loss_cls_stage0: 0.3558  loss_box_reg_stage0: 0.3601  loss_cls_stage1: 0.1696  loss_box_reg_stage1: 0.1772  loss_cls_stage2: 0.09023  loss_box_reg_stage2: 0.05539  loss_rpn_cls: 0.06485  loss_rpn_loc: 0.02031    time: 1.5421  last_time: 1.6018  data_time: 0.0238  last_data_time: 0.0371   lr: 9.9966e-05  max_mem: 11500M
# [03/05 02:14:07 d2.utils.events]:  eta: 2:10:09  iter: 79  total_loss: 1.737  loss_cls_stage0: 0.4336  loss_box_reg_stage0: 0.5058  loss_cls_stage1: 0.2354  loss_box_reg_stage1: 0.2732  loss_cls_stage2: 0.1117  loss_box_reg_stage2: 0.07531  loss_rpn_cls: 0.05741  loss_rpn_loc: 0.02367    time: 1.5388  last_time: 1.5869  data_time: 0.0260  last_data_time: 0.0184   lr: 9.9938e-05  max_mem: 11500M
# [03/05 02:14:38 d2.utils.events]:  eta: 2:09:36  iter: 99  total_loss: 1.637  loss_cls_stage0: 0.3404  loss_box_reg_stage0: 0.4134  loss_cls_stage1: 0.2225  loss_box_reg_stage1: 0.3107  loss_cls_stage2: 0.1112  loss_box_reg_stage2: 0.09849  loss_rpn_cls: 0.04272  loss_rpn_loc: 0.01905    time: 1.5424  last_time: 1.6041  data_time: 0.0264  last_data_time: 0.0308   lr: 9.9903e-05  max_mem: 11500M
# [03/05 02:15:09 d2.utils.events]:  eta: 2:09:08  iter: 119  total_loss: 1.719  loss_cls_stage0: 0.3039  loss_box_reg_stage0: 0.3845  loss_cls_stage1: 0.2369  loss_box_reg_stage1: 0.4131  loss_cls_stage2: 0.1321  loss_box_reg_stage2: 0.1958  loss_rpn_cls: 0.05229  loss_rpn_loc: 0.02141    time: 1.5419  last_time: 1.5756  data_time: 0.0266  last_data_time: 0.0210   lr: 9.986e-05  max_mem: 11500M
# [03/05 02:15:41 d2.utils.events]:  eta: 2:08:45  iter: 139  total_loss: 1.865  loss_cls_stage0: 0.2772  loss_box_reg_stage0: 0.3788  loss_cls_stage1: 0.2363  loss_box_reg_stage1: 0.4986  loss_cls_stage2: 0.1454  loss_box_reg_stage2: 0.2725  loss_rpn_cls: 0.04005  loss_rpn_loc: 0.01749    time: 1.5506  last_time: 1.6046  data_time: 0.0261  last_data_time: 0.0269   lr: 9.9809e-05  max_mem: 11500M
# [03/05 02:16:10 d2.utils.events]:  eta: 2:08:08  iter: 159  total_loss: 1.779  loss_cls_stage0: 0.2259  loss_box_reg_stage0: 0.3104  loss_cls_stage1: 0.2203  loss_box_reg_stage1: 0.4893  loss_cls_stage2: 0.1467  loss_box_reg_stage2: 0.3259  loss_rpn_cls: 0.04016  loss_rpn_loc: 0.01668    time: 1.5374  last_time: 1.0342  data_time: 0.0290  last_data_time: 0.0360   lr: 9.9751e-05  max_mem: 11500M
# [03/05 02:16:39 d2.utils.events]:  eta: 2:07:39  iter: 179  total_loss: 2.074  loss_cls_stage0: 0.2698  loss_box_reg_stage0: 0.3505  loss_cls_stage1: 0.2519  loss_box_reg_stage1: 0.5394  loss_cls_stage2: 0.1758  loss_box_reg_stage2: 0.4133  loss_rpn_cls: 0.03606  loss_rpn_loc: 0.01817    time: 1.5288  last_time: 1.5905  data_time: 0.0328  last_data_time: 0.0317   lr: 9.9684e-05  max_mem: 11500M
# [03/05 02:17:10 d2.utils.events]:  eta: 2:07:13  iter: 199  total_loss: 2.28  loss_cls_stage0: 0.2465  loss_box_reg_stage0: 0.3402  loss_cls_stage1: 0.221  loss_box_reg_stage1: 0.5989  loss_cls_stage2: 0.1902  loss_box_reg_stage2: 0.5452  loss_rpn_cls: 0.04437  loss_rpn_loc: 0.02349    time: 1.5331  last_time: 1.6256  data_time: 0.0332  last_data_time: 0.0314   lr: 9.961e-05  max_mem: 11500M
# [03/05 02:17:41 d2.utils.events]:  eta: 2:06:44  iter: 219  total_loss: 2.322  loss_cls_stage0: 0.2467  loss_box_reg_stage0: 0.3283  loss_cls_stage1: 0.2376  loss_box_reg_stage1: 0.5927  loss_cls_stage2: 0.2216  loss_box_reg_stage2: 0.5944  loss_rpn_cls: 0.03711  loss_rpn_loc: 0.0191    time: 1.5342  last_time: 1.5850  data_time: 0.0311  last_data_time: 0.0293   lr: 9.9527e-05  max_mem: 11500M
# [03/05 02:18:12 d2.utils.events]:  eta: 2:06:16  iter: 239  total_loss: 2.371  loss_cls_stage0: 0.2671  loss_box_reg_stage0: 0.3435  loss_cls_stage1: 0.2546  loss_box_reg_stage1: 0.6428  loss_cls_stage2: 0.2184  loss_box_reg_stage2: 0.64  loss_rpn_cls: 0.03954  loss_rpn_loc: 0.0174    time: 1.5354  last_time: 1.6148  data_time: 0.0332  last_data_time: 0.0311   lr: 9.9437e-05  max_mem: 11500M
# [03/05 02:18:43 d2.utils.events]:  eta: 2:05:51  iter: 259  total_loss: 2.278  loss_cls_stage0: 0.2512  loss_box_reg_stage0: 0.3591  loss_cls_stage1: 0.2544  loss_box_reg_stage1: 0.6048  loss_cls_stage2: 0.2238  loss_box_reg_stage2: 0.5735  loss_rpn_cls: 0.02929  loss_rpn_loc: 0.01588    time: 1.5374  last_time: 1.2977  data_time: 0.0585  last_data_time: 0.2880   lr: 9.9339e-05  max_mem: 11500M
# [03/05 02:19:15 d2.utils.events]:  eta: 2:05:24  iter: 279  total_loss: 2.232  loss_cls_stage0: 0.2407  loss_box_reg_stage0: 0.3146  loss_cls_stage1: 0.2373  loss_box_reg_stage1: 0.5395  loss_cls_stage2: 0.2076  loss_box_reg_stage2: 0.5973  loss_rpn_cls: 0.03252  loss_rpn_loc: 0.01413    time: 1.5409  last_time: 1.6148  data_time: 0.0332  last_data_time: 0.0415   lr: 9.9234e-05  max_mem: 11501M
# [03/05 02:19:46 d2.utils.events]:  eta: 2:04:56  iter: 299  total_loss: 2.364  loss_cls_stage0: 0.2306  loss_box_reg_stage0: 0.3515  loss_cls_stage1: 0.2439  loss_box_reg_stage1: 0.6367  loss_cls_stage2: 0.2248  loss_box_reg_stage2: 0.6895  loss_rpn_cls: 0.02107  loss_rpn_loc: 0.01525    time: 1.5418  last_time: 1.6122  data_time: 0.0339  last_data_time: 0.0333   lr: 9.912e-05  max_mem: 11501M
# [03/05 02:20:17 d2.utils.events]:  eta: 2:04:29  iter: 319  total_loss: 2.414  loss_cls_stage0: 0.2491  loss_box_reg_stage0: 0.3332  loss_cls_stage1: 0.2569  loss_box_reg_stage1: 0.6354  loss_cls_stage2: 0.2325  loss_box_reg_stage2: 0.5916  loss_rpn_cls: 0.02901  loss_rpn_loc: 0.01264    time: 1.5416  last_time: 1.6270  data_time: 0.0456  last_data_time: 0.0308   lr: 9.8999e-05  max_mem: 11501M
# [03/05 02:20:47 d2.utils.events]:  eta: 2:04:00  iter: 339  total_loss: 2.343  loss_cls_stage0: 0.2389  loss_box_reg_stage0: 0.314  loss_cls_stage1: 0.2404  loss_box_reg_stage1: 0.6622  loss_cls_stage2: 0.2304  loss_box_reg_stage2: 0.6531  loss_rpn_cls: 0.02956  loss_rpn_loc: 0.01749    time: 1.5390  last_time: 1.5898  data_time: 0.0336  last_data_time: 0.0299   lr: 9.887e-05  max_mem: 11501M
# ...
# [03/05 04:01:06 d2.utils.events]:  eta: 0:20:11  iter: 4239  total_loss: 0.9925  loss_cls_stage0: 0.05669  loss_box_reg_stage0: 0.1268  loss_cls_stage1: 0.04718  loss_box_reg_stage1: 0.266  loss_cls_stage2: 0.04707  loss_box_reg_stage2: 0.4173  loss_rpn_cls: 0.003465  loss_rpn_loc: 0.005604    time: 1.5423  last_time: 1.6053  data_time: 0.0465  last_data_time: 0.0337   lr: 5.6076e-06  max_mem: 11501M
# [03/05 04:01:36 d2.utils.events]:  eta: 0:19:39  iter: 4259  total_loss: 1.073  loss_cls_stage0: 0.0509  loss_box_reg_stage0: 0.1397  loss_cls_stage1: 0.04403  loss_box_reg_stage1: 0.3104  loss_cls_stage2: 0.04145  loss_box_reg_stage2: 0.4643  loss_rpn_cls: 0.002882  loss_rpn_loc: 0.00653    time: 1.5421  last_time: 1.5969  data_time: 0.0326  last_data_time: 0.0341   lr: 5.322e-06  max_mem: 11501M
# [03/05 04:02:07 d2.utils.events]:  eta: 0:19:07  iter: 4279  total_loss: 1.065  loss_cls_stage0: 0.05602  loss_box_reg_stage0: 0.1328  loss_cls_stage1: 0.04191  loss_box_reg_stage1: 0.3216  loss_cls_stage2: 0.04533  loss_box_reg_stage2: 0.426  loss_rpn_cls: 0.00351  loss_rpn_loc: 0.006341    time: 1.5420  last_time: 1.5871  data_time: 0.0300  last_data_time: 0.0226   lr: 5.0435e-06  max_mem: 11501M
# [03/05 04:02:39 d2.utils.events]:  eta: 0:18:36  iter: 4299  total_loss: 1.051  loss_cls_stage0: 0.0608  loss_box_reg_stage0: 0.1363  loss_cls_stage1: 0.04249  loss_box_reg_stage1: 0.2954  loss_cls_stage2: 0.04495  loss_box_reg_stage2: 0.4518  loss_rpn_cls: 0.00284  loss_rpn_loc: 0.006056    time: 1.5423  last_time: 1.5928  data_time: 0.0306  last_data_time: 0.0302   lr: 4.772e-06  max_mem: 11501M
# [03/05 04:03:09 d2.utils.events]:  eta: 0:18:04  iter: 4319  total_loss: 0.9632  loss_cls_stage0: 0.05668  loss_box_reg_stage0: 0.1281  loss_cls_stage1: 0.04941  loss_box_reg_stage1: 0.2837  loss_cls_stage2: 0.03905  loss_box_reg_stage2: 0.4345  loss_rpn_cls: 0.00358  loss_rpn_loc: 0.006345    time: 1.5422  last_time: 1.6032  data_time: 0.0456  last_data_time: 0.0315   lr: 4.5077e-06  max_mem: 11501M
# [03/05 04:03:41 d2.utils.events]:  eta: 0:17:32  iter: 4339  total_loss: 0.9783  loss_cls_stage0: 0.05875  loss_box_reg_stage0: 0.1215  loss_cls_stage1: 0.05132  loss_box_reg_stage1: 0.2818  loss_cls_stage2: 0.05254  loss_box_reg_stage2: 0.3948  loss_rpn_cls: 0.00359  loss_rpn_loc: 0.006468    time: 1.5424  last_time: 1.6053  data_time: 0.0312  last_data_time: 0.0340   lr: 4.2506e-06  max_mem: 11501M
# [03/05 04:04:12 d2.utils.events]:  eta: 0:17:00  iter: 4359  total_loss: 1.066  loss_cls_stage0: 0.0631  loss_box_reg_stage0: 0.1309  loss_cls_stage1: 0.05385  loss_box_reg_stage1: 0.2953  loss_cls_stage2: 0.05229  loss_box_reg_stage2: 0.4688  loss_rpn_cls: 0.005295  loss_rpn_loc: 0.007242    time: 1.5425  last_time: 1.5935  data_time: 0.0439  last_data_time: 0.0303   lr: 4.0007e-06  max_mem: 11501M
# [03/05 04:04:43 d2.utils.events]:  eta: 0:16:28  iter: 4379  total_loss: 0.9953  loss_cls_stage0: 0.05038  loss_box_reg_stage0: 0.1201  loss_cls_stage1: 0.04309  loss_box_reg_stage1: 0.2715  loss_cls_stage2: 0.03929  loss_box_reg_stage2: 0.4329  loss_rpn_cls: 0.002635  loss_rpn_loc: 0.006147    time: 1.5425  last_time: 1.6018  data_time: 0.0321  last_data_time: 0.0331   lr: 3.7581e-06  max_mem: 11501M
# [03/05 04:05:13 d2.utils.events]:  eta: 0:15:56  iter: 4399  total_loss: 0.9293  loss_cls_stage0: 0.059  loss_box_reg_stage0: 0.1141  loss_cls_stage1: 0.03704  loss_box_reg_stage1: 0.2643  loss_cls_stage2: 0.03677  loss_box_reg_stage2: 0.3941  loss_rpn_cls: 0.003701  loss_rpn_loc: 0.005155    time: 1.5423  last_time: 1.5864  data_time: 0.0317  last_data_time: 0.0211   lr: 3.5227e-06  max_mem: 11501M
# [03/05 04:05:45 d2.utils.events]:  eta: 0:15:24  iter: 4419  total_loss: 1.249  loss_cls_stage0: 0.06936  loss_box_reg_stage0: 0.1551  loss_cls_stage1: 0.05832  loss_box_reg_stage1: 0.364  loss_cls_stage2: 0.046  loss_box_reg_stage2: 0.5334  loss_rpn_cls: 0.003376  loss_rpn_loc: 0.006214    time: 1.5425  last_time: 1.5920  data_time: 0.0326  last_data_time: 0.0281   lr: 3.2948e-06  max_mem: 11501M
# [03/05 04:06:16 d2.utils.events]:  eta: 0:14:52  iter: 4439  total_loss: 0.892  loss_cls_stage0: 0.06056  loss_box_reg_stage0: 0.1269  loss_cls_stage1: 0.05068  loss_box_reg_stage1: 0.2591  loss_cls_stage2: 0.04414  loss_box_reg_stage2: 0.4027  loss_rpn_cls: 0.00319  loss_rpn_loc: 0.004968    time: 1.5426  last_time: 1.6129  data_time: 0.0321  last_data_time: 0.0406   lr: 3.0741e-06  max_mem: 11501M
# [03/05 04:06:47 d2.utils.events]:  eta: 0:14:21  iter: 4459  total_loss: 1.155  loss_cls_stage0: 0.07092  loss_box_reg_stage0: 0.1469  loss_cls_stage1: 0.05099  loss_box_reg_stage1: 0.334  loss_cls_stage2: 0.05501  loss_box_reg_stage2: 0.4958  loss_rpn_cls: 0.004927  loss_rpn_loc: 0.008742    time: 1.5427  last_time: 1.5960  data_time: 0.0465  last_data_time: 0.0328   lr: 2.8609e-06  max_mem: 11501M
# [03/05 04:07:19 d2.utils.events]:  eta: 0:13:49  iter: 4479  total_loss: 1.19  loss_cls_stage0: 0.06207  loss_box_reg_stage0: 0.144  loss_cls_stage1: 0.05625  loss_box_reg_stage1: 0.3097  loss_cls_stage2: 0.05644  loss_box_reg_stage2: 0.4463  loss_rpn_cls: 0.003657  loss_rpn_loc: 0.007013    time: 1.5428  last_time: 1.5866  data_time: 0.0307  last_data_time: 0.0268   lr: 2.6552e-06  max_mem: 11501M
# [03/05 04:07:51 d2.utils.events]:  eta: 0:13:17  iter: 4499  total_loss: 1.1  loss_cls_stage0: 0.07028  loss_box_reg_stage0: 0.1412  loss_cls_stage1: 0.0471  loss_box_reg_stage1: 0.2998  loss_cls_stage2: 0.04557  loss_box_reg_stage2: 0.4668  loss_rpn_cls: 0.008534  loss_rpn_loc: 0.007161    time: 1.5430  last_time: 1.5816  data_time: 0.0312  last_data_time: 0.0197   lr: 2.4569e-06  max_mem: 11501M
# [03/05 04:08:21 d2.utils.events]:  eta: 0:12:45  iter: 4519  total_loss: 1.015  loss_cls_stage0: 0.05635  loss_box_reg_stage0: 0.1298  loss_cls_stage1: 0.04686  loss_box_reg_stage1: 0.2768  loss_cls_stage2: 0.04452  loss_box_reg_stage2: 0.419  loss_rpn_cls: 0.004814  loss_rpn_loc: 0.005829    time: 1.5430  last_time: 1.5923  data_time: 0.0444  last_data_time: 0.0271   lr: 2.2661e-06  max_mem: 11501M
# [03/05 04:08:52 d2.utils.events]:  eta: 0:12:13  iter: 4539  total_loss: 1.074  loss_cls_stage0: 0.07966  loss_box_reg_stage0: 0.1403  loss_cls_stage1: 0.05789  loss_box_reg_stage1: 0.2959  loss_cls_stage2: 0.05452  loss_box_reg_stage2: 0.4511  loss_rpn_cls: 0.003782  loss_rpn_loc: 0.006322    time: 1.5429  last_time: 1.6068  data_time: 0.0450  last_data_time: 0.0386   lr: 2.0829e-06  max_mem: 11501M
# [03/05 04:09:22 d2.utils.events]:  eta: 0:11:42  iter: 4559  total_loss: 1.016  loss_cls_stage0: 0.05881  loss_box_reg_stage0: 0.1208  loss_cls_stage1: 0.03639  loss_box_reg_stage1: 0.2777  loss_cls_stage2: 0.04036  loss_box_reg_stage2: 0.4367  loss_rpn_cls: 0.003811  loss_rpn_loc: 0.0064    time: 1.5428  last_time: 1.0351  data_time: 0.0323  last_data_time: 0.0279   lr: 1.9072e-06  max_mem: 11501M
# [03/05 04:09:52 d2.utils.events]:  eta: 0:11:10  iter: 4579  total_loss: 1.134  loss_cls_stage0: 0.07926  loss_box_reg_stage0: 0.1421  loss_cls_stage1: 0.05525  loss_box_reg_stage1: 0.3269  loss_cls_stage2: 0.0667  loss_box_reg_stage2: 0.4884  loss_rpn_cls: 0.00455  loss_rpn_loc: 0.007133    time: 1.5425  last_time: 1.5909  data_time: 0.0332  last_data_time: 0.0304   lr: 1.7391e-06  max_mem: 11501M
# [03/05 04:10:23 d2.utils.events]:  eta: 0:10:38  iter: 4599  total_loss: 1.067  loss_cls_stage0: 0.06351  loss_box_reg_stage0: 0.137  loss_cls_stage1: 0.04641  loss_box_reg_stage1: 0.3075  loss_cls_stage2: 0.03524  loss_box_reg_stage2: 0.4631  loss_rpn_cls: 0.003037  loss_rpn_loc: 0.007228    time: 1.5427  last_time: 1.6079  data_time: 0.0579  last_data_time: 0.0365   lr: 1.5787e-06  max_mem: 11501M
# [03/05 04:10:54 d2.utils.events]:  eta: 0:10:06  iter: 4619  total_loss: 1.184  loss_cls_stage0: 0.07313  loss_box_reg_stage0: 0.1468  loss_cls_stage1: 0.06061  loss_box_reg_stage1: 0.3431  loss_cls_stage2: 0.05929  loss_box_reg_stage2: 0.463  loss_rpn_cls: 0.007501  loss_rpn_loc: 0.007362    time: 1.5426  last_time: 1.6074  data_time: 0.0330  last_data_time: 0.0367   lr: 1.4259e-06  max_mem: 11501M
# [03/05 04:11:26 d2.utils.events]:  eta: 0:09:34  iter: 4639  total_loss: 1.035  loss_cls_stage0: 0.06286  loss_box_reg_stage0: 0.1283  loss_cls_stage1: 0.04625  loss_box_reg_stage1: 0.297  loss_cls_stage2: 0.04481  loss_box_reg_stage2: 0.4754  loss_rpn_cls: 0.00635  loss_rpn_loc: 0.007542    time: 1.5428  last_time: 1.5979  data_time: 0.0312  last_data_time: 0.0388   lr: 1.2807e-06  max_mem: 11501M
# [03/05 04:11:58 d2.utils.events]:  eta: 0:09:03  iter: 4659  total_loss: 1.189  loss_cls_stage0: 0.06429  loss_box_reg_stage0: 0.1421  loss_cls_stage1: 0.05093  loss_box_reg_stage1: 0.3387  loss_cls_stage2: 0.04439  loss_box_reg_stage2: 0.4617  loss_rpn_cls: 0.003732  loss_rpn_loc: 0.007223    time: 1.5431  last_time: 1.8486  data_time: 0.0578  last_data_time: 0.2788   lr: 1.1433e-06  max_mem: 11501M
# [03/05 04:12:29 d2.utils.events]:  eta: 0:08:31  iter: 4679  total_loss: 1.024  loss_cls_stage0: 0.06414  loss_box_reg_stage0: 0.1279  loss_cls_stage1: 0.04792  loss_box_reg_stage1: 0.2873  loss_cls_stage2: 0.04896  loss_box_reg_stage2: 0.4725  loss_rpn_cls: 0.003228  loss_rpn_loc: 0.007484    time: 1.5432  last_time: 1.6155  data_time: 0.0301  last_data_time: 0.0386   lr: 1.0135e-06  max_mem: 11501M
# [03/05 04:12:58 d2.utils.events]:  eta: 0:07:59  iter: 4699  total_loss: 1.06  loss_cls_stage0: 0.06502  loss_box_reg_stage0: 0.1399  loss_cls_stage1: 0.04557  loss_box_reg_stage1: 0.2894  loss_cls_stage2: 0.04236  loss_box_reg_stage2: 0.4504  loss_rpn_cls: 0.002943  loss_rpn_loc: 0.006693    time: 1.5428  last_time: 1.5850  data_time: 0.0328  last_data_time: 0.0295   lr: 8.9153e-07  max_mem: 11501M
# [03/05 04:13:30 d2.utils.events]:  eta: 0:07:27  iter: 4719  total_loss: 1.134  loss_cls_stage0: 0.07039  loss_box_reg_stage0: 0.1554  loss_cls_stage1: 0.04774  loss_box_reg_stage1: 0.3317  loss_cls_stage2: 0.04881  loss_box_reg_stage2: 0.4967  loss_rpn_cls: 0.003374  loss_rpn_loc: 0.007476    time: 1.5431  last_time: 1.6077  data_time: 0.0315  last_data_time: 0.0248   lr: 7.7729e-07  max_mem: 11501M
# [03/05 04:14:03 d2.utils.events]:  eta: 0:06:55  iter: 4739  total_loss: 1.064  loss_cls_stage0: 0.06292  loss_box_reg_stage0: 0.1272  loss_cls_stage1: 0.04652  loss_box_reg_stage1: 0.2964  loss_cls_stage2: 0.04552  loss_box_reg_stage2: 0.466  loss_rpn_cls: 0.00358  loss_rpn_loc: 0.006589    time: 1.5434  last_time: 1.5939  data_time: 0.0449  last_data_time: 0.0267   lr: 6.7082e-07  max_mem: 11501M
# [03/05 04:14:33 d2.utils.events]:  eta: 0:06:23  iter: 4759  total_loss: 1.03  loss_cls_stage0: 0.04958  loss_box_reg_stage0: 0.1135  loss_cls_stage1: 0.03705  loss_box_reg_stage1: 0.276  loss_cls_stage2: 0.03642  loss_box_reg_stage2: 0.4457  loss_rpn_cls: 0.003801  loss_rpn_loc: 0.005571    time: 1.5432  last_time: 1.5939  data_time: 0.0449  last_data_time: 0.0235   lr: 5.7214e-07  max_mem: 11501M
# [03/05 04:15:02 d2.utils.events]:  eta: 0:05:51  iter: 4779  total_loss: 1.156  loss_cls_stage0: 0.07516  loss_box_reg_stage0: 0.1517  loss_cls_stage1: 0.05694  loss_box_reg_stage1: 0.3263  loss_cls_stage2: 0.05726  loss_box_reg_stage2: 0.4646  loss_rpn_cls: 0.005412  loss_rpn_loc: 0.007334    time: 1.5430  last_time: 1.5891  data_time: 0.0296  last_data_time: 0.0217   lr: 4.8127e-07  max_mem: 11501M
# [03/05 04:15:34 d2.utils.events]:  eta: 0:05:19  iter: 4799  total_loss: 1.147  loss_cls_stage0: 0.06102  loss_box_reg_stage0: 0.136  loss_cls_stage1: 0.04169  loss_box_reg_stage1: 0.3347  loss_cls_stage2: 0.03856  loss_box_reg_stage2: 0.4801  loss_rpn_cls: 0.004351  loss_rpn_loc: 0.006463    time: 1.5430  last_time: 1.6001  data_time: 0.0426  last_data_time: 0.0291   lr: 3.9821e-07  max_mem: 11501M
# [03/05 04:16:04 d2.utils.events]:  eta: 0:04:47  iter: 4819  total_loss: 1.032  loss_cls_stage0: 0.08138  loss_box_reg_stage0: 0.1386  loss_cls_stage1: 0.07089  loss_box_reg_stage1: 0.2813  loss_cls_stage2: 0.05257  loss_box_reg_stage2: 0.4482  loss_rpn_cls: 0.005489  loss_rpn_loc: 0.006815    time: 1.5429  last_time: 1.6026  data_time: 0.0330  last_data_time: 0.0353   lr: 3.2299e-07  max_mem: 11501M
# [03/05 04:16:36 d2.utils.events]:  eta: 0:04:15  iter: 4839  total_loss: 1.092  loss_cls_stage0: 0.08028  loss_box_reg_stage0: 0.1573  loss_cls_stage1: 0.05853  loss_box_reg_stage1: 0.3019  loss_cls_stage2: 0.04974  loss_box_reg_stage2: 0.4817  loss_rpn_cls: 0.003312  loss_rpn_loc: 0.007795    time: 1.5432  last_time: 1.5934  data_time: 0.0326  last_data_time: 0.0291   lr: 2.5561e-07  max_mem: 11501M
# [03/05 04:17:07 d2.utils.events]:  eta: 0:03:43  iter: 4859  total_loss: 1.123  loss_cls_stage0: 0.05712  loss_box_reg_stage0: 0.1366  loss_cls_stage1: 0.0466  loss_box_reg_stage1: 0.3131  loss_cls_stage2: 0.04389  loss_box_reg_stage2: 0.4579  loss_rpn_cls: 0.002982  loss_rpn_loc: 0.006458    time: 1.5433  last_time: 1.5964  data_time: 0.0571  last_data_time: 0.0277   lr: 1.9609e-07  max_mem: 11501M
# [03/05 04:17:38 d2.utils.events]:  eta: 0:03:11  iter: 4879  total_loss: 0.9214  loss_cls_stage0: 0.04785  loss_box_reg_stage0: 0.1174  loss_cls_stage1: 0.03113  loss_box_reg_stage1: 0.2545  loss_cls_stage2: 0.02954  loss_box_reg_stage2: 0.4014  loss_rpn_cls: 0.003553  loss_rpn_loc: 0.005817    time: 1.5432  last_time: 1.5999  data_time: 0.0291  last_data_time: 0.0223   lr: 1.4443e-07  max_mem: 11501M
# [03/05 04:18:07 d2.utils.events]:  eta: 0:02:39  iter: 4899  total_loss: 1.071  loss_cls_stage0: 0.0561  loss_box_reg_stage0: 0.1366  loss_cls_stage1: 0.04556  loss_box_reg_stage1: 0.2896  loss_cls_stage2: 0.04463  loss_box_reg_stage2: 0.468  loss_rpn_cls: 0.002695  loss_rpn_loc: 0.005923    time: 1.5429  last_time: 1.6080  data_time: 0.0337  last_data_time: 0.0348   lr: 1.0065e-07  max_mem: 11501M
# [03/05 04:18:39 d2.utils.events]:  eta: 0:02:07  iter: 4919  total_loss: 1.012  loss_cls_stage0: 0.05939  loss_box_reg_stage0: 0.1277  loss_cls_stage1: 0.04561  loss_box_reg_stage1: 0.2975  loss_cls_stage2: 0.04514  loss_box_reg_stage2: 0.4571  loss_rpn_cls: 0.003372  loss_rpn_loc: 0.00602    time: 1.5430  last_time: 1.6094  data_time: 0.0312  last_data_time: 0.0418   lr: 6.474e-08  max_mem: 11501M
# [03/05 04:19:10 d2.utils.events]:  eta: 0:01:35  iter: 4939  total_loss: 0.9315  loss_cls_stage0: 0.04491  loss_box_reg_stage0: 0.1063  loss_cls_stage1: 0.03586  loss_box_reg_stage1: 0.2679  loss_cls_stage2: 0.03274  loss_box_reg_stage2: 0.4284  loss_rpn_cls: 0.002373  loss_rpn_loc: 0.00707    time: 1.5431  last_time: 1.6371  data_time: 0.0306  last_data_time: 0.0275   lr: 3.672e-08  max_mem: 11501M
# [03/05 04:19:42 d2.utils.events]:  eta: 0:01:03  iter: 4959  total_loss: 1.161  loss_cls_stage0: 0.06644  loss_box_reg_stage0: 0.1453  loss_cls_stage1: 0.05118  loss_box_reg_stage1: 0.3256  loss_cls_stage2: 0.04914  loss_box_reg_stage2: 0.5022  loss_rpn_cls: 0.003174  loss_rpn_loc: 0.007409    time: 1.5433  last_time: 1.6269  data_time: 0.0458  last_data_time: 0.0371   lr: 1.659e-08  max_mem: 11501M
# [03/05 04:20:13 d2.utils.events]:  eta: 0:00:31  iter: 4979  total_loss: 1.145  loss_cls_stage0: 0.06497  loss_box_reg_stage0: 0.1376  loss_cls_stage1: 0.05183  loss_box_reg_stage1: 0.3218  loss_cls_stage2: 0.04841  loss_box_reg_stage2: 0.4955  loss_rpn_cls: 0.003086  loss_rpn_loc: 0.00658    time: 1.5432  last_time: 1.6010  data_time: 0.0320  last_data_time: 0.0262   lr: 4.3524e-09  max_mem: 11501M
# [03/05 04:20:45 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 0.9423  loss_cls_stage0: 0.04795  loss_box_reg_stage0: 0.1157  loss_cls_stage1: 0.03655  loss_box_reg_stage1: 0.2657  loss_cls_stage2: 0.03592  loss_box_reg_stage2: 0.4106  loss_rpn_cls: 0.002034  loss_rpn_loc: 0.005423    time: 1.5432  last_time: 1.6032  data_time: 0.0293  last_data_time: 0.0309   lr: 9.8697e-12  max_mem: 11501M
# [03/05 04:20:45 d2.engine.hooks]: Overall training speed: 4998 iterations in 2:08:33 (1.5432 s / it)
# [03/05 04:20:45 d2.engine.hooks]: Total training time: 2:08:49 (0:00:16 on hooks)

# %% [markdown]
# ## 7. Visualize Train Hooks
# ___

# %%
metrics = pd.read_json(os.path.join(CFG.output_dir, 'metrics.json'), orient='records', lines=True)
metrics = metrics.sort_values(by=['iteration'])

print('Shape of Metrics: ',metrics.shape)
metrics.head()
# Out:
# Shape of Metrics:  (250, 32)
#    data_time  eta_seconds  iteration  loss_box_reg_stage0  \
# 0   0.017943  7873.158612         19             0.209209
# 1   0.021975  7878.894349         39             0.326605
# 2   0.023249  7847.547896         59             0.360066
# 3   0.025324  7809.963031         79             0.505758
# 4   0.025093  7776.434500         99             0.413361
#
#    loss_box_reg_stage1  loss_box_reg_stage2  loss_cls_stage0  loss_cls_stage1  \
# 0             0.089908             0.032098         0.290447         0.171257
# 1             0.153059             0.039798         0.349090         0.171568
# 2             0.177175             0.055387         0.355838         0.169619
# 3             0.273172             0.075307         0.433622         0.235436
# 4             0.310723             0.098488         0.340445         0.222496
#
#    loss_cls_stage2  loss_rpn_cls  ...  stage1/fast_rcnn/fg_cls_accuracy  \
# 0         0.117364      0.165087  ...                               0.0
# 1         0.085481      0.070802  ...                               0.0
# 2         0.090226      0.064847  ...                               0.0
# 3         0.111691      0.057406  ...                               0.0
# 4         0.111211      0.042721  ...                               0.0
#
#    stage1/roi_head/num_bg_samples  stage1/roi_head/num_fg_samples  \
# 0                        250.0000                          6.0000
# 1                        247.6875                          8.3125
# 2                        246.7500                          9.2500
# 3                        242.5000                         13.5000
# 4                        241.4375                         14.5625
#
#    stage2/fast_rcnn/cls_accuracy  stage2/fast_rcnn/false_negative  \
# 0                       0.986084                              1.0
# 1                       0.986572                              1.0
# 2                       0.984375                              1.0
# 3                       0.979980                              1.0
# 4                       0.977539                              1.0
#
#    stage2/fast_rcnn/fg_cls_accuracy  stage2/roi_head/num_bg_samples  \
# 0                               0.0                        252.8125
# 1                               0.0                        252.5625
# 2                               0.0                        252.0000
# 3                               0.0                        250.8750
# 4                               0.0                        250.2500
#
#    stage2/roi_head/num_fg_samples      time  total_loss
# 0                          3.1875  1.580956    1.143890
# 1                          3.4375  1.593977    1.225362
# 2                          4.0000  1.588705    1.252749
# 3                          5.1250  1.584968    1.736760
# 4                          5.7500  1.580703    1.637436
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Scheduler Graph

# %%
print('Scheduler Type is :', CFG.lr_scheduler_name)
print('Base Learning Rate is :', CFG.base_lr)
print('Last Learning Rate is :', CFG.base_lr_end/CFG.base_lr)
print('Iteration is: ', CFG.max_iter)

plt.style.use('default')
plt.figure(figsize=(12,6))
plt.title(CFG.lr_scheduler_name, size=10)

tmp = metrics[~metrics['lr'].isna()]

plt.plot(tmp['iteration'], tmp['lr'])
plt.xlabel('iterations')
plt.ylabel('Learning Rate')

plt.show()
# Out:
# Scheduler Type is : CosineParamScheduler
# Base Learning Rate is : 0.0001
# Last Learning Rate is : 1e-12
# Iteration is:  5000

# %% [markdown]
# #### Foreground & Background Fraction in RPN & ROI

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('RPN Fraction Ratio')
tmp = metrics[~metrics['rpn/num_neg_anchors'].isna()]
tmp = tmp[~tmp['rpn/num_pos_anchors'].isna()]
plt.plot(tmp['iteration'], tmp['rpn/num_neg_anchors'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_neg_anchors'].mean(), tmp['rpn/num_neg_anchors'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['rpn/num_pos_anchors'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_pos_anchors'].mean(),tmp['rpn/num_pos_anchors'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title('ROI Head Fraction Ratio')
tmp = metrics[~metrics['roi_head/num_bg_samples'].isna()]
tmp = tmp[~tmp['roi_head/num_fg_samples'].isna()]
plt.plot(tmp['iteration'], tmp['roi_head/num_bg_samples'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_bg_samples'].mean(), tmp['roi_head/num_bg_samples'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['roi_head/num_fg_samples'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_fg_samples'].mean(),tmp['roi_head/num_fg_samples'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Loss: rpn_loc, rpn_cls, box_reg, box_cls

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(3,3,1)
tmp1 = metrics[~metrics['loss_box_reg_stage0'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_box_reg_stage0'], color='red', label='box_reg_stage0')
plt.grid(True); plt.legend()

plt.subplot(3,3,2)
tmp1 = metrics[~metrics['loss_box_reg_stage1'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_box_reg_stage1'], color='red', label='box_reg_stage1')
plt.grid(True); plt.legend()

plt.subplot(3,3,3)
tmp1 = metrics[~metrics['loss_box_reg_stage2'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_box_reg_stage2'], color='red', label='box_reg_stage2')
plt.grid(True); plt.legend()

plt.subplot(3,3,4)
tmp2 = metrics[~metrics['loss_cls_stage0'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_cls_stage0'], color='orange', label='box_cls_stage0')
plt.grid(True); plt.legend()

plt.subplot(3,3,5)
tmp2 = metrics[~metrics['loss_cls_stage1'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_cls_stage1'], color='orange', label='box_cls_stage1')
plt.grid(True); plt.legend()

plt.subplot(3,3,6)
tmp2 = metrics[~metrics['loss_cls_stage2'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_cls_stage2'], color='orange', label='box_cls_stage2')
plt.grid(True); plt.legend()

plt.subplot(3,3,7)
tmp3 = metrics[~metrics['loss_rpn_cls'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_cls'], color='green', label='rpn_cls')
plt.grid(True); plt.legend()

plt.subplot(3,3,8)
tmp4 = metrics[~metrics['loss_rpn_loc'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_loc'], color='skyblue', label='rpn_loc')
plt.grid(True); plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Evaluation
# ___

# %%
cfg = setup()

evaluator = COCOEvaluator("colonoscopy_valid", ("bbox",), False, output_dir=os.path.join(CFG.output_dir, 'inference'))

val_loader = build_detection_test_loader(
      dataset = get_detection_dataset_dicts(names='colonoscopy_valid'),
      mapper=AlbumentationsMapper(is_train=False),
      batch_size = CFG.ims_per_batch,
      num_workers = CFG.num_workers,
      )

## Build and Load Model
model = instantiate(cfg.model)
DetectionCheckpointer(model, save_dir=CFG.output_dir).resume_or_load(
            f'{CFG.output_dir}/model_final.pth', resume=False
        )
model.eval()

## Evaluate Metrics
result = inference_on_dataset(model, val_loader, evaluator)

clean_memory(); del model, evaluator, val_loader
# Out:
# [03/05 04:20:48 d2.evaluation.coco_evaluation]: Trying to convert 'colonoscopy_valid' to COCO format ...
# [03/05 04:20:48 d2.data.datasets.coco]: Converting annotations of dataset 'colonoscopy_valid' to COCO format ...)
# [03/05 04:20:48 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [03/05 04:20:48 d2.data.datasets.coco]: Conversion finished, #images: 320, #annotations: 391
# [03/05 04:20:48 d2.data.datasets.coco]: Caching COCO format annotations at 'runs/detect/inference/colonoscopy_valid_coco_format.json' ...
# [03/05 04:20:48 d2.data.build]: Removed 0 images with no usable annotations. 320 images left.
# [03/05 04:20:48 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 133          |   Polyp    | 85           |   Cancer   | 173          |
# |            |              |            |              |            |              |
# |   total    | 391          |            |              |            |              |
# [AlbumentationsMapper] Augmentations used in inference: Compose([
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [03/05 04:20:48 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/05 04:20:48 d2.data.common]: Serializing 320 elements to byte tensors and concatenating them all ...
# [03/05 04:20:48 d2.data.common]: Serialized dataset takes 0.09 MiB
# [03/05 04:20:50 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from runs/detect/model_final.pth ...
# [03/05 04:20:51 d2.evaluation.evaluator]: Start inference on 40 batches
# [03/05 04:21:38 d2.evaluation.evaluator]: Inference done 1/40. Dataloading: 0.3960 s/iter. Inference: 47.1404 s/iter. Eval: 0.0030 s/iter. Total: 47.5411 s/iter. ETA=0:30:54
# [03/05 04:22:25 d2.evaluation.evaluator]: Inference done 2/40. Dataloading: 0.1997 s/iter. Inference: 47.0837 s/iter. Eval: 0.0028 s/iter. Total: 47.2889 s/iter. ETA=0:29:56
# [03/05 04:23:11 d2.evaluation.evaluator]: Inference done 3/40. Dataloading: 0.1342 s/iter. Inference: 46.5500 s/iter. Eval: 0.0025 s/iter. Total: 46.6888 s/iter. ETA=0:28:47
# [03/05 04:23:57 d2.evaluation.evaluator]: Inference done 4/40. Dataloading: 0.1047 s/iter. Inference: 46.4045 s/iter. Eval: 0.0025 s/iter. Total: 46.5136 s/iter. ETA=0:27:54
# [03/05 04:24:43 d2.evaluation.evaluator]: Inference done 5/40. Dataloading: 0.0953 s/iter. Inference: 46.4591 s/iter. Eval: 0.0024 s/iter. Total: 46.5585 s/iter. ETA=0:27:09
# [03/05 04:25:29 d2.evaluation.evaluator]: Inference done 6/40. Dataloading: 0.0000 s/iter. Inference: 45.0978 s/iter. Eval: 0.0017 s/iter. Total: 45.0996 s/iter. ETA=0:25:33
# [03/05 04:26:14 d2.evaluation.evaluator]: Inference done 7/40. Dataloading: 0.0015 s/iter. Inference: 45.1699 s/iter. Eval: 0.0022 s/iter. Total: 45.1741 s/iter. ETA=0:24:50
# [03/05 04:26:59 d2.evaluation.evaluator]: Inference done 8/40. Dataloading: 0.0019 s/iter. Inference: 45.1051 s/iter. Eval: 0.0020 s/iter. Total: 45.1097 s/iter. ETA=0:24:03
# [03/05 04:27:45 d2.evaluation.evaluator]: Inference done 9/40. Dataloading: 0.0056 s/iter. Inference: 45.3875 s/iter. Eval: 0.0020 s/iter. Total: 45.3959 s/iter. ETA=0:23:27
# [03/05 04:28:32 d2.evaluation.evaluator]: Inference done 10/40. Dataloading: 0.0076 s/iter. Inference: 45.6640 s/iter. Eval: 0.0020 s/iter. Total: 45.6744 s/iter. ETA=0:22:50
# [03/05 04:29:18 d2.evaluation.evaluator]: Inference done 11/40. Dataloading: 0.0091 s/iter. Inference: 45.7935 s/iter. Eval: 0.0019 s/iter. Total: 45.8054 s/iter. ETA=0:22:08
# [03/05 04:30:05 d2.evaluation.evaluator]: Inference done 12/40. Dataloading: 0.0105 s/iter. Inference: 45.9872 s/iter. Eval: 0.0019 s/iter. Total: 46.0005 s/iter. ETA=0:21:28
# [03/05 04:30:52 d2.evaluation.evaluator]: Inference done 13/40. Dataloading: 0.0112 s/iter. Inference: 46.0340 s/iter. Eval: 0.0019 s/iter. Total: 46.0479 s/iter. ETA=0:20:43
# [03/05 04:31:37 d2.evaluation.evaluator]: Inference done 14/40. Dataloading: 0.0117 s/iter. Inference: 45.9756 s/iter. Eval: 0.0019 s/iter. Total: 45.9902 s/iter. ETA=0:19:55
# [03/05 04:32:23 d2.evaluation.evaluator]: Inference done 15/40. Dataloading: 0.0123 s/iter. Inference: 45.8927 s/iter. Eval: 0.0019 s/iter. Total: 45.9078 s/iter. ETA=0:19:07
# [03/05 04:33:08 d2.evaluation.evaluator]: Inference done 16/40. Dataloading: 0.0128 s/iter. Inference: 45.8721 s/iter. Eval: 0.0019 s/iter. Total: 45.8877 s/iter. ETA=0:18:21
# [03/05 04:33:54 d2.evaluation.evaluator]: Inference done 17/40. Dataloading: 0.0129 s/iter. Inference: 45.8430 s/iter. Eval: 0.0019 s/iter. Total: 45.8588 s/iter. ETA=0:17:34
# [03/05 04:34:40 d2.evaluation.evaluator]: Inference done 18/40. Dataloading: 0.0130 s/iter. Inference: 45.8717 s/iter. Eval: 0.0020 s/iter. Total: 45.8876 s/iter. ETA=0:16:49
# [03/05 04:35:26 d2.evaluation.evaluator]: Inference done 19/40. Dataloading: 0.0133 s/iter. Inference: 45.8595 s/iter. Eval: 0.0019 s/iter. Total: 45.8757 s/iter. ETA=0:16:03
# [03/05 04:36:11 d2.evaluation.evaluator]: Inference done 20/40. Dataloading: 0.0134 s/iter. Inference: 45.8047 s/iter. Eval: 0.0019 s/iter. Total: 45.8210 s/iter. ETA=0:15:16
# [03/05 04:36:57 d2.evaluation.evaluator]: Inference done 21/40. Dataloading: 0.0137 s/iter. Inference: 45.8170 s/iter. Eval: 0.0019 s/iter. Total: 45.8336 s/iter. ETA=0:14:30
# [03/05 04:37:42 d2.evaluation.evaluator]: Inference done 22/40. Dataloading: 0.0139 s/iter. Inference: 45.7996 s/iter. Eval: 0.0020 s/iter. Total: 45.8164 s/iter. ETA=0:13:44
# [03/05 04:38:28 d2.evaluation.evaluator]: Inference done 23/40. Dataloading: 0.0140 s/iter. Inference: 45.7894 s/iter. Eval: 0.0020 s/iter. Total: 45.8064 s/iter. ETA=0:12:58
# [03/05 04:39:13 d2.evaluation.evaluator]: Inference done 24/40. Dataloading: 0.0141 s/iter. Inference: 45.7319 s/iter. Eval: 0.0019 s/iter. Total: 45.7489 s/iter. ETA=0:12:11
# [03/05 04:39:58 d2.evaluation.evaluator]: Inference done 25/40. Dataloading: 0.0142 s/iter. Inference: 45.6936 s/iter. Eval: 0.0019 s/iter. Total: 45.7108 s/iter. ETA=0:11:25
# [03/05 04:40:43 d2.evaluation.evaluator]: Inference done 26/40. Dataloading: 0.0144 s/iter. Inference: 45.6578 s/iter. Eval: 0.0019 s/iter. Total: 45.6751 s/iter. ETA=0:10:39
# [03/05 04:41:28 d2.evaluation.evaluator]: Inference done 27/40. Dataloading: 0.0145 s/iter. Inference: 45.6334 s/iter. Eval: 0.0020 s/iter. Total: 45.6508 s/iter. ETA=0:09:53
# [03/05 04:42:14 d2.evaluation.evaluator]: Inference done 28/40. Dataloading: 0.0146 s/iter. Inference: 45.6465 s/iter. Eval: 0.0020 s/iter. Total: 45.6640 s/iter. ETA=0:09:07
# [03/05 04:42:59 d2.evaluation.evaluator]: Inference done 29/40. Dataloading: 0.0146 s/iter. Inference: 45.6465 s/iter. Eval: 0.0020 s/iter. Total: 45.6641 s/iter. ETA=0:08:22
# [03/05 04:43:45 d2.evaluation.evaluator]: Inference done 30/40. Dataloading: 0.0147 s/iter. Inference: 45.6413 s/iter. Eval: 0.0019 s/iter. Total: 45.6590 s/iter. ETA=0:07:36
# [03/05 04:44:31 d2.evaluation.evaluator]: Inference done 31/40. Dataloading: 0.0147 s/iter. Inference: 45.6507 s/iter. Eval: 0.0019 s/iter. Total: 45.6684 s/iter. ETA=0:06:51
# [03/05 04:45:15 d2.evaluation.evaluator]: Inference done 32/40. Dataloading: 0.0148 s/iter. Inference: 45.6113 s/iter. Eval: 0.0020 s/iter. Total: 45.6291 s/iter. ETA=0:06:05
# [03/05 04:46:22 d2.evaluation.evaluator]: Inference done 33/40. Dataloading: 0.7587 s/iter. Inference: 45.6076 s/iter. Eval: 0.0020 s/iter. Total: 46.3693 s/iter. ETA=0:05:24
# [03/05 04:47:07 d2.evaluation.evaluator]: Inference done 34/40. Dataloading: 0.7331 s/iter. Inference: 45.5905 s/iter. Eval: 0.0020 s/iter. Total: 46.3266 s/iter. ETA=0:04:37
# [03/05 04:47:52 d2.evaluation.evaluator]: Inference done 35/40. Dataloading: 0.7092 s/iter. Inference: 45.5724 s/iter. Eval: 0.0019 s/iter. Total: 46.2846 s/iter. ETA=0:03:51
# [03/05 04:48:37 d2.evaluation.evaluator]: Inference done 36/40. Dataloading: 0.6869 s/iter. Inference: 45.5635 s/iter. Eval: 0.0019 s/iter. Total: 46.2533 s/iter. ETA=0:03:05
# [03/05 04:49:23 d2.evaluation.evaluator]: Inference done 37/40. Dataloading: 0.6659 s/iter. Inference: 45.5554 s/iter. Eval: 0.0020 s/iter. Total: 46.2243 s/iter. ETA=0:02:18
# [03/05 04:50:08 d2.evaluation.evaluator]: Inference done 38/40. Dataloading: 0.6462 s/iter. Inference: 45.5385 s/iter. Eval: 0.0020 s/iter. Total: 46.1877 s/iter. ETA=0:01:32
# [03/05 04:50:52 d2.evaluation.evaluator]: Inference done 39/40. Dataloading: 0.6276 s/iter. Inference: 45.5081 s/iter. Eval: 0.0019 s/iter. Total: 46.1387 s/iter. ETA=0:00:46
# [03/05 04:51:38 d2.evaluation.evaluator]: Inference done 40/40. Dataloading: 0.6101 s/iter. Inference: 45.5295 s/iter. Eval: 0.0019 s/iter. Total: 46.1426 s/iter. ETA=0:00:00
# [03/05 04:51:39 d2.evaluation.evaluator]: Total inference time: 0:26:55.156294 (46.147323 s / iter per device, on 1 devices)
# [03/05 04:51:39 d2.evaluation.evaluator]: Total inference pure compute time: 0:26:33 (45.529492 s / iter per device, on 1 devices)
# [03/05 04:51:39 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [03/05 04:51:39 d2.evaluation.coco_evaluation]: Saving results to runs/detect/inference/coco_instances_results.json
# [03/05 04:51:39 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# [03/05 04:51:39 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [03/05 04:51:39 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.21 seconds.
# [03/05 04:51:39 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [03/05 04:51:39 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.07 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.444
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.441
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.259
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.437
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.470
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.640
# [03/05 04:51:39 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 44.383 | 70.164 | 44.116 | 25.928 | 43.682 | 52.440 |
# [03/05 04:51:39 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Ulcer      | 19.074 | Polyp      | 56.331 | Cancer     | 57.743 |

# %%
# !pip -q install palettable
import palettable.colorbrewer.qualitative as pbq

plt.title('Bbox AP in Valid Dataset', size=10)
ax = plt.barh(y=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'],
        width=[result['bbox']['AP'], result['bbox']['AP50'], result['bbox']['AP75'], result['bbox']['APl'],
           result['bbox']['APm'], result['bbox']['APm'],], 
        color=pbq.Pastel1_7.hex_colors, edgecolor='white',
        label=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'])

for rect in ax.patches:
    x = rect.get_width()
    y = rect.get_y() + rect.get_height()/2.0
    plt.text(x, y, f'{x:.2f}', ha='left', va='center', size=10, color='blue')

plt.legend()
plt.show()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 6.1 MB/s eta 0:00:00

# %%
plt.style.use('default')
plt.figure(figsize=(12,6))

plt.title('AP by Class', size=10)
ax = plt.bar(
    x=[f'AP-{col}' for col in thing_classes],
    height=[result['bbox'][f'AP-{col}'] for col in thing_classes],
    color=pbq.Pastel1_7.hex_colors,
    edgecolor='white',
    label=[f'bbox/AP-{col}' for col in thing_classes]
)

# 막대 위에 텍스트 추가
for rect in ax.patches:
    x = rect.get_x() + rect.get_width() / 2.0  # 막대 중앙 x좌표
    y = rect.get_height()  # 막대 길이
    plt.text(x, y, f'{y:.2f}', ha='center', va='bottom', size=10, color='gray')  # 텍스트 위치 조정


plt.legend()
plt.xticks(rotation=60)
plt.show()
