# %% [markdown]
# ## 1. Import Library
# ___

# %%
import os
import sys
import pickle
import random
import gc
import ctypes
import copy

from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from colorama import Fore

from PIL import Image
import cv2

import torch
import torch.nn as nn

from sklearn.model_selection import GroupKFold
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Configuration

# %%
class CFG:
    debug = False
    output_dir = 'runs/detect'
    seed = 42
    train_ds = 'colonoscopy_train' ##DatasetDictSampler
    
    model_name = 'MViTv2_T' ## Tiny Version
    img_size = [1024,1024]
    input_format = 'RGB' ## VitDet 
    imgdir = '/kaggle/input/colonoscopy-256x256-resized-png'

    split_mode = 'valid20'
    max_iter = 5_000
    ims_per_batch = 4
    num_workers = 4

    lr_scheduler_name = "CosineParamScheduler" ## MultiStepParamScheduler
    base_lr = 1e-4
    base_lr_end = base_lr * 1e-9
    weight_decay = 1e-2
    eval_period = max_iter * 10 ## In Training
    log_period = 20
    amp = True

    device = 'cuda' if torch.cuda.is_available() else 'cpu'

os.makedirs(CFG.output_dir, exist_ok=True)

# %% [markdown]
# #### Reproducibility

# %%
def seed_everything(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark= False

    os.environ['PYTHONHASHSEED'] = str(seed)

seed_everything(CFG.seed)

# %% [markdown]
# #### Clean_memory

# %%
def clean_memory():
    ctypes.CDLL('libc.so.6').malloc_trim(0)
    gc.collect()
    
clean_memory()

# %% [markdown]
# #### Install Detectron2 Library

# %%
print(f'=> {Fore.GREEN}Installing Detectron2 Library...' )
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# => Installing Detectron2 Library...
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.3 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done

# %% [markdown]
# ## 2. Build Dataset_Dicts
# ___
#
# - **궤양**: `ulcer(label: 0)`
#
# - **용종**: `polyp(label: 1)`
#
# - **암**: `cancer(label: 2)`

# %%
meta_data = pd.read_csv('/kaggle/input/metadataset/colonoscopy_data2.csv')
print('Shape of DataFrame: ', meta_data.shape)
meta_data.head()
# Out:
# Shape of DataFrame:  (2496, 14)
#         image_id  height  width        organ  lesion_label  location  \
# 0  2_1_00001.png    2048   2048  colonoscopy             0         1
# 1  2_1_00001.png    2048   2048  colonoscopy             0         1
# 2  2_1_00002.png    2048   2048  colonoscopy             0         1
# 3  2_1_00002.png    2048   2048  colonoscopy             0         1
# 4  2_1_00002.png    2048   2048  colonoscopy             0         1
#
#   shape_type_polygon                                       polygon_mask  \
# 0            polygon  1484.52,775.16;1516.82,710.56;1519.30,640.99;1...
# 1            polygon  1663.40,1478.26;1653.47,1426.09;1616.20,1388.8...
# 2            polygon  687.01,223.60;687.01,273.29;704.40,337.89;726....
# 3            polygon  826.14,1200.00;878.31,1207.45;932.97,1187.58;9...
# 4            polygon  575.20,1038.51;520.55,1050.93;468.37,1050.93;4...
#
#   bounding_box_shape        x_min        y_min        x_max        y_max  \
# 0          rectangle   838.559006   149.068323  1519.304348   807.453416
# 1          rectangle  1310.608696  1324.223602  1663.403727  1868.322981
# 2          rectangle   687.006211   168.944099  1591.354037  1465.838509
# 3          rectangle   488.248447   434.782609  1007.503106  1207.453416
# 4          rectangle   212.472050   725.465839   607.503106  1050.931677
#
#   lesion
# 0  ulcer
# 1  ulcer
# 2  ulcer
# 3  ulcer
# 4  ulcer

# %%
thing_classes = [
    'Ulcer',
    'Polyp',
    'Cancer',
]

category_id_to_name = {index: class_name for index,class_name in enumerate(thing_classes) }

meta_data['lesion'] = meta_data['lesion_label'].map(category_id_to_name)

# %%
train_id = [x.split('/')[-1] for x in glob('/kaggle/input/colonoscopy-256x256-resized-png/train/*.png')] 
test_id = [x.split('/')[-1] for x in glob('/kaggle/input/colonoscopy-256x256-resized-png/test/*.png')] 

train_df = meta_data[meta_data['image_id'].isin(train_id)].reset_index(drop=True)
test_df = meta_data[meta_data['image_id'].isin(test_id)].reset_index(drop=True)

print('=> Number of Unique Image_id in Train: ', train_df.image_id.nunique())
print('=> Number of Unique Image_id in Test: ', test_df.image_id.nunique())
# Out:
# => Number of Unique Image_id in Train:  1596
# => Number of Unique Image_id in Test:  400

# %%
from detectron2.structures import BoxMode

def get_colonoscopy_dicts(
    imgdir: str, 
    df,
    mode: str = 'train',
    use_cache: bool = True, 
    debug: bool = True,
    target_indices: list = None
): 
    debug_str = f"_debug{int(debug)}"
    cache_path = f'/kaggle/working/dataset_dicts_cache_{mode}{debug_str}.pkl'

    if not use_cache or not os.path.exists(cache_path):
       print(f'{Fore.BLUE}#'* 25)
       print(f'### Creating {mode} Data...')
       print('#' * 25)

       meta_df = pd.read_csv(f'/kaggle/input/colonoscopy-256x256-resized-png/{mode}_meta.csv')
        
       if debug:
           meta_df = meta_df[:500]

       image_id = meta_df.loc[0,'image_id']
       image_path = os.path.join(imgdir,mode, image_id)
       image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
       resized_height, resized_width, channel = image.shape
       print(f'=> Height of Image: {resized_height}')
       print(f'=> Width of Image: {resized_width}')

       dataset_dicts = []
       for _, (image_id, height, width) in tqdm(meta_df.iterrows(), total=len(meta_df), desc='Build Dataset Dict'):
           record = {}
           record['file_name'] = os.path.join(imgdir,'train',image_id)
           record['image_id'] = image_id
           record['height'] = resized_height
           record['width'] = resized_width

           if mode != 'test':
              objs = []
              for _, row in df[df.image_id == image_id].iterrows():
                  class_id = row['lesion_label']

                  h_ratio = resized_height / height
                  w_ratio = resized_width / width

                  bbox_resized = [
                      row['x_min'] * w_ratio,
                      row['y_min'] * h_ratio,
                      row['x_max'] * w_ratio,
                      row['y_max'] * h_ratio,
                  ]

                  obj = {
                     'bbox': bbox_resized,
                     'bbox_mode': BoxMode.XYXY_ABS,
                     'category_id': class_id,
                  }
                  objs.append(obj)
              record['annotations'] = objs
              dataset_dicts.append(record)
           else: 
              dataset_dicts.append(record)
       with open(cache_path, mode='wb') as f:
           pickle.dump(dataset_dicts, f)
    with open(cache_path, mode='rb') as f:
        dataset_dicts = pickle.load(f)

    if target_indices is not None:
        dataset_dicts = [dataset_dicts[i] for i in target_indices]

    return dataset_dicts

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog

if CFG.split_mode == 'valid20':
    n_dataset = len(
        get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug)
        )
    
    n_train = int(n_dataset * 0.8)
    n_valid = n_dataset - n_train
    rs = np.random.RandomState(CFG.seed)
    inds = rs.permutation(n_dataset)
    train_inds, valid_inds = inds[:n_train], inds[n_train:]

    print(f'n_train: {len(train_inds)} n_valid: {len(valid_inds)}')

    DatasetCatalog.register(
        'colonoscopy_train',
        lambda: get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = train_inds
        )
    )
    MetadataCatalog.get('colonoscopy_train').set(thing_classes = thing_classes)

    DatasetCatalog.register(
        'colonoscopy_valid',
        lambda: get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = valid_inds
        )
    )

    MetadataCatalog.get('colonoscopy_valid').set(thing_classes = thing_classes)
# Out:
# #########################
# ### Creating train Data...
# #########################
# => Height of Image: 256
# => Width of Image: 256
# Build Dataset Dict: 100%|██████████| 1596/1596 [00:01<00:00, 1451.10it/s]
# n_train: 1276 n_valid: 320

# %%
dataset_dicts = get_colonoscopy_dicts(CFG.imgdir, train_df, mode='train', debug=CFG.debug)

clean_memory()

# %% [markdown]
# ## 3. Build Albumentation Mapper
# ___

# %%
def get_train_transform():
    return A.Compose(
               [
                A.HorizontalFlip(p=0.5),

                ## CLAHE
                A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0),

               
                ### Channel Transform
                A.OneOf([
                    A.ChannelShuffle(p=1.0),
                    A.ChannelDropout(p=1.0),
                    A.ToGray(p=1.0),
                    A.RGBShift(r_shift_limit=[-5,5], g_shift_limit=[-5,5], b_shift_limit=[-5,5], p=1.0)],
                    p=0.5),

                ### Dropout Transform   
                A.OneOf([
                    A.XYMasking(
                        num_masks_x=[1,1],
                        num_masks_y=[1,1],
                        mask_x_length = [int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],
                        mask_y_length = [int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        p=1.0),
                    A.CoarseDropout(
                        num_holes_range=[2,4],
                        hole_height_range=[int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        hole_width_range=[int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],p=1.0),
                    A.BBoxSafeRandomCrop(
                        height=int(CFG.img_size[0] * 0.8),  # 높이 계산
                         width=int(CFG.img_size[1] * 0.8), p=1.0),],
                    p=0.25),

                ## Noisy Transform
                A.OneOf([
                    A.RandomGravel(number_of_patches=1, p=1.0),
                    A.RandomSnow(brightness_coeff=1.1, p=1.0),
                ],
                    p=0.25
                       ), 
                
                A.Resize(*CFG.img_size, p=1.0),
                ],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    ) 
        
def get_valid_transform():
    return A.Compose(
                [A.Resize(*CFG.img_size, p=1.0),],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    )

# %%
import albumentations as A
import detectron2.data.transforms as T
from detectron2.data import detection_utils as utils

class AlbumentationsMapper:
    def __init__(self, is_train: bool=True, mixup_prob: float=0.1, mosaic_prob: float=0.25):
        self.is_train = is_train
        self.mixup_prob = mixup_prob
        self.mosaic_prob = mosaic_prob
        
        if self.is_train:
            self.transform = get_train_transform()
        else:
            self.transform = get_valid_transform()
            

        mode='training' if self.is_train else 'inference'
        print(f'{Fore.GREEN}[AlbumentationsMapper]{Fore.BLACK} Augmentations used in {mode}: {self.transform}')

    def datadict_sampler(self, ds_name=CFG.train_ds, n=3):
        ds = DatasetCatalog.get(ds_name)

        indices = np.random.randint(0, len(ds) - 1, n)
        return [copy.deepcopy(ds[idx]) for idx in indices]

    def __mixup_transform(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        mu_dict = self.datadict_sampler(n=1)[0]

        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        mu_image = utils.read_image(mu_dict['file_name'], format=CFG.input_format)

        lam = np.random.beta(2.0, 2.0)
        image = (lam * image + (1 - lam) * mu_image).astype(np.uint8)
        
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        image = transform(image=image)['image']
        dataset_dict['image'] = image
        dataset_dict['annotations'] += mu_dict['annotations']
            
        return dataset_dict

    def __mosaic_transform(self, dataset_dict):
        dataset_dict= copy.deepcopy(dataset_dict)
        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        im_h, im_w = image.shape[:2]
        resized_w = random.randint(int(im_w*0.75), int(im_w*1.25))
        resized_h = random.randint(int(im_h*0.75), int(im_h*1.25))
        image = cv2.resize(image, (resized_w, resized_h))
        boxes = np.array([anno['bbox'] for anno in dataset_dict['annotations']]) 
        boxes[:,[0,2]] *= resized_w / im_w
        boxes[:,[1,3]] *= resized_h / im_h
        
        mo_items = self.datadict_sampler(n=3)
        mo_images = []
        mo_boxes = []
        
        resize_list = [
            [(im_w*2-resized_w),resized_h], [resized_w,(im_h*2-resized_h)], [(im_w*2-resized_w),(im_h*2-resized_h)],
        ]
        
        for i, mo_dict in enumerate(mo_items):
            mo_image = utils.read_image(mo_dict['file_name'],format=CFG.input_format)
            mo_h, mo_w = mo_image.shape[:2]
            mo_image = cv2.resize(mo_image, (resize_list[i][0], resize_list[i][1]))
            mo_images.append(mo_image)
            mo_bbox = np.array([
                 anno['bbox'] for anno in mo_dict['annotations']
            ])
            mo_bbox[:,[0,2]] *= resize_list[i][0] / mo_w
            mo_bbox[:,[1,3]] *= resize_list[i][1] / mo_h
            mo_boxes.append(mo_bbox)
             
        
            dataset_dict['annotations'] += mo_dict['annotations']
        
        images = [image] + mo_images
        boxes = [boxes] + mo_boxes

        
        heights = [i.shape[0] for i in images] 
        widths =  [i.shape[1] for i in images]

        ch = max(heights[0], heights[1])
        cw = max(widths[0], widths[2]) 
        h = (max(heights[0], heights[1]) + 
             max(heights[2], heights[3]))
        w = (max(widths[0], widths[2]) +
             max(widths[1], widths[3]))
        
        # pad or start coordinates 
        y0, x0 = ch - heights[0], cw - widths[0] # Height: 0,  Width: 0 
        y1, x1 = ch - heights[1], cw # Height: 0, Width: 256 
        y2, x2 = ch, cw - widths[2] # Height: 256, Width: 0
        y3, x3 = ch, cw # Height: 256, Width: 256
        x_pads = [x0, x1, x2, x3]
        y_pads = [y0, y1, y2, y3]

        output = np.zeros((h,w,3)).astype(np.uint8)
        for i, img in enumerate(images):
            output[y_pads[i]: y_pads[i] + heights[i],
                   x_pads[i]: x_pads[i] + widths[i],
                   :] = img
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        output = transform(image=output)['image']
        dataset_dict['image'] = output

        for i, bbox in enumerate(boxes):
            bbox += np.array([x_pads[i], y_pads[i], x_pads[i], y_pads[i]])
            
        boxes = np.vstack(boxes)

        for i, box in enumerate(boxes):
            dataset_dict['annotations'][i]['bbox'] = box
        
        return dataset_dict
        
    def __call__(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)

        if self.is_train:
            if np.random.rand() <= self.mosaic_prob:
               dataset_dict = self.__mosaic_transform(dataset_dict)

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict
            elif np.random.rand() <= self.mixup_prob:
               dataset_dict = self.__mixup_transform(dataset_dict)
    

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict

        
        image = utils.read_image(dataset_dict['file_name'], format=CFG.input_format)

        ### Bounding Box
        bboxes = np.array([obj['bbox'] for obj in dataset_dict['annotations']], dtype=np.float32)
        annotation_id = np.arange(len(dataset_dict['annotations']))

        ### Applying Augmentation
        transformed = self.transform(image=image, bboxes=bboxes, category_ids=annotation_id)
        dataset_dict['image'] = transformed['image']
        
        for i in transformed['category_ids']:
            dataset_dict['annotations'][i]['bbox'] = transformed['bboxes'][i] 
        

        image_shape = (CFG.img_size[1], CFG.img_size[0]) # height, width
        dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

        instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
        dataset_dict['instances'] = utils.filter_empty_instances(instances)

        ## Remove annotations for convert to instances
        dataset_dict.pop('annotations', None)

        return dataset_dict

# %% [markdown]
# ## 4. Visualize ColonoScopy Augmentation
# ___

# %%
colonoscopy_metadata = MetadataCatalog.get('colonoscopy_train')
print(colonoscopy_metadata)
# Out:
# Metadata(name='colonoscopy_train', thing_classes=['Ulcer', 'Polyp', 'Cancer'])

# %%
import detectron2
from detectron2.utils.visualizer import Visualizer, ColorMode

mapper = AlbumentationsMapper(is_train=True)

plt.figure(figsize=(12,8))

for i in range(8):
    plt.subplot(4,4,2*i+1)
    plt.title('Before Augmentation')
    d = dataset_dicts[i]
    img = Image.open(d['file_name'])
    img = np.array(img)
    img = cv2.resize(img, tuple(CFG.img_size))
    visualizer = Visualizer(img, metadata=colonoscopy_metadata, scale=1.0)
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image())
    plt.axis('off')
    
    plt.subplot(4,4, 2*i+2)
    plt.title('After Augmentation')
    mapped_d = mapper(d)
    img_arr = mapped_d['image'].cpu().permute(1,2,0).numpy()
    # img_arr[:,:,::-1] # BGR -> RGB
    # VitModel's Input Format: RGB
    visualizer = Visualizer(img_arr, metadata=colonoscopy_metadata, scale=1.0)
    target_fields = mapped_d['instances'].get_fields()
    labels = [colonoscopy_metadata.thing_classes[i] for i in target_fields['gt_classes']]

    out = visualizer.overlay_instances(
        labels = labels,
        boxes = target_fields.get('gt_boxes',None),
        masks = target_fields.get('gt_masks',None),
        keypoints = target_fields.get('gt_keypoints', None)
    )
     
    plt.imshow(out.get_image())
    plt.axis('off')

    del out, visualizer, labels
    
plt.tight_layout()
plt.show()

del mapper; clean_memory()
# Out:
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(51, 102), mask_y_length=(51, 102), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(51, 102), hole_width_range=(51, 102)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=1024, width=1024, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)

# %% [markdown]
# ## 5. Lazyconfing Train Net
# ___
#
# 1) DefaultTrainer is limited to yacs configs. So, for using LazyConfig file, we should use `SimpleTrainer` or `AMPTrainer`
#
# 2) LazyConfig is an alternative, non-intrusive config system that can be used with detectron2 or potentially any other complex projects.
#
# ![image.png](attachment:41883ae9-a20e-45de-a56d-09184cd02ac0.png)

# %%
import logging
from functools import partial
from fvcore.common.param_scheduler import MultiStepParamScheduler, CosineParamScheduler

from omegaconf import OmegaConf

from detectron2 import model_zoo 
from detectron2.config import get_cfg, LazyConfig, instantiate
from detectron2.config import LazyCall as L

from detectron2.data import (
    build_detection_train_loader, 
    build_detection_test_loader,
    DatasetMapper,
    get_detection_dataset_dicts)

from detectron2.evaluation import (
     COCOEvaluator,
     inference_on_dataset, 
     print_csv_format)

from detectron2.engine import (
     create_ddp_model,
     AMPTrainer, SimpleTrainer,
     default_argument_parser, default_setup, default_writers,
     hooks, launch ## DDP 
)

from detectron2.solver import WarmupParamScheduler
from detectron2.checkpoint import DetectionCheckpointer
from detectron2.modeling import MViT

from detectron2.utils import comm
from detectron2.utils.logger import setup_logger

setup_logger()
# Out:
# <_Logger detectron2 (DEBUG)>

# %% [markdown]
# #### Setting LazyConfig File

# %%
def setup():
    """DataLoader LazyConfig"""
    dataloader = OmegaConf.create()

    dataloader.train = L(build_detection_train_loader)(
        dataset = L(get_detection_dataset_dicts)(names='colonoscopy_train'),
        mapper = L(AlbumentationsMapper)(is_train=True),
        total_batch_size = CFG.ims_per_batch,
        num_workers = CFG.num_workers
    )

    """Train LazyConfig"""
    train = model_zoo.get_config("common/train.py").train
    train.amp.enabled = True 
    train.ddp.fp16_compression = True
    train.init_checkpoint = (
    "detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth"
    )
    train.output_dir = CFG.output_dir
    train.max_iter = CFG.max_iter
    train.eval_period = CFG.eval_period
    train.checkpointer.period = CFG.eval_period
    train.log_period = CFG.log_period
    train.device = CFG.device

    """Scheduler LazyConfig"""
    lr_multiplier = L(WarmupParamScheduler)(
    scheduler=L(CosineParamScheduler)( 
        start_value = 1, 
        end_value = CFG.base_lr_end / CFG.base_lr),
    warmup_length=0,
    warmup_factor=0,
    warmup_method='linear'
    )

    """Optimizer LazyConfig"""
    optimizer = model_zoo.get_config("common/optim.py").AdamW ## or SGD
    optimizer.params.overrides = {
    "pos_embed": {"weight_decay": 0.0},
    "rel_pos_h": {"weight_decay": 0.0},
    "rel_pos_w": {"weight_decay": 0.0},
     } 
    
    optimizer.lr = CFG.base_lr
        
    optimizer.weight_decay = CFG.weight_decay

    """Model LazyConfig"""
    model = model_zoo.get_config("common/models/mask_rcnn_fpn.py").model
    model.input_format = CFG.input_format

    model.backbone.bottom_up = L(MViT)(
    embed_dim=96,
    depth=10,
    num_heads=1,
    last_block_indexes=(0, 2, 7, 9),
    residual_pooling=True,
    drop_path_rate=0.2,
    norm_layer=partial(nn.LayerNorm, eps=1e-6),
    out_features=("scale2", "scale3", "scale4", "scale5"),
    )
    model.backbone.in_features = "${.bottom_up.out_features}"

    #### Model RPN 
    model.proposal_generator.in_features = ['p2','p3','p4','p5','p6']
    model.proposal_generator.anchor_generator.sizes = [[32], [64], [128], [256], [512]]
    model.proposal_generator.anchor_generator.aspect_ratios = [0.5, 1.0, 2.0]
    model.proposal_generator.anchor_generator.offset = 0.5
    model.proposal_generator.anchor_matcher.thresholds = [0.3, 0.7]
    model.proposal_generator.batch_size_per_image = 256
    model.proposal_generator.pre_nms_topk = [2000, 1000]
    model.proposal_generator.post_nms_topk = [1000, 1000]
    
    #### Model ROI
    model.roi_heads.num_classes = len(thing_classes)
    model.roi_heads.batch_size_per_image = 512
    model.roi_heads.box_in_features = ['p2','p3','p4','p5']
    model.roi_heads.box_pooler.output_size = 7
    model.roi_heads.box_pooler.pooler_type = 'ROIAlignV2'
    model.roi_heads.proposal_matcher.thresholds = [0.5]
    model.roi_heads.box_predictor.test_score_thresh = 0.0

    cfg = OmegaConf.create()
    cfg.model = model
    cfg.dataloader = dataloader
    cfg.train = train
    cfg.optimizer = optimizer
    cfg.lr_multiplier = lr_multiplier

    """Mask-RCNN -> Faster-RCNN"""
    del cfg.model.roi_heads.mask_in_features
    del cfg.model.roi_heads.mask_pooler
    del cfg.model.roi_heads.mask_head 

    return cfg

# %% [markdown]
# #### train_net.py

# %%
def do_train(resume, cfg):
    model = instantiate(cfg.model)
    logger = logging.getLogger('detectron2')
    logger.info("Model:\n{}".format(model))
    model.to(cfg.train.device)

    cfg.optimizer.params.model = model
    optim = instantiate(cfg.optimizer)

    train_loader = instantiate(cfg.dataloader.train)

    model = create_ddp_model(model, **cfg.train.ddp)
    trainer = (AMPTrainer if cfg.train.amp.enabled else SimpleTrainer)(model, train_loader, optim)

    checkpointer = DetectionCheckpointer(
        model, cfg.train.output_dir, trainer=trainer
    )

    ## including timing 
    ## including checkpointing
    ## including lr scheduling
    ## including writing events
    trainer.register_hooks(
        [
            hooks.IterationTimer(),
            hooks.LRScheduler(scheduler=instantiate(cfg.lr_multiplier)),
            hooks.PeriodicCheckpointer(checkpointer, **cfg.train.checkpointer)
            if comm.is_main_process() else None,
            hooks.PeriodicWriter(
                default_writers(cfg.train.output_dir, cfg.train.max_iter),
                period = cfg.train.log_period,
            )
            if comm.is_main_process() else None,
        ]
    )

    checkpointer.resume_or_load(cfg.train.init_checkpoint, resume=resume)
    if resume and checkpointer.has_checkpoint():
        start_iter = trainer.iter + 1
    else:
        start_iter = 0
    trainer.train(start_iter, cfg.train.max_iter)

# %% [markdown]
# #### save lazy config file

# %%
config_file = LazyConfig.to_py(setup())

with open(f'{CFG.output_dir}/mvit_config.py', 'w') as f:
    f.write(config_file)

# %%
SHOW = True

if SHOW:
    with open(f'{CFG.output_dir}/mvit_config.py', 'r') as f:
        print(f.read())
# Out:
# cfg.dataloader.train=detectron2.data.build_detection_train_loader(dataset=detectron2.data.get_detection_dataset_dicts(names='colonoscopy_train'), mapper=__main__.AlbumentationsMapper(is_train=True), num_workers=4, total_batch_size=4)
# cfg.lr_multiplier=detectron2.solver.WarmupParamScheduler(scheduler=fvcore.common.param_scheduler.CosineParamScheduler(end_value=1e-09, start_value=1), warmup_factor=0, warmup_length=0, warmup_method='linear')
# cfg.model=detectron2.modeling.GeneralizedRCNN(backbone=detectron2.modeling.FPN(bottom_up=detectron2.modeling.MViT(depth=10, drop_path_rate=0.2, embed_dim=96, last_block_indexes=[0,2,7,9], norm_layer=functools.partial(<class 'torch.nn.modules.normalization.LayerNorm'>, eps=1e-06), num_heads=1, out_features=['scale2','scale3','scale4','scale5'], residual_pooling=True), in_features=['scale2','scale3','scale4','scale5'], out_channels=256, top_block=detectron2.modeling.backbone.fpn.LastLevelMaxPool()), input_format='RGB', pixel_mean=[103.53,116.28,123.675], pixel_std=[1.0,1.0,1.0], proposal_generator=detectron2.modeling.proposal_generator.RPN(anchor_generator=detectron2.modeling.anchor_generator.DefaultAnchorGenerator(aspect_ratios=[0.5,1.0,2.0], offset=0.5, sizes=[[32],[64],[128],[256],[512]], strides=[4,8,16,32,64]), anchor_matcher=detectron2.modeling.matcher.Matcher(allow_low_quality_matches=True, labels=[0,-1,1], thresholds=[0.3,0.7]), batch_size_per_image=256, box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[1.0,1.0,1.0,1.0]), head=detectron2.modeling.proposal_generator.StandardRPNHead(in_channels=256, num_anchors=3), in_features=['p2','p3','p4','p5','p6'], nms_thresh=0.7, positive_fraction=0.5, post_nms_topk=[1000,1000], pre_nms_topk=[2000,1000]), roi_heads=detectron2.modeling.StandardROIHeads(batch_size_per_image=512, box_head=detectron2.modeling.roi_heads.FastRCNNConvFCHead(conv_dims=[], fc_dims=[1024,1024], input_shape={'channels': 256,'height': 7,'stride': None,'width': 7}), box_in_features=['p2','p3','p4','p5'], box_pooler=detectron2.modeling.poolers.ROIPooler(output_size=7, pooler_type='ROIAlignV2', sampling_ratio=0, scales=[0.25,0.125,0.0625,0.03125]), box_predictor=detectron2.modeling.FastRCNNOutputLayers(box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[10,10,5,5]), input_shape={'channels': 1024,'height': None,'stride': None,'width': None}, num_classes=3, test_score_thresh=0.0), num_classes=3, positive_fraction=0.25, proposal_matcher=detectron2.modeling.matcher.Matcher(allow_low_quality_matches=False, labels=[0,1], thresholds=[0.5])))
# cfg.optimizer=torch.optim.AdamW(betas=[0.9,0.999], lr=0.0001, params=detectron2.solver.get_default_optimizer_params(base_lr=0.0001, overrides={'pos_embed': {'weight_decay': 0.0},'rel_pos_h': {'weight_decay': 0.0},'rel_pos_w': {'weight_decay': 0.0}}, weight_decay_norm=0.0), weight_decay=0.01)
# cfg.train.amp.enabled=True
# cfg.train.checkpointer.max_to_keep=100
# cfg.train.checkpointer.period=50000
# cfg.train.ddp.broadcast_buffers=False
# cfg.train.ddp.find_unused_parameters=False
# cfg.train.ddp.fp16_compression=True
# cfg.train.device='cuda'
# cfg.train.eval_period=50000
# cfg.train.init_checkpoint='detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth'
# cfg.train.log_period=20
# cfg.train.max_iter=5000
# cfg.train.output_dir='runs/detect'

# %% [markdown]
# ## 6. Training MultiScale VisionTransformer Detection Model
# ___

# %%
do_train(resume=False, cfg=setup())
# Out:
# [03/03 04:56:10 detectron2]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): MViT(
#       (patch_embed): PatchEmbed(
#         (proj): Conv2d(3, 96, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#       )
#       (blocks): ModuleList(
#         (0): MultiScaleBlock(
#           (norm1): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=96, out_features=288, bias=True)
#             (proj): Linear(in_features=96, out_features=96, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): MultiScaleBlock(
#           (norm1): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=96, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.022)
#           (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=96, out_features=192, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (2): MultiScaleBlock(
#           (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.044)
#           (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): MultiScaleBlock(
#           (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=192, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.067)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=192, out_features=384, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (4): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.089)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.111)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.133)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.156)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=2304, bias=True)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.178)
#           (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=384, out_features=768, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (9): MultiScaleBlock(
#           (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.200)
#           (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (scale2_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#       (scale3_norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (scale4_norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (scale5_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#   )
# )
# [03/03 04:56:11 d2.data.build]: Removed 0 images with no usable annotations. 1276 images left.
# [03/03 04:56:11 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 630          |   Polyp    | 352          |   Cancer   | 627          |
# |            |              |            |              |            |              |
# |   total    | 1609         |            |              |            |              |
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(51, 102), mask_y_length=(51, 102), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(51, 102), hole_width_range=(51, 102)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=1024, width=1024, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [03/03 04:56:11 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/03 04:56:11 d2.data.common]: Serializing 1276 elements to byte tensors and concatenating them all ...
# [03/03 04:56:11 d2.data.common]: Serialized dataset takes 0.37 MiB
# [03/03 04:56:11 d2.data.build]: Making batched data loader with batch_size=4
# [03/03 04:56:11 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth ...
# MViTv2_T_in1k.pyth: 290MB [00:02, 120MB/s]
# [03/03 04:56:14 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 54
# [03/03 04:56:14 d2.engine.train_loop]: Starting training from iteration 0
# [03/03 04:56:43 d2.utils.events]:  eta: 1:49:15  iter: 19  total_loss: 0.6722  loss_cls: 0.2605  loss_box_reg: 0.0875  loss_rpn_cls: 0.1981  loss_rpn_loc: 0.02337    time: 1.3222  last_time: 1.3133  data_time: 0.0318  last_data_time: 0.0217   lr: 9.9996e-05  max_mem: 11937M
# [03/03 04:57:21 d2.utils.events]:  eta: 1:49:01  iter: 39  total_loss: 0.3373  loss_cls: 0.147  loss_box_reg: 0.08855  loss_rpn_cls: 0.06522  loss_rpn_loc: 0.01736    time: 1.3004  last_time: 1.3135  data_time: 0.0216  last_data_time: 0.0191   lr: 9.9985e-05  max_mem: 11938M
# [03/03 04:57:47 d2.utils.events]:  eta: 1:48:20  iter: 59  total_loss: 0.3497  loss_cls: 0.1261  loss_box_reg: 0.09059  loss_rpn_cls: 0.05805  loss_rpn_loc: 0.02043    time: 1.3056  last_time: 1.3007  data_time: 0.0226  last_data_time: 0.0198   lr: 9.9966e-05  max_mem: 11940M
# [03/03 04:58:13 d2.utils.events]:  eta: 1:47:49  iter: 79  total_loss: 0.419  loss_cls: 0.1915  loss_box_reg: 0.1426  loss_rpn_cls: 0.05857  loss_rpn_loc: 0.02273    time: 1.3073  last_time: 1.3098  data_time: 0.0203  last_data_time: 0.0202   lr: 9.9938e-05  max_mem: 11941M
# [03/03 04:58:39 d2.utils.events]:  eta: 1:47:28  iter: 99  total_loss: 0.3645  loss_cls: 0.1634  loss_box_reg: 0.1147  loss_rpn_cls: 0.05025  loss_rpn_loc: 0.01689    time: 1.3005  last_time: 1.3263  data_time: 0.0220  last_data_time: 0.0189   lr: 9.9903e-05  max_mem: 11941M
# [03/03 04:59:04 d2.utils.events]:  eta: 1:46:56  iter: 119  total_loss: 0.4352  loss_cls: 0.1899  loss_box_reg: 0.1573  loss_rpn_cls: 0.05858  loss_rpn_loc: 0.02277    time: 1.2949  last_time: 1.3169  data_time: 0.0214  last_data_time: 0.0233   lr: 9.986e-05  max_mem: 11941M
# [03/03 04:59:30 d2.utils.events]:  eta: 1:46:35  iter: 139  total_loss: 0.363  loss_cls: 0.1615  loss_box_reg: 0.134  loss_rpn_cls: 0.04634  loss_rpn_loc: 0.02318    time: 1.2984  last_time: 1.3185  data_time: 0.0238  last_data_time: 0.0199   lr: 9.9809e-05  max_mem: 11941M
# [03/03 04:59:57 d2.utils.events]:  eta: 1:46:10  iter: 159  total_loss: 0.3375  loss_cls: 0.1478  loss_box_reg: 0.135  loss_rpn_cls: 0.03846  loss_rpn_loc: 0.02402    time: 1.3007  last_time: 1.3152  data_time: 0.0233  last_data_time: 0.0255   lr: 9.9751e-05  max_mem: 11941M
# [03/03 05:00:23 d2.utils.events]:  eta: 1:45:39  iter: 179  total_loss: 0.3921  loss_cls: 0.1831  loss_box_reg: 0.1408  loss_rpn_cls: 0.0509  loss_rpn_loc: 0.02414    time: 1.3019  last_time: 1.3066  data_time: 0.0217  last_data_time: 0.0235   lr: 9.9684e-05  max_mem: 11941M
# [03/03 05:00:49 d2.utils.events]:  eta: 1:45:12  iter: 199  total_loss: 0.4086  loss_cls: 0.1851  loss_box_reg: 0.1596  loss_rpn_cls: 0.0423  loss_rpn_loc: 0.02386    time: 1.3027  last_time: 1.3004  data_time: 0.0212  last_data_time: 0.0214   lr: 9.961e-05  max_mem: 11941M
# [03/03 05:01:15 d2.utils.events]:  eta: 1:44:43  iter: 219  total_loss: 0.5079  loss_cls: 0.2138  loss_box_reg: 0.1842  loss_rpn_cls: 0.04603  loss_rpn_loc: 0.02305    time: 1.3035  last_time: 1.3138  data_time: 0.0215  last_data_time: 0.0145   lr: 9.9527e-05  max_mem: 11941M
# [03/03 05:01:42 d2.utils.events]:  eta: 1:44:16  iter: 239  total_loss: 0.42  loss_cls: 0.187  loss_box_reg: 0.1747  loss_rpn_cls: 0.0367  loss_rpn_loc: 0.02257    time: 1.3044  last_time: 1.3024  data_time: 0.0230  last_data_time: 0.0191   lr: 9.9437e-05  max_mem: 11941M
# [03/03 05:02:07 d2.utils.events]:  eta: 1:43:49  iter: 259  total_loss: 0.4061  loss_cls: 0.1752  loss_box_reg: 0.1745  loss_rpn_cls: 0.03256  loss_rpn_loc: 0.02266    time: 1.3016  last_time: 1.3249  data_time: 0.0217  last_data_time: 0.0198   lr: 9.9339e-05  max_mem: 11942M
# [03/03 05:02:33 d2.utils.events]:  eta: 1:43:20  iter: 279  total_loss: 0.4772  loss_cls: 0.2035  loss_box_reg: 0.1905  loss_rpn_cls: 0.04282  loss_rpn_loc: 0.02636    time: 1.3019  last_time: 1.3154  data_time: 0.0211  last_data_time: 0.0210   lr: 9.9234e-05  max_mem: 11942M
# [03/03 05:03:00 d2.utils.events]:  eta: 1:42:53  iter: 299  total_loss: 0.3825  loss_cls: 0.1802  loss_box_reg: 0.1286  loss_rpn_cls: 0.0322  loss_rpn_loc: 0.01717    time: 1.3026  last_time: 1.3156  data_time: 0.0220  last_data_time: 0.0245   lr: 9.912e-05  max_mem: 11942M
# [03/03 05:03:26 d2.utils.events]:  eta: 1:42:25  iter: 319  total_loss: 0.4367  loss_cls: 0.1931  loss_box_reg: 0.1817  loss_rpn_cls: 0.03567  loss_rpn_loc: 0.01814    time: 1.3030  last_time: 1.3076  data_time: 0.0205  last_data_time: 0.0196   lr: 9.8999e-05  max_mem: 11942M
# [03/03 05:03:52 d2.utils.events]:  eta: 1:41:59  iter: 339  total_loss: 0.422  loss_cls: 0.1892  loss_box_reg: 0.1801  loss_rpn_cls: 0.03066  loss_rpn_loc: 0.02163    time: 1.3036  last_time: 1.3064  data_time: 0.0224  last_data_time: 0.0172   lr: 9.887e-05  max_mem: 11942M
# [03/03 05:04:18 d2.utils.events]:  eta: 1:41:33  iter: 359  total_loss: 0.4213  loss_cls: 0.1828  loss_box_reg: 0.1718  loss_rpn_cls: 0.03285  loss_rpn_loc: 0.02028    time: 1.3042  last_time: 1.3079  data_time: 0.0233  last_data_time: 0.0265   lr: 9.8733e-05  max_mem: 11942M
# [03/03 05:04:45 d2.utils.events]:  eta: 1:41:07  iter: 379  total_loss: 0.3989  loss_cls: 0.1766  loss_box_reg: 0.1738  loss_rpn_cls: 0.03644  loss_rpn_loc: 0.0218    time: 1.3048  last_time: 1.3045  data_time: 0.0229  last_data_time: 0.0181   lr: 9.8589e-05  max_mem: 11942M
# [03/03 05:05:11 d2.utils.events]:  eta: 1:40:42  iter: 399  total_loss: 0.4158  loss_cls: 0.1799  loss_box_reg: 0.1804  loss_rpn_cls: 0.02758  loss_rpn_loc: 0.02129    time: 1.3056  last_time: 1.3165  data_time: 0.0248  last_data_time: 0.0190   lr: 9.8437e-05  max_mem: 11942M
# [03/03 05:05:37 d2.utils.events]:  eta: 1:40:15  iter: 419  total_loss: 0.4179  loss_cls: 0.1879  loss_box_reg: 0.1732  loss_rpn_cls: 0.03146  loss_rpn_loc: 0.02703    time: 1.3059  last_time: 1.3169  data_time: 0.0233  last_data_time: 0.0244   lr: 9.8277e-05  max_mem: 11942M
# [03/03 05:06:03 d2.utils.events]:  eta: 1:39:49  iter: 439  total_loss: 0.4106  loss_cls: 0.1737  loss_box_reg: 0.1803  loss_rpn_cls: 0.03885  loss_rpn_loc: 0.02388    time: 1.3044  last_time: 1.3183  data_time: 0.0227  last_data_time: 0.0279   lr: 9.811e-05  max_mem: 11942M
# [03/03 05:06:28 d2.utils.events]:  eta: 1:39:23  iter: 459  total_loss: 0.3827  loss_cls: 0.1703  loss_box_reg: 0.1592  loss_rpn_cls: 0.02898  loss_rpn_loc: 0.01472    time: 1.3030  last_time: 1.3233  data_time: 0.0235  last_data_time: 0.0282   lr: 9.7935e-05  max_mem: 11942M
# [03/03 05:06:55 d2.utils.events]:  eta: 1:38:58  iter: 479  total_loss: 0.3851  loss_cls: 0.1756  loss_box_reg: 0.1624  loss_rpn_cls: 0.02568  loss_rpn_loc: 0.01428    time: 1.3036  last_time: 1.3433  data_time: 0.0255  last_data_time: 0.0284   lr: 9.7753e-05  max_mem: 11942M
# [03/03 05:07:21 d2.utils.events]:  eta: 1:38:33  iter: 499  total_loss: 0.374  loss_cls: 0.1763  loss_box_reg: 0.1477  loss_rpn_cls: 0.02263  loss_rpn_loc: 0.01757    time: 1.3042  last_time: 1.3071  data_time: 0.0251  last_data_time: 0.0176   lr: 9.7563e-05  max_mem: 11942M
# [03/03 05:07:47 d2.utils.events]:  eta: 1:38:06  iter: 519  total_loss: 0.4438  loss_cls: 0.1985  loss_box_reg: 0.196  loss_rpn_cls: 0.0266  loss_rpn_loc: 0.02253    time: 1.3045  last_time: 1.3148  data_time: 0.0234  last_data_time: 0.0202   lr: 9.7365e-05  max_mem: 11942M
# [03/03 05:08:14 d2.utils.events]:  eta: 1:37:41  iter: 539  total_loss: 0.3401  loss_cls: 0.1538  loss_box_reg: 0.1353  loss_rpn_cls: 0.02334  loss_rpn_loc: 0.01725    time: 1.3051  last_time: 1.2954  data_time: 0.0260  last_data_time: 0.0236   lr: 9.716e-05  max_mem: 11942M
# [03/03 05:08:40 d2.utils.events]:  eta: 1:37:15  iter: 559  total_loss: 0.3757  loss_cls: 0.1685  loss_box_reg: 0.1634  loss_rpn_cls: 0.02527  loss_rpn_loc: 0.01772    time: 1.3055  last_time: 1.3184  data_time: 0.0231  last_data_time: 0.0198   lr: 9.6948e-05  max_mem: 11942M
# [03/03 05:09:06 d2.utils.events]:  eta: 1:36:49  iter: 579  total_loss: 0.3864  loss_cls: 0.1735  loss_box_reg: 0.1742  loss_rpn_cls: 0.03271  loss_rpn_loc: 0.02023    time: 1.3058  last_time: 1.3258  data_time: 0.0227  last_data_time: 0.0210   lr: 9.6728e-05  max_mem: 11942M
# [03/03 05:09:33 d2.utils.events]:  eta: 1:36:24  iter: 599  total_loss: 0.3831  loss_cls: 0.1787  loss_box_reg: 0.1568  loss_rpn_cls: 0.02908  loss_rpn_loc: 0.01741    time: 1.3063  last_time: 1.3316  data_time: 0.0247  last_data_time: 0.0288   lr: 9.65e-05  max_mem: 11942M
# [03/03 05:09:59 d2.utils.events]:  eta: 1:35:59  iter: 619  total_loss: 0.3833  loss_cls: 0.1671  loss_box_reg: 0.1648  loss_rpn_cls: 0.02415  loss_rpn_loc: 0.01862    time: 1.3068  last_time: 1.3222  data_time: 0.0262  last_data_time: 0.0268   lr: 9.6266e-05  max_mem: 11942M
# [03/03 05:10:25 d2.utils.events]:  eta: 1:35:33  iter: 639  total_loss: 0.3627  loss_cls: 0.16  loss_box_reg: 0.1503  loss_rpn_cls: 0.02302  loss_rpn_loc: 0.02007    time: 1.3071  last_time: 1.3157  data_time: 0.0245  last_data_time: 0.0249   lr: 9.6024e-05  max_mem: 11942M
# [03/03 05:10:51 d2.utils.events]:  eta: 1:35:06  iter: 659  total_loss: 0.4283  loss_cls: 0.1976  loss_box_reg: 0.1784  loss_rpn_cls: 0.02439  loss_rpn_loc: 0.01702    time: 1.3059  last_time: 1.3106  data_time: 0.0227  last_data_time: 0.0209   lr: 9.5775e-05  max_mem: 11942M
# [03/03 05:11:17 d2.utils.events]:  eta: 1:34:39  iter: 679  total_loss: 0.4382  loss_cls: 0.1905  loss_box_reg: 0.1866  loss_rpn_cls: 0.03329  loss_rpn_loc: 0.01998    time: 1.3061  last_time: 1.3107  data_time: 0.0233  last_data_time: 0.0233   lr: 9.5518e-05  max_mem: 11942M
# [03/03 05:11:43 d2.utils.events]:  eta: 1:34:14  iter: 699  total_loss: 0.3488  loss_cls: 0.1521  loss_box_reg: 0.1558  loss_rpn_cls: 0.01645  loss_rpn_loc: 0.0146    time: 1.3053  last_time: 0.4317  data_time: 0.0243  last_data_time: 0.0201   lr: 9.5255e-05  max_mem: 11942M
# [03/03 05:12:09 d2.utils.events]:  eta: 1:33:49  iter: 719  total_loss: 0.3816  loss_cls: 0.1632  loss_box_reg: 0.1485  loss_rpn_cls: 0.02309  loss_rpn_loc: 0.01537    time: 1.3058  last_time: 1.3175  data_time: 0.0256  last_data_time: 0.0242   lr: 9.4984e-05  max_mem: 11942M
# [03/03 05:12:35 d2.utils.events]:  eta: 1:33:22  iter: 739  total_loss: 0.3851  loss_cls: 0.1739  loss_box_reg: 0.1575  loss_rpn_cls: 0.02455  loss_rpn_loc: 0.01692    time: 1.3061  last_time: 1.3192  data_time: 0.0237  last_data_time: 0.0288   lr: 9.4706e-05  max_mem: 11942M
# [03/03 05:13:02 d2.utils.events]:  eta: 1:32:56  iter: 759  total_loss: 0.3417  loss_cls: 0.1508  loss_box_reg: 0.1561  loss_rpn_cls: 0.02053  loss_rpn_loc: 0.01331    time: 1.3064  last_time: 1.3181  data_time: 0.0242  last_data_time: 0.0284   lr: 9.4421e-05  max_mem: 11942M
# [03/03 05:13:28 d2.utils.events]:  eta: 1:32:30  iter: 779  total_loss: 0.3916  loss_cls: 0.1864  loss_box_reg: 0.1714  loss_rpn_cls: 0.01574  loss_rpn_loc: 0.01516    time: 1.3066  last_time: 1.3176  data_time: 0.0231  last_data_time: 0.0185   lr: 9.4129e-05  max_mem: 11942M
# [03/03 05:13:54 d2.utils.events]:  eta: 1:32:04  iter: 799  total_loss: 0.4266  loss_cls: 0.1814  loss_box_reg: 0.1915  loss_rpn_cls: 0.02079  loss_rpn_loc: 0.01589    time: 1.3057  last_time: 1.3105  data_time: 0.0223  last_data_time: 0.0260   lr: 9.383e-05  max_mem: 11942M
# [03/03 05:14:20 d2.utils.events]:  eta: 1:31:38  iter: 819  total_loss: 0.3792  loss_cls: 0.1713  loss_box_reg: 0.175  loss_rpn_cls: 0.01983  loss_rpn_loc: 0.01889    time: 1.3059  last_time: 1.3283  data_time: 0.0234  last_data_time: 0.0283   lr: 9.3525e-05  max_mem: 11942M
# [03/03 05:14:46 d2.utils.events]:  eta: 1:31:11  iter: 839  total_loss: 0.4454  loss_cls: 0.1995  loss_box_reg: 0.1947  loss_rpn_cls: 0.01852  loss_rpn_loc: 0.01877    time: 1.3062  last_time: 1.3360  data_time: 0.0240  last_data_time: 0.0282   lr: 9.3212e-05  max_mem: 11942M
# [03/03 05:15:13 d2.utils.events]:  eta: 1:30:45  iter: 859  total_loss: 0.3701  loss_cls: 0.1527  loss_box_reg: 0.164  loss_rpn_cls: 0.0212  loss_rpn_loc: 0.01692    time: 1.3064  last_time: 1.3276  data_time: 0.0231  last_data_time: 0.0276   lr: 9.2892e-05  max_mem: 11942M
# [03/03 05:15:39 d2.utils.events]:  eta: 1:30:19  iter: 879  total_loss: 0.3277  loss_cls: 0.1477  loss_box_reg: 0.1425  loss_rpn_cls: 0.01862  loss_rpn_loc: 0.01682    time: 1.3066  last_time: 1.3300  data_time: 0.0238  last_data_time: 0.0260   lr: 9.2566e-05  max_mem: 11942M
# [03/03 05:16:05 d2.utils.events]:  eta: 1:29:53  iter: 899  total_loss: 0.4001  loss_cls: 0.1716  loss_box_reg: 0.1768  loss_rpn_cls: 0.02541  loss_rpn_loc: 0.02148    time: 1.3069  last_time: 1.3102  data_time: 0.0254  last_data_time: 0.0197   lr: 9.2233e-05  max_mem: 11942M
# [03/03 05:16:32 d2.utils.events]:  eta: 1:29:27  iter: 919  total_loss: 0.3787  loss_cls: 0.1535  loss_box_reg: 0.1628  loss_rpn_cls: 0.02431  loss_rpn_loc: 0.01874    time: 1.3072  last_time: 1.3068  data_time: 0.0244  last_data_time: 0.0244   lr: 9.1894e-05  max_mem: 11942M
# [03/03 05:16:58 d2.utils.events]:  eta: 1:29:01  iter: 939  total_loss: 0.3436  loss_cls: 0.1528  loss_box_reg: 0.1493  loss_rpn_cls: 0.01892  loss_rpn_loc: 0.01513    time: 1.3075  last_time: 1.3316  data_time: 0.0254  last_data_time: 0.0333   lr: 9.1547e-05  max_mem: 11942M
# [03/03 05:17:25 d2.utils.events]:  eta: 1:28:35  iter: 959  total_loss: 0.4283  loss_cls: 0.183  loss_box_reg: 0.1807  loss_rpn_cls: 0.02133  loss_rpn_loc: 0.02061    time: 1.3077  last_time: 1.3191  data_time: 0.0234  last_data_time: 0.0250   lr: 9.1194e-05  max_mem: 11942M
# [03/03 05:17:51 d2.utils.events]:  eta: 1:28:09  iter: 979  total_loss: 0.4459  loss_cls: 0.1784  loss_box_reg: 0.2024  loss_rpn_cls: 0.02352  loss_rpn_loc: 0.01986    time: 1.3079  last_time: 1.3272  data_time: 0.0222  last_data_time: 0.0211   lr: 9.0835e-05  max_mem: 11942M
# [03/03 05:18:17 d2.utils.events]:  eta: 1:27:42  iter: 999  total_loss: 0.3853  loss_cls: 0.1518  loss_box_reg: 0.1792  loss_rpn_cls: 0.01823  loss_rpn_loc: 0.01765    time: 1.3081  last_time: 1.3040  data_time: 0.0238  last_data_time: 0.0157   lr: 9.0469e-05  max_mem: 11942M
# [03/03 05:18:44 d2.utils.events]:  eta: 1:27:16  iter: 1019  total_loss: 0.3437  loss_cls: 0.1482  loss_box_reg: 0.1439  loss_rpn_cls: 0.02229  loss_rpn_loc: 0.01794    time: 1.3083  last_time: 1.3308  data_time: 0.0241  last_data_time: 0.0283   lr: 9.0097e-05  max_mem: 11942M
# [03/03 05:19:10 d2.utils.events]:  eta: 1:26:50  iter: 1039  total_loss: 0.3245  loss_cls: 0.1445  loss_box_reg: 0.1479  loss_rpn_cls: 0.01781  loss_rpn_loc: 0.01603    time: 1.3085  last_time: 1.3261  data_time: 0.0241  last_data_time: 0.0229   lr: 8.9719e-05  max_mem: 11942M
# [03/03 05:19:36 d2.utils.events]:  eta: 1:26:24  iter: 1059  total_loss: 0.3644  loss_cls: 0.1677  loss_box_reg: 0.1749  loss_rpn_cls: 0.0195  loss_rpn_loc: 0.01691    time: 1.3078  last_time: 0.4458  data_time: 0.0243  last_data_time: 0.0287   lr: 8.9334e-05  max_mem: 11942M
# [03/03 05:20:01 d2.utils.events]:  eta: 1:25:58  iter: 1079  total_loss: 0.4269  loss_cls: 0.1812  loss_box_reg: 0.206  loss_rpn_cls: 0.01907  loss_rpn_loc: 0.01908    time: 1.3071  last_time: 1.3215  data_time: 0.0221  last_data_time: 0.0255   lr: 8.8943e-05  max_mem: 11942M
# [03/03 05:20:27 d2.utils.events]:  eta: 1:25:31  iter: 1099  total_loss: 0.4058  loss_cls: 0.1672  loss_box_reg: 0.1818  loss_rpn_cls: 0.02105  loss_rpn_loc: 0.01942    time: 1.3071  last_time: 1.3045  data_time: 0.0230  last_data_time: 0.0237   lr: 8.8546e-05  max_mem: 11942M
# [03/03 05:20:53 d2.utils.events]:  eta: 1:25:05  iter: 1119  total_loss: 0.3324  loss_cls: 0.1543  loss_box_reg: 0.1586  loss_rpn_cls: 0.01671  loss_rpn_loc: 0.01425    time: 1.3072  last_time: 1.2962  data_time: 0.0231  last_data_time: 0.0196   lr: 8.8142e-05  max_mem: 11942M
# [03/03 05:21:20 d2.utils.events]:  eta: 1:24:39  iter: 1139  total_loss: 0.3331  loss_cls: 0.1276  loss_box_reg: 0.1409  loss_rpn_cls: 0.02274  loss_rpn_loc: 0.01853    time: 1.3076  last_time: 1.3403  data_time: 0.0266  last_data_time: 0.0299   lr: 8.7733e-05  max_mem: 11942M
# [03/03 05:21:46 d2.utils.events]:  eta: 1:24:12  iter: 1159  total_loss: 0.3732  loss_cls: 0.1549  loss_box_reg: 0.1706  loss_rpn_cls: 0.02204  loss_rpn_loc: 0.02208    time: 1.3077  last_time: 1.3013  data_time: 0.0225  last_data_time: 0.0259   lr: 8.7318e-05  max_mem: 11942M
# [03/03 05:22:12 d2.utils.events]:  eta: 1:23:46  iter: 1179  total_loss: 0.3788  loss_cls: 0.1595  loss_box_reg: 0.1927  loss_rpn_cls: 0.01741  loss_rpn_loc: 0.01265    time: 1.3071  last_time: 1.3265  data_time: 0.0220  last_data_time: 0.0171   lr: 8.6897e-05  max_mem: 11942M
# [03/03 05:22:37 d2.utils.events]:  eta: 1:23:20  iter: 1199  total_loss: 0.4045  loss_cls: 0.1588  loss_box_reg: 0.1857  loss_rpn_cls: 0.02066  loss_rpn_loc: 0.0211    time: 1.3065  last_time: 1.3105  data_time: 0.0227  last_data_time: 0.0201   lr: 8.647e-05  max_mem: 11942M
# [03/03 05:23:03 d2.utils.events]:  eta: 1:22:54  iter: 1219  total_loss: 0.3638  loss_cls: 0.1437  loss_box_reg: 0.1778  loss_rpn_cls: 0.01717  loss_rpn_loc: 0.01565    time: 1.3067  last_time: 1.3256  data_time: 0.0239  last_data_time: 0.0251   lr: 8.6037e-05  max_mem: 11942M
# [03/03 05:23:30 d2.utils.events]:  eta: 1:22:27  iter: 1239  total_loss: 0.411  loss_cls: 0.1667  loss_box_reg: 0.2028  loss_rpn_cls: 0.01914  loss_rpn_loc: 0.02317    time: 1.3068  last_time: 1.3046  data_time: 0.0233  last_data_time: 0.0200   lr: 8.5599e-05  max_mem: 11942M
# [03/03 05:23:56 d2.utils.events]:  eta: 1:22:01  iter: 1259  total_loss: 0.3486  loss_cls: 0.1475  loss_box_reg: 0.166  loss_rpn_cls: 0.01937  loss_rpn_loc: 0.01429    time: 1.3069  last_time: 1.3097  data_time: 0.0227  last_data_time: 0.0168   lr: 8.5155e-05  max_mem: 11942M
# [03/03 05:24:21 d2.utils.events]:  eta: 1:21:35  iter: 1279  total_loss: 0.3734  loss_cls: 0.1587  loss_box_reg: 0.187  loss_rpn_cls: 0.01471  loss_rpn_loc: 0.01629    time: 1.3063  last_time: 1.3161  data_time: 0.0220  last_data_time: 0.0253   lr: 8.4705e-05  max_mem: 11942M
# [03/03 05:24:48 d2.utils.events]:  eta: 1:21:09  iter: 1299  total_loss: 0.4066  loss_cls: 0.1585  loss_box_reg: 0.1995  loss_rpn_cls: 0.01711  loss_rpn_loc: 0.01504    time: 1.3064  last_time: 1.3146  data_time: 0.0238  last_data_time: 0.0250   lr: 8.425e-05  max_mem: 11942M
# [03/03 05:25:14 d2.utils.events]:  eta: 1:20:43  iter: 1319  total_loss: 0.4462  loss_cls: 0.1912  loss_box_reg: 0.2056  loss_rpn_cls: 0.01758  loss_rpn_loc: 0.01612    time: 1.3065  last_time: 1.3031  data_time: 0.0237  last_data_time: 0.0189   lr: 8.379e-05  max_mem: 11942M
# [03/03 05:25:40 d2.utils.events]:  eta: 1:20:17  iter: 1339  total_loss: 0.3718  loss_cls: 0.1543  loss_box_reg: 0.1901  loss_rpn_cls: 0.01583  loss_rpn_loc: 0.01439    time: 1.3066  last_time: 1.3208  data_time: 0.0230  last_data_time: 0.0222   lr: 8.3324e-05  max_mem: 11942M
# [03/03 05:26:06 d2.utils.events]:  eta: 1:19:51  iter: 1359  total_loss: 0.3088  loss_cls: 0.1324  loss_box_reg: 0.1452  loss_rpn_cls: 0.01542  loss_rpn_loc: 0.01652    time: 1.3062  last_time: 1.3167  data_time: 0.0242  last_data_time: 0.0297   lr: 8.2853e-05  max_mem: 11942M
# [03/03 05:26:32 d2.utils.events]:  eta: 1:19:25  iter: 1379  total_loss: 0.3627  loss_cls: 0.1522  loss_box_reg: 0.1692  loss_rpn_cls: 0.01217  loss_rpn_loc: 0.01577    time: 1.3064  last_time: 1.3228  data_time: 0.0239  last_data_time: 0.0300   lr: 8.2377e-05  max_mem: 11942M
# [03/03 05:26:58 d2.utils.events]:  eta: 1:18:58  iter: 1399  total_loss: 0.3716  loss_cls: 0.1487  loss_box_reg: 0.1732  loss_rpn_cls: 0.01266  loss_rpn_loc: 0.01905    time: 1.3065  last_time: 1.3109  data_time: 0.0228  last_data_time: 0.0271   lr: 8.1895e-05  max_mem: 11942M
# [03/03 05:27:25 d2.utils.events]:  eta: 1:18:32  iter: 1419  total_loss: 0.3779  loss_cls: 0.1491  loss_box_reg: 0.1883  loss_rpn_cls: 0.01731  loss_rpn_loc: 0.01737    time: 1.3066  last_time: 1.3030  data_time: 0.0232  last_data_time: 0.0251   lr: 8.1409e-05  max_mem: 11942M
# [03/03 05:27:51 d2.utils.events]:  eta: 1:18:06  iter: 1439  total_loss: 0.3541  loss_cls: 0.134  loss_box_reg: 0.1781  loss_rpn_cls: 0.01645  loss_rpn_loc: 0.01783    time: 1.3067  last_time: 1.3276  data_time: 0.0231  last_data_time: 0.0210   lr: 8.0918e-05  max_mem: 11943M
# [03/03 05:28:17 d2.utils.events]:  eta: 1:17:40  iter: 1459  total_loss: 0.4412  loss_cls: 0.1592  loss_box_reg: 0.2164  loss_rpn_cls: 0.01919  loss_rpn_loc: 0.02017    time: 1.3068  last_time: 1.3009  data_time: 0.0226  last_data_time: 0.0191   lr: 8.0421e-05  max_mem: 11943M
# [03/03 05:28:44 d2.utils.events]:  eta: 1:17:13  iter: 1479  total_loss: 0.4034  loss_cls: 0.1647  loss_box_reg: 0.1961  loss_rpn_cls: 0.01575  loss_rpn_loc: 0.01563    time: 1.3070  last_time: 1.3676  data_time: 0.0239  last_data_time: 0.0494   lr: 7.992e-05  max_mem: 11943M
# [03/03 05:29:10 d2.utils.events]:  eta: 1:16:47  iter: 1499  total_loss: 0.3964  loss_cls: 0.1685  loss_box_reg: 0.1888  loss_rpn_cls: 0.01671  loss_rpn_loc: 0.01649    time: 1.3071  last_time: 1.3230  data_time: 0.0239  last_data_time: 0.0201   lr: 7.9415e-05  max_mem: 11943M
# [03/03 05:29:36 d2.utils.events]:  eta: 1:16:22  iter: 1519  total_loss: 0.2896  loss_cls: 0.128  loss_box_reg: 0.1341  loss_rpn_cls: 0.0135  loss_rpn_loc: 0.01446    time: 1.3068  last_time: 1.3192  data_time: 0.0251  last_data_time: 0.0223   lr: 7.8904e-05  max_mem: 11943M
# [03/03 05:30:02 d2.utils.events]:  eta: 1:15:55  iter: 1539  total_loss: 0.3231  loss_cls: 0.1525  loss_box_reg: 0.1449  loss_rpn_cls: 0.01668  loss_rpn_loc: 0.01614    time: 1.3069  last_time: 1.3297  data_time: 0.0236  last_data_time: 0.0293   lr: 7.8389e-05  max_mem: 11943M
# [03/03 05:30:29 d2.utils.events]:  eta: 1:15:29  iter: 1559  total_loss: 0.3298  loss_cls: 0.1336  loss_box_reg: 0.1599  loss_rpn_cls: 0.02044  loss_rpn_loc: 0.01329    time: 1.3071  last_time: 1.3314  data_time: 0.0248  last_data_time: 0.0276   lr: 7.787e-05  max_mem: 11943M
# [03/03 05:30:55 d2.utils.events]:  eta: 1:15:03  iter: 1579  total_loss: 0.3329  loss_cls: 0.1553  loss_box_reg: 0.1573  loss_rpn_cls: 0.01835  loss_rpn_loc: 0.01543    time: 1.3072  last_time: 1.3162  data_time: 0.0242  last_data_time: 0.0198   lr: 7.7346e-05  max_mem: 11943M
# [03/03 05:31:21 d2.utils.events]:  eta: 1:14:36  iter: 1599  total_loss: 0.3492  loss_cls: 0.1415  loss_box_reg: 0.1732  loss_rpn_cls: 0.01248  loss_rpn_loc: 0.01737    time: 1.3074  last_time: 1.3237  data_time: 0.0239  last_data_time: 0.0301   lr: 7.6818e-05  max_mem: 11943M
# [03/03 05:31:48 d2.utils.events]:  eta: 1:14:10  iter: 1619  total_loss: 0.2702  loss_cls: 0.1171  loss_box_reg: 0.1357  loss_rpn_cls: 0.01396  loss_rpn_loc: 0.01276    time: 1.3075  last_time: 1.3036  data_time: 0.0255  last_data_time: 0.0241   lr: 7.6285e-05  max_mem: 11943M
# [03/03 05:32:13 d2.utils.events]:  eta: 1:13:43  iter: 1639  total_loss: 0.3718  loss_cls: 0.1536  loss_box_reg: 0.165  loss_rpn_cls: 0.01219  loss_rpn_loc: 0.0145    time: 1.3071  last_time: 1.3140  data_time: 0.0226  last_data_time: 0.0118   lr: 7.5749e-05  max_mem: 11943M
# [03/03 05:32:40 d2.utils.events]:  eta: 1:13:18  iter: 1659  total_loss: 0.3522  loss_cls: 0.1414  loss_box_reg: 0.1665  loss_rpn_cls: 0.01817  loss_rpn_loc: 0.01803    time: 1.3072  last_time: 1.3005  data_time: 0.0244  last_data_time: 0.0257   lr: 7.5208e-05  max_mem: 11943M
# [03/03 05:33:06 d2.utils.events]:  eta: 1:12:52  iter: 1679  total_loss: 0.3607  loss_cls: 0.1542  loss_box_reg: 0.1521  loss_rpn_cls: 0.02218  loss_rpn_loc: 0.01769    time: 1.3073  last_time: 1.3266  data_time: 0.0216  last_data_time: 0.0291   lr: 7.4664e-05  max_mem: 11943M
# [03/03 05:33:31 d2.utils.events]:  eta: 1:12:25  iter: 1699  total_loss: 0.3414  loss_cls: 0.1373  loss_box_reg: 0.1683  loss_rpn_cls: 0.01918  loss_rpn_loc: 0.0138    time: 1.3070  last_time: 1.3117  data_time: 0.0228  last_data_time: 0.0242   lr: 7.4115e-05  max_mem: 11943M
# [03/03 05:33:58 d2.utils.events]:  eta: 1:11:58  iter: 1719  total_loss: 0.3504  loss_cls: 0.1505  loss_box_reg: 0.1684  loss_rpn_cls: 0.01487  loss_rpn_loc: 0.01586    time: 1.3071  last_time: 1.3191  data_time: 0.0225  last_data_time: 0.0249   lr: 7.3563e-05  max_mem: 11943M
# [03/03 05:34:24 d2.utils.events]:  eta: 1:11:32  iter: 1739  total_loss: 0.3808  loss_cls: 0.1458  loss_box_reg: 0.1851  loss_rpn_cls: 0.01058  loss_rpn_loc: 0.01758    time: 1.3072  last_time: 1.3149  data_time: 0.0235  last_data_time: 0.0209   lr: 7.3007e-05  max_mem: 11943M
# [03/03 05:34:50 d2.utils.events]:  eta: 1:11:05  iter: 1759  total_loss: 0.3618  loss_cls: 0.1468  loss_box_reg: 0.1837  loss_rpn_cls: 0.01333  loss_rpn_loc: 0.01523    time: 1.3072  last_time: 1.3211  data_time: 0.0235  last_data_time: 0.0216   lr: 7.2447e-05  max_mem: 11943M
# [03/03 05:35:17 d2.utils.events]:  eta: 1:10:38  iter: 1779  total_loss: 0.3349  loss_cls: 0.1341  loss_box_reg: 0.1618  loss_rpn_cls: 0.01352  loss_rpn_loc: 0.01386    time: 1.3073  last_time: 1.3029  data_time: 0.0245  last_data_time: 0.0248   lr: 7.1884e-05  max_mem: 11943M
# [03/03 05:35:43 d2.utils.events]:  eta: 1:10:12  iter: 1799  total_loss: 0.3597  loss_cls: 0.1477  loss_box_reg: 0.185  loss_rpn_cls: 0.01688  loss_rpn_loc: 0.01692    time: 1.3074  last_time: 1.3116  data_time: 0.0227  last_data_time: 0.0257   lr: 7.1317e-05  max_mem: 11943M
# [03/03 05:36:08 d2.utils.events]:  eta: 1:09:47  iter: 1819  total_loss: 0.3486  loss_cls: 0.1406  loss_box_reg: 0.1644  loss_rpn_cls: 0.01479  loss_rpn_loc: 0.01736    time: 1.3071  last_time: 1.3259  data_time: 0.0242  last_data_time: 0.0195   lr: 7.0747e-05  max_mem: 11943M
# [03/03 05:36:35 d2.utils.events]:  eta: 1:09:20  iter: 1839  total_loss: 0.3894  loss_cls: 0.1481  loss_box_reg: 0.1777  loss_rpn_cls: 0.01597  loss_rpn_loc: 0.01853    time: 1.3072  last_time: 1.3084  data_time: 0.0240  last_data_time: 0.0240   lr: 7.0174e-05  max_mem: 11943M
# [03/03 05:37:00 d2.utils.events]:  eta: 1:08:54  iter: 1859  total_loss: 0.3002  loss_cls: 0.1277  loss_box_reg: 0.1434  loss_rpn_cls: 0.02174  loss_rpn_loc: 0.01443    time: 1.3068  last_time: 1.3292  data_time: 0.0239  last_data_time: 0.0304   lr: 6.9598e-05  max_mem: 11943M
# [03/03 05:37:27 d2.utils.events]:  eta: 1:08:28  iter: 1879  total_loss: 0.303  loss_cls: 0.1263  loss_box_reg: 0.1396  loss_rpn_cls: 0.01323  loss_rpn_loc: 0.01286    time: 1.3069  last_time: 1.3144  data_time: 0.0244  last_data_time: 0.0207   lr: 6.9018e-05  max_mem: 11943M
# [03/03 05:37:53 d2.utils.events]:  eta: 1:08:02  iter: 1899  total_loss: 0.362  loss_cls: 0.1503  loss_box_reg: 0.177  loss_rpn_cls: 0.0142  loss_rpn_loc: 0.01644    time: 1.3071  last_time: 1.3098  data_time: 0.0244  last_data_time: 0.0211   lr: 6.8435e-05  max_mem: 11943M
# [03/03 05:38:18 d2.utils.events]:  eta: 1:07:35  iter: 1919  total_loss: 0.3713  loss_cls: 0.136  loss_box_reg: 0.1893  loss_rpn_cls: 0.01356  loss_rpn_loc: 0.01633    time: 1.3067  last_time: 1.3236  data_time: 0.0226  last_data_time: 0.0277   lr: 6.785e-05  max_mem: 11943M
# [03/03 05:38:45 d2.utils.events]:  eta: 1:07:09  iter: 1939  total_loss: 0.3314  loss_cls: 0.1271  loss_box_reg: 0.1626  loss_rpn_cls: 0.01705  loss_rpn_loc: 0.0213    time: 1.3068  last_time: 1.3297  data_time: 0.0253  last_data_time: 0.0514   lr: 6.7262e-05  max_mem: 11943M
# [03/03 05:39:11 d2.utils.events]:  eta: 1:06:42  iter: 1959  total_loss: 0.314  loss_cls: 0.1346  loss_box_reg: 0.1543  loss_rpn_cls: 0.01559  loss_rpn_loc: 0.01207    time: 1.3070  last_time: 1.3135  data_time: 0.0239  last_data_time: 0.0185   lr: 6.6671e-05  max_mem: 11943M
# [03/03 05:39:38 d2.utils.events]:  eta: 1:06:17  iter: 1979  total_loss: 0.3579  loss_cls: 0.1406  loss_box_reg: 0.1817  loss_rpn_cls: 0.01674  loss_rpn_loc: 0.01925    time: 1.3071  last_time: 1.3096  data_time: 0.0233  last_data_time: 0.0246   lr: 6.6077e-05  max_mem: 11943M
# [03/03 05:40:04 d2.utils.events]:  eta: 1:05:50  iter: 1999  total_loss: 0.2724  loss_cls: 0.1066  loss_box_reg: 0.1341  loss_rpn_cls: 0.009563  loss_rpn_loc: 0.01368    time: 1.3072  last_time: 1.3187  data_time: 0.0232  last_data_time: 0.0237   lr: 6.5481e-05  max_mem: 11943M
# [03/03 05:40:31 d2.utils.events]:  eta: 1:05:24  iter: 2019  total_loss: 0.3471  loss_cls: 0.1463  loss_box_reg: 0.1808  loss_rpn_cls: 0.01079  loss_rpn_loc: 0.01754    time: 1.3073  last_time: 1.3189  data_time: 0.0232  last_data_time: 0.0239   lr: 6.4882e-05  max_mem: 11943M
# [03/03 05:40:57 d2.utils.events]:  eta: 1:04:58  iter: 2039  total_loss: 0.3006  loss_cls: 0.1152  loss_box_reg: 0.1405  loss_rpn_cls: 0.01139  loss_rpn_loc: 0.01447    time: 1.3074  last_time: 1.3008  data_time: 0.0235  last_data_time: 0.0163   lr: 6.4281e-05  max_mem: 11943M
# [03/03 05:41:23 d2.utils.events]:  eta: 1:04:32  iter: 2059  total_loss: 0.323  loss_cls: 0.1233  loss_box_reg: 0.1716  loss_rpn_cls: 0.01108  loss_rpn_loc: 0.01205    time: 1.3076  last_time: 1.3279  data_time: 0.0247  last_data_time: 0.0281   lr: 6.3678e-05  max_mem: 11943M
# ...
# [03/03 06:21:27 d2.utils.events]:  eta: 0:24:06  iter: 3899  total_loss: 0.2682  loss_cls: 0.09234  loss_box_reg: 0.1437  loss_rpn_cls: 0.006643  loss_rpn_loc: 0.01149    time: 1.3068  last_time: 1.3080  data_time: 0.0239  last_data_time: 0.0225   lr: 1.1494e-05  max_mem: 11944M
# [03/03 06:21:54 d2.utils.events]:  eta: 0:23:40  iter: 3919  total_loss: 0.2831  loss_cls: 0.1121  loss_box_reg: 0.1565  loss_rpn_cls: 0.01169  loss_rpn_loc: 0.01292    time: 1.3069  last_time: 1.3110  data_time: 0.0238  last_data_time: 0.0252   lr: 1.1097e-05  max_mem: 11944M
# [03/03 06:22:19 d2.utils.events]:  eta: 0:23:13  iter: 3939  total_loss: 0.3488  loss_cls: 0.1389  loss_box_reg: 0.1993  loss_rpn_cls: 0.008473  loss_rpn_loc: 0.01434    time: 1.3067  last_time: 1.3082  data_time: 0.0225  last_data_time: 0.0244   lr: 1.0705e-05  max_mem: 11944M
# [03/03 06:22:45 d2.utils.events]:  eta: 0:22:47  iter: 3959  total_loss: 0.2664  loss_cls: 0.097  loss_box_reg: 0.134  loss_rpn_cls: 0.01023  loss_rpn_loc: 0.01374    time: 1.3067  last_time: 1.3200  data_time: 0.0236  last_data_time: 0.0274   lr: 1.032e-05  max_mem: 11944M
# [03/03 06:23:12 d2.utils.events]:  eta: 0:22:21  iter: 3979  total_loss: 0.2615  loss_cls: 0.09324  loss_box_reg: 0.1358  loss_rpn_cls: 0.009313  loss_rpn_loc: 0.01375    time: 1.3068  last_time: 1.3132  data_time: 0.0241  last_data_time: 0.0216   lr: 9.9404e-06  max_mem: 11944M
# [03/03 06:23:38 d2.utils.events]:  eta: 0:21:54  iter: 3999  total_loss: 0.2825  loss_cls: 0.1117  loss_box_reg: 0.1536  loss_rpn_cls: 0.009463  loss_rpn_loc: 0.01382    time: 1.3068  last_time: 1.3251  data_time: 0.0231  last_data_time: 0.0278   lr: 9.5676e-06  max_mem: 11944M
# [03/03 06:24:03 d2.utils.events]:  eta: 0:21:28  iter: 4019  total_loss: 0.2863  loss_cls: 0.1012  loss_box_reg: 0.15  loss_rpn_cls: 0.007608  loss_rpn_loc: 0.01261    time: 1.3066  last_time: 1.3151  data_time: 0.0229  last_data_time: 0.0201   lr: 9.2012e-06  max_mem: 11944M
# [03/03 06:24:30 d2.utils.events]:  eta: 0:21:02  iter: 4039  total_loss: 0.3459  loss_cls: 0.1179  loss_box_reg: 0.1814  loss_rpn_cls: 0.007957  loss_rpn_loc: 0.01482    time: 1.3066  last_time: 1.3066  data_time: 0.0237  last_data_time: 0.0242   lr: 8.8412e-06  max_mem: 11944M
# [03/03 06:24:56 d2.utils.events]:  eta: 0:20:35  iter: 4059  total_loss: 0.2626  loss_cls: 0.09324  loss_box_reg: 0.1437  loss_rpn_cls: 0.00871  loss_rpn_loc: 0.008242    time: 1.3067  last_time: 1.3060  data_time: 0.0243  last_data_time: 0.0211   lr: 8.4877e-06  max_mem: 11944M
# [03/03 06:25:22 d2.utils.events]:  eta: 0:20:09  iter: 4079  total_loss: 0.2748  loss_cls: 0.1026  loss_box_reg: 0.1405  loss_rpn_cls: 0.009296  loss_rpn_loc: 0.01412    time: 1.3067  last_time: 1.3297  data_time: 0.0240  last_data_time: 0.0264   lr: 8.1408e-06  max_mem: 11944M
# [03/03 06:25:48 d2.utils.events]:  eta: 0:19:43  iter: 4099  total_loss: 0.4037  loss_cls: 0.1512  loss_box_reg: 0.2169  loss_rpn_cls: 0.01143  loss_rpn_loc: 0.01408    time: 1.3065  last_time: 1.2979  data_time: 0.0217  last_data_time: 0.0160   lr: 7.8004e-06  max_mem: 11944M
# [03/03 06:26:14 d2.utils.events]:  eta: 0:19:16  iter: 4119  total_loss: 0.2498  loss_cls: 0.09589  loss_box_reg: 0.1323  loss_rpn_cls: 0.008764  loss_rpn_loc: 0.01368    time: 1.3066  last_time: 1.3067  data_time: 0.0227  last_data_time: 0.0234   lr: 7.4668e-06  max_mem: 11944M
# [03/03 06:26:40 d2.utils.events]:  eta: 0:18:50  iter: 4139  total_loss: 0.3047  loss_cls: 0.1079  loss_box_reg: 0.1786  loss_rpn_cls: 0.009044  loss_rpn_loc: 0.01451    time: 1.3066  last_time: 1.3156  data_time: 0.0226  last_data_time: 0.0205   lr: 7.1398e-06  max_mem: 11944M
# [03/03 06:27:07 d2.utils.events]:  eta: 0:18:24  iter: 4159  total_loss: 0.258  loss_cls: 0.1014  loss_box_reg: 0.136  loss_rpn_cls: 0.01023  loss_rpn_loc: 0.01328    time: 1.3066  last_time: 1.3288  data_time: 0.0236  last_data_time: 0.0255   lr: 6.8197e-06  max_mem: 11944M
# [03/03 06:27:33 d2.utils.events]:  eta: 0:17:57  iter: 4179  total_loss: 0.2563  loss_cls: 0.09813  loss_box_reg: 0.1359  loss_rpn_cls: 0.006578  loss_rpn_loc: 0.01071    time: 1.3067  last_time: 1.3274  data_time: 0.0233  last_data_time: 0.0230   lr: 6.5063e-06  max_mem: 11944M
# [03/03 06:27:58 d2.utils.events]:  eta: 0:17:31  iter: 4199  total_loss: 0.2727  loss_cls: 0.1126  loss_box_reg: 0.1292  loss_rpn_cls: 0.01145  loss_rpn_loc: 0.0154    time: 1.3065  last_time: 1.3155  data_time: 0.0233  last_data_time: 0.0239   lr: 6.1998e-06  max_mem: 11944M
# [03/03 06:28:25 d2.utils.events]:  eta: 0:17:05  iter: 4219  total_loss: 0.2642  loss_cls: 0.1054  loss_box_reg: 0.1292  loss_rpn_cls: 0.01097  loss_rpn_loc: 0.01378    time: 1.3066  last_time: 1.3037  data_time: 0.0253  last_data_time: 0.0248   lr: 5.9002e-06  max_mem: 11944M
# [03/03 06:28:50 d2.utils.events]:  eta: 0:16:39  iter: 4239  total_loss: 0.2783  loss_cls: 0.1077  loss_box_reg: 0.1461  loss_rpn_cls: 0.009807  loss_rpn_loc: 0.01199    time: 1.3064  last_time: 1.3148  data_time: 0.0219  last_data_time: 0.0250   lr: 5.6076e-06  max_mem: 11944M
# [03/03 06:29:16 d2.utils.events]:  eta: 0:16:12  iter: 4259  total_loss: 0.2889  loss_cls: 0.1093  loss_box_reg: 0.1507  loss_rpn_cls: 0.009472  loss_rpn_loc: 0.01619    time: 1.3064  last_time: 1.3012  data_time: 0.0248  last_data_time: 0.0244   lr: 5.322e-06  max_mem: 11944M
# [03/03 06:29:43 d2.utils.events]:  eta: 0:15:46  iter: 4279  total_loss: 0.2673  loss_cls: 0.1089  loss_box_reg: 0.1257  loss_rpn_cls: 0.01051  loss_rpn_loc: 0.01182    time: 1.3065  last_time: 1.3220  data_time: 0.0235  last_data_time: 0.0232   lr: 5.0435e-06  max_mem: 11944M
# [03/03 06:30:09 d2.utils.events]:  eta: 0:15:20  iter: 4299  total_loss: 0.2637  loss_cls: 0.0942  loss_box_reg: 0.1437  loss_rpn_cls: 0.00887  loss_rpn_loc: 0.01437    time: 1.3065  last_time: 1.3142  data_time: 0.0247  last_data_time: 0.0242   lr: 4.772e-06  max_mem: 11944M
# [03/03 06:30:35 d2.utils.events]:  eta: 0:14:53  iter: 4319  total_loss: 0.2978  loss_cls: 0.1033  loss_box_reg: 0.1394  loss_rpn_cls: 0.01236  loss_rpn_loc: 0.01336    time: 1.3066  last_time: 1.3145  data_time: 0.0243  last_data_time: 0.0224   lr: 4.5077e-06  max_mem: 11944M
# [03/03 06:31:01 d2.utils.events]:  eta: 0:14:27  iter: 4339  total_loss: 0.2923  loss_cls: 0.1122  loss_box_reg: 0.1441  loss_rpn_cls: 0.01148  loss_rpn_loc: 0.01155    time: 1.3064  last_time: 1.3307  data_time: 0.0226  last_data_time: 0.0271   lr: 4.2506e-06  max_mem: 11944M
# [03/03 06:31:27 d2.utils.events]:  eta: 0:14:01  iter: 4359  total_loss: 0.2451  loss_cls: 0.1076  loss_box_reg: 0.1337  loss_rpn_cls: 0.009918  loss_rpn_loc: 0.01292    time: 1.3065  last_time: 1.3267  data_time: 0.0241  last_data_time: 0.0257   lr: 4.0007e-06  max_mem: 11944M
# [03/03 06:31:54 d2.utils.events]:  eta: 0:13:34  iter: 4379  total_loss: 0.2638  loss_cls: 0.09054  loss_box_reg: 0.1352  loss_rpn_cls: 0.008536  loss_rpn_loc: 0.01234    time: 1.3065  last_time: 1.3257  data_time: 0.0238  last_data_time: 0.0263   lr: 3.7581e-06  max_mem: 11944M
# [03/03 06:32:20 d2.utils.events]:  eta: 0:13:08  iter: 4399  total_loss: 0.2786  loss_cls: 0.09942  loss_box_reg: 0.1482  loss_rpn_cls: 0.007868  loss_rpn_loc: 0.01302    time: 1.3065  last_time: 1.3310  data_time: 0.0233  last_data_time: 0.0282   lr: 3.5227e-06  max_mem: 11944M
# [03/03 06:32:45 d2.utils.events]:  eta: 0:12:42  iter: 4419  total_loss: 0.3227  loss_cls: 0.1158  loss_box_reg: 0.1757  loss_rpn_cls: 0.01177  loss_rpn_loc: 0.01287    time: 1.3063  last_time: 1.3148  data_time: 0.0217  last_data_time: 0.0215   lr: 3.2948e-06  max_mem: 11944M
# [03/03 06:33:11 d2.utils.events]:  eta: 0:12:16  iter: 4439  total_loss: 0.2799  loss_cls: 0.1035  loss_box_reg: 0.1268  loss_rpn_cls: 0.01077  loss_rpn_loc: 0.01221    time: 1.3064  last_time: 1.3054  data_time: 0.0246  last_data_time: 0.0167   lr: 3.0741e-06  max_mem: 11944M
# [03/03 06:33:37 d2.utils.events]:  eta: 0:11:49  iter: 4459  total_loss: 0.2737  loss_cls: 0.1104  loss_box_reg: 0.1554  loss_rpn_cls: 0.007024  loss_rpn_loc: 0.01256    time: 1.3062  last_time: 1.3294  data_time: 0.0235  last_data_time: 0.0210   lr: 2.8609e-06  max_mem: 11944M
# [03/03 06:34:03 d2.utils.events]:  eta: 0:11:23  iter: 4479  total_loss: 0.2466  loss_cls: 0.09681  loss_box_reg: 0.1367  loss_rpn_cls: 0.008737  loss_rpn_loc: 0.01269    time: 1.3063  last_time: 1.3148  data_time: 0.0239  last_data_time: 0.0228   lr: 2.6552e-06  max_mem: 11944M
# [03/03 06:34:29 d2.utils.events]:  eta: 0:10:57  iter: 4499  total_loss: 0.2875  loss_cls: 0.1018  loss_box_reg: 0.1599  loss_rpn_cls: 0.009091  loss_rpn_loc: 0.01399    time: 1.3063  last_time: 1.3076  data_time: 0.0232  last_data_time: 0.0293   lr: 2.4569e-06  max_mem: 11944M
# [03/03 06:34:56 d2.utils.events]:  eta: 0:10:30  iter: 4519  total_loss: 0.3026  loss_cls: 0.1073  loss_box_reg: 0.1694  loss_rpn_cls: 0.01004  loss_rpn_loc: 0.01518    time: 1.3063  last_time: 1.3269  data_time: 0.0225  last_data_time: 0.0253   lr: 2.2661e-06  max_mem: 11944M
# [03/03 06:35:21 d2.utils.events]:  eta: 0:10:04  iter: 4539  total_loss: 0.2232  loss_cls: 0.08169  loss_box_reg: 0.1207  loss_rpn_cls: 0.007617  loss_rpn_loc: 0.009123    time: 1.3062  last_time: 1.3214  data_time: 0.0243  last_data_time: 0.0244   lr: 2.0829e-06  max_mem: 11944M
# [03/03 06:35:47 d2.utils.events]:  eta: 0:09:38  iter: 4559  total_loss: 0.3254  loss_cls: 0.1308  loss_box_reg: 0.1636  loss_rpn_cls: 0.01101  loss_rpn_loc: 0.01361    time: 1.3062  last_time: 1.3067  data_time: 0.0232  last_data_time: 0.0218   lr: 1.9072e-06  max_mem: 11944M
# [03/03 06:36:14 d2.utils.events]:  eta: 0:09:12  iter: 4579  total_loss: 0.2498  loss_cls: 0.09422  loss_box_reg: 0.1201  loss_rpn_cls: 0.01022  loss_rpn_loc: 0.009667    time: 1.3062  last_time: 1.3181  data_time: 0.0246  last_data_time: 0.0270   lr: 1.7391e-06  max_mem: 11944M
# [03/03 06:36:40 d2.utils.events]:  eta: 0:08:45  iter: 4599  total_loss: 0.2492  loss_cls: 0.09733  loss_box_reg: 0.122  loss_rpn_cls: 0.01034  loss_rpn_loc: 0.00987    time: 1.3063  last_time: 1.3237  data_time: 0.0234  last_data_time: 0.0218   lr: 1.5787e-06  max_mem: 11944M
# [03/03 06:37:06 d2.utils.events]:  eta: 0:08:19  iter: 4619  total_loss: 0.2036  loss_cls: 0.08571  loss_box_reg: 0.08928  loss_rpn_cls: 0.007425  loss_rpn_loc: 0.008761    time: 1.3061  last_time: 1.3173  data_time: 0.0264  last_data_time: 0.0288   lr: 1.4259e-06  max_mem: 11944M
# [03/03 06:37:32 d2.utils.events]:  eta: 0:07:53  iter: 4639  total_loss: 0.2778  loss_cls: 0.1081  loss_box_reg: 0.1417  loss_rpn_cls: 0.007367  loss_rpn_loc: 0.00911    time: 1.3062  last_time: 1.3190  data_time: 0.0227  last_data_time: 0.0199   lr: 1.2807e-06  max_mem: 11944M
# [03/03 06:37:58 d2.utils.events]:  eta: 0:07:27  iter: 4659  total_loss: 0.273  loss_cls: 0.1023  loss_box_reg: 0.1312  loss_rpn_cls: 0.01085  loss_rpn_loc: 0.01273    time: 1.3062  last_time: 1.3283  data_time: 0.0240  last_data_time: 0.0199   lr: 1.1433e-06  max_mem: 11944M
# [03/03 06:38:24 d2.utils.events]:  eta: 0:07:00  iter: 4679  total_loss: 0.3049  loss_cls: 0.1024  loss_box_reg: 0.1534  loss_rpn_cls: 0.007657  loss_rpn_loc: 0.01286    time: 1.3062  last_time: 1.3158  data_time: 0.0233  last_data_time: 0.0192   lr: 1.0135e-06  max_mem: 11944M
# [03/03 06:38:50 d2.utils.events]:  eta: 0:06:34  iter: 4699  total_loss: 0.2547  loss_cls: 0.09576  loss_box_reg: 0.1378  loss_rpn_cls: 0.008182  loss_rpn_loc: 0.01064    time: 1.3061  last_time: 1.3208  data_time: 0.0251  last_data_time: 0.0265   lr: 8.9153e-07  max_mem: 11944M
# [03/03 06:39:16 d2.utils.events]:  eta: 0:06:08  iter: 4719  total_loss: 0.2642  loss_cls: 0.1002  loss_box_reg: 0.1445  loss_rpn_cls: 0.01181  loss_rpn_loc: 0.01195    time: 1.3062  last_time: 1.3075  data_time: 0.0241  last_data_time: 0.0176   lr: 7.7729e-07  max_mem: 11944M
# [03/03 06:39:43 d2.utils.events]:  eta: 0:05:41  iter: 4739  total_loss: 0.2466  loss_cls: 0.0901  loss_box_reg: 0.1255  loss_rpn_cls: 0.01053  loss_rpn_loc: 0.01098    time: 1.3062  last_time: 1.3280  data_time: 0.0243  last_data_time: 0.0262   lr: 6.7082e-07  max_mem: 11944M
# [03/03 06:40:09 d2.utils.events]:  eta: 0:05:15  iter: 4759  total_loss: 0.2677  loss_cls: 0.1058  loss_box_reg: 0.1311  loss_rpn_cls: 0.01118  loss_rpn_loc: 0.01248    time: 1.3063  last_time: 1.3190  data_time: 0.0271  last_data_time: 0.0265   lr: 5.7214e-07  max_mem: 11944M
# [03/03 06:40:34 d2.utils.events]:  eta: 0:04:49  iter: 4779  total_loss: 0.2851  loss_cls: 0.1075  loss_box_reg: 0.1752  loss_rpn_cls: 0.009158  loss_rpn_loc: 0.01324    time: 1.3061  last_time: 1.3133  data_time: 0.0223  last_data_time: 0.0216   lr: 4.8127e-07  max_mem: 11944M
# [03/03 06:40:59 d2.utils.events]:  eta: 0:04:23  iter: 4799  total_loss: 0.3185  loss_cls: 0.1262  loss_box_reg: 0.1698  loss_rpn_cls: 0.01208  loss_rpn_loc: 0.01389    time: 1.3058  last_time: 1.3182  data_time: 0.0227  last_data_time: 0.0313   lr: 3.9821e-07  max_mem: 11944M
# [03/03 06:41:25 d2.utils.events]:  eta: 0:03:56  iter: 4819  total_loss: 0.2777  loss_cls: 0.1051  loss_box_reg: 0.1445  loss_rpn_cls: 0.01042  loss_rpn_loc: 0.01195    time: 1.3058  last_time: 1.3004  data_time: 0.0233  last_data_time: 0.0277   lr: 3.2299e-07  max_mem: 11944M
# [03/03 06:41:49 d2.utils.events]:  eta: 0:03:30  iter: 4839  total_loss: 0.3464  loss_cls: 0.1194  loss_box_reg: 0.1821  loss_rpn_cls: 0.008773  loss_rpn_loc: 0.01365    time: 1.3053  last_time: 0.4422  data_time: 0.0219  last_data_time: 0.0216   lr: 2.5561e-07  max_mem: 11944M
# [03/03 06:42:15 d2.utils.events]:  eta: 0:03:04  iter: 4859  total_loss: 0.2682  loss_cls: 0.1087  loss_box_reg: 0.1501  loss_rpn_cls: 0.01306  loss_rpn_loc: 0.01663    time: 1.3053  last_time: 1.3208  data_time: 0.0238  last_data_time: 0.0253   lr: 1.9609e-07  max_mem: 11944M
# [03/03 06:42:42 d2.utils.events]:  eta: 0:02:37  iter: 4879  total_loss: 0.2347  loss_cls: 0.1003  loss_box_reg: 0.1241  loss_rpn_cls: 0.005084  loss_rpn_loc: 0.01113    time: 1.3054  last_time: 1.2981  data_time: 0.0244  last_data_time: 0.0209   lr: 1.4443e-07  max_mem: 11944M
# [03/03 06:43:06 d2.utils.events]:  eta: 0:02:11  iter: 4899  total_loss: 0.2633  loss_cls: 0.1018  loss_box_reg: 0.1299  loss_rpn_cls: 0.01043  loss_rpn_loc: 0.01167    time: 1.3051  last_time: 0.4362  data_time: 0.0234  last_data_time: 0.0241   lr: 1.0065e-07  max_mem: 11944M
# [03/03 06:43:32 d2.utils.events]:  eta: 0:01:45  iter: 4919  total_loss: 0.2744  loss_cls: 0.1118  loss_box_reg: 0.1363  loss_rpn_cls: 0.009783  loss_rpn_loc: 0.01204    time: 1.3051  last_time: 1.3111  data_time: 0.0232  last_data_time: 0.0248   lr: 6.4741e-08  max_mem: 11944M
# [03/03 06:43:58 d2.utils.events]:  eta: 0:01:18  iter: 4939  total_loss: 0.2605  loss_cls: 0.1012  loss_box_reg: 0.1402  loss_rpn_cls: 0.008303  loss_rpn_loc: 0.01388    time: 1.3049  last_time: 1.3019  data_time: 0.0240  last_data_time: 0.0196   lr: 3.672e-08  max_mem: 11944M
# [03/03 06:44:24 d2.utils.events]:  eta: 0:00:52  iter: 4959  total_loss: 0.2982  loss_cls: 0.1119  loss_box_reg: 0.1634  loss_rpn_cls: 0.01341  loss_rpn_loc: 0.01599    time: 1.3050  last_time: 1.3136  data_time: 0.0234  last_data_time: 0.0212   lr: 1.659e-08  max_mem: 11944M
# [03/03 06:44:50 d2.utils.events]:  eta: 0:00:26  iter: 4979  total_loss: 0.2864  loss_cls: 0.1038  loss_box_reg: 0.1469  loss_rpn_cls: 0.01123  loss_rpn_loc: 0.01078    time: 1.3050  last_time: 1.3084  data_time: 0.0240  last_data_time: 0.0168   lr: 4.3525e-09  max_mem: 11944M
# [03/03 06:45:18 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 0.2062  loss_cls: 0.08243  loss_box_reg: 0.1038  loss_rpn_cls: 0.009632  loss_rpn_loc: 0.008289    time: 1.3051  last_time: 1.3145  data_time: 0.0246  last_data_time: 0.0211   lr: 9.9696e-12  max_mem: 11944M
# [03/03 06:45:18 d2.engine.hooks]: Overall training speed: 4998 iterations in 1:48:42 (1.3051 s / it)
# [03/03 06:45:18 d2.engine.hooks]: Total training time: 1:48:58 (0:00:15 on hooks)

# %% [markdown]
# ## 7. Visualize Train Hooks
# ___

# %%
metrics = pd.read_json(os.path.join(CFG.output_dir, 'metrics.json'), orient='records', lines=True)
metrics = metrics.sort_values(by=['iteration'])

print('Shape of Metrics: ',metrics.shape)
metrics.head()
# Out:
# Shape of Metrics:  (250, 18)
#    data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0   0.021942  6555.032207                0.975342                       1.0
# 1   0.021317  6541.247921                0.977783                       1.0
# 2   0.022254  6500.945656                0.976074                       1.0
# 3   0.020082  6469.123653                0.962891                       1.0
# 4   0.022438  6448.306420                0.968018                       1.0
#
#    fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_rpn_cls  \
# 0                        0.0         19      0.087496  0.260506      0.198119
# 1                        0.0         39      0.088547  0.146988      0.065220
# 2                        0.0         59      0.090591  0.126114      0.058053
# 3                        0.0         79      0.142595  0.191475      0.058568
# 4                        0.0         99      0.114666  0.163444      0.050252
#
#    loss_rpn_loc      lr  rank_data_time  roi_head/num_bg_samples  \
# 0      0.023365  0.0001        0.021942                  500.250
# 1      0.017357  0.0001        0.021317                  500.625
# 2      0.020431  0.0001        0.022254                  499.750
# 3      0.022727  0.0001        0.020082                  493.000
# 4      0.016886  0.0001        0.022438                  495.625
#
#    roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                   11.750              247.875                8.125
# 1                   11.375              248.750                7.250
# 2                   12.250              247.250                8.750
# 3                   19.000              245.750               10.250
# 4                   16.375              248.000                8.000
#
#        time  total_loss
# 0  1.316272    0.672223
# 1  1.319820    0.337268
# 2  1.315506    0.349691
# 3  1.311700    0.419044
# 4  1.318681    0.364477

# %% [markdown]
# #### Scheduler Graph

# %%
print('Scheduler Type is :', CFG.lr_scheduler_name)
print('Base Learning Rate is :', CFG.base_lr)
print('Last Learning Rate is :', CFG.base_lr_end/CFG.base_lr)
print('Iteration is: ', CFG.max_iter)

plt.style.use('default')
plt.figure(figsize=(12,6))
plt.title(CFG.lr_scheduler_name, size=10)

tmp = metrics[~metrics['lr'].isna()]

plt.plot(tmp['iteration'], tmp['lr'])
plt.xlabel('iterations')
plt.ylabel('Learning Rate')

plt.show()
# Out:
# Scheduler Type is : CosineParamScheduler
# Base Learning Rate is : 0.0001
# Last Learning Rate is : 1e-09
# Iteration is:  5000

# %% [markdown]
# #### Foreground & Background Fraction in RPN & ROI

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('RPN Fraction Ratio')
tmp = metrics[~metrics['rpn/num_neg_anchors'].isna()]
tmp = tmp[~tmp['rpn/num_pos_anchors'].isna()]
plt.plot(tmp['iteration'], tmp['rpn/num_neg_anchors'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_neg_anchors'].mean(), tmp['rpn/num_neg_anchors'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['rpn/num_pos_anchors'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_pos_anchors'].mean(),tmp['rpn/num_pos_anchors'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title('ROI Head Fraction Ratio')
tmp = metrics[~metrics['roi_head/num_bg_samples'].isna()]
tmp = tmp[~tmp['roi_head/num_fg_samples'].isna()]
plt.plot(tmp['iteration'], tmp['roi_head/num_bg_samples'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_bg_samples'].mean(), tmp['roi_head/num_bg_samples'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['roi_head/num_fg_samples'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_fg_samples'].mean(),tmp['roi_head/num_fg_samples'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Loss: rpn_loc, rpn_cls, box_reg, box_cls

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(2,2,1)
tmp1 = metrics[~metrics['loss_box_reg'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_box_reg'], color='red', label='box_reg')
plt.grid(True); plt.legend()

plt.subplot(2,2,2)
tmp2 = metrics[~metrics['loss_cls'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_cls'], color='orange', label='box_cls')
plt.grid(True); plt.legend()

plt.subplot(2,2,3)
tmp3 = metrics[~metrics['loss_rpn_cls'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_cls'], color='green', label='rpn_cls')
plt.grid(True); plt.legend()

plt.subplot(2,2,4)
tmp4 = metrics[~metrics['loss_rpn_loc'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_loc'], color='skyblue', label='rpn_loc')
plt.grid(True); plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Evaluation
# ___

# %%
cfg = setup()

evaluator = COCOEvaluator("colonoscopy_valid", ("bbox",), False, output_dir=os.path.join(CFG.output_dir, 'inference'))

val_loader = build_detection_test_loader(
      dataset = get_detection_dataset_dicts(names='colonoscopy_valid'),
      mapper=AlbumentationsMapper(is_train=False),
      batch_size = CFG.ims_per_batch,
      num_workers = CFG.num_workers,
      )

## Build and Load Model
model = instantiate(cfg.model)
DetectionCheckpointer(model, save_dir=CFG.output_dir).resume_or_load(
            f'{CFG.output_dir}/model_final.pth', resume=False
        )
model.eval()

## Evaluate Metrics
result = inference_on_dataset(model, val_loader, evaluator)

clean_memory(); del model, evaluator, val_loader
# Out:
# [03/03 06:45:20 d2.evaluation.coco_evaluation]: Trying to convert 'colonoscopy_valid' to COCO format ...
# [03/03 06:45:20 d2.data.datasets.coco]: Converting annotations of dataset 'colonoscopy_valid' to COCO format ...)
# [03/03 06:45:20 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [03/03 06:45:20 d2.data.datasets.coco]: Conversion finished, #images: 320, #annotations: 391
# [03/03 06:45:20 d2.data.datasets.coco]: Caching COCO format annotations at 'runs/detect/inference/colonoscopy_valid_coco_format.json' ...
# [03/03 06:45:20 d2.data.build]: Removed 0 images with no usable annotations. 320 images left.
# [03/03 06:45:20 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 133          |   Polyp    | 85           |   Cancer   | 173          |
# |            |              |            |              |            |              |
# |   total    | 391          |            |              |            |              |
# [AlbumentationsMapper] Augmentations used in inference: Compose([
#   Resize(p=1.0, height=1024, width=1024, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [03/03 06:45:20 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/03 06:45:20 d2.data.common]: Serializing 320 elements to byte tensors and concatenating them all ...
# [03/03 06:45:20 d2.data.common]: Serialized dataset takes 0.09 MiB
# [03/03 06:45:21 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from runs/detect/model_final.pth ...
# [03/03 06:45:21 d2.evaluation.evaluator]: Start inference on 80 batches
# [03/03 06:45:44 d2.evaluation.evaluator]: Inference done 1/80. Dataloading: 0.5143 s/iter. Inference: 22.7052 s/iter. Eval: 0.0014 s/iter. Total: 23.2219 s/iter. ETA=0:30:34
# [03/03 06:46:07 d2.evaluation.evaluator]: Inference done 2/80. Dataloading: 0.2644 s/iter. Inference: 22.8372 s/iter. Eval: 0.0012 s/iter. Total: 23.1048 s/iter. ETA=0:30:02
# [03/03 06:46:29 d2.evaluation.evaluator]: Inference done 3/80. Dataloading: 0.1809 s/iter. Inference: 22.6245 s/iter. Eval: 0.0012 s/iter. Total: 22.8081 s/iter. ETA=0:29:16
# [03/03 06:46:52 d2.evaluation.evaluator]: Inference done 4/80. Dataloading: 0.1391 s/iter. Inference: 22.6736 s/iter. Eval: 0.0011 s/iter. Total: 22.8152 s/iter. ETA=0:28:53
# [03/03 06:47:16 d2.evaluation.evaluator]: Inference done 5/80. Dataloading: 0.1165 s/iter. Inference: 22.8235 s/iter. Eval: 0.0011 s/iter. Total: 22.9424 s/iter. ETA=0:28:40
# [03/03 06:47:39 d2.evaluation.evaluator]: Inference done 6/80. Dataloading: 0.0000 s/iter. Inference: 22.8426 s/iter. Eval: 0.0011 s/iter. Total: 22.8437 s/iter. ETA=0:28:10
# [03/03 06:48:02 d2.evaluation.evaluator]: Inference done 7/80. Dataloading: 0.0074 s/iter. Inference: 22.9860 s/iter. Eval: 0.0011 s/iter. Total: 22.9949 s/iter. ETA=0:27:58
# [03/03 06:48:25 d2.evaluation.evaluator]: Inference done 8/80. Dataloading: 0.0094 s/iter. Inference: 22.9397 s/iter. Eval: 0.0011 s/iter. Total: 22.9508 s/iter. ETA=0:27:32
# [03/03 06:48:48 d2.evaluation.evaluator]: Inference done 9/80. Dataloading: 0.0138 s/iter. Inference: 23.0219 s/iter. Eval: 0.0011 s/iter. Total: 23.0375 s/iter. ETA=0:27:15
# [03/03 06:49:10 d2.evaluation.evaluator]: Inference done 10/80. Dataloading: 0.0148 s/iter. Inference: 22.9198 s/iter. Eval: 0.0010 s/iter. Total: 22.9365 s/iter. ETA=0:26:45
# [03/03 06:49:33 d2.evaluation.evaluator]: Inference done 11/80. Dataloading: 0.0159 s/iter. Inference: 22.8589 s/iter. Eval: 0.0010 s/iter. Total: 22.8767 s/iter. ETA=0:26:18
# [03/03 06:49:56 d2.evaluation.evaluator]: Inference done 12/80. Dataloading: 0.0167 s/iter. Inference: 22.8125 s/iter. Eval: 0.0010 s/iter. Total: 22.8311 s/iter. ETA=0:25:52
# [03/03 06:50:18 d2.evaluation.evaluator]: Inference done 13/80. Dataloading: 0.0178 s/iter. Inference: 22.7531 s/iter. Eval: 0.0010 s/iter. Total: 22.7729 s/iter. ETA=0:25:25
# [03/03 06:50:41 d2.evaluation.evaluator]: Inference done 14/80. Dataloading: 0.0181 s/iter. Inference: 22.7738 s/iter. Eval: 0.0010 s/iter. Total: 22.7939 s/iter. ETA=0:25:04
# [03/03 06:51:04 d2.evaluation.evaluator]: Inference done 15/80. Dataloading: 0.0189 s/iter. Inference: 22.7900 s/iter. Eval: 0.0010 s/iter. Total: 22.8108 s/iter. ETA=0:24:42
# [03/03 06:51:26 d2.evaluation.evaluator]: Inference done 16/80. Dataloading: 0.0191 s/iter. Inference: 22.7033 s/iter. Eval: 0.0010 s/iter. Total: 22.7243 s/iter. ETA=0:24:14
# [03/03 06:51:48 d2.evaluation.evaluator]: Inference done 17/80. Dataloading: 0.0193 s/iter. Inference: 22.6865 s/iter. Eval: 0.0010 s/iter. Total: 22.7078 s/iter. ETA=0:23:50
# [03/03 06:52:11 d2.evaluation.evaluator]: Inference done 18/80. Dataloading: 0.0194 s/iter. Inference: 22.6805 s/iter. Eval: 0.0010 s/iter. Total: 22.7019 s/iter. ETA=0:23:27
# [03/03 06:52:34 d2.evaluation.evaluator]: Inference done 19/80. Dataloading: 0.0198 s/iter. Inference: 22.6866 s/iter. Eval: 0.0011 s/iter. Total: 22.7084 s/iter. ETA=0:23:05
# [03/03 06:52:56 d2.evaluation.evaluator]: Inference done 20/80. Dataloading: 0.0198 s/iter. Inference: 22.6672 s/iter. Eval: 0.0011 s/iter. Total: 22.6890 s/iter. ETA=0:22:41
# [03/03 06:53:19 d2.evaluation.evaluator]: Inference done 21/80. Dataloading: 0.0199 s/iter. Inference: 22.6633 s/iter. Eval: 0.0011 s/iter. Total: 22.6853 s/iter. ETA=0:22:18
# [03/03 06:53:42 d2.evaluation.evaluator]: Inference done 22/80. Dataloading: 0.0201 s/iter. Inference: 22.6749 s/iter. Eval: 0.0011 s/iter. Total: 22.6971 s/iter. ETA=0:21:56
# [03/03 06:54:04 d2.evaluation.evaluator]: Inference done 23/80. Dataloading: 0.0203 s/iter. Inference: 22.6321 s/iter. Eval: 0.0011 s/iter. Total: 22.6544 s/iter. ETA=0:21:31
# [03/03 06:54:26 d2.evaluation.evaluator]: Inference done 24/80. Dataloading: 0.0203 s/iter. Inference: 22.6220 s/iter. Eval: 0.0011 s/iter. Total: 22.6444 s/iter. ETA=0:21:08
# [03/03 06:54:49 d2.evaluation.evaluator]: Inference done 25/80. Dataloading: 0.0203 s/iter. Inference: 22.6348 s/iter. Eval: 0.0011 s/iter. Total: 22.6571 s/iter. ETA=0:20:46
# [03/03 06:55:11 d2.evaluation.evaluator]: Inference done 26/80. Dataloading: 0.0203 s/iter. Inference: 22.6187 s/iter. Eval: 0.0011 s/iter. Total: 22.6411 s/iter. ETA=0:20:22
# [03/03 06:55:34 d2.evaluation.evaluator]: Inference done 27/80. Dataloading: 0.0204 s/iter. Inference: 22.6101 s/iter. Eval: 0.0011 s/iter. Total: 22.6325 s/iter. ETA=0:19:59
# [03/03 06:55:56 d2.evaluation.evaluator]: Inference done 28/80. Dataloading: 0.0204 s/iter. Inference: 22.6069 s/iter. Eval: 0.0011 s/iter. Total: 22.6294 s/iter. ETA=0:19:36
# [03/03 06:56:19 d2.evaluation.evaluator]: Inference done 29/80. Dataloading: 0.0204 s/iter. Inference: 22.6107 s/iter. Eval: 0.0011 s/iter. Total: 22.6332 s/iter. ETA=0:19:14
# [03/03 06:56:41 d2.evaluation.evaluator]: Inference done 30/80. Dataloading: 0.0205 s/iter. Inference: 22.5970 s/iter. Eval: 0.0011 s/iter. Total: 22.6195 s/iter. ETA=0:18:50
# [03/03 06:57:04 d2.evaluation.evaluator]: Inference done 31/80. Dataloading: 0.0205 s/iter. Inference: 22.6055 s/iter. Eval: 0.0011 s/iter. Total: 22.6281 s/iter. ETA=0:18:28
# [03/03 06:57:27 d2.evaluation.evaluator]: Inference done 32/80. Dataloading: 0.0205 s/iter. Inference: 22.6139 s/iter. Eval: 0.0011 s/iter. Total: 22.6364 s/iter. ETA=0:18:06
# [03/03 06:57:50 d2.evaluation.evaluator]: Inference done 33/80. Dataloading: 0.0205 s/iter. Inference: 22.6410 s/iter. Eval: 0.0011 s/iter. Total: 22.6635 s/iter. ETA=0:17:45
# [03/03 06:58:13 d2.evaluation.evaluator]: Inference done 34/80. Dataloading: 0.0206 s/iter. Inference: 22.6506 s/iter. Eval: 0.0011 s/iter. Total: 22.6733 s/iter. ETA=0:17:22
# [03/03 06:58:36 d2.evaluation.evaluator]: Inference done 35/80. Dataloading: 0.0208 s/iter. Inference: 22.6536 s/iter. Eval: 0.0011 s/iter. Total: 22.6764 s/iter. ETA=0:17:00
# [03/03 06:58:59 d2.evaluation.evaluator]: Inference done 36/80. Dataloading: 0.0208 s/iter. Inference: 22.6780 s/iter. Eval: 0.0011 s/iter. Total: 22.7008 s/iter. ETA=0:16:38
# [03/03 06:59:22 d2.evaluation.evaluator]: Inference done 37/80. Dataloading: 0.0210 s/iter. Inference: 22.6852 s/iter. Eval: 0.0011 s/iter. Total: 22.7083 s/iter. ETA=0:16:16
# [03/03 06:59:46 d2.evaluation.evaluator]: Inference done 38/80. Dataloading: 0.0210 s/iter. Inference: 22.7037 s/iter. Eval: 0.0011 s/iter. Total: 22.7268 s/iter. ETA=0:15:54
# [03/03 07:00:09 d2.evaluation.evaluator]: Inference done 39/80. Dataloading: 0.0211 s/iter. Inference: 22.7117 s/iter. Eval: 0.0011 s/iter. Total: 22.7348 s/iter. ETA=0:15:32
# [03/03 07:00:31 d2.evaluation.evaluator]: Inference done 40/80. Dataloading: 0.0210 s/iter. Inference: 22.7099 s/iter. Eval: 0.0011 s/iter. Total: 22.7330 s/iter. ETA=0:15:09
# [03/03 07:00:54 d2.evaluation.evaluator]: Inference done 41/80. Dataloading: 0.0211 s/iter. Inference: 22.7034 s/iter. Eval: 0.0011 s/iter. Total: 22.7266 s/iter. ETA=0:14:46
# [03/03 07:01:16 d2.evaluation.evaluator]: Inference done 42/80. Dataloading: 0.0211 s/iter. Inference: 22.6865 s/iter. Eval: 0.0011 s/iter. Total: 22.7096 s/iter. ETA=0:14:22
# [03/03 07:01:39 d2.evaluation.evaluator]: Inference done 43/80. Dataloading: 0.0212 s/iter. Inference: 22.6972 s/iter. Eval: 0.0011 s/iter. Total: 22.7204 s/iter. ETA=0:14:00
# [03/03 07:02:01 d2.evaluation.evaluator]: Inference done 44/80. Dataloading: 0.0213 s/iter. Inference: 22.6869 s/iter. Eval: 0.0011 s/iter. Total: 22.7102 s/iter. ETA=0:13:37
# [03/03 07:02:24 d2.evaluation.evaluator]: Inference done 45/80. Dataloading: 0.0213 s/iter. Inference: 22.6720 s/iter. Eval: 0.0011 s/iter. Total: 22.6953 s/iter. ETA=0:13:14
# [03/03 07:02:46 d2.evaluation.evaluator]: Inference done 46/80. Dataloading: 0.0213 s/iter. Inference: 22.6773 s/iter. Eval: 0.0011 s/iter. Total: 22.7006 s/iter. ETA=0:12:51
# [03/03 07:03:09 d2.evaluation.evaluator]: Inference done 47/80. Dataloading: 0.0213 s/iter. Inference: 22.6694 s/iter. Eval: 0.0011 s/iter. Total: 22.6928 s/iter. ETA=0:12:28
# [03/03 07:03:31 d2.evaluation.evaluator]: Inference done 48/80. Dataloading: 0.0213 s/iter. Inference: 22.6652 s/iter. Eval: 0.0011 s/iter. Total: 22.6885 s/iter. ETA=0:12:06
# [03/03 07:03:54 d2.evaluation.evaluator]: Inference done 49/80. Dataloading: 0.0214 s/iter. Inference: 22.6657 s/iter. Eval: 0.0011 s/iter. Total: 22.6891 s/iter. ETA=0:11:43
# [03/03 07:04:16 d2.evaluation.evaluator]: Inference done 50/80. Dataloading: 0.0214 s/iter. Inference: 22.6544 s/iter. Eval: 0.0011 s/iter. Total: 22.6779 s/iter. ETA=0:11:20
# [03/03 07:04:38 d2.evaluation.evaluator]: Inference done 51/80. Dataloading: 0.0215 s/iter. Inference: 22.6262 s/iter. Eval: 0.0011 s/iter. Total: 22.6497 s/iter. ETA=0:10:56
# [03/03 07:04:59 d2.evaluation.evaluator]: Inference done 52/80. Dataloading: 0.0215 s/iter. Inference: 22.6011 s/iter. Eval: 0.0011 s/iter. Total: 22.6246 s/iter. ETA=0:10:33
# [03/03 07:05:21 d2.evaluation.evaluator]: Inference done 53/80. Dataloading: 0.0215 s/iter. Inference: 22.5884 s/iter. Eval: 0.0011 s/iter. Total: 22.6120 s/iter. ETA=0:10:10
# [03/03 07:05:43 d2.evaluation.evaluator]: Inference done 54/80. Dataloading: 0.0215 s/iter. Inference: 22.5804 s/iter. Eval: 0.0011 s/iter. Total: 22.6040 s/iter. ETA=0:09:47
# [03/03 07:06:06 d2.evaluation.evaluator]: Inference done 55/80. Dataloading: 0.0217 s/iter. Inference: 22.5795 s/iter. Eval: 0.0011 s/iter. Total: 22.6033 s/iter. ETA=0:09:25
# [03/03 07:06:28 d2.evaluation.evaluator]: Inference done 56/80. Dataloading: 0.0217 s/iter. Inference: 22.5679 s/iter. Eval: 0.0011 s/iter. Total: 22.5916 s/iter. ETA=0:09:02
# [03/03 07:06:50 d2.evaluation.evaluator]: Inference done 57/80. Dataloading: 0.0217 s/iter. Inference: 22.5540 s/iter. Eval: 0.0011 s/iter. Total: 22.5777 s/iter. ETA=0:08:39
# [03/03 07:07:12 d2.evaluation.evaluator]: Inference done 58/80. Dataloading: 0.0217 s/iter. Inference: 22.5458 s/iter. Eval: 0.0011 s/iter. Total: 22.5696 s/iter. ETA=0:08:16
# [03/03 07:07:35 d2.evaluation.evaluator]: Inference done 59/80. Dataloading: 0.0216 s/iter. Inference: 22.5586 s/iter. Eval: 0.0011 s/iter. Total: 22.5823 s/iter. ETA=0:07:54
# [03/03 07:07:58 d2.evaluation.evaluator]: Inference done 60/80. Dataloading: 0.0217 s/iter. Inference: 22.5607 s/iter. Eval: 0.0011 s/iter. Total: 22.5844 s/iter. ETA=0:07:31
# [03/03 07:08:20 d2.evaluation.evaluator]: Inference done 61/80. Dataloading: 0.0217 s/iter. Inference: 22.5535 s/iter. Eval: 0.0011 s/iter. Total: 22.5773 s/iter. ETA=0:07:08
# [03/03 07:08:43 d2.evaluation.evaluator]: Inference done 62/80. Dataloading: 0.0216 s/iter. Inference: 22.5610 s/iter. Eval: 0.0011 s/iter. Total: 22.5847 s/iter. ETA=0:06:46
# [03/03 07:09:06 d2.evaluation.evaluator]: Inference done 63/80. Dataloading: 0.0217 s/iter. Inference: 22.5585 s/iter. Eval: 0.0011 s/iter. Total: 22.5822 s/iter. ETA=0:06:23
# [03/03 07:09:28 d2.evaluation.evaluator]: Inference done 64/80. Dataloading: 0.0217 s/iter. Inference: 22.5593 s/iter. Eval: 0.0011 s/iter. Total: 22.5831 s/iter. ETA=0:06:01
# [03/03 07:09:51 d2.evaluation.evaluator]: Inference done 65/80. Dataloading: 0.0218 s/iter. Inference: 22.5685 s/iter. Eval: 0.0011 s/iter. Total: 22.5924 s/iter. ETA=0:05:38
# [03/03 07:10:14 d2.evaluation.evaluator]: Inference done 66/80. Dataloading: 0.0218 s/iter. Inference: 22.5643 s/iter. Eval: 0.0011 s/iter. Total: 22.5881 s/iter. ETA=0:05:16
# [03/03 07:10:36 d2.evaluation.evaluator]: Inference done 67/80. Dataloading: 0.0218 s/iter. Inference: 22.5536 s/iter. Eval: 0.0011 s/iter. Total: 22.5774 s/iter. ETA=0:04:53
# [03/03 07:10:58 d2.evaluation.evaluator]: Inference done 68/80. Dataloading: 0.0218 s/iter. Inference: 22.5561 s/iter. Eval: 0.0011 s/iter. Total: 22.5799 s/iter. ETA=0:04:30
# [03/03 07:11:21 d2.evaluation.evaluator]: Inference done 69/80. Dataloading: 0.0218 s/iter. Inference: 22.5575 s/iter. Eval: 0.0011 s/iter. Total: 22.5813 s/iter. ETA=0:04:08
# [03/03 07:11:43 d2.evaluation.evaluator]: Inference done 70/80. Dataloading: 0.0217 s/iter. Inference: 22.5441 s/iter. Eval: 0.0011 s/iter. Total: 22.5678 s/iter. ETA=0:03:45
# [03/03 07:12:05 d2.evaluation.evaluator]: Inference done 71/80. Dataloading: 0.0218 s/iter. Inference: 22.5383 s/iter. Eval: 0.0011 s/iter. Total: 22.5621 s/iter. ETA=0:03:23
# [03/03 07:12:27 d2.evaluation.evaluator]: Inference done 72/80. Dataloading: 0.0217 s/iter. Inference: 22.5368 s/iter. Eval: 0.0011 s/iter. Total: 22.5606 s/iter. ETA=0:03:00
# [03/03 07:12:49 d2.evaluation.evaluator]: Inference done 73/80. Dataloading: 0.0218 s/iter. Inference: 22.5252 s/iter. Eval: 0.0011 s/iter. Total: 22.5490 s/iter. ETA=0:02:37
# [03/03 07:13:11 d2.evaluation.evaluator]: Inference done 74/80. Dataloading: 0.0218 s/iter. Inference: 22.5217 s/iter. Eval: 0.0011 s/iter. Total: 22.5455 s/iter. ETA=0:02:15
# [03/03 07:13:34 d2.evaluation.evaluator]: Inference done 75/80. Dataloading: 0.0218 s/iter. Inference: 22.5186 s/iter. Eval: 0.0011 s/iter. Total: 22.5425 s/iter. ETA=0:01:52
# [03/03 07:13:56 d2.evaluation.evaluator]: Inference done 76/80. Dataloading: 0.0217 s/iter. Inference: 22.5099 s/iter. Eval: 0.0011 s/iter. Total: 22.5337 s/iter. ETA=0:01:30
# [03/03 07:14:18 d2.evaluation.evaluator]: Inference done 77/80. Dataloading: 0.0217 s/iter. Inference: 22.5081 s/iter. Eval: 0.0011 s/iter. Total: 22.5319 s/iter. ETA=0:01:07
# [03/03 07:14:41 d2.evaluation.evaluator]: Inference done 78/80. Dataloading: 0.0217 s/iter. Inference: 22.5089 s/iter. Eval: 0.0011 s/iter. Total: 22.5327 s/iter. ETA=0:00:45
# [03/03 07:15:03 d2.evaluation.evaluator]: Inference done 79/80. Dataloading: 0.0217 s/iter. Inference: 22.5091 s/iter. Eval: 0.0011 s/iter. Total: 22.5329 s/iter. ETA=0:00:22
# [03/03 07:15:26 d2.evaluation.evaluator]: Inference done 80/80. Dataloading: 0.0217 s/iter. Inference: 22.5063 s/iter. Eval: 0.0011 s/iter. Total: 22.5301 s/iter. ETA=0:00:00
# [03/03 07:15:26 d2.evaluation.evaluator]: Total inference time: 0:28:09.858296 (22.531444 s / iter per device, on 1 devices)
# [03/03 07:15:26 d2.evaluation.evaluator]: Total inference pure compute time: 0:28:07 (22.506294 s / iter per device, on 1 devices)
# [03/03 07:15:26 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [03/03 07:15:26 d2.evaluation.coco_evaluation]: Saving results to runs/detect/inference/coco_instances_results.json
# [03/03 07:15:26 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=20.62s)
# creating index...
# index created!
# [03/03 07:15:47 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [03/03 07:15:47 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.17 seconds.
# [03/03 07:15:47 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [03/03 07:15:47 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.695
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.275
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.572
# [03/03 07:15:47 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 39.278 | 69.461 | 36.179 | 27.546 | 38.841 | 46.554 |
# [03/03 07:15:47 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Ulcer      | 19.998 | Polyp      | 44.317 | Cancer     | 53.520 |

# %%
# !pip -q install palettable
import palettable.colorbrewer.qualitative as pbq

plt.title('Bbox AP in Valid Dataset', size=10)
ax = plt.barh(y=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'],
        width=[result['bbox']['AP'], result['bbox']['AP50'], result['bbox']['AP75'], result['bbox']['APl'],
           result['bbox']['APm'], result['bbox']['APm'],], 
        color=pbq.Pastel1_7.hex_colors, edgecolor='white',
        label=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'])

for rect in ax.patches:
    x = rect.get_width()
    y = rect.get_y() + rect.get_height()/2.0
    plt.text(x, y, f'{x:.2f}', ha='left', va='center', size=10, color='blue')

plt.legend()
plt.show()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 6.1 MB/s eta 0:00:00

# %%
plt.style.use('default')
plt.figure(figsize=(12,6))

plt.title('AP by Class', size=10)
ax = plt.bar(
    x=[f'AP-{col}' for col in thing_classes],
    height=[result['bbox'][f'AP-{col}'] for col in thing_classes],
    color=pbq.Pastel1_7.hex_colors,
    edgecolor='white',
    label=[f'bbox/AP-{col}' for col in thing_classes]
)

# 막대 위에 텍스트 추가
for rect in ax.patches:
    x = rect.get_x() + rect.get_width() / 2.0  # 막대 중앙 x좌표
    y = rect.get_height()  # 막대 길이
    plt.text(x, y, f'{y:.2f}', ha='center', va='bottom', size=10, color='gray')  # 텍스트 위치 조정


plt.legend()
plt.xticks(rotation=60)
plt.show()
