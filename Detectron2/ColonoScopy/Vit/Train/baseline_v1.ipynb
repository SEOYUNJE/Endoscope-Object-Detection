# %% [markdown]
# ## 1. Import Library
# ___

# %%
import os
import sys
import pickle
import random
import gc
import ctypes
import copy

from glob import glob
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from colorama import Fore

from PIL import Image
import cv2

import torch
import torch.nn as nn

from sklearn.model_selection import GroupKFold
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Configuration

# %%
class CFG:
    debug = False
    output_dir = 'runs/detect'
    seed = 42
    train_ds = 'colonoscopy_train' ##DatasetDictSampler
    
    model_name = 'MViTv2_T' ## Tiny Version
    img_size = [256,256]
    input_format = 'RGB' ## VitDet 
    imgdir = '/kaggle/input/colonoscopy-256x256-resized-png'

    split_mode = 'valid20'
    max_iter = 5_000
    ims_per_batch = 16
    num_workers = 4

    lr_scheduler_name = "CosineParamScheduler" ## MultiStepParamScheduler
    base_lr = 1e-4
    base_lr_end = base_lr * 1e-9
    weight_decay = 1e-2
    eval_period = max_iter * 10 ## In Training
    log_period = 20
    amp = True

    device = 'cuda' if torch.cuda.is_available() else 'cpu'

os.makedirs(CFG.output_dir, exist_ok=True)

# %% [markdown]
# #### Reproducibility

# %%
def seed_everything(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark= False

    os.environ['PYTHONHASHSEED'] = str(seed)

seed_everything(CFG.seed)

# %% [markdown]
# #### Clean_memory

# %%
def clean_memory():
    ctypes.CDLL('libc.so.6').malloc_trim(0)
    gc.collect()
    
clean_memory()

# %% [markdown]
# #### Install Detectron2 Library

# %%
print(f'=> {Fore.GREEN}Installing Detectron2 Library...' )
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# => Installing Detectron2 Library...
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.4 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done

# %% [markdown]
# ## 2. Build Dataset_Dicts
# ___
#
# - **궤양**: `ulcer(label: 0)`
#
# - **용종**: `polyp(label: 1)`
#
# - **암**: `cancer(label: 2)`

# %%
meta_data = pd.read_csv('/kaggle/input/metadataset/colonoscopy_data2.csv')
print('Shape of DataFrame: ', meta_data.shape)
meta_data.head()
# Out:
# Shape of DataFrame:  (2496, 14)
#         image_id  height  width        organ  lesion_label  location  \
# 0  2_1_00001.png    2048   2048  colonoscopy             0         1
# 1  2_1_00001.png    2048   2048  colonoscopy             0         1
# 2  2_1_00002.png    2048   2048  colonoscopy             0         1
# 3  2_1_00002.png    2048   2048  colonoscopy             0         1
# 4  2_1_00002.png    2048   2048  colonoscopy             0         1
#
#   shape_type_polygon                                       polygon_mask  \
# 0            polygon  1484.52,775.16;1516.82,710.56;1519.30,640.99;1...
# 1            polygon  1663.40,1478.26;1653.47,1426.09;1616.20,1388.8...
# 2            polygon  687.01,223.60;687.01,273.29;704.40,337.89;726....
# 3            polygon  826.14,1200.00;878.31,1207.45;932.97,1187.58;9...
# 4            polygon  575.20,1038.51;520.55,1050.93;468.37,1050.93;4...
#
#   bounding_box_shape        x_min        y_min        x_max        y_max  \
# 0          rectangle   838.559006   149.068323  1519.304348   807.453416
# 1          rectangle  1310.608696  1324.223602  1663.403727  1868.322981
# 2          rectangle   687.006211   168.944099  1591.354037  1465.838509
# 3          rectangle   488.248447   434.782609  1007.503106  1207.453416
# 4          rectangle   212.472050   725.465839   607.503106  1050.931677
#
#   lesion
# 0  ulcer
# 1  ulcer
# 2  ulcer
# 3  ulcer
# 4  ulcer

# %%
thing_classes = [
    'Ulcer',
    'Polyp',
    'Cancer',
]

category_id_to_name = {index: class_name for index,class_name in enumerate(thing_classes) }

meta_data['lesion'] = meta_data['lesion_label'].map(category_id_to_name)

# %%
train_id = [x.split('/')[-1] for x in glob('/kaggle/input/colonoscopy-256x256-resized-png/train/*.png')] 
test_id = [x.split('/')[-1] for x in glob('/kaggle/input/colonoscopy-256x256-resized-png/test/*.png')] 

train_df = meta_data[meta_data['image_id'].isin(train_id)].reset_index(drop=True)
test_df = meta_data[meta_data['image_id'].isin(test_id)].reset_index(drop=True)

print('=> Number of Unique Image_id in Train: ', train_df.image_id.nunique())
print('=> Number of Unique Image_id in Test: ', test_df.image_id.nunique())
# Out:
# => Number of Unique Image_id in Train:  1596
# => Number of Unique Image_id in Test:  400

# %%
from detectron2.structures import BoxMode

def get_colonoscopy_dicts(
    imgdir: str, 
    df,
    mode: str = 'train',
    use_cache: bool = True, 
    debug: bool = True,
    target_indices: list = None
): 
    debug_str = f"_debug{int(debug)}"
    cache_path = f'/kaggle/working/dataset_dicts_cache_{mode}{debug_str}.pkl'

    if not use_cache or not os.path.exists(cache_path):
       print(f'{Fore.BLUE}#'* 25)
       print(f'### Creating {mode} Data...')
       print('#' * 25)

       meta_df = pd.read_csv(f'/kaggle/input/colonoscopy-256x256-resized-png/{mode}_meta.csv')
        
       if debug:
           meta_df = meta_df[:500]

       resized_height = CFG.img_size[1]
       resized_width = CFG.img_size[0]
       print(f'=> Height of Image: {resized_height}')
       print(f'=> Width of Image: {resized_width}')

       dataset_dicts = []
       for _, (image_id, height, width) in tqdm(meta_df.iterrows(), total=len(meta_df), desc='Build Dataset Dict'):
           record = {}
           record['file_name'] = os.path.join(imgdir,'train',image_id)
           record['image_id'] = image_id
           record['height'] = resized_height
           record['width'] = resized_width

           if mode != 'test':
              objs = []
              for _, row in df[df.image_id == image_id].iterrows():
                  class_id = row['lesion_label']

                  h_ratio = resized_height / height
                  w_ratio = resized_width / width

                  bbox_resized = [
                      row['x_min'] * w_ratio,
                      row['y_min'] * h_ratio,
                      row['x_max'] * w_ratio,
                      row['y_max'] * h_ratio,
                  ]

                  obj = {
                     'bbox': bbox_resized,
                     'bbox_mode': BoxMode.XYXY_ABS,
                     'category_id': class_id,
                  }
                  objs.append(obj)
              record['annotations'] = objs
              dataset_dicts.append(record)
           else: 
              dataset_dicts.append(record)
       with open(cache_path, mode='wb') as f:
           pickle.dump(dataset_dicts, f)
    with open(cache_path, mode='rb') as f:
        dataset_dicts = pickle.load(f)

    if target_indices is not None:
        dataset_dicts = [dataset_dicts[i] for i in target_indices]

    return dataset_dicts

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog

if CFG.split_mode == 'valid20':
    n_dataset = len(
        get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug)
        )
    
    n_train = int(n_dataset * 0.8)
    n_valid = n_dataset - n_train
    rs = np.random.RandomState(CFG.seed)
    inds = rs.permutation(n_dataset)
    train_inds, valid_inds = inds[:n_train], inds[n_train:]

    print(f'n_train: {len(train_inds)} n_valid: {len(valid_inds)}')

    DatasetCatalog.register(
        'colonoscopy_train',
        lambda: get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = train_inds
        )
    )
    MetadataCatalog.get('colonoscopy_train').set(thing_classes = thing_classes)

    DatasetCatalog.register(
        'colonoscopy_valid',
        lambda: get_colonoscopy_dicts(
            CFG.imgdir, train_df, mode='train', debug=CFG.debug, target_indices = valid_inds
        )
    )

    MetadataCatalog.get('colonoscopy_valid').set(thing_classes = thing_classes)
# Out:
# #########################
# ### Creating train Data...
# #########################
# => Height of Image: 256
# => Width of Image: 256
# Build Dataset Dict: 100%|██████████| 1596/1596 [00:01<00:00, 1392.87it/s]
# n_train: 1276 n_valid: 320

# %%
dataset_dicts = get_colonoscopy_dicts(CFG.imgdir, train_df, mode='train', debug=CFG.debug)

clean_memory()

# %% [markdown]
# ## 3. Build Albumentation Mapper
# ___

# %%
def get_train_transform():
    return A.Compose(
               [
                A.HorizontalFlip(p=0.5),

                ## CLAHE
                A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0),

               
                ### Channel Transform
                A.OneOf([
                    A.ChannelShuffle(p=1.0),
                    A.ChannelDropout(p=1.0),
                    A.ToGray(p=1.0),
                    A.RGBShift(r_shift_limit=[-5,5], g_shift_limit=[-5,5], b_shift_limit=[-5,5], p=1.0)],
                    p=0.5),

                ### Dropout Transform   
                A.OneOf([
                    A.XYMasking(
                        num_masks_x=[1,1],
                        num_masks_y=[1,1],
                        mask_x_length = [int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],
                        mask_y_length = [int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        p=1.0),
                    A.CoarseDropout(
                        num_holes_range=[2,4],
                        hole_height_range=[int(CFG.img_size[0] * 0.05),int(CFG.img_size[0] * 0.1)],
                        hole_width_range=[int(CFG.img_size[1] * 0.05),int(CFG.img_size[1] * 0.1)],p=1.0),
                    A.BBoxSafeRandomCrop(
                        height=int(CFG.img_size[0] * 0.8),  # 높이 계산
                         width=int(CFG.img_size[1] * 0.8), p=1.0),],
                    p=0.25),

                ## Noisy Transform
                A.OneOf([
                    A.RandomGravel(number_of_patches=1, p=1.0),
                    A.RandomSnow(brightness_coeff=1.1, p=1.0),
                ],
                    p=0.25
                       ), 
                
                A.Resize(*CFG.img_size, p=1.0),
                ],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    ) 
        
def get_valid_transform():
    return A.Compose(
                [A.Resize(*CFG.img_size, p=1.0),],
        
                bbox_params = A.BboxParams(format='pascal_voc', label_fields = ['category_ids'])
    )

# %%
import albumentations as A
import detectron2.data.transforms as T
from detectron2.data import detection_utils as utils

class AlbumentationsMapper:
    def __init__(self, is_train: bool=True, mixup_prob: float=0.1, mosaic_prob: float=0.25):
        self.is_train = is_train
        self.mixup_prob = mixup_prob
        self.mosaic_prob = mosaic_prob
        
        if self.is_train:
            self.transform = get_train_transform()
        else:
            self.transform = get_valid_transform()
            

        mode='training' if self.is_train else 'inference'
        print(f'{Fore.GREEN}[AlbumentationsMapper]{Fore.BLACK} Augmentations used in {mode}: {self.transform}')

    def datadict_sampler(self, ds_name=CFG.train_ds, n=3):
        ds = DatasetCatalog.get(ds_name)

        indices = np.random.randint(0, len(ds) - 1, n)
        return [copy.deepcopy(ds[idx]) for idx in indices]

    def __mixup_transform(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)
        mu_dict = self.datadict_sampler(n=1)[0]

        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        mu_image = utils.read_image(mu_dict['file_name'], format=CFG.input_format)

        lam = np.random.beta(2.0, 2.0)
        image = (lam * image + (1 - lam) * mu_image).astype(np.uint8)
        
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        image = transform(image=image)['image']
        dataset_dict['image'] = image
        dataset_dict['annotations'] += mu_dict['annotations']
            
        return dataset_dict

    def __mosaic_transform(self, dataset_dict):
        dataset_dict= copy.deepcopy(dataset_dict)
        image = utils.read_image(dataset_dict['file_name'],format=CFG.input_format)
        im_h, im_w = image.shape[:2]
        resized_w = random.randint(int(CFG.img_size[0]*0.75), int(CFG.img_size[0]*1.25))
        resized_h = random.randint(int(CFG.img_size[1]*0.75), int(CFG.img_size[1]*1.25))
        image = cv2.resize(image, (resized_w, resized_h))
        boxes = np.array([anno['bbox'] for anno in dataset_dict['annotations']]) 
        boxes[:,[0,2]] *= resized_w / im_w
        boxes[:,[1,3]] *= resized_h / im_h
        
        mo_items = self.datadict_sampler(n=3)
        mo_images = []
        mo_boxes = []
        
        resize_list = [
            [(im_w*2-resized_w),resized_h], [resized_w,(im_h*2-resized_h)], [(im_w*2-resized_w),(im_h*2-resized_h)],
        ]
        
        for i, mo_dict in enumerate(mo_items):
            mo_image = utils.read_image(mo_dict['file_name'],format=CFG.input_format)
            mo_h, mo_w = mo_image.shape[:2]
            mo_image = cv2.resize(mo_image, (resize_list[i][0], resize_list[i][1]))
            mo_images.append(mo_image)
            mo_bbox = np.array([
                 anno['bbox'] for anno in mo_dict['annotations']
            ])
            mo_bbox[:,[0,2]] *= resize_list[i][0] / mo_w
            mo_bbox[:,[1,3]] *= resize_list[i][1] / mo_h
            mo_boxes.append(mo_bbox)
             
        
            dataset_dict['annotations'] += mo_dict['annotations']
        
        images = [image] + mo_images
        boxes = [boxes] + mo_boxes

        
        heights = [i.shape[0] for i in images] 
        widths =  [i.shape[1] for i in images]

        ch = max(heights[0], heights[1])
        cw = max(widths[0], widths[2]) 
        h = (max(heights[0], heights[1]) + 
             max(heights[2], heights[3]))
        w = (max(widths[0], widths[2]) +
             max(widths[1], widths[3]))
        
        # pad or start coordinates 
        y0, x0 = ch - heights[0], cw - widths[0] # Height: 0,  Width: 0 
        y1, x1 = ch - heights[1], cw # Height: 0, Width: 256 
        y2, x2 = ch, cw - widths[2] # Height: 256, Width: 0
        y3, x3 = ch, cw # Height: 256, Width: 256
        x_pads = [x0, x1, x2, x3]
        y_pads = [y0, y1, y2, y3]

        output = np.zeros((h,w,3)).astype(np.uint8)
        for i, img in enumerate(images):
            output[y_pads[i]: y_pads[i] + heights[i],
                   x_pads[i]: x_pads[i] + widths[i],
                   :] = img
        transform = A.Compose([A.CLAHE(clipLimit=(1,3), tileGridSize=(8,8), p=1.0)])
        output = transform(image=output)['image']
        dataset_dict['image'] = output

        for i, bbox in enumerate(boxes):
            bbox += np.array([x_pads[i], y_pads[i], x_pads[i], y_pads[i]])
            
        boxes = np.vstack(boxes)

        for i, box in enumerate(boxes):
            dataset_dict['annotations'][i]['bbox'] = box
        
        return dataset_dict
        
    def __call__(self, dataset_dict):
        dataset_dict = copy.deepcopy(dataset_dict)

        if self.is_train:
            if np.random.rand() <= self.mosaic_prob:
               dataset_dict = self.__mosaic_transform(dataset_dict)

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict
            elif np.random.rand() <= self.mixup_prob:
               dataset_dict = self.__mixup_transform(dataset_dict)
    

               image = dataset_dict['image']

               image_shape = dataset_dict['image'].shape[:2] # height, width
               dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

               instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
               dataset_dict['instances'] = utils.filter_empty_instances(instances)

               dataset_dict.pop('annotations', None)

               return dataset_dict

        
        image = utils.read_image(dataset_dict['file_name'], format=CFG.input_format)

        ### Bounding Box
        bboxes = np.array([obj['bbox'] for obj in dataset_dict['annotations']], dtype=np.float32)
        annotation_id = np.arange(len(dataset_dict['annotations']))

        ### Applying Augmentation
        transformed = self.transform(image=image, bboxes=bboxes, category_ids=annotation_id)
        dataset_dict['image'] = transformed['image']
        
        for i in transformed['category_ids']:
            dataset_dict['annotations'][i]['bbox'] = transformed['bboxes'][i] 
        

        image_shape = dataset_dict['image'].shape[:2] # height, width
        dataset_dict['image'] = torch.as_tensor(dataset_dict['image'].transpose(2,0,1).astype('float32'))

        instances = utils.annotations_to_instances(dataset_dict['annotations'], image_shape)
        dataset_dict['instances'] = utils.filter_empty_instances(instances)

        ## Remove annotations for convert to instances
        dataset_dict.pop('annotations', None)

        return dataset_dict

# %% [markdown]
# ## 4. Visualize ColonoScopy Augmentation
# ___

# %%
colonoscopy_metadata = MetadataCatalog.get('colonoscopy_train')
print(colonoscopy_metadata)
# Out:
# Metadata(name='colonoscopy_train', thing_classes=['Ulcer', 'Polyp', 'Cancer'])

# %%
import detectron2
from detectron2.utils.visualizer import Visualizer, ColorMode

mapper = AlbumentationsMapper(is_train=True)

plt.figure(figsize=(12,8))

for i in range(8):
    plt.subplot(4,4,2*i+1)
    plt.title('Before Augmentation')
    d = dataset_dicts[i]
    img = Image.open(d['file_name'])
    img = np.array(img)
    visualizer = Visualizer(img, metadata=colonoscopy_metadata, scale=0.8)
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image())
    plt.axis('off')
    
    plt.subplot(4,4, 2*i+2)
    plt.title('After Augmentation')
    mapped_d = mapper(d)
    img_arr = mapped_d['image'].cpu().permute(1,2,0).numpy()
    # img_arr[:,:,::-1] # BGR -> RGB
    # VitModel's Input Format: RGB
    visualizer = Visualizer(img_arr, metadata=colonoscopy_metadata, scale=0.8)
    target_fields = mapped_d['instances'].get_fields()
    labels = [colonoscopy_metadata.thing_classes[i] for i in target_fields['gt_classes']]

    out = visualizer.overlay_instances(
        labels = labels,
        boxes = target_fields.get('gt_boxes',None),
        masks = target_fields.get('gt_masks',None),
        keypoints = target_fields.get('gt_keypoints', None)
    )
     
    plt.imshow(out.get_image())
    plt.axis('off')

    del out, visualizer, labels
    
plt.tight_layout()
plt.show()

del mapper; clean_memory()
# Out:
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(12, 25), mask_y_length=(12, 25), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(12, 25), hole_width_range=(12, 25)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)

# %% [markdown]
# ## 5. Lazyconfing Train Net
# ___
#
# 1) DefaultTrainer is limited to yacs configs. So, for using LazyConfig file, we should use `SimpleTrainer` or `AMPTrainer`
#
# 2) LazyConfig is an alternative, non-intrusive config system that can be used with detectron2 or potentially any other complex projects.
#
# ![image.png](attachment:41883ae9-a20e-45de-a56d-09184cd02ac0.png)

# %%
import logging
from functools import partial
from fvcore.common.param_scheduler import MultiStepParamScheduler, CosineParamScheduler

from omegaconf import OmegaConf

from detectron2 import model_zoo 
from detectron2.config import get_cfg, LazyConfig, instantiate
from detectron2.config import LazyCall as L

from detectron2.data import (
    build_detection_train_loader, 
    build_detection_test_loader,
    DatasetMapper,
    get_detection_dataset_dicts)

from detectron2.evaluation import (
     COCOEvaluator,
     inference_on_dataset, 
     print_csv_format)

from detectron2.engine import (
     create_ddp_model,
     AMPTrainer, SimpleTrainer,
     default_argument_parser, default_setup, default_writers,
     hooks, launch ## DDP 
)

from detectron2.solver import WarmupParamScheduler
from detectron2.checkpoint import DetectionCheckpointer
from detectron2.modeling import MViT

from detectron2.utils import comm
from detectron2.utils.logger import setup_logger

setup_logger()
# Out:
# <_Logger detectron2 (DEBUG)>

# %% [markdown]
# #### Setting LazyConfig File

# %%
def setup():
    """DataLoader LazyConfig"""
    dataloader = OmegaConf.create()

    dataloader.train = L(build_detection_train_loader)(
        dataset = L(get_detection_dataset_dicts)(names='colonoscopy_train'),
        mapper = L(AlbumentationsMapper)(is_train=True),
        total_batch_size = CFG.ims_per_batch,
        num_workers = CFG.num_workers
    )

    """Train LazyConfig"""
    train = model_zoo.get_config("common/train.py").train
    train.amp.enabled = True 
    train.ddp.fp16_compression = True
    train.init_checkpoint = (
    "detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth"
    )
    train.output_dir = CFG.output_dir
    train.max_iter = CFG.max_iter
    train.eval_period = CFG.eval_period
    train.checkpointer.period = CFG.eval_period
    train.log_period = CFG.log_period
    train.device = CFG.device

    """Scheduler LazyConfig"""
    lr_multiplier = L(WarmupParamScheduler)(
    scheduler=L(CosineParamScheduler)( 
        start_value = 1, 
        end_value = CFG.base_lr_end / CFG.base_lr),
    warmup_length=0,
    warmup_factor=0,
    warmup_method='linear'
    )

    """Optimizer LazyConfig"""
    optimizer = model_zoo.get_config("common/optim.py").AdamW ## or SGD
    optimizer.params.overrides = {
    "pos_embed": {"weight_decay": 0.0},
    "rel_pos_h": {"weight_decay": 0.0},
    "rel_pos_w": {"weight_decay": 0.0},
     } 
    
    optimizer.lr = CFG.base_lr
        
    optimizer.weight_decay = CFG.weight_decay

    """Model LazyConfig"""
    model = model_zoo.get_config("common/models/mask_rcnn_fpn.py").model
    model.input_format = CFG.input_format

    model.backbone.bottom_up = L(MViT)(
    embed_dim=96,
    depth=10,
    num_heads=1,
    last_block_indexes=(0, 2, 7, 9),
    residual_pooling=True,
    drop_path_rate=0.2,
    norm_layer=partial(nn.LayerNorm, eps=1e-6),
    out_features=("scale2", "scale3", "scale4", "scale5"),
    )
    model.backbone.in_features = "${.bottom_up.out_features}"

    #### Model RPN 
    model.proposal_generator.in_features = ['p2','p3','p4','p5','p6']
    model.proposal_generator.anchor_generator.sizes = [[16], [32], [64], [128], [256]]
    model.proposal_generator.anchor_generator.aspect_ratios = [0.5, 1.0, 2.0]
    model.proposal_generator.anchor_generator.offset = 0.5
    model.proposal_generator.anchor_matcher.thresholds = [0.3, 0.7]
    model.proposal_generator.batch_size_per_image = 256
    model.proposal_generator.pre_nms_topk = [2000, 1000]
    model.proposal_generator.post_nms_topk = [1000, 1000]
    
    #### Model ROI
    model.roi_heads.num_classes = len(thing_classes)
    model.roi_heads.batch_size_per_image = 512
    model.roi_heads.box_in_features = ['p2','p3','p4','p5']
    model.roi_heads.box_pooler.output_size = 7
    model.roi_heads.box_pooler.pooler_type = 'ROIAlignV2'
    model.roi_heads.proposal_matcher.thresholds = [0.5]
    model.roi_heads.box_predictor.test_score_thresh = 0.0

    cfg = OmegaConf.create()
    cfg.model = model
    cfg.dataloader = dataloader
    cfg.train = train
    cfg.optimizer = optimizer
    cfg.lr_multiplier = lr_multiplier

    """Mask-RCNN -> Faster-RCNN"""
    del cfg.model.roi_heads.mask_in_features
    del cfg.model.roi_heads.mask_pooler
    del cfg.model.roi_heads.mask_head 

    return cfg

# %% [markdown]
# #### train_net.py

# %%
def do_train(resume, cfg):
    model = instantiate(cfg.model)
    logger = logging.getLogger('detectron2')
    logger.info("Model:\n{}".format(model))
    model.to(cfg.train.device)

    cfg.optimizer.params.model = model
    optim = instantiate(cfg.optimizer)

    train_loader = instantiate(cfg.dataloader.train)

    model = create_ddp_model(model, **cfg.train.ddp)
    trainer = (AMPTrainer if cfg.train.amp.enabled else SimpleTrainer)(model, train_loader, optim)

    checkpointer = DetectionCheckpointer(
        model, cfg.train.output_dir, trainer=trainer
    )

    ## including timing 
    ## including checkpointing
    ## including lr scheduling
    ## including writing events
    trainer.register_hooks(
        [
            hooks.IterationTimer(),
            hooks.LRScheduler(scheduler=instantiate(cfg.lr_multiplier)),
            hooks.PeriodicCheckpointer(checkpointer, **cfg.train.checkpointer)
            if comm.is_main_process() else None,
            hooks.PeriodicWriter(
                default_writers(cfg.train.output_dir, cfg.train.max_iter),
                period = cfg.train.log_period,
            )
            if comm.is_main_process() else None,
        ]
    )

    checkpointer.resume_or_load(cfg.train.init_checkpoint, resume=resume)
    if resume and checkpointer.has_checkpoint():
        start_iter = trainer.iter + 1
    else:
        start_iter = 0
    trainer.train(start_iter, cfg.train.max_iter)

# %% [markdown]
# #### save lazy config file

# %%
config_file = LazyConfig.to_py(setup())

with open(f'{CFG.output_dir}/mvit_config.py', 'w') as f:
    f.write(config_file)

# %%
SHOW = True

if SHOW:
    with open(f'{CFG.output_dir}/mvit_config.py', 'r') as f:
        print(f.read())
# Out:
# cfg.dataloader.train=detectron2.data.build_detection_train_loader(dataset=detectron2.data.get_detection_dataset_dicts(names='colonoscopy_train'), mapper=__main__.AlbumentationsMapper(is_train=True), num_workers=4, total_batch_size=16)
# cfg.lr_multiplier=detectron2.solver.WarmupParamScheduler(scheduler=fvcore.common.param_scheduler.CosineParamScheduler(end_value=1e-09, start_value=1), warmup_factor=0, warmup_length=0, warmup_method='linear')
# cfg.model=detectron2.modeling.GeneralizedRCNN(backbone=detectron2.modeling.FPN(bottom_up=detectron2.modeling.MViT(depth=10, drop_path_rate=0.2, embed_dim=96, last_block_indexes=[0,2,7,9], norm_layer=functools.partial(<class 'torch.nn.modules.normalization.LayerNorm'>, eps=1e-06), num_heads=1, out_features=['scale2','scale3','scale4','scale5'], residual_pooling=True), in_features=['scale2','scale3','scale4','scale5'], out_channels=256, top_block=detectron2.modeling.backbone.fpn.LastLevelMaxPool()), input_format='RGB', pixel_mean=[103.53,116.28,123.675], pixel_std=[1.0,1.0,1.0], proposal_generator=detectron2.modeling.proposal_generator.RPN(anchor_generator=detectron2.modeling.anchor_generator.DefaultAnchorGenerator(aspect_ratios=[0.5,1.0,2.0], offset=0.5, sizes=[[16],[32],[64],[128],[256]], strides=[4,8,16,32,64]), anchor_matcher=detectron2.modeling.matcher.Matcher(allow_low_quality_matches=True, labels=[0,-1,1], thresholds=[0.3,0.7]), batch_size_per_image=256, box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[1.0,1.0,1.0,1.0]), head=detectron2.modeling.proposal_generator.StandardRPNHead(in_channels=256, num_anchors=3), in_features=['p2','p3','p4','p5','p6'], nms_thresh=0.7, positive_fraction=0.5, post_nms_topk=[1000,1000], pre_nms_topk=[2000,1000]), roi_heads=detectron2.modeling.StandardROIHeads(batch_size_per_image=512, box_head=detectron2.modeling.roi_heads.FastRCNNConvFCHead(conv_dims=[], fc_dims=[1024,1024], input_shape={'channels': 256,'height': 7,'stride': None,'width': 7}), box_in_features=['p2','p3','p4','p5'], box_pooler=detectron2.modeling.poolers.ROIPooler(output_size=7, pooler_type='ROIAlignV2', sampling_ratio=0, scales=[0.25,0.125,0.0625,0.03125]), box_predictor=detectron2.modeling.FastRCNNOutputLayers(box2box_transform=detectron2.modeling.box_regression.Box2BoxTransform(weights=[10,10,5,5]), input_shape={'channels': 1024,'height': None,'stride': None,'width': None}, num_classes=3, test_score_thresh=0.0), num_classes=3, positive_fraction=0.25, proposal_matcher=detectron2.modeling.matcher.Matcher(allow_low_quality_matches=False, labels=[0,1], thresholds=[0.5])))
# cfg.optimizer=torch.optim.AdamW(betas=[0.9,0.999], lr=0.0001, params=detectron2.solver.get_default_optimizer_params(base_lr=0.0001, overrides={'pos_embed': {'weight_decay': 0.0},'rel_pos_h': {'weight_decay': 0.0},'rel_pos_w': {'weight_decay': 0.0}}, weight_decay_norm=0.0), weight_decay=0.01)
# cfg.train.amp.enabled=True
# cfg.train.checkpointer.max_to_keep=100
# cfg.train.checkpointer.period=50000
# cfg.train.ddp.broadcast_buffers=False
# cfg.train.ddp.find_unused_parameters=False
# cfg.train.ddp.fp16_compression=True
# cfg.train.device='cuda'
# cfg.train.eval_period=50000
# cfg.train.init_checkpoint='detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth'
# cfg.train.log_period=20
# cfg.train.max_iter=5000
# cfg.train.output_dir='runs/detect'

# %% [markdown]
# ## 6. Training MultiScale VisionTransformer Detection Model
# ___

# %%
do_train(resume=False, cfg=setup())
# Out:
# [03/01 15:03:13 detectron2]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): MViT(
#       (patch_embed): PatchEmbed(
#         (proj): Conv2d(3, 96, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#       )
#       (blocks): ModuleList(
#         (0): MultiScaleBlock(
#           (norm1): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=96, out_features=288, bias=True)
#             (proj): Linear(in_features=96, out_features=96, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): MultiScaleBlock(
#           (norm1): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=96, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.022)
#           (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=96, out_features=192, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (2): MultiScaleBlock(
#           (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.044)
#           (norm2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): MultiScaleBlock(
#           (norm1): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=192, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.067)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=192, out_features=384, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (4): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.089)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.111)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.133)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.156)
#           (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): MultiScaleBlock(
#           (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=384, out_features=2304, bias=True)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.178)
#           (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (proj): Linear(in_features=384, out_features=768, bias=True)
#           (pool_skip): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (9): MultiScaleBlock(
#           (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (pool_q): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_q): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_k): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#             (norm_v): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path): DropPath(drop_prob=0.200)
#           (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (scale2_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#       (scale3_norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#       (scale4_norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (scale5_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#   )
# )
# [03/01 15:03:14 d2.data.build]: Removed 0 images with no usable annotations. 1276 images left.
# [03/01 15:03:14 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 630          |   Polyp    | 352          |   Cancer   | 627          |
# |            |              |            |              |            |              |
# |   total    | 1609         |            |              |            |              |
# [AlbumentationsMapper] Augmentations used in training: Compose([
#   HorizontalFlip(p=0.5),
#   CLAHE(p=1.0, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8)),
#   OneOf([
#     ChannelShuffle(p=1.0),
#     ChannelDropout(p=1.0, channel_drop_range=(1, 1), fill_value=0.0),
#     ToGray(p=1.0, num_output_channels=3, method='weighted_average'),
#     RGBShift(p=1.0, r_shift_limit=(-5, 5), g_shift_limit=(-5, 5), b_shift_limit=(-5, 5)),
#   ], p=0.5),
#   OneOf([
#     XYMasking(p=1.0, num_masks_x=(1, 1), num_masks_y=(1, 1), mask_x_length=(12, 25), mask_y_length=(12, 25), fill_value=0.0, mask_fill_value=0.0),
#     CoarseDropout(p=1.0, fill_value=0.0, mask_fill_value=None, num_holes_range=(2, 4), hole_height_range=(12, 25), hole_width_range=(12, 25)),
#     BBoxSafeRandomCrop(p=1.0, erosion_rate=0.0),
#   ], p=0.25),
#   OneOf([
#     RandomGravel(p=1.0, gravel_roi=(0.1, 0.4, 0.9, 0.9), number_of_patches=1),
#     RandomSnow(p=1.0, snow_point_range=(0.1, 0.3), brightness_coeff=1.1),
#   ], p=0.25),
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [03/01 15:03:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/01 15:03:14 d2.data.common]: Serializing 1276 elements to byte tensors and concatenating them all ...
# [03/01 15:03:14 d2.data.common]: Serialized dataset takes 0.37 MiB
# [03/01 15:03:14 d2.data.build]: Making batched data loader with batch_size=16
# [03/01 15:03:14 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/mvitv2/MViTv2_T_in1k.pyth ...
# MViTv2_T_in1k.pyth: 290MB [00:02, 104MB/s]
# [03/01 15:03:17 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 54
# [03/01 15:03:17 d2.engine.train_loop]: Starting training from iteration 0
# [03/01 15:03:53 d2.utils.events]:  eta: 2:18:54  iter: 19  total_loss: 0.45  loss_cls: 0.161  loss_box_reg: 0.05804  loss_rpn_cls: 0.1777  loss_rpn_loc: 0.0083    time: 1.6343  last_time: 1.7488  data_time: 0.1394  last_data_time: 0.1927   lr: 9.9996e-05  max_mem: 12022M
# [03/01 15:04:39 d2.utils.events]:  eta: 2:19:37  iter: 39  total_loss: 0.2465  loss_cls: 0.124  loss_box_reg: 0.07745  loss_rpn_cls: 0.0359  loss_rpn_loc: 0.007343    time: 1.6811  last_time: 1.6983  data_time: 0.1274  last_data_time: 0.1046   lr: 9.9985e-05  max_mem: 12023M
# [03/01 15:05:13 d2.utils.events]:  eta: 2:20:00  iter: 59  total_loss: 0.304  loss_cls: 0.1551  loss_box_reg: 0.1058  loss_rpn_cls: 0.03088  loss_rpn_loc: 0.00849    time: 1.6970  last_time: 1.7098  data_time: 0.1364  last_data_time: 0.1091   lr: 9.9966e-05  max_mem: 12023M
# [03/01 15:05:48 d2.utils.events]:  eta: 2:19:08  iter: 79  total_loss: 0.333  loss_cls: 0.1653  loss_box_reg: 0.1325  loss_rpn_cls: 0.02422  loss_rpn_loc: 0.007175    time: 1.7012  last_time: 1.7048  data_time: 0.1310  last_data_time: 0.1178   lr: 9.9938e-05  max_mem: 12023M
# [03/01 15:06:22 d2.utils.events]:  eta: 2:18:13  iter: 99  total_loss: 0.3252  loss_cls: 0.1558  loss_box_reg: 0.1339  loss_rpn_cls: 0.02544  loss_rpn_loc: 0.006977    time: 1.7007  last_time: 1.6531  data_time: 0.1192  last_data_time: 0.1016   lr: 9.9903e-05  max_mem: 12023M
# [03/01 15:06:55 d2.utils.events]:  eta: 2:17:31  iter: 119  total_loss: 0.3138  loss_cls: 0.1443  loss_box_reg: 0.1321  loss_rpn_cls: 0.02182  loss_rpn_loc: 0.007385    time: 1.6997  last_time: 1.6323  data_time: 0.1156  last_data_time: 0.0721   lr: 9.986e-05  max_mem: 12023M
# [03/01 15:07:28 d2.utils.events]:  eta: 2:16:35  iter: 139  total_loss: 0.2813  loss_cls: 0.1269  loss_box_reg: 0.1244  loss_rpn_cls: 0.02089  loss_rpn_loc: 0.006809    time: 1.6899  last_time: 1.6600  data_time: 0.1040  last_data_time: 0.0863   lr: 9.9809e-05  max_mem: 12023M
# [03/01 15:08:01 d2.utils.events]:  eta: 2:15:17  iter: 159  total_loss: 0.2849  loss_cls: 0.1303  loss_box_reg: 0.1307  loss_rpn_cls: 0.01952  loss_rpn_loc: 0.006563    time: 1.6870  last_time: 1.6556  data_time: 0.1043  last_data_time: 0.0896   lr: 9.9751e-05  max_mem: 12023M
# [03/01 15:08:35 d2.utils.events]:  eta: 2:14:38  iter: 179  total_loss: 0.2799  loss_cls: 0.1288  loss_box_reg: 0.1279  loss_rpn_cls: 0.01874  loss_rpn_loc: 0.006551    time: 1.6868  last_time: 1.6327  data_time: 0.1226  last_data_time: 0.0812   lr: 9.9684e-05  max_mem: 12023M
# [03/01 15:09:09 d2.utils.events]:  eta: 2:14:05  iter: 199  total_loss: 0.3031  loss_cls: 0.1387  loss_box_reg: 0.1329  loss_rpn_cls: 0.01768  loss_rpn_loc: 0.006255    time: 1.6896  last_time: 1.6321  data_time: 0.1515  last_data_time: 0.0787   lr: 9.961e-05  max_mem: 12023M
# [03/01 15:09:43 d2.utils.events]:  eta: 2:13:23  iter: 219  total_loss: 0.2794  loss_cls: 0.1287  loss_box_reg: 0.1336  loss_rpn_cls: 0.01638  loss_rpn_loc: 0.006205    time: 1.6869  last_time: 1.6311  data_time: 0.0987  last_data_time: 0.0751   lr: 9.9527e-05  max_mem: 12023M
# [03/01 15:10:16 d2.utils.events]:  eta: 2:12:51  iter: 239  total_loss: 0.2956  loss_cls: 0.1276  loss_box_reg: 0.1384  loss_rpn_cls: 0.01473  loss_rpn_loc: 0.006044    time: 1.6860  last_time: 1.6781  data_time: 0.1085  last_data_time: 0.1043   lr: 9.9437e-05  max_mem: 12023M
# [03/01 15:10:49 d2.utils.events]:  eta: 2:12:07  iter: 259  total_loss: 0.2607  loss_cls: 0.1145  loss_box_reg: 0.1295  loss_rpn_cls: 0.01498  loss_rpn_loc: 0.005953    time: 1.6836  last_time: 1.6093  data_time: 0.1023  last_data_time: 0.0781   lr: 9.9339e-05  max_mem: 12023M
# [03/01 15:11:23 d2.utils.events]:  eta: 2:11:33  iter: 279  total_loss: 0.2727  loss_cls: 0.1175  loss_box_reg: 0.1338  loss_rpn_cls: 0.01474  loss_rpn_loc: 0.006578    time: 1.6840  last_time: 1.6719  data_time: 0.1265  last_data_time: 0.1009   lr: 9.9234e-05  max_mem: 12023M
# [03/01 15:11:57 d2.utils.events]:  eta: 2:11:00  iter: 299  total_loss: 0.2914  loss_cls: 0.1188  loss_box_reg: 0.146  loss_rpn_cls: 0.01357  loss_rpn_loc: 0.00622    time: 1.6853  last_time: 1.6469  data_time: 0.1347  last_data_time: 0.0844   lr: 9.912e-05  max_mem: 12023M
# [03/01 15:12:31 d2.utils.events]:  eta: 2:10:20  iter: 319  total_loss: 0.2841  loss_cls: 0.1221  loss_box_reg: 0.1461  loss_rpn_cls: 0.01387  loss_rpn_loc: 0.006323    time: 1.6851  last_time: 1.6615  data_time: 0.1214  last_data_time: 0.1025   lr: 9.8999e-05  max_mem: 12023M
# [03/01 15:13:04 d2.utils.events]:  eta: 2:09:34  iter: 339  total_loss: 0.2805  loss_cls: 0.1182  loss_box_reg: 0.1441  loss_rpn_cls: 0.01104  loss_rpn_loc: 0.005813    time: 1.6836  last_time: 1.6156  data_time: 0.0963  last_data_time: 0.0626   lr: 9.887e-05  max_mem: 12023M
# [03/01 15:13:37 d2.utils.events]:  eta: 2:08:57  iter: 359  total_loss: 0.2552  loss_cls: 0.1088  loss_box_reg: 0.1278  loss_rpn_cls: 0.01257  loss_rpn_loc: 0.006184    time: 1.6826  last_time: 1.6979  data_time: 0.1077  last_data_time: 0.1363   lr: 9.8733e-05  max_mem: 12023M
# [03/01 15:14:11 d2.utils.events]:  eta: 2:08:22  iter: 379  total_loss: 0.2756  loss_cls: 0.1146  loss_box_reg: 0.1401  loss_rpn_cls: 0.01188  loss_rpn_loc: 0.006048    time: 1.6822  last_time: 1.6625  data_time: 0.1178  last_data_time: 0.1191   lr: 9.8589e-05  max_mem: 12023M
# [03/01 15:14:45 d2.utils.events]:  eta: 2:07:49  iter: 399  total_loss: 0.2667  loss_cls: 0.1122  loss_box_reg: 0.1372  loss_rpn_cls: 0.01083  loss_rpn_loc: 0.005291    time: 1.6827  last_time: 1.6446  data_time: 0.1292  last_data_time: 0.0842   lr: 9.8437e-05  max_mem: 12023M
# [03/01 15:15:18 d2.utils.events]:  eta: 2:07:17  iter: 419  total_loss: 0.267  loss_cls: 0.1111  loss_box_reg: 0.1348  loss_rpn_cls: 0.01108  loss_rpn_loc: 0.005302    time: 1.6814  last_time: 1.6354  data_time: 0.1259  last_data_time: 0.0715   lr: 9.8277e-05  max_mem: 12024M
# [03/01 15:15:52 d2.utils.events]:  eta: 2:06:46  iter: 439  total_loss: 0.2799  loss_cls: 0.1223  loss_box_reg: 0.1377  loss_rpn_cls: 0.01054  loss_rpn_loc: 0.005983    time: 1.6821  last_time: 1.6551  data_time: 0.1214  last_data_time: 0.0929   lr: 9.811e-05  max_mem: 12024M
# [03/01 15:16:25 d2.utils.events]:  eta: 2:06:17  iter: 459  total_loss: 0.2833  loss_cls: 0.1173  loss_box_reg: 0.1454  loss_rpn_cls: 0.01083  loss_rpn_loc: 0.006138    time: 1.6820  last_time: 1.6505  data_time: 0.1014  last_data_time: 0.0862   lr: 9.7935e-05  max_mem: 12024M
# [03/01 15:16:59 d2.utils.events]:  eta: 2:05:40  iter: 479  total_loss: 0.261  loss_cls: 0.1126  loss_box_reg: 0.1339  loss_rpn_cls: 0.01259  loss_rpn_loc: 0.005743    time: 1.6820  last_time: 1.6730  data_time: 0.1213  last_data_time: 0.0914   lr: 9.7753e-05  max_mem: 12024M
# [03/01 15:17:33 d2.utils.events]:  eta: 2:05:09  iter: 499  total_loss: 0.2661  loss_cls: 0.1059  loss_box_reg: 0.1337  loss_rpn_cls: 0.009918  loss_rpn_loc: 0.005506    time: 1.6822  last_time: 1.6472  data_time: 0.1219  last_data_time: 0.0812   lr: 9.7563e-05  max_mem: 12024M
# [03/01 15:18:06 d2.utils.events]:  eta: 2:04:31  iter: 519  total_loss: 0.274  loss_cls: 0.1118  loss_box_reg: 0.1437  loss_rpn_cls: 0.008194  loss_rpn_loc: 0.00565    time: 1.6821  last_time: 1.7112  data_time: 0.1210  last_data_time: 0.1401   lr: 9.7365e-05  max_mem: 12024M
# [03/01 15:18:40 d2.utils.events]:  eta: 2:03:56  iter: 539  total_loss: 0.2733  loss_cls: 0.1165  loss_box_reg: 0.1483  loss_rpn_cls: 0.009185  loss_rpn_loc: 0.005315    time: 1.6818  last_time: 1.6662  data_time: 0.1143  last_data_time: 0.0997   lr: 9.716e-05  max_mem: 12024M
# [03/01 15:19:12 d2.utils.events]:  eta: 2:03:20  iter: 559  total_loss: 0.2533  loss_cls: 0.1087  loss_box_reg: 0.1261  loss_rpn_cls: 0.008691  loss_rpn_loc: 0.005128    time: 1.6794  last_time: 1.6612  data_time: 0.0881  last_data_time: 0.0893   lr: 9.6948e-05  max_mem: 12024M
# [03/01 15:19:45 d2.utils.events]:  eta: 2:02:45  iter: 579  total_loss: 0.2611  loss_cls: 0.1101  loss_box_reg: 0.1364  loss_rpn_cls: 0.01011  loss_rpn_loc: 0.005234    time: 1.6784  last_time: 1.6485  data_time: 0.0896  last_data_time: 0.0841   lr: 9.6728e-05  max_mem: 12024M
# [03/01 15:20:19 d2.utils.events]:  eta: 2:02:09  iter: 599  total_loss: 0.2495  loss_cls: 0.1014  loss_box_reg: 0.1369  loss_rpn_cls: 0.007809  loss_rpn_loc: 0.005063    time: 1.6782  last_time: 1.6210  data_time: 0.1177  last_data_time: 0.0693   lr: 9.65e-05  max_mem: 12024M
# [03/01 15:20:52 d2.utils.events]:  eta: 2:01:31  iter: 619  total_loss: 0.237  loss_cls: 0.09725  loss_box_reg: 0.1252  loss_rpn_cls: 0.007747  loss_rpn_loc: 0.004909    time: 1.6769  last_time: 0.8536  data_time: 0.1164  last_data_time: 0.0724   lr: 9.6266e-05  max_mem: 12024M
# [03/01 15:21:25 d2.utils.events]:  eta: 2:00:57  iter: 639  total_loss: 0.2454  loss_cls: 0.1032  loss_box_reg: 0.1281  loss_rpn_cls: 0.00745  loss_rpn_loc: 0.005336    time: 1.6772  last_time: 1.7005  data_time: 0.1147  last_data_time: 0.1264   lr: 9.6024e-05  max_mem: 12025M
# [03/01 15:21:58 d2.utils.events]:  eta: 2:00:23  iter: 659  total_loss: 0.2362  loss_cls: 0.08722  loss_box_reg: 0.1298  loss_rpn_cls: 0.007653  loss_rpn_loc: 0.00531    time: 1.6754  last_time: 0.8456  data_time: 0.0919  last_data_time: 0.0707   lr: 9.5775e-05  max_mem: 12025M
# [03/01 15:22:31 d2.utils.events]:  eta: 1:59:47  iter: 679  total_loss: 0.251  loss_cls: 0.1009  loss_box_reg: 0.1326  loss_rpn_cls: 0.008479  loss_rpn_loc: 0.0048    time: 1.6755  last_time: 1.6494  data_time: 0.1187  last_data_time: 0.0964   lr: 9.5518e-05  max_mem: 12025M
# [03/01 15:23:05 d2.utils.events]:  eta: 1:59:14  iter: 699  total_loss: 0.2646  loss_cls: 0.1099  loss_box_reg: 0.1407  loss_rpn_cls: 0.007561  loss_rpn_loc: 0.005276    time: 1.6761  last_time: 1.6771  data_time: 0.1297  last_data_time: 0.1026   lr: 9.5255e-05  max_mem: 12025M
# [03/01 15:23:38 d2.utils.events]:  eta: 1:58:38  iter: 719  total_loss: 0.2153  loss_cls: 0.08814  loss_box_reg: 0.1162  loss_rpn_cls: 0.005867  loss_rpn_loc: 0.004577    time: 1.6756  last_time: 1.6344  data_time: 0.1116  last_data_time: 0.0855   lr: 9.4984e-05  max_mem: 12025M
# [03/01 15:24:12 d2.utils.events]:  eta: 1:58:03  iter: 739  total_loss: 0.2385  loss_cls: 0.09996  loss_box_reg: 0.13  loss_rpn_cls: 0.00752  loss_rpn_loc: 0.005423    time: 1.6756  last_time: 1.9098  data_time: 0.1235  last_data_time: 0.3597   lr: 9.4706e-05  max_mem: 12025M
# [03/01 15:24:45 d2.utils.events]:  eta: 1:57:27  iter: 759  total_loss: 0.2403  loss_cls: 0.09722  loss_box_reg: 0.1288  loss_rpn_cls: 0.007263  loss_rpn_loc: 0.004947    time: 1.6755  last_time: 1.6509  data_time: 0.1149  last_data_time: 0.0757   lr: 9.4421e-05  max_mem: 12025M
# [03/01 15:25:19 d2.utils.events]:  eta: 1:56:54  iter: 779  total_loss: 0.2081  loss_cls: 0.08302  loss_box_reg: 0.1135  loss_rpn_cls: 0.006365  loss_rpn_loc: 0.004639    time: 1.6753  last_time: 1.6736  data_time: 0.1058  last_data_time: 0.1284   lr: 9.4129e-05  max_mem: 12025M
# [03/01 15:25:52 d2.utils.events]:  eta: 1:56:21  iter: 799  total_loss: 0.225  loss_cls: 0.09334  loss_box_reg: 0.1192  loss_rpn_cls: 0.006515  loss_rpn_loc: 0.00467    time: 1.6753  last_time: 1.6605  data_time: 0.1128  last_data_time: 0.0837   lr: 9.383e-05  max_mem: 12025M
# [03/01 15:26:25 d2.utils.events]:  eta: 1:55:46  iter: 819  total_loss: 0.2221  loss_cls: 0.08438  loss_box_reg: 0.1204  loss_rpn_cls: 0.007318  loss_rpn_loc: 0.004434    time: 1.6740  last_time: 1.6620  data_time: 0.1012  last_data_time: 0.0981   lr: 9.3525e-05  max_mem: 12025M
# [03/01 15:26:58 d2.utils.events]:  eta: 1:55:12  iter: 839  total_loss: 0.2088  loss_cls: 0.08189  loss_box_reg: 0.12  loss_rpn_cls: 0.006079  loss_rpn_loc: 0.004005    time: 1.6737  last_time: 1.6118  data_time: 0.1051  last_data_time: 0.0680   lr: 9.3212e-05  max_mem: 12025M
# [03/01 15:27:32 d2.utils.events]:  eta: 1:54:37  iter: 859  total_loss: 0.2215  loss_cls: 0.0842  loss_box_reg: 0.123  loss_rpn_cls: 0.00591  loss_rpn_loc: 0.004439    time: 1.6739  last_time: 1.6406  data_time: 0.1288  last_data_time: 0.0925   lr: 9.2892e-05  max_mem: 12025M
# [03/01 15:28:05 d2.utils.events]:  eta: 1:54:03  iter: 879  total_loss: 0.2467  loss_cls: 0.09895  loss_box_reg: 0.1371  loss_rpn_cls: 0.006313  loss_rpn_loc: 0.004862    time: 1.6735  last_time: 1.6407  data_time: 0.0962  last_data_time: 0.0753   lr: 9.2566e-05  max_mem: 12025M
# [03/01 15:28:38 d2.utils.events]:  eta: 1:53:29  iter: 899  total_loss: 0.2285  loss_cls: 0.08951  loss_box_reg: 0.1318  loss_rpn_cls: 0.005272  loss_rpn_loc: 0.004474    time: 1.6736  last_time: 1.6245  data_time: 0.1324  last_data_time: 0.0916   lr: 9.2233e-05  max_mem: 12025M
# [03/01 15:29:12 d2.utils.events]:  eta: 1:52:55  iter: 919  total_loss: 0.2335  loss_cls: 0.09945  loss_box_reg: 0.1261  loss_rpn_cls: 0.006632  loss_rpn_loc: 0.004957    time: 1.6742  last_time: 1.6323  data_time: 0.1436  last_data_time: 0.0869   lr: 9.1894e-05  max_mem: 12025M
# [03/01 15:29:45 d2.utils.events]:  eta: 1:52:22  iter: 939  total_loss: 0.2115  loss_cls: 0.08565  loss_box_reg: 0.1118  loss_rpn_cls: 0.006505  loss_rpn_loc: 0.004476    time: 1.6739  last_time: 1.6605  data_time: 0.0958  last_data_time: 0.1056   lr: 9.1547e-05  max_mem: 12025M
# [03/01 15:30:19 d2.utils.events]:  eta: 1:51:49  iter: 959  total_loss: 0.2269  loss_cls: 0.0883  loss_box_reg: 0.1238  loss_rpn_cls: 0.006546  loss_rpn_loc: 0.004862    time: 1.6740  last_time: 1.8831  data_time: 0.1175  last_data_time: 0.3233   lr: 9.1194e-05  max_mem: 12025M
# [03/01 15:30:52 d2.utils.events]:  eta: 1:51:15  iter: 979  total_loss: 0.2135  loss_cls: 0.0812  loss_box_reg: 0.1152  loss_rpn_cls: 0.004835  loss_rpn_loc: 0.003786    time: 1.6736  last_time: 1.6559  data_time: 0.0990  last_data_time: 0.1004   lr: 9.0835e-05  max_mem: 12025M
# [03/01 15:31:26 d2.utils.events]:  eta: 1:50:42  iter: 999  total_loss: 0.2275  loss_cls: 0.08918  loss_box_reg: 0.1267  loss_rpn_cls: 0.006549  loss_rpn_loc: 0.004872    time: 1.6736  last_time: 1.6729  data_time: 0.1056  last_data_time: 0.1103   lr: 9.0469e-05  max_mem: 12025M
# [03/01 15:31:59 d2.utils.events]:  eta: 1:50:08  iter: 1019  total_loss: 0.2026  loss_cls: 0.08061  loss_box_reg: 0.1153  loss_rpn_cls: 0.006316  loss_rpn_loc: 0.004245    time: 1.6736  last_time: 1.8987  data_time: 0.1205  last_data_time: 0.3469   lr: 9.0097e-05  max_mem: 12025M
# [03/01 15:32:32 d2.utils.events]:  eta: 1:49:32  iter: 1039  total_loss: 0.2188  loss_cls: 0.08823  loss_box_reg: 0.1238  loss_rpn_cls: 0.005833  loss_rpn_loc: 0.004644    time: 1.6733  last_time: 1.6225  data_time: 0.1039  last_data_time: 0.0727   lr: 8.9719e-05  max_mem: 12025M
# [03/01 15:33:06 d2.utils.events]:  eta: 1:48:57  iter: 1059  total_loss: 0.2056  loss_cls: 0.0827  loss_box_reg: 0.1071  loss_rpn_cls: 0.007051  loss_rpn_loc: 0.004195    time: 1.6730  last_time: 1.6226  data_time: 0.1427  last_data_time: 0.0803   lr: 8.9334e-05  max_mem: 12025M
# [03/01 15:33:39 d2.utils.events]:  eta: 1:48:21  iter: 1079  total_loss: 0.2063  loss_cls: 0.0775  loss_box_reg: 0.1142  loss_rpn_cls: 0.006129  loss_rpn_loc: 0.004557    time: 1.6728  last_time: 1.8686  data_time: 0.1156  last_data_time: 0.3274   lr: 8.8943e-05  max_mem: 12025M
# [03/01 15:34:12 d2.utils.events]:  eta: 1:47:45  iter: 1099  total_loss: 0.2128  loss_cls: 0.08169  loss_box_reg: 0.1195  loss_rpn_cls: 0.005242  loss_rpn_loc: 0.004084    time: 1.6723  last_time: 1.6179  data_time: 0.1044  last_data_time: 0.0705   lr: 8.8546e-05  max_mem: 12025M
# [03/01 15:34:44 d2.utils.events]:  eta: 1:47:09  iter: 1119  total_loss: 0.2078  loss_cls: 0.08003  loss_box_reg: 0.1209  loss_rpn_cls: 0.006284  loss_rpn_loc: 0.003988    time: 1.6714  last_time: 1.6088  data_time: 0.1174  last_data_time: 0.0794   lr: 8.8142e-05  max_mem: 12025M
# [03/01 15:35:18 d2.utils.events]:  eta: 1:46:37  iter: 1139  total_loss: 0.2287  loss_cls: 0.08438  loss_box_reg: 0.1268  loss_rpn_cls: 0.006252  loss_rpn_loc: 0.004737    time: 1.6716  last_time: 1.9122  data_time: 0.1194  last_data_time: 0.3357   lr: 8.7733e-05  max_mem: 12025M
# [03/01 15:35:50 d2.utils.events]:  eta: 1:46:02  iter: 1159  total_loss: 0.1864  loss_cls: 0.07322  loss_box_reg: 0.1029  loss_rpn_cls: 0.005104  loss_rpn_loc: 0.004056    time: 1.6706  last_time: 1.6303  data_time: 0.0980  last_data_time: 0.0834   lr: 8.7318e-05  max_mem: 12025M
# [03/01 15:36:24 d2.utils.events]:  eta: 1:45:28  iter: 1179  total_loss: 0.1792  loss_cls: 0.06939  loss_box_reg: 0.1032  loss_rpn_cls: 0.004015  loss_rpn_loc: 0.003674    time: 1.6707  last_time: 1.6403  data_time: 0.1262  last_data_time: 0.0938   lr: 8.6897e-05  max_mem: 12025M
# [03/01 15:36:56 d2.utils.events]:  eta: 1:44:53  iter: 1199  total_loss: 0.1848  loss_cls: 0.06975  loss_box_reg: 0.108  loss_rpn_cls: 0.005084  loss_rpn_loc: 0.003997    time: 1.6701  last_time: 1.6212  data_time: 0.0914  last_data_time: 0.0752   lr: 8.647e-05  max_mem: 12025M
# [03/01 15:37:30 d2.utils.events]:  eta: 1:44:19  iter: 1219  total_loss: 0.1995  loss_cls: 0.07915  loss_box_reg: 0.115  loss_rpn_cls: 0.006007  loss_rpn_loc: 0.004681    time: 1.6702  last_time: 1.6468  data_time: 0.1327  last_data_time: 0.0942   lr: 8.6037e-05  max_mem: 12025M
# [03/01 15:38:03 d2.utils.events]:  eta: 1:43:45  iter: 1239  total_loss: 0.2138  loss_cls: 0.07869  loss_box_reg: 0.1216  loss_rpn_cls: 0.005167  loss_rpn_loc: 0.00439    time: 1.6701  last_time: 1.6940  data_time: 0.1085  last_data_time: 0.1153   lr: 8.5599e-05  max_mem: 12025M
# [03/01 15:38:36 d2.utils.events]:  eta: 1:43:12  iter: 1259  total_loss: 0.1827  loss_cls: 0.07044  loss_box_reg: 0.1052  loss_rpn_cls: 0.004705  loss_rpn_loc: 0.003668    time: 1.6698  last_time: 1.6756  data_time: 0.1310  last_data_time: 0.1079   lr: 8.5155e-05  max_mem: 12025M
# [03/01 15:39:10 d2.utils.events]:  eta: 1:42:37  iter: 1279  total_loss: 0.1755  loss_cls: 0.06355  loss_box_reg: 0.1028  loss_rpn_cls: 0.003653  loss_rpn_loc: 0.003923    time: 1.6698  last_time: 1.6391  data_time: 0.1160  last_data_time: 0.0810   lr: 8.4705e-05  max_mem: 12025M
# [03/01 15:39:43 d2.utils.events]:  eta: 1:42:02  iter: 1299  total_loss: 0.1958  loss_cls: 0.07684  loss_box_reg: 0.1138  loss_rpn_cls: 0.004514  loss_rpn_loc: 0.003994    time: 1.6698  last_time: 1.6646  data_time: 0.1193  last_data_time: 0.1037   lr: 8.425e-05  max_mem: 12025M
# [03/01 15:40:16 d2.utils.events]:  eta: 1:41:27  iter: 1319  total_loss: 0.1978  loss_cls: 0.0716  loss_box_reg: 0.1173  loss_rpn_cls: 0.003751  loss_rpn_loc: 0.004145    time: 1.6696  last_time: 1.6139  data_time: 0.1092  last_data_time: 0.0726   lr: 8.379e-05  max_mem: 12025M
# [03/01 15:40:49 d2.utils.events]:  eta: 1:40:52  iter: 1339  total_loss: 0.1888  loss_cls: 0.07021  loss_box_reg: 0.1064  loss_rpn_cls: 0.003748  loss_rpn_loc: 0.003886    time: 1.6693  last_time: 1.6508  data_time: 0.1058  last_data_time: 0.1039   lr: 8.3324e-05  max_mem: 12025M
# [03/01 15:41:23 d2.utils.events]:  eta: 1:40:18  iter: 1359  total_loss: 0.1996  loss_cls: 0.07163  loss_box_reg: 0.1187  loss_rpn_cls: 0.005138  loss_rpn_loc: 0.004461    time: 1.6694  last_time: 1.6340  data_time: 0.1220  last_data_time: 0.0972   lr: 8.2853e-05  max_mem: 12025M
# [03/01 15:41:57 d2.utils.events]:  eta: 1:39:45  iter: 1379  total_loss: 0.1954  loss_cls: 0.0716  loss_box_reg: 0.1087  loss_rpn_cls: 0.004975  loss_rpn_loc: 0.004285    time: 1.6697  last_time: 1.6435  data_time: 0.1413  last_data_time: 0.0866   lr: 8.2377e-05  max_mem: 12025M
# [03/01 15:42:30 d2.utils.events]:  eta: 1:39:10  iter: 1399  total_loss: 0.2001  loss_cls: 0.07437  loss_box_reg: 0.1142  loss_rpn_cls: 0.004637  loss_rpn_loc: 0.004349    time: 1.6697  last_time: 1.6503  data_time: 0.1195  last_data_time: 0.0973   lr: 8.1895e-05  max_mem: 12025M
# [03/01 15:43:03 d2.utils.events]:  eta: 1:38:34  iter: 1419  total_loss: 0.1738  loss_cls: 0.06717  loss_box_reg: 0.0982  loss_rpn_cls: 0.004371  loss_rpn_loc: 0.003695    time: 1.6696  last_time: 1.6363  data_time: 0.1138  last_data_time: 0.0815   lr: 8.1409e-05  max_mem: 12025M
# [03/01 15:43:36 d2.utils.events]:  eta: 1:37:59  iter: 1439  total_loss: 0.1987  loss_cls: 0.07157  loss_box_reg: 0.1151  loss_rpn_cls: 0.004102  loss_rpn_loc: 0.004048    time: 1.6694  last_time: 1.6534  data_time: 0.1007  last_data_time: 0.0937   lr: 8.0918e-05  max_mem: 12025M
# [03/01 15:44:10 d2.utils.events]:  eta: 1:37:23  iter: 1459  total_loss: 0.184  loss_cls: 0.06819  loss_box_reg: 0.1075  loss_rpn_cls: 0.004423  loss_rpn_loc: 0.003567    time: 1.6697  last_time: 1.6127  data_time: 0.1404  last_data_time: 0.0773   lr: 8.0421e-05  max_mem: 12025M
# [03/01 15:44:42 d2.utils.events]:  eta: 1:36:49  iter: 1479  total_loss: 0.1712  loss_cls: 0.06496  loss_box_reg: 0.0987  loss_rpn_cls: 0.004054  loss_rpn_loc: 0.003618    time: 1.6687  last_time: 1.6433  data_time: 0.0896  last_data_time: 0.0838   lr: 7.992e-05  max_mem: 12025M
# [03/01 15:45:16 d2.utils.events]:  eta: 1:36:14  iter: 1499  total_loss: 0.2022  loss_cls: 0.0747  loss_box_reg: 0.1186  loss_rpn_cls: 0.004407  loss_rpn_loc: 0.004148    time: 1.6688  last_time: 1.6380  data_time: 0.1168  last_data_time: 0.0837   lr: 7.9415e-05  max_mem: 12025M
# [03/01 15:45:48 d2.utils.events]:  eta: 1:35:40  iter: 1519  total_loss: 0.1905  loss_cls: 0.07092  loss_box_reg: 0.1058  loss_rpn_cls: 0.004443  loss_rpn_loc: 0.004165    time: 1.6683  last_time: 1.6223  data_time: 0.1163  last_data_time: 0.0732   lr: 7.8904e-05  max_mem: 12025M
# [03/01 15:46:21 d2.utils.events]:  eta: 1:35:06  iter: 1539  total_loss: 0.1981  loss_cls: 0.07572  loss_box_reg: 0.1153  loss_rpn_cls: 0.004422  loss_rpn_loc: 0.0043    time: 1.6681  last_time: 1.6243  data_time: 0.1012  last_data_time: 0.0845   lr: 7.8389e-05  max_mem: 12025M
# [03/01 15:46:55 d2.utils.events]:  eta: 1:34:33  iter: 1559  total_loss: 0.1848  loss_cls: 0.06841  loss_box_reg: 0.1051  loss_rpn_cls: 0.003822  loss_rpn_loc: 0.0042    time: 1.6681  last_time: 1.8723  data_time: 0.1164  last_data_time: 0.3143   lr: 7.787e-05  max_mem: 12025M
# [03/01 15:47:28 d2.utils.events]:  eta: 1:33:59  iter: 1579  total_loss: 0.1787  loss_cls: 0.0681  loss_box_reg: 0.1055  loss_rpn_cls: 0.003946  loss_rpn_loc: 0.003905    time: 1.6679  last_time: 1.6183  data_time: 0.1023  last_data_time: 0.0877   lr: 7.7346e-05  max_mem: 12025M
# [03/01 15:48:00 d2.utils.events]:  eta: 1:33:23  iter: 1599  total_loss: 0.1777  loss_cls: 0.06231  loss_box_reg: 0.1036  loss_rpn_cls: 0.003895  loss_rpn_loc: 0.003712    time: 1.6671  last_time: 1.6494  data_time: 0.1005  last_data_time: 0.1129   lr: 7.6818e-05  max_mem: 12025M
# [03/01 15:48:32 d2.utils.events]:  eta: 1:32:50  iter: 1619  total_loss: 0.1778  loss_cls: 0.06643  loss_box_reg: 0.1028  loss_rpn_cls: 0.003652  loss_rpn_loc: 0.003987    time: 1.6665  last_time: 1.6384  data_time: 0.1061  last_data_time: 0.0898   lr: 7.6285e-05  max_mem: 12025M
# [03/01 15:49:06 d2.utils.events]:  eta: 1:32:15  iter: 1639  total_loss: 0.1868  loss_cls: 0.06797  loss_box_reg: 0.1054  loss_rpn_cls: 0.004388  loss_rpn_loc: 0.003812    time: 1.6666  last_time: 1.9024  data_time: 0.1191  last_data_time: 0.3410   lr: 7.5749e-05  max_mem: 12025M
# [03/01 15:49:39 d2.utils.events]:  eta: 1:31:42  iter: 1659  total_loss: 0.1744  loss_cls: 0.06367  loss_box_reg: 0.1053  loss_rpn_cls: 0.003467  loss_rpn_loc: 0.003903    time: 1.6665  last_time: 1.6581  data_time: 0.1042  last_data_time: 0.0922   lr: 7.5208e-05  max_mem: 12025M
# [03/01 15:50:12 d2.utils.events]:  eta: 1:31:09  iter: 1679  total_loss: 0.1805  loss_cls: 0.06522  loss_box_reg: 0.1075  loss_rpn_cls: 0.004748  loss_rpn_loc: 0.003944    time: 1.6661  last_time: 1.6616  data_time: 0.1051  last_data_time: 0.0927   lr: 7.4664e-05  max_mem: 12025M
# [03/01 15:50:45 d2.utils.events]:  eta: 1:30:34  iter: 1699  total_loss: 0.1787  loss_cls: 0.06598  loss_box_reg: 0.103  loss_rpn_cls: 0.004086  loss_rpn_loc: 0.004199    time: 1.6660  last_time: 1.8418  data_time: 0.1116  last_data_time: 0.2855   lr: 7.4115e-05  max_mem: 12025M
# [03/01 15:51:18 d2.utils.events]:  eta: 1:30:02  iter: 1719  total_loss: 0.1903  loss_cls: 0.0734  loss_box_reg: 0.1084  loss_rpn_cls: 0.003598  loss_rpn_loc: 0.003863    time: 1.6661  last_time: 1.6626  data_time: 0.1178  last_data_time: 0.1037   lr: 7.3563e-05  max_mem: 12025M
# [03/01 15:51:52 d2.utils.events]:  eta: 1:29:29  iter: 1739  total_loss: 0.1654  loss_cls: 0.0593  loss_box_reg: 0.09226  loss_rpn_cls: 0.004186  loss_rpn_loc: 0.00366    time: 1.6662  last_time: 1.6565  data_time: 0.1172  last_data_time: 0.1122   lr: 7.3007e-05  max_mem: 12025M
# [03/01 15:52:25 d2.utils.events]:  eta: 1:28:56  iter: 1759  total_loss: 0.1599  loss_cls: 0.05702  loss_box_reg: 0.09426  loss_rpn_cls: 0.004736  loss_rpn_loc: 0.003873    time: 1.6663  last_time: 1.6664  data_time: 0.1141  last_data_time: 0.1057   lr: 7.2447e-05  max_mem: 12025M
# [03/01 15:52:59 d2.utils.events]:  eta: 1:28:22  iter: 1779  total_loss: 0.1594  loss_cls: 0.06091  loss_box_reg: 0.09308  loss_rpn_cls: 0.003563  loss_rpn_loc: 0.003513    time: 1.6663  last_time: 1.6245  data_time: 0.1160  last_data_time: 0.0742   lr: 7.1884e-05  max_mem: 12025M
# [03/01 15:53:32 d2.utils.events]:  eta: 1:27:49  iter: 1799  total_loss: 0.1716  loss_cls: 0.06123  loss_box_reg: 0.1032  loss_rpn_cls: 0.003926  loss_rpn_loc: 0.003519    time: 1.6661  last_time: 1.6090  data_time: 0.1034  last_data_time: 0.0830   lr: 7.1317e-05  max_mem: 12025M
# [03/01 15:54:05 d2.utils.events]:  eta: 1:27:16  iter: 1819  total_loss: 0.174  loss_cls: 0.05988  loss_box_reg: 0.1002  loss_rpn_cls: 0.003749  loss_rpn_loc: 0.003886    time: 1.6663  last_time: 1.6530  data_time: 0.1331  last_data_time: 0.0889   lr: 7.0747e-05  max_mem: 12025M
# [03/01 15:54:38 d2.utils.events]:  eta: 1:26:44  iter: 1839  total_loss: 0.1662  loss_cls: 0.05752  loss_box_reg: 0.09533  loss_rpn_cls: 0.003591  loss_rpn_loc: 0.003539    time: 1.6658  last_time: 1.6261  data_time: 0.0955  last_data_time: 0.0815   lr: 7.0174e-05  max_mem: 12025M
# [03/01 15:55:11 d2.utils.events]:  eta: 1:26:10  iter: 1859  total_loss: 0.1779  loss_cls: 0.06206  loss_box_reg: 0.09643  loss_rpn_cls: 0.003477  loss_rpn_loc: 0.004143    time: 1.6657  last_time: 1.6400  data_time: 0.1075  last_data_time: 0.0833   lr: 6.9598e-05  max_mem: 12025M
# [03/01 15:55:44 d2.utils.events]:  eta: 1:25:36  iter: 1879  total_loss: 0.1597  loss_cls: 0.0571  loss_box_reg: 0.09926  loss_rpn_cls: 0.003543  loss_rpn_loc: 0.003835    time: 1.6659  last_time: 1.6390  data_time: 0.1259  last_data_time: 0.0862   lr: 6.9018e-05  max_mem: 12025M
# [03/01 15:56:17 d2.utils.events]:  eta: 1:25:04  iter: 1899  total_loss: 0.1768  loss_cls: 0.0638  loss_box_reg: 0.1081  loss_rpn_cls: 0.003409  loss_rpn_loc: 0.003757    time: 1.6657  last_time: 1.6100  data_time: 0.0933  last_data_time: 0.0755   lr: 6.8435e-05  max_mem: 12025M
# [03/01 15:56:51 d2.utils.events]:  eta: 1:24:30  iter: 1919  total_loss: 0.1733  loss_cls: 0.06261  loss_box_reg: 0.09983  loss_rpn_cls: 0.002629  loss_rpn_loc: 0.00382    time: 1.6656  last_time: 1.6179  data_time: 0.1159  last_data_time: 0.0723   lr: 6.785e-05  max_mem: 12025M
# [03/01 15:57:23 d2.utils.events]:  eta: 1:23:56  iter: 1939  total_loss: 0.1644  loss_cls: 0.06135  loss_box_reg: 0.09982  loss_rpn_cls: 0.002839  loss_rpn_loc: 0.00338    time: 1.6653  last_time: 1.6403  data_time: 0.0984  last_data_time: 0.0968   lr: 6.7262e-05  max_mem: 12025M
# [03/01 15:57:57 d2.utils.events]:  eta: 1:23:22  iter: 1959  total_loss: 0.1599  loss_cls: 0.05761  loss_box_reg: 0.09411  loss_rpn_cls: 0.003036  loss_rpn_loc: 0.003818    time: 1.6654  last_time: 1.6317  data_time: 0.1274  last_data_time: 0.0917   lr: 6.6671e-05  max_mem: 12025M
# [03/01 15:58:30 d2.utils.events]:  eta: 1:22:48  iter: 1979  total_loss: 0.1593  loss_cls: 0.05701  loss_box_reg: 0.09445  loss_rpn_cls: 0.003619  loss_rpn_loc: 0.003342    time: 1.6651  last_time: 1.6643  data_time: 0.0917  last_data_time: 0.0990   lr: 6.6077e-05  max_mem: 12025M
# [03/01 15:59:03 d2.utils.events]:  eta: 1:22:14  iter: 1999  total_loss: 0.1888  loss_cls: 0.06358  loss_box_reg: 0.1141  loss_rpn_cls: 0.004288  loss_rpn_loc: 0.004372    time: 1.6650  last_time: 1.6441  data_time: 0.1059  last_data_time: 0.1014   lr: 6.5481e-05  max_mem: 12025M
# [03/01 15:59:36 d2.utils.events]:  eta: 1:21:40  iter: 2019  total_loss: 0.1623  loss_cls: 0.05712  loss_box_reg: 0.09944  loss_rpn_cls: 0.003183  loss_rpn_loc: 0.003429    time: 1.6649  last_time: 1.6708  data_time: 0.1034  last_data_time: 0.1081   lr: 6.4882e-05  max_mem: 12025M
# [03/01 16:00:10 d2.utils.events]:  eta: 1:21:06  iter: 2039  total_loss: 0.1825  loss_cls: 0.06587  loss_box_reg: 0.1096  loss_rpn_cls: 0.003212  loss_rpn_loc: 0.003831    time: 1.6651  last_time: 1.6310  data_time: 0.1190  last_data_time: 0.0945   lr: 6.4281e-05  max_mem: 12025M
# ...
# [03/01 16:51:34 d2.utils.events]:  eta: 0:30:12  iter: 3899  total_loss: 0.1279  loss_cls: 0.03971  loss_box_reg: 0.07902  loss_rpn_cls: 0.001964  loss_rpn_loc: 0.002955    time: 1.6616  last_time: 1.6423  data_time: 0.1228  last_data_time: 0.0863   lr: 1.1494e-05  max_mem: 12026M
# [03/01 16:52:07 d2.utils.events]:  eta: 0:29:39  iter: 3919  total_loss: 0.1191  loss_cls: 0.04089  loss_box_reg: 0.07556  loss_rpn_cls: 0.001944  loss_rpn_loc: 0.002621    time: 1.6615  last_time: 1.6335  data_time: 0.1038  last_data_time: 0.0867   lr: 1.1097e-05  max_mem: 12026M
# [03/01 16:52:41 d2.utils.events]:  eta: 0:29:06  iter: 3939  total_loss: 0.1338  loss_cls: 0.04491  loss_box_reg: 0.08141  loss_rpn_cls: 0.001616  loss_rpn_loc: 0.002904    time: 1.6616  last_time: 1.6917  data_time: 0.1121  last_data_time: 0.1139   lr: 1.0705e-05  max_mem: 12026M
# [03/01 16:53:14 d2.utils.events]:  eta: 0:28:33  iter: 3959  total_loss: 0.1144  loss_cls: 0.03914  loss_box_reg: 0.07509  loss_rpn_cls: 0.001497  loss_rpn_loc: 0.002337    time: 1.6616  last_time: 1.6398  data_time: 0.1030  last_data_time: 0.0868   lr: 1.032e-05  max_mem: 12026M
# [03/01 16:53:47 d2.utils.events]:  eta: 0:28:01  iter: 3979  total_loss: 0.1218  loss_cls: 0.0414  loss_box_reg: 0.07429  loss_rpn_cls: 0.002195  loss_rpn_loc: 0.002689    time: 1.6617  last_time: 1.6383  data_time: 0.1273  last_data_time: 0.0832   lr: 9.9404e-06  max_mem: 12026M
# [03/01 16:54:21 d2.utils.events]:  eta: 0:27:28  iter: 3999  total_loss: 0.1329  loss_cls: 0.04516  loss_box_reg: 0.08542  loss_rpn_cls: 0.002262  loss_rpn_loc: 0.003077    time: 1.6618  last_time: 1.6509  data_time: 0.1211  last_data_time: 0.0923   lr: 9.5676e-06  max_mem: 12026M
# [03/01 16:54:54 d2.utils.events]:  eta: 0:26:55  iter: 4019  total_loss: 0.1397  loss_cls: 0.04655  loss_box_reg: 0.08518  loss_rpn_cls: 0.00197  loss_rpn_loc: 0.00304    time: 1.6618  last_time: 1.6682  data_time: 0.1030  last_data_time: 0.1091   lr: 9.2012e-06  max_mem: 12026M
# [03/01 16:55:27 d2.utils.events]:  eta: 0:26:22  iter: 4039  total_loss: 0.1274  loss_cls: 0.04177  loss_box_reg: 0.07935  loss_rpn_cls: 0.001891  loss_rpn_loc: 0.002832    time: 1.6616  last_time: 1.6358  data_time: 0.1116  last_data_time: 0.0835   lr: 8.8412e-06  max_mem: 12026M
# [03/01 16:56:00 d2.utils.events]:  eta: 0:25:49  iter: 4059  total_loss: 0.1178  loss_cls: 0.03897  loss_box_reg: 0.07459  loss_rpn_cls: 0.001584  loss_rpn_loc: 0.002596    time: 1.6615  last_time: 1.6455  data_time: 0.0885  last_data_time: 0.0943   lr: 8.4877e-06  max_mem: 12026M
# [03/01 16:56:33 d2.utils.events]:  eta: 0:25:16  iter: 4079  total_loss: 0.1315  loss_cls: 0.04653  loss_box_reg: 0.08157  loss_rpn_cls: 0.001641  loss_rpn_loc: 0.002658    time: 1.6616  last_time: 1.6168  data_time: 0.1140  last_data_time: 0.0753   lr: 8.1408e-06  max_mem: 12026M
# [03/01 16:57:06 d2.utils.events]:  eta: 0:24:43  iter: 4099  total_loss: 0.1419  loss_cls: 0.04591  loss_box_reg: 0.08649  loss_rpn_cls: 0.002523  loss_rpn_loc: 0.003114    time: 1.6615  last_time: 1.9086  data_time: 0.1336  last_data_time: 0.3361   lr: 7.8004e-06  max_mem: 12026M
# [03/01 16:57:39 d2.utils.events]:  eta: 0:24:11  iter: 4119  total_loss: 0.1312  loss_cls: 0.04686  loss_box_reg: 0.07903  loss_rpn_cls: 0.002034  loss_rpn_loc: 0.003019    time: 1.6615  last_time: 1.6748  data_time: 0.1012  last_data_time: 0.1102   lr: 7.4668e-06  max_mem: 12026M
# [03/01 16:58:13 d2.utils.events]:  eta: 0:23:37  iter: 4139  total_loss: 0.1132  loss_cls: 0.03675  loss_box_reg: 0.06903  loss_rpn_cls: 0.002077  loss_rpn_loc: 0.002508    time: 1.6615  last_time: 1.6410  data_time: 0.1106  last_data_time: 0.0961   lr: 7.1398e-06  max_mem: 12026M
# [03/01 16:58:46 d2.utils.events]:  eta: 0:23:05  iter: 4159  total_loss: 0.1326  loss_cls: 0.04479  loss_box_reg: 0.08324  loss_rpn_cls: 0.001504  loss_rpn_loc: 0.002875    time: 1.6615  last_time: 1.6544  data_time: 0.1102  last_data_time: 0.1066   lr: 6.8197e-06  max_mem: 12026M
# [03/01 16:59:19 d2.utils.events]:  eta: 0:22:31  iter: 4179  total_loss: 0.1299  loss_cls: 0.04495  loss_box_reg: 0.07887  loss_rpn_cls: 0.002233  loss_rpn_loc: 0.002684    time: 1.6615  last_time: 1.6308  data_time: 0.1028  last_data_time: 0.0853   lr: 6.5063e-06  max_mem: 12026M
# [03/01 16:59:53 d2.utils.events]:  eta: 0:21:58  iter: 4199  total_loss: 0.1223  loss_cls: 0.04203  loss_box_reg: 0.07232  loss_rpn_cls: 0.002263  loss_rpn_loc: 0.002624    time: 1.6616  last_time: 1.6349  data_time: 0.1113  last_data_time: 0.0737   lr: 6.1998e-06  max_mem: 12026M
# [03/01 17:00:25 d2.utils.events]:  eta: 0:21:26  iter: 4219  total_loss: 0.131  loss_cls: 0.04569  loss_box_reg: 0.08321  loss_rpn_cls: 0.002482  loss_rpn_loc: 0.002902    time: 1.6614  last_time: 1.6727  data_time: 0.1064  last_data_time: 0.1132   lr: 5.9002e-06  max_mem: 12026M
# [03/01 17:00:58 d2.utils.events]:  eta: 0:20:53  iter: 4239  total_loss: 0.1194  loss_cls: 0.04109  loss_box_reg: 0.07183  loss_rpn_cls: 0.002161  loss_rpn_loc: 0.002453    time: 1.6613  last_time: 1.6237  data_time: 0.1074  last_data_time: 0.0756   lr: 5.6076e-06  max_mem: 12026M
# [03/01 17:01:31 d2.utils.events]:  eta: 0:20:20  iter: 4259  total_loss: 0.1338  loss_cls: 0.0461  loss_box_reg: 0.08066  loss_rpn_cls: 0.002323  loss_rpn_loc: 0.002793    time: 1.6613  last_time: 1.6269  data_time: 0.1181  last_data_time: 0.0868   lr: 5.322e-06  max_mem: 12026M
# [03/01 17:02:05 d2.utils.events]:  eta: 0:19:47  iter: 4279  total_loss: 0.1393  loss_cls: 0.04686  loss_box_reg: 0.08486  loss_rpn_cls: 0.002911  loss_rpn_loc: 0.003156    time: 1.6614  last_time: 1.6405  data_time: 0.1150  last_data_time: 0.0867   lr: 5.0435e-06  max_mem: 12026M
# [03/01 17:02:36 d2.utils.events]:  eta: 0:19:14  iter: 4299  total_loss: 0.1212  loss_cls: 0.04051  loss_box_reg: 0.07395  loss_rpn_cls: 0.002276  loss_rpn_loc: 0.002726    time: 1.6610  last_time: 1.6578  data_time: 0.1002  last_data_time: 0.0937   lr: 4.772e-06  max_mem: 12026M
# [03/01 17:03:10 d2.utils.events]:  eta: 0:18:41  iter: 4319  total_loss: 0.1118  loss_cls: 0.03787  loss_box_reg: 0.07052  loss_rpn_cls: 0.002008  loss_rpn_loc: 0.002599    time: 1.6611  last_time: 1.6149  data_time: 0.1244  last_data_time: 0.0806   lr: 4.5077e-06  max_mem: 12026M
# [03/01 17:03:43 d2.utils.events]:  eta: 0:18:08  iter: 4339  total_loss: 0.1368  loss_cls: 0.04453  loss_box_reg: 0.08718  loss_rpn_cls: 0.00222  loss_rpn_loc: 0.003072    time: 1.6610  last_time: 1.6454  data_time: 0.1075  last_data_time: 0.0999   lr: 4.2506e-06  max_mem: 12026M
# [03/01 17:04:16 d2.utils.events]:  eta: 0:17:35  iter: 4359  total_loss: 0.1124  loss_cls: 0.03757  loss_box_reg: 0.0703  loss_rpn_cls: 0.00261  loss_rpn_loc: 0.00257    time: 1.6610  last_time: 1.6360  data_time: 0.1010  last_data_time: 0.0938   lr: 4.0007e-06  max_mem: 12026M
# [03/01 17:04:49 d2.utils.events]:  eta: 0:17:02  iter: 4379  total_loss: 0.1091  loss_cls: 0.03768  loss_box_reg: 0.06641  loss_rpn_cls: 0.001485  loss_rpn_loc: 0.002273    time: 1.6608  last_time: 1.6408  data_time: 0.1088  last_data_time: 0.0793   lr: 3.7581e-06  max_mem: 12026M
# [03/01 17:05:21 d2.utils.events]:  eta: 0:16:29  iter: 4399  total_loss: 0.1308  loss_cls: 0.04508  loss_box_reg: 0.08103  loss_rpn_cls: 0.002195  loss_rpn_loc: 0.002616    time: 1.6607  last_time: 1.6399  data_time: 0.0871  last_data_time: 0.0905   lr: 3.5227e-06  max_mem: 12026M
# [03/01 17:05:54 d2.utils.events]:  eta: 0:15:55  iter: 4419  total_loss: 0.1099  loss_cls: 0.03796  loss_box_reg: 0.07061  loss_rpn_cls: 0.001752  loss_rpn_loc: 0.002607    time: 1.6607  last_time: 1.6613  data_time: 0.0993  last_data_time: 0.0956   lr: 3.2948e-06  max_mem: 12026M
# [03/01 17:06:27 d2.utils.events]:  eta: 0:15:22  iter: 4439  total_loss: 0.1077  loss_cls: 0.03869  loss_box_reg: 0.06469  loss_rpn_cls: 0.001645  loss_rpn_loc: 0.002412    time: 1.6606  last_time: 1.6699  data_time: 0.1000  last_data_time: 0.1038   lr: 3.0741e-06  max_mem: 12026M
# [03/01 17:07:01 d2.utils.events]:  eta: 0:14:49  iter: 4459  total_loss: 0.1393  loss_cls: 0.04674  loss_box_reg: 0.08779  loss_rpn_cls: 0.001752  loss_rpn_loc: 0.002908    time: 1.6607  last_time: 1.6583  data_time: 0.1209  last_data_time: 0.1101   lr: 2.8609e-06  max_mem: 12026M
# [03/01 17:07:33 d2.utils.events]:  eta: 0:14:16  iter: 4479  total_loss: 0.1059  loss_cls: 0.0358  loss_box_reg: 0.06621  loss_rpn_cls: 0.001113  loss_rpn_loc: 0.002282    time: 1.6605  last_time: 1.6373  data_time: 0.0986  last_data_time: 0.0835   lr: 2.6552e-06  max_mem: 12026M
# [03/01 17:08:07 d2.utils.events]:  eta: 0:13:43  iter: 4499  total_loss: 0.1219  loss_cls: 0.04392  loss_box_reg: 0.07935  loss_rpn_cls: 0.00204  loss_rpn_loc: 0.002883    time: 1.6605  last_time: 1.6307  data_time: 0.1181  last_data_time: 0.0833   lr: 2.4569e-06  max_mem: 12026M
# [03/01 17:08:40 d2.utils.events]:  eta: 0:13:10  iter: 4519  total_loss: 0.1217  loss_cls: 0.04282  loss_box_reg: 0.07417  loss_rpn_cls: 0.002465  loss_rpn_loc: 0.002783    time: 1.6606  last_time: 1.6337  data_time: 0.1260  last_data_time: 0.0806   lr: 2.2661e-06  max_mem: 12026M
# [03/01 17:09:13 d2.utils.events]:  eta: 0:12:37  iter: 4539  total_loss: 0.1272  loss_cls: 0.04157  loss_box_reg: 0.07894  loss_rpn_cls: 0.002686  loss_rpn_loc: 0.002823    time: 1.6605  last_time: 1.6379  data_time: 0.0841  last_data_time: 0.0826   lr: 2.0829e-06  max_mem: 12026M
# [03/01 17:09:46 d2.utils.events]:  eta: 0:12:04  iter: 4559  total_loss: 0.1209  loss_cls: 0.04266  loss_box_reg: 0.07295  loss_rpn_cls: 0.002089  loss_rpn_loc: 0.002485    time: 1.6605  last_time: 1.6286  data_time: 0.1239  last_data_time: 0.0815   lr: 1.9072e-06  max_mem: 12026M
# [03/01 17:10:19 d2.utils.events]:  eta: 0:11:31  iter: 4579  total_loss: 0.1161  loss_cls: 0.0383  loss_box_reg: 0.07329  loss_rpn_cls: 0.001978  loss_rpn_loc: 0.002617    time: 1.6605  last_time: 1.6267  data_time: 0.0938  last_data_time: 0.0739   lr: 1.7391e-06  max_mem: 12026M
# [03/01 17:10:53 d2.utils.events]:  eta: 0:10:58  iter: 4599  total_loss: 0.0999  loss_cls: 0.03421  loss_box_reg: 0.06424  loss_rpn_cls: 0.001833  loss_rpn_loc: 0.002356    time: 1.6605  last_time: 1.6061  data_time: 0.1210  last_data_time: 0.0616   lr: 1.5787e-06  max_mem: 12026M
# [03/01 17:11:26 d2.utils.events]:  eta: 0:10:25  iter: 4619  total_loss: 0.1146  loss_cls: 0.03933  loss_box_reg: 0.07262  loss_rpn_cls: 0.002921  loss_rpn_loc: 0.002548    time: 1.6605  last_time: 1.6562  data_time: 0.0932  last_data_time: 0.0917   lr: 1.4259e-06  max_mem: 12026M
# [03/01 17:11:59 d2.utils.events]:  eta: 0:09:52  iter: 4639  total_loss: 0.1293  loss_cls: 0.0416  loss_box_reg: 0.0807  loss_rpn_cls: 0.001346  loss_rpn_loc: 0.00264    time: 1.6606  last_time: 1.6702  data_time: 0.1140  last_data_time: 0.1165   lr: 1.2807e-06  max_mem: 12026M
# [03/01 17:12:33 d2.utils.events]:  eta: 0:09:20  iter: 4659  total_loss: 0.1277  loss_cls: 0.04206  loss_box_reg: 0.07965  loss_rpn_cls: 0.001968  loss_rpn_loc: 0.002686    time: 1.6607  last_time: 1.6584  data_time: 0.1268  last_data_time: 0.0872   lr: 1.1433e-06  max_mem: 12026M
# [03/01 17:13:06 d2.utils.events]:  eta: 0:08:47  iter: 4679  total_loss: 0.1186  loss_cls: 0.03905  loss_box_reg: 0.07336  loss_rpn_cls: 0.002049  loss_rpn_loc: 0.002339    time: 1.6606  last_time: 0.8298  data_time: 0.1153  last_data_time: 0.0714   lr: 1.0135e-06  max_mem: 12026M
# [03/01 17:13:39 d2.utils.events]:  eta: 0:08:14  iter: 4699  total_loss: 0.1189  loss_cls: 0.03849  loss_box_reg: 0.07911  loss_rpn_cls: 0.001483  loss_rpn_loc: 0.00286    time: 1.6606  last_time: 1.6295  data_time: 0.1078  last_data_time: 0.0811   lr: 8.9153e-07  max_mem: 12026M
# [03/01 17:14:12 d2.utils.events]:  eta: 0:07:41  iter: 4719  total_loss: 0.1215  loss_cls: 0.04019  loss_box_reg: 0.07801  loss_rpn_cls: 0.00153  loss_rpn_loc: 0.003088    time: 1.6606  last_time: 1.6586  data_time: 0.0960  last_data_time: 0.0977   lr: 7.7729e-07  max_mem: 12026M
# [03/01 17:14:46 d2.utils.events]:  eta: 0:07:08  iter: 4739  total_loss: 0.1077  loss_cls: 0.03726  loss_box_reg: 0.06816  loss_rpn_cls: 0.00174  loss_rpn_loc: 0.002445    time: 1.6607  last_time: 1.6880  data_time: 0.1322  last_data_time: 0.1125   lr: 6.7082e-07  max_mem: 12026M
# [03/01 17:15:19 d2.utils.events]:  eta: 0:06:35  iter: 4759  total_loss: 0.1214  loss_cls: 0.04277  loss_box_reg: 0.07352  loss_rpn_cls: 0.002396  loss_rpn_loc: 0.002589    time: 1.6607  last_time: 1.6416  data_time: 0.1058  last_data_time: 0.0800   lr: 5.7214e-07  max_mem: 12026M
# [03/01 17:15:53 d2.utils.events]:  eta: 0:06:02  iter: 4779  total_loss: 0.1365  loss_cls: 0.04707  loss_box_reg: 0.07989  loss_rpn_cls: 0.002155  loss_rpn_loc: 0.002643    time: 1.6607  last_time: 1.6489  data_time: 0.0957  last_data_time: 0.0951   lr: 4.8127e-07  max_mem: 12026M
# [03/01 17:16:26 d2.utils.events]:  eta: 0:05:29  iter: 4799  total_loss: 0.1167  loss_cls: 0.03937  loss_box_reg: 0.06966  loss_rpn_cls: 0.002169  loss_rpn_loc: 0.002595    time: 1.6607  last_time: 1.6463  data_time: 0.0923  last_data_time: 0.1027   lr: 3.9821e-07  max_mem: 12026M
# [03/01 17:16:59 d2.utils.events]:  eta: 0:04:56  iter: 4819  total_loss: 0.1292  loss_cls: 0.04419  loss_box_reg: 0.07992  loss_rpn_cls: 0.002052  loss_rpn_loc: 0.002526    time: 1.6607  last_time: 1.6481  data_time: 0.1213  last_data_time: 0.0964   lr: 3.2299e-07  max_mem: 12026M
# [03/01 17:17:33 d2.utils.events]:  eta: 0:04:23  iter: 4839  total_loss: 0.1249  loss_cls: 0.04364  loss_box_reg: 0.07754  loss_rpn_cls: 0.002004  loss_rpn_loc: 0.002793    time: 1.6609  last_time: 1.6508  data_time: 0.1410  last_data_time: 0.0971   lr: 2.5561e-07  max_mem: 12026M
# [03/01 17:18:06 d2.utils.events]:  eta: 0:03:50  iter: 4859  total_loss: 0.1295  loss_cls: 0.04338  loss_box_reg: 0.07886  loss_rpn_cls: 0.002074  loss_rpn_loc: 0.002747    time: 1.6607  last_time: 1.6361  data_time: 0.0941  last_data_time: 0.0796   lr: 1.9609e-07  max_mem: 12026M
# [03/01 17:18:39 d2.utils.events]:  eta: 0:03:17  iter: 4879  total_loss: 0.1101  loss_cls: 0.04017  loss_box_reg: 0.06577  loss_rpn_cls: 0.001702  loss_rpn_loc: 0.002375    time: 1.6608  last_time: 1.6539  data_time: 0.1169  last_data_time: 0.0961   lr: 1.4443e-07  max_mem: 12026M
# [03/01 17:19:12 d2.utils.events]:  eta: 0:02:44  iter: 4899  total_loss: 0.1202  loss_cls: 0.03983  loss_box_reg: 0.07459  loss_rpn_cls: 0.001732  loss_rpn_loc: 0.002568    time: 1.6608  last_time: 1.6932  data_time: 0.1065  last_data_time: 0.1270   lr: 1.0065e-07  max_mem: 12026M
# [03/01 17:19:46 d2.utils.events]:  eta: 0:02:11  iter: 4919  total_loss: 0.1247  loss_cls: 0.04247  loss_box_reg: 0.07414  loss_rpn_cls: 0.001981  loss_rpn_loc: 0.00283    time: 1.6608  last_time: 1.6553  data_time: 0.1071  last_data_time: 0.0949   lr: 6.4741e-08  max_mem: 12026M
# [03/01 17:20:20 d2.utils.events]:  eta: 0:01:38  iter: 4939  total_loss: 0.1437  loss_cls: 0.04786  loss_box_reg: 0.08881  loss_rpn_cls: 0.002713  loss_rpn_loc: 0.003254    time: 1.6610  last_time: 1.6726  data_time: 0.1366  last_data_time: 0.1105   lr: 3.672e-08  max_mem: 12026M
# [03/01 17:20:53 d2.utils.events]:  eta: 0:01:05  iter: 4959  total_loss: 0.112  loss_cls: 0.03488  loss_box_reg: 0.07255  loss_rpn_cls: 0.002018  loss_rpn_loc: 0.002543    time: 1.6609  last_time: 1.6386  data_time: 0.0958  last_data_time: 0.0951   lr: 1.659e-08  max_mem: 12026M
# [03/01 17:21:27 d2.utils.events]:  eta: 0:00:32  iter: 4979  total_loss: 0.1306  loss_cls: 0.04393  loss_box_reg: 0.07782  loss_rpn_cls: 0.001985  loss_rpn_loc: 0.0027    time: 1.6610  last_time: 1.6523  data_time: 0.1309  last_data_time: 0.0966   lr: 4.3525e-09  max_mem: 12026M
# [03/01 17:22:00 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 0.119  loss_cls: 0.03967  loss_box_reg: 0.07509  loss_rpn_cls: 0.002033  loss_rpn_loc: 0.002503    time: 1.6608  last_time: 1.6605  data_time: 0.0917  last_data_time: 0.0938   lr: 9.9696e-12  max_mem: 12026M
# [03/01 17:22:00 d2.engine.hooks]: Overall training speed: 4998 iterations in 2:18:20 (1.6608 s / it)
# [03/01 17:22:00 d2.engine.hooks]: Total training time: 2:18:36 (0:00:15 on hooks)

# %% [markdown]
# ## 7. Visualize Train Hooks
# ___

# %%
metrics = pd.read_json(os.path.join(CFG.output_dir, 'metrics.json'), orient='records', lines=True)
metrics = metrics.sort_values(by=['iteration'])

print('Shape of Metrics: ',metrics.shape)
metrics.head()
# Out:
# Shape of Metrics:  (250, 18)
#    data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0   0.126574  8334.638949                0.981201                   1.00000
# 1   0.099437  8377.986470                0.977966                   1.00000
# 2   0.118855  8400.370871                0.970337                   1.00000
# 3   0.106799  8348.082056                0.964478                   1.00000
# 4   0.099684  8293.677699                0.965088                   0.99697
#
#    fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_rpn_cls  \
# 0                    0.00000         19      0.058044  0.160968      0.177710
# 1                    0.00000         39      0.077449  0.124043      0.035897
# 2                    0.00000         59      0.105775  0.155114      0.030879
# 3                    0.00000         79      0.132493  0.165263      0.024223
# 4                    0.00303         99      0.133948  0.155759      0.025443
#
#    loss_rpn_loc      lr  rank_data_time  roi_head/num_bg_samples  \
# 0      0.008300  0.0001        0.126574                502.93750
# 1      0.007343  0.0001        0.099437                500.71875
# 2      0.008490  0.0001        0.118855                496.81250
# 3      0.007175  0.0001        0.106799                493.81250
# 4      0.006977  0.0001        0.099684                494.00000
#
#    roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                  9.06250            252.78125              3.21875
# 1                 11.28125            253.12500              2.87500
# 2                 15.18750            252.43750              3.56250
# 3                 18.18750            252.62500              3.37500
# 4                 18.00000            252.90625              3.09375
#
#        time  total_loss
# 0  1.673622    0.449989
# 1  1.696857    0.246549
# 2  1.709673    0.303952
# 3  1.691322    0.332956
# 4  1.681237    0.325169

# %% [markdown]
# #### Scheduler Graph

# %%
print('Scheduler Type is :', CFG.lr_scheduler_name)
print('Base Learning Rate is :', CFG.base_lr)
print('Last Learning Rate is :', CFG.base_lr_end/CFG.base_lr)
print('Iteration is: ', CFG.max_iter)

plt.style.use('default')
plt.figure(figsize=(12,6))
plt.title(CFG.lr_scheduler_name, size=10)

tmp = metrics[~metrics['lr'].isna()]

plt.plot(tmp['iteration'], tmp['lr'])
plt.xlabel('iterations')
plt.ylabel('Learning Rate')

plt.show()
# Out:
# Scheduler Type is : CosineParamScheduler
# Base Learning Rate is : 0.0001
# Last Learning Rate is : 1e-09
# Iteration is:  5000

# %% [markdown]
# #### Foreground & Background Fraction in RPN & ROI

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('RPN Fraction Ratio')
tmp = metrics[~metrics['rpn/num_neg_anchors'].isna()]
tmp = tmp[~tmp['rpn/num_pos_anchors'].isna()]
plt.plot(tmp['iteration'], tmp['rpn/num_neg_anchors'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_neg_anchors'].mean(), tmp['rpn/num_neg_anchors'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['rpn/num_pos_anchors'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_pos_anchors'].mean(),tmp['rpn/num_pos_anchors'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title('ROI Head Fraction Ratio')
tmp = metrics[~metrics['roi_head/num_bg_samples'].isna()]
tmp = tmp[~tmp['roi_head/num_fg_samples'].isna()]
plt.plot(tmp['iteration'], tmp['roi_head/num_bg_samples'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_bg_samples'].mean(), tmp['roi_head/num_bg_samples'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['roi_head/num_fg_samples'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_fg_samples'].mean(),tmp['roi_head/num_fg_samples'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Loss: rpn_loc, rpn_cls, box_reg, box_cls

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(2,2,1)
tmp1 = metrics[~metrics['loss_box_reg'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_box_reg'], color='red', label='box_reg')
plt.grid(True); plt.legend()

plt.subplot(2,2,2)
tmp2 = metrics[~metrics['loss_cls'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_cls'], color='orange', label='box_cls')
plt.grid(True); plt.legend()

plt.subplot(2,2,3)
tmp3 = metrics[~metrics['loss_rpn_cls'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_cls'], color='green', label='rpn_cls')
plt.grid(True); plt.legend()

plt.subplot(2,2,4)
tmp4 = metrics[~metrics['loss_rpn_loc'].isna()]
plt.plot(tmp1['iteration'], tmp1['loss_rpn_loc'], color='skyblue', label='rpn_loc')
plt.grid(True); plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Evaluation
# ___

# %%
cfg = setup()

evaluator = COCOEvaluator("colonoscopy_valid", ("bbox",), False, output_dir=os.path.join(CFG.output_dir, 'inference'))

val_loader = build_detection_test_loader(
      dataset = get_detection_dataset_dicts(names='colonoscopy_valid'),
      mapper=AlbumentationsMapper(is_train=False),
      batch_size = CFG.ims_per_batch,
      num_workers = CFG.num_workers,
      )

## Build and Load Model
model = instantiate(cfg.model)
DetectionCheckpointer(model, save_dir=CFG.output_dir).resume_or_load(
            f'{CFG.output_dir}/model_final.pth', resume=False
        )
model.eval()

## Evaluate Metrics
result = inference_on_dataset(model, val_loader, evaluator)

clean_memory(); del model, evaluator, val_loader
# Out:
# [03/01 17:22:02 d2.evaluation.coco_evaluation]: Trying to convert 'colonoscopy_valid' to COCO format ...
# [03/01 17:22:02 d2.data.datasets.coco]: Converting annotations of dataset 'colonoscopy_valid' to COCO format ...)
# [03/01 17:22:02 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [03/01 17:22:02 d2.data.datasets.coco]: Conversion finished, #images: 320, #annotations: 391
# [03/01 17:22:02 d2.data.datasets.coco]: Caching COCO format annotations at 'runs/detect/inference/colonoscopy_valid_coco_format.json' ...
# [03/01 17:22:02 d2.data.build]: Removed 0 images with no usable annotations. 320 images left.
# [03/01 17:22:02 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   Ulcer    | 133          |   Polyp    | 85           |   Cancer   | 173          |
# |            |              |            |              |            |              |
# |   total    | 391          |            |              |            |              |
# [AlbumentationsMapper] Augmentations used in inference: Compose([
#   Resize(p=1.0, height=256, width=256, interpolation=1, mask_interpolation=0),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': ['category_ids'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False}, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [03/01 17:22:02 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/01 17:22:02 d2.data.common]: Serializing 320 elements to byte tensors and concatenating them all ...
# [03/01 17:22:02 d2.data.common]: Serialized dataset takes 0.09 MiB
# [03/01 17:22:03 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from runs/detect/model_final.pth ...
# [03/01 17:22:03 d2.evaluation.evaluator]: Start inference on 20 batches
# [03/01 17:22:16 d2.evaluation.evaluator]: Inference done 1/20. Dataloading: 0.4975 s/iter. Inference: 11.7037 s/iter. Eval: 0.0041 s/iter. Total: 12.2069 s/iter. ETA=0:03:51
# [03/01 17:22:27 d2.evaluation.evaluator]: Inference done 2/20. Dataloading: 0.2642 s/iter. Inference: 11.5840 s/iter. Eval: 0.0042 s/iter. Total: 11.8546 s/iter. ETA=0:03:33
# [03/01 17:22:39 d2.evaluation.evaluator]: Inference done 3/20. Dataloading: 0.1838 s/iter. Inference: 11.5841 s/iter. Eval: 0.0039 s/iter. Total: 11.7736 s/iter. ETA=0:03:20
# [03/01 17:22:50 d2.evaluation.evaluator]: Inference done 4/20. Dataloading: 0.1446 s/iter. Inference: 11.5656 s/iter. Eval: 0.0040 s/iter. Total: 11.7158 s/iter. ETA=0:03:07
# [03/01 17:23:02 d2.evaluation.evaluator]: Inference done 5/20. Dataloading: 0.1272 s/iter. Inference: 11.5430 s/iter. Eval: 0.0039 s/iter. Total: 11.6756 s/iter. ETA=0:02:55
# [03/01 17:23:14 d2.evaluation.evaluator]: Inference done 6/20. Dataloading: 0.0000 s/iter. Inference: 11.9335 s/iter. Eval: 0.0034 s/iter. Total: 11.9369 s/iter. ETA=0:02:47
# [03/01 17:23:25 d2.evaluation.evaluator]: Inference done 7/20. Dataloading: 0.0029 s/iter. Inference: 11.6902 s/iter. Eval: 0.0038 s/iter. Total: 11.6975 s/iter. ETA=0:02:32
# [03/01 17:23:36 d2.evaluation.evaluator]: Inference done 8/20. Dataloading: 0.0035 s/iter. Inference: 11.5574 s/iter. Eval: 0.0036 s/iter. Total: 11.5652 s/iter. ETA=0:02:18
# [03/01 17:23:48 d2.evaluation.evaluator]: Inference done 9/20. Dataloading: 0.0085 s/iter. Inference: 11.6223 s/iter. Eval: 0.0038 s/iter. Total: 11.6353 s/iter. ETA=0:02:07
# [03/01 17:24:00 d2.evaluation.evaluator]: Inference done 10/20. Dataloading: 0.0133 s/iter. Inference: 11.5816 s/iter. Eval: 0.0037 s/iter. Total: 11.5993 s/iter. ETA=0:01:55
# [03/01 17:24:11 d2.evaluation.evaluator]: Inference done 11/20. Dataloading: 0.0163 s/iter. Inference: 11.5907 s/iter. Eval: 0.0036 s/iter. Total: 11.6115 s/iter. ETA=0:01:44
# [03/01 17:24:23 d2.evaluation.evaluator]: Inference done 12/20. Dataloading: 0.0184 s/iter. Inference: 11.6216 s/iter. Eval: 0.0038 s/iter. Total: 11.6448 s/iter. ETA=0:01:33
# [03/01 17:24:34 d2.evaluation.evaluator]: Inference done 13/20. Dataloading: 0.0196 s/iter. Inference: 11.5607 s/iter. Eval: 0.0038 s/iter. Total: 11.5849 s/iter. ETA=0:01:21
# [03/01 17:24:46 d2.evaluation.evaluator]: Inference done 14/20. Dataloading: 0.0209 s/iter. Inference: 11.5802 s/iter. Eval: 0.0038 s/iter. Total: 11.6058 s/iter. ETA=0:01:09
# [03/01 17:24:58 d2.evaluation.evaluator]: Inference done 15/20. Dataloading: 0.0211 s/iter. Inference: 11.5695 s/iter. Eval: 0.0038 s/iter. Total: 11.5954 s/iter. ETA=0:00:57
# [03/01 17:25:09 d2.evaluation.evaluator]: Inference done 16/20. Dataloading: 0.0217 s/iter. Inference: 11.5604 s/iter. Eval: 0.0037 s/iter. Total: 11.5868 s/iter. ETA=0:00:46
# [03/01 17:25:21 d2.evaluation.evaluator]: Inference done 17/20. Dataloading: 0.0218 s/iter. Inference: 11.5598 s/iter. Eval: 0.0038 s/iter. Total: 11.5863 s/iter. ETA=0:00:34
# [03/01 17:25:32 d2.evaluation.evaluator]: Inference done 18/20. Dataloading: 0.0219 s/iter. Inference: 11.5422 s/iter. Eval: 0.0038 s/iter. Total: 11.5688 s/iter. ETA=0:00:23
# [03/01 17:25:44 d2.evaluation.evaluator]: Inference done 19/20. Dataloading: 0.0222 s/iter. Inference: 11.5398 s/iter. Eval: 0.0038 s/iter. Total: 11.5668 s/iter. ETA=0:00:11
# [03/01 17:25:56 d2.evaluation.evaluator]: Inference done 20/20. Dataloading: 0.0225 s/iter. Inference: 11.5789 s/iter. Eval: 0.0038 s/iter. Total: 11.6061 s/iter. ETA=0:00:00
# [03/01 17:25:56 d2.evaluation.evaluator]: Total inference time: 0:02:54.185631 (11.612375 s / iter per device, on 1 devices)
# [03/01 17:25:56 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:53 (11.578931 s / iter per device, on 1 devices)
# [03/01 17:25:56 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [03/01 17:25:56 d2.evaluation.coco_evaluation]: Saving results to runs/detect/inference/coco_instances_results.json
# [03/01 17:25:56 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=20.62s)
# creating index...
# index created!
# [03/01 17:26:17 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [03/01 17:26:17 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.18 seconds.
# [03/01 17:26:17 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [03/01 17:26:17 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.06 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.399
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.690
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.576
# [03/01 17:26:17 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 39.915 | 69.008 | 39.049 | 20.119 | 39.743 | 46.780 |
# [03/01 17:26:17 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Ulcer      | 18.616 | Polyp      | 48.375 | Cancer     | 52.755 |

# %%
# !pip -q install palettable
import palettable.colorbrewer.qualitative as pbq

plt.title('Bbox AP in Valid Dataset', size=10)
ax = plt.barh(y=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'],
        width=[result['bbox']['AP'], result['bbox']['AP50'], result['bbox']['AP75'], result['bbox']['APl'],
           result['bbox']['APm'], result['bbox']['APm'],], 
        color=pbq.Pastel1_7.hex_colors, edgecolor='white',
        label=['bbox-AP', 'bbox-AP50', 'bbox-AP75', 'bbox-APl', 'bbox-APm', 'bbox-APs'])

for rect in ax.patches:
    x = rect.get_width()
    y = rect.get_y() + rect.get_height()/2.0
    plt.text(x, y, f'{x:.2f}', ha='left', va='center', size=10, color='blue')

plt.legend()
plt.show()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 6.1 MB/s eta 0:00:00

# %%
plt.style.use('default')
plt.figure(figsize=(12,6))

plt.title('AP by Class', size=10)
ax = plt.bar(
    x=[f'AP-{col}' for col in thing_classes],
    height=[result['bbox'][f'AP-{col}'] for col in thing_classes],
    color=pbq.Pastel1_7.hex_colors,
    edgecolor='white',
    label=[f'bbox/AP-{col}' for col in thing_classes]
)

# 막대 위에 텍스트 추가
for rect in ax.patches:
    x = rect.get_x() + rect.get_width() / 2.0  # 막대 중앙 x좌표
    y = rect.get_height()  # 막대 길이
    plt.text(x, y, f'{y:.2f}', ha='center', va='bottom', size=10, color='gray')  # 텍스트 위치 조정


plt.legend()
plt.xticks(rotation=60)
plt.show()
