# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
import os
import torch

# %%
# def csv_to_coco(csv_path, meta_csv, output_json):
#     df = pd.read_csv(csv_path)
#     meta_df = pd.read_csv(meta_csv)
#     filtered_df = df[df["image_id"].isin(meta_df["image_id"])]

#     class_map = {"ulcer": 0, "polyp": 1, "cancer": 2}
#     coco_json = {"images": [], "annotations": [], "categories": []}

#     for class_name, class_id in class_map.items():
#         coco_json["categories"].append({"id": class_id, "name": class_name})

#     image_id_map = {}
#     annotation_id = 1

#     for _, row in filtered_df.iterrows():
#         image_id = row["image_id"]
#         image_name = row["image_id"]

#         if image_id not in image_id_map:
#             image_id_map[image_id] = image_name
#             coco_json["images"].append({
#                 "id": image_id,
#                 "width": row["width"],
#                 "height": row["height"],
#                 "file_name": image_name
#             })

#         x_min, y_min, x_max, y_max = row["x_min"], row["y_min"], row["x_max"], row["y_max"]
#         bbox = [x_min, y_min, x_max - x_min, y_max - y_min]

#         coco_json["annotations"].append({
#             "id": annotation_id,
#             "image_id": image_id,
#             "category_id": class_map[row["lesion"]],
#             "bbox": bbox,
#             "area": bbox[2] * bbox[3],
#             "iscrowd": 0
#         })
#         annotation_id += 1

#     with open(output_json, "w") as f:
#         json.dump(coco_json, f, indent=4)

#     print(f"COCO JSON saved: {output_json}")

# base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
# csv_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/resize_colonoscopy.csv"

# meta_paths = {
#     "train": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/train_meta.csv",
#     "val": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/val_meta.csv",
#     "test": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/test_meta.csv",
# }

# json_paths = {
#     "train": os.path.join(base_path, "Dataset", "train_coco.json"),
#     "val": os.path.join(base_path, "Dataset", "val_coco.json"),
#     "test": os.path.join(base_path, "Dataset", "test_coco.json"),
# }

# for split in ["train", "val", "test"]:
#     csv_to_coco(csv_path, meta_paths[split], json_paths[split])

# %%
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.4 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

def register_coco_dataset(name, json_file, image_root):
    DatasetCatalog.register(
        name,
        lambda: load_coco_json(json_file, image_root)
    )
    MetadataCatalog.get(name).set(thing_classes=["ulcer", "polyp","cancer"])

def load_coco_json(json_file, image_root):
    with open(json_file, "r") as f:
        coco_data = json.load(f)

    dataset_dicts = []
    for image_info in coco_data['images']:
        record = {}
        record['file_name'] = os.path.join(image_root, image_info['file_name'])
        record['image_id'] = image_info['id']
        record['height'] = image_info['height']
        record['width'] = image_info['width']

        annotations = []
        for ann in coco_data['annotations']:
            if ann['image_id'] == image_info['id']:
                annotations.append({
                    "bbox": ann['bbox'],
                    "bbox_mode": BoxMode.XYWH_ABS,
                    "category_id": ann['category_id']
                })

        record['annotations'] = annotations
        dataset_dicts.append(record)
    return dataset_dicts


image_folders = {
    "train": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/train",
    "val": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/val",
    "test": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/test"
}

base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
json_paths = {
    "train": os.path.join(base_path, "Dataset", "train_coco.json"),
    "val": os.path.join(base_path, "Dataset", "val_coco.json"),
    "test": os.path.join(base_path, "Dataset", "test_coco.json"),
}

for split in ["train", "val", "test"]:
    register_coco_dataset(f"colonoscopy_{split}", json_paths[split], image_folders[split])

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.4)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (3.11.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.evaluation import COCOEvaluator
from detectron2.data import build_detection_train_loader, build_detection_test_loader

# %%
# !wget -O /content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Out:
# --2025-02-19 05:29:12--  https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318 (1.3K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’
#
# /content/drive/MyDr 100%[===================>]   1.29K  --.-KB/s    in 0s
#
# 2025-02-19 05:29:12 (51.1 MB/s) - ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’ saved [1318/1318]

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog, DatasetMapper
from detectron2.data.transforms import (RandomFlip, RandomRotation, RandomContrast, RandomBrightness, RandomLighting)
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_train_loader, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator
from detectron2.config import get_cfg
import os
import cv2
import random
import numpy as np
from detectron2.data.transforms import Augmentation, Transform
from detectron2.data import detection_utils as utils
from detectron2.structures import BoxMode

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Error loading image: {image_path}")
    return image

class Mosaic:
    def __init__(self, prob=0.5, image_size=(640, 640)):
        self.prob = prob
        self.image_size = image_size

    def __call__(self, dataset_dicts):
        if random.random() >= self.prob:
            return dataset_dicts

        h, w = self.image_size
        mosaic_image = np.zeros((h, w, 3), dtype=np.uint8)
        mosaic_boxes = []
        mosaic_classes = []

        selected_samples = random.sample(dataset_dicts, 4)

        for i, sample in enumerate(selected_samples):
            image_path = sample["file_name"]
            image = load_image(image_path)
            height, width = image.shape[:2]

            x1 = random.randint(0, width // 2)
            y1 = random.randint(0, height // 2)
            x2 = random.randint(width // 2, width)
            y2 = random.randint(height // 2, height)
            cropped_image = image[y1:y2, x1:x2]

            pos_x, pos_y = (i % 2) * (w // 2), (i // 2) * (h // 2)
            resized_crop = cv2.resize(cropped_image, (w // 2, h // 2))
            mosaic_image[pos_y:pos_y + h // 2, pos_x:pos_x + w // 2] = resized_crop

            for ann in sample["annotations"]:
                bbox = ann["bbox"]
                bbox_mode = ann["bbox_mode"]
                bbox = BoxMode.convert(bbox, bbox_mode, BoxMode.XYXY_ABS)
                x_min, y_min, x_max, y_max = bbox

                if x1 < x_min < x2 and y1 < y_min < y2:
                    clipped_bbox = [
                        max(x_min - x1, 0) + pos_x,
                        max(y_min - y1, 0) + pos_y,
                        min(x_max - x1, x2 - x1) + pos_x,
                        min(y_max - y1, y2 - y1) + pos_y
                    ]
                    mosaic_boxes.append(clipped_bbox)
                    mosaic_classes.append(ann["category_id"])

        dataset_dicts[0]["image"] = mosaic_image
        dataset_dicts[0]["annotations"] = [
            {"bbox": bbox, "bbox_mode": BoxMode.XYXY_ABS, "category_id": cls}
            for bbox, cls in zip(mosaic_boxes, mosaic_classes)
        ]

        return dataset_dicts[0]

def adjust_augmentation(cfg, dataset_dicts):
    augmentations = [
        RandomFlip(prob=0.4, horizontal=True, vertical=False),
        RandomContrast(intensity_min=0.5, intensity_max=1.5),
        RandomBrightness(intensity_min=0.5, intensity_max=1.5),
        RandomLighting(scale=0.1),
        RandomRotation(angle=[-10, 10], expand=True),
        Mosaic(prob=0.2)
    ]
    mapper = DatasetMapper(cfg, is_train=True, augmentations=augmentations)
    return build_detection_train_loader(cfg, mapper=mapper)

# %%
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return adjust_augmentation(cfg)

    @classmethod
    def build_test_loader(cls, cfg, dataset_name):
        return build_detection_test_loader(cfg, dataset_name)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = cfg.OUTPUT_DIR
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

# %%
cfg = get_cfg()
cfg.merge_from_file("/content/drive/MyDrive/Endoscope Detection/colonoscopy/config.yaml")

cfg.OUTPUT_DIR = "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v4"
cfg.DATASETS.TRAIN = ("colonoscopy_train",)
cfg.DATASETS.TEST = ("colonoscopy_val",)

trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/21 06:38:52 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=81, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=320, bias=True)
#     )
#   )
# )
# [02/21 06:38:52 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [RandomFlip(prob=0.4), RandomContrast(intensity_min=0.5, intensity_max=1.5), RandomBrightness(intensity_min=0.5, intensity_max=1.5), RandomLighting(scale=0.1), RandomRotation(angle=[-10, 10])]
# [02/21 06:38:53 d2.data.build]: Removed 0 images with no usable annotations. 1277 images left.
# [02/21 06:38:53 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   ulcer    | 610          |   polyp    | 350          |   cancer   | 640          |
# |            |              |            |              |            |              |
# |   total    | 1600         |            |              |            |              |
# [02/21 06:38:53 d2.data.build]: Using training sampler TrainingSampler
# [02/21 06:38:53 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/21 06:38:53 d2.data.common]: Serializing 1277 elements to byte tensors and concatenating them all ...
# [02/21 06:38:53 d2.data.common]: Serialized dataset takes 0.40 MiB
# [02/21 06:38:53 d2.data.build]: Making batched data loader with batch_size=2
# WARNING [02/21 06:38:53 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [02/21 06:38:54 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/MSRA/R-50.pkl ...
# R-50.pkl: 102MB [00:00, 171MB/s]
# [02/21 06:38:55 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [02/21 06:38:55 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 54
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   fc1000.{bias, weight}
#   stem.conv1.bias
# [02/21 06:38:55 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/21 06:39:20 d2.utils.events]:  eta: 2:00:36  iter: 19  total_loss: 4.136  loss_cls: 3.398  loss_box_reg: 0.004827  loss_rpn_cls: 0.7165  loss_rpn_loc: 0.01047    time: 0.7395  last_time: 1.1287  data_time: 0.9575  last_data_time: 0.9780   lr: 4.9952e-05  max_mem: 746M
# [02/21 06:39:38 d2.utils.events]:  eta: 1:57:59  iter: 39  total_loss: 0.7647  loss_cls: 0.1091  loss_box_reg: 0.02416  loss_rpn_cls: 0.6196  loss_rpn_loc: 0.01236    time: 0.7334  last_time: 0.6894  data_time: 0.6112  last_data_time: 0.5882   lr: 9.9902e-05  max_mem: 746M
# [02/21 06:39:53 d2.utils.events]:  eta: 1:59:19  iter: 59  total_loss: 0.6497  loss_cls: 0.1818  loss_box_reg: 0.05428  loss_rpn_cls: 0.3922  loss_rpn_loc: 0.01365    time: 0.7432  last_time: 0.7817  data_time: 0.6507  last_data_time: 0.6337   lr: 0.00014985  max_mem: 746M
# [02/21 06:40:08 d2.utils.events]:  eta: 1:57:35  iter: 79  total_loss: 0.4485  loss_cls: 0.1912  loss_box_reg: 0.03668  loss_rpn_cls: 0.2055  loss_rpn_loc: 0.0156    time: 0.7381  last_time: 0.6621  data_time: 0.6142  last_data_time: 0.5586   lr: 0.0001998  max_mem: 746M
# [02/21 06:40:22 d2.utils.events]:  eta: 1:56:01  iter: 99  total_loss: 0.4113  loss_cls: 0.2159  loss_box_reg: 0.06315  loss_rpn_cls: 0.131  loss_rpn_loc: 0.01133    time: 0.7325  last_time: 0.7492  data_time: 0.6019  last_data_time: 0.6417   lr: 0.00024975  max_mem: 746M
# [02/21 06:40:36 d2.utils.events]:  eta: 1:55:34  iter: 119  total_loss: 0.3896  loss_cls: 0.1742  loss_box_reg: 0.0921  loss_rpn_cls: 0.09109  loss_rpn_loc: 0.01065    time: 0.7296  last_time: 0.9146  data_time: 0.6047  last_data_time: 0.8047   lr: 0.0002997  max_mem: 746M
# [02/21 06:40:51 d2.utils.events]:  eta: 1:55:53  iter: 139  total_loss: 0.3868  loss_cls: 0.1595  loss_box_reg: 0.09603  loss_rpn_cls: 0.07332  loss_rpn_loc: 0.01522    time: 0.7294  last_time: 0.7352  data_time: 0.6137  last_data_time: 0.6289   lr: 0.00034965  max_mem: 746M
# [02/21 06:41:05 d2.utils.events]:  eta: 1:55:19  iter: 159  total_loss: 0.3109  loss_cls: 0.1421  loss_box_reg: 0.08853  loss_rpn_cls: 0.06955  loss_rpn_loc: 0.00955    time: 0.7276  last_time: 0.6604  data_time: 0.5986  last_data_time: 0.5518   lr: 0.0003996  max_mem: 746M
# [02/21 06:41:20 d2.utils.events]:  eta: 1:54:30  iter: 179  total_loss: 0.2639  loss_cls: 0.1117  loss_box_reg: 0.07046  loss_rpn_cls: 0.04619  loss_rpn_loc: 0.008253    time: 0.7281  last_time: 0.7742  data_time: 0.6175  last_data_time: 0.6695   lr: 0.00044955  max_mem: 746M
# [02/21 06:41:35 d2.utils.events]:  eta: 1:54:16  iter: 199  total_loss: 0.3341  loss_cls: 0.1421  loss_box_reg: 0.1061  loss_rpn_cls: 0.05881  loss_rpn_loc: 0.01101    time: 0.7322  last_time: 0.7517  data_time: 0.6510  last_data_time: 0.6313   lr: 0.0004995  max_mem: 746M
# [02/21 06:41:50 d2.utils.events]:  eta: 1:53:55  iter: 219  total_loss: 0.2658  loss_cls: 0.1158  loss_box_reg: 0.0884  loss_rpn_cls: 0.04835  loss_rpn_loc: 0.01116    time: 0.7324  last_time: 0.6278  data_time: 0.6171  last_data_time: 0.5010   lr: 0.00054945  max_mem: 746M
# [02/21 06:42:05 d2.utils.events]:  eta: 1:53:48  iter: 239  total_loss: 0.3041  loss_cls: 0.1271  loss_box_reg: 0.1031  loss_rpn_cls: 0.05532  loss_rpn_loc: 0.0115    time: 0.7329  last_time: 0.7154  data_time: 0.6256  last_data_time: 0.6081   lr: 0.0005994  max_mem: 746M
# [02/21 06:42:18 d2.utils.events]:  eta: 1:53:22  iter: 259  total_loss: 0.234  loss_cls: 0.1075  loss_box_reg: 0.0846  loss_rpn_cls: 0.05132  loss_rpn_loc: 0.009423    time: 0.7295  last_time: 0.6700  data_time: 0.5698  last_data_time: 0.5582   lr: 0.00064935  max_mem: 746M
# [02/21 06:42:32 d2.utils.events]:  eta: 1:53:08  iter: 279  total_loss: 0.3154  loss_cls: 0.1291  loss_box_reg: 0.1079  loss_rpn_cls: 0.05456  loss_rpn_loc: 0.009218    time: 0.7277  last_time: 0.7200  data_time: 0.5862  last_data_time: 0.6161   lr: 0.0006993  max_mem: 746M
# [02/21 06:42:47 d2.utils.events]:  eta: 1:52:40  iter: 299  total_loss: 0.2606  loss_cls: 0.1109  loss_box_reg: 0.08505  loss_rpn_cls: 0.04459  loss_rpn_loc: 0.009246    time: 0.7288  last_time: 0.7700  data_time: 0.6278  last_data_time: 0.6636   lr: 0.00074925  max_mem: 746M
# [02/21 06:43:02 d2.utils.events]:  eta: 1:52:07  iter: 319  total_loss: 0.3101  loss_cls: 0.1278  loss_box_reg: 0.1068  loss_rpn_cls: 0.05506  loss_rpn_loc: 0.01122    time: 0.7286  last_time: 0.6999  data_time: 0.6102  last_data_time: 0.5939   lr: 0.0007992  max_mem: 746M
# [02/21 06:43:17 d2.utils.events]:  eta: 1:51:37  iter: 339  total_loss: 0.3025  loss_cls: 0.1346  loss_box_reg: 0.1135  loss_rpn_cls: 0.0479  loss_rpn_loc: 0.008723    time: 0.7304  last_time: 0.6571  data_time: 0.6414  last_data_time: 0.5536   lr: 0.00084915  max_mem: 746M
# [02/21 06:43:33 d2.utils.events]:  eta: 1:51:24  iter: 359  total_loss: 0.2625  loss_cls: 0.1217  loss_box_reg: 0.1013  loss_rpn_cls: 0.03358  loss_rpn_loc: 0.00803    time: 0.7342  last_time: 1.9491  data_time: 0.6792  last_data_time: 1.7746   lr: 0.0008991  max_mem: 746M
# [02/21 06:43:48 d2.utils.events]:  eta: 1:51:25  iter: 379  total_loss: 0.2776  loss_cls: 0.1251  loss_box_reg: 0.1129  loss_rpn_cls: 0.03476  loss_rpn_loc: 0.007652    time: 0.7358  last_time: 0.6424  data_time: 0.6499  last_data_time: 0.5271   lr: 0.00094905  max_mem: 746M
# [02/21 06:44:03 d2.utils.events]:  eta: 1:51:23  iter: 399  total_loss: 0.2993  loss_cls: 0.1442  loss_box_reg: 0.1173  loss_rpn_cls: 0.04028  loss_rpn_loc: 0.01217    time: 0.7351  last_time: 0.7075  data_time: 0.6066  last_data_time: 0.5871   lr: 0.000999  max_mem: 746M
# [02/21 06:44:18 d2.utils.events]:  eta: 1:51:10  iter: 419  total_loss: 0.2513  loss_cls: 0.1065  loss_box_reg: 0.09141  loss_rpn_cls: 0.03555  loss_rpn_loc: 0.0088    time: 0.7365  last_time: 0.6438  data_time: 0.6513  last_data_time: 0.5363   lr: 0.001049  max_mem: 746M
# [02/21 06:44:33 d2.utils.events]:  eta: 1:50:52  iter: 439  total_loss: 0.3022  loss_cls: 0.1452  loss_box_reg: 0.1202  loss_rpn_cls: 0.03877  loss_rpn_loc: 0.008684    time: 0.7360  last_time: 0.6530  data_time: 0.6129  last_data_time: 0.5361   lr: 0.0010989  max_mem: 746M
# [02/21 06:44:47 d2.utils.events]:  eta: 1:50:20  iter: 459  total_loss: 0.2972  loss_cls: 0.1213  loss_box_reg: 0.1063  loss_rpn_cls: 0.04895  loss_rpn_loc: 0.01276    time: 0.7346  last_time: 0.7107  data_time: 0.5909  last_data_time: 0.5993   lr: 0.0011489  max_mem: 746M
# [02/21 06:45:01 d2.utils.events]:  eta: 1:50:10  iter: 479  total_loss: 0.2591  loss_cls: 0.0972  loss_box_reg: 0.1158  loss_rpn_cls: 0.0438  loss_rpn_loc: 0.008693    time: 0.7340  last_time: 0.7179  data_time: 0.6101  last_data_time: 0.6109   lr: 0.0011988  max_mem: 746M
# [02/21 06:45:16 d2.utils.events]:  eta: 1:50:02  iter: 499  total_loss: 0.2681  loss_cls: 0.1197  loss_box_reg: 0.09471  loss_rpn_cls: 0.03764  loss_rpn_loc: 0.009681    time: 0.7342  last_time: 0.8228  data_time: 0.6282  last_data_time: 0.7208   lr: 0.0012488  max_mem: 746M
# [02/21 06:45:29 d2.utils.events]:  eta: 1:49:33  iter: 519  total_loss: 0.2685  loss_cls: 0.1108  loss_box_reg: 0.1091  loss_rpn_cls: 0.0315  loss_rpn_loc: 0.008015    time: 0.7320  last_time: 0.6522  data_time: 0.5650  last_data_time: 0.5452   lr: 0.0012987  max_mem: 746M
# [02/21 06:45:45 d2.utils.events]:  eta: 1:49:12  iter: 539  total_loss: 0.2431  loss_cls: 0.08756  loss_box_reg: 0.09699  loss_rpn_cls: 0.02716  loss_rpn_loc: 0.006192    time: 0.7329  last_time: 0.7613  data_time: 0.6361  last_data_time: 0.6417   lr: 0.0013487  max_mem: 746M
# [02/21 06:45:59 d2.utils.events]:  eta: 1:49:05  iter: 559  total_loss: 0.268  loss_cls: 0.1151  loss_box_reg: 0.1078  loss_rpn_cls: 0.02968  loss_rpn_loc: 0.008814    time: 0.7322  last_time: 0.6580  data_time: 0.5931  last_data_time: 0.5453   lr: 0.0013986  max_mem: 746M
# [02/21 06:46:14 d2.utils.events]:  eta: 1:48:57  iter: 579  total_loss: 0.2938  loss_cls: 0.1181  loss_box_reg: 0.1037  loss_rpn_cls: 0.04515  loss_rpn_loc: 0.009482    time: 0.7337  last_time: 0.6347  data_time: 0.6557  last_data_time: 0.5300   lr: 0.0014486  max_mem: 746M
# [02/21 06:46:30 d2.utils.events]:  eta: 1:48:42  iter: 599  total_loss: 0.2557  loss_cls: 0.1087  loss_box_reg: 0.1123  loss_rpn_cls: 0.02826  loss_rpn_loc: 0.01023    time: 0.7353  last_time: 0.5638  data_time: 0.6667  last_data_time: 0.4518   lr: 0.0014985  max_mem: 746M
# [02/21 06:46:45 d2.utils.events]:  eta: 1:48:10  iter: 619  total_loss: 0.2596  loss_cls: 0.1065  loss_box_reg: 0.1075  loss_rpn_cls: 0.02576  loss_rpn_loc: 0.00789    time: 0.7365  last_time: 0.6145  data_time: 0.6597  last_data_time: 0.4994   lr: 0.0015485  max_mem: 746M
# [02/21 06:46:59 d2.utils.events]:  eta: 1:47:49  iter: 639  total_loss: 0.2719  loss_cls: 0.1075  loss_box_reg: 0.1157  loss_rpn_cls: 0.03077  loss_rpn_loc: 0.008592    time: 0.7342  last_time: 0.1476  data_time: 0.5492  last_data_time: 0.0152   lr: 0.0015984  max_mem: 746M
# [02/21 06:47:01 d2.utils.events]:  eta: 1:46:54  iter: 659  total_loss: 0.2443  loss_cls: 0.09613  loss_box_reg: 0.1164  loss_rpn_cls: 0.03234  loss_rpn_loc: 0.01274    time: 0.7158  last_time: 0.1258  data_time: 0.0048  last_data_time: 0.0041   lr: 0.0016484  max_mem: 746M
# [02/21 06:47:04 d2.utils.events]:  eta: 1:46:10  iter: 679  total_loss: 0.2442  loss_cls: 0.1076  loss_box_reg: 0.09524  loss_rpn_cls: 0.03042  loss_rpn_loc: 0.007022    time: 0.6982  last_time: 0.1176  data_time: 0.0039  last_data_time: 0.0043   lr: 0.0016983  max_mem: 746M
# [02/21 06:47:06 d2.utils.events]:  eta: 1:45:33  iter: 699  total_loss: 0.2357  loss_cls: 0.09376  loss_box_reg: 0.1066  loss_rpn_cls: 0.02276  loss_rpn_loc: 0.009504    time: 0.6816  last_time: 0.1168  data_time: 0.0036  last_data_time: 0.0032   lr: 0.0017483  max_mem: 746M
# [02/21 06:47:08 d2.utils.events]:  eta: 1:44:59  iter: 719  total_loss: 0.268  loss_cls: 0.1149  loss_box_reg: 0.1153  loss_rpn_cls: 0.04191  loss_rpn_loc: 0.009596    time: 0.6660  last_time: 0.1160  data_time: 0.0036  last_data_time: 0.0036   lr: 0.0017982  max_mem: 746M
# [02/21 06:47:11 d2.utils.events]:  eta: 1:44:21  iter: 739  total_loss: 0.2444  loss_cls: 0.1063  loss_box_reg: 0.0986  loss_rpn_cls: 0.02449  loss_rpn_loc: 0.007118    time: 0.6515  last_time: 0.1494  data_time: 0.0067  last_data_time: 0.0055   lr: 0.0018482  max_mem: 746M
# [02/21 06:47:14 d2.utils.events]:  eta: 1:43:34  iter: 759  total_loss: 0.2454  loss_cls: 0.0945  loss_box_reg: 0.1068  loss_rpn_cls: 0.02962  loss_rpn_loc: 0.009459    time: 0.6380  last_time: 0.1181  data_time: 0.0128  last_data_time: 0.0043   lr: 0.0018981  max_mem: 746M
# [02/21 06:47:16 d2.utils.events]:  eta: 1:43:01  iter: 779  total_loss: 0.2386  loss_cls: 0.1027  loss_box_reg: 0.1075  loss_rpn_cls: 0.02806  loss_rpn_loc: 0.005794    time: 0.6248  last_time: 0.1280  data_time: 0.0040  last_data_time: 0.0036   lr: 0.0019481  max_mem: 746M
# [02/21 06:47:19 d2.utils.events]:  eta: 1:42:37  iter: 799  total_loss: 0.236  loss_cls: 0.1035  loss_box_reg: 0.09813  loss_rpn_cls: 0.02512  loss_rpn_loc: 0.008022    time: 0.6121  last_time: 0.1198  data_time: 0.0036  last_data_time: 0.0035   lr: 0.001998  max_mem: 746M
# [02/21 06:47:21 d2.utils.events]:  eta: 1:41:54  iter: 819  total_loss: 0.3027  loss_cls: 0.1413  loss_box_reg: 0.1194  loss_rpn_cls: 0.03429  loss_rpn_loc: 0.009199    time: 0.6001  last_time: 0.1283  data_time: 0.0040  last_data_time: 0.0036   lr: 0.002048  max_mem: 746M
# [02/21 06:47:24 d2.utils.events]:  eta: 1:41:13  iter: 839  total_loss: 0.2509  loss_cls: 0.11  loss_box_reg: 0.1034  loss_rpn_cls: 0.02458  loss_rpn_loc: 0.01003    time: 0.5889  last_time: 0.1350  data_time: 0.0042  last_data_time: 0.0036   lr: 0.0020979  max_mem: 746M
# [02/21 06:47:27 d2.utils.events]:  eta: 1:40:36  iter: 859  total_loss: 0.2134  loss_cls: 0.08306  loss_box_reg: 0.09879  loss_rpn_cls: 0.01865  loss_rpn_loc: 0.007399    time: 0.5786  last_time: 0.1244  data_time: 0.0112  last_data_time: 0.0040   lr: 0.0021479  max_mem: 746M
# [02/21 06:47:29 d2.utils.events]:  eta: 1:40:09  iter: 879  total_loss: 0.2269  loss_cls: 0.09096  loss_box_reg: 0.1064  loss_rpn_cls: 0.02168  loss_rpn_loc: 0.01163    time: 0.5681  last_time: 0.1177  data_time: 0.0038  last_data_time: 0.0038   lr: 0.0021978  max_mem: 746M
# [02/21 06:47:32 d2.utils.events]:  eta: 1:39:45  iter: 899  total_loss: 0.2577  loss_cls: 0.08726  loss_box_reg: 0.09151  loss_rpn_cls: 0.03596  loss_rpn_loc: 0.01075    time: 0.5581  last_time: 0.1198  data_time: 0.0038  last_data_time: 0.0035   lr: 0.0022478  max_mem: 746M
# [02/21 06:47:34 d2.utils.events]:  eta: 1:39:12  iter: 919  total_loss: 0.3065  loss_cls: 0.1211  loss_box_reg: 0.1023  loss_rpn_cls: 0.04384  loss_rpn_loc: 0.01066    time: 0.5486  last_time: 0.1188  data_time: 0.0045  last_data_time: 0.0035   lr: 0.0022977  max_mem: 746M
# [02/21 06:47:36 d2.utils.events]:  eta: 1:38:51  iter: 939  total_loss: 0.213  loss_cls: 0.1004  loss_box_reg: 0.09622  loss_rpn_cls: 0.01867  loss_rpn_loc: 0.00657    time: 0.5394  last_time: 0.1242  data_time: 0.0035  last_data_time: 0.0034   lr: 0.0023477  max_mem: 746M
# [02/21 06:47:39 d2.utils.events]:  eta: 1:38:19  iter: 959  total_loss: 0.2286  loss_cls: 0.09327  loss_box_reg: 0.1123  loss_rpn_cls: 0.01646  loss_rpn_loc: 0.007642    time: 0.5311  last_time: 0.1558  data_time: 0.0043  last_data_time: 0.0046   lr: 0.0023976  max_mem: 746M
# [02/21 06:47:42 d2.utils.events]:  eta: 1:37:49  iter: 979  total_loss: 0.2655  loss_cls: 0.1082  loss_box_reg: 0.1115  loss_rpn_cls: 0.01674  loss_rpn_loc: 0.009335    time: 0.5229  last_time: 0.1169  data_time: 0.0068  last_data_time: 0.0035   lr: 0.0024476  max_mem: 746M
# [02/21 06:47:44 d2.utils.events]:  eta: 1:37:16  iter: 999  total_loss: 0.282  loss_cls: 0.1222  loss_box_reg: 0.1212  loss_rpn_cls: 0.02084  loss_rpn_loc: 0.009036    time: 0.5148  last_time: 0.1199  data_time: 0.0040  last_data_time: 0.0041   lr: 0.0024975  max_mem: 746M
# [02/21 06:47:47 d2.utils.events]:  eta: 1:36:26  iter: 1019  total_loss: 0.2423  loss_cls: 0.1117  loss_box_reg: 0.112  loss_rpn_cls: 0.01659  loss_rpn_loc: 0.01041    time: 0.5072  last_time: 0.1229  data_time: 0.0044  last_data_time: 0.0056   lr: 0.0025  max_mem: 746M
# [02/21 06:47:49 d2.utils.events]:  eta: 1:35:39  iter: 1039  total_loss: 0.2449  loss_cls: 0.1046  loss_box_reg: 0.107  loss_rpn_cls: 0.02249  loss_rpn_loc: 0.007883    time: 0.4997  last_time: 0.1231  data_time: 0.0037  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:47:52 d2.utils.events]:  eta: 1:34:41  iter: 1059  total_loss: 0.2373  loss_cls: 0.09655  loss_box_reg: 0.1055  loss_rpn_cls: 0.02348  loss_rpn_loc: 0.009499    time: 0.4928  last_time: 0.1384  data_time: 0.0124  last_data_time: 0.0276   lr: 0.0025  max_mem: 746M
# [02/21 06:47:55 d2.utils.events]:  eta: 1:33:28  iter: 1079  total_loss: 0.2329  loss_cls: 0.1059  loss_box_reg: 0.09813  loss_rpn_cls: 0.02092  loss_rpn_loc: 0.008001    time: 0.4862  last_time: 0.1371  data_time: 0.0085  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:47:57 d2.utils.events]:  eta: 1:31:40  iter: 1099  total_loss: 0.2496  loss_cls: 0.1128  loss_box_reg: 0.1123  loss_rpn_cls: 0.02744  loss_rpn_loc: 0.008416    time: 0.4795  last_time: 0.1217  data_time: 0.0038  last_data_time: 0.0039   lr: 0.0025  max_mem: 746M
# [02/21 06:47:59 d2.utils.events]:  eta: 1:29:05  iter: 1119  total_loss: 0.2365  loss_cls: 0.09218  loss_box_reg: 0.1169  loss_rpn_cls: 0.01699  loss_rpn_loc: 0.008877    time: 0.4731  last_time: 0.1230  data_time: 0.0038  last_data_time: 0.0036   lr: 0.0025  max_mem: 746M
# [02/21 06:48:02 d2.utils.events]:  eta: 0:23:55  iter: 1139  total_loss: 0.2413  loss_cls: 0.09504  loss_box_reg: 0.1128  loss_rpn_cls: 0.02163  loss_rpn_loc: 0.007797    time: 0.4670  last_time: 0.1252  data_time: 0.0040  last_data_time: 0.0033   lr: 0.0025  max_mem: 746M
# [02/21 06:48:04 d2.utils.events]:  eta: 0:22:41  iter: 1159  total_loss: 0.2241  loss_cls: 0.09626  loss_box_reg: 0.1092  loss_rpn_cls: 0.02026  loss_rpn_loc: 0.007439    time: 0.4612  last_time: 0.1393  data_time: 0.0065  last_data_time: 0.0274   lr: 0.0025  max_mem: 746M
# [02/21 06:48:07 d2.utils.events]:  eta: 0:21:58  iter: 1179  total_loss: 0.2138  loss_cls: 0.08901  loss_box_reg: 0.09828  loss_rpn_cls: 0.01753  loss_rpn_loc: 0.005881    time: 0.4557  last_time: 0.1175  data_time: 0.0120  last_data_time: 0.0036   lr: 0.0025  max_mem: 746M
# [02/21 06:48:10 d2.utils.events]:  eta: 0:21:30  iter: 1199  total_loss: 0.2273  loss_cls: 0.09651  loss_box_reg: 0.1064  loss_rpn_cls: 0.02144  loss_rpn_loc: 0.007247    time: 0.4501  last_time: 0.1206  data_time: 0.0038  last_data_time: 0.0040   lr: 0.0025  max_mem: 746M
# [02/21 06:48:12 d2.utils.events]:  eta: 0:21:03  iter: 1219  total_loss: 0.2431  loss_cls: 0.0995  loss_box_reg: 0.1197  loss_rpn_cls: 0.01722  loss_rpn_loc: 0.008167    time: 0.4447  last_time: 0.1260  data_time: 0.0039  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:48:15 d2.utils.events]:  eta: 0:20:17  iter: 1239  total_loss: 0.2614  loss_cls: 0.1149  loss_box_reg: 0.1334  loss_rpn_cls: 0.01747  loss_rpn_loc: 0.009684    time: 0.4395  last_time: 0.1227  data_time: 0.0040  last_data_time: 0.0042   lr: 0.0025  max_mem: 746M
# [02/21 06:48:17 d2.utils.events]:  eta: 0:19:36  iter: 1259  total_loss: 0.2633  loss_cls: 0.1021  loss_box_reg: 0.1136  loss_rpn_cls: 0.01856  loss_rpn_loc: 0.008633    time: 0.4345  last_time: 0.1331  data_time: 0.0038  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:48:20 d2.utils.events]:  eta: 0:19:29  iter: 1279  total_loss: 0.2179  loss_cls: 0.09451  loss_box_reg: 0.09651  loss_rpn_cls: 0.02278  loss_rpn_loc: 0.00749    time: 0.4299  last_time: 0.1654  data_time: 0.0166  last_data_time: 0.0205   lr: 0.0025  max_mem: 746M
# [02/21 06:48:22 d2.utils.events]:  eta: 0:18:59  iter: 1299  total_loss: 0.2197  loss_cls: 0.09404  loss_box_reg: 0.09892  loss_rpn_cls: 0.02115  loss_rpn_loc: 0.007205    time: 0.4252  last_time: 0.1152  data_time: 0.0039  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:48:25 d2.utils.events]:  eta: 0:18:38  iter: 1319  total_loss: 0.2399  loss_cls: 0.1061  loss_box_reg: 0.1104  loss_rpn_cls: 0.01812  loss_rpn_loc: 0.006779    time: 0.4205  last_time: 0.1210  data_time: 0.0037  last_data_time: 0.0032   lr: 0.0025  max_mem: 746M
# [02/21 06:48:27 d2.utils.events]:  eta: 0:18:24  iter: 1339  total_loss: 0.2348  loss_cls: 0.1086  loss_box_reg: 0.1166  loss_rpn_cls: 0.01393  loss_rpn_loc: 0.008545    time: 0.4161  last_time: 0.1246  data_time: 0.0037  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:48:30 d2.utils.events]:  eta: 0:18:13  iter: 1359  total_loss: 0.25  loss_cls: 0.1061  loss_box_reg: 0.1177  loss_rpn_cls: 0.02364  loss_rpn_loc: 0.01019    time: 0.4117  last_time: 0.1292  data_time: 0.0040  last_data_time: 0.0109   lr: 0.0025  max_mem: 746M
# [02/21 06:48:32 d2.utils.events]:  eta: 0:18:09  iter: 1379  total_loss: 0.2353  loss_cls: 0.09281  loss_box_reg: 0.1063  loss_rpn_cls: 0.0252  loss_rpn_loc: 0.006021    time: 0.4078  last_time: 0.1425  data_time: 0.0063  last_data_time: 0.0049   lr: 0.0025  max_mem: 746M
# [02/21 06:48:35 d2.utils.events]:  eta: 0:17:59  iter: 1399  total_loss: 0.2243  loss_cls: 0.08989  loss_box_reg: 0.1129  loss_rpn_cls: 0.01717  loss_rpn_loc: 0.008799    time: 0.4038  last_time: 0.1209  data_time: 0.0047  last_data_time: 0.0047   lr: 0.0025  max_mem: 746M
# [02/21 06:48:37 d2.utils.events]:  eta: 0:17:47  iter: 1419  total_loss: 0.2546  loss_cls: 0.1102  loss_box_reg: 0.1064  loss_rpn_cls: 0.02202  loss_rpn_loc: 0.006861    time: 0.3998  last_time: 0.1202  data_time: 0.0039  last_data_time: 0.0036   lr: 0.0025  max_mem: 746M
# [02/21 06:48:40 d2.utils.events]:  eta: 0:17:39  iter: 1439  total_loss: 0.2327  loss_cls: 0.1014  loss_box_reg: 0.1004  loss_rpn_cls: 0.01519  loss_rpn_loc: 0.004462    time: 0.3959  last_time: 0.1220  data_time: 0.0036  last_data_time: 0.0033   lr: 0.0025  max_mem: 746M
# [02/21 06:48:42 d2.utils.events]:  eta: 0:17:34  iter: 1459  total_loss: 0.2893  loss_cls: 0.1051  loss_box_reg: 0.1398  loss_rpn_cls: 0.01763  loss_rpn_loc: 0.0108    time: 0.3922  last_time: 0.1191  data_time: 0.0037  last_data_time: 0.0039   lr: 0.0025  max_mem: 746M
# [02/21 06:48:45 d2.utils.events]:  eta: 0:17:31  iter: 1479  total_loss: 0.2293  loss_cls: 0.0928  loss_box_reg: 0.1035  loss_rpn_cls: 0.01229  loss_rpn_loc: 0.005917    time: 0.3887  last_time: 0.1461  data_time: 0.0052  last_data_time: 0.0037   lr: 0.0025  max_mem: 746M
# [02/21 06:48:48 d2.utils.events]:  eta: 0:17:27  iter: 1499  total_loss: 0.1995  loss_cls: 0.0863  loss_box_reg: 0.09744  loss_rpn_cls: 0.01427  loss_rpn_loc: 0.007931    time: 0.3854  last_time: 0.1328  data_time: 0.0103  last_data_time: 0.0065   lr: 0.0025  max_mem: 746M
# [02/21 06:48:50 d2.utils.events]:  eta: 0:17:22  iter: 1519  total_loss: 0.246  loss_cls: 0.12  loss_box_reg: 0.1108  loss_rpn_cls: 0.009952  loss_rpn_loc: 0.006618    time: 0.3819  last_time: 0.1154  data_time: 0.0037  last_data_time: 0.0032   lr: 0.0025  max_mem: 746M
# [02/21 06:48:53 d2.utils.events]:  eta: 0:17:17  iter: 1539  total_loss: 0.2101  loss_cls: 0.08621  loss_box_reg: 0.1159  loss_rpn_cls: 0.01662  loss_rpn_loc: 0.007506    time: 0.3785  last_time: 0.1213  data_time: 0.0036  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:48:55 d2.utils.events]:  eta: 0:17:13  iter: 1559  total_loss: 0.2549  loss_cls: 0.1088  loss_box_reg: 0.1364  loss_rpn_cls: 0.01026  loss_rpn_loc: 0.006556    time: 0.3752  last_time: 0.1165  data_time: 0.0037  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:48:58 d2.utils.events]:  eta: 0:17:10  iter: 1579  total_loss: 0.2023  loss_cls: 0.06952  loss_box_reg: 0.1169  loss_rpn_cls: 0.01002  loss_rpn_loc: 0.007637    time: 0.3720  last_time: 0.1358  data_time: 0.0043  last_data_time: 0.0044   lr: 0.0025  max_mem: 746M
# [02/21 06:49:01 d2.utils.events]:  eta: 0:17:07  iter: 1599  total_loss: 0.2518  loss_cls: 0.09458  loss_box_reg: 0.1269  loss_rpn_cls: 0.01561  loss_rpn_loc: 0.008914    time: 0.3692  last_time: 0.1207  data_time: 0.0138  last_data_time: 0.0046   lr: 0.0025  max_mem: 746M
# [02/21 06:49:03 d2.utils.events]:  eta: 0:17:02  iter: 1619  total_loss: 0.215  loss_cls: 0.093  loss_box_reg: 0.11  loss_rpn_cls: 0.0129  loss_rpn_loc: 0.005766    time: 0.3661  last_time: 0.1169  data_time: 0.0039  last_data_time: 0.0036   lr: 0.0025  max_mem: 746M
# [02/21 06:49:05 d2.utils.events]:  eta: 0:16:59  iter: 1639  total_loss: 0.2195  loss_cls: 0.08572  loss_box_reg: 0.1086  loss_rpn_cls: 0.0146  loss_rpn_loc: 0.006224    time: 0.3631  last_time: 0.1178  data_time: 0.0034  last_data_time: 0.0033   lr: 0.0025  max_mem: 746M
# [02/21 06:49:08 d2.utils.events]:  eta: 0:16:55  iter: 1659  total_loss: 0.2798  loss_cls: 0.1279  loss_box_reg: 0.1256  loss_rpn_cls: 0.02786  loss_rpn_loc: 0.00694    time: 0.3601  last_time: 0.1165  data_time: 0.0038  last_data_time: 0.0032   lr: 0.0025  max_mem: 746M
# [02/21 06:49:10 d2.utils.events]:  eta: 0:16:54  iter: 1679  total_loss: 0.278  loss_cls: 0.1153  loss_box_reg: 0.1331  loss_rpn_cls: 0.01862  loss_rpn_loc: 0.00598    time: 0.3573  last_time: 0.1290  data_time: 0.0037  last_data_time: 0.0033   lr: 0.0025  max_mem: 746M
# [02/21 06:49:13 d2.utils.events]:  eta: 0:16:53  iter: 1699  total_loss: 0.2359  loss_cls: 0.09414  loss_box_reg: 0.1103  loss_rpn_cls: 0.01749  loss_rpn_loc: 0.006206    time: 0.3548  last_time: 0.1460  data_time: 0.0133  last_data_time: 0.0049   lr: 0.0025  max_mem: 746M
# [02/21 06:49:16 d2.utils.events]:  eta: 0:16:51  iter: 1719  total_loss: 0.2565  loss_cls: 0.1092  loss_box_reg: 0.1274  loss_rpn_cls: 0.01344  loss_rpn_loc: 0.00866    time: 0.3521  last_time: 0.1352  data_time: 0.0040  last_data_time: 0.0041   lr: 0.0025  max_mem: 746M
# [02/21 06:49:18 d2.utils.events]:  eta: 0:16:47  iter: 1739  total_loss: 0.2194  loss_cls: 0.09862  loss_box_reg: 0.09957  loss_rpn_cls: 0.01548  loss_rpn_loc: 0.00642    time: 0.3495  last_time: 0.1178  data_time: 0.0040  last_data_time: 0.0036   lr: 0.0025  max_mem: 746M
# [02/21 06:49:20 d2.utils.events]:  eta: 0:16:44  iter: 1759  total_loss: 0.2335  loss_cls: 0.1102  loss_box_reg: 0.09745  loss_rpn_cls: 0.02173  loss_rpn_loc: 0.007309    time: 0.3469  last_time: 0.1208  data_time: 0.0037  last_data_time: 0.0039   lr: 0.0025  max_mem: 746M
# [02/21 06:49:23 d2.utils.events]:  eta: 0:16:42  iter: 1779  total_loss: 0.2371  loss_cls: 0.1186  loss_box_reg: 0.1247  loss_rpn_cls: 0.01649  loss_rpn_loc: 0.008003    time: 0.3444  last_time: 0.1154  data_time: 0.0039  last_data_time: 0.0035   lr: 0.0025  max_mem: 746M
# [02/21 06:49:26 d2.utils.events]:  eta: 0:16:40  iter: 1799  total_loss: 0.1995  loss_cls: 0.07838  loss_box_reg: 0.1043  loss_rpn_cls: 0.009005  loss_rpn_loc: 0.006461    time: 0.3420  last_time: 0.1377  data_time: 0.0059  last_data_time: 0.0103   lr: 0.0025  max_mem: 746M
# [02/21 06:49:28 d2.utils.events]:  eta: 0:16:38  iter: 1819  total_loss: 0.2221  loss_cls: 0.09728  loss_box_reg: 0.1117  loss_rpn_cls: 0.01395  loss_rpn_loc: 0.005123    time: 0.3397  last_time: 0.1182  data_time: 0.0055  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:49:31 d2.utils.events]:  eta: 0:16:35  iter: 1839  total_loss: 0.2146  loss_cls: 0.0773  loss_box_reg: 0.1068  loss_rpn_cls: 0.01188  loss_rpn_loc: 0.007027    time: 0.3373  last_time: 0.1171  data_time: 0.0037  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:49:33 d2.utils.events]:  eta: 0:16:31  iter: 1859  total_loss: 0.231  loss_cls: 0.09732  loss_box_reg: 0.1091  loss_rpn_cls: 0.01317  loss_rpn_loc: 0.006374    time: 0.3350  last_time: 0.1196  data_time: 0.0038  last_data_time: 0.0035   lr: 0.0025  max_mem: 746M
# [02/21 06:49:35 d2.utils.events]:  eta: 0:16:29  iter: 1879  total_loss: 0.2153  loss_cls: 0.08561  loss_box_reg: 0.09994  loss_rpn_cls: 0.01427  loss_rpn_loc: 0.006771    time: 0.3327  last_time: 0.1137  data_time: 0.0035  last_data_time: 0.0037   lr: 0.0025  max_mem: 746M
# [02/21 06:49:38 d2.utils.events]:  eta: 0:16:27  iter: 1899  total_loss: 0.237  loss_cls: 0.09775  loss_box_reg: 0.1073  loss_rpn_cls: 0.02263  loss_rpn_loc: 0.006039    time: 0.3305  last_time: 0.1336  data_time: 0.0081  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:49:41 d2.utils.events]:  eta: 0:16:26  iter: 1919  total_loss: 0.2242  loss_cls: 0.09109  loss_box_reg: 0.1032  loss_rpn_cls: 0.01452  loss_rpn_loc: 0.008767    time: 0.3285  last_time: 0.1270  data_time: 0.0100  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:49:43 d2.utils.events]:  eta: 0:16:24  iter: 1939  total_loss: 0.2241  loss_cls: 0.09813  loss_box_reg: 0.1053  loss_rpn_cls: 0.01083  loss_rpn_loc: 0.00577    time: 0.3264  last_time: 0.1274  data_time: 0.0037  last_data_time: 0.0033   lr: 0.0025  max_mem: 746M
# [02/21 06:49:46 d2.utils.events]:  eta: 0:16:20  iter: 1959  total_loss: 0.2212  loss_cls: 0.09282  loss_box_reg: 0.1125  loss_rpn_cls: 0.01235  loss_rpn_loc: 0.004806    time: 0.3243  last_time: 0.1252  data_time: 0.0038  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:49:48 d2.utils.events]:  eta: 0:16:17  iter: 1979  total_loss: 0.2212  loss_cls: 0.08713  loss_box_reg: 0.09745  loss_rpn_cls: 0.01359  loss_rpn_loc: 0.006565    time: 0.3222  last_time: 0.1186  data_time: 0.0037  last_data_time: 0.0033   lr: 0.0025  max_mem: 746M
# [02/21 06:49:50 d2.utils.events]:  eta: 0:16:14  iter: 1999  total_loss: 0.2013  loss_cls: 0.08752  loss_box_reg: 0.1009  loss_rpn_cls: 0.01418  loss_rpn_loc: 0.006919    time: 0.3202  last_time: 0.1536  data_time: 0.0050  last_data_time: 0.0301   lr: 0.0025  max_mem: 746M
# [02/21 06:49:53 d2.utils.events]:  eta: 0:16:12  iter: 2019  total_loss: 0.2379  loss_cls: 0.09617  loss_box_reg: 0.1076  loss_rpn_cls: 0.02199  loss_rpn_loc: 0.00665    time: 0.3184  last_time: 0.1429  data_time: 0.0151  last_data_time: 0.0163   lr: 0.0025  max_mem: 746M
# [02/21 06:49:56 d2.utils.events]:  eta: 0:16:10  iter: 2039  total_loss: 0.1855  loss_cls: 0.07407  loss_box_reg: 0.1042  loss_rpn_cls: 0.005922  loss_rpn_loc: 0.007229    time: 0.3165  last_time: 0.1195  data_time: 0.0042  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:49:58 d2.utils.events]:  eta: 0:16:07  iter: 2059  total_loss: 0.2368  loss_cls: 0.08718  loss_box_reg: 0.1189  loss_rpn_cls: 0.01217  loss_rpn_loc: 0.00706    time: 0.3146  last_time: 0.1174  data_time: 0.0037  last_data_time: 0.0037   lr: 0.0025  max_mem: 746M
# [02/21 06:50:01 d2.utils.events]:  eta: 0:16:03  iter: 2079  total_loss: 0.1803  loss_cls: 0.07917  loss_box_reg: 0.08265  loss_rpn_cls: 0.0186  loss_rpn_loc: 0.00652    time: 0.3127  last_time: 0.1174  data_time: 0.0037  last_data_time: 0.0035   lr: 0.0025  max_mem: 746M
# [02/21 06:50:03 d2.utils.events]:  eta: 0:16:00  iter: 2099  total_loss: 0.176  loss_cls: 0.06028  loss_box_reg: 0.1022  loss_rpn_cls: 0.005493  loss_rpn_loc: 0.004901    time: 0.3109  last_time: 0.1232  data_time: 0.0038  last_data_time: 0.0041   lr: 0.0025  max_mem: 746M
# [02/21 06:50:06 d2.utils.events]:  eta: 0:15:59  iter: 2119  total_loss: 0.2093  loss_cls: 0.08546  loss_box_reg: 0.107  loss_rpn_cls: 0.01533  loss_rpn_loc: 0.006771    time: 0.3093  last_time: 0.1454  data_time: 0.0126  last_data_time: 0.0086   lr: 0.0025  max_mem: 746M
# [02/21 06:50:08 d2.utils.events]:  eta: 0:15:57  iter: 2139  total_loss: 0.2127  loss_cls: 0.08449  loss_box_reg: 0.1071  loss_rpn_cls: 0.01447  loss_rpn_loc: 0.009927    time: 0.3076  last_time: 0.1234  data_time: 0.0042  last_data_time: 0.0042   lr: 0.0025  max_mem: 746M
# [02/21 06:50:11 d2.utils.events]:  eta: 0:15:53  iter: 2159  total_loss: 0.2057  loss_cls: 0.07573  loss_box_reg: 0.1139  loss_rpn_cls: 0.01352  loss_rpn_loc: 0.005355    time: 0.3058  last_time: 0.1139  data_time: 0.0037  last_data_time: 0.0034   lr: 0.0025  max_mem: 746M
# [02/21 06:50:13 d2.utils.events]:  eta: 0:15:49  iter: 2179  total_loss: 0.2982  loss_cls: 0.1014  loss_box_reg: 0.1074  loss_rpn_cls: 0.02279  loss_rpn_loc: 0.01034    time: 0.3041  last_time: 0.1330  data_time: 0.0037  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:50:16 d2.utils.events]:  eta: 0:15:46  iter: 2199  total_loss: 0.2164  loss_cls: 0.08525  loss_box_reg: 0.1119  loss_rpn_cls: 0.01582  loss_rpn_loc: 0.008462    time: 0.3024  last_time: 0.1170  data_time: 0.0037  last_data_time: 0.0035   lr: 0.0025  max_mem: 746M
# [02/21 06:50:18 d2.utils.events]:  eta: 0:15:44  iter: 2219  total_loss: 0.2668  loss_cls: 0.09628  loss_box_reg: 0.1029  loss_rpn_cls: 0.02109  loss_rpn_loc: 0.008139    time: 0.3009  last_time: 0.1415  data_time: 0.0073  last_data_time: 0.0265   lr: 0.0025  max_mem: 746M
# [02/21 06:50:21 d2.utils.events]:  eta: 0:15:43  iter: 2239  total_loss: 0.1917  loss_cls: 0.07231  loss_box_reg: 0.08792  loss_rpn_cls: 0.004415  loss_rpn_loc: 0.007839    time: 0.2994  last_time: 0.1298  data_time: 0.0059  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:50:23 d2.utils.events]:  eta: 0:15:41  iter: 2259  total_loss: 0.2019  loss_cls: 0.08493  loss_box_reg: 0.1001  loss_rpn_cls: 0.01588  loss_rpn_loc: 0.009741    time: 0.2978  last_time: 0.1166  data_time: 0.0040  last_data_time: 0.0053   lr: 0.0025  max_mem: 746M
# [02/21 06:50:26 d2.utils.events]:  eta: 0:15:37  iter: 2279  total_loss: 0.2146  loss_cls: 0.1034  loss_box_reg: 0.1075  loss_rpn_cls: 0.01085  loss_rpn_loc: 0.006419    time: 0.2963  last_time: 0.1223  data_time: 0.0039  last_data_time: 0.0039   lr: 0.0025  max_mem: 746M
# [02/21 06:50:28 d2.utils.events]:  eta: 0:15:35  iter: 2299  total_loss: 0.213  loss_cls: 0.09597  loss_box_reg: 0.1015  loss_rpn_cls: 0.01156  loss_rpn_loc: 0.006603    time: 0.2947  last_time: 0.1161  data_time: 0.0039  last_data_time: 0.0038   lr: 0.0025  max_mem: 746M
# [02/21 06:50:31 d2.utils.events]:  eta: 0:15:32  iter: 2319  total_loss: 0.188  loss_cls: 0.07129  loss_box_reg: 0.1023  loss_rpn_cls: 0.0136  loss_rpn_loc: 0.007495    time: 0.2932  last_time: 0.1446  data_time: 0.0057  last_data_time: 0.0191   lr: 0.0025  max_mem: 746M
# [02/21 06:50:33 d2.utils.events]:  eta: 0:15:31  iter: 2339  total_loss: 0.1797  loss_cls: 0.08211  loss_box_reg: 0.08406  loss_rpn_cls: 0.01415  loss_rpn_loc: 0.006438    time: 0.2920  last_time: 0.1456  data_time: 0.0088  last_data_time: 0.0042   lr: 0.0025  max_mem: 746M
# [02/21 06:50:36 d2.utils.events]:  eta: 0:15:28  iter: 2359  total_loss: 0.2294  loss_cls: 0.09243  loss_box_reg: 0.1119  loss_rpn_cls: 0.009058  loss_rpn_loc: 0.006611    time: 0.2905  last_time: 0.1232  data_time: 0.0042  last_data_time: 0.0040   lr: 0.0025  max_mem: 746M
# ...
# [02/21 07:06:41 d2.utils.events]:  eta: 0:01:38  iter: 9179  total_loss: 0.1431  loss_cls: 0.04177  loss_box_reg: 0.09562  loss_rpn_cls: 0.002526  loss_rpn_loc: 0.003834    time: 0.1668  last_time: 0.1189  data_time: 0.0044  last_data_time: 0.0036   lr: 0.0025  max_mem: 747M
# [02/21 07:06:44 d2.utils.events]:  eta: 0:01:36  iter: 9199  total_loss: 0.141  loss_cls: 0.05335  loss_box_reg: 0.08058  loss_rpn_cls: 0.002732  loss_rpn_loc: 0.003697    time: 0.1667  last_time: 0.1137  data_time: 0.0037  last_data_time: 0.0035   lr: 0.0025  max_mem: 747M
# [02/21 07:06:47 d2.utils.events]:  eta: 0:01:34  iter: 9219  total_loss: 0.1453  loss_cls: 0.04688  loss_box_reg: 0.0806  loss_rpn_cls: 0.005037  loss_rpn_loc: 0.005072    time: 0.1666  last_time: 0.1713  data_time: 0.0101  last_data_time: 0.0208   lr: 0.0025  max_mem: 747M
# [02/21 07:06:49 d2.utils.events]:  eta: 0:01:31  iter: 9239  total_loss: 0.1677  loss_cls: 0.05737  loss_box_reg: 0.09362  loss_rpn_cls: 0.004825  loss_rpn_loc: 0.006236    time: 0.1665  last_time: 0.1129  data_time: 0.0097  last_data_time: 0.0037   lr: 0.0025  max_mem: 747M
# [02/21 07:06:52 d2.utils.events]:  eta: 0:01:29  iter: 9259  total_loss: 0.1311  loss_cls: 0.04076  loss_box_reg: 0.07545  loss_rpn_cls: 0.007706  loss_rpn_loc: 0.006144    time: 0.1664  last_time: 0.1272  data_time: 0.0043  last_data_time: 0.0038   lr: 0.0025  max_mem: 747M
# [02/21 07:06:54 d2.utils.events]:  eta: 0:01:26  iter: 9279  total_loss: 0.1706  loss_cls: 0.05668  loss_box_reg: 0.09598  loss_rpn_cls: 0.004904  loss_rpn_loc: 0.006185    time: 0.1663  last_time: 0.1198  data_time: 0.0039  last_data_time: 0.0036   lr: 0.0025  max_mem: 747M
# [02/21 07:06:56 d2.utils.events]:  eta: 0:01:24  iter: 9299  total_loss: 0.148  loss_cls: 0.05632  loss_box_reg: 0.0726  loss_rpn_cls: 0.005766  loss_rpn_loc: 0.005116    time: 0.1662  last_time: 0.1221  data_time: 0.0038  last_data_time: 0.0037   lr: 0.0025  max_mem: 747M
# [02/21 07:06:59 d2.utils.events]:  eta: 0:01:21  iter: 9319  total_loss: 0.132  loss_cls: 0.03871  loss_box_reg: 0.08379  loss_rpn_cls: 0.002773  loss_rpn_loc: 0.005613    time: 0.1661  last_time: 0.1440  data_time: 0.0040  last_data_time: 0.0035   lr: 0.0025  max_mem: 747M
# [02/21 07:07:02 d2.utils.events]:  eta: 0:01:19  iter: 9339  total_loss: 0.1587  loss_cls: 0.05056  loss_box_reg: 0.08562  loss_rpn_cls: 0.003539  loss_rpn_loc: 0.004944    time: 0.1661  last_time: 0.1208  data_time: 0.0068  last_data_time: 0.0043   lr: 0.0025  max_mem: 747M
# [02/21 07:07:04 d2.utils.events]:  eta: 0:01:17  iter: 9359  total_loss: 0.19  loss_cls: 0.07189  loss_box_reg: 0.09673  loss_rpn_cls: 0.005225  loss_rpn_loc: 0.005193    time: 0.1660  last_time: 0.1293  data_time: 0.0041  last_data_time: 0.0037   lr: 0.0025  max_mem: 747M
# [02/21 07:07:07 d2.utils.events]:  eta: 0:01:14  iter: 9379  total_loss: 0.1319  loss_cls: 0.04328  loss_box_reg: 0.07724  loss_rpn_cls: 0.001735  loss_rpn_loc: 0.003329    time: 0.1659  last_time: 0.1220  data_time: 0.0039  last_data_time: 0.0038   lr: 0.0025  max_mem: 747M
# [02/21 07:07:09 d2.utils.events]:  eta: 0:01:12  iter: 9399  total_loss: 0.1515  loss_cls: 0.05491  loss_box_reg: 0.07857  loss_rpn_cls: 0.002789  loss_rpn_loc: 0.005819    time: 0.1658  last_time: 0.1216  data_time: 0.0039  last_data_time: 0.0043   lr: 0.0025  max_mem: 747M
# [02/21 07:07:11 d2.utils.events]:  eta: 0:01:09  iter: 9419  total_loss: 0.1492  loss_cls: 0.05592  loss_box_reg: 0.08524  loss_rpn_cls: 0.004234  loss_rpn_loc: 0.004793    time: 0.1657  last_time: 0.1280  data_time: 0.0039  last_data_time: 0.0040   lr: 0.0025  max_mem: 747M
# [02/21 07:07:14 d2.utils.events]:  eta: 0:01:07  iter: 9439  total_loss: 0.1786  loss_cls: 0.06225  loss_box_reg: 0.09205  loss_rpn_cls: 0.006379  loss_rpn_loc: 0.004953    time: 0.1656  last_time: 0.1371  data_time: 0.0100  last_data_time: 0.0046   lr: 0.0025  max_mem: 747M
# [02/21 07:07:17 d2.utils.events]:  eta: 0:01:05  iter: 9459  total_loss: 0.1345  loss_cls: 0.05155  loss_box_reg: 0.07189  loss_rpn_cls: 0.003675  loss_rpn_loc: 0.004638    time: 0.1655  last_time: 0.1170  data_time: 0.0046  last_data_time: 0.0037   lr: 0.0025  max_mem: 747M
# [02/21 07:07:19 d2.utils.events]:  eta: 0:01:02  iter: 9479  total_loss: 0.1558  loss_cls: 0.05608  loss_box_reg: 0.08636  loss_rpn_cls: 0.004016  loss_rpn_loc: 0.004728    time: 0.1654  last_time: 0.1164  data_time: 0.0039  last_data_time: 0.0041   lr: 0.0025  max_mem: 747M
# [02/21 07:07:21 d2.utils.events]:  eta: 0:01:00  iter: 9499  total_loss: 0.1255  loss_cls: 0.03845  loss_box_reg: 0.07524  loss_rpn_cls: 0.002104  loss_rpn_loc: 0.00395    time: 0.1654  last_time: 0.1179  data_time: 0.0039  last_data_time: 0.0039   lr: 0.0025  max_mem: 747M
# [02/21 07:07:24 d2.utils.events]:  eta: 0:00:57  iter: 9519  total_loss: 0.1685  loss_cls: 0.0631  loss_box_reg: 0.09596  loss_rpn_cls: 0.004573  loss_rpn_loc: 0.005607    time: 0.1652  last_time: 0.1179  data_time: 0.0047  last_data_time: 0.0036   lr: 0.0025  max_mem: 747M
# [02/21 07:07:27 d2.utils.events]:  eta: 0:00:55  iter: 9539  total_loss: 0.1331  loss_cls: 0.04088  loss_box_reg: 0.07938  loss_rpn_cls: 0.00462  loss_rpn_loc: 0.004241    time: 0.1652  last_time: 0.1537  data_time: 0.0085  last_data_time: 0.0270   lr: 0.0025  max_mem: 747M
# [02/21 07:07:29 d2.utils.events]:  eta: 0:00:53  iter: 9559  total_loss: 0.1739  loss_cls: 0.0633  loss_box_reg: 0.09478  loss_rpn_cls: 0.005694  loss_rpn_loc: 0.006215    time: 0.1651  last_time: 0.1195  data_time: 0.0088  last_data_time: 0.0038   lr: 0.0025  max_mem: 747M
# [02/21 07:07:32 d2.utils.events]:  eta: 0:00:50  iter: 9579  total_loss: 0.1406  loss_cls: 0.0518  loss_box_reg: 0.0788  loss_rpn_cls: 0.004591  loss_rpn_loc: 0.006364    time: 0.1650  last_time: 0.1171  data_time: 0.0037  last_data_time: 0.0032   lr: 0.0025  max_mem: 747M
# [02/21 07:07:34 d2.utils.events]:  eta: 0:00:48  iter: 9599  total_loss: 0.1378  loss_cls: 0.04929  loss_box_reg: 0.08117  loss_rpn_cls: 0.004736  loss_rpn_loc: 0.004296    time: 0.1649  last_time: 0.1162  data_time: 0.0040  last_data_time: 0.0034   lr: 0.0025  max_mem: 747M
# [02/21 07:07:36 d2.utils.events]:  eta: 0:00:45  iter: 9619  total_loss: 0.1422  loss_cls: 0.04307  loss_box_reg: 0.09036  loss_rpn_cls: 0.001369  loss_rpn_loc: 0.003556    time: 0.1648  last_time: 0.1166  data_time: 0.0039  last_data_time: 0.0039   lr: 0.0025  max_mem: 747M
# [02/21 07:07:39 d2.utils.events]:  eta: 0:00:43  iter: 9639  total_loss: 0.1586  loss_cls: 0.05406  loss_box_reg: 0.09586  loss_rpn_cls: 0.00564  loss_rpn_loc: 0.003965    time: 0.1648  last_time: 0.1358  data_time: 0.0066  last_data_time: 0.0067   lr: 0.0025  max_mem: 747M
# [02/21 07:07:42 d2.utils.events]:  eta: 0:00:41  iter: 9659  total_loss: 0.1651  loss_cls: 0.05281  loss_box_reg: 0.09412  loss_rpn_cls: 0.004224  loss_rpn_loc: 0.004308    time: 0.1647  last_time: 0.1159  data_time: 0.0091  last_data_time: 0.0040   lr: 0.0025  max_mem: 747M
# [02/21 07:07:44 d2.utils.events]:  eta: 0:00:38  iter: 9679  total_loss: 0.129  loss_cls: 0.04335  loss_box_reg: 0.07415  loss_rpn_cls: 0.002159  loss_rpn_loc: 0.004205    time: 0.1646  last_time: 0.1207  data_time: 0.0040  last_data_time: 0.0039   lr: 0.0025  max_mem: 747M
# [02/21 07:07:47 d2.utils.events]:  eta: 0:00:36  iter: 9699  total_loss: 0.1462  loss_cls: 0.04371  loss_box_reg: 0.08877  loss_rpn_cls: 0.001492  loss_rpn_loc: 0.002887    time: 0.1645  last_time: 0.1214  data_time: 0.0040  last_data_time: 0.0040   lr: 0.0025  max_mem: 747M
# [02/21 07:07:49 d2.utils.events]:  eta: 0:00:33  iter: 9719  total_loss: 0.1592  loss_cls: 0.05115  loss_box_reg: 0.09159  loss_rpn_cls: 0.002384  loss_rpn_loc: 0.005451    time: 0.1644  last_time: 0.1238  data_time: 0.0038  last_data_time: 0.0043   lr: 0.0025  max_mem: 747M
# [02/21 07:07:51 d2.utils.events]:  eta: 0:00:31  iter: 9739  total_loss: 0.1122  loss_cls: 0.04019  loss_box_reg: 0.06948  loss_rpn_cls: 0.001215  loss_rpn_loc: 0.005267    time: 0.1643  last_time: 0.1149  data_time: 0.0043  last_data_time: 0.0035   lr: 0.0025  max_mem: 747M
# [02/21 07:07:54 d2.utils.events]:  eta: 0:00:28  iter: 9759  total_loss: 0.1632  loss_cls: 0.06012  loss_box_reg: 0.09122  loss_rpn_cls: 0.005244  loss_rpn_loc: 0.005444    time: 0.1643  last_time: 0.1447  data_time: 0.0095  last_data_time: 0.0049   lr: 0.0025  max_mem: 747M
# [02/21 07:07:57 d2.utils.events]:  eta: 0:00:26  iter: 9779  total_loss: 0.1522  loss_cls: 0.04897  loss_box_reg: 0.08897  loss_rpn_cls: 0.004266  loss_rpn_loc: 0.004807    time: 0.1642  last_time: 0.1184  data_time: 0.0058  last_data_time: 0.0037   lr: 0.0025  max_mem: 747M
# [02/21 07:07:59 d2.utils.events]:  eta: 0:00:24  iter: 9799  total_loss: 0.1563  loss_cls: 0.0429  loss_box_reg: 0.1003  loss_rpn_cls: 0.005807  loss_rpn_loc: 0.006335    time: 0.1641  last_time: 0.1146  data_time: 0.0039  last_data_time: 0.0040   lr: 0.0025  max_mem: 747M
# [02/21 07:08:02 d2.utils.events]:  eta: 0:00:21  iter: 9819  total_loss: 0.1434  loss_cls: 0.04593  loss_box_reg: 0.09244  loss_rpn_cls: 0.003065  loss_rpn_loc: 0.004503    time: 0.1640  last_time: 0.1210  data_time: 0.0038  last_data_time: 0.0035   lr: 0.0025  max_mem: 747M
# [02/21 07:08:04 d2.utils.events]:  eta: 0:00:19  iter: 9839  total_loss: 0.1246  loss_cls: 0.04741  loss_box_reg: 0.07882  loss_rpn_cls: 0.001859  loss_rpn_loc: 0.004531    time: 0.1639  last_time: 0.1184  data_time: 0.0039  last_data_time: 0.0035   lr: 0.0025  max_mem: 747M
# [02/21 07:08:07 d2.utils.events]:  eta: 0:00:16  iter: 9859  total_loss: 0.1667  loss_cls: 0.05415  loss_box_reg: 0.09754  loss_rpn_cls: 0.006286  loss_rpn_loc: 0.004682    time: 0.1639  last_time: 0.1511  data_time: 0.0047  last_data_time: 0.0097   lr: 0.0025  max_mem: 747M
# [02/21 07:08:09 d2.utils.events]:  eta: 0:00:14  iter: 9879  total_loss: 0.1394  loss_cls: 0.04573  loss_box_reg: 0.09326  loss_rpn_cls: 0.002499  loss_rpn_loc: 0.004316    time: 0.1638  last_time: 0.1168  data_time: 0.0061  last_data_time: 0.0034   lr: 0.0025  max_mem: 747M
# [02/21 07:08:12 d2.utils.events]:  eta: 0:00:12  iter: 9899  total_loss: 0.1297  loss_cls: 0.05113  loss_box_reg: 0.07855  loss_rpn_cls: 0.003504  loss_rpn_loc: 0.006386    time: 0.1637  last_time: 0.1124  data_time: 0.0039  last_data_time: 0.0042   lr: 0.0025  max_mem: 747M
# [02/21 07:08:14 d2.utils.events]:  eta: 0:00:09  iter: 9919  total_loss: 0.1756  loss_cls: 0.05961  loss_box_reg: 0.1004  loss_rpn_cls: 0.003659  loss_rpn_loc: 0.005714    time: 0.1636  last_time: 0.1181  data_time: 0.0039  last_data_time: 0.0033   lr: 0.0025  max_mem: 747M
# [02/21 07:08:16 d2.utils.events]:  eta: 0:00:07  iter: 9939  total_loss: 0.1567  loss_cls: 0.05385  loss_box_reg: 0.09629  loss_rpn_cls: 0.007591  loss_rpn_loc: 0.006099    time: 0.1635  last_time: 0.1224  data_time: 0.0038  last_data_time: 0.0060   lr: 0.0025  max_mem: 747M
# [02/21 07:08:19 d2.utils.events]:  eta: 0:00:04  iter: 9959  total_loss: 0.1548  loss_cls: 0.05813  loss_box_reg: 0.09213  loss_rpn_cls: 0.004065  loss_rpn_loc: 0.004477    time: 0.1635  last_time: 0.1407  data_time: 0.0068  last_data_time: 0.0042   lr: 0.0025  max_mem: 747M
# [02/21 07:08:22 d2.utils.events]:  eta: 0:00:02  iter: 9979  total_loss: 0.1332  loss_cls: 0.04516  loss_box_reg: 0.08416  loss_rpn_cls: 0.003596  loss_rpn_loc: 0.005156    time: 0.1634  last_time: 0.1161  data_time: 0.0079  last_data_time: 0.0036   lr: 0.0025  max_mem: 747M
# [02/21 07:08:27 d2.utils.events]:  eta: 0:00:00  iter: 9999  total_loss: 0.123  loss_cls: 0.0368  loss_box_reg: 0.08102  loss_rpn_cls: 0.002012  loss_rpn_loc: 0.004407    time: 0.1633  last_time: 0.1206  data_time: 0.0043  last_data_time: 0.0038   lr: 0.0025  max_mem: 747M
# [02/21 07:08:27 d2.engine.hooks]: Overall training speed: 9998 iterations in 0:27:13 (0.1633 s / it)
# [02/21 07:08:27 d2.engine.hooks]: Total training time: 0:29:20 (0:02:07 on hooks)
# [02/21 07:08:27 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(256, 256), max_size=1333, sample_style='choice')]
# [02/21 07:08:27 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/21 07:08:27 d2.data.common]: Serializing 319 elements to byte tensors and concatenating them all ...
# [02/21 07:08:27 d2.data.common]: Serialized dataset takes 0.10 MiB
# WARNING [02/21 07:08:27 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [02/21 07:08:27 d2.evaluation.evaluator]: Start inference on 319 batches
# [02/21 07:08:28 d2.evaluation.evaluator]: Inference done 11/319. Dataloading: 0.0013 s/iter. Inference: 0.0427 s/iter. Eval: 0.0003 s/iter. Total: 0.0444 s/iter. ETA=0:00:13
# [02/21 07:08:33 d2.evaluation.evaluator]: Inference done 152/319. Dataloading: 0.0011 s/iter. Inference: 0.0346 s/iter. Eval: 0.0003 s/iter. Total: 0.0360 s/iter. ETA=0:00:06
# [02/21 07:08:38 d2.evaluation.evaluator]: Inference done 262/319. Dataloading: 0.0015 s/iter. Inference: 0.0382 s/iter. Eval: 0.0003 s/iter. Total: 0.0401 s/iter. ETA=0:00:02
# [02/21 07:08:40 d2.evaluation.evaluator]: Total inference time: 0:00:12.524388 (0.039887 s / iter per device, on 1 devices)
# [02/21 07:08:40 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:11 (0.037942 s / iter per device, on 1 devices)
# [02/21 07:08:40 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/21 07:08:40 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v4/coco_instances_results.json
# [02/21 07:08:40 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [02/21 07:08:40 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/21 07:08:40 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.05 seconds.
# [02/21 07:08:40 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/21 07:08:40 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.370
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.453
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.482
# [02/21 07:08:40 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 32.778 | 65.319 | 28.755 | 21.424 | 33.668 | 35.077 |
# [02/21 07:08:40 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | ulcer      | 12.437 | polyp      | 44.724 | cancer     | 41.174 |
# [02/21 07:08:40 d2.engine.defaults]: Evaluation results for colonoscopy_val in csv format:
# [02/21 07:08:40 d2.evaluation.testing]: copypaste: Task: bbox
# [02/21 07:08:40 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/21 07:08:40 d2.evaluation.testing]: copypaste: 32.7780,65.3193,28.7546,21.4241,33.6683,35.0772
