# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
import os
import torch

# %%
# def csv_to_coco(csv_path, meta_csv, output_json):
#     df = pd.read_csv(csv_path)
#     meta_df = pd.read_csv(meta_csv)
#     filtered_df = df[df["image_id"].isin(meta_df["image_id"])]

#     class_map = {"ulcer": 0, "polyp": 1, "cancer": 2}
#     coco_json = {"images": [], "annotations": [], "categories": []}

#     for class_name, class_id in class_map.items():
#         coco_json["categories"].append({"id": class_id, "name": class_name})

#     image_id_map = {}
#     annotation_id = 1

#     for _, row in filtered_df.iterrows():
#         image_id = row["image_id"]
#         image_name = row["image_id"]

#         if image_id not in image_id_map:
#             image_id_map[image_id] = image_name
#             coco_json["images"].append({
#                 "id": image_id,
#                 "width": row["width"],
#                 "height": row["height"],
#                 "file_name": image_name
#             })

#         x_min, y_min, x_max, y_max = row["x_min"], row["y_min"], row["x_max"], row["y_max"]
#         bbox = [x_min, y_min, x_max - x_min, y_max - y_min]

#         coco_json["annotations"].append({
#             "id": annotation_id,
#             "image_id": image_id,
#             "category_id": class_map[row["lesion"]],
#             "bbox": bbox,
#             "area": bbox[2] * bbox[3],
#             "iscrowd": 0
#         })
#         annotation_id += 1

#     with open(output_json, "w") as f:
#         json.dump(coco_json, f, indent=4)

#     print(f"COCO JSON saved: {output_json}")

# base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
# csv_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/resize_colonoscopy.csv"

# meta_paths = {
#     "train": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/train_meta.csv",
#     "val": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/val_meta.csv",
#     "test": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/test_meta.csv",
# }

# json_paths = {
#     "train": os.path.join(base_path, "Dataset", "train_coco.json"),
#     "val": os.path.join(base_path, "Dataset", "val_coco.json"),
#     "test": os.path.join(base_path, "Dataset", "test_coco.json"),
# }

# for split in ["train", "val", "test"]:
#     csv_to_coco(csv_path, meta_paths[split], json_paths[split])

# %%
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.1 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

def register_coco_dataset(name, json_file, image_root):
    DatasetCatalog.register(
        name,
        lambda: load_coco_json(json_file, image_root)
    )
    MetadataCatalog.get(name).set(thing_classes=["ulcer", "polyp","cancer"])

def load_coco_json(json_file, image_root):
    with open(json_file, "r") as f:
        coco_data = json.load(f)

    dataset_dicts = []
    for image_info in coco_data['images']:
        record = {}
        record['file_name'] = os.path.join(image_root, image_info['file_name'])
        record['image_id'] = image_info['id']
        record['height'] = image_info['height']
        record['width'] = image_info['width']

        annotations = []
        for ann in coco_data['annotations']:
            if ann['image_id'] == image_info['id']:
                annotations.append({
                    "bbox": ann['bbox'],
                    "bbox_mode": BoxMode.XYWH_ABS,
                    "category_id": ann['category_id']
                })

        record['annotations'] = annotations
        dataset_dicts.append(record)
    return dataset_dicts


image_folders = {
    "train": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/train",
    "val": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/val",
    "test": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/test"
}

base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
json_paths = {
    "train": os.path.join(base_path, "Dataset", "train_coco.json"),
    "val": os.path.join(base_path, "Dataset", "val_coco.json"),
    "test": os.path.join(base_path, "Dataset", "test_coco.json"),
}

for split in ["train", "val", "test"]:
    register_coco_dataset(f"colonoscopy_{split}", json_paths[split], image_folders[split])

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.4)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (3.11.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.evaluation import COCOEvaluator
from detectron2.data import build_detection_train_loader, build_detection_test_loader

# %%
# !wget -O /content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Out:
# --2025-02-19 05:29:12--  https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318 (1.3K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’
#
# /content/drive/MyDr 100%[===================>]   1.29K  --.-KB/s    in 0s
#
# 2025-02-19 05:29:12 (51.1 MB/s) - ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’ saved [1318/1318]

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog, DatasetMapper
from detectron2.data.transforms import (RandomFlip, RandomRotation, RandomContrast, RandomBrightness, RandomLighting)
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_train_loader, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator
from detectron2.config import get_cfg
import os
import cv2
import random
import numpy as np
from detectron2.data.transforms import Augmentation, Transform
from detectron2.data import detection_utils as utils
from detectron2.structures import BoxMode

# %%
class MosaicTransform(Transform):
    def __init__(self, image_size):
        self.image_size = image_size

    def apply_image(self, img):
        return img

    def apply_coords(self, coords):
        return coords

class Mosaic(Augmentation):
    def __init__(self, prob=0.5, image_size=(640, 640)):
        super().__init__()
        self.prob = prob
        self.image_size = image_size

    def get_transform(self, image):
        return MosaicTransform(self.image_size)

def adjust_augmentation(cfg):
    augmentations = [
        RandomFlip(prob=0.4, horizontal=True, vertical=False),
        RandomContrast(intensity_min=0.8, intensity_max=1.2),
        RandomBrightness(intensity_min=0.5, intensity_max=1.5),
        RandomLighting(scale=0.1),
        RandomRotation(angle=[-10, 10], expand=True),
        Mosaic(prob=0.2)
    ]

    mapper = DatasetMapper(cfg, is_train=True, augmentations=augmentations)
    return build_detection_train_loader(cfg, mapper=mapper)

# %%
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return adjust_augmentation(cfg)

    @classmethod
    def build_test_loader(cls, cfg, dataset_name):
        return build_detection_test_loader(cfg, dataset_name)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = cfg.OUTPUT_DIR
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

# %%
cfg = get_cfg()
cfg.merge_from_file("/content/drive/MyDrive/Endoscope Detection/colonoscopy/config.yaml")

cfg.OUTPUT_DIR = "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v3-2"
cfg.DATASETS.TRAIN = ("colonoscopy_train",)
cfg.DATASETS.TEST = ("colonoscopy_val",)

trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/20 15:59:40 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=81, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=320, bias=True)
#     )
#   )
# )
# [02/20 15:59:40 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [RandomFlip(prob=0.4), RandomContrast(intensity_min=0.8, intensity_max=1.2), RandomBrightness(intensity_min=0.5, intensity_max=1.5), RandomLighting(scale=0.1), RandomRotation(angle=[-10, 10]), Mosaic(prob=0.2)]
# [02/20 15:59:40 d2.data.build]: Removed 0 images with no usable annotations. 1277 images left.
# [02/20 15:59:40 d2.data.build]: Using training sampler TrainingSampler
# [02/20 15:59:40 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 15:59:40 d2.data.common]: Serializing 1277 elements to byte tensors and concatenating them all ...
# [02/20 15:59:40 d2.data.common]: Serialized dataset takes 0.40 MiB
# [02/20 15:59:40 d2.data.build]: Making batched data loader with batch_size=2
# WARNING [02/20 15:59:40 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [02/20 15:59:40 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/MSRA/R-50.pkl ...
# R-50.pkl: 102MB [00:00, 137MB/s]
# [02/20 15:59:41 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [02/20 15:59:41 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 54
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   fc1000.{bias, weight}
#   stem.conv1.bias
# [02/20 15:59:41 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/20 15:59:58 d2.utils.events]:  eta: 1:08:19  iter: 19  total_loss: 4.305  loss_cls: 3.589  loss_box_reg: 0.0163  loss_rpn_cls: 0.6784  loss_rpn_loc: 0.01112    time: 0.4091  last_time: 0.3940  data_time: 0.5633  last_data_time: 0.2975   lr: 4.9952e-05  max_mem: 906M
# [02/20 16:00:12 d2.utils.events]:  eta: 1:11:49  iter: 39  total_loss: 0.802  loss_cls: 0.157  loss_box_reg: 0.03484  loss_rpn_cls: 0.5815  loss_rpn_loc: 0.01136    time: 0.4518  last_time: 0.4933  data_time: 0.3674  last_data_time: 0.3891   lr: 9.9902e-05  max_mem: 906M
# [02/20 16:00:22 d2.utils.events]:  eta: 1:12:56  iter: 59  total_loss: 0.6362  loss_cls: 0.1782  loss_box_reg: 0.03515  loss_rpn_cls: 0.3678  loss_rpn_loc: 0.01286    time: 0.4737  last_time: 0.7355  data_time: 0.3921  last_data_time: 0.6259   lr: 0.00014985  max_mem: 906M
# [02/20 16:00:31 d2.utils.events]:  eta: 1:10:38  iter: 79  total_loss: 0.4305  loss_cls: 0.1755  loss_box_reg: 0.04807  loss_rpn_cls: 0.2054  loss_rpn_loc: 0.01146    time: 0.4679  last_time: 0.4030  data_time: 0.3374  last_data_time: 0.2959   lr: 0.0001998  max_mem: 906M
# [02/20 16:00:40 d2.utils.events]:  eta: 1:09:19  iter: 99  total_loss: 0.4058  loss_cls: 0.184  loss_box_reg: 0.06844  loss_rpn_cls: 0.1326  loss_rpn_loc: 0.01408    time: 0.4617  last_time: 0.4918  data_time: 0.3293  last_data_time: 0.3857   lr: 0.00024975  max_mem: 906M
# [02/20 16:00:51 d2.utils.events]:  eta: 1:10:05  iter: 119  total_loss: 0.3322  loss_cls: 0.1482  loss_box_reg: 0.07276  loss_rpn_cls: 0.09489  loss_rpn_loc: 0.0117    time: 0.4814  last_time: 0.3704  data_time: 0.4588  last_data_time: 0.2596   lr: 0.0002997  max_mem: 906M
# [02/20 16:01:00 d2.utils.events]:  eta: 1:09:29  iter: 139  total_loss: 0.3899  loss_cls: 0.1674  loss_box_reg: 0.1017  loss_rpn_cls: 0.07615  loss_rpn_loc: 0.01135    time: 0.4773  last_time: 0.4006  data_time: 0.3350  last_data_time: 0.2938   lr: 0.00034965  max_mem: 906M
# [02/20 16:01:11 d2.utils.events]:  eta: 1:10:47  iter: 159  total_loss: 0.3009  loss_cls: 0.131  loss_box_reg: 0.08797  loss_rpn_cls: 0.06681  loss_rpn_loc: 0.01134    time: 0.4860  last_time: 0.4439  data_time: 0.4286  last_data_time: 0.3315   lr: 0.0003996  max_mem: 906M
# [02/20 16:01:21 d2.utils.events]:  eta: 1:11:11  iter: 179  total_loss: 0.2554  loss_cls: 0.1138  loss_box_reg: 0.066  loss_rpn_cls: 0.06305  loss_rpn_loc: 0.01087    time: 0.4832  last_time: 0.3122  data_time: 0.3456  last_data_time: 0.2036   lr: 0.00044955  max_mem: 906M
# [02/20 16:01:29 d2.utils.events]:  eta: 1:11:27  iter: 199  total_loss: 0.3212  loss_cls: 0.1416  loss_box_reg: 0.1099  loss_rpn_cls: 0.06028  loss_rpn_loc: 0.01157    time: 0.4780  last_time: 0.4726  data_time: 0.3145  last_data_time: 0.3512   lr: 0.0004995  max_mem: 906M
# [02/20 16:01:38 d2.utils.events]:  eta: 1:10:52  iter: 219  total_loss: 0.2627  loss_cls: 0.1092  loss_box_reg: 0.08637  loss_rpn_cls: 0.04058  loss_rpn_loc: 0.007902    time: 0.4765  last_time: 0.3688  data_time: 0.3456  last_data_time: 0.2613   lr: 0.00054945  max_mem: 906M
# [02/20 16:01:48 d2.utils.events]:  eta: 1:10:12  iter: 239  total_loss: 0.3107  loss_cls: 0.1362  loss_box_reg: 0.09117  loss_rpn_cls: 0.06129  loss_rpn_loc: 0.01191    time: 0.4748  last_time: 0.5154  data_time: 0.3411  last_data_time: 0.4006   lr: 0.0005994  max_mem: 906M
# [02/20 16:01:57 d2.utils.events]:  eta: 1:09:41  iter: 259  total_loss: 0.2487  loss_cls: 0.1054  loss_box_reg: 0.07975  loss_rpn_cls: 0.05317  loss_rpn_loc: 0.008921    time: 0.4740  last_time: 0.2865  data_time: 0.3349  last_data_time: 0.1052   lr: 0.00064935  max_mem: 906M
# [02/20 16:02:05 d2.utils.events]:  eta: 1:09:09  iter: 279  total_loss: 0.2781  loss_cls: 0.1087  loss_box_reg: 0.09503  loss_rpn_cls: 0.04678  loss_rpn_loc: 0.009024    time: 0.4696  last_time: 0.3672  data_time: 0.3048  last_data_time: 0.2560   lr: 0.0006993  max_mem: 906M
# [02/20 16:02:14 d2.utils.events]:  eta: 1:08:51  iter: 299  total_loss: 0.2914  loss_cls: 0.1186  loss_box_reg: 0.1045  loss_rpn_cls: 0.04452  loss_rpn_loc: 0.008775    time: 0.4695  last_time: 0.4907  data_time: 0.3473  last_data_time: 0.3727   lr: 0.00074925  max_mem: 906M
# [02/20 16:02:24 d2.utils.events]:  eta: 1:09:05  iter: 319  total_loss: 0.3171  loss_cls: 0.1274  loss_box_reg: 0.09622  loss_rpn_cls: 0.06258  loss_rpn_loc: 0.01243    time: 0.4685  last_time: 0.3109  data_time: 0.3358  last_data_time: 0.2015   lr: 0.0007992  max_mem: 906M
# [02/20 16:02:32 d2.utils.events]:  eta: 1:08:30  iter: 339  total_loss: 0.2955  loss_cls: 0.1381  loss_box_reg: 0.1187  loss_rpn_cls: 0.04677  loss_rpn_loc: 0.009276    time: 0.4657  last_time: 0.3787  data_time: 0.2953  last_data_time: 0.2552   lr: 0.00084915  max_mem: 906M
# [02/20 16:02:41 d2.utils.events]:  eta: 1:08:21  iter: 359  total_loss: 0.2838  loss_cls: 0.1254  loss_box_reg: 0.1033  loss_rpn_cls: 0.03663  loss_rpn_loc: 0.007892    time: 0.4649  last_time: 0.4486  data_time: 0.3350  last_data_time: 0.3348   lr: 0.0008991  max_mem: 906M
# [02/20 16:02:50 d2.utils.events]:  eta: 1:08:13  iter: 379  total_loss: 0.2738  loss_cls: 0.1248  loss_box_reg: 0.1083  loss_rpn_cls: 0.03793  loss_rpn_loc: 0.008853    time: 0.4642  last_time: 0.4217  data_time: 0.3316  last_data_time: 0.3129   lr: 0.00094905  max_mem: 906M
# [02/20 16:02:59 d2.utils.events]:  eta: 1:07:53  iter: 399  total_loss: 0.3082  loss_cls: 0.1386  loss_box_reg: 0.1124  loss_rpn_cls: 0.04385  loss_rpn_loc: 0.01095    time: 0.4629  last_time: 0.6505  data_time: 0.3204  last_data_time: 0.5300   lr: 0.000999  max_mem: 906M
# [02/20 16:03:07 d2.utils.events]:  eta: 1:07:37  iter: 419  total_loss: 0.2695  loss_cls: 0.1158  loss_box_reg: 0.1101  loss_rpn_cls: 0.03779  loss_rpn_loc: 0.01071    time: 0.4606  last_time: 0.4995  data_time: 0.2958  last_data_time: 0.3809   lr: 0.001049  max_mem: 906M
# [02/20 16:03:16 d2.utils.events]:  eta: 1:07:25  iter: 439  total_loss: 0.3153  loss_cls: 0.1457  loss_box_reg: 0.1181  loss_rpn_cls: 0.03656  loss_rpn_loc: 0.008499    time: 0.4592  last_time: 0.8295  data_time: 0.3098  last_data_time: 0.7107   lr: 0.0010989  max_mem: 906M
# [02/20 16:03:25 d2.utils.events]:  eta: 1:07:25  iter: 459  total_loss: 0.301  loss_cls: 0.1204  loss_box_reg: 0.1043  loss_rpn_cls: 0.04793  loss_rpn_loc: 0.01015    time: 0.4588  last_time: 0.4742  data_time: 0.3302  last_data_time: 0.3651   lr: 0.0011489  max_mem: 906M
# [02/20 16:03:34 d2.utils.events]:  eta: 1:07:24  iter: 479  total_loss: 0.3198  loss_cls: 0.1342  loss_box_reg: 0.1201  loss_rpn_cls: 0.04327  loss_rpn_loc: 0.01107    time: 0.4599  last_time: 0.3629  data_time: 0.3664  last_data_time: 0.2253   lr: 0.0011988  max_mem: 906M
# [02/20 16:03:43 d2.utils.events]:  eta: 1:07:01  iter: 499  total_loss: 0.2885  loss_cls: 0.1299  loss_box_reg: 0.1186  loss_rpn_cls: 0.03981  loss_rpn_loc: 0.009054    time: 0.4583  last_time: 0.4937  data_time: 0.3047  last_data_time: 0.3845   lr: 0.0012488  max_mem: 906M
# [02/20 16:03:51 d2.utils.events]:  eta: 1:07:03  iter: 519  total_loss: 0.2606  loss_cls: 0.116  loss_box_reg: 0.09565  loss_rpn_cls: 0.03404  loss_rpn_loc: 0.006637    time: 0.4572  last_time: 0.3576  data_time: 0.3129  last_data_time: 0.2401   lr: 0.0012987  max_mem: 906M
# [02/20 16:04:00 d2.utils.events]:  eta: 1:07:05  iter: 539  total_loss: 0.2366  loss_cls: 0.09868  loss_box_reg: 0.09493  loss_rpn_cls: 0.02454  loss_rpn_loc: 0.007845    time: 0.4569  last_time: 0.5345  data_time: 0.3282  last_data_time: 0.2944   lr: 0.0013487  max_mem: 906M
# [02/20 16:04:09 d2.utils.events]:  eta: 1:06:42  iter: 559  total_loss: 0.2727  loss_cls: 0.1185  loss_box_reg: 0.09849  loss_rpn_cls: 0.0364  loss_rpn_loc: 0.008802    time: 0.4553  last_time: 0.4840  data_time: 0.3001  last_data_time: 0.3762   lr: 0.0013986  max_mem: 906M
# [02/20 16:04:18 d2.utils.events]:  eta: 1:06:48  iter: 579  total_loss: 0.302  loss_cls: 0.1304  loss_box_reg: 0.1099  loss_rpn_cls: 0.04059  loss_rpn_loc: 0.008714    time: 0.4563  last_time: 0.5181  data_time: 0.3358  last_data_time: 0.4059   lr: 0.0014486  max_mem: 906M
# [02/20 16:04:32 d2.utils.events]:  eta: 1:06:43  iter: 599  total_loss: 0.2718  loss_cls: 0.1144  loss_box_reg: 0.1099  loss_rpn_cls: 0.0291  loss_rpn_loc: 0.008338    time: 0.4633  last_time: 0.4035  data_time: 0.5427  last_data_time: 0.2961   lr: 0.0014985  max_mem: 906M
# [02/20 16:04:40 d2.utils.events]:  eta: 1:06:31  iter: 619  total_loss: 0.2499  loss_cls: 0.111  loss_box_reg: 0.1227  loss_rpn_cls: 0.02794  loss_rpn_loc: 0.009141    time: 0.4621  last_time: 0.4773  data_time: 0.3074  last_data_time: 0.3598   lr: 0.0015485  max_mem: 906M
# [02/20 16:04:49 d2.utils.events]:  eta: 1:06:31  iter: 639  total_loss: 0.264  loss_cls: 0.1076  loss_box_reg: 0.1077  loss_rpn_cls: 0.03257  loss_rpn_loc: 0.01073    time: 0.4614  last_time: 0.1431  data_time: 0.3198  last_data_time: 0.0064   lr: 0.0015984  max_mem: 906M
# [02/20 16:04:52 d2.utils.events]:  eta: 1:05:40  iter: 659  total_loss: 0.2549  loss_cls: 0.1074  loss_box_reg: 0.115  loss_rpn_cls: 0.03048  loss_rpn_loc: 0.0106    time: 0.4514  last_time: 0.1204  data_time: 0.0048  last_data_time: 0.0035   lr: 0.0016484  max_mem: 906M
# [02/20 16:04:54 d2.utils.events]:  eta: 1:04:58  iter: 679  total_loss: 0.2775  loss_cls: 0.1295  loss_box_reg: 0.115  loss_rpn_cls: 0.0285  loss_rpn_loc: 0.008431    time: 0.4419  last_time: 0.1330  data_time: 0.0040  last_data_time: 0.0040   lr: 0.0016983  max_mem: 906M
# [02/20 16:04:57 d2.utils.events]:  eta: 1:04:15  iter: 699  total_loss: 0.2575  loss_cls: 0.114  loss_box_reg: 0.113  loss_rpn_cls: 0.02536  loss_rpn_loc: 0.007524    time: 0.4330  last_time: 0.1328  data_time: 0.0038  last_data_time: 0.0037   lr: 0.0017483  max_mem: 906M
# [02/20 16:04:59 d2.utils.events]:  eta: 1:03:27  iter: 719  total_loss: 0.2641  loss_cls: 0.1088  loss_box_reg: 0.1114  loss_rpn_cls: 0.03721  loss_rpn_loc: 0.009262    time: 0.4245  last_time: 0.1309  data_time: 0.0040  last_data_time: 0.0042   lr: 0.0017982  max_mem: 906M
# [02/20 16:05:03 d2.utils.events]:  eta: 1:02:51  iter: 739  total_loss: 0.2541  loss_cls: 0.1203  loss_box_reg: 0.1076  loss_rpn_cls: 0.01813  loss_rpn_loc: 0.006178    time: 0.4172  last_time: 0.1542  data_time: 0.0103  last_data_time: 0.0071   lr: 0.0018482  max_mem: 906M
# [02/20 16:05:05 d2.utils.events]:  eta: 1:02:10  iter: 759  total_loss: 0.2301  loss_cls: 0.08839  loss_box_reg: 0.09781  loss_rpn_cls: 0.03371  loss_rpn_loc: 0.008497    time: 0.4097  last_time: 0.1299  data_time: 0.0051  last_data_time: 0.0036   lr: 0.0018981  max_mem: 906M
# [02/20 16:05:08 d2.utils.events]:  eta: 1:01:49  iter: 779  total_loss: 0.2519  loss_cls: 0.1161  loss_box_reg: 0.1068  loss_rpn_cls: 0.02488  loss_rpn_loc: 0.006104    time: 0.4025  last_time: 0.1345  data_time: 0.0040  last_data_time: 0.0038   lr: 0.0019481  max_mem: 906M
# [02/20 16:05:11 d2.utils.events]:  eta: 1:01:22  iter: 799  total_loss: 0.2355  loss_cls: 0.1001  loss_box_reg: 0.1029  loss_rpn_cls: 0.0253  loss_rpn_loc: 0.00892    time: 0.3957  last_time: 0.1279  data_time: 0.0037  last_data_time: 0.0033   lr: 0.001998  max_mem: 906M
# [02/20 16:05:13 d2.utils.events]:  eta: 1:00:52  iter: 819  total_loss: 0.3356  loss_cls: 0.1416  loss_box_reg: 0.1335  loss_rpn_cls: 0.03884  loss_rpn_loc: 0.009059    time: 0.3895  last_time: 0.3044  data_time: 0.0046  last_data_time: 0.0046   lr: 0.002048  max_mem: 906M
# [02/20 16:05:17 d2.utils.events]:  eta: 1:00:14  iter: 839  total_loss: 0.2622  loss_cls: 0.1054  loss_box_reg: 0.1256  loss_rpn_cls: 0.02186  loss_rpn_loc: 0.007112    time: 0.3844  last_time: 0.1254  data_time: 0.0120  last_data_time: 0.0035   lr: 0.0020979  max_mem: 906M
# [02/20 16:05:19 d2.utils.events]:  eta: 0:59:36  iter: 859  total_loss: 0.2205  loss_cls: 0.09473  loss_box_reg: 0.1027  loss_rpn_cls: 0.02328  loss_rpn_loc: 0.006924    time: 0.3785  last_time: 0.1398  data_time: 0.0041  last_data_time: 0.0038   lr: 0.0021479  max_mem: 906M
# [02/20 16:05:22 d2.utils.events]:  eta: 0:59:01  iter: 879  total_loss: 0.2591  loss_cls: 0.09786  loss_box_reg: 0.1078  loss_rpn_cls: 0.02614  loss_rpn_loc: 0.008967    time: 0.3727  last_time: 0.1208  data_time: 0.0040  last_data_time: 0.0039   lr: 0.0021978  max_mem: 906M
# [02/20 16:05:25 d2.utils.events]:  eta: 0:58:10  iter: 899  total_loss: 0.2436  loss_cls: 0.0942  loss_box_reg: 0.1068  loss_rpn_cls: 0.03516  loss_rpn_loc: 0.01414    time: 0.3672  last_time: 0.1215  data_time: 0.0038  last_data_time: 0.0038   lr: 0.0022478  max_mem: 906M
# [02/20 16:05:27 d2.utils.events]:  eta: 0:57:29  iter: 919  total_loss: 0.2872  loss_cls: 0.1029  loss_box_reg: 0.1174  loss_rpn_cls: 0.04167  loss_rpn_loc: 0.009997    time: 0.3620  last_time: 0.1395  data_time: 0.0043  last_data_time: 0.0047   lr: 0.0022977  max_mem: 906M
# [02/20 16:05:30 d2.utils.events]:  eta: 0:56:58  iter: 939  total_loss: 0.188  loss_cls: 0.08682  loss_box_reg: 0.08977  loss_rpn_cls: 0.01791  loss_rpn_loc: 0.005928    time: 0.3575  last_time: 0.1258  data_time: 0.0115  last_data_time: 0.0042   lr: 0.0023477  max_mem: 906M
# [02/20 16:05:33 d2.utils.events]:  eta: 0:56:31  iter: 959  total_loss: 0.2103  loss_cls: 0.08598  loss_box_reg: 0.1024  loss_rpn_cls: 0.01706  loss_rpn_loc: 0.00709    time: 0.3527  last_time: 0.1252  data_time: 0.0040  last_data_time: 0.0045   lr: 0.0023976  max_mem: 906M
# [02/20 16:05:35 d2.utils.events]:  eta: 0:56:06  iter: 979  total_loss: 0.2861  loss_cls: 0.1089  loss_box_reg: 0.1301  loss_rpn_cls: 0.02161  loss_rpn_loc: 0.007714    time: 0.3481  last_time: 0.1257  data_time: 0.0040  last_data_time: 0.0042   lr: 0.0024476  max_mem: 906M
# [02/20 16:05:38 d2.utils.events]:  eta: 0:55:29  iter: 999  total_loss: 0.2476  loss_cls: 0.1187  loss_box_reg: 0.1073  loss_rpn_cls: 0.01972  loss_rpn_loc: 0.008973    time: 0.3436  last_time: 0.1272  data_time: 0.0041  last_data_time: 0.0043   lr: 0.0024975  max_mem: 906M
# [02/20 16:05:40 d2.utils.events]:  eta: 0:54:52  iter: 1019  total_loss: 0.2264  loss_cls: 0.1026  loss_box_reg: 0.1021  loss_rpn_cls: 0.01756  loss_rpn_loc: 0.008445    time: 0.3394  last_time: 0.1499  data_time: 0.0052  last_data_time: 0.0047   lr: 0.0025  max_mem: 906M
# [02/20 16:05:43 d2.utils.events]:  eta: 0:54:16  iter: 1039  total_loss: 0.2182  loss_cls: 0.09481  loss_box_reg: 0.1015  loss_rpn_cls: 0.01837  loss_rpn_loc: 0.00624    time: 0.3358  last_time: 0.1240  data_time: 0.0105  last_data_time: 0.0038   lr: 0.0025  max_mem: 906M
# [02/20 16:05:46 d2.utils.events]:  eta: 0:53:13  iter: 1059  total_loss: 0.237  loss_cls: 0.09916  loss_box_reg: 0.09085  loss_rpn_cls: 0.02855  loss_rpn_loc: 0.007775    time: 0.3318  last_time: 0.1268  data_time: 0.0039  last_data_time: 0.0037   lr: 0.0025  max_mem: 906M
# [02/20 16:05:49 d2.utils.events]:  eta: 0:51:48  iter: 1079  total_loss: 0.248  loss_cls: 0.1058  loss_box_reg: 0.1057  loss_rpn_cls: 0.0223  loss_rpn_loc: 0.007892    time: 0.3283  last_time: 0.1307  data_time: 0.0065  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:05:51 d2.utils.events]:  eta: 0:50:05  iter: 1099  total_loss: 0.2312  loss_cls: 0.1033  loss_box_reg: 0.09467  loss_rpn_cls: 0.02201  loss_rpn_loc: 0.008999    time: 0.3246  last_time: 0.1215  data_time: 0.0040  last_data_time: 0.0037   lr: 0.0025  max_mem: 906M
# [02/20 16:05:54 d2.utils.events]:  eta: 0:47:32  iter: 1119  total_loss: 0.249  loss_cls: 0.09661  loss_box_reg: 0.1164  loss_rpn_cls: 0.0163  loss_rpn_loc: 0.009707    time: 0.3211  last_time: 0.1380  data_time: 0.0050  last_data_time: 0.0057   lr: 0.0025  max_mem: 906M
# [02/20 16:05:57 d2.utils.events]:  eta: 0:38:07  iter: 1139  total_loss: 0.2476  loss_cls: 0.09819  loss_box_reg: 0.1099  loss_rpn_cls: 0.01748  loss_rpn_loc: 0.007728    time: 0.3181  last_time: 0.1228  data_time: 0.0123  last_data_time: 0.0049   lr: 0.0025  max_mem: 906M
# [02/20 16:05:59 d2.utils.events]:  eta: 0:24:10  iter: 1159  total_loss: 0.2162  loss_cls: 0.102  loss_box_reg: 0.09788  loss_rpn_cls: 0.02553  loss_rpn_loc: 0.008574    time: 0.3148  last_time: 0.1208  data_time: 0.0041  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:06:02 d2.utils.events]:  eta: 0:22:56  iter: 1179  total_loss: 0.1999  loss_cls: 0.07903  loss_box_reg: 0.08457  loss_rpn_cls: 0.01683  loss_rpn_loc: 0.005647    time: 0.3116  last_time: 0.1243  data_time: 0.0043  last_data_time: 0.0040   lr: 0.0025  max_mem: 906M
# [02/20 16:06:05 d2.utils.events]:  eta: 0:22:23  iter: 1199  total_loss: 0.2326  loss_cls: 0.09513  loss_box_reg: 0.1062  loss_rpn_cls: 0.01413  loss_rpn_loc: 0.006695    time: 0.3085  last_time: 0.1300  data_time: 0.0041  last_data_time: 0.0041   lr: 0.0025  max_mem: 906M
# [02/20 16:06:07 d2.utils.events]:  eta: 0:21:45  iter: 1219  total_loss: 0.2265  loss_cls: 0.1015  loss_box_reg: 0.1096  loss_rpn_cls: 0.01627  loss_rpn_loc: 0.005351    time: 0.3056  last_time: 0.1547  data_time: 0.0048  last_data_time: 0.0128   lr: 0.0025  max_mem: 906M
# [02/20 16:06:10 d2.utils.events]:  eta: 0:21:34  iter: 1239  total_loss: 0.2355  loss_cls: 0.08797  loss_box_reg: 0.1138  loss_rpn_cls: 0.02037  loss_rpn_loc: 0.01057    time: 0.3031  last_time: 0.1298  data_time: 0.0158  last_data_time: 0.0042   lr: 0.0025  max_mem: 906M
# [02/20 16:06:13 d2.utils.events]:  eta: 0:20:50  iter: 1259  total_loss: 0.247  loss_cls: 0.104  loss_box_reg: 0.1178  loss_rpn_cls: 0.02368  loss_rpn_loc: 0.00687    time: 0.3003  last_time: 0.1222  data_time: 0.0042  last_data_time: 0.0042   lr: 0.0025  max_mem: 906M
# [02/20 16:06:15 d2.utils.events]:  eta: 0:20:18  iter: 1279  total_loss: 0.2377  loss_cls: 0.09578  loss_box_reg: 0.1006  loss_rpn_cls: 0.02126  loss_rpn_loc: 0.005168    time: 0.2976  last_time: 0.1321  data_time: 0.0042  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:06:18 d2.utils.events]:  eta: 0:19:49  iter: 1299  total_loss: 0.2087  loss_cls: 0.08576  loss_box_reg: 0.09227  loss_rpn_cls: 0.01879  loss_rpn_loc: 0.006938    time: 0.2949  last_time: 0.1190  data_time: 0.0041  last_data_time: 0.0038   lr: 0.0025  max_mem: 906M
# [02/20 16:06:20 d2.utils.events]:  eta: 0:19:33  iter: 1319  total_loss: 0.2497  loss_cls: 0.1042  loss_box_reg: 0.1063  loss_rpn_cls: 0.02621  loss_rpn_loc: 0.007709    time: 0.2924  last_time: 0.1582  data_time: 0.0041  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:06:24 d2.utils.events]:  eta: 0:19:26  iter: 1339  total_loss: 0.2224  loss_cls: 0.09401  loss_box_reg: 0.09683  loss_rpn_cls: 0.01671  loss_rpn_loc: 0.00891    time: 0.2911  last_time: 0.1240  data_time: 0.0140  last_data_time: 0.0037   lr: 0.0025  max_mem: 906M
# [02/20 16:06:27 d2.utils.events]:  eta: 0:19:13  iter: 1359  total_loss: 0.2711  loss_cls: 0.1147  loss_box_reg: 0.1067  loss_rpn_cls: 0.03262  loss_rpn_loc: 0.008972    time: 0.2886  last_time: 0.1242  data_time: 0.0041  last_data_time: 0.0041   lr: 0.0025  max_mem: 906M
# [02/20 16:06:29 d2.utils.events]:  eta: 0:19:02  iter: 1379  total_loss: 0.2308  loss_cls: 0.09547  loss_box_reg: 0.09624  loss_rpn_cls: 0.02089  loss_rpn_loc: 0.007175    time: 0.2862  last_time: 0.1266  data_time: 0.0042  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:06:32 d2.utils.events]:  eta: 0:18:53  iter: 1399  total_loss: 0.2011  loss_cls: 0.07273  loss_box_reg: 0.09252  loss_rpn_cls: 0.01718  loss_rpn_loc: 0.00601    time: 0.2840  last_time: 0.1329  data_time: 0.0042  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:06:35 d2.utils.events]:  eta: 0:18:47  iter: 1419  total_loss: 0.2352  loss_cls: 0.09575  loss_box_reg: 0.1149  loss_rpn_cls: 0.02206  loss_rpn_loc: 0.007366    time: 0.2819  last_time: 0.1649  data_time: 0.0052  last_data_time: 0.0042   lr: 0.0025  max_mem: 906M
# [02/20 16:06:38 d2.utils.events]:  eta: 0:18:43  iter: 1439  total_loss: 0.2223  loss_cls: 0.1005  loss_box_reg: 0.1077  loss_rpn_cls: 0.01421  loss_rpn_loc: 0.005916    time: 0.2800  last_time: 0.1324  data_time: 0.0116  last_data_time: 0.0042   lr: 0.0025  max_mem: 906M
# [02/20 16:06:40 d2.utils.events]:  eta: 0:18:36  iter: 1459  total_loss: 0.2237  loss_cls: 0.09672  loss_box_reg: 0.1056  loss_rpn_cls: 0.02134  loss_rpn_loc: 0.007056    time: 0.2779  last_time: 0.1259  data_time: 0.0041  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:06:43 d2.utils.events]:  eta: 0:18:30  iter: 1479  total_loss: 0.1992  loss_cls: 0.08354  loss_box_reg: 0.09401  loss_rpn_cls: 0.01162  loss_rpn_loc: 0.005766    time: 0.2759  last_time: 0.1242  data_time: 0.0047  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:06:45 d2.utils.events]:  eta: 0:18:23  iter: 1499  total_loss: 0.2113  loss_cls: 0.08469  loss_box_reg: 0.09642  loss_rpn_cls: 0.02064  loss_rpn_loc: 0.006372    time: 0.2738  last_time: 0.1243  data_time: 0.0038  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:06:48 d2.utils.events]:  eta: 0:18:19  iter: 1519  total_loss: 0.2124  loss_cls: 0.09485  loss_box_reg: 0.09431  loss_rpn_cls: 0.01244  loss_rpn_loc: 0.007116    time: 0.2720  last_time: 0.1391  data_time: 0.0105  last_data_time: 0.0188   lr: 0.0025  max_mem: 906M
# [02/20 16:06:51 d2.utils.events]:  eta: 0:18:16  iter: 1539  total_loss: 0.1921  loss_cls: 0.07881  loss_box_reg: 0.1045  loss_rpn_cls: 0.01752  loss_rpn_loc: 0.007617    time: 0.2704  last_time: 0.1225  data_time: 0.0073  last_data_time: 0.0049   lr: 0.0025  max_mem: 906M
# [02/20 16:06:53 d2.utils.events]:  eta: 0:18:11  iter: 1559  total_loss: 0.2236  loss_cls: 0.08689  loss_box_reg: 0.1034  loss_rpn_cls: 0.01063  loss_rpn_loc: 0.005866    time: 0.2685  last_time: 0.1330  data_time: 0.0040  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:06:56 d2.utils.events]:  eta: 0:18:07  iter: 1579  total_loss: 0.2238  loss_cls: 0.08799  loss_box_reg: 0.1033  loss_rpn_cls: 0.0147  loss_rpn_loc: 0.006335    time: 0.2668  last_time: 0.1230  data_time: 0.0057  last_data_time: 0.0040   lr: 0.0025  max_mem: 906M
# [02/20 16:06:59 d2.utils.events]:  eta: 0:18:00  iter: 1599  total_loss: 0.2717  loss_cls: 0.1091  loss_box_reg: 0.1304  loss_rpn_cls: 0.01762  loss_rpn_loc: 0.009879    time: 0.2651  last_time: 0.1250  data_time: 0.0038  last_data_time: 0.0038   lr: 0.0025  max_mem: 906M
# [02/20 16:07:01 d2.utils.events]:  eta: 0:17:57  iter: 1619  total_loss: 0.214  loss_cls: 0.09574  loss_box_reg: 0.1067  loss_rpn_cls: 0.01124  loss_rpn_loc: 0.005225    time: 0.2635  last_time: 0.1565  data_time: 0.0042  last_data_time: 0.0058   lr: 0.0025  max_mem: 906M
# [02/20 16:07:04 d2.utils.events]:  eta: 0:17:54  iter: 1639  total_loss: 0.2376  loss_cls: 0.08141  loss_box_reg: 0.1175  loss_rpn_cls: 0.01051  loss_rpn_loc: 0.007048    time: 0.2621  last_time: 0.1318  data_time: 0.0082  last_data_time: 0.0038   lr: 0.0025  max_mem: 906M
# [02/20 16:07:07 d2.utils.events]:  eta: 0:17:51  iter: 1659  total_loss: 0.2997  loss_cls: 0.1227  loss_box_reg: 0.1344  loss_rpn_cls: 0.03505  loss_rpn_loc: 0.01263    time: 0.2604  last_time: 0.1255  data_time: 0.0038  last_data_time: 0.0035   lr: 0.0025  max_mem: 906M
# [02/20 16:07:09 d2.utils.events]:  eta: 0:17:48  iter: 1679  total_loss: 0.2739  loss_cls: 0.1035  loss_box_reg: 0.125  loss_rpn_cls: 0.01573  loss_rpn_loc: 0.007362    time: 0.2588  last_time: 0.1182  data_time: 0.0038  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:07:12 d2.utils.events]:  eta: 0:17:44  iter: 1699  total_loss: 0.2288  loss_cls: 0.1069  loss_box_reg: 0.1099  loss_rpn_cls: 0.0199  loss_rpn_loc: 0.005977    time: 0.2572  last_time: 0.1179  data_time: 0.0038  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:07:15 d2.utils.events]:  eta: 0:17:41  iter: 1719  total_loss: 0.2435  loss_cls: 0.1049  loss_box_reg: 0.1201  loss_rpn_cls: 0.01456  loss_rpn_loc: 0.007337    time: 0.2558  last_time: 0.1441  data_time: 0.0039  last_data_time: 0.0044   lr: 0.0025  max_mem: 906M
# [02/20 16:07:17 d2.utils.events]:  eta: 0:17:38  iter: 1739  total_loss: 0.2299  loss_cls: 0.1023  loss_box_reg: 0.09636  loss_rpn_cls: 0.01449  loss_rpn_loc: 0.00673    time: 0.2545  last_time: 0.1342  data_time: 0.0158  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:07:20 d2.utils.events]:  eta: 0:17:35  iter: 1759  total_loss: 0.2504  loss_cls: 0.1154  loss_box_reg: 0.1013  loss_rpn_cls: 0.0214  loss_rpn_loc: 0.008557    time: 0.2531  last_time: 0.1221  data_time: 0.0042  last_data_time: 0.0038   lr: 0.0025  max_mem: 906M
# [02/20 16:07:23 d2.utils.events]:  eta: 0:17:31  iter: 1779  total_loss: 0.2514  loss_cls: 0.1189  loss_box_reg: 0.1166  loss_rpn_cls: 0.01263  loss_rpn_loc: 0.007814    time: 0.2517  last_time: 0.1271  data_time: 0.0039  last_data_time: 0.0041   lr: 0.0025  max_mem: 906M
# [02/20 16:07:25 d2.utils.events]:  eta: 0:17:28  iter: 1799  total_loss: 0.2063  loss_cls: 0.07993  loss_box_reg: 0.09778  loss_rpn_cls: 0.006602  loss_rpn_loc: 0.005822    time: 0.2503  last_time: 0.1295  data_time: 0.0040  last_data_time: 0.0041   lr: 0.0025  max_mem: 906M
# [02/20 16:07:28 d2.utils.events]:  eta: 0:17:24  iter: 1819  total_loss: 0.2387  loss_cls: 0.1074  loss_box_reg: 0.1052  loss_rpn_cls: 0.01696  loss_rpn_loc: 0.005762    time: 0.2492  last_time: 0.1342  data_time: 0.0086  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:07:31 d2.utils.events]:  eta: 0:17:22  iter: 1839  total_loss: 0.199  loss_cls: 0.07689  loss_box_reg: 0.1041  loss_rpn_cls: 0.01117  loss_rpn_loc: 0.006335    time: 0.2480  last_time: 0.1242  data_time: 0.0125  last_data_time: 0.0035   lr: 0.0025  max_mem: 906M
# [02/20 16:07:34 d2.utils.events]:  eta: 0:17:19  iter: 1859  total_loss: 0.2327  loss_cls: 0.09402  loss_box_reg: 0.1184  loss_rpn_cls: 0.01648  loss_rpn_loc: 0.006685    time: 0.2467  last_time: 0.1287  data_time: 0.0046  last_data_time: 0.0040   lr: 0.0025  max_mem: 906M
# [02/20 16:07:36 d2.utils.events]:  eta: 0:17:17  iter: 1879  total_loss: 0.2024  loss_cls: 0.08493  loss_box_reg: 0.1051  loss_rpn_cls: 0.01725  loss_rpn_loc: 0.007963    time: 0.2455  last_time: 0.1361  data_time: 0.0050  last_data_time: 0.0043   lr: 0.0025  max_mem: 906M
# [02/20 16:07:39 d2.utils.events]:  eta: 0:17:14  iter: 1899  total_loss: 0.2621  loss_cls: 0.1057  loss_box_reg: 0.1127  loss_rpn_cls: 0.02259  loss_rpn_loc: 0.00547    time: 0.2442  last_time: 0.1197  data_time: 0.0040  last_data_time: 0.0040   lr: 0.0025  max_mem: 906M
# [02/20 16:07:41 d2.utils.events]:  eta: 0:17:12  iter: 1919  total_loss: 0.2166  loss_cls: 0.08961  loss_box_reg: 0.1033  loss_rpn_cls: 0.01878  loss_rpn_loc: 0.007604    time: 0.2430  last_time: 0.1558  data_time: 0.0078  last_data_time: 0.0258   lr: 0.0025  max_mem: 906M
# [02/20 16:07:44 d2.utils.events]:  eta: 0:17:09  iter: 1939  total_loss: 0.2006  loss_cls: 0.08398  loss_box_reg: 0.09803  loss_rpn_cls: 0.01183  loss_rpn_loc: 0.005807    time: 0.2420  last_time: 0.1222  data_time: 0.0090  last_data_time: 0.0033   lr: 0.0025  max_mem: 906M
# [02/20 16:07:47 d2.utils.events]:  eta: 0:17:06  iter: 1959  total_loss: 0.2133  loss_cls: 0.09204  loss_box_reg: 0.1062  loss_rpn_cls: 0.01278  loss_rpn_loc: 0.006651    time: 0.2408  last_time: 0.1246  data_time: 0.0040  last_data_time: 0.0038   lr: 0.0025  max_mem: 906M
# [02/20 16:07:49 d2.utils.events]:  eta: 0:17:03  iter: 1979  total_loss: 0.1984  loss_cls: 0.07267  loss_box_reg: 0.09886  loss_rpn_cls: 0.01349  loss_rpn_loc: 0.006592    time: 0.2396  last_time: 0.1298  data_time: 0.0040  last_data_time: 0.0040   lr: 0.0025  max_mem: 906M
# [02/20 16:07:52 d2.utils.events]:  eta: 0:17:01  iter: 1999  total_loss: 0.1859  loss_cls: 0.07762  loss_box_reg: 0.08947  loss_rpn_cls: 0.01386  loss_rpn_loc: 0.005781    time: 0.2385  last_time: 0.1240  data_time: 0.0040  last_data_time: 0.0044   lr: 0.0025  max_mem: 906M
# [02/20 16:07:54 d2.utils.events]:  eta: 0:16:59  iter: 2019  total_loss: 0.2286  loss_cls: 0.08852  loss_box_reg: 0.1095  loss_rpn_cls: 0.02075  loss_rpn_loc: 0.007505    time: 0.2374  last_time: 0.1482  data_time: 0.0043  last_data_time: 0.0063   lr: 0.0025  max_mem: 906M
# [02/20 16:07:57 d2.utils.events]:  eta: 0:16:56  iter: 2039  total_loss: 0.1806  loss_cls: 0.07905  loss_box_reg: 0.1086  loss_rpn_cls: 0.008902  loss_rpn_loc: 0.00611    time: 0.2365  last_time: 0.1204  data_time: 0.0061  last_data_time: 0.0033   lr: 0.0025  max_mem: 906M
# [02/20 16:08:00 d2.utils.events]:  eta: 0:16:54  iter: 2059  total_loss: 0.2286  loss_cls: 0.1021  loss_box_reg: 0.1192  loss_rpn_cls: 0.009565  loss_rpn_loc: 0.008955    time: 0.2355  last_time: 0.1312  data_time: 0.0040  last_data_time: 0.0047   lr: 0.0025  max_mem: 906M
# [02/20 16:08:02 d2.utils.events]:  eta: 0:16:51  iter: 2079  total_loss: 0.1995  loss_cls: 0.07906  loss_box_reg: 0.09159  loss_rpn_cls: 0.011  loss_rpn_loc: 0.007629    time: 0.2345  last_time: 0.1240  data_time: 0.0060  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:08:05 d2.utils.events]:  eta: 0:16:48  iter: 2099  total_loss: 0.1903  loss_cls: 0.06709  loss_box_reg: 0.1183  loss_rpn_cls: 0.005021  loss_rpn_loc: 0.005809    time: 0.2335  last_time: 0.1312  data_time: 0.0038  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:08:08 d2.utils.events]:  eta: 0:16:46  iter: 2119  total_loss: 0.2399  loss_cls: 0.1086  loss_box_reg: 0.1105  loss_rpn_cls: 0.01385  loss_rpn_loc: 0.007698    time: 0.2325  last_time: 0.1511  data_time: 0.0042  last_data_time: 0.0044   lr: 0.0025  max_mem: 906M
# [02/20 16:08:11 d2.utils.events]:  eta: 0:16:44  iter: 2139  total_loss: 0.2341  loss_cls: 0.09049  loss_box_reg: 0.122  loss_rpn_cls: 0.01548  loss_rpn_loc: 0.009134    time: 0.2318  last_time: 0.1338  data_time: 0.0130  last_data_time: 0.0037   lr: 0.0025  max_mem: 906M
# [02/20 16:08:13 d2.utils.events]:  eta: 0:16:42  iter: 2159  total_loss: 0.2192  loss_cls: 0.08071  loss_box_reg: 0.1173  loss_rpn_cls: 0.01104  loss_rpn_loc: 0.005721    time: 0.2308  last_time: 0.1313  data_time: 0.0042  last_data_time: 0.0040   lr: 0.0025  max_mem: 906M
# [02/20 16:08:16 d2.utils.events]:  eta: 0:16:38  iter: 2179  total_loss: 0.2208  loss_cls: 0.08938  loss_box_reg: 0.1118  loss_rpn_cls: 0.02543  loss_rpn_loc: 0.01155    time: 0.2298  last_time: 0.1207  data_time: 0.0040  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:08:18 d2.utils.events]:  eta: 0:16:36  iter: 2199  total_loss: 0.2032  loss_cls: 0.09526  loss_box_reg: 0.1132  loss_rpn_cls: 0.0119  loss_rpn_loc: 0.007327    time: 0.2289  last_time: 0.1248  data_time: 0.0049  last_data_time: 0.0035   lr: 0.0025  max_mem: 906M
# [02/20 16:08:21 d2.utils.events]:  eta: 0:16:33  iter: 2219  total_loss: 0.2866  loss_cls: 0.1209  loss_box_reg: 0.114  loss_rpn_cls: 0.02589  loss_rpn_loc: 0.009042    time: 0.2280  last_time: 0.1464  data_time: 0.0048  last_data_time: 0.0176   lr: 0.0025  max_mem: 906M
# [02/20 16:08:24 d2.utils.events]:  eta: 0:16:31  iter: 2239  total_loss: 0.1817  loss_cls: 0.06545  loss_box_reg: 0.09287  loss_rpn_cls: 0.006717  loss_rpn_loc: 0.005272    time: 0.2272  last_time: 0.1505  data_time: 0.0086  last_data_time: 0.0155   lr: 0.0025  max_mem: 906M
# [02/20 16:08:26 d2.utils.events]:  eta: 0:16:28  iter: 2259  total_loss: 0.2222  loss_cls: 0.09617  loss_box_reg: 0.108  loss_rpn_cls: 0.0143  loss_rpn_loc: 0.006952    time: 0.2263  last_time: 0.1234  data_time: 0.0041  last_data_time: 0.0039   lr: 0.0025  max_mem: 906M
# [02/20 16:08:29 d2.utils.events]:  eta: 0:16:26  iter: 2279  total_loss: 0.2422  loss_cls: 0.1017  loss_box_reg: 0.1179  loss_rpn_cls: 0.009565  loss_rpn_loc: 0.007026    time: 0.2255  last_time: 0.1303  data_time: 0.0043  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:08:31 d2.utils.events]:  eta: 0:16:23  iter: 2299  total_loss: 0.2321  loss_cls: 0.09252  loss_box_reg: 0.1141  loss_rpn_cls: 0.01082  loss_rpn_loc: 0.008481    time: 0.2246  last_time: 0.1210  data_time: 0.0041  last_data_time: 0.0036   lr: 0.0025  max_mem: 906M
# [02/20 16:08:34 d2.utils.events]:  eta: 0:16:21  iter: 2319  total_loss: 0.1869  loss_cls: 0.07294  loss_box_reg: 0.08861  loss_rpn_cls: 0.01507  loss_rpn_loc: 0.006856    time: 0.2238  last_time: 0.1319  data_time: 0.0047  last_data_time: 0.0035   lr: 0.0025  max_mem: 908M
# [02/20 16:08:37 d2.utils.events]:  eta: 0:16:19  iter: 2339  total_loss: 0.1936  loss_cls: 0.07682  loss_box_reg: 0.08968  loss_rpn_cls: 0.0121  loss_rpn_loc: 0.005528    time: 0.2232  last_time: 0.1537  data_time: 0.0124  last_data_time: 0.0050   lr: 0.0025  max_mem: 908M
# [02/20 16:08:40 d2.utils.events]:  eta: 0:16:17  iter: 2359  total_loss: 0.2086  loss_cls: 0.08775  loss_box_reg: 0.09457  loss_rpn_cls: 0.008125  loss_rpn_loc: 0.006305    time: 0.2224  last_time: 0.1216  data_time: 0.0044  last_data_time: 0.0036   lr: 0.0025  max_mem: 908M
# [02/20 16:08:42 d2.utils.events]:  eta: 0:16:15  iter: 2379  total_loss: 0.1984  loss_cls: 0.07927  loss_box_reg: 0.09491  loss_rpn_cls: 0.01392  loss_rpn_loc: 0.005151    time: 0.2216  last_time: 0.1249  data_time: 0.0039  last_data_time: 0.0040   lr: 0.0025  max_mem: 908M
# [02/20 16:08:45 d2.utils.events]:  eta: 0:16:12  iter: 2399  total_loss: 0.2339  loss_cls: 0.1003  loss_box_reg: 0.1273  loss_rpn_cls: 0.0121  loss_rpn_loc: 0.00623    time: 0.2208  last_time: 0.1215  data_time: 0.0043  last_data_time: 0.0038   lr: 0.0025  max_mem: 908M
# ...
# [02/20 16:24:57 d2.utils.events]:  eta: 0:01:42  iter: 9179  total_loss: 0.1193  loss_cls: 0.04101  loss_box_reg: 0.07653  loss_rpn_cls: 0.002888  loss_rpn_loc: 0.004606    time: 0.1545  last_time: 0.1446  data_time: 0.0056  last_data_time: 0.0047   lr: 0.0025  max_mem: 909M
# [02/20 16:25:00 d2.utils.events]:  eta: 0:01:40  iter: 9199  total_loss: 0.1224  loss_cls: 0.04835  loss_box_reg: 0.07463  loss_rpn_cls: 0.00448  loss_rpn_loc: 0.004271    time: 0.1544  last_time: 0.1211  data_time: 0.0083  last_data_time: 0.0037   lr: 0.0025  max_mem: 909M
# [02/20 16:25:03 d2.utils.events]:  eta: 0:01:37  iter: 9219  total_loss: 0.1194  loss_cls: 0.04942  loss_box_reg: 0.06416  loss_rpn_cls: 0.003325  loss_rpn_loc: 0.004671    time: 0.1543  last_time: 0.1210  data_time: 0.0037  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:25:05 d2.utils.events]:  eta: 0:01:35  iter: 9239  total_loss: 0.1461  loss_cls: 0.0516  loss_box_reg: 0.08613  loss_rpn_cls: 0.003362  loss_rpn_loc: 0.005242    time: 0.1543  last_time: 0.1209  data_time: 0.0040  last_data_time: 0.0041   lr: 0.0025  max_mem: 909M
# [02/20 16:25:08 d2.utils.events]:  eta: 0:01:32  iter: 9259  total_loss: 0.16  loss_cls: 0.04547  loss_box_reg: 0.08991  loss_rpn_cls: 0.005212  loss_rpn_loc: 0.007377    time: 0.1542  last_time: 0.1299  data_time: 0.0046  last_data_time: 0.0042   lr: 0.0025  max_mem: 909M
# [02/20 16:25:11 d2.utils.events]:  eta: 0:01:30  iter: 9279  total_loss: 0.1539  loss_cls: 0.05658  loss_box_reg: 0.08438  loss_rpn_cls: 0.005064  loss_rpn_loc: 0.00649    time: 0.1542  last_time: 0.1560  data_time: 0.0082  last_data_time: 0.0170   lr: 0.0025  max_mem: 909M
# [02/20 16:25:13 d2.utils.events]:  eta: 0:01:27  iter: 9299  total_loss: 0.1438  loss_cls: 0.0456  loss_box_reg: 0.08821  loss_rpn_cls: 0.006276  loss_rpn_loc: 0.005118    time: 0.1542  last_time: 0.1190  data_time: 0.0063  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:25:16 d2.utils.events]:  eta: 0:01:25  iter: 9319  total_loss: 0.1376  loss_cls: 0.04293  loss_box_reg: 0.08756  loss_rpn_cls: 0.003486  loss_rpn_loc: 0.004864    time: 0.1541  last_time: 0.1183  data_time: 0.0038  last_data_time: 0.0037   lr: 0.0025  max_mem: 909M
# [02/20 16:25:18 d2.utils.events]:  eta: 0:01:22  iter: 9339  total_loss: 0.1655  loss_cls: 0.05339  loss_box_reg: 0.09445  loss_rpn_cls: 0.006225  loss_rpn_loc: 0.00653    time: 0.1541  last_time: 0.1249  data_time: 0.0037  last_data_time: 0.0032   lr: 0.0025  max_mem: 909M
# [02/20 16:25:21 d2.utils.events]:  eta: 0:01:20  iter: 9359  total_loss: 0.1811  loss_cls: 0.0665  loss_box_reg: 0.1003  loss_rpn_cls: 0.006059  loss_rpn_loc: 0.004447    time: 0.1540  last_time: 0.1341  data_time: 0.0040  last_data_time: 0.0043   lr: 0.0025  max_mem: 909M
# [02/20 16:25:24 d2.utils.events]:  eta: 0:01:17  iter: 9379  total_loss: 0.1267  loss_cls: 0.0463  loss_box_reg: 0.07198  loss_rpn_cls: 0.004317  loss_rpn_loc: 0.005072    time: 0.1540  last_time: 0.1422  data_time: 0.0048  last_data_time: 0.0119   lr: 0.0025  max_mem: 909M
# [02/20 16:25:27 d2.utils.events]:  eta: 0:01:15  iter: 9399  total_loss: 0.1509  loss_cls: 0.05873  loss_box_reg: 0.09294  loss_rpn_cls: 0.002809  loss_rpn_loc: 0.004543    time: 0.1539  last_time: 0.1295  data_time: 0.0141  last_data_time: 0.0037   lr: 0.0025  max_mem: 909M
# [02/20 16:25:29 d2.utils.events]:  eta: 0:01:12  iter: 9419  total_loss: 0.1433  loss_cls: 0.05108  loss_box_reg: 0.07399  loss_rpn_cls: 0.006767  loss_rpn_loc: 0.004128    time: 0.1539  last_time: 0.1174  data_time: 0.0038  last_data_time: 0.0033   lr: 0.0025  max_mem: 909M
# [02/20 16:25:32 d2.utils.events]:  eta: 0:01:10  iter: 9439  total_loss: 0.1513  loss_cls: 0.0518  loss_box_reg: 0.08165  loss_rpn_cls: 0.005112  loss_rpn_loc: 0.00346    time: 0.1538  last_time: 0.1156  data_time: 0.0044  last_data_time: 0.0039   lr: 0.0025  max_mem: 909M
# [02/20 16:25:34 d2.utils.events]:  eta: 0:01:07  iter: 9459  total_loss: 0.1414  loss_cls: 0.05196  loss_box_reg: 0.07617  loss_rpn_cls: 0.003673  loss_rpn_loc: 0.004193    time: 0.1537  last_time: 0.1258  data_time: 0.0041  last_data_time: 0.0043   lr: 0.0025  max_mem: 909M
# [02/20 16:25:37 d2.utils.events]:  eta: 0:01:05  iter: 9479  total_loss: 0.1382  loss_cls: 0.04558  loss_box_reg: 0.07186  loss_rpn_cls: 0.003322  loss_rpn_loc: 0.005621    time: 0.1537  last_time: 0.1575  data_time: 0.0043  last_data_time: 0.0068   lr: 0.0025  max_mem: 909M
# [02/20 16:25:40 d2.utils.events]:  eta: 0:01:02  iter: 9499  total_loss: 0.1153  loss_cls: 0.03334  loss_box_reg: 0.06737  loss_rpn_cls: 0.005297  loss_rpn_loc: 0.004036    time: 0.1537  last_time: 0.1422  data_time: 0.0077  last_data_time: 0.0042   lr: 0.0025  max_mem: 909M
# [02/20 16:25:42 d2.utils.events]:  eta: 0:01:00  iter: 9519  total_loss: 0.1447  loss_cls: 0.04737  loss_box_reg: 0.07741  loss_rpn_cls: 0.003998  loss_rpn_loc: 0.004038    time: 0.1536  last_time: 0.1399  data_time: 0.0040  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:25:45 d2.utils.events]:  eta: 0:00:57  iter: 9539  total_loss: 0.1251  loss_cls: 0.04452  loss_box_reg: 0.07683  loss_rpn_cls: 0.002758  loss_rpn_loc: 0.00412    time: 0.1536  last_time: 0.1280  data_time: 0.0050  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:25:47 d2.utils.events]:  eta: 0:00:55  iter: 9559  total_loss: 0.1603  loss_cls: 0.05384  loss_box_reg: 0.09382  loss_rpn_cls: 0.005404  loss_rpn_loc: 0.004747    time: 0.1535  last_time: 0.1236  data_time: 0.0039  last_data_time: 0.0038   lr: 0.0025  max_mem: 909M
# [02/20 16:25:50 d2.utils.events]:  eta: 0:00:52  iter: 9579  total_loss: 0.1159  loss_cls: 0.03582  loss_box_reg: 0.08086  loss_rpn_cls: 0.003062  loss_rpn_loc: 0.005058    time: 0.1535  last_time: 0.1408  data_time: 0.0045  last_data_time: 0.0041   lr: 0.0025  max_mem: 909M
# [02/20 16:25:53 d2.utils.events]:  eta: 0:00:50  iter: 9599  total_loss: 0.1821  loss_cls: 0.0532  loss_box_reg: 0.09695  loss_rpn_cls: 0.004227  loss_rpn_loc: 0.004704    time: 0.1534  last_time: 0.1535  data_time: 0.0081  last_data_time: 0.0102   lr: 0.0025  max_mem: 909M
# [02/20 16:25:55 d2.utils.events]:  eta: 0:00:47  iter: 9619  total_loss: 0.1323  loss_cls: 0.0562  loss_box_reg: 0.07791  loss_rpn_cls: 0.004704  loss_rpn_loc: 0.004755    time: 0.1534  last_time: 0.1249  data_time: 0.0052  last_data_time: 0.0044   lr: 0.0025  max_mem: 909M
# [02/20 16:25:58 d2.utils.events]:  eta: 0:00:45  iter: 9639  total_loss: 0.1553  loss_cls: 0.05285  loss_box_reg: 0.09362  loss_rpn_cls: 0.003221  loss_rpn_loc: 0.004142    time: 0.1533  last_time: 0.1248  data_time: 0.0037  last_data_time: 0.0040   lr: 0.0025  max_mem: 909M
# [02/20 16:26:00 d2.utils.events]:  eta: 0:00:42  iter: 9659  total_loss: 0.1431  loss_cls: 0.05197  loss_box_reg: 0.08727  loss_rpn_cls: 0.005477  loss_rpn_loc: 0.005267    time: 0.1533  last_time: 0.1251  data_time: 0.0045  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:26:03 d2.utils.events]:  eta: 0:00:40  iter: 9679  total_loss: 0.134  loss_cls: 0.04105  loss_box_reg: 0.08304  loss_rpn_cls: 0.002347  loss_rpn_loc: 0.005159    time: 0.1532  last_time: 0.1222  data_time: 0.0037  last_data_time: 0.0039   lr: 0.0025  max_mem: 909M
# [02/20 16:26:06 d2.utils.events]:  eta: 0:00:37  iter: 9699  total_loss: 0.1534  loss_cls: 0.04958  loss_box_reg: 0.08905  loss_rpn_cls: 0.002294  loss_rpn_loc: 0.004116    time: 0.1532  last_time: 0.1434  data_time: 0.0101  last_data_time: 0.0051   lr: 0.0025  max_mem: 909M
# [02/20 16:26:09 d2.utils.events]:  eta: 0:00:35  iter: 9719  total_loss: 0.1665  loss_cls: 0.06043  loss_box_reg: 0.0963  loss_rpn_cls: 0.003374  loss_rpn_loc: 0.004951    time: 0.1532  last_time: 0.1201  data_time: 0.0064  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:26:11 d2.utils.events]:  eta: 0:00:32  iter: 9739  total_loss: 0.1405  loss_cls: 0.04877  loss_box_reg: 0.08452  loss_rpn_cls: 0.001941  loss_rpn_loc: 0.004128    time: 0.1531  last_time: 0.1224  data_time: 0.0055  last_data_time: 0.0037   lr: 0.0025  max_mem: 909M
# [02/20 16:26:14 d2.utils.events]:  eta: 0:00:30  iter: 9759  total_loss: 0.1734  loss_cls: 0.05665  loss_box_reg: 0.1029  loss_rpn_cls: 0.003677  loss_rpn_loc: 0.005797    time: 0.1531  last_time: 0.1190  data_time: 0.0041  last_data_time: 0.0036   lr: 0.0025  max_mem: 909M
# [02/20 16:26:17 d2.utils.events]:  eta: 0:00:27  iter: 9779  total_loss: 0.1566  loss_cls: 0.05391  loss_box_reg: 0.09314  loss_rpn_cls: 0.003076  loss_rpn_loc: 0.006104    time: 0.1531  last_time: 0.1523  data_time: 0.0053  last_data_time: 0.0043   lr: 0.0025  max_mem: 909M
# [02/20 16:26:20 d2.utils.events]:  eta: 0:00:25  iter: 9799  total_loss: 0.1581  loss_cls: 0.04851  loss_box_reg: 0.1024  loss_rpn_cls: 0.005931  loss_rpn_loc: 0.006646    time: 0.1530  last_time: 0.1475  data_time: 0.0133  last_data_time: 0.0104   lr: 0.0025  max_mem: 909M
# [02/20 16:26:22 d2.utils.events]:  eta: 0:00:22  iter: 9819  total_loss: 0.1542  loss_cls: 0.05439  loss_box_reg: 0.08444  loss_rpn_cls: 0.007405  loss_rpn_loc: 0.004374    time: 0.1530  last_time: 0.1221  data_time: 0.0051  last_data_time: 0.0042   lr: 0.0025  max_mem: 909M
# [02/20 16:26:25 d2.utils.events]:  eta: 0:00:20  iter: 9839  total_loss: 0.1192  loss_cls: 0.03668  loss_box_reg: 0.07676  loss_rpn_cls: 0.001933  loss_rpn_loc: 0.00445    time: 0.1529  last_time: 0.1277  data_time: 0.0040  last_data_time: 0.0043   lr: 0.0025  max_mem: 909M
# [02/20 16:26:27 d2.utils.events]:  eta: 0:00:17  iter: 9859  total_loss: 0.1281  loss_cls: 0.04029  loss_box_reg: 0.08193  loss_rpn_cls: 0.003491  loss_rpn_loc: 0.003444    time: 0.1529  last_time: 0.1175  data_time: 0.0040  last_data_time: 0.0038   lr: 0.0025  max_mem: 909M
# [02/20 16:26:30 d2.utils.events]:  eta: 0:00:15  iter: 9879  total_loss: 0.129  loss_cls: 0.04247  loss_box_reg: 0.08298  loss_rpn_cls: 0.003748  loss_rpn_loc: 0.004664    time: 0.1528  last_time: 0.1287  data_time: 0.0039  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:26:32 d2.utils.events]:  eta: 0:00:12  iter: 9899  total_loss: 0.1268  loss_cls: 0.04641  loss_box_reg: 0.08632  loss_rpn_cls: 0.004183  loss_rpn_loc: 0.004951    time: 0.1528  last_time: 0.1378  data_time: 0.0078  last_data_time: 0.0155   lr: 0.0025  max_mem: 909M
# [02/20 16:26:35 d2.utils.events]:  eta: 0:00:10  iter: 9919  total_loss: 0.1738  loss_cls: 0.05335  loss_box_reg: 0.1046  loss_rpn_cls: 0.004559  loss_rpn_loc: 0.005031    time: 0.1528  last_time: 0.1308  data_time: 0.0051  last_data_time: 0.0045   lr: 0.0025  max_mem: 909M
# [02/20 16:26:38 d2.utils.events]:  eta: 0:00:07  iter: 9939  total_loss: 0.1521  loss_cls: 0.05199  loss_box_reg: 0.09745  loss_rpn_cls: 0.003725  loss_rpn_loc: 0.003952    time: 0.1527  last_time: 0.1246  data_time: 0.0042  last_data_time: 0.0038   lr: 0.0025  max_mem: 909M
# [02/20 16:26:40 d2.utils.events]:  eta: 0:00:05  iter: 9959  total_loss: 0.1351  loss_cls: 0.04503  loss_box_reg: 0.08696  loss_rpn_cls: 0.003652  loss_rpn_loc: 0.004875    time: 0.1526  last_time: 0.1191  data_time: 0.0040  last_data_time: 0.0035   lr: 0.0025  max_mem: 909M
# [02/20 16:26:43 d2.utils.events]:  eta: 0:00:02  iter: 9979  total_loss: 0.134  loss_cls: 0.0402  loss_box_reg: 0.07807  loss_rpn_cls: 0.004692  loss_rpn_loc: 0.004473    time: 0.1526  last_time: 0.1220  data_time: 0.0038  last_data_time: 0.0038   lr: 0.0025  max_mem: 909M
# [02/20 16:26:48 d2.utils.events]:  eta: 0:00:00  iter: 9999  total_loss: 0.1214  loss_cls: 0.03713  loss_box_reg: 0.07372  loss_rpn_cls: 0.003061  loss_rpn_loc: 0.006093    time: 0.1526  last_time: 0.1422  data_time: 0.0055  last_data_time: 0.0076   lr: 0.0025  max_mem: 909M
# [02/20 16:26:48 d2.engine.hooks]: Overall training speed: 9998 iterations in 0:25:25 (0.1526 s / it)
# [02/20 16:26:48 d2.engine.hooks]: Total training time: 0:26:57 (0:01:31 on hooks)
# [02/20 16:26:48 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(256, 256), max_size=1333, sample_style='choice')]
# [02/20 16:26:48 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/20 16:26:48 d2.data.common]: Serializing 319 elements to byte tensors and concatenating them all ...
# [02/20 16:26:48 d2.data.common]: Serialized dataset takes 0.10 MiB
# WARNING [02/20 16:26:48 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [02/20 16:26:48 d2.evaluation.evaluator]: Start inference on 319 batches
# [02/20 16:26:49 d2.evaluation.evaluator]: Inference done 11/319. Dataloading: 0.0015 s/iter. Inference: 0.0571 s/iter. Eval: 0.0004 s/iter. Total: 0.0590 s/iter. ETA=0:00:18
# [02/20 16:26:54 d2.evaluation.evaluator]: Inference done 142/319. Dataloading: 0.0011 s/iter. Inference: 0.0378 s/iter. Eval: 0.0003 s/iter. Total: 0.0393 s/iter. ETA=0:00:06
# [02/20 16:26:59 d2.evaluation.evaluator]: Inference done 236/319. Dataloading: 0.0017 s/iter. Inference: 0.0430 s/iter. Eval: 0.0004 s/iter. Total: 0.0451 s/iter. ETA=0:00:03
# [02/20 16:27:03 d2.evaluation.evaluator]: Total inference time: 0:00:14.307926 (0.045567 s / iter per device, on 1 devices)
# [02/20 16:27:03 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:13 (0.043305 s / iter per device, on 1 devices)
# [02/20 16:27:03 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/20 16:27:03 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v3-2/coco_instances_results.json
# [02/20 16:27:03 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/20 16:27:03 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/20 16:27:03 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [02/20 16:27:03 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/20 16:27:03 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.610
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.216
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.275
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.299
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.403
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.448
# [02/20 16:27:03 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 27.070 | 61.045 | 21.553 | 17.093 | 27.540 | 29.878 |
# [02/20 16:27:03 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | ulcer      | 11.037 | polyp      | 37.321 | cancer     | 32.853 |
# [02/20 16:27:03 d2.engine.defaults]: Evaluation results for colonoscopy_val in csv format:
# [02/20 16:27:03 d2.evaluation.testing]: copypaste: Task: bbox
# [02/20 16:27:03 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/20 16:27:03 d2.evaluation.testing]: copypaste: 27.0701,61.0450,21.5528,17.0930,27.5395,29.8784
