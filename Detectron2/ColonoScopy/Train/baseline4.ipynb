# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
import os
import torch

# %%
# def csv_to_coco(csv_path, meta_csv, output_json):
#     df = pd.read_csv(csv_path)
#     meta_df = pd.read_csv(meta_csv)
#     filtered_df = df[df["image_id"].isin(meta_df["image_id"])]

#     class_map = {"ulcer": 0, "polyp": 1, "cancer": 2}
#     coco_json = {"images": [], "annotations": [], "categories": []}

#     for class_name, class_id in class_map.items():
#         coco_json["categories"].append({"id": class_id, "name": class_name})

#     image_id_map = {}
#     annotation_id = 1

#     for _, row in filtered_df.iterrows():
#         image_id = row["image_id"]
#         image_name = row["image_id"]

#         if image_id not in image_id_map:
#             image_id_map[image_id] = image_name
#             coco_json["images"].append({
#                 "id": image_id,
#                 "width": row["width"],
#                 "height": row["height"],
#                 "file_name": image_name
#             })

#         x_min, y_min, x_max, y_max = row["x_min"], row["y_min"], row["x_max"], row["y_max"]
#         bbox = [x_min, y_min, x_max - x_min, y_max - y_min]

#         coco_json["annotations"].append({
#             "id": annotation_id,
#             "image_id": image_id,
#             "category_id": class_map[row["lesion"]],
#             "bbox": bbox,
#             "area": bbox[2] * bbox[3],
#             "iscrowd": 0
#         })
#         annotation_id += 1

#     with open(output_json, "w") as f:
#         json.dump(coco_json, f, indent=4)

#     print(f"COCO JSON saved: {output_json}")

# base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
# csv_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/resize_colonoscopy.csv"

# meta_paths = {
#     "train": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/train_meta.csv",
#     "val": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/val_meta.csv",
#     "test": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/test_meta.csv",
# }

# json_paths = {
#     "train": os.path.join(base_path, "Dataset", "train_coco.json"),
#     "val": os.path.join(base_path, "Dataset", "val_coco.json"),
#     "test": os.path.join(base_path, "Dataset", "test_coco.json"),
# }

# for split in ["train", "val", "test"]:
#     csv_to_coco(csv_path, meta_paths[split], json_paths[split])

# %%
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 76.9 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

def register_coco_dataset(name, json_file, image_root):
    DatasetCatalog.register(
        name,
        lambda: load_coco_json(json_file, image_root)
    )
    MetadataCatalog.get(name).set(thing_classes=["ulcer", "polyp","cancer"])

def load_coco_json(json_file, image_root):
    with open(json_file, "r") as f:
        coco_data = json.load(f)

    dataset_dicts = []
    for image_info in coco_data['images']:
        record = {}
        record['file_name'] = os.path.join(image_root, image_info['file_name'])
        record['image_id'] = image_info['id']
        record['height'] = image_info['height']
        record['width'] = image_info['width']

        annotations = []
        for ann in coco_data['annotations']:
            if ann['image_id'] == image_info['id']:
                annotations.append({
                    "bbox": ann['bbox'],
                    "bbox_mode": BoxMode.XYWH_ABS,
                    "category_id": ann['category_id']
                })

        record['annotations'] = annotations
        dataset_dicts.append(record)
    return dataset_dicts


image_folders = {
    "train": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/train",
    "val": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/val",
    "test": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/test"
}

base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
json_paths = {
    "train": os.path.join(base_path, "Dataset", "train_coco.json"),
    "val": os.path.join(base_path, "Dataset", "val_coco.json"),
    "test": os.path.join(base_path, "Dataset", "test_coco.json"),
}

for split in ["train", "val", "test"]:
    register_coco_dataset(f"colonoscopy_{split}", json_paths[split], image_folders[split])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-53-965f6c18095d> in <cell line: 0>()
#      49
#      50 for split in ["train", "val", "test"]:
# ---> 51     register_coco_dataset(f"colonoscopy_{split}", json_paths[split], image_folders[split])
#
# <ipython-input-53-965f6c18095d> in register_coco_dataset(name, json_file, image_root)
#       3
#       4 def register_coco_dataset(name, json_file, image_root):
# ----> 5     DatasetCatalog.register(
#       6         name,
#       7         lambda: load_coco_json(json_file, image_root)
#
# /usr/local/lib/python3.11/dist-packages/detectron2/data/catalog.py in register(self, name, func)
#      35         """
#      36         assert callable(func), "You must register a function with `DatasetCatalog.register`!"
# ---> 37         assert name not in self, "Dataset '{}' is already registered!".format(name)
#      38         self[name] = func
#      39
#
# AssertionError: Dataset 'colonoscopy_train' is already registered!

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.4)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (3.11.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.evaluation import COCOEvaluator
from detectron2.data import build_detection_train_loader, build_detection_test_loader

# %%
# !wget -O /content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Out:
# --2025-02-23 15:33:06--  https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318 (1.3K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’
#
# /content/drive/MyDr 100%[===================>]   1.29K  --.-KB/s    in 0s
#
# 2025-02-23 15:33:06 (41.3 MB/s) - ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’ saved [1318/1318]

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog, DatasetMapper
from detectron2.data.transforms import (RandomFlip, RandomRotation, RandomContrast, RandomBrightness, RandomLighting)
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_train_loader, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator
from detectron2.config import get_cfg
import os
import cv2
import random
import numpy as np
from detectron2.data.transforms import Augmentation, Transform
from detectron2.data import detection_utils as utils
from detectron2.structures import BoxMode

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Error loading image: {image_path}")
    return image

class Mosaic:
    def __init__(self, prob=0.5, image_size=(128, 128)):
        self.prob = prob
        self.image_size = image_size

    def __call__(self, dataset_dicts):
        if random.random() >= self.prob:
            return dataset_dicts[0]

        h, w = self.image_size
        mosaic_image = np.zeros((h, w, 3), dtype=np.uint8)
        mosaic_boxes = []
        mosaic_classes = []

        selected_samples = random.sample(dataset_dicts, 4)
        positions = [
            (0, 0), (w // 2, 0),
            (0, h // 2), (w // 2, h // 2)
        ]

        for i, sample in enumerate(selected_samples):
            image_path = sample["file_name"]
            image = load_image(image_path)
            orig_h, orig_w = image.shape[:2]


            x1 = random.randint(0, orig_w // 2)
            y1 = random.randint(0, orig_h // 2)
            x2 = random.randint(orig_w // 2, orig_w)
            y2 = random.randint(orig_h // 2, orig_h)
            cropped_image = image[y1:y2, x1:x2]

            pos_x, pos_y = positions[i]

            resized_crop = cv2.resize(cropped_image, (w // 2, h // 2))
            mosaic_image[pos_y:pos_y + h // 2, pos_x:pos_x + w // 2] = resized_crop

            for ann in sample["annotations"]:
                bbox = ann["bbox"]
                bbox_mode = ann["bbox_mode"]

                if bbox_mode != BoxMode.XYXY_ABS:
                    bbox = BoxMode.convert(bbox, bbox_mode, BoxMode.XYXY_ABS)

                x_min, y_min, x_max, y_max = bbox


                if x_min < x2 and x_max > x1 and y_min < y2 and y_max > y1:
                    clipped_bbox = [
                        max(x_min, x1) - x1,  # X_min 상대 좌표
                        max(y_min, y1) - y1,  # Y_min 상대 좌표
                        min(x_max, x2) - x1,  # X_max 상대 좌표
                        min(y_max, y2) - y1   # Y_max 상대 좌표
                    ]

                    scale_x = (w // 2) / (x2 - x1)
                    scale_y = (h // 2) / (y2 - y1)
                    scaled_bbox = [
                        clipped_bbox[0] * scale_x + pos_x,
                        clipped_bbox[1] * scale_y + pos_y,
                        clipped_bbox[2] * scale_x + pos_x,
                        clipped_bbox[3] * scale_y + pos_y
                    ]

                    mosaic_boxes.append(scaled_bbox)
                    mosaic_classes.append(ann["category_id"])

        dataset_dicts[0]["image"] = mosaic_image
        dataset_dicts[0]["annotations"] = [
            {"bbox": bbox, "bbox_mode": BoxMode.XYXY_ABS, "category_id": cls}
            for bbox, cls in zip(mosaic_boxes, mosaic_classes)
        ]

        return dataset_dicts[0]

# %%
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer

def visualize_mosaic(dataset_name, num_samples=2):
    dataset_dicts = DatasetCatalog.get(dataset_name)
    metadata = MetadataCatalog.get(dataset_name)

    mosaic_images = []

    for _ in range(num_samples):
        mosaic_transform = Mosaic(prob=1.0)
        mosaic_sample = mosaic_transform(random.sample(dataset_dicts, 4))

        image = mosaic_sample["image"]
        annotations = mosaic_sample["annotations"]

        visualizer = Visualizer(image[:, :, ::-1], metadata=metadata, scale=1.0)
        for ann in annotations:
            bbox = ann["bbox"]
            category_id = ann["category_id"]
            visualizer.draw_box(bbox, edge_color="red", line_style="-")
            visualizer.draw_text(str(category_id), (bbox[0], bbox[1]), color="white")

        output = visualizer.get_output()
        mosaic_images.append(output.get_image())

    fig, axes = plt.subplots(1, num_samples, figsize=(num_samples * 8, 8))

    for i in range(num_samples):
        axes[i].imshow(mosaic_images[i])
        axes[i].axis("off")
        axes[i].set_title(f"Mosaic Sample {i+1}")

    plt.show()

visualize_mosaic("colonoscopy_train", num_samples=2)

# %%
def adjust_augmentation(cfg, dataset_dicts):
    augmentations = [
        RandomFlip(prob=0.4, horizontal=True, vertical=False),
        RandomContrast(intensity_min=0.5, intensity_max=1.5),
        RandomBrightness(intensity_min=0.5, intensity_max=1.5),
        RandomLighting(scale=0.1),
        RandomRotation(angle=[-10, 10], expand=True),
        Mosaic(prob=0.2)
    ]
    mapper = DatasetMapper(cfg, is_train=True, augmentations=augmentations)
    return build_detection_train_loader(cfg, mapper=mapper)

# %%
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return adjust_augmentation(cfg)

    @classmethod
    def build_test_loader(cls, cfg, dataset_name):
        return build_detection_test_loader(cfg, dataset_name)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = cfg.OUTPUT_DIR
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

# %%
"""
_BASE_: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/faster_rcnn_R_50_FPN_1x.yaml"
MODEL:
  META_ARCHITECTURE: "GeneralizedRCNN"
  WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-50.pkl"
  MASK_ON: False
  RESNETS:
    DEPTH: 50
DATASETS:
  TRAIN: ("colonoscopy_train",)
  TEST: ("colonoscopy_val",)
DATALOADER:
  NUM_WORKERS: 2
SOLVER:
  IMS_PER_BATCH: 2
  BASE_LR: 0.0025
  MAX_ITER: 10000
  LR_SCHEDULER_NAME: "WarmupCosineLR"
  WARMUP_FACTOR: 0.001
  WARMUP_ITERS: 1000
INPUT:
  MIN_SIZE_TRAIN: (256, 512, 1024)
  MAX_SIZE_TRAIN: 1333
  MIN_SIZE_TEST: 256
  MAX_SIZE_TEST: 1333
TEST:
  EVAL_PERIOD: 5000
OUTPUT_DIR: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment"

"""
# Out:
# '\n_BASE_: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/faster_rcnn_R_50_FPN_1x.yaml"\nMODEL:\n  META_ARCHITECTURE: "GeneralizedRCNN"\n  WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-50.pkl"\n  MASK_ON: False\n  RESNETS:\n    DEPTH: 50\nDATASETS:\n  TRAIN: ("colonoscopy_train",)\n  TEST: ("colonoscopy_val",)\nDATALOADER:\n  NUM_WORKERS: 2\nSOLVER:\n  IMS_PER_BATCH: 2\n  BASE_LR: 0.0025\n  MAX_ITER: 10000\n  LR_SCHEDULER_NAME: "WarmupCosineLR" \n  WARMUP_FACTOR: 0.001\n  WARMUP_ITERS: 1000\nINPUT:\n  MIN_SIZE_TRAIN: (256, 512, 1024)\n  MAX_SIZE_TRAIN: 1333\n  MIN_SIZE_TEST: 256\n  MAX_SIZE_TEST: 1333\nTEST:\n  EVAL_PERIOD: 5000\nOUTPUT_DIR: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment"\n\n'

# %%
cfg = get_cfg()
cfg.merge_from_file("/content/drive/MyDrive/Endoscope Detection/colonoscopy/config.yaml")

cfg.OUTPUT_DIR = "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v4"
cfg.DATASETS.TRAIN = ("colonoscopy_train",)
cfg.DATASETS.TEST = ("colonoscopy_val",)

trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/23 16:47:20 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=81, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=320, bias=True)
#     )
#   )
# )
# [02/23 16:47:21 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [RandomFlip(prob=0.4), RandomContrast(intensity_min=0.5, intensity_max=1.5), RandomBrightness(intensity_min=0.5, intensity_max=1.5), RandomLighting(scale=0.1), RandomRotation(angle=[-10, 10])]
# [02/23 16:47:21 d2.data.build]: Removed 0 images with no usable annotations. 1277 images left.
# [02/23 16:47:21 d2.data.build]: Using training sampler TrainingSampler
# [02/23 16:47:21 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/23 16:47:21 d2.data.common]: Serializing 1277 elements to byte tensors and concatenating them all ...
# [02/23 16:47:21 d2.data.common]: Serialized dataset takes 0.40 MiB
# [02/23 16:47:21 d2.data.build]: Making batched data loader with batch_size=2
# [02/23 16:47:21 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/MSRA/R-50.pkl ...
# [02/23 16:47:21 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [02/23 16:47:21 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 54
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   fc1000.{bias, weight}
#   stem.conv1.bias
# [02/23 16:47:21 d2.engine.train_loop]: Starting training from iteration 0
# [02/23 16:47:24 d2.utils.events]:  eta: 0:22:55  iter: 19  total_loss: 3.94  loss_cls: 3.228  loss_box_reg: 0.02074  loss_rpn_cls: 0.6694  loss_rpn_loc: 0.009987    time: 0.1346  last_time: 0.1447  data_time: 0.0120  last_data_time: 0.0036   lr: 4.879e-05  max_mem: 1728M
# [02/23 16:47:27 d2.utils.events]:  eta: 0:23:36  iter: 39  total_loss: 0.8084  loss_cls: 0.1585  loss_box_reg: 0.04786  loss_rpn_cls: 0.572  loss_rpn_loc: 0.01107    time: 0.1476  last_time: 0.1346  data_time: 0.0143  last_data_time: 0.0049   lr: 9.7517e-05  max_mem: 1728M
# [02/23 16:47:30 d2.utils.events]:  eta: 0:22:59  iter: 59  total_loss: 0.5926  loss_cls: 0.1389  loss_box_reg: 0.05308  loss_rpn_cls: 0.3758  loss_rpn_loc: 0.01325    time: 0.1437  last_time: 0.1372  data_time: 0.0045  last_data_time: 0.0045   lr: 0.00014624  max_mem: 1728M
# [02/23 16:47:33 d2.utils.events]:  eta: 0:22:55  iter: 79  total_loss: 0.4596  loss_cls: 0.1732  loss_box_reg: 0.03475  loss_rpn_cls: 0.2035  loss_rpn_loc: 0.01366    time: 0.1418  last_time: 0.1425  data_time: 0.0044  last_data_time: 0.0046   lr: 0.00019497  max_mem: 1728M
# [02/23 16:47:35 d2.utils.events]:  eta: 0:22:44  iter: 99  total_loss: 0.4282  loss_cls: 0.2282  loss_box_reg: 0.07302  loss_rpn_cls: 0.1348  loss_rpn_loc: 0.01305    time: 0.1406  last_time: 0.1395  data_time: 0.0043  last_data_time: 0.0045   lr: 0.0002437  max_mem: 1728M
# [02/23 16:47:39 d2.utils.events]:  eta: 0:22:55  iter: 119  total_loss: 0.3694  loss_cls: 0.1477  loss_box_reg: 0.07442  loss_rpn_cls: 0.1016  loss_rpn_loc: 0.01182    time: 0.1446  last_time: 0.1615  data_time: 0.0110  last_data_time: 0.0286   lr: 0.00029242  max_mem: 1728M
# [02/23 16:47:41 d2.utils.events]:  eta: 0:22:48  iter: 139  total_loss: 0.3819  loss_cls: 0.1617  loss_box_reg: 0.1088  loss_rpn_cls: 0.07328  loss_rpn_loc: 0.01342    time: 0.1438  last_time: 0.1274  data_time: 0.0045  last_data_time: 0.0038   lr: 0.00034115  max_mem: 1728M
# [02/23 16:47:44 d2.utils.events]:  eta: 0:22:46  iter: 159  total_loss: 0.3106  loss_cls: 0.1435  loss_box_reg: 0.08553  loss_rpn_cls: 0.06673  loss_rpn_loc: 0.0101    time: 0.1434  last_time: 0.1324  data_time: 0.0042  last_data_time: 0.0039   lr: 0.00038987  max_mem: 1728M
# [02/23 16:47:47 d2.utils.events]:  eta: 0:22:43  iter: 179  total_loss: 0.2946  loss_cls: 0.1299  loss_box_reg: 0.08736  loss_rpn_cls: 0.05313  loss_rpn_loc: 0.008549    time: 0.1426  last_time: 0.1397  data_time: 0.0042  last_data_time: 0.0039   lr: 0.0004386  max_mem: 1728M
# [02/23 16:47:50 d2.utils.events]:  eta: 0:22:39  iter: 199  total_loss: 0.304  loss_cls: 0.1303  loss_box_reg: 0.0922  loss_rpn_cls: 0.06073  loss_rpn_loc: 0.01055    time: 0.1426  last_time: 0.1655  data_time: 0.0069  last_data_time: 0.0296   lr: 0.00048733  max_mem: 1728M
# [02/23 16:47:53 d2.utils.events]:  eta: 0:22:44  iter: 219  total_loss: 0.2785  loss_cls: 0.1227  loss_box_reg: 0.09943  loss_rpn_cls: 0.0496  loss_rpn_loc: 0.009865    time: 0.1443  last_time: 0.1464  data_time: 0.0144  last_data_time: 0.0043   lr: 0.00053605  max_mem: 1728M
# [02/23 16:47:56 d2.utils.events]:  eta: 0:22:40  iter: 239  total_loss: 0.3121  loss_cls: 0.132  loss_box_reg: 0.0983  loss_rpn_cls: 0.06863  loss_rpn_loc: 0.01104    time: 0.1437  last_time: 0.1410  data_time: 0.0041  last_data_time: 0.0036   lr: 0.00058478  max_mem: 1728M
# [02/23 16:47:59 d2.utils.events]:  eta: 0:22:37  iter: 259  total_loss: 0.2419  loss_cls: 0.1052  loss_box_reg: 0.08354  loss_rpn_cls: 0.04984  loss_rpn_loc: 0.008836    time: 0.1434  last_time: 0.1266  data_time: 0.0046  last_data_time: 0.0038   lr: 0.00063351  max_mem: 1728M
# [02/23 16:48:01 d2.utils.events]:  eta: 0:22:31  iter: 279  total_loss: 0.2659  loss_cls: 0.1162  loss_box_reg: 0.08653  loss_rpn_cls: 0.04565  loss_rpn_loc: 0.008293    time: 0.1429  last_time: 0.1338  data_time: 0.0052  last_data_time: 0.0049   lr: 0.00068223  max_mem: 1728M
# [02/23 16:48:04 d2.utils.events]:  eta: 0:22:33  iter: 299  total_loss: 0.2763  loss_cls: 0.1149  loss_box_reg: 0.09693  loss_rpn_cls: 0.04357  loss_rpn_loc: 0.009629    time: 0.1437  last_time: 0.1746  data_time: 0.0103  last_data_time: 0.0075   lr: 0.00073096  max_mem: 1728M
# [02/23 16:48:07 d2.utils.events]:  eta: 0:22:32  iter: 319  total_loss: 0.2879  loss_cls: 0.1186  loss_box_reg: 0.08735  loss_rpn_cls: 0.05423  loss_rpn_loc: 0.009482    time: 0.1443  last_time: 0.1345  data_time: 0.0075  last_data_time: 0.0040   lr: 0.00077969  max_mem: 1728M
# [02/23 16:48:10 d2.utils.events]:  eta: 0:22:26  iter: 339  total_loss: 0.2929  loss_cls: 0.1317  loss_box_reg: 0.1154  loss_rpn_cls: 0.04107  loss_rpn_loc: 0.008127    time: 0.1437  last_time: 0.1340  data_time: 0.0042  last_data_time: 0.0052   lr: 0.00082841  max_mem: 1728M
# [02/23 16:48:13 d2.utils.events]:  eta: 0:22:25  iter: 359  total_loss: 0.2838  loss_cls: 0.1226  loss_box_reg: 0.1004  loss_rpn_cls: 0.03589  loss_rpn_loc: 0.008565    time: 0.1435  last_time: 0.1582  data_time: 0.0056  last_data_time: 0.0080   lr: 0.00087714  max_mem: 1728M
# [02/23 16:48:16 d2.utils.events]:  eta: 0:22:20  iter: 379  total_loss: 0.285  loss_cls: 0.1121  loss_box_reg: 0.1083  loss_rpn_cls: 0.03747  loss_rpn_loc: 0.01201    time: 0.1431  last_time: 0.1336  data_time: 0.0045  last_data_time: 0.0047   lr: 0.00092587  max_mem: 1728M
# [02/23 16:48:19 d2.utils.events]:  eta: 0:22:22  iter: 399  total_loss: 0.3413  loss_cls: 0.1494  loss_box_reg: 0.1244  loss_rpn_cls: 0.04558  loss_rpn_loc: 0.009234    time: 0.1444  last_time: 0.1746  data_time: 0.0112  last_data_time: 0.0055   lr: 0.00097459  max_mem: 1728M
# [02/23 16:48:22 d2.utils.events]:  eta: 0:22:17  iter: 419  total_loss: 0.2654  loss_cls: 0.1234  loss_box_reg: 0.1057  loss_rpn_cls: 0.03686  loss_rpn_loc: 0.01031    time: 0.1439  last_time: 0.1303  data_time: 0.0045  last_data_time: 0.0038   lr: 0.0010233  max_mem: 1728M
# [02/23 16:48:24 d2.utils.events]:  eta: 0:22:10  iter: 439  total_loss: 0.3043  loss_cls: 0.1412  loss_box_reg: 0.114  loss_rpn_cls: 0.04104  loss_rpn_loc: 0.008578    time: 0.1435  last_time: 0.1357  data_time: 0.0043  last_data_time: 0.0041   lr: 0.001072  max_mem: 1728M
# [02/23 16:48:27 d2.utils.events]:  eta: 0:22:04  iter: 459  total_loss: 0.3034  loss_cls: 0.1261  loss_box_reg: 0.1042  loss_rpn_cls: 0.05063  loss_rpn_loc: 0.01103    time: 0.1430  last_time: 0.1369  data_time: 0.0045  last_data_time: 0.0040   lr: 0.0011208  max_mem: 1728M
# [02/23 16:48:30 d2.utils.events]:  eta: 0:22:00  iter: 479  total_loss: 0.2887  loss_cls: 0.1169  loss_box_reg: 0.1139  loss_rpn_cls: 0.0325  loss_rpn_loc: 0.008439    time: 0.1429  last_time: 0.1504  data_time: 0.0045  last_data_time: 0.0050   lr: 0.0011695  max_mem: 1728M
# [02/23 16:48:33 d2.utils.events]:  eta: 0:21:59  iter: 499  total_loss: 0.2626  loss_cls: 0.118  loss_box_reg: 0.1052  loss_rpn_cls: 0.03467  loss_rpn_loc: 0.009082    time: 0.1433  last_time: 0.1297  data_time: 0.0101  last_data_time: 0.0040   lr: 0.0012182  max_mem: 1728M
# [02/23 16:48:36 d2.utils.events]:  eta: 0:21:54  iter: 519  total_loss: 0.2512  loss_cls: 0.1014  loss_box_reg: 0.09777  loss_rpn_cls: 0.03679  loss_rpn_loc: 0.008465    time: 0.1428  last_time: 0.1254  data_time: 0.0043  last_data_time: 0.0044   lr: 0.001267  max_mem: 1728M
# [02/23 16:48:38 d2.utils.events]:  eta: 0:21:48  iter: 539  total_loss: 0.2383  loss_cls: 0.1021  loss_box_reg: 0.09756  loss_rpn_cls: 0.02683  loss_rpn_loc: 0.006637    time: 0.1425  last_time: 0.1359  data_time: 0.0043  last_data_time: 0.0051   lr: 0.0013157  max_mem: 1728M
# [02/23 16:48:41 d2.utils.events]:  eta: 0:21:44  iter: 559  total_loss: 0.3084  loss_cls: 0.1221  loss_box_reg: 0.1173  loss_rpn_cls: 0.03091  loss_rpn_loc: 0.00932    time: 0.1422  last_time: 0.1372  data_time: 0.0041  last_data_time: 0.0043   lr: 0.0013644  max_mem: 1728M
# [02/23 16:48:44 d2.utils.events]:  eta: 0:21:45  iter: 579  total_loss: 0.3157  loss_cls: 0.1271  loss_box_reg: 0.1022  loss_rpn_cls: 0.03556  loss_rpn_loc: 0.00984    time: 0.1427  last_time: 0.1699  data_time: 0.0105  last_data_time: 0.0276   lr: 0.0014131  max_mem: 1728M
# [02/23 16:48:47 d2.utils.events]:  eta: 0:21:42  iter: 599  total_loss: 0.232  loss_cls: 0.1078  loss_box_reg: 0.09376  loss_rpn_cls: 0.03582  loss_rpn_loc: 0.006824    time: 0.1428  last_time: 0.1247  data_time: 0.0090  last_data_time: 0.0036   lr: 0.0014619  max_mem: 1728M
# [02/23 16:48:50 d2.utils.events]:  eta: 0:21:36  iter: 619  total_loss: 0.2801  loss_cls: 0.1078  loss_box_reg: 0.1206  loss_rpn_cls: 0.02847  loss_rpn_loc: 0.008381    time: 0.1426  last_time: 0.1379  data_time: 0.0043  last_data_time: 0.0046   lr: 0.0015106  max_mem: 1728M
# [02/23 16:48:52 d2.utils.events]:  eta: 0:21:31  iter: 639  total_loss: 0.2778  loss_cls: 0.1105  loss_box_reg: 0.1112  loss_rpn_cls: 0.03741  loss_rpn_loc: 0.013    time: 0.1423  last_time: 0.1366  data_time: 0.0044  last_data_time: 0.0044   lr: 0.0015593  max_mem: 1728M
# [02/23 16:48:55 d2.utils.events]:  eta: 0:21:25  iter: 659  total_loss: 0.2726  loss_cls: 0.1039  loss_box_reg: 0.1188  loss_rpn_cls: 0.0353  loss_rpn_loc: 0.01147    time: 0.1420  last_time: 0.1208  data_time: 0.0053  last_data_time: 0.0037   lr: 0.001608  max_mem: 1728M
# [02/23 16:48:58 d2.utils.events]:  eta: 0:21:25  iter: 679  total_loss: 0.2487  loss_cls: 0.112  loss_box_reg: 0.09334  loss_rpn_cls: 0.032  loss_rpn_loc: 0.00921    time: 0.1422  last_time: 0.1655  data_time: 0.0080  last_data_time: 0.0051   lr: 0.0016568  max_mem: 1728M
# [02/23 16:49:01 d2.utils.events]:  eta: 0:21:22  iter: 699  total_loss: 0.2427  loss_cls: 0.1041  loss_box_reg: 0.1048  loss_rpn_cls: 0.02677  loss_rpn_loc: 0.007236    time: 0.1421  last_time: 0.1300  data_time: 0.0052  last_data_time: 0.0043   lr: 0.0017055  max_mem: 1728M
# [02/23 16:49:03 d2.utils.events]:  eta: 0:21:14  iter: 719  total_loss: 0.3029  loss_cls: 0.1328  loss_box_reg: 0.1035  loss_rpn_cls: 0.04836  loss_rpn_loc: 0.01256    time: 0.1417  last_time: 0.1334  data_time: 0.0040  last_data_time: 0.0041   lr: 0.0017542  max_mem: 1728M
# [02/23 16:49:06 d2.utils.events]:  eta: 0:21:10  iter: 739  total_loss: 0.2248  loss_cls: 0.1006  loss_box_reg: 0.1007  loss_rpn_cls: 0.02374  loss_rpn_loc: 0.008065    time: 0.1415  last_time: 0.1251  data_time: 0.0044  last_data_time: 0.0038   lr: 0.0018029  max_mem: 1728M
# [02/23 16:49:09 d2.utils.events]:  eta: 0:21:07  iter: 759  total_loss: 0.2197  loss_cls: 0.07797  loss_box_reg: 0.1078  loss_rpn_cls: 0.02369  loss_rpn_loc: 0.01026    time: 0.1414  last_time: 0.1810  data_time: 0.0047  last_data_time: 0.0073   lr: 0.0018517  max_mem: 1728M
# [02/23 16:49:12 d2.utils.events]:  eta: 0:21:07  iter: 779  total_loss: 0.2509  loss_cls: 0.1086  loss_box_reg: 0.1085  loss_rpn_cls: 0.02529  loss_rpn_loc: 0.007496    time: 0.1418  last_time: 0.1369  data_time: 0.0193  last_data_time: 0.0046   lr: 0.0019004  max_mem: 1728M
# [02/23 16:49:15 d2.utils.events]:  eta: 0:21:03  iter: 799  total_loss: 0.2113  loss_cls: 0.08712  loss_box_reg: 0.08962  loss_rpn_cls: 0.02376  loss_rpn_loc: 0.00631    time: 0.1416  last_time: 0.1302  data_time: 0.0040  last_data_time: 0.0038   lr: 0.0019491  max_mem: 1728M
# [02/23 16:49:17 d2.utils.events]:  eta: 0:20:59  iter: 819  total_loss: 0.3137  loss_cls: 0.1428  loss_box_reg: 0.118  loss_rpn_cls: 0.02899  loss_rpn_loc: 0.00857    time: 0.1414  last_time: 0.1243  data_time: 0.0042  last_data_time: 0.0035   lr: 0.0019978  max_mem: 1728M
# [02/23 16:49:20 d2.utils.events]:  eta: 0:20:55  iter: 839  total_loss: 0.2316  loss_cls: 0.103  loss_box_reg: 0.09823  loss_rpn_cls: 0.02664  loss_rpn_loc: 0.01016    time: 0.1412  last_time: 0.1243  data_time: 0.0039  last_data_time: 0.0039   lr: 0.0020466  max_mem: 1728M
# [02/23 16:49:23 d2.utils.events]:  eta: 0:20:52  iter: 859  total_loss: 0.2257  loss_cls: 0.08381  loss_box_reg: 0.09018  loss_rpn_cls: 0.02506  loss_rpn_loc: 0.007863    time: 0.1411  last_time: 0.1520  data_time: 0.0075  last_data_time: 0.0160   lr: 0.0020953  max_mem: 1728M
# [02/23 16:49:26 d2.utils.events]:  eta: 0:20:51  iter: 879  total_loss: 0.2258  loss_cls: 0.09311  loss_box_reg: 0.09742  loss_rpn_cls: 0.02132  loss_rpn_loc: 0.008619    time: 0.1414  last_time: 0.1229  data_time: 0.0108  last_data_time: 0.0043   lr: 0.002144  max_mem: 1728M
# [02/23 16:49:29 d2.utils.events]:  eta: 0:20:47  iter: 899  total_loss: 0.2615  loss_cls: 0.103  loss_box_reg: 0.1054  loss_rpn_cls: 0.0311  loss_rpn_loc: 0.008719    time: 0.1412  last_time: 0.1484  data_time: 0.0046  last_data_time: 0.0055   lr: 0.0021928  max_mem: 1728M
# [02/23 16:49:31 d2.utils.events]:  eta: 0:20:43  iter: 919  total_loss: 0.2981  loss_cls: 0.1243  loss_box_reg: 0.1004  loss_rpn_cls: 0.043  loss_rpn_loc: 0.01222    time: 0.1410  last_time: 0.1317  data_time: 0.0043  last_data_time: 0.0044   lr: 0.0022415  max_mem: 1728M
# [02/23 16:49:34 d2.utils.events]:  eta: 0:20:38  iter: 939  total_loss: 0.2448  loss_cls: 0.1068  loss_box_reg: 0.09427  loss_rpn_cls: 0.02693  loss_rpn_loc: 0.009084    time: 0.1408  last_time: 0.1490  data_time: 0.0042  last_data_time: 0.0060   lr: 0.0022902  max_mem: 1728M
# [02/23 16:49:37 d2.utils.events]:  eta: 0:20:35  iter: 959  total_loss: 0.1892  loss_cls: 0.08159  loss_box_reg: 0.08943  loss_rpn_cls: 0.01764  loss_rpn_loc: 0.007488    time: 0.1408  last_time: 0.1592  data_time: 0.0078  last_data_time: 0.0093   lr: 0.0023389  max_mem: 1728M
# [02/23 16:49:40 d2.utils.events]:  eta: 0:20:33  iter: 979  total_loss: 0.2551  loss_cls: 0.1039  loss_box_reg: 0.1096  loss_rpn_cls: 0.02839  loss_rpn_loc: 0.01054    time: 0.1408  last_time: 0.1374  data_time: 0.0083  last_data_time: 0.0051   lr: 0.0023877  max_mem: 1728M
# [02/23 16:49:42 d2.utils.events]:  eta: 0:20:30  iter: 999  total_loss: 0.2518  loss_cls: 0.1207  loss_box_reg: 0.1112  loss_rpn_cls: 0.02518  loss_rpn_loc: 0.008693    time: 0.1407  last_time: 0.1334  data_time: 0.0043  last_data_time: 0.0041   lr: 0.0024364  max_mem: 1728M
# [02/23 16:49:45 d2.utils.events]:  eta: 0:20:25  iter: 1019  total_loss: 0.265  loss_cls: 0.1125  loss_box_reg: 0.1121  loss_rpn_cls: 0.02101  loss_rpn_loc: 0.009299    time: 0.1404  last_time: 0.1333  data_time: 0.0040  last_data_time: 0.0042   lr: 0.0024365  max_mem: 1728M
# [02/23 16:49:47 d2.utils.events]:  eta: 0:20:20  iter: 1039  total_loss: 0.2309  loss_cls: 0.1044  loss_box_reg: 0.1037  loss_rpn_cls: 0.01869  loss_rpn_loc: 0.00754    time: 0.1403  last_time: 0.1337  data_time: 0.0047  last_data_time: 0.0044   lr: 0.002434  max_mem: 1728M
# [02/23 16:49:51 d2.utils.events]:  eta: 0:20:19  iter: 1059  total_loss: 0.2246  loss_cls: 0.08937  loss_box_reg: 0.09177  loss_rpn_cls: 0.02553  loss_rpn_loc: 0.009819    time: 0.1406  last_time: 0.1692  data_time: 0.0120  last_data_time: 0.0263   lr: 0.0024315  max_mem: 1728M
# [02/23 16:49:54 d2.utils.events]:  eta: 0:20:16  iter: 1079  total_loss: 0.2068  loss_cls: 0.09171  loss_box_reg: 0.09057  loss_rpn_cls: 0.02526  loss_rpn_loc: 0.007224    time: 0.1407  last_time: 0.1520  data_time: 0.0079  last_data_time: 0.0051   lr: 0.0024289  max_mem: 1728M
# [02/23 16:49:56 d2.utils.events]:  eta: 0:20:12  iter: 1099  total_loss: 0.2125  loss_cls: 0.0896  loss_box_reg: 0.09709  loss_rpn_cls: 0.02741  loss_rpn_loc: 0.008075    time: 0.1405  last_time: 0.1237  data_time: 0.0045  last_data_time: 0.0037   lr: 0.0024262  max_mem: 1728M
# [02/23 16:49:59 d2.utils.events]:  eta: 0:20:04  iter: 1119  total_loss: 0.2422  loss_cls: 0.09784  loss_box_reg: 0.1119  loss_rpn_cls: 0.01914  loss_rpn_loc: 0.008541    time: 0.1403  last_time: 0.1216  data_time: 0.0048  last_data_time: 0.0044   lr: 0.0024236  max_mem: 1728M
# [02/23 16:50:01 d2.utils.events]:  eta: 0:20:00  iter: 1139  total_loss: 0.2269  loss_cls: 0.09653  loss_box_reg: 0.1137  loss_rpn_cls: 0.01318  loss_rpn_loc: 0.007025    time: 0.1401  last_time: 0.1310  data_time: 0.0041  last_data_time: 0.0046   lr: 0.0024208  max_mem: 1728M
# [02/23 16:50:04 d2.utils.events]:  eta: 0:19:58  iter: 1159  total_loss: 0.2392  loss_cls: 0.107  loss_box_reg: 0.106  loss_rpn_cls: 0.02609  loss_rpn_loc: 0.005413    time: 0.1404  last_time: 0.1720  data_time: 0.0094  last_data_time: 0.0126   lr: 0.0024181  max_mem: 1728M
# [02/23 16:50:07 d2.utils.events]:  eta: 0:19:56  iter: 1179  total_loss: 0.1826  loss_cls: 0.07186  loss_box_reg: 0.08144  loss_rpn_cls: 0.01906  loss_rpn_loc: 0.007788    time: 0.1403  last_time: 0.1265  data_time: 0.0055  last_data_time: 0.0041   lr: 0.0024152  max_mem: 1728M
# [02/23 16:50:10 d2.utils.events]:  eta: 0:19:51  iter: 1199  total_loss: 0.2251  loss_cls: 0.09558  loss_box_reg: 0.1138  loss_rpn_cls: 0.01256  loss_rpn_loc: 0.008173    time: 0.1402  last_time: 0.1371  data_time: 0.0041  last_data_time: 0.0036   lr: 0.0024124  max_mem: 1728M
# [02/23 16:50:12 d2.utils.events]:  eta: 0:19:46  iter: 1219  total_loss: 0.2279  loss_cls: 0.09018  loss_box_reg: 0.09828  loss_rpn_cls: 0.01784  loss_rpn_loc: 0.007198    time: 0.1401  last_time: 0.1230  data_time: 0.0046  last_data_time: 0.0041   lr: 0.0024095  max_mem: 1728M
# [02/23 16:50:15 d2.utils.events]:  eta: 0:19:42  iter: 1239  total_loss: 0.218  loss_cls: 0.08941  loss_box_reg: 0.1037  loss_rpn_cls: 0.01882  loss_rpn_loc: 0.009224    time: 0.1399  last_time: 0.1485  data_time: 0.0058  last_data_time: 0.0080   lr: 0.0024065  max_mem: 1728M
# [02/23 16:50:18 d2.utils.events]:  eta: 0:19:40  iter: 1259  total_loss: 0.265  loss_cls: 0.1041  loss_box_reg: 0.1088  loss_rpn_cls: 0.02645  loss_rpn_loc: 0.00764    time: 0.1401  last_time: 0.1381  data_time: 0.0130  last_data_time: 0.0056   lr: 0.0024035  max_mem: 1728M
# [02/23 16:50:21 d2.utils.events]:  eta: 0:19:36  iter: 1279  total_loss: 0.2174  loss_cls: 0.09899  loss_box_reg: 0.09561  loss_rpn_cls: 0.01894  loss_rpn_loc: 0.007249    time: 0.1400  last_time: 0.1294  data_time: 0.0047  last_data_time: 0.0044   lr: 0.0024004  max_mem: 1728M
# [02/23 16:50:23 d2.utils.events]:  eta: 0:19:30  iter: 1299  total_loss: 0.2112  loss_cls: 0.09217  loss_box_reg: 0.09311  loss_rpn_cls: 0.01936  loss_rpn_loc: 0.008991    time: 0.1398  last_time: 0.1246  data_time: 0.0044  last_data_time: 0.0047   lr: 0.0023973  max_mem: 1728M
# [02/23 16:50:26 d2.utils.events]:  eta: 0:19:24  iter: 1319  total_loss: 0.2131  loss_cls: 0.09231  loss_box_reg: 0.0926  loss_rpn_cls: 0.02367  loss_rpn_loc: 0.007262    time: 0.1396  last_time: 0.1308  data_time: 0.0042  last_data_time: 0.0050   lr: 0.0023942  max_mem: 1728M
# [02/23 16:50:29 d2.utils.events]:  eta: 0:19:21  iter: 1339  total_loss: 0.2187  loss_cls: 0.0898  loss_box_reg: 0.107  loss_rpn_cls: 0.01538  loss_rpn_loc: 0.007329    time: 0.1395  last_time: 0.1369  data_time: 0.0055  last_data_time: 0.0149   lr: 0.002391  max_mem: 1728M
# [02/23 16:50:31 d2.utils.events]:  eta: 0:19:18  iter: 1359  total_loss: 0.2187  loss_cls: 0.09428  loss_box_reg: 0.1065  loss_rpn_cls: 0.01989  loss_rpn_loc: 0.00954    time: 0.1396  last_time: 0.1302  data_time: 0.0082  last_data_time: 0.0043   lr: 0.0023878  max_mem: 1728M
# [02/23 16:50:34 d2.utils.events]:  eta: 0:19:15  iter: 1379  total_loss: 0.2424  loss_cls: 0.1027  loss_box_reg: 0.1005  loss_rpn_cls: 0.02374  loss_rpn_loc: 0.008983    time: 0.1395  last_time: 0.1233  data_time: 0.0050  last_data_time: 0.0046   lr: 0.0023845  max_mem: 1728M
# [02/23 16:50:37 d2.utils.events]:  eta: 0:19:10  iter: 1399  total_loss: 0.2022  loss_cls: 0.08786  loss_box_reg: 0.09936  loss_rpn_cls: 0.02092  loss_rpn_loc: 0.007602    time: 0.1393  last_time: 0.1331  data_time: 0.0044  last_data_time: 0.0047   lr: 0.0023812  max_mem: 1728M
# [02/23 16:50:39 d2.utils.events]:  eta: 0:19:07  iter: 1419  total_loss: 0.2259  loss_cls: 0.08641  loss_box_reg: 0.1151  loss_rpn_cls: 0.01643  loss_rpn_loc: 0.006641    time: 0.1392  last_time: 0.1275  data_time: 0.0041  last_data_time: 0.0037   lr: 0.0023778  max_mem: 1728M
# [02/23 16:50:42 d2.utils.events]:  eta: 0:19:05  iter: 1439  total_loss: 0.2285  loss_cls: 0.0936  loss_box_reg: 0.1018  loss_rpn_cls: 0.01938  loss_rpn_loc: 0.008862    time: 0.1393  last_time: 0.1583  data_time: 0.0070  last_data_time: 0.0041   lr: 0.0023744  max_mem: 1728M
# [02/23 16:50:45 d2.utils.events]:  eta: 0:19:03  iter: 1459  total_loss: 0.2366  loss_cls: 0.09677  loss_box_reg: 0.1084  loss_rpn_cls: 0.01883  loss_rpn_loc: 0.007369    time: 0.1395  last_time: 0.1413  data_time: 0.0158  last_data_time: 0.0046   lr: 0.002371  max_mem: 1728M
# [02/23 16:50:48 d2.utils.events]:  eta: 0:19:00  iter: 1479  total_loss: 0.2039  loss_cls: 0.08029  loss_box_reg: 0.1031  loss_rpn_cls: 0.01526  loss_rpn_loc: 0.005666    time: 0.1394  last_time: 0.1306  data_time: 0.0047  last_data_time: 0.0046   lr: 0.0023675  max_mem: 1728M
# [02/23 16:50:51 d2.utils.events]:  eta: 0:18:56  iter: 1499  total_loss: 0.1987  loss_cls: 0.08827  loss_box_reg: 0.09766  loss_rpn_cls: 0.01571  loss_rpn_loc: 0.004324    time: 0.1393  last_time: 0.1456  data_time: 0.0042  last_data_time: 0.0041   lr: 0.0023639  max_mem: 1728M
# [02/23 16:50:53 d2.utils.events]:  eta: 0:18:54  iter: 1519  total_loss: 0.2027  loss_cls: 0.0986  loss_box_reg: 0.1031  loss_rpn_cls: 0.01111  loss_rpn_loc: 0.006718    time: 0.1393  last_time: 0.1329  data_time: 0.0043  last_data_time: 0.0039   lr: 0.0023604  max_mem: 1728M
# [02/23 16:50:56 d2.utils.events]:  eta: 0:18:53  iter: 1539  total_loss: 0.2098  loss_cls: 0.08886  loss_box_reg: 0.09239  loss_rpn_cls: 0.0183  loss_rpn_loc: 0.007259    time: 0.1393  last_time: 0.1421  data_time: 0.0066  last_data_time: 0.0045   lr: 0.0023567  max_mem: 1728M
# [02/23 16:50:59 d2.utils.events]:  eta: 0:18:51  iter: 1559  total_loss: 0.2029  loss_cls: 0.08743  loss_box_reg: 0.08897  loss_rpn_cls: 0.009703  loss_rpn_loc: 0.006198    time: 0.1394  last_time: 0.1381  data_time: 0.0093  last_data_time: 0.0039   lr: 0.002353  max_mem: 1728M
# [02/23 16:51:02 d2.utils.events]:  eta: 0:18:46  iter: 1579  total_loss: 0.1974  loss_cls: 0.06958  loss_box_reg: 0.09246  loss_rpn_cls: 0.01032  loss_rpn_loc: 0.005577    time: 0.1393  last_time: 0.1314  data_time: 0.0044  last_data_time: 0.0043   lr: 0.0023493  max_mem: 1728M
# [02/23 16:51:04 d2.utils.events]:  eta: 0:18:42  iter: 1599  total_loss: 0.2331  loss_cls: 0.08998  loss_box_reg: 0.1151  loss_rpn_cls: 0.01467  loss_rpn_loc: 0.01179    time: 0.1392  last_time: 0.1214  data_time: 0.0044  last_data_time: 0.0037   lr: 0.0023456  max_mem: 1728M
# [02/23 16:51:07 d2.utils.events]:  eta: 0:18:38  iter: 1619  total_loss: 0.2356  loss_cls: 0.104  loss_box_reg: 0.1147  loss_rpn_cls: 0.01527  loss_rpn_loc: 0.004989    time: 0.1391  last_time: 0.1330  data_time: 0.0041  last_data_time: 0.0041   lr: 0.0023418  max_mem: 1728M
# [02/23 16:51:10 d2.utils.events]:  eta: 0:18:37  iter: 1639  total_loss: 0.2235  loss_cls: 0.08196  loss_box_reg: 0.1068  loss_rpn_cls: 0.01272  loss_rpn_loc: 0.007899    time: 0.1392  last_time: 0.1540  data_time: 0.0078  last_data_time: 0.0042   lr: 0.0023379  max_mem: 1728M
# [02/23 16:51:13 d2.utils.events]:  eta: 0:18:34  iter: 1659  total_loss: 0.2595  loss_cls: 0.106  loss_box_reg: 0.1096  loss_rpn_cls: 0.02748  loss_rpn_loc: 0.008092    time: 0.1391  last_time: 0.1219  data_time: 0.0063  last_data_time: 0.0037   lr: 0.002334  max_mem: 1728M
# [02/23 16:51:15 d2.utils.events]:  eta: 0:18:29  iter: 1679  total_loss: 0.2459  loss_cls: 0.09258  loss_box_reg: 0.1163  loss_rpn_cls: 0.01574  loss_rpn_loc: 0.007017    time: 0.1390  last_time: 0.1247  data_time: 0.0046  last_data_time: 0.0035   lr: 0.0023301  max_mem: 1728M
# [02/23 16:51:18 d2.utils.events]:  eta: 0:18:25  iter: 1699  total_loss: 0.2395  loss_cls: 0.1101  loss_box_reg: 0.1065  loss_rpn_cls: 0.01275  loss_rpn_loc: 0.007309    time: 0.1389  last_time: 0.1344  data_time: 0.0041  last_data_time: 0.0040   lr: 0.0023261  max_mem: 1728M
# [02/23 16:51:20 d2.utils.events]:  eta: 0:18:22  iter: 1719  total_loss: 0.2239  loss_cls: 0.1006  loss_box_reg: 0.1091  loss_rpn_cls: 0.01405  loss_rpn_loc: 0.008418    time: 0.1388  last_time: 0.1476  data_time: 0.0041  last_data_time: 0.0046   lr: 0.0023221  max_mem: 1728M
# [02/23 16:51:24 d2.utils.events]:  eta: 0:18:22  iter: 1739  total_loss: 0.2146  loss_cls: 0.09119  loss_box_reg: 0.1037  loss_rpn_cls: 0.01586  loss_rpn_loc: 0.007489    time: 0.1390  last_time: 0.1849  data_time: 0.0080  last_data_time: 0.0127   lr: 0.0023181  max_mem: 1728M
# [02/23 16:51:26 d2.utils.events]:  eta: 0:18:18  iter: 1759  total_loss: 0.2404  loss_cls: 0.11  loss_box_reg: 0.1111  loss_rpn_cls: 0.02009  loss_rpn_loc: 0.008122    time: 0.1389  last_time: 0.1291  data_time: 0.0043  last_data_time: 0.0041   lr: 0.0023139  max_mem: 1728M
# [02/23 16:51:29 d2.utils.events]:  eta: 0:18:12  iter: 1779  total_loss: 0.2347  loss_cls: 0.09176  loss_box_reg: 0.1295  loss_rpn_cls: 0.01124  loss_rpn_loc: 0.006384    time: 0.1388  last_time: 0.1505  data_time: 0.0042  last_data_time: 0.0060   lr: 0.0023098  max_mem: 1728M
# [02/23 16:51:31 d2.utils.events]:  eta: 0:18:09  iter: 1799  total_loss: 0.1967  loss_cls: 0.07374  loss_box_reg: 0.107  loss_rpn_cls: 0.009519  loss_rpn_loc: 0.00622    time: 0.1387  last_time: 0.1349  data_time: 0.0040  last_data_time: 0.0046   lr: 0.0023056  max_mem: 1728M
# [02/23 16:51:34 d2.utils.events]:  eta: 0:18:06  iter: 1819  total_loss: 0.2172  loss_cls: 0.09035  loss_box_reg: 0.1043  loss_rpn_cls: 0.01966  loss_rpn_loc: 0.007253    time: 0.1386  last_time: 0.1772  data_time: 0.0047  last_data_time: 0.0054   lr: 0.0023014  max_mem: 1728M
# [02/23 16:51:37 d2.utils.events]:  eta: 0:18:06  iter: 1839  total_loss: 0.2043  loss_cls: 0.07616  loss_box_reg: 0.1072  loss_rpn_cls: 0.01075  loss_rpn_loc: 0.006628    time: 0.1389  last_time: 0.1384  data_time: 0.0086  last_data_time: 0.0043   lr: 0.0022971  max_mem: 1728M
# [02/23 16:51:40 d2.utils.events]:  eta: 0:18:04  iter: 1859  total_loss: 0.2471  loss_cls: 0.09671  loss_box_reg: 0.1162  loss_rpn_cls: 0.01572  loss_rpn_loc: 0.007686    time: 0.1388  last_time: 0.1299  data_time: 0.0044  last_data_time: 0.0048   lr: 0.0022928  max_mem: 1728M
# [02/23 16:51:43 d2.utils.events]:  eta: 0:17:58  iter: 1879  total_loss: 0.2095  loss_cls: 0.07934  loss_box_reg: 0.1083  loss_rpn_cls: 0.01083  loss_rpn_loc: 0.009199    time: 0.1387  last_time: 0.1250  data_time: 0.0041  last_data_time: 0.0034   lr: 0.0022885  max_mem: 1728M
# [02/23 16:51:45 d2.utils.events]:  eta: 0:17:55  iter: 1899  total_loss: 0.2425  loss_cls: 0.08957  loss_box_reg: 0.09686  loss_rpn_cls: 0.0232  loss_rpn_loc: 0.006538    time: 0.1386  last_time: 0.1238  data_time: 0.0042  last_data_time: 0.0043   lr: 0.0022841  max_mem: 1728M
# [02/23 16:51:48 d2.utils.events]:  eta: 0:17:53  iter: 1919  total_loss: 0.212  loss_cls: 0.07618  loss_box_reg: 0.1121  loss_rpn_cls: 0.01934  loss_rpn_loc: 0.008141    time: 0.1386  last_time: 0.1400  data_time: 0.0071  last_data_time: 0.0154   lr: 0.0022796  max_mem: 1728M
# [02/23 16:51:51 d2.utils.events]:  eta: 0:17:52  iter: 1939  total_loss: 0.1986  loss_cls: 0.08626  loss_box_reg: 0.09446  loss_rpn_cls: 0.009701  loss_rpn_loc: 0.008041    time: 0.1387  last_time: 0.1367  data_time: 0.0133  last_data_time: 0.0037   lr: 0.0022752  max_mem: 1728M
# [02/23 16:51:54 d2.utils.events]:  eta: 0:17:48  iter: 1959  total_loss: 0.2035  loss_cls: 0.08792  loss_box_reg: 0.1092  loss_rpn_cls: 0.01021  loss_rpn_loc: 0.005787    time: 0.1386  last_time: 0.1404  data_time: 0.0044  last_data_time: 0.0045   lr: 0.0022707  max_mem: 1728M
# [02/23 16:51:56 d2.utils.events]:  eta: 0:17:45  iter: 1979  total_loss: 0.1887  loss_cls: 0.08019  loss_box_reg: 0.09366  loss_rpn_cls: 0.007862  loss_rpn_loc: 0.004763    time: 0.1386  last_time: 0.1283  data_time: 0.0041  last_data_time: 0.0034   lr: 0.0022661  max_mem: 1728M
# [02/23 16:51:59 d2.utils.events]:  eta: 0:17:42  iter: 1999  total_loss: 0.2096  loss_cls: 0.08142  loss_box_reg: 0.1016  loss_rpn_cls: 0.0143  loss_rpn_loc: 0.007247    time: 0.1385  last_time: 0.1406  data_time: 0.0041  last_data_time: 0.0042   lr: 0.0022615  max_mem: 1728M
# [02/23 16:52:02 d2.utils.events]:  eta: 0:17:40  iter: 2019  total_loss: 0.2211  loss_cls: 0.08486  loss_box_reg: 0.1021  loss_rpn_cls: 0.01671  loss_rpn_loc: 0.006107    time: 0.1385  last_time: 0.1607  data_time: 0.0066  last_data_time: 0.0137   lr: 0.0022569  max_mem: 1728M
# [02/23 16:52:05 d2.utils.events]:  eta: 0:17:37  iter: 2039  total_loss: 0.1682  loss_cls: 0.07155  loss_box_reg: 0.08802  loss_rpn_cls: 0.007699  loss_rpn_loc: 0.004698    time: 0.1386  last_time: 0.1238  data_time: 0.0103  last_data_time: 0.0035   lr: 0.0022522  max_mem: 1728M
# [02/23 16:52:07 d2.utils.events]:  eta: 0:17:34  iter: 2059  total_loss: 0.2396  loss_cls: 0.09435  loss_box_reg: 0.1176  loss_rpn_cls: 0.01655  loss_rpn_loc: 0.009388    time: 0.1385  last_time: 0.1451  data_time: 0.0039  last_data_time: 0.0043   lr: 0.0022475  max_mem: 1728M
# [02/23 16:52:10 d2.utils.events]:  eta: 0:17:30  iter: 2079  total_loss: 0.2116  loss_cls: 0.0864  loss_box_reg: 0.09583  loss_rpn_cls: 0.02186  loss_rpn_loc: 0.008929    time: 0.1384  last_time: 0.1211  data_time: 0.0043  last_data_time: 0.0040   lr: 0.0022427  max_mem: 1728M
# [02/23 16:52:12 d2.utils.events]:  eta: 0:17:28  iter: 2099  total_loss: 0.1695  loss_cls: 0.05459  loss_box_reg: 0.1041  loss_rpn_cls: 0.006722  loss_rpn_loc: 0.006215    time: 0.1383  last_time: 0.1317  data_time: 0.0041  last_data_time: 0.0047   lr: 0.0022379  max_mem: 1728M
# [02/23 16:52:15 d2.utils.events]:  eta: 0:17:26  iter: 2119  total_loss: 0.2159  loss_cls: 0.09463  loss_box_reg: 0.1037  loss_rpn_cls: 0.01748  loss_rpn_loc: 0.00558    time: 0.1384  last_time: 0.1703  data_time: 0.0082  last_data_time: 0.0046   lr: 0.0022331  max_mem: 1728M
# [02/23 16:52:18 d2.utils.events]:  eta: 0:17:23  iter: 2139  total_loss: 0.2422  loss_cls: 0.09976  loss_box_reg: 0.1265  loss_rpn_cls: 0.01377  loss_rpn_loc: 0.006992    time: 0.1384  last_time: 0.1197  data_time: 0.0071  last_data_time: 0.0038   lr: 0.0022282  max_mem: 1728M
# [02/23 16:52:21 d2.utils.events]:  eta: 0:17:19  iter: 2159  total_loss: 0.2085  loss_cls: 0.0778  loss_box_reg: 0.1192  loss_rpn_cls: 0.01122  loss_rpn_loc: 0.006944    time: 0.1383  last_time: 0.1218  data_time: 0.0040  last_data_time: 0.0038   lr: 0.0022233  max_mem: 1728M
# [02/23 16:52:23 d2.utils.events]:  eta: 0:17:14  iter: 2179  total_loss: 0.236  loss_cls: 0.08927  loss_box_reg: 0.09731  loss_rpn_cls: 0.03007  loss_rpn_loc: 0.009641    time: 0.1382  last_time: 0.1310  data_time: 0.0042  last_data_time: 0.0042   lr: 0.0022184  max_mem: 1728M
# [02/23 16:52:26 d2.utils.events]:  eta: 0:17:13  iter: 2199  total_loss: 0.199  loss_cls: 0.08721  loss_box_reg: 0.1012  loss_rpn_cls: 0.01528  loss_rpn_loc: 0.006912    time: 0.1382  last_time: 0.1321  data_time: 0.0047  last_data_time: 0.0041   lr: 0.0022134  max_mem: 1728M
# [02/23 16:52:29 d2.utils.events]:  eta: 0:17:11  iter: 2219  total_loss: 0.2852  loss_cls: 0.1185  loss_box_reg: 0.1277  loss_rpn_cls: 0.02116  loss_rpn_loc: 0.007993    time: 0.1382  last_time: 0.1804  data_time: 0.0092  last_data_time: 0.0043   lr: 0.0022084  max_mem: 1728M
# [02/23 16:52:32 d2.utils.events]:  eta: 0:17:09  iter: 2239  total_loss: 0.1837  loss_cls: 0.06946  loss_box_reg: 0.09618  loss_rpn_cls: 0.008383  loss_rpn_loc: 0.007472    time: 0.1383  last_time: 0.1355  data_time: 0.0046  last_data_time: 0.0050   lr: 0.0022033  max_mem: 1728M
# [02/23 16:52:34 d2.utils.events]:  eta: 0:17:06  iter: 2259  total_loss: 0.219  loss_cls: 0.09264  loss_box_reg: 0.1043  loss_rpn_cls: 0.01124  loss_rpn_loc: 0.006643    time: 0.1382  last_time: 0.1388  data_time: 0.0042  last_data_time: 0.0043   lr: 0.0021982  max_mem: 1728M
# [02/23 16:52:37 d2.utils.events]:  eta: 0:17:04  iter: 2279  total_loss: 0.2436  loss_cls: 0.1076  loss_box_reg: 0.116  loss_rpn_cls: 0.007558  loss_rpn_loc: 0.005918    time: 0.1382  last_time: 0.1333  data_time: 0.0041  last_data_time: 0.0040   lr: 0.0021931  max_mem: 1728M
# [02/23 16:52:40 d2.utils.events]:  eta: 0:17:02  iter: 2299  total_loss: 0.2761  loss_cls: 0.1243  loss_box_reg: 0.1266  loss_rpn_cls: 0.01917  loss_rpn_loc: 0.009383    time: 0.1381  last_time: 0.1267  data_time: 0.0049  last_data_time: 0.0038   lr: 0.0021879  max_mem: 1728M
# [02/23 16:52:42 d2.utils.events]:  eta: 0:17:00  iter: 2319  total_loss: 0.1969  loss_cls: 0.0843  loss_box_reg: 0.1006  loss_rpn_cls: 0.0153  loss_rpn_loc: 0.006422    time: 0.1381  last_time: 0.1457  data_time: 0.0072  last_data_time: 0.0039   lr: 0.0021827  max_mem: 1728M
# [02/23 16:52:45 d2.utils.events]:  eta: 0:16:58  iter: 2339  total_loss: 0.1866  loss_cls: 0.08086  loss_box_reg: 0.09239  loss_rpn_cls: 0.0111  loss_rpn_loc: 0.00631    time: 0.1381  last_time: 0.1366  data_time: 0.0050  last_data_time: 0.0041   lr: 0.0021774  max_mem: 1728M
# [02/23 16:52:48 d2.utils.events]:  eta: 0:16:54  iter: 2359  total_loss: 0.1966  loss_cls: 0.08856  loss_box_reg: 0.097  loss_rpn_cls: 0.005992  loss_rpn_loc: 0.005622    time: 0.1381  last_time: 0.1206  data_time: 0.0045  last_data_time: 0.0036   lr: 0.0021722  max_mem: 1728M
# [02/23 16:52:50 d2.utils.events]:  eta: 0:16:51  iter: 2379  total_loss: 0.1995  loss_cls: 0.08252  loss_box_reg: 0.1027  loss_rpn_cls: 0.01584  loss_rpn_loc: 0.007066    time: 0.1380  last_time: 0.1296  data_time: 0.0041  last_data_time: 0.0044   lr: 0.0021668  max_mem: 1728M
# [02/23 16:52:53 d2.utils.events]:  eta: 0:16:48  iter: 2399  total_loss: 0.2274  loss_cls: 0.08801  loss_box_reg: 0.1323  loss_rpn_cls: 0.01366  loss_rpn_loc: 0.006717    time: 0.1379  last_time: 0.1374  data_time: 0.0041  last_data_time: 0.0039   lr: 0.0021615  max_mem: 1728M
# ...
# [02/23 17:07:37 d2.utils.events]:  eta: 0:02:18  iter: 8939  total_loss: 0.1445  loss_cls: 0.04728  loss_box_reg: 0.09118  loss_rpn_cls: 0.002208  loss_rpn_loc: 0.00407    time: 0.1355  last_time: 0.1196  data_time: 0.0044  last_data_time: 0.0040   lr: 6.88e-05  max_mem: 1730M
# [02/23 17:07:39 d2.utils.events]:  eta: 0:02:15  iter: 8959  total_loss: 0.1497  loss_cls: 0.04723  loss_box_reg: 0.08594  loss_rpn_cls: 0.002253  loss_rpn_loc: 0.004704    time: 0.1355  last_time: 0.1459  data_time: 0.0043  last_data_time: 0.0049   lr: 6.6253e-05  max_mem: 1730M
# [02/23 17:07:42 d2.utils.events]:  eta: 0:02:13  iter: 8979  total_loss: 0.1707  loss_cls: 0.05587  loss_box_reg: 0.1095  loss_rpn_cls: 0.005012  loss_rpn_loc: 0.006091    time: 0.1354  last_time: 0.1230  data_time: 0.0042  last_data_time: 0.0038   lr: 6.3754e-05  max_mem: 1730M
# [02/23 17:07:45 d2.utils.events]:  eta: 0:02:10  iter: 8999  total_loss: 0.1655  loss_cls: 0.05221  loss_box_reg: 0.09347  loss_rpn_cls: 0.0049  loss_rpn_loc: 0.004091    time: 0.1355  last_time: 0.1558  data_time: 0.0118  last_data_time: 0.0052   lr: 6.1301e-05  max_mem: 1730M
# [02/23 17:07:48 d2.utils.events]:  eta: 0:02:08  iter: 9019  total_loss: 0.1187  loss_cls: 0.03675  loss_box_reg: 0.07128  loss_rpn_cls: 0.003095  loss_rpn_loc: 0.003508    time: 0.1355  last_time: 0.1213  data_time: 0.0046  last_data_time: 0.0039   lr: 5.8895e-05  max_mem: 1730M
# [02/23 17:07:50 d2.utils.events]:  eta: 0:02:05  iter: 9039  total_loss: 0.1504  loss_cls: 0.0508  loss_box_reg: 0.09012  loss_rpn_cls: 0.003328  loss_rpn_loc: 0.005148    time: 0.1355  last_time: 0.1304  data_time: 0.0043  last_data_time: 0.0041   lr: 5.6536e-05  max_mem: 1730M
# [02/23 17:07:53 d2.utils.events]:  eta: 0:02:02  iter: 9059  total_loss: 0.1517  loss_cls: 0.05365  loss_box_reg: 0.08458  loss_rpn_cls: 0.00356  loss_rpn_loc: 0.004515    time: 0.1354  last_time: 0.1287  data_time: 0.0043  last_data_time: 0.0044   lr: 5.4224e-05  max_mem: 1730M
# [02/23 17:07:55 d2.utils.events]:  eta: 0:01:59  iter: 9079  total_loss: 0.1845  loss_cls: 0.06177  loss_box_reg: 0.1087  loss_rpn_cls: 0.005031  loss_rpn_loc: 0.005079    time: 0.1354  last_time: 0.1270  data_time: 0.0041  last_data_time: 0.0037   lr: 5.196e-05  max_mem: 1730M
# [02/23 17:07:58 d2.utils.events]:  eta: 0:01:57  iter: 9099  total_loss: 0.1412  loss_cls: 0.04484  loss_box_reg: 0.08652  loss_rpn_cls: 0.004071  loss_rpn_loc: 0.00422    time: 0.1355  last_time: 0.1525  data_time: 0.0140  last_data_time: 0.0236   lr: 4.9743e-05  max_mem: 1730M
# [02/23 17:08:01 d2.utils.events]:  eta: 0:01:54  iter: 9119  total_loss: 0.1094  loss_cls: 0.03397  loss_box_reg: 0.06746  loss_rpn_cls: 0.002217  loss_rpn_loc: 0.004139    time: 0.1355  last_time: 0.1185  data_time: 0.0048  last_data_time: 0.0039   lr: 4.7573e-05  max_mem: 1730M
# [02/23 17:08:04 d2.utils.events]:  eta: 0:01:52  iter: 9139  total_loss: 0.1278  loss_cls: 0.04097  loss_box_reg: 0.08034  loss_rpn_cls: 0.005204  loss_rpn_loc: 0.005275    time: 0.1354  last_time: 0.1257  data_time: 0.0042  last_data_time: 0.0038   lr: 4.545e-05  max_mem: 1730M
# [02/23 17:08:06 d2.utils.events]:  eta: 0:01:49  iter: 9159  total_loss: 0.1251  loss_cls: 0.0387  loss_box_reg: 0.0802  loss_rpn_cls: 0.001881  loss_rpn_loc: 0.003477    time: 0.1354  last_time: 0.1296  data_time: 0.0042  last_data_time: 0.0049   lr: 4.3375e-05  max_mem: 1730M
# [02/23 17:08:09 d2.utils.events]:  eta: 0:01:46  iter: 9179  total_loss: 0.1298  loss_cls: 0.04014  loss_box_reg: 0.08516  loss_rpn_cls: 0.00419  loss_rpn_loc: 0.004714    time: 0.1354  last_time: 0.1192  data_time: 0.0042  last_data_time: 0.0043   lr: 4.1348e-05  max_mem: 1730M
# [02/23 17:08:12 d2.utils.events]:  eta: 0:01:44  iter: 9199  total_loss: 0.127  loss_cls: 0.05082  loss_box_reg: 0.07199  loss_rpn_cls: 0.004035  loss_rpn_loc: 0.003774    time: 0.1354  last_time: 0.1484  data_time: 0.0111  last_data_time: 0.0056   lr: 3.9369e-05  max_mem: 1730M
# [02/23 17:08:14 d2.utils.events]:  eta: 0:01:41  iter: 9219  total_loss: 0.1313  loss_cls: 0.04038  loss_box_reg: 0.08092  loss_rpn_cls: 0.002316  loss_rpn_loc: 0.004258    time: 0.1354  last_time: 0.1249  data_time: 0.0042  last_data_time: 0.0039   lr: 3.7437e-05  max_mem: 1730M
# [02/23 17:08:17 d2.utils.events]:  eta: 0:01:38  iter: 9239  total_loss: 0.1285  loss_cls: 0.04315  loss_box_reg: 0.08373  loss_rpn_cls: 0.002735  loss_rpn_loc: 0.006073    time: 0.1354  last_time: 0.1225  data_time: 0.0043  last_data_time: 0.0038   lr: 3.5553e-05  max_mem: 1730M
# [02/23 17:08:19 d2.utils.events]:  eta: 0:01:36  iter: 9259  total_loss: 0.1425  loss_cls: 0.04463  loss_box_reg: 0.088  loss_rpn_cls: 0.003684  loss_rpn_loc: 0.005441    time: 0.1354  last_time: 0.1474  data_time: 0.0041  last_data_time: 0.0046   lr: 3.3717e-05  max_mem: 1730M
# [02/23 17:08:22 d2.utils.events]:  eta: 0:01:33  iter: 9279  total_loss: 0.1721  loss_cls: 0.06046  loss_box_reg: 0.09985  loss_rpn_cls: 0.004838  loss_rpn_loc: 0.007199    time: 0.1354  last_time: 0.1271  data_time: 0.0043  last_data_time: 0.0044   lr: 3.193e-05  max_mem: 1730M
# [02/23 17:08:25 d2.utils.events]:  eta: 0:01:31  iter: 9299  total_loss: 0.1414  loss_cls: 0.05031  loss_box_reg: 0.08562  loss_rpn_cls: 0.0073  loss_rpn_loc: 0.004892    time: 0.1354  last_time: 0.1484  data_time: 0.0206  last_data_time: 0.0049   lr: 3.019e-05  max_mem: 1730M
# [02/23 17:08:28 d2.utils.events]:  eta: 0:01:28  iter: 9319  total_loss: 0.1324  loss_cls: 0.03669  loss_box_reg: 0.08126  loss_rpn_cls: 0.002039  loss_rpn_loc: 0.004161    time: 0.1354  last_time: 0.1346  data_time: 0.0047  last_data_time: 0.0053   lr: 2.8498e-05  max_mem: 1730M
# [02/23 17:08:30 d2.utils.events]:  eta: 0:01:25  iter: 9339  total_loss: 0.1493  loss_cls: 0.05189  loss_box_reg: 0.09325  loss_rpn_cls: 0.005598  loss_rpn_loc: 0.005571    time: 0.1354  last_time: 0.1311  data_time: 0.0042  last_data_time: 0.0046   lr: 2.6855e-05  max_mem: 1730M
# [02/23 17:08:33 d2.utils.events]:  eta: 0:01:23  iter: 9359  total_loss: 0.1506  loss_cls: 0.05375  loss_box_reg: 0.1007  loss_rpn_cls: 0.005257  loss_rpn_loc: 0.004872    time: 0.1354  last_time: 0.1247  data_time: 0.0043  last_data_time: 0.0049   lr: 2.526e-05  max_mem: 1730M
# [02/23 17:08:36 d2.utils.events]:  eta: 0:01:20  iter: 9379  total_loss: 0.1349  loss_cls: 0.04945  loss_box_reg: 0.07811  loss_rpn_cls: 0.001406  loss_rpn_loc: 0.004434    time: 0.1354  last_time: 0.1377  data_time: 0.0042  last_data_time: 0.0045   lr: 2.3713e-05  max_mem: 1730M
# [02/23 17:08:39 d2.utils.events]:  eta: 0:01:18  iter: 9399  total_loss: 0.1404  loss_cls: 0.04344  loss_box_reg: 0.08733  loss_rpn_cls: 0.002816  loss_rpn_loc: 0.003644    time: 0.1354  last_time: 0.1738  data_time: 0.0120  last_data_time: 0.0189   lr: 2.2215e-05  max_mem: 1730M
# [02/23 17:08:41 d2.utils.events]:  eta: 0:01:15  iter: 9419  total_loss: 0.1233  loss_cls: 0.03665  loss_box_reg: 0.08262  loss_rpn_cls: 0.003116  loss_rpn_loc: 0.004861    time: 0.1354  last_time: 0.1241  data_time: 0.0046  last_data_time: 0.0041   lr: 2.0765e-05  max_mem: 1730M
# [02/23 17:08:44 d2.utils.events]:  eta: 0:01:12  iter: 9439  total_loss: 0.1533  loss_cls: 0.04944  loss_box_reg: 0.09494  loss_rpn_cls: 0.004273  loss_rpn_loc: 0.004263    time: 0.1354  last_time: 0.1244  data_time: 0.0040  last_data_time: 0.0039   lr: 1.9363e-05  max_mem: 1730M
# [02/23 17:08:46 d2.utils.events]:  eta: 0:01:10  iter: 9459  total_loss: 0.1185  loss_cls: 0.05183  loss_box_reg: 0.07789  loss_rpn_cls: 0.004048  loss_rpn_loc: 0.003123    time: 0.1354  last_time: 0.1200  data_time: 0.0042  last_data_time: 0.0041   lr: 1.8011e-05  max_mem: 1730M
# [02/23 17:08:49 d2.utils.events]:  eta: 0:01:07  iter: 9479  total_loss: 0.1373  loss_cls: 0.04312  loss_box_reg: 0.07932  loss_rpn_cls: 0.002015  loss_rpn_loc: 0.00365    time: 0.1353  last_time: 0.1517  data_time: 0.0043  last_data_time: 0.0037   lr: 1.6706e-05  max_mem: 1730M
# [02/23 17:08:52 d2.utils.events]:  eta: 0:01:05  iter: 9499  total_loss: 0.1308  loss_cls: 0.04351  loss_box_reg: 0.0754  loss_rpn_cls: 0.002287  loss_rpn_loc: 0.003557    time: 0.1354  last_time: 0.1688  data_time: 0.0101  last_data_time: 0.0078   lr: 1.5451e-05  max_mem: 1730M
# [02/23 17:08:55 d2.utils.events]:  eta: 0:01:02  iter: 9519  total_loss: 0.1547  loss_cls: 0.06375  loss_box_reg: 0.08558  loss_rpn_cls: 0.006811  loss_rpn_loc: 0.004234    time: 0.1354  last_time: 0.1370  data_time: 0.0055  last_data_time: 0.0049   lr: 1.4244e-05  max_mem: 1730M
# [02/23 17:08:57 d2.utils.events]:  eta: 0:00:59  iter: 9539  total_loss: 0.1323  loss_cls: 0.04034  loss_box_reg: 0.08648  loss_rpn_cls: 0.002288  loss_rpn_loc: 0.003921    time: 0.1354  last_time: 0.1393  data_time: 0.0054  last_data_time: 0.0195   lr: 1.3086e-05  max_mem: 1730M
# [02/23 17:09:00 d2.utils.events]:  eta: 0:00:57  iter: 9559  total_loss: 0.1573  loss_cls: 0.05423  loss_box_reg: 0.09381  loss_rpn_cls: 0.005899  loss_rpn_loc: 0.005293    time: 0.1354  last_time: 0.1283  data_time: 0.0042  last_data_time: 0.0037   lr: 1.1977e-05  max_mem: 1730M
# [02/23 17:09:03 d2.utils.events]:  eta: 0:00:54  iter: 9579  total_loss: 0.1173  loss_cls: 0.03731  loss_box_reg: 0.07102  loss_rpn_cls: 0.00302  loss_rpn_loc: 0.005034    time: 0.1354  last_time: 0.1459  data_time: 0.0069  last_data_time: 0.0235   lr: 1.0917e-05  max_mem: 1730M
# [02/23 17:09:06 d2.utils.events]:  eta: 0:00:52  iter: 9599  total_loss: 0.1616  loss_cls: 0.05482  loss_box_reg: 0.09895  loss_rpn_cls: 0.003038  loss_rpn_loc: 0.004435    time: 0.1354  last_time: 0.1329  data_time: 0.0061  last_data_time: 0.0047   lr: 9.9059e-06  max_mem: 1730M
# [02/23 17:09:08 d2.utils.events]:  eta: 0:00:49  iter: 9619  total_loss: 0.1319  loss_cls: 0.03952  loss_box_reg: 0.08357  loss_rpn_cls: 0.001948  loss_rpn_loc: 0.003589    time: 0.1354  last_time: 0.1348  data_time: 0.0046  last_data_time: 0.0037   lr: 8.9436e-06  max_mem: 1730M
# [02/23 17:09:11 d2.utils.events]:  eta: 0:00:46  iter: 9639  total_loss: 0.1352  loss_cls: 0.04355  loss_box_reg: 0.08272  loss_rpn_cls: 0.0041  loss_rpn_loc: 0.003675    time: 0.1354  last_time: 0.1214  data_time: 0.0044  last_data_time: 0.0043   lr: 8.0302e-06  max_mem: 1730M
# [02/23 17:09:13 d2.utils.events]:  eta: 0:00:44  iter: 9659  total_loss: 0.175  loss_cls: 0.05773  loss_box_reg: 0.09122  loss_rpn_cls: 0.004971  loss_rpn_loc: 0.004439    time: 0.1354  last_time: 0.1263  data_time: 0.0045  last_data_time: 0.0039   lr: 7.1659e-06  max_mem: 1730M
# [02/23 17:09:16 d2.utils.events]:  eta: 0:00:41  iter: 9679  total_loss: 0.1208  loss_cls: 0.0417  loss_box_reg: 0.07069  loss_rpn_cls: 0.003208  loss_rpn_loc: 0.004739    time: 0.1353  last_time: 0.1416  data_time: 0.0045  last_data_time: 0.0065   lr: 6.3507e-06  max_mem: 1730M
# [02/23 17:09:19 d2.utils.events]:  eta: 0:00:39  iter: 9699  total_loss: 0.1314  loss_cls: 0.04375  loss_box_reg: 0.07949  loss_rpn_cls: 0.002938  loss_rpn_loc: 0.003869    time: 0.1354  last_time: 0.1238  data_time: 0.0159  last_data_time: 0.0034   lr: 5.5846e-06  max_mem: 1730M
# [02/23 17:09:22 d2.utils.events]:  eta: 0:00:36  iter: 9719  total_loss: 0.1392  loss_cls: 0.0504  loss_box_reg: 0.07957  loss_rpn_cls: 0.002283  loss_rpn_loc: 0.004021    time: 0.1354  last_time: 0.1262  data_time: 0.0041  last_data_time: 0.0040   lr: 4.8675e-06  max_mem: 1730M
# [02/23 17:09:24 d2.utils.events]:  eta: 0:00:33  iter: 9739  total_loss: 0.1174  loss_cls: 0.03225  loss_box_reg: 0.07543  loss_rpn_cls: 0.001485  loss_rpn_loc: 0.003783    time: 0.1354  last_time: 0.1226  data_time: 0.0042  last_data_time: 0.0038   lr: 4.1997e-06  max_mem: 1730M
# [02/23 17:09:27 d2.utils.events]:  eta: 0:00:31  iter: 9759  total_loss: 0.1547  loss_cls: 0.05106  loss_box_reg: 0.09861  loss_rpn_cls: 0.006179  loss_rpn_loc: 0.004529    time: 0.1353  last_time: 0.1262  data_time: 0.0041  last_data_time: 0.0052   lr: 3.581e-06  max_mem: 1730M
# [02/23 17:09:29 d2.utils.events]:  eta: 0:00:28  iter: 9779  total_loss: 0.1551  loss_cls: 0.04947  loss_box_reg: 0.09576  loss_rpn_cls: 0.0036  loss_rpn_loc: 0.004353    time: 0.1353  last_time: 0.1373  data_time: 0.0048  last_data_time: 0.0037   lr: 3.0115e-06  max_mem: 1730M
# [02/23 17:09:32 d2.utils.events]:  eta: 0:00:26  iter: 9799  total_loss: 0.1504  loss_cls: 0.05084  loss_box_reg: 0.09281  loss_rpn_cls: 0.008194  loss_rpn_loc: 0.007539    time: 0.1354  last_time: 0.1212  data_time: 0.0077  last_data_time: 0.0041   lr: 2.4913e-06  max_mem: 1730M
# [02/23 17:09:35 d2.utils.events]:  eta: 0:00:23  iter: 9819  total_loss: 0.135  loss_cls: 0.0485  loss_box_reg: 0.07618  loss_rpn_cls: 0.004372  loss_rpn_loc: 0.005412    time: 0.1353  last_time: 0.1196  data_time: 0.0042  last_data_time: 0.0044   lr: 2.0203e-06  max_mem: 1730M
# [02/23 17:09:37 d2.utils.events]:  eta: 0:00:20  iter: 9839  total_loss: 0.1292  loss_cls: 0.0387  loss_box_reg: 0.08617  loss_rpn_cls: 0.001868  loss_rpn_loc: 0.003767    time: 0.1353  last_time: 0.1261  data_time: 0.0040  last_data_time: 0.0035   lr: 1.5986e-06  max_mem: 1730M
# [02/23 17:09:40 d2.utils.events]:  eta: 0:00:18  iter: 9859  total_loss: 0.1188  loss_cls: 0.03414  loss_box_reg: 0.08069  loss_rpn_cls: 0.003202  loss_rpn_loc: 0.004752    time: 0.1353  last_time: 0.1281  data_time: 0.0045  last_data_time: 0.0043   lr: 1.2262e-06  max_mem: 1730M
# [02/23 17:09:43 d2.utils.events]:  eta: 0:00:15  iter: 9879  total_loss: 0.1213  loss_cls: 0.03988  loss_box_reg: 0.07096  loss_rpn_cls: 0.003008  loss_rpn_loc: 0.004979    time: 0.1353  last_time: 0.1647  data_time: 0.0055  last_data_time: 0.0270   lr: 9.0302e-07  max_mem: 1730M
# [02/23 17:09:46 d2.utils.events]:  eta: 0:00:12  iter: 9899  total_loss: 0.1482  loss_cls: 0.0507  loss_box_reg: 0.09445  loss_rpn_cls: 0.00563  loss_rpn_loc: 0.004582    time: 0.1353  last_time: 0.1253  data_time: 0.0138  last_data_time: 0.0041   lr: 6.292e-07  max_mem: 1730M
# [02/23 17:09:48 d2.utils.events]:  eta: 0:00:10  iter: 9919  total_loss: 0.1712  loss_cls: 0.05807  loss_box_reg: 0.09431  loss_rpn_cls: 0.005115  loss_rpn_loc: 0.004733    time: 0.1353  last_time: 0.1311  data_time: 0.0052  last_data_time: 0.0046   lr: 4.0469e-07  max_mem: 1730M
# [02/23 17:09:51 d2.utils.events]:  eta: 0:00:07  iter: 9939  total_loss: 0.1633  loss_cls: 0.04649  loss_box_reg: 0.1041  loss_rpn_cls: 0.004723  loss_rpn_loc: 0.004321    time: 0.1353  last_time: 0.1320  data_time: 0.0041  last_data_time: 0.0056   lr: 2.2952e-07  max_mem: 1730M
# [02/23 17:09:53 d2.utils.events]:  eta: 0:00:05  iter: 9959  total_loss: 0.1331  loss_cls: 0.04159  loss_box_reg: 0.07998  loss_rpn_cls: 0.003275  loss_rpn_loc: 0.004765    time: 0.1353  last_time: 0.1191  data_time: 0.0042  last_data_time: 0.0044   lr: 1.0369e-07  max_mem: 1730M
# [02/23 17:09:56 d2.utils.events]:  eta: 0:00:02  iter: 9979  total_loss: 0.1297  loss_cls: 0.03477  loss_box_reg: 0.07399  loss_rpn_cls: 0.003887  loss_rpn_loc: 0.003297    time: 0.1353  last_time: 0.1527  data_time: 0.0050  last_data_time: 0.0108   lr: 2.7203e-08  max_mem: 1730M
# [02/23 17:10:02 d2.utils.events]:  eta: 0:00:00  iter: 9999  total_loss: 0.124  loss_cls: 0.03849  loss_box_reg: 0.07856  loss_rpn_cls: 0.002886  loss_rpn_loc: 0.003384    time: 0.1353  last_time: 0.1293  data_time: 0.0138  last_data_time: 0.0040   lr: 6.1685e-11  max_mem: 1730M
# [02/23 17:10:02 d2.engine.hooks]: Overall training speed: 9998 iterations in 0:22:33 (0.1353 s / it)
# [02/23 17:10:02 d2.engine.hooks]: Total training time: 0:22:40 (0:00:07 on hooks)
# [02/23 17:10:02 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(256, 256), max_size=1333, sample_style='choice')]
# [02/23 17:10:02 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/23 17:10:02 d2.data.common]: Serializing 319 elements to byte tensors and concatenating them all ...
# [02/23 17:10:02 d2.data.common]: Serialized dataset takes 0.10 MiB
# WARNING [02/23 17:10:02 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %% [markdown]
# result

# %%
import pandas as pd

metrics_path = "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v4/metrics.json"
metrics = pd.read_json(metrics_path, orient='records', lines=True)
metrics = metrics.sort_values(by=['iteration'])

print('Shape of Metrics: ', metrics.shape)
metrics.head()
# Out:
# Shape of Metrics:  (500, 18)
#    data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0   0.004608  1375.451978                0.706055                  0.547619
# 1   0.007186  1416.108328                0.987305                  1.000000
# 2   0.004446  1379.955807                0.986328                  1.000000
# 3   0.004408  1375.929499                0.989258                  1.000000
# 4   0.004163  1364.523351                0.980957                  1.000000
#
#    fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_rpn_cls  \
# 0                        0.0         19      0.020742  3.228227      0.669357
# 1                        0.0         39      0.047861  0.158537      0.572044
# 2                        0.0         59      0.053079  0.138939      0.375784
# 3                        0.0         79      0.034749  0.173219      0.203498
# 4                        0.0         99      0.073024  0.228212      0.134821
#
#    loss_rpn_loc        lr  rank_data_time  roi_head/num_bg_samples  \
# 0      0.009987  0.000049        0.004608                   508.75
# 1      0.011072  0.000098        0.007186                   505.50
# 2      0.013248  0.000146        0.004446                   505.00
# 3      0.013664  0.000195        0.004408                   506.50
# 4      0.013054  0.000244        0.004163                   502.25
#
#    roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                     3.25               252.25                 3.75
# 1                     6.50               252.50                 3.50
# 2                     7.00               251.75                 4.25
# 3                     5.50               251.25                 4.75
# 4                     9.75               251.25                 4.75
#
#        time  total_loss
# 0  0.137821    3.939882
# 1  0.161771    0.808402
# 2  0.137269    0.592596
# 3  0.137159    0.459622
# 4  0.135486    0.428241

# %%
import matplotlib.pyplot as plt

plt.style.use('default')
plt.figure(figsize=(12,6))

tmp = metrics[~metrics['lr'].isna()]

plt.plot(tmp['iteration'], tmp['lr'])
plt.xlabel('iterations')
plt.ylabel('Learning Rate')

plt.show()

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('RPN Fraction Ratio')
tmp = metrics[~metrics['rpn/num_neg_anchors'].isna()]
tmp = tmp[~tmp['rpn/num_pos_anchors'].isna()]
plt.plot(tmp['iteration'], tmp['rpn/num_neg_anchors'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_neg_anchors'].mean(), tmp['rpn/num_neg_anchors'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['rpn/num_pos_anchors'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_pos_anchors'].mean(),tmp['rpn/num_pos_anchors'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title('ROI Head Fraction Ratio')
tmp = metrics[~metrics['roi_head/num_bg_samples'].isna()]
tmp = tmp[~tmp['roi_head/num_fg_samples'].isna()]
plt.plot(tmp['iteration'], tmp['roi_head/num_bg_samples'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_bg_samples'].mean(), tmp['roi_head/num_bg_samples'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['roi_head/num_fg_samples'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_fg_samples'].mean(),tmp['roi_head/num_fg_samples'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(metrics["total_loss"], label="Final Loss", color="red", linewidth=1.5)
plt.xlabel("Iteration")
plt.ylabel("Loss Value")
plt.title("Final Loss Over Iterations")
plt.legend()
plt.grid(True)
plt.show()
