# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
import os
import torch

# %%
# def csv_to_coco(csv_path, meta_csv, output_json):
#     df = pd.read_csv(csv_path)
#     meta_df = pd.read_csv(meta_csv)
#     filtered_df = df[df["image_id"].isin(meta_df["image_id"])]

#     class_map = {"ulcer": 0, "polyp": 1, "cancer": 2}
#     coco_json = {"images": [], "annotations": [], "categories": []}

#     for class_name, class_id in class_map.items():
#         coco_json["categories"].append({"id": class_id, "name": class_name})

#     image_id_map = {}
#     annotation_id = 1

#     for _, row in filtered_df.iterrows():
#         image_id = row["image_id"]
#         image_name = row["image_id"]

#         if image_id not in image_id_map:
#             image_id_map[image_id] = image_name
#             coco_json["images"].append({
#                 "id": image_id,
#                 "width": row["width"],
#                 "height": row["height"],
#                 "file_name": image_name
#             })

#         x_min, y_min, x_max, y_max = row["x_min"], row["y_min"], row["x_max"], row["y_max"]
#         bbox = [x_min, y_min, x_max - x_min, y_max - y_min]

#         coco_json["annotations"].append({
#             "id": annotation_id,
#             "image_id": image_id,
#             "category_id": class_map[row["lesion"]],
#             "bbox": bbox,
#             "area": bbox[2] * bbox[3],
#             "iscrowd": 0
#         })
#         annotation_id += 1

#     with open(output_json, "w") as f:
#         json.dump(coco_json, f, indent=4)

#     print(f"COCO JSON saved: {output_json}")

# base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
# csv_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/resize_colonoscopy.csv"

# meta_paths = {
#     "train": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/train_meta.csv",
#     "val": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/val_meta.csv",
#     "test": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/test_meta.csv",
# }

# json_paths = {
#     "train": os.path.join(base_path, "Dataset", "train_coco.json"),
#     "val": os.path.join(base_path, "Dataset", "val_coco.json"),
#     "test": os.path.join(base_path, "Dataset", "test_coco.json"),
# }

# for split in ["train", "val", "test"]:
#     csv_to_coco(csv_path, meta_paths[split], json_paths[split])

# %%
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 49.2 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

def register_coco_dataset(name, json_file, image_root):
    DatasetCatalog.register(
        name,
        lambda: load_coco_json(json_file, image_root)
    )
    MetadataCatalog.get(name).set(thing_classes=["ulcer", "polyp","cancer"])

def load_coco_json(json_file, image_root):
    with open(json_file, "r") as f:
        coco_data = json.load(f)

    dataset_dicts = []
    for image_info in coco_data['images']:
        record = {}
        record['file_name'] = os.path.join(image_root, image_info['file_name'])
        record['image_id'] = image_info['id']
        record['height'] = image_info['height']
        record['width'] = image_info['width']

        annotations = []
        for ann in coco_data['annotations']:
            if ann['image_id'] == image_info['id']:
                annotations.append({
                    "bbox": ann['bbox'],
                    "bbox_mode": BoxMode.XYWH_ABS,
                    "category_id": ann['category_id']
                })

        record['annotations'] = annotations
        dataset_dicts.append(record)
    return dataset_dicts


image_folders = {
    "train": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/train",
    "val": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/val",
    "test": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/test"
}

base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
json_paths = {
    "train": os.path.join(base_path, "Dataset", "train_coco.json"),
    "val": os.path.join(base_path, "Dataset", "val_coco.json"),
    "test": os.path.join(base_path, "Dataset", "test_coco.json"),
}

for split in ["train", "val", "test"]:
    register_coco_dataset(f"colonoscopy_{split}", json_paths[split], image_folders[split])

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.4)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (3.11.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.evaluation import COCOEvaluator
from detectron2.data import build_detection_train_loader, build_detection_test_loader

# %%
# !wget -O /content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Out:
# --2025-02-24 15:49:16--  https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318 (1.3K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’
#
# /content/drive/MyDr 100%[===================>]   1.29K  --.-KB/s    in 0s
#
# 2025-02-24 15:49:16 (68.4 MB/s) - ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’ saved [1318/1318]

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog, DatasetMapper
from detectron2.data.transforms import (RandomFlip, RandomRotation, RandomContrast, RandomBrightness, RandomLighting)
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_train_loader, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator
from detectron2.config import get_cfg
import os
import cv2
import random
import numpy as np
from detectron2.data.transforms import Augmentation, Transform
from detectron2.data import detection_utils as utils
from detectron2.structures import BoxMode

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Error loading image: {image_path}")
    return image

class Mosaic:
    def __init__(self, prob=0.5, image_size=(128, 128)):
        self.prob = prob
        self.image_size = image_size

    def __call__(self, dataset_dicts):
        if random.random() >= self.prob:
            return dataset_dicts[0]

        h, w = self.image_size
        mosaic_image = np.zeros((h, w, 3), dtype=np.uint8)
        mosaic_boxes = []
        mosaic_classes = []

        selected_samples = random.sample(dataset_dicts, 4)
        positions = [
            (0, 0), (w // 2, 0),
            (0, h // 2), (w // 2, h // 2)
        ]

        for i, sample in enumerate(selected_samples):
            image_path = sample["file_name"]
            image = load_image(image_path)
            orig_h, orig_w = image.shape[:2]


            x1 = random.randint(0, orig_w // 2)
            y1 = random.randint(0, orig_h // 2)
            x2 = random.randint(orig_w // 2, orig_w)
            y2 = random.randint(orig_h // 2, orig_h)
            cropped_image = image[y1:y2, x1:x2]

            pos_x, pos_y = positions[i]

            resized_crop = cv2.resize(cropped_image, (w // 2, h // 2))
            mosaic_image[pos_y:pos_y + h // 2, pos_x:pos_x + w // 2] = resized_crop

            for ann in sample["annotations"]:
                bbox = ann["bbox"]
                bbox_mode = ann["bbox_mode"]

                if bbox_mode != BoxMode.XYXY_ABS:
                    bbox = BoxMode.convert(bbox, bbox_mode, BoxMode.XYXY_ABS)

                x_min, y_min, x_max, y_max = bbox


                if x_min < x2 and x_max > x1 and y_min < y2 and y_max > y1:
                    clipped_bbox = [
                        max(x_min, x1) - x1,  # X_min 상대 좌표
                        max(y_min, y1) - y1,  # Y_min 상대 좌표
                        min(x_max, x2) - x1,  # X_max 상대 좌표
                        min(y_max, y2) - y1   # Y_max 상대 좌표
                    ]

                    scale_x = (w // 2) / (x2 - x1)
                    scale_y = (h // 2) / (y2 - y1)
                    scaled_bbox = [
                        clipped_bbox[0] * scale_x + pos_x,
                        clipped_bbox[1] * scale_y + pos_y,
                        clipped_bbox[2] * scale_x + pos_x,
                        clipped_bbox[3] * scale_y + pos_y
                    ]

                    mosaic_boxes.append(scaled_bbox)
                    mosaic_classes.append(ann["category_id"])

        dataset_dicts[0]["image"] = mosaic_image
        dataset_dicts[0]["annotations"] = [
            {"bbox": bbox, "bbox_mode": BoxMode.XYXY_ABS, "category_id": cls}
            for bbox, cls in zip(mosaic_boxes, mosaic_classes)
        ]

        return dataset_dicts[0]

# %%
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer

def visualize_mosaic(dataset_name, num_samples=2):
    dataset_dicts = DatasetCatalog.get(dataset_name)
    metadata = MetadataCatalog.get(dataset_name)

    mosaic_images = []

    for _ in range(num_samples):
        mosaic_transform = Mosaic(prob=1.0)
        mosaic_sample = mosaic_transform(random.sample(dataset_dicts, 4))

        image = mosaic_sample["image"]
        annotations = mosaic_sample["annotations"]

        visualizer = Visualizer(image[:, :, ::-1], metadata=metadata, scale=1.0)
        for ann in annotations:
            bbox = ann["bbox"]
            category_id = ann["category_id"]
            visualizer.draw_box(bbox, edge_color="red", line_style="-")
            visualizer.draw_text(str(category_id), (bbox[0], bbox[1]), color="white")

        output = visualizer.get_output()
        mosaic_images.append(output.get_image())

    fig, axes = plt.subplots(1, num_samples, figsize=(num_samples * 8, 8))

    for i in range(num_samples):
        axes[i].imshow(mosaic_images[i])
        axes[i].axis("off")
        axes[i].set_title(f"Mosaic Sample {i+1}")

    plt.show()

visualize_mosaic("colonoscopy_train", num_samples=2)

# %%
def adjust_augmentation(cfg):
    augmentations = [
        RandomFlip(prob=0.4, horizontal=True, vertical=False),
        RandomContrast(intensity_min=0.5, intensity_max=1.5),
        RandomBrightness(intensity_min=0.5, intensity_max=1.5),
        RandomLighting(scale=0.1),
        RandomRotation(angle=[-10, 10], expand=True),
        Mosaic(prob=0.2)
    ]
    mapper = DatasetMapper(cfg, is_train=True, augmentations=augmentations)
    return build_detection_train_loader(cfg, mapper=mapper)

# %%
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return adjust_augmentation(cfg)

    @classmethod
    def build_test_loader(cls, cfg, dataset_name):
        return build_detection_test_loader(cfg, dataset_name)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = cfg.OUTPUT_DIR
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

# %%
"""
_BASE_: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/faster_rcnn_R_50_FPN_3x.yaml"

MODEL:
  META_ARCHITECTURE: "GeneralizedRCNN"
  WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-50.pkl"
  MASK_ON: False
  RESNETS:
    DEPTH: 50

DATASETS:
  TRAIN: ("colonoscopy_train",)
  TEST: ("colonoscopy_val",)

DATALOADER:
  NUM_WORKERS: 2

SOLVER:
  IMS_PER_BATCH: 8
  BASE_LR: 0.0025
  MAX_ITER: 10000
  LR_SCHEDULER_NAME: "WarmupMultiStepLR"
  WARMUP_FACTOR: 5e-4
  WARMUP_ITERS: 1000
  WEIGHT_DECAY: 1e-4

INPUT:
  MIN_SIZE_TRAIN: (256, 512, 1024)
  MAX_SIZE_TRAIN: 1333
  MIN_SIZE_TEST: 256
  MAX_SIZE_TEST: 1333

TEST:
  EVAL_PERIOD: 5000

OUTPUT_DIR: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment"

"""
# Out:
# '\n_BASE_: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/faster_rcnn_R_50_FPN_3x.yaml"\n\nMODEL:\n  META_ARCHITECTURE: "GeneralizedRCNN"\n  WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-50.pkl"\n  MASK_ON: False\n  RESNETS:\n    DEPTH: 50\n\nDATASETS:\n  TRAIN: ("colonoscopy_train",)\n  TEST: ("colonoscopy_val",)\n\nDATALOADER:\n  NUM_WORKERS: 2\n  TOTAL_BATCH_SIZE: 8\n\nSOLVER:\n  IMS_PER_BATCH: 8 \n  BASE_LR: 0.0025\n  MAX_ITER: 10000\n  LR_SCHEDULER_NAME: "WarmupMultiStepLR"\n  WARMUP_FACTOR: 5e-4\n  WARMUP_ITERS: 1000\n  WEIGHT_DECAY: 1e-4\n\nINPUT:\n  MIN_SIZE_TRAIN: (256, 512, 1024)\n  MAX_SIZE_TRAIN: 1333\n  MIN_SIZE_TEST: 256\n  MAX_SIZE_TEST: 1333\n\nTEST:\n  EVAL_PERIOD: 5000\n\nOUTPUT_DIR: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment"\n\n'

# %%
cfg = get_cfg()
cfg.merge_from_file("/content/drive/MyDrive/Endoscope Detection/colonoscopy/config.yaml")

cfg.OUTPUT_DIR = "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v5"
cfg.DATASETS.TRAIN = ("colonoscopy_train",)
cfg.DATASETS.TEST = ("colonoscopy_val",)

trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/24 15:51:23 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=81, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=320, bias=True)
#     )
#   )
# )
# [02/24 15:51:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [RandomFlip(prob=0.4), RandomContrast(intensity_min=0.5, intensity_max=1.5), RandomBrightness(intensity_min=0.5, intensity_max=1.5), RandomLighting(scale=0.1), RandomRotation(angle=[-10, 10])]
# [02/24 15:51:23 d2.data.build]: Removed 0 images with no usable annotations. 1277 images left.
# [02/24 15:51:23 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   ulcer    | 610          |   polyp    | 350          |   cancer   | 640          |
# |            |              |            |              |            |              |
# |   total    | 1600         |            |              |            |              |
# [02/24 15:51:23 d2.data.build]: Using training sampler TrainingSampler
# [02/24 15:51:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/24 15:51:23 d2.data.common]: Serializing 1277 elements to byte tensors and concatenating them all ...
# [02/24 15:51:23 d2.data.common]: Serialized dataset takes 0.40 MiB
# [02/24 15:51:23 d2.data.build]: Making batched data loader with batch_size=8
# WARNING [02/24 15:51:23 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [02/24 15:51:23 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/MSRA/R-50.pkl ...
# R-50.pkl: 102MB [00:01, 54.5MB/s]
# [02/24 15:51:25 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [02/24 15:51:25 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 54
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   fc1000.{bias, weight}
#   stem.conv1.bias
# [02/24 15:51:25 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/24 15:52:11 d2.utils.events]:  eta: 5:02:41  iter: 19  total_loss: 3.822  loss_cls: 3.098  loss_box_reg: 0.008083  loss_rpn_cls: 0.6958  loss_rpn_loc: 0.01489    time: 2.1607  last_time: 8.0285  data_time: 1.7947  last_data_time: 7.5918   lr: 4.8726e-05  max_mem: 1548M
# [02/24 15:52:50 d2.utils.events]:  eta: 4:56:11  iter: 39  total_loss: 0.7136  loss_cls: 0.08998  loss_box_reg: 0.01594  loss_rpn_cls: 0.5842  loss_rpn_loc: 0.01284    time: 1.9434  last_time: 1.6520  data_time: 1.3763  last_data_time: 1.2622   lr: 9.8701e-05  max_mem: 1552M
# [02/24 15:53:24 d2.utils.events]:  eta: 4:49:41  iter: 59  total_loss: 0.5839  loss_cls: 0.1531  loss_box_reg: 0.04398  loss_rpn_cls: 0.3578  loss_rpn_loc: 0.0159    time: 1.8526  last_time: 1.8429  data_time: 1.2828  last_data_time: 1.4038   lr: 0.00014868  max_mem: 1552M
# [02/24 15:53:59 d2.utils.events]:  eta: 4:44:52  iter: 79  total_loss: 0.4248  loss_cls: 0.1712  loss_box_reg: 0.04057  loss_rpn_cls: 0.1946  loss_rpn_loc: 0.01439    time: 1.8326  last_time: 1.7603  data_time: 1.3604  last_data_time: 1.3443   lr: 0.00019865  max_mem: 1552M
# [02/24 15:54:37 d2.utils.events]:  eta: 4:43:19  iter: 99  total_loss: 0.3875  loss_cls: 0.1771  loss_box_reg: 0.06251  loss_rpn_cls: 0.1301  loss_rpn_loc: 0.01354    time: 1.8398  last_time: 2.4024  data_time: 1.4406  last_data_time: 1.8977   lr: 0.00024863  max_mem: 1552M
# [02/24 15:55:11 d2.utils.events]:  eta: 4:41:51  iter: 119  total_loss: 0.346  loss_cls: 0.1625  loss_box_reg: 0.07644  loss_rpn_cls: 0.101  loss_rpn_loc: 0.0129    time: 1.8217  last_time: 1.7680  data_time: 1.3061  last_data_time: 1.3420   lr: 0.0002986  max_mem: 1552M
# [02/24 15:55:46 d2.utils.events]:  eta: 4:41:11  iter: 139  total_loss: 0.2854  loss_cls: 0.1304  loss_box_reg: 0.06894  loss_rpn_cls: 0.08407  loss_rpn_loc: 0.01072    time: 1.8123  last_time: 1.7771  data_time: 1.3130  last_data_time: 1.3425   lr: 0.00034858  max_mem: 1553M
# [02/24 15:56:20 d2.utils.events]:  eta: 4:39:52  iter: 159  total_loss: 0.3233  loss_cls: 0.1435  loss_box_reg: 0.08762  loss_rpn_cls: 0.0671  loss_rpn_loc: 0.01142    time: 1.7983  last_time: 1.2531  data_time: 1.2583  last_data_time: 0.8387   lr: 0.00039855  max_mem: 1553M
# [02/24 15:56:31 d2.utils.events]:  eta: 4:32:54  iter: 179  total_loss: 0.28  loss_cls: 0.1164  loss_box_reg: 0.07833  loss_rpn_cls: 0.06575  loss_rpn_loc: 0.01236    time: 1.6528  last_time: 0.4870  data_time: 0.0559  last_data_time: 0.0480   lr: 0.00044853  max_mem: 1553M
# [02/24 15:56:40 d2.utils.events]:  eta: 4:29:23  iter: 199  total_loss: 0.2768  loss_cls: 0.1222  loss_box_reg: 0.08619  loss_rpn_cls: 0.05441  loss_rpn_loc: 0.009525    time: 1.5347  last_time: 0.5094  data_time: 0.0475  last_data_time: 0.0729   lr: 0.0004985  max_mem: 1553M
# [02/24 15:56:50 d2.utils.events]:  eta: 4:25:15  iter: 219  total_loss: 0.3038  loss_cls: 0.1234  loss_box_reg: 0.1026  loss_rpn_cls: 0.05619  loss_rpn_loc: 0.01132    time: 1.4392  last_time: 0.4823  data_time: 0.0541  last_data_time: 0.0439   lr: 0.00054848  max_mem: 1553M
# [02/24 15:57:00 d2.utils.events]:  eta: 4:20:44  iter: 239  total_loss: 0.2915  loss_cls: 0.1211  loss_box_reg: 0.09951  loss_rpn_cls: 0.0554  loss_rpn_loc: 0.0123    time: 1.3608  last_time: 0.4730  data_time: 0.0618  last_data_time: 0.0646   lr: 0.00059845  max_mem: 1553M
# [02/24 15:57:10 d2.utils.events]:  eta: 4:16:24  iter: 259  total_loss: 0.2949  loss_cls: 0.1252  loss_box_reg: 0.0943  loss_rpn_cls: 0.05822  loss_rpn_loc: 0.0116    time: 1.2940  last_time: 0.4781  data_time: 0.0521  last_data_time: 0.0421   lr: 0.00064843  max_mem: 1553M
# [02/24 15:57:20 d2.utils.events]:  eta: 4:08:02  iter: 279  total_loss: 0.2989  loss_cls: 0.1308  loss_box_reg: 0.1025  loss_rpn_cls: 0.0591  loss_rpn_loc: 0.0112    time: 1.2357  last_time: 0.5328  data_time: 0.0480  last_data_time: 0.0818   lr: 0.0006984  max_mem: 1553M
# [02/24 15:57:30 d2.utils.events]:  eta: 3:57:17  iter: 299  total_loss: 0.2918  loss_cls: 0.1251  loss_box_reg: 0.1084  loss_rpn_cls: 0.05093  loss_rpn_loc: 0.0113    time: 1.1857  last_time: 0.4848  data_time: 0.0514  last_data_time: 0.0472   lr: 0.00074838  max_mem: 1553M
# [02/24 15:57:40 d2.utils.events]:  eta: 1:32:08  iter: 319  total_loss: 0.2941  loss_cls: 0.1246  loss_box_reg: 0.1129  loss_rpn_cls: 0.04876  loss_rpn_loc: 0.01183    time: 1.1423  last_time: 0.4789  data_time: 0.0522  last_data_time: 0.0420   lr: 0.00079835  max_mem: 1553M
# [02/24 15:57:50 d2.utils.events]:  eta: 1:29:22  iter: 339  total_loss: 0.2814  loss_cls: 0.1105  loss_box_reg: 0.1055  loss_rpn_cls: 0.05207  loss_rpn_loc: 0.01156    time: 1.1038  last_time: 0.4934  data_time: 0.0540  last_data_time: 0.0630   lr: 0.00084833  max_mem: 1553M
# [02/24 15:57:59 d2.utils.events]:  eta: 1:26:46  iter: 359  total_loss: 0.2861  loss_cls: 0.1195  loss_box_reg: 0.1064  loss_rpn_cls: 0.04805  loss_rpn_loc: 0.0103    time: 1.0686  last_time: 0.5255  data_time: 0.0484  last_data_time: 0.0824   lr: 0.0008983  max_mem: 1553M
# [02/24 15:58:09 d2.utils.events]:  eta: 1:25:17  iter: 379  total_loss: 0.287  loss_cls: 0.1189  loss_box_reg: 0.1072  loss_rpn_cls: 0.0429  loss_rpn_loc: 0.01201    time: 1.0380  last_time: 0.4861  data_time: 0.0530  last_data_time: 0.0445   lr: 0.00094828  max_mem: 1553M
# [02/24 15:58:19 d2.utils.events]:  eta: 1:24:08  iter: 399  total_loss: 0.2765  loss_cls: 0.1122  loss_box_reg: 0.1078  loss_rpn_cls: 0.04526  loss_rpn_loc: 0.01229    time: 1.0107  last_time: 0.4724  data_time: 0.0561  last_data_time: 0.0417   lr: 0.00099825  max_mem: 1553M
# [02/24 15:58:29 d2.utils.events]:  eta: 1:22:57  iter: 419  total_loss: 0.2787  loss_cls: 0.115  loss_box_reg: 0.1104  loss_rpn_cls: 0.0436  loss_rpn_loc: 0.009981    time: 0.9858  last_time: 0.4826  data_time: 0.0562  last_data_time: 0.0530   lr: 0.0010482  max_mem: 1553M
# [02/24 15:58:38 d2.utils.events]:  eta: 1:20:49  iter: 439  total_loss: 0.2664  loss_cls: 0.1079  loss_box_reg: 0.1091  loss_rpn_cls: 0.04449  loss_rpn_loc: 0.01048    time: 0.9625  last_time: 0.5365  data_time: 0.0448  last_data_time: 0.0691   lr: 0.0010982  max_mem: 1553M
# [02/24 15:58:48 d2.utils.events]:  eta: 1:20:07  iter: 459  total_loss: 0.2603  loss_cls: 0.1064  loss_box_reg: 0.1083  loss_rpn_cls: 0.03737  loss_rpn_loc: 0.009828    time: 0.9418  last_time: 0.4831  data_time: 0.0546  last_data_time: 0.0529   lr: 0.0011482  max_mem: 1553M
# [02/24 15:58:58 d2.utils.events]:  eta: 1:19:01  iter: 479  total_loss: 0.2868  loss_cls: 0.1166  loss_box_reg: 0.1154  loss_rpn_cls: 0.0399  loss_rpn_loc: 0.01221    time: 0.9233  last_time: 0.4511  data_time: 0.0603  last_data_time: 0.0472   lr: 0.0011982  max_mem: 1553M
# [02/24 15:59:08 d2.utils.events]:  eta: 1:18:04  iter: 499  total_loss: 0.263  loss_cls: 0.09953  loss_box_reg: 0.1144  loss_rpn_cls: 0.03565  loss_rpn_loc: 0.01046    time: 0.9059  last_time: 0.4715  data_time: 0.0568  last_data_time: 0.0528   lr: 0.0012481  max_mem: 1553M
# [02/24 15:59:17 d2.utils.events]:  eta: 1:17:14  iter: 519  total_loss: 0.2739  loss_cls: 0.1099  loss_box_reg: 0.116  loss_rpn_cls: 0.03652  loss_rpn_loc: 0.01019    time: 0.8889  last_time: 0.4698  data_time: 0.0464  last_data_time: 0.0433   lr: 0.0012981  max_mem: 1553M
# [02/24 15:59:27 d2.utils.events]:  eta: 1:16:55  iter: 539  total_loss: 0.2654  loss_cls: 0.1109  loss_box_reg: 0.114  loss_rpn_cls: 0.03323  loss_rpn_loc: 0.009098    time: 0.8740  last_time: 0.4690  data_time: 0.0557  last_data_time: 0.0440   lr: 0.0013481  max_mem: 1553M
# [02/24 15:59:36 d2.utils.events]:  eta: 1:16:44  iter: 559  total_loss: 0.2669  loss_cls: 0.1029  loss_box_reg: 0.1133  loss_rpn_cls: 0.03816  loss_rpn_loc: 0.01089    time: 0.8601  last_time: 0.4638  data_time: 0.0548  last_data_time: 0.0476   lr: 0.0013981  max_mem: 1553M
# [02/24 15:59:46 d2.utils.events]:  eta: 1:16:33  iter: 579  total_loss: 0.2541  loss_cls: 0.1058  loss_box_reg: 0.1139  loss_rpn_cls: 0.03171  loss_rpn_loc: 0.01011    time: 0.8472  last_time: 0.5272  data_time: 0.0566  last_data_time: 0.0696   lr: 0.001448  max_mem: 1553M
# [02/24 15:59:56 d2.utils.events]:  eta: 1:16:13  iter: 599  total_loss: 0.259  loss_cls: 0.1006  loss_box_reg: 0.1167  loss_rpn_cls: 0.03178  loss_rpn_loc: 0.01078    time: 0.8345  last_time: 0.4545  data_time: 0.0483  last_data_time: 0.0430   lr: 0.001498  max_mem: 1553M
# [02/24 16:00:05 d2.utils.events]:  eta: 1:15:59  iter: 619  total_loss: 0.2597  loss_cls: 0.09972  loss_box_reg: 0.115  loss_rpn_cls: 0.03625  loss_rpn_loc: 0.01239    time: 0.8230  last_time: 0.4336  data_time: 0.0576  last_data_time: 0.0416   lr: 0.001548  max_mem: 1553M
# [02/24 16:00:15 d2.utils.events]:  eta: 1:15:48  iter: 639  total_loss: 0.2542  loss_cls: 0.1047  loss_box_reg: 0.1057  loss_rpn_cls: 0.02903  loss_rpn_loc: 0.009158    time: 0.8124  last_time: 0.4633  data_time: 0.0542  last_data_time: 0.0435   lr: 0.001598  max_mem: 1553M
# [02/24 16:00:24 d2.utils.events]:  eta: 1:15:36  iter: 659  total_loss: 0.2304  loss_cls: 0.09188  loss_box_reg: 0.1064  loss_rpn_cls: 0.02694  loss_rpn_loc: 0.009383    time: 0.8023  last_time: 0.5410  data_time: 0.0536  last_data_time: 0.1033   lr: 0.0016479  max_mem: 1553M
# [02/24 16:00:34 d2.utils.events]:  eta: 1:15:22  iter: 679  total_loss: 0.2807  loss_cls: 0.1119  loss_box_reg: 0.1241  loss_rpn_cls: 0.03076  loss_rpn_loc: 0.01017    time: 0.7926  last_time: 0.4669  data_time: 0.0512  last_data_time: 0.0454   lr: 0.0016979  max_mem: 1553M
# [02/24 16:00:43 d2.utils.events]:  eta: 1:15:10  iter: 699  total_loss: 0.2389  loss_cls: 0.08687  loss_box_reg: 0.1051  loss_rpn_cls: 0.03232  loss_rpn_loc: 0.01015    time: 0.7835  last_time: 0.4694  data_time: 0.0550  last_data_time: 0.0443   lr: 0.0017479  max_mem: 1553M
# [02/24 16:00:53 d2.utils.events]:  eta: 1:14:58  iter: 719  total_loss: 0.236  loss_cls: 0.09697  loss_box_reg: 0.1105  loss_rpn_cls: 0.02519  loss_rpn_loc: 0.008544    time: 0.7750  last_time: 0.4717  data_time: 0.0544  last_data_time: 0.0442   lr: 0.0017979  max_mem: 1553M
# [02/24 16:01:02 d2.utils.events]:  eta: 1:14:40  iter: 739  total_loss: 0.2634  loss_cls: 0.09787  loss_box_reg: 0.1155  loss_rpn_cls: 0.03487  loss_rpn_loc: 0.01035    time: 0.7665  last_time: 0.4866  data_time: 0.0434  last_data_time: 0.0430   lr: 0.0018478  max_mem: 1553M
# [02/24 16:01:12 d2.utils.events]:  eta: 1:14:24  iter: 759  total_loss: 0.241  loss_cls: 0.09022  loss_box_reg: 0.1063  loss_rpn_cls: 0.02822  loss_rpn_loc: 0.01238    time: 0.7588  last_time: 0.4693  data_time: 0.0545  last_data_time: 0.0441   lr: 0.0018978  max_mem: 1553M
# [02/24 16:01:21 d2.utils.events]:  eta: 1:14:12  iter: 779  total_loss: 0.2392  loss_cls: 0.09478  loss_box_reg: 0.116  loss_rpn_cls: 0.02528  loss_rpn_loc: 0.01002    time: 0.7515  last_time: 0.4300  data_time: 0.0545  last_data_time: 0.0407   lr: 0.0019478  max_mem: 1553M
# [02/24 16:01:31 d2.utils.events]:  eta: 1:14:00  iter: 799  total_loss: 0.2339  loss_cls: 0.1006  loss_box_reg: 0.109  loss_rpn_cls: 0.02031  loss_rpn_loc: 0.00801    time: 0.7446  last_time: 0.5420  data_time: 0.0537  last_data_time: 0.0712   lr: 0.0019978  max_mem: 1553M
# [02/24 16:01:40 d2.utils.events]:  eta: 1:13:45  iter: 819  total_loss: 0.2359  loss_cls: 0.0852  loss_box_reg: 0.1084  loss_rpn_cls: 0.02264  loss_rpn_loc: 0.01077    time: 0.7378  last_time: 0.4541  data_time: 0.0459  last_data_time: 0.0398   lr: 0.0020477  max_mem: 1553M
# [02/24 16:01:50 d2.utils.events]:  eta: 1:13:33  iter: 839  total_loss: 0.2298  loss_cls: 0.08727  loss_box_reg: 0.1054  loss_rpn_cls: 0.0248  loss_rpn_loc: 0.00927    time: 0.7315  last_time: 0.4602  data_time: 0.0541  last_data_time: 0.0439   lr: 0.0020977  max_mem: 1553M
# [02/24 16:01:59 d2.utils.events]:  eta: 1:13:20  iter: 859  total_loss: 0.241  loss_cls: 0.09416  loss_box_reg: 0.1054  loss_rpn_cls: 0.0222  loss_rpn_loc: 0.009007    time: 0.7256  last_time: 0.4503  data_time: 0.0564  last_data_time: 0.0428   lr: 0.0021477  max_mem: 1553M
# [02/24 16:02:08 d2.utils.events]:  eta: 1:13:04  iter: 879  total_loss: 0.2591  loss_cls: 0.1008  loss_box_reg: 0.1152  loss_rpn_cls: 0.03021  loss_rpn_loc: 0.009067    time: 0.7196  last_time: 0.5327  data_time: 0.0489  last_data_time: 0.0903   lr: 0.0021977  max_mem: 1553M
# [02/24 16:02:18 d2.utils.events]:  eta: 1:12:50  iter: 899  total_loss: 0.2461  loss_cls: 0.1043  loss_box_reg: 0.1228  loss_rpn_cls: 0.01939  loss_rpn_loc: 0.008249    time: 0.7140  last_time: 0.4495  data_time: 0.0522  last_data_time: 0.0430   lr: 0.0022476  max_mem: 1553M
# [02/24 16:02:27 d2.utils.events]:  eta: 1:12:39  iter: 919  total_loss: 0.2414  loss_cls: 0.09567  loss_box_reg: 0.1182  loss_rpn_cls: 0.02143  loss_rpn_loc: 0.00787    time: 0.7089  last_time: 0.4616  data_time: 0.0533  last_data_time: 0.0487   lr: 0.0022976  max_mem: 1553M
# [02/24 16:02:37 d2.utils.events]:  eta: 1:12:26  iter: 939  total_loss: 0.2638  loss_cls: 0.1096  loss_box_reg: 0.1241  loss_rpn_cls: 0.0323  loss_rpn_loc: 0.01142    time: 0.7041  last_time: 0.4616  data_time: 0.0573  last_data_time: 0.0445   lr: 0.0023476  max_mem: 1553M
# [02/24 16:02:46 d2.utils.events]:  eta: 1:12:12  iter: 959  total_loss: 0.2415  loss_cls: 0.09903  loss_box_reg: 0.1181  loss_rpn_cls: 0.0208  loss_rpn_loc: 0.008016    time: 0.6991  last_time: 0.4796  data_time: 0.0473  last_data_time: 0.0629   lr: 0.0023976  max_mem: 1553M
# [02/24 16:02:56 d2.utils.events]:  eta: 1:12:01  iter: 979  total_loss: 0.2269  loss_cls: 0.09416  loss_box_reg: 0.1132  loss_rpn_cls: 0.01779  loss_rpn_loc: 0.007317    time: 0.6947  last_time: 0.4524  data_time: 0.0585  last_data_time: 0.0457   lr: 0.0024475  max_mem: 1553M
# [02/24 16:03:06 d2.utils.events]:  eta: 1:11:51  iter: 999  total_loss: 0.2614  loss_cls: 0.1082  loss_box_reg: 0.1188  loss_rpn_cls: 0.01813  loss_rpn_loc: 0.008956    time: 0.6903  last_time: 0.4637  data_time: 0.0563  last_data_time: 0.0464   lr: 0.0024975  max_mem: 1553M
# [02/24 16:03:15 d2.utils.events]:  eta: 1:11:32  iter: 1019  total_loss: 0.2297  loss_cls: 0.09306  loss_box_reg: 0.1136  loss_rpn_cls: 0.01986  loss_rpn_loc: 0.007656    time: 0.6858  last_time: 0.5174  data_time: 0.0523  last_data_time: 0.0890   lr: 0.0025  max_mem: 1553M
# [02/24 16:03:24 d2.utils.events]:  eta: 1:11:11  iter: 1039  total_loss: 0.2401  loss_cls: 0.1004  loss_box_reg: 0.1277  loss_rpn_cls: 0.01898  loss_rpn_loc: 0.009484    time: 0.6817  last_time: 0.4612  data_time: 0.0527  last_data_time: 0.0430   lr: 0.0025  max_mem: 1553M
# [02/24 16:03:34 d2.utils.events]:  eta: 1:10:53  iter: 1059  total_loss: 0.2502  loss_cls: 0.09664  loss_box_reg: 0.1156  loss_rpn_cls: 0.02767  loss_rpn_loc: 0.01048    time: 0.6779  last_time: 0.4619  data_time: 0.0548  last_data_time: 0.0431   lr: 0.0025  max_mem: 1553M
# [02/24 16:03:43 d2.utils.events]:  eta: 1:10:36  iter: 1079  total_loss: 0.2178  loss_cls: 0.07806  loss_box_reg: 0.1098  loss_rpn_cls: 0.0162  loss_rpn_loc: 0.008054    time: 0.6742  last_time: 0.4539  data_time: 0.0543  last_data_time: 0.0445   lr: 0.0025  max_mem: 1553M
# [02/24 16:03:53 d2.utils.events]:  eta: 1:10:10  iter: 1099  total_loss: 0.2393  loss_cls: 0.08896  loss_box_reg: 0.1159  loss_rpn_cls: 0.01969  loss_rpn_loc: 0.007862    time: 0.6702  last_time: 0.4597  data_time: 0.0440  last_data_time: 0.0433   lr: 0.0025  max_mem: 1553M
# [02/24 16:04:02 d2.utils.events]:  eta: 1:09:51  iter: 1119  total_loss: 0.2171  loss_cls: 0.08501  loss_box_reg: 0.1023  loss_rpn_cls: 0.01965  loss_rpn_loc: 0.009453    time: 0.6667  last_time: 0.4633  data_time: 0.0547  last_data_time: 0.0432   lr: 0.0025  max_mem: 1553M
# [02/24 16:04:12 d2.utils.events]:  eta: 1:09:35  iter: 1139  total_loss: 0.2662  loss_cls: 0.1028  loss_box_reg: 0.1245  loss_rpn_cls: 0.0174  loss_rpn_loc: 0.008591    time: 0.6634  last_time: 0.4411  data_time: 0.0540  last_data_time: 0.0579   lr: 0.0025  max_mem: 1553M
# [02/24 16:04:21 d2.utils.events]:  eta: 1:09:19  iter: 1159  total_loss: 0.2491  loss_cls: 0.09827  loss_box_reg: 0.1138  loss_rpn_cls: 0.02323  loss_rpn_loc: 0.009279    time: 0.6601  last_time: 0.5131  data_time: 0.0519  last_data_time: 0.0744   lr: 0.0025  max_mem: 1553M
# [02/24 16:04:30 d2.utils.events]:  eta: 1:09:06  iter: 1179  total_loss: 0.2099  loss_cls: 0.08528  loss_box_reg: 0.1074  loss_rpn_cls: 0.01882  loss_rpn_loc: 0.009895    time: 0.6566  last_time: 0.4749  data_time: 0.0498  last_data_time: 0.0564   lr: 0.0025  max_mem: 1553M
# [02/24 16:04:40 d2.utils.events]:  eta: 1:08:53  iter: 1199  total_loss: 0.2136  loss_cls: 0.09073  loss_box_reg: 0.1004  loss_rpn_cls: 0.01778  loss_rpn_loc: 0.008416    time: 0.6536  last_time: 0.4540  data_time: 0.0525  last_data_time: 0.0439   lr: 0.0025  max_mem: 1553M
# [02/24 16:04:49 d2.utils.events]:  eta: 1:08:40  iter: 1219  total_loss: 0.2543  loss_cls: 0.1008  loss_box_reg: 0.1094  loss_rpn_cls: 0.01832  loss_rpn_loc: 0.008437    time: 0.6507  last_time: 0.4455  data_time: 0.0553  last_data_time: 0.0409   lr: 0.0025  max_mem: 1553M
# [02/24 16:04:58 d2.utils.events]:  eta: 1:08:20  iter: 1239  total_loss: 0.2382  loss_cls: 0.09274  loss_box_reg: 0.1043  loss_rpn_cls: 0.02257  loss_rpn_loc: 0.008562    time: 0.6476  last_time: 0.5336  data_time: 0.0465  last_data_time: 0.0762   lr: 0.0025  max_mem: 1553M
# [02/24 16:05:08 d2.utils.events]:  eta: 1:08:08  iter: 1259  total_loss: 0.2386  loss_cls: 0.09236  loss_box_reg: 0.1174  loss_rpn_cls: 0.02145  loss_rpn_loc: 0.008691    time: 0.6448  last_time: 0.4542  data_time: 0.0562  last_data_time: 0.0426   lr: 0.0025  max_mem: 1553M
# [02/24 16:05:18 d2.utils.events]:  eta: 1:07:56  iter: 1279  total_loss: 0.2399  loss_cls: 0.09258  loss_box_reg: 0.1151  loss_rpn_cls: 0.01469  loss_rpn_loc: 0.008355    time: 0.6423  last_time: 0.4665  data_time: 0.0552  last_data_time: 0.0437   lr: 0.0025  max_mem: 1553M
# [02/24 16:05:27 d2.utils.events]:  eta: 1:07:44  iter: 1299  total_loss: 0.2164  loss_cls: 0.0832  loss_box_reg: 0.1058  loss_rpn_cls: 0.01648  loss_rpn_loc: 0.007699    time: 0.6397  last_time: 0.5120  data_time: 0.0551  last_data_time: 0.0709   lr: 0.0025  max_mem: 1553M
# [02/24 16:05:36 d2.utils.events]:  eta: 1:07:30  iter: 1319  total_loss: 0.2226  loss_cls: 0.08507  loss_box_reg: 0.1156  loss_rpn_cls: 0.01563  loss_rpn_loc: 0.006818    time: 0.6369  last_time: 0.4555  data_time: 0.0455  last_data_time: 0.0468   lr: 0.0025  max_mem: 1553M
# [02/24 16:05:46 d2.utils.events]:  eta: 1:07:18  iter: 1339  total_loss: 0.2152  loss_cls: 0.08566  loss_box_reg: 0.1042  loss_rpn_cls: 0.0148  loss_rpn_loc: 0.007986    time: 0.6346  last_time: 0.4573  data_time: 0.0554  last_data_time: 0.0435   lr: 0.0025  max_mem: 1553M
# [02/24 16:05:55 d2.utils.events]:  eta: 1:07:07  iter: 1359  total_loss: 0.2348  loss_cls: 0.09138  loss_box_reg: 0.1173  loss_rpn_cls: 0.01648  loss_rpn_loc: 0.008758    time: 0.6322  last_time: 0.4620  data_time: 0.0539  last_data_time: 0.0398   lr: 0.0025  max_mem: 1553M
# [02/24 16:06:05 d2.utils.events]:  eta: 1:06:53  iter: 1379  total_loss: 0.2364  loss_cls: 0.09442  loss_box_reg: 0.1178  loss_rpn_cls: 0.01679  loss_rpn_loc: 0.008343    time: 0.6298  last_time: 0.5403  data_time: 0.0459  last_data_time: 0.0697   lr: 0.0025  max_mem: 1553M
# [02/24 16:06:14 d2.utils.events]:  eta: 1:06:40  iter: 1399  total_loss: 0.2497  loss_cls: 0.08962  loss_box_reg: 0.128  loss_rpn_cls: 0.02151  loss_rpn_loc: 0.008509    time: 0.6274  last_time: 0.4538  data_time: 0.0507  last_data_time: 0.0425   lr: 0.0025  max_mem: 1553M
# [02/24 16:06:23 d2.utils.events]:  eta: 1:06:28  iter: 1419  total_loss: 0.2202  loss_cls: 0.08098  loss_box_reg: 0.1163  loss_rpn_cls: 0.01569  loss_rpn_loc: 0.007298    time: 0.6252  last_time: 0.4516  data_time: 0.0580  last_data_time: 0.0405   lr: 0.0025  max_mem: 1553M
# [02/24 16:06:33 d2.utils.events]:  eta: 1:06:16  iter: 1439  total_loss: 0.2103  loss_cls: 0.08453  loss_box_reg: 0.1102  loss_rpn_cls: 0.01324  loss_rpn_loc: 0.007214    time: 0.6229  last_time: 0.5245  data_time: 0.0537  last_data_time: 0.0815   lr: 0.0025  max_mem: 1553M
# [02/24 16:06:41 d2.utils.events]:  eta: 1:06:03  iter: 1459  total_loss: 0.2118  loss_cls: 0.07857  loss_box_reg: 0.1057  loss_rpn_cls: 0.01852  loss_rpn_loc: 0.008272    time: 0.6205  last_time: 0.4229  data_time: 0.0439  last_data_time: 0.0420   lr: 0.0025  max_mem: 1553M
# [02/24 16:06:51 d2.utils.events]:  eta: 1:05:51  iter: 1479  total_loss: 0.2262  loss_cls: 0.08332  loss_box_reg: 0.1132  loss_rpn_cls: 0.01557  loss_rpn_loc: 0.00709    time: 0.6184  last_time: 0.4304  data_time: 0.0547  last_data_time: 0.0483   lr: 0.0025  max_mem: 1553M
# [02/24 16:07:00 d2.utils.events]:  eta: 1:05:39  iter: 1499  total_loss: 0.2058  loss_cls: 0.07618  loss_box_reg: 0.1082  loss_rpn_cls: 0.01456  loss_rpn_loc: 0.009006    time: 0.6165  last_time: 0.4572  data_time: 0.0537  last_data_time: 0.0429   lr: 0.0025  max_mem: 1553M
# [02/24 16:07:10 d2.utils.events]:  eta: 1:05:27  iter: 1519  total_loss: 0.2161  loss_cls: 0.08131  loss_box_reg: 0.1085  loss_rpn_cls: 0.01367  loss_rpn_loc: 0.006594    time: 0.6145  last_time: 0.5045  data_time: 0.0460  last_data_time: 0.0670   lr: 0.0025  max_mem: 1553M
# [02/24 16:07:19 d2.utils.events]:  eta: 1:05:16  iter: 1539  total_loss: 0.2279  loss_cls: 0.08161  loss_box_reg: 0.1204  loss_rpn_cls: 0.01619  loss_rpn_loc: 0.008018    time: 0.6125  last_time: 0.4536  data_time: 0.0529  last_data_time: 0.0482   lr: 0.0025  max_mem: 1553M
# [02/24 16:07:28 d2.utils.events]:  eta: 1:05:05  iter: 1559  total_loss: 0.2315  loss_cls: 0.08965  loss_box_reg: 0.1155  loss_rpn_cls: 0.01401  loss_rpn_loc: 0.007304    time: 0.6107  last_time: 0.4504  data_time: 0.0537  last_data_time: 0.0425   lr: 0.0025  max_mem: 1553M
# [02/24 16:07:38 d2.utils.events]:  eta: 1:04:54  iter: 1579  total_loss: 0.2344  loss_cls: 0.08682  loss_box_reg: 0.119  loss_rpn_cls: 0.01425  loss_rpn_loc: 0.007587    time: 0.6090  last_time: 0.5319  data_time: 0.0527  last_data_time: 0.0737   lr: 0.0025  max_mem: 1553M
# [02/24 16:07:47 d2.utils.events]:  eta: 1:04:41  iter: 1599  total_loss: 0.2282  loss_cls: 0.0838  loss_box_reg: 0.1217  loss_rpn_cls: 0.01495  loss_rpn_loc: 0.0076    time: 0.6070  last_time: 0.4467  data_time: 0.0448  last_data_time: 0.0391   lr: 0.0025  max_mem: 1553M
# [02/24 16:07:56 d2.utils.events]:  eta: 1:04:31  iter: 1619  total_loss: 0.2174  loss_cls: 0.08012  loss_box_reg: 0.1171  loss_rpn_cls: 0.01444  loss_rpn_loc: 0.006848    time: 0.6053  last_time: 0.4554  data_time: 0.0527  last_data_time: 0.0445   lr: 0.0025  max_mem: 1553M
# [02/24 16:08:06 d2.utils.events]:  eta: 1:04:21  iter: 1639  total_loss: 0.216  loss_cls: 0.0729  loss_box_reg: 0.1171  loss_rpn_cls: 0.01071  loss_rpn_loc: 0.007629    time: 0.6036  last_time: 0.4475  data_time: 0.0540  last_data_time: 0.0437   lr: 0.0025  max_mem: 1553M
# [02/24 16:08:15 d2.utils.events]:  eta: 1:04:09  iter: 1659  total_loss: 0.2348  loss_cls: 0.08815  loss_box_reg: 0.1168  loss_rpn_cls: 0.01517  loss_rpn_loc: 0.006876    time: 0.6019  last_time: 0.5085  data_time: 0.0478  last_data_time: 0.0744   lr: 0.0025  max_mem: 1553M
# [02/24 16:08:24 d2.utils.events]:  eta: 1:03:58  iter: 1679  total_loss: 0.2209  loss_cls: 0.08486  loss_box_reg: 0.1139  loss_rpn_cls: 0.02094  loss_rpn_loc: 0.007591    time: 0.6003  last_time: 0.4275  data_time: 0.0536  last_data_time: 0.0409   lr: 0.0025  max_mem: 1553M
# [02/24 16:08:34 d2.utils.events]:  eta: 1:03:49  iter: 1699  total_loss: 0.2391  loss_cls: 0.08583  loss_box_reg: 0.1231  loss_rpn_cls: 0.01689  loss_rpn_loc: 0.007937    time: 0.5988  last_time: 0.4755  data_time: 0.0568  last_data_time: 0.0658   lr: 0.0025  max_mem: 1553M
# [02/24 16:08:43 d2.utils.events]:  eta: 1:03:40  iter: 1719  total_loss: 0.216  loss_cls: 0.08351  loss_box_reg: 0.1036  loss_rpn_cls: 0.01625  loss_rpn_loc: 0.007652    time: 0.5973  last_time: 0.5036  data_time: 0.0502  last_data_time: 0.0748   lr: 0.0025  max_mem: 1553M
# [02/24 16:08:52 d2.utils.events]:  eta: 1:03:28  iter: 1739  total_loss: 0.2464  loss_cls: 0.09271  loss_box_reg: 0.1265  loss_rpn_cls: 0.01615  loss_rpn_loc: 0.007565    time: 0.5957  last_time: 0.4669  data_time: 0.0461  last_data_time: 0.0428   lr: 0.0025  max_mem: 1553M
# [02/24 16:09:02 d2.utils.events]:  eta: 1:03:19  iter: 1759  total_loss: 0.2096  loss_cls: 0.07828  loss_box_reg: 0.1092  loss_rpn_cls: 0.01437  loss_rpn_loc: 0.006615    time: 0.5943  last_time: 0.4549  data_time: 0.0540  last_data_time: 0.0449   lr: 0.0025  max_mem: 1553M
# [02/24 16:09:11 d2.utils.events]:  eta: 1:03:09  iter: 1779  total_loss: 0.1971  loss_cls: 0.07099  loss_box_reg: 0.09868  loss_rpn_cls: 0.01217  loss_rpn_loc: 0.00592    time: 0.5929  last_time: 0.4506  data_time: 0.0558  last_data_time: 0.0412   lr: 0.0025  max_mem: 1553M
# [02/24 16:09:20 d2.utils.events]:  eta: 1:02:55  iter: 1799  total_loss: 0.2114  loss_cls: 0.0828  loss_box_reg: 0.1126  loss_rpn_cls: 0.01422  loss_rpn_loc: 0.007815    time: 0.5913  last_time: 0.5239  data_time: 0.0471  last_data_time: 0.0924   lr: 0.0025  max_mem: 1553M
# [02/24 16:09:30 d2.utils.events]:  eta: 1:02:45  iter: 1819  total_loss: 0.2135  loss_cls: 0.07805  loss_box_reg: 0.1173  loss_rpn_cls: 0.011  loss_rpn_loc: 0.007459    time: 0.5900  last_time: 0.4647  data_time: 0.0573  last_data_time: 0.0430   lr: 0.0025  max_mem: 1553M
# [02/24 16:09:39 d2.utils.events]:  eta: 1:02:36  iter: 1839  total_loss: 0.2038  loss_cls: 0.07637  loss_box_reg: 0.1083  loss_rpn_cls: 0.01427  loss_rpn_loc: 0.007435    time: 0.5887  last_time: 0.4593  data_time: 0.0544  last_data_time: 0.0435   lr: 0.0025  max_mem: 1553M
# [02/24 16:09:48 d2.utils.events]:  eta: 1:02:25  iter: 1859  total_loss: 0.2298  loss_cls: 0.08348  loss_box_reg: 0.1196  loss_rpn_cls: 0.0138  loss_rpn_loc: 0.007131    time: 0.5874  last_time: 0.5141  data_time: 0.0524  last_data_time: 0.0718   lr: 0.0025  max_mem: 1553M
# [02/24 16:09:57 d2.utils.events]:  eta: 1:02:14  iter: 1879  total_loss: 0.2109  loss_cls: 0.07914  loss_box_reg: 0.1158  loss_rpn_cls: 0.01281  loss_rpn_loc: 0.006914    time: 0.5860  last_time: 0.4560  data_time: 0.0438  last_data_time: 0.0436   lr: 0.0025  max_mem: 1553M
# [02/24 16:10:07 d2.utils.events]:  eta: 1:02:04  iter: 1899  total_loss: 0.2338  loss_cls: 0.09047  loss_box_reg: 0.1196  loss_rpn_cls: 0.01407  loss_rpn_loc: 0.008062    time: 0.5847  last_time: 0.4427  data_time: 0.0563  last_data_time: 0.0432   lr: 0.0025  max_mem: 1553M
# [02/24 16:10:16 d2.utils.events]:  eta: 1:01:53  iter: 1919  total_loss: 0.2191  loss_cls: 0.07703  loss_box_reg: 0.1161  loss_rpn_cls: 0.01522  loss_rpn_loc: 0.00735    time: 0.5835  last_time: 0.4508  data_time: 0.0547  last_data_time: 0.0443   lr: 0.0025  max_mem: 1553M
# [02/24 16:10:25 d2.utils.events]:  eta: 1:01:38  iter: 1939  total_loss: 0.2042  loss_cls: 0.07456  loss_box_reg: 0.1135  loss_rpn_cls: 0.01215  loss_rpn_loc: 0.006464    time: 0.5821  last_time: 0.4603  data_time: 0.0440  last_data_time: 0.0423   lr: 0.0025  max_mem: 1553M
# [02/24 16:10:35 d2.utils.events]:  eta: 1:01:28  iter: 1959  total_loss: 0.2019  loss_cls: 0.07635  loss_box_reg: 0.1033  loss_rpn_cls: 0.0127  loss_rpn_loc: 0.008537    time: 0.5810  last_time: 0.4620  data_time: 0.0548  last_data_time: 0.0455   lr: 0.0025  max_mem: 1553M
# [02/24 16:10:44 d2.utils.events]:  eta: 1:01:19  iter: 1979  total_loss: 0.2231  loss_cls: 0.08317  loss_box_reg: 0.1177  loss_rpn_cls: 0.0153  loss_rpn_loc: 0.007348    time: 0.5800  last_time: 0.4516  data_time: 0.0585  last_data_time: 0.0425   lr: 0.0025  max_mem: 1553M
# [02/24 16:10:54 d2.utils.events]:  eta: 1:01:11  iter: 1999  total_loss: 0.1965  loss_cls: 0.07195  loss_box_reg: 0.1107  loss_rpn_cls: 0.01183  loss_rpn_loc: 0.006659    time: 0.5789  last_time: 0.5442  data_time: 0.0517  last_data_time: 0.0820   lr: 0.0025  max_mem: 1553M
# [02/24 16:11:03 d2.utils.events]:  eta: 1:01:01  iter: 2019  total_loss: 0.1939  loss_cls: 0.0706  loss_box_reg: 0.1107  loss_rpn_cls: 0.01072  loss_rpn_loc: 0.006274    time: 0.5777  last_time: 0.4763  data_time: 0.0457  last_data_time: 0.0611   lr: 0.0025  max_mem: 1553M
# [02/24 16:11:12 d2.utils.events]:  eta: 1:00:51  iter: 2039  total_loss: 0.1805  loss_cls: 0.06765  loss_box_reg: 0.1028  loss_rpn_cls: 0.008909  loss_rpn_loc: 0.005975    time: 0.5767  last_time: 0.4554  data_time: 0.0551  last_data_time: 0.0436   lr: 0.0025  max_mem: 1553M
# [02/24 16:11:22 d2.utils.events]:  eta: 1:00:41  iter: 2059  total_loss: 0.2429  loss_cls: 0.08868  loss_box_reg: 0.1253  loss_rpn_cls: 0.01504  loss_rpn_loc: 0.007551    time: 0.5757  last_time: 0.4654  data_time: 0.0557  last_data_time: 0.0443   lr: 0.0025  max_mem: 1553M
# [02/24 16:11:31 d2.utils.events]:  eta: 1:00:31  iter: 2079  total_loss: 0.2207  loss_cls: 0.07662  loss_box_reg: 0.1186  loss_rpn_cls: 0.009555  loss_rpn_loc: 0.006989    time: 0.5746  last_time: 0.5133  data_time: 0.0458  last_data_time: 0.0735   lr: 0.0025  max_mem: 1553M
# [02/24 16:11:40 d2.utils.events]:  eta: 1:00:21  iter: 2099  total_loss: 0.2125  loss_cls: 0.07047  loss_box_reg: 0.106  loss_rpn_cls: 0.01574  loss_rpn_loc: 0.00693    time: 0.5736  last_time: 0.4473  data_time: 0.0548  last_data_time: 0.0426   lr: 0.0025  max_mem: 1553M
# [02/24 16:11:50 d2.utils.events]:  eta: 1:00:10  iter: 2119  total_loss: 0.2094  loss_cls: 0.07392  loss_box_reg: 0.1099  loss_rpn_cls: 0.01159  loss_rpn_loc: 0.007343    time: 0.5726  last_time: 0.4559  data_time: 0.0571  last_data_time: 0.0445   lr: 0.0025  max_mem: 1553M
# [02/24 16:11:59 d2.utils.events]:  eta: 0:59:59  iter: 2139  total_loss: 0.2041  loss_cls: 0.07734  loss_box_reg: 0.1158  loss_rpn_cls: 0.008677  loss_rpn_loc: 0.006141    time: 0.5716  last_time: 0.4840  data_time: 0.0484  last_data_time: 0.0776   lr: 0.0025  max_mem: 1553M
# [02/24 16:12:08 d2.utils.events]:  eta: 0:59:48  iter: 2159  total_loss: 0.2345  loss_cls: 0.08715  loss_box_reg: 0.1158  loss_rpn_cls: 0.01258  loss_rpn_loc: 0.007217    time: 0.5705  last_time: 0.4536  data_time: 0.0471  last_data_time: 0.0428   lr: 0.0025  max_mem: 1553M
# [02/24 16:12:18 d2.utils.events]:  eta: 0:59:39  iter: 2179  total_loss: 0.2085  loss_cls: 0.07914  loss_box_reg: 0.1152  loss_rpn_cls: 0.01076  loss_rpn_loc: 0.007581    time: 0.5695  last_time: 0.4478  data_time: 0.0525  last_data_time: 0.0438   lr: 0.0025  max_mem: 1553M
# [02/24 16:12:27 d2.utils.events]:  eta: 0:59:29  iter: 2199  total_loss: 0.2  loss_cls: 0.07805  loss_box_reg: 0.1102  loss_rpn_cls: 0.01226  loss_rpn_loc: 0.007155    time: 0.5686  last_time: 0.4708  data_time: 0.0537  last_data_time: 0.0583   lr: 0.0025  max_mem: 1553M
# [02/24 16:12:36 d2.utils.events]:  eta: 0:59:18  iter: 2219  total_loss: 0.2231  loss_cls: 0.07387  loss_box_reg: 0.1156  loss_rpn_cls: 0.0116  loss_rpn_loc: 0.006944    time: 0.5676  last_time: 0.4544  data_time: 0.0452  last_data_time: 0.0431   lr: 0.0025  max_mem: 1553M
# [02/24 16:12:45 d2.utils.events]:  eta: 0:59:10  iter: 2239  total_loss: 0.1911  loss_cls: 0.07164  loss_box_reg: 0.1041  loss_rpn_cls: 0.01302  loss_rpn_loc: 0.006593    time: 0.5667  last_time: 0.4553  data_time: 0.0561  last_data_time: 0.0445   lr: 0.0025  max_mem: 1553M
# [02/24 16:12:55 d2.utils.events]:  eta: 0:59:01  iter: 2259  total_loss: 0.211  loss_cls: 0.08392  loss_box_reg: 0.1094  loss_rpn_cls: 0.01253  loss_rpn_loc: 0.007635    time: 0.5659  last_time: 0.4491  data_time: 0.0544  last_data_time: 0.0415   lr: 0.0025  max_mem: 1553M
# [02/24 16:13:04 d2.utils.events]:  eta: 0:58:49  iter: 2279  total_loss: 0.2093  loss_cls: 0.07683  loss_box_reg: 0.1089  loss_rpn_cls: 0.01255  loss_rpn_loc: 0.006311    time: 0.5650  last_time: 0.5057  data_time: 0.0521  last_data_time: 0.0760   lr: 0.0025  max_mem: 1553M
# [02/24 16:13:13 d2.utils.events]:  eta: 0:58:37  iter: 2299  total_loss: 0.2136  loss_cls: 0.08384  loss_box_reg: 0.1112  loss_rpn_cls: 0.0125  loss_rpn_loc: 0.007015    time: 0.5641  last_time: 0.4493  data_time: 0.0492  last_data_time: 0.0433   lr: 0.0025  max_mem: 1553M
# [02/24 16:13:23 d2.utils.events]:  eta: 0:58:30  iter: 2319  total_loss: 0.2262  loss_cls: 0.09094  loss_box_reg: 0.1259  loss_rpn_cls: 0.01182  loss_rpn_loc: 0.007898    time: 0.5633  last_time: 0.4399  data_time: 0.0550  last_data_time: 0.0628   lr: 0.0025  max_mem: 1553M
# [02/24 16:13:32 d2.utils.events]:  eta: 0:58:18  iter: 2339  total_loss: 0.2127  loss_cls: 0.07407  loss_box_reg: 0.114  loss_rpn_cls: 0.01082  loss_rpn_loc: 0.00726    time: 0.5625  last_time: 0.4652  data_time: 0.0533  last_data_time: 0.0437   lr: 0.0025  max_mem: 1553M
# ...
# [02/24 17:07:01 d2.utils.events]:  eta: 0:06:03  iter: 9179  total_loss: 0.09558  loss_cls: 0.02667  loss_box_reg: 0.06423  loss_rpn_cls: 0.001292  loss_rpn_loc: 0.004569    time: 0.4846  last_time: 0.4345  data_time: 0.0451  last_data_time: 0.0410   lr: 0.0025  max_mem: 1554M
# [02/24 17:07:10 d2.utils.events]:  eta: 0:05:54  iter: 9199  total_loss: 0.1063  loss_cls: 0.02955  loss_box_reg: 0.07142  loss_rpn_cls: 0.00178  loss_rpn_loc: 0.003869    time: 0.4846  last_time: 0.4119  data_time: 0.0542  last_data_time: 0.0437   lr: 0.0025  max_mem: 1554M
# [02/24 17:07:19 d2.utils.events]:  eta: 0:05:45  iter: 9219  total_loss: 0.1014  loss_cls: 0.02904  loss_box_reg: 0.06651  loss_rpn_cls: 0.0011  loss_rpn_loc: 0.004387    time: 0.4845  last_time: 0.4737  data_time: 0.0537  last_data_time: 0.0687   lr: 0.0025  max_mem: 1554M
# [02/24 17:07:28 d2.utils.events]:  eta: 0:05:36  iter: 9239  total_loss: 0.09233  loss_cls: 0.02839  loss_box_reg: 0.06083  loss_rpn_cls: 0.001497  loss_rpn_loc: 0.003619    time: 0.4844  last_time: 0.4349  data_time: 0.0426  last_data_time: 0.0413   lr: 0.0025  max_mem: 1554M
# [02/24 17:07:37 d2.utils.events]:  eta: 0:05:27  iter: 9259  total_loss: 0.1059  loss_cls: 0.02926  loss_box_reg: 0.06937  loss_rpn_cls: 0.001269  loss_rpn_loc: 0.004323    time: 0.4843  last_time: 0.4375  data_time: 0.0514  last_data_time: 0.0413   lr: 0.0025  max_mem: 1554M
# [02/24 17:07:46 d2.utils.events]:  eta: 0:05:18  iter: 9279  total_loss: 0.1165  loss_cls: 0.03024  loss_box_reg: 0.07873  loss_rpn_cls: 0.001623  loss_rpn_loc: 0.004827    time: 0.4843  last_time: 0.4346  data_time: 0.0532  last_data_time: 0.0408   lr: 0.0025  max_mem: 1554M
# [02/24 17:07:55 d2.utils.events]:  eta: 0:05:10  iter: 9299  total_loss: 0.1036  loss_cls: 0.02615  loss_box_reg: 0.07066  loss_rpn_cls: 0.0009422  loss_rpn_loc: 0.003831    time: 0.4842  last_time: 0.4594  data_time: 0.0438  last_data_time: 0.0525   lr: 0.0025  max_mem: 1554M
# [02/24 17:08:04 d2.utils.events]:  eta: 0:05:01  iter: 9319  total_loss: 0.09173  loss_cls: 0.02647  loss_box_reg: 0.06222  loss_rpn_cls: 0.001109  loss_rpn_loc: 0.00336    time: 0.4841  last_time: 0.4337  data_time: 0.0533  last_data_time: 0.0410   lr: 0.0025  max_mem: 1554M
# [02/24 17:08:13 d2.utils.events]:  eta: 0:04:52  iter: 9339  total_loss: 0.07932  loss_cls: 0.02365  loss_box_reg: 0.0524  loss_rpn_cls: 0.001277  loss_rpn_loc: 0.003022    time: 0.4841  last_time: 0.4391  data_time: 0.0531  last_data_time: 0.0409   lr: 0.0025  max_mem: 1554M
# [02/24 17:08:22 d2.utils.events]:  eta: 0:04:43  iter: 9359  total_loss: 0.1252  loss_cls: 0.03264  loss_box_reg: 0.08777  loss_rpn_cls: 0.00201  loss_rpn_loc: 0.00457    time: 0.4840  last_time: 0.5019  data_time: 0.0488  last_data_time: 0.0704   lr: 0.0025  max_mem: 1554M
# [02/24 17:08:31 d2.utils.events]:  eta: 0:04:34  iter: 9379  total_loss: 0.1094  loss_cls: 0.03001  loss_box_reg: 0.07128  loss_rpn_cls: 0.002061  loss_rpn_loc: 0.004518    time: 0.4839  last_time: 0.4446  data_time: 0.0468  last_data_time: 0.0416   lr: 0.0025  max_mem: 1554M
# [02/24 17:08:40 d2.utils.events]:  eta: 0:04:25  iter: 9399  total_loss: 0.1087  loss_cls: 0.02768  loss_box_reg: 0.07214  loss_rpn_cls: 0.001702  loss_rpn_loc: 0.004434    time: 0.4839  last_time: 0.4418  data_time: 0.0534  last_data_time: 0.0397   lr: 0.0025  max_mem: 1554M
# [02/24 17:08:49 d2.utils.events]:  eta: 0:04:17  iter: 9419  total_loss: 0.09845  loss_cls: 0.02685  loss_box_reg: 0.06432  loss_rpn_cls: 0.0009809  loss_rpn_loc: 0.003795    time: 0.4838  last_time: 0.4912  data_time: 0.0519  last_data_time: 0.0735   lr: 0.0025  max_mem: 1554M
# [02/24 17:08:58 d2.utils.events]:  eta: 0:04:08  iter: 9439  total_loss: 0.1029  loss_cls: 0.03044  loss_box_reg: 0.07217  loss_rpn_cls: 0.001286  loss_rpn_loc: 0.004467    time: 0.4837  last_time: 0.4451  data_time: 0.0478  last_data_time: 0.0410   lr: 0.0025  max_mem: 1554M
# [02/24 17:09:07 d2.utils.events]:  eta: 0:03:59  iter: 9459  total_loss: 0.1107  loss_cls: 0.03079  loss_box_reg: 0.07096  loss_rpn_cls: 0.001118  loss_rpn_loc: 0.004816    time: 0.4836  last_time: 0.4317  data_time: 0.0569  last_data_time: 0.0410   lr: 0.0025  max_mem: 1554M
# [02/24 17:09:16 d2.utils.events]:  eta: 0:03:50  iter: 9479  total_loss: 0.09888  loss_cls: 0.0275  loss_box_reg: 0.06747  loss_rpn_cls: 0.0007835  loss_rpn_loc: 0.004459    time: 0.4836  last_time: 0.4876  data_time: 0.0543  last_data_time: 0.0653   lr: 0.0025  max_mem: 1554M
# [02/24 17:09:25 d2.utils.events]:  eta: 0:03:41  iter: 9499  total_loss: 0.1044  loss_cls: 0.03182  loss_box_reg: 0.06704  loss_rpn_cls: 0.002032  loss_rpn_loc: 0.004145    time: 0.4835  last_time: 0.4399  data_time: 0.0429  last_data_time: 0.0418   lr: 0.0025  max_mem: 1554M
# [02/24 17:09:34 d2.utils.events]:  eta: 0:03:32  iter: 9519  total_loss: 0.09538  loss_cls: 0.02828  loss_box_reg: 0.06203  loss_rpn_cls: 0.001463  loss_rpn_loc: 0.004629    time: 0.4834  last_time: 0.4690  data_time: 0.0536  last_data_time: 0.0675   lr: 0.0025  max_mem: 1554M
# [02/24 17:09:43 d2.utils.events]:  eta: 0:03:23  iter: 9539  total_loss: 0.09439  loss_cls: 0.02626  loss_box_reg: 0.06305  loss_rpn_cls: 0.001013  loss_rpn_loc: 0.003417    time: 0.4834  last_time: 0.4505  data_time: 0.0529  last_data_time: 0.0402   lr: 0.0025  max_mem: 1554M
# [02/24 17:09:52 d2.utils.events]:  eta: 0:03:14  iter: 9559  total_loss: 0.1049  loss_cls: 0.02629  loss_box_reg: 0.06942  loss_rpn_cls: 0.001443  loss_rpn_loc: 0.003958    time: 0.4833  last_time: 0.4329  data_time: 0.0460  last_data_time: 0.0410   lr: 0.0025  max_mem: 1554M
# [02/24 17:10:01 d2.utils.events]:  eta: 0:03:05  iter: 9579  total_loss: 0.089  loss_cls: 0.0246  loss_box_reg: 0.05927  loss_rpn_cls: 0.001652  loss_rpn_loc: 0.00398    time: 0.4832  last_time: 0.4113  data_time: 0.0543  last_data_time: 0.0424   lr: 0.0025  max_mem: 1554M
# [02/24 17:10:10 d2.utils.events]:  eta: 0:02:57  iter: 9599  total_loss: 0.08553  loss_cls: 0.02364  loss_box_reg: 0.05505  loss_rpn_cls: 0.001273  loss_rpn_loc: 0.003712    time: 0.4831  last_time: 0.4442  data_time: 0.0543  last_data_time: 0.0423   lr: 0.0025  max_mem: 1554M
# [02/24 17:10:19 d2.utils.events]:  eta: 0:02:48  iter: 9619  total_loss: 0.1109  loss_cls: 0.02916  loss_box_reg: 0.07653  loss_rpn_cls: 0.001478  loss_rpn_loc: 0.004262    time: 0.4830  last_time: 0.4614  data_time: 0.0440  last_data_time: 0.0415   lr: 0.0025  max_mem: 1554M
# [02/24 17:10:28 d2.utils.events]:  eta: 0:02:39  iter: 9639  total_loss: 0.08615  loss_cls: 0.02443  loss_box_reg: 0.05341  loss_rpn_cls: 0.0009119  loss_rpn_loc: 0.00368    time: 0.4830  last_time: 0.4286  data_time: 0.0516  last_data_time: 0.0406   lr: 0.0025  max_mem: 1554M
# [02/24 17:10:37 d2.utils.events]:  eta: 0:02:30  iter: 9659  total_loss: 0.1137  loss_cls: 0.03257  loss_box_reg: 0.07641  loss_rpn_cls: 0.001458  loss_rpn_loc: 0.005037    time: 0.4829  last_time: 0.4314  data_time: 0.0581  last_data_time: 0.0409   lr: 0.0025  max_mem: 1554M
# [02/24 17:10:46 d2.utils.events]:  eta: 0:02:21  iter: 9679  total_loss: 0.088  loss_cls: 0.02613  loss_box_reg: 0.05863  loss_rpn_cls: 0.001159  loss_rpn_loc: 0.003869    time: 0.4828  last_time: 0.4928  data_time: 0.0459  last_data_time: 0.0866   lr: 0.0025  max_mem: 1554M
# [02/24 17:10:55 d2.utils.events]:  eta: 0:02:12  iter: 9699  total_loss: 0.0919  loss_cls: 0.02543  loss_box_reg: 0.06395  loss_rpn_cls: 0.0008354  loss_rpn_loc: 0.004202    time: 0.4827  last_time: 0.4358  data_time: 0.0518  last_data_time: 0.0410   lr: 0.0025  max_mem: 1554M
# [02/24 17:11:04 d2.utils.events]:  eta: 0:02:03  iter: 9719  total_loss: 0.09781  loss_cls: 0.02649  loss_box_reg: 0.0679  loss_rpn_cls: 0.001224  loss_rpn_loc: 0.003986    time: 0.4827  last_time: 0.4565  data_time: 0.0537  last_data_time: 0.0610   lr: 0.0025  max_mem: 1554M
# [02/24 17:11:13 d2.utils.events]:  eta: 0:01:54  iter: 9739  total_loss: 0.1178  loss_cls: 0.03849  loss_box_reg: 0.07168  loss_rpn_cls: 0.002093  loss_rpn_loc: 0.003867    time: 0.4826  last_time: 0.5016  data_time: 0.0494  last_data_time: 0.0820   lr: 0.0025  max_mem: 1554M
# [02/24 17:11:22 d2.utils.events]:  eta: 0:01:46  iter: 9759  total_loss: 0.1094  loss_cls: 0.02791  loss_box_reg: 0.07447  loss_rpn_cls: 0.001696  loss_rpn_loc: 0.004085    time: 0.4825  last_time: 0.4345  data_time: 0.0517  last_data_time: 0.0435   lr: 0.0025  max_mem: 1554M
# [02/24 17:11:31 d2.utils.events]:  eta: 0:01:37  iter: 9779  total_loss: 0.09364  loss_cls: 0.02497  loss_box_reg: 0.06062  loss_rpn_cls: 0.001104  loss_rpn_loc: 0.003701    time: 0.4825  last_time: 0.4492  data_time: 0.0546  last_data_time: 0.0456   lr: 0.0025  max_mem: 1554M
# [02/24 17:11:40 d2.utils.events]:  eta: 0:01:28  iter: 9799  total_loss: 0.1096  loss_cls: 0.02908  loss_box_reg: 0.07071  loss_rpn_cls: 0.001737  loss_rpn_loc: 0.004254    time: 0.4824  last_time: 0.4912  data_time: 0.0524  last_data_time: 0.0786   lr: 0.0025  max_mem: 1554M
# [02/24 17:11:48 d2.utils.events]:  eta: 0:01:19  iter: 9819  total_loss: 0.1069  loss_cls: 0.0272  loss_box_reg: 0.07408  loss_rpn_cls: 0.001687  loss_rpn_loc: 0.004826    time: 0.4823  last_time: 0.4025  data_time: 0.0451  last_data_time: 0.0416   lr: 0.0025  max_mem: 1554M
# [02/24 17:11:57 d2.utils.events]:  eta: 0:01:10  iter: 9839  total_loss: 0.08302  loss_cls: 0.02537  loss_box_reg: 0.05553  loss_rpn_cls: 0.001473  loss_rpn_loc: 0.003739    time: 0.4822  last_time: 0.4395  data_time: 0.0541  last_data_time: 0.0445   lr: 0.0025  max_mem: 1554M
# [02/24 17:12:07 d2.utils.events]:  eta: 0:01:01  iter: 9859  total_loss: 0.09105  loss_cls: 0.02513  loss_box_reg: 0.05796  loss_rpn_cls: 0.001215  loss_rpn_loc: 0.003303    time: 0.4822  last_time: 0.5044  data_time: 0.0538  last_data_time: 0.0695   lr: 0.0025  max_mem: 1554M
# [02/24 17:12:15 d2.utils.events]:  eta: 0:00:52  iter: 9879  total_loss: 0.09013  loss_cls: 0.02418  loss_box_reg: 0.06074  loss_rpn_cls: 0.0009766  loss_rpn_loc: 0.003845    time: 0.4821  last_time: 0.4380  data_time: 0.0455  last_data_time: 0.0435   lr: 0.0025  max_mem: 1554M
# [02/24 17:12:25 d2.utils.events]:  eta: 0:00:44  iter: 9899  total_loss: 0.09402  loss_cls: 0.02395  loss_box_reg: 0.06182  loss_rpn_cls: 0.001865  loss_rpn_loc: 0.004218    time: 0.4821  last_time: 0.4341  data_time: 0.0725  last_data_time: 0.0436   lr: 0.0025  max_mem: 1554M
# [02/24 17:12:34 d2.utils.events]:  eta: 0:00:35  iter: 9919  total_loss: 0.09121  loss_cls: 0.02614  loss_box_reg: 0.05817  loss_rpn_cls: 0.001801  loss_rpn_loc: 0.00422    time: 0.4820  last_time: 0.5016  data_time: 0.0509  last_data_time: 0.0736   lr: 0.0025  max_mem: 1554M
# [02/24 17:12:43 d2.utils.events]:  eta: 0:00:26  iter: 9939  total_loss: 0.08545  loss_cls: 0.02224  loss_box_reg: 0.05645  loss_rpn_cls: 0.001579  loss_rpn_loc: 0.003866    time: 0.4820  last_time: 0.4329  data_time: 0.0482  last_data_time: 0.0406   lr: 0.0025  max_mem: 1554M
# [02/24 17:12:52 d2.utils.events]:  eta: 0:00:17  iter: 9959  total_loss: 0.1016  loss_cls: 0.02751  loss_box_reg: 0.06565  loss_rpn_cls: 0.001346  loss_rpn_loc: 0.004634    time: 0.4819  last_time: 0.4401  data_time: 0.0531  last_data_time: 0.0403   lr: 0.0025  max_mem: 1554M
# [02/24 17:13:01 d2.utils.events]:  eta: 0:00:08  iter: 9979  total_loss: 0.09313  loss_cls: 0.02496  loss_box_reg: 0.06068  loss_rpn_cls: 0.001156  loss_rpn_loc: 0.003695    time: 0.4819  last_time: 0.4118  data_time: 0.0548  last_data_time: 0.0408   lr: 0.0025  max_mem: 1554M
# [02/24 17:13:16 d2.utils.events]:  eta: 0:00:00  iter: 9999  total_loss: 0.08587  loss_cls: 0.02567  loss_box_reg: 0.05821  loss_rpn_cls: 0.0006761  loss_rpn_loc: 0.003585    time: 0.4818  last_time: 0.4361  data_time: 0.0447  last_data_time: 0.0421   lr: 0.0025  max_mem: 1554M
# [02/24 17:13:16 d2.engine.hooks]: Overall training speed: 9998 iterations in 1:20:16 (0.4818 s / it)
# [02/24 17:13:16 d2.engine.hooks]: Total training time: 1:21:43 (0:01:26 on hooks)
# [02/24 17:13:16 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(256, 256), max_size=1333, sample_style='choice')]
# [02/24 17:13:16 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/24 17:13:16 d2.data.common]: Serializing 319 elements to byte tensors and concatenating them all ...
# [02/24 17:13:16 d2.data.common]: Serialized dataset takes 0.10 MiB
# WARNING [02/24 17:13:16 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [02/24 17:13:16 d2.evaluation.evaluator]: Start inference on 319 batches
# [02/24 17:13:17 d2.evaluation.evaluator]: Inference done 11/319. Dataloading: 0.0008 s/iter. Inference: 0.0330 s/iter. Eval: 0.0002 s/iter. Total: 0.0340 s/iter. ETA=0:00:10
# [02/24 17:13:22 d2.evaluation.evaluator]: Inference done 138/319. Dataloading: 0.0013 s/iter. Inference: 0.0377 s/iter. Eval: 0.0003 s/iter. Total: 0.0394 s/iter. ETA=0:00:07
# [02/24 17:13:27 d2.evaluation.evaluator]: Inference done 206/319. Dataloading: 0.0024 s/iter. Inference: 0.0485 s/iter. Eval: 0.0004 s/iter. Total: 0.0513 s/iter. ETA=0:00:05
# [02/24 17:13:31 d2.evaluation.evaluator]: Total inference time: 0:00:14.271838 (0.045452 s / iter per device, on 1 devices)
# [02/24 17:13:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:13 (0.043056 s / iter per device, on 1 devices)
# [02/24 17:13:31 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/24 17:13:31 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v5/coco_instances_results.json
# [02/24 17:13:31 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [02/24 17:13:31 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [02/24 17:13:31 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [02/24 17:13:31 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [02/24 17:13:31 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.263
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.409
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.410
# [02/24 17:13:31 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 29.467 | 63.633 | 26.262 | 21.545 | 29.949 | 31.642 |
# [02/24 17:13:31 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | ulcer      | 12.371 | polyp      | 38.802 | cancer     | 37.228 |
# [02/24 17:13:31 d2.engine.defaults]: Evaluation results for colonoscopy_val in csv format:
# [02/24 17:13:31 d2.evaluation.testing]: copypaste: Task: bbox
# [02/24 17:13:31 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/24 17:13:31 d2.evaluation.testing]: copypaste: 29.4673,63.6334,26.2617,21.5452,29.9491,31.6417
