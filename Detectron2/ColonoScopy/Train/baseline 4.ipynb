# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
import os
import torch

# %%
# def csv_to_coco(csv_path, meta_csv, output_json):
#     df = pd.read_csv(csv_path)
#     meta_df = pd.read_csv(meta_csv)
#     filtered_df = df[df["image_id"].isin(meta_df["image_id"])]

#     class_map = {"ulcer": 0, "polyp": 1, "cancer": 2}
#     coco_json = {"images": [], "annotations": [], "categories": []}

#     for class_name, class_id in class_map.items():
#         coco_json["categories"].append({"id": class_id, "name": class_name})

#     image_id_map = {}
#     annotation_id = 1

#     for _, row in filtered_df.iterrows():
#         image_id = row["image_id"]
#         image_name = row["image_id"]

#         if image_id not in image_id_map:
#             image_id_map[image_id] = image_name
#             coco_json["images"].append({
#                 "id": image_id,
#                 "width": row["width"],
#                 "height": row["height"],
#                 "file_name": image_name
#             })

#         x_min, y_min, x_max, y_max = row["x_min"], row["y_min"], row["x_max"], row["y_max"]
#         bbox = [x_min, y_min, x_max - x_min, y_max - y_min]

#         coco_json["annotations"].append({
#             "id": annotation_id,
#             "image_id": image_id,
#             "category_id": class_map[row["lesion"]],
#             "bbox": bbox,
#             "area": bbox[2] * bbox[3],
#             "iscrowd": 0
#         })
#         annotation_id += 1

#     with open(output_json, "w") as f:
#         json.dump(coco_json, f, indent=4)

#     print(f"COCO JSON saved: {output_json}")

# base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
# csv_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/resize_colonoscopy.csv"

# meta_paths = {
#     "train": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/train_meta.csv",
#     "val": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/val_meta.csv",
#     "test": "/content/drive/MyDrive/Endoscope Detection/colonoscopy/test_meta.csv",
# }

# json_paths = {
#     "train": os.path.join(base_path, "Dataset", "train_coco.json"),
#     "val": os.path.join(base_path, "Dataset", "val_coco.json"),
#     "test": os.path.join(base_path, "Dataset", "test_coco.json"),
# }

# for split in ["train", "val", "test"]:
#     csv_to_coco(csv_path, meta_paths[split], json_paths[split])

# %%
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.1 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
import json

def register_coco_dataset(name, json_file, image_root):
    DatasetCatalog.register(
        name,
        lambda: load_coco_json(json_file, image_root)
    )
    MetadataCatalog.get(name).set(thing_classes=["ulcer", "polyp","cancer"])

def load_coco_json(json_file, image_root):
    with open(json_file, "r") as f:
        coco_data = json.load(f)

    dataset_dicts = []
    for image_info in coco_data['images']:
        record = {}
        record['file_name'] = os.path.join(image_root, image_info['file_name'])
        record['image_id'] = image_info['id']
        record['height'] = image_info['height']
        record['width'] = image_info['width']

        annotations = []
        for ann in coco_data['annotations']:
            if ann['image_id'] == image_info['id']:
                annotations.append({
                    "bbox": ann['bbox'],
                    "bbox_mode": BoxMode.XYWH_ABS,
                    "category_id": ann['category_id']
                })

        record['annotations'] = annotations
        dataset_dicts.append(record)
    return dataset_dicts


image_folders = {
    "train": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/train",
    "val": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/val",
    "test": r"/content/drive/MyDrive/Endoscope Detection/colonoscopy/Dataset/images/test"
}

base_path = r"/content/drive/MyDrive/Endoscope Detection/colonoscopy"
json_paths = {
    "train": os.path.join(base_path, "Dataset", "train_coco.json"),
    "val": os.path.join(base_path, "Dataset", "val_coco.json"),
    "test": os.path.join(base_path, "Dataset", "test_coco.json"),
}

for split in ["train", "val", "test"]:
    register_coco_dataset(f"colonoscopy_{split}", json_paths[split], image_folders[split])

# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.5)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (3.12.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.evaluation import COCOEvaluator
from detectron2.data import build_detection_train_loader, build_detection_test_loader

# %%
# !wget -O /content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Out:
# --2025-03-07 05:11:38--  https://raw.githubusercontent.com/facebookresearch/detectron2/main/configs/Base-RCNN-FPN.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318 (1.3K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’
#
# /content/drive/MyDr 100%[===================>]   1.29K  --.-KB/s    in 0s
#
# 2025-03-07 05:11:38 (49.5 MB/s) - ‘/content/drive/MyDrive/Endoscope/Detection/colonoscopy/Base-RCNN-FPN.yaml’ saved [1318/1318]

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog, DatasetMapper
from detectron2.data.transforms import (RandomFlip, RandomRotation, RandomContrast, RandomBrightness, RandomLighting)
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_train_loader, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator
from detectron2.config import get_cfg
import os
import cv2
import random
import numpy as np
from detectron2.data.transforms import Augmentation, Transform
from detectron2.data import detection_utils as utils
from detectron2.structures import BoxMode

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Error loading image: {image_path}")
    return image

class Mosaic:
    def __init__(self, prob=0.5, image_size=(128, 128)):
        self.prob = prob
        self.image_size = image_size

    def __call__(self, dataset_dicts):
        if random.random() >= self.prob:
            return dataset_dicts[0]

        h, w = self.image_size
        mosaic_image = np.zeros((h, w, 3), dtype=np.uint8)
        mosaic_boxes = []
        mosaic_classes = []

        selected_samples = random.sample(dataset_dicts, 4)
        positions = [
            (0, 0), (w // 2, 0),
            (0, h // 2), (w // 2, h // 2)
        ]

        for i, sample in enumerate(selected_samples):
            image_path = sample["file_name"]
            image = load_image(image_path)
            orig_h, orig_w = image.shape[:2]


            x1 = random.randint(0, orig_w // 2)
            y1 = random.randint(0, orig_h // 2)
            x2 = random.randint(orig_w // 2, orig_w)
            y2 = random.randint(orig_h // 2, orig_h)
            cropped_image = image[y1:y2, x1:x2]

            pos_x, pos_y = positions[i]

            resized_crop = cv2.resize(cropped_image, (w // 2, h // 2))
            mosaic_image[pos_y:pos_y + h // 2, pos_x:pos_x + w // 2] = resized_crop

            for ann in sample["annotations"]:
                bbox = ann["bbox"]
                bbox_mode = ann["bbox_mode"]

                if bbox_mode != BoxMode.XYXY_ABS:
                    bbox = BoxMode.convert(bbox, bbox_mode, BoxMode.XYXY_ABS)

                x_min, y_min, x_max, y_max = bbox


                if x_min < x2 and x_max > x1 and y_min < y2 and y_max > y1:
                    clipped_bbox = [
                        max(x_min, x1) - x1,  # X_min 상대 좌표
                        max(y_min, y1) - y1,  # Y_min 상대 좌표
                        min(x_max, x2) - x1,  # X_max 상대 좌표
                        min(y_max, y2) - y1   # Y_max 상대 좌표
                    ]

                    scale_x = (w // 2) / (x2 - x1)
                    scale_y = (h // 2) / (y2 - y1)
                    scaled_bbox = [
                        clipped_bbox[0] * scale_x + pos_x,
                        clipped_bbox[1] * scale_y + pos_y,
                        clipped_bbox[2] * scale_x + pos_x,
                        clipped_bbox[3] * scale_y + pos_y
                    ]

                    mosaic_boxes.append(scaled_bbox)
                    mosaic_classes.append(ann["category_id"])

        dataset_dicts[0]["image"] = mosaic_image
        dataset_dicts[0]["annotations"] = [
            {"bbox": bbox, "bbox_mode": BoxMode.XYXY_ABS, "category_id": cls}
            for bbox, cls in zip(mosaic_boxes, mosaic_classes)
        ]

        return dataset_dicts[0]

# %%
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer

def visualize_mosaic(dataset_name, num_samples=2):
    dataset_dicts = DatasetCatalog.get(dataset_name)
    metadata = MetadataCatalog.get(dataset_name)

    mosaic_images = []

    for _ in range(num_samples):
        mosaic_transform = Mosaic(prob=1.0)
        mosaic_sample = mosaic_transform(random.sample(dataset_dicts, 4))

        image = mosaic_sample["image"]
        annotations = mosaic_sample["annotations"]

        visualizer = Visualizer(image[:, :, ::-1], metadata=metadata, scale=1.0)
        for ann in annotations:
            bbox = ann["bbox"]
            category_id = ann["category_id"]
            visualizer.draw_box(bbox, edge_color="red", line_style="-")
            visualizer.draw_text(str(category_id), (bbox[0], bbox[1]), color="white")

        output = visualizer.get_output()
        mosaic_images.append(output.get_image())

    fig, axes = plt.subplots(1, num_samples, figsize=(num_samples * 8, 8))

    for i in range(num_samples):
        axes[i].imshow(mosaic_images[i])
        axes[i].axis("off")
        axes[i].set_title(f"Mosaic Sample {i+1}")

    plt.show()

visualize_mosaic("colonoscopy_train", num_samples=2)

# %%
def adjust_augmentation(cfg):
    augmentations = [
        RandomFlip(prob=0.4, horizontal=True, vertical=False),
        RandomContrast(intensity_min=0.5, intensity_max=1.5),
        RandomBrightness(intensity_min=0.5, intensity_max=1.5),
        RandomLighting(scale=0.1),
        RandomRotation(angle=[-10, 10], expand=True),
        # Mosaic(prob=0.2)
    ]
    mapper = DatasetMapper(cfg, is_train=True, augmentations=augmentations)
    return build_detection_train_loader(cfg, mapper=mapper)

# %%
class MyTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return adjust_augmentation(cfg)

    @classmethod
    def build_test_loader(cls, cfg, dataset_name):
        return build_detection_test_loader(cfg, dataset_name)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = cfg.OUTPUT_DIR
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

# %%
# !pip install PyYAML
import yaml
# Out:
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (6.0.2)

# %%
with open("/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/config.yaml") as f:
    film = yaml.load(f, Loader=yaml.FullLoader)
    display(film)
# Out:
# {'_BASE_': '/content/drive/MyDrive/Endoscope Detection/colonoscopy/faster_rcnn_R_50_FPN_1x.yaml',
#  'MODEL': {'META_ARCHITECTURE': 'GeneralizedRCNN',
#   'WEIGHTS': 'detectron2://ImageNetPretrained/MSRA/R-50.pkl',
#   'MASK_ON': False,
#   'RESNETS': {'DEPTH': 50}},
#  'DATASETS': {'TRAIN': '("colonoscopy_train",)',
#   'TEST': '("colonoscopy_val",)'},
#  'DATALOADER': {'NUM_WORKERS': 2},
#  'SOLVER': {'IMS_PER_BATCH': 2,
#   'BASE_LR': 0.0025,
#   'MAX_ITER': 10000,
#   'LR_SCHEDULER_NAME': 'WarmupCosineLR',
#   'WARMUP_FACTOR': 0.001,
#   'WARMUP_ITERS': 1000},
#  'INPUT': {'MIN_SIZE_TRAIN': '(256, 512, 1024)',
#   'MAX_SIZE_TRAIN': 1333,
#   'MIN_SIZE_TEST': 256,
#   'MAX_SIZE_TEST': 1333},
#  'TEST': {'EVAL_PERIOD': 5000},
#  'OUTPUT_DIR': '/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment'}

# %%
"""
_BASE_: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/faster_rcnn_R_50_FPN_3x.yaml"
MODEL:
  META_ARCHITECTURE: "GeneralizedRCNN"
  WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-50.pkl"
  MASK_ON: False
  RESNETS:
    DEPTH: 50
DATASETS:
  TRAIN: ("colonoscopy_train",)
  TEST: ("colonoscopy_val",)
DATALOADER:
  NUM_WORKERS: 2
SOLVER:
  IMS_PER_BATCH: 2
  BASE_LR: 0.0025
  MAX_ITER: 10000
  LR_SCHEDULER_NAME: "WarmupCosineLR"
  WARMUP_FACTOR: 0.001
  WARMUP_ITERS: 1000
INPUT:
  MIN_SIZE_TRAIN: (256, 512, 1024)
  MAX_SIZE_TRAIN: 1333
  MIN_SIZE_TEST: 256
  MAX_SIZE_TEST: 1333
TEST:
  EVAL_PERIOD: 5000
OUTPUT_DIR: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment"

"""
# Out:
# '\n_BASE_: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/faster_rcnn_R_50_FPN_1x.yaml"\nMODEL:\n  META_ARCHITECTURE: "GeneralizedRCNN"\n  WEIGHTS: "detectron2://ImageNetPretrained/MSRA/R-50.pkl"\n  MASK_ON: False\n  RESNETS:\n    DEPTH: 50\nDATASETS:\n  TRAIN: ("colonoscopy_train",)\n  TEST: ("colonoscopy_val",)\nDATALOADER:\n  NUM_WORKERS: 2\nSOLVER:\n  IMS_PER_BATCH: 2\n  BASE_LR: 0.0025\n  MAX_ITER: 10000\n  LR_SCHEDULER_NAME: "WarmupCosineLR" \n  WARMUP_FACTOR: 0.001\n  WARMUP_ITERS: 1000\nINPUT:\n  MIN_SIZE_TRAIN: (256, 512, 1024)\n  MAX_SIZE_TRAIN: 1333\n  MIN_SIZE_TEST: 256\n  MAX_SIZE_TEST: 1333\nTEST:\n  EVAL_PERIOD: 5000\nOUTPUT_DIR: "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment"\n\n'

# %%
cfg = get_cfg()
cfg.merge_from_file("/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/config.yaml")

cfg.OUTPUT_DIR = "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v4"
cfg.DATASETS.TRAIN = ("colonoscopy_train",)
cfg.DATASETS.TEST = ("colonoscopy_val",)

trainer = MyTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [03/10 02:51:47 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=81, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=320, bias=True)
#     )
#   )
# )
# [03/10 02:51:47 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [RandomFlip(prob=0.4), RandomContrast(intensity_min=0.5, intensity_max=1.5), RandomBrightness(intensity_min=0.5, intensity_max=1.5), RandomLighting(scale=0.1), RandomRotation(angle=[-10, 10])]
# [03/10 02:51:47 d2.data.build]: Removed 0 images with no usable annotations. 1277 images left.
# [03/10 02:51:47 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   ulcer    | 610          |   polyp    | 350          |   cancer   | 640          |
# |            |              |            |              |            |              |
# |   total    | 1600         |            |              |            |              |
# [03/10 02:51:47 d2.data.build]: Using training sampler TrainingSampler
# [03/10 02:51:47 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/10 02:51:47 d2.data.common]: Serializing 1277 elements to byte tensors and concatenating them all ...
# [03/10 02:51:47 d2.data.common]: Serialized dataset takes 0.40 MiB
# [03/10 02:51:47 d2.data.build]: Making batched data loader with batch_size=2
# [03/10 02:51:47 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://ImageNetPretrained/MSRA/R-50.pkl ...
# R-50.pkl: 102MB [00:00, 195MB/s]
# [03/10 02:51:48 d2.checkpoint.c2_model_loading]: Renaming Caffe2 weights ......
# [03/10 02:51:48 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up - Total num: 54
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   fc1000.{bias, weight}
#   stem.conv1.bias
# [03/10 02:51:48 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [03/10 02:52:00 d2.utils.events]:  eta: 1:00:47  iter: 19  total_loss: 4.378  loss_cls: 3.662  loss_box_reg: 0.008196  loss_rpn_cls: 0.6868  loss_rpn_loc: 0.00866    time: 0.4172  last_time: 0.4042  data_time: 0.3107  last_data_time: 0.2631   lr: 4.879e-05  max_mem: 744M
# [03/10 02:52:11 d2.utils.events]:  eta: 1:01:37  iter: 39  total_loss: 0.7806  loss_cls: 0.1471  loss_box_reg: 0.03383  loss_rpn_cls: 0.591  loss_rpn_loc: 0.008003    time: 0.3874  last_time: 0.4107  data_time: 0.2517  last_data_time: 0.3032   lr: 9.7517e-05  max_mem: 744M
# [03/10 02:52:18 d2.utils.events]:  eta: 1:00:10  iter: 59  total_loss: 0.581  loss_cls: 0.1443  loss_box_reg: 0.0498  loss_rpn_cls: 0.3769  loss_rpn_loc: 0.01625    time: 0.3828  last_time: 0.3013  data_time: 0.2635  last_data_time: 0.1992   lr: 0.00014624  max_mem: 744M
# [03/10 02:52:26 d2.utils.events]:  eta: 0:59:33  iter: 79  total_loss: 0.4555  loss_cls: 0.1668  loss_box_reg: 0.03433  loss_rpn_cls: 0.213  loss_rpn_loc: 0.01107    time: 0.3828  last_time: 0.4559  data_time: 0.2727  last_data_time: 0.3195   lr: 0.00019497  max_mem: 744M
# [03/10 02:52:34 d2.utils.events]:  eta: 0:59:54  iter: 99  total_loss: 0.3468  loss_cls: 0.1557  loss_box_reg: 0.04205  loss_rpn_cls: 0.1416  loss_rpn_loc: 0.0137    time: 0.3868  last_time: 0.4516  data_time: 0.2958  last_data_time: 0.3425   lr: 0.0002437  max_mem: 744M
# [03/10 02:52:42 d2.utils.events]:  eta: 0:59:58  iter: 119  total_loss: 0.3942  loss_cls: 0.1751  loss_box_reg: 0.08111  loss_rpn_cls: 0.1063  loss_rpn_loc: 0.009715    time: 0.3856  last_time: 0.3373  data_time: 0.2700  last_data_time: 0.2326   lr: 0.00029242  max_mem: 744M
# [03/10 02:52:49 d2.utils.events]:  eta: 1:00:00  iter: 139  total_loss: 0.3993  loss_cls: 0.1767  loss_box_reg: 0.08763  loss_rpn_cls: 0.09313  loss_rpn_loc: 0.01773    time: 0.3860  last_time: 0.4020  data_time: 0.2825  last_data_time: 0.2888   lr: 0.00034115  max_mem: 744M
# [03/10 02:52:58 d2.utils.events]:  eta: 1:00:25  iter: 159  total_loss: 0.3186  loss_cls: 0.1441  loss_box_reg: 0.085  loss_rpn_cls: 0.07452  loss_rpn_loc: 0.0103    time: 0.3907  last_time: 0.7992  data_time: 0.3124  last_data_time: 0.6897   lr: 0.00038987  max_mem: 744M
# [03/10 02:53:07 d2.utils.events]:  eta: 0:59:43  iter: 179  total_loss: 0.248  loss_cls: 0.09688  loss_box_reg: 0.05518  loss_rpn_cls: 0.06689  loss_rpn_loc: 0.01051    time: 0.3952  last_time: 0.3116  data_time: 0.3197  last_data_time: 0.2072   lr: 0.0004386  max_mem: 744M
# [03/10 02:53:15 d2.utils.events]:  eta: 1:00:37  iter: 199  total_loss: 0.3141  loss_cls: 0.1351  loss_box_reg: 0.1055  loss_rpn_cls: 0.06129  loss_rpn_loc: 0.01173    time: 0.3974  last_time: 0.3945  data_time: 0.3050  last_data_time: 0.2635   lr: 0.00048733  max_mem: 744M
# [03/10 02:53:24 d2.utils.events]:  eta: 0:59:38  iter: 219  total_loss: 0.2654  loss_cls: 0.1207  loss_box_reg: 0.0814  loss_rpn_cls: 0.04354  loss_rpn_loc: 0.00908    time: 0.4036  last_time: 2.4279  data_time: 0.3530  last_data_time: 2.2369   lr: 0.00053605  max_mem: 744M
# [03/10 02:53:31 d2.utils.events]:  eta: 0:59:41  iter: 239  total_loss: 0.3208  loss_cls: 0.1427  loss_box_reg: 0.1067  loss_rpn_cls: 0.06454  loss_rpn_loc: 0.01186    time: 0.3992  last_time: 0.3892  data_time: 0.2395  last_data_time: 0.2875   lr: 0.00058478  max_mem: 744M
# [03/10 02:53:41 d2.utils.events]:  eta: 0:59:34  iter: 259  total_loss: 0.2672  loss_cls: 0.1157  loss_box_reg: 0.09639  loss_rpn_cls: 0.0506  loss_rpn_loc: 0.008009    time: 0.4054  last_time: 0.3472  data_time: 0.3647  last_data_time: 0.2346   lr: 0.00063351  max_mem: 744M
# [03/10 02:53:50 d2.utils.events]:  eta: 0:59:26  iter: 279  total_loss: 0.2691  loss_cls: 0.119  loss_box_reg: 0.09688  loss_rpn_cls: 0.04715  loss_rpn_loc: 0.009324    time: 0.4090  last_time: 0.4234  data_time: 0.3411  last_data_time: 0.2988   lr: 0.00068223  max_mem: 744M
# [03/10 02:53:58 d2.utils.events]:  eta: 0:59:02  iter: 299  total_loss: 0.3093  loss_cls: 0.134  loss_box_reg: 0.1088  loss_rpn_cls: 0.04459  loss_rpn_loc: 0.009376    time: 0.4072  last_time: 0.6151  data_time: 0.2647  last_data_time: 0.5038   lr: 0.00073096  max_mem: 744M
# [03/10 02:54:05 d2.utils.events]:  eta: 0:58:52  iter: 319  total_loss: 0.2972  loss_cls: 0.1289  loss_box_reg: 0.1006  loss_rpn_cls: 0.05458  loss_rpn_loc: 0.01201    time: 0.4057  last_time: 0.3057  data_time: 0.2709  last_data_time: 0.1999   lr: 0.00077969  max_mem: 744M
# [03/10 02:54:12 d2.utils.events]:  eta: 0:58:34  iter: 339  total_loss: 0.3111  loss_cls: 0.1415  loss_box_reg: 0.1161  loss_rpn_cls: 0.03914  loss_rpn_loc: 0.009508    time: 0.4026  last_time: 0.2578  data_time: 0.2460  last_data_time: 0.1475   lr: 0.00082841  max_mem: 744M
# [03/10 02:54:20 d2.utils.events]:  eta: 0:58:27  iter: 359  total_loss: 0.2517  loss_cls: 0.1123  loss_box_reg: 0.0958  loss_rpn_cls: 0.04238  loss_rpn_loc: 0.009194    time: 0.4006  last_time: 0.4536  data_time: 0.2548  last_data_time: 0.3430   lr: 0.00087714  max_mem: 744M
# [03/10 02:54:27 d2.utils.events]:  eta: 0:58:00  iter: 379  total_loss: 0.244  loss_cls: 0.1021  loss_box_reg: 0.09023  loss_rpn_cls: 0.03656  loss_rpn_loc: 0.008087    time: 0.3979  last_time: 0.3422  data_time: 0.2389  last_data_time: 0.2128   lr: 0.00092587  max_mem: 744M
# [03/10 02:54:33 d2.utils.events]:  eta: 0:57:30  iter: 399  total_loss: 0.301  loss_cls: 0.1404  loss_box_reg: 0.1195  loss_rpn_cls: 0.0457  loss_rpn_loc: 0.01092    time: 0.3947  last_time: 0.2804  data_time: 0.2225  last_data_time: 0.1750   lr: 0.00097459  max_mem: 744M
# [03/10 02:54:45 d2.utils.events]:  eta: 0:57:19  iter: 419  total_loss: 0.2848  loss_cls: 0.1178  loss_box_reg: 0.1116  loss_rpn_cls: 0.03942  loss_rpn_loc: 0.00925    time: 0.4037  last_time: 0.3769  data_time: 0.4654  last_data_time: 0.2627   lr: 0.0010233  max_mem: 744M
# [03/10 02:54:52 d2.utils.events]:  eta: 0:57:05  iter: 439  total_loss: 0.3332  loss_cls: 0.1448  loss_box_reg: 0.1175  loss_rpn_cls: 0.03591  loss_rpn_loc: 0.007652    time: 0.4016  last_time: 0.3156  data_time: 0.2447  last_data_time: 0.1926   lr: 0.001072  max_mem: 744M
# [03/10 02:55:02 d2.utils.events]:  eta: 0:56:39  iter: 459  total_loss: 0.2848  loss_cls: 0.1244  loss_box_reg: 0.106  loss_rpn_cls: 0.05209  loss_rpn_loc: 0.01164    time: 0.4056  last_time: 0.4661  data_time: 0.3782  last_data_time: 0.3558   lr: 0.0011208  max_mem: 744M
# [03/10 02:55:09 d2.utils.events]:  eta: 0:56:29  iter: 479  total_loss: 0.2828  loss_cls: 0.1242  loss_box_reg: 0.1181  loss_rpn_cls: 0.03659  loss_rpn_loc: 0.008681    time: 0.4035  last_time: 0.2930  data_time: 0.2423  last_data_time: 0.1850   lr: 0.0011695  max_mem: 744M
# [03/10 02:55:18 d2.utils.events]:  eta: 0:56:22  iter: 499  total_loss: 0.2608  loss_cls: 0.1078  loss_box_reg: 0.1083  loss_rpn_cls: 0.03397  loss_rpn_loc: 0.01005    time: 0.4041  last_time: 0.3865  data_time: 0.3080  last_data_time: 0.2837   lr: 0.0012182  max_mem: 744M
# [03/10 02:55:25 d2.utils.events]:  eta: 0:56:12  iter: 519  total_loss: 0.2673  loss_cls: 0.1131  loss_box_reg: 0.1101  loss_rpn_cls: 0.03256  loss_rpn_loc: 0.008334    time: 0.4024  last_time: 0.4204  data_time: 0.2509  last_data_time: 0.3101   lr: 0.001267  max_mem: 744M
# [03/10 02:55:32 d2.utils.events]:  eta: 0:56:00  iter: 539  total_loss: 0.2523  loss_cls: 0.1042  loss_box_reg: 0.1059  loss_rpn_cls: 0.02421  loss_rpn_loc: 0.007203    time: 0.4011  last_time: 0.2965  data_time: 0.2527  last_data_time: 0.1888   lr: 0.0013157  max_mem: 744M
# [03/10 02:55:39 d2.utils.events]:  eta: 0:56:04  iter: 559  total_loss: 0.2754  loss_cls: 0.1123  loss_box_reg: 0.1203  loss_rpn_cls: 0.0294  loss_rpn_loc: 0.008463    time: 0.3998  last_time: 0.3954  data_time: 0.2562  last_data_time: 0.2622   lr: 0.0013644  max_mem: 744M
# [03/10 02:55:47 d2.utils.events]:  eta: 0:56:00  iter: 579  total_loss: 0.2866  loss_cls: 0.1303  loss_box_reg: 0.1037  loss_rpn_cls: 0.03758  loss_rpn_loc: 0.008855    time: 0.3989  last_time: 0.3620  data_time: 0.2571  last_data_time: 0.2517   lr: 0.0014131  max_mem: 744M
# [03/10 02:55:54 d2.utils.events]:  eta: 0:55:50  iter: 599  total_loss: 0.2925  loss_cls: 0.1304  loss_box_reg: 0.1199  loss_rpn_cls: 0.02789  loss_rpn_loc: 0.007041    time: 0.3978  last_time: 0.3082  data_time: 0.2555  last_data_time: 0.1991   lr: 0.0014619  max_mem: 744M
# [03/10 02:56:01 d2.utils.events]:  eta: 0:55:45  iter: 619  total_loss: 0.2698  loss_cls: 0.1161  loss_box_reg: 0.111  loss_rpn_cls: 0.03467  loss_rpn_loc: 0.009569    time: 0.3966  last_time: 0.4648  data_time: 0.2513  last_data_time: 0.3603   lr: 0.0015106  max_mem: 744M
# [03/10 02:56:08 d2.utils.events]:  eta: 0:55:38  iter: 639  total_loss: 0.2562  loss_cls: 0.1105  loss_box_reg: 0.1123  loss_rpn_cls: 0.02668  loss_rpn_loc: 0.01182    time: 0.3950  last_time: 0.1277  data_time: 0.2303  last_data_time: 0.0037   lr: 0.0015593  max_mem: 744M
# [03/10 02:56:11 d2.utils.events]:  eta: 0:55:14  iter: 659  total_loss: 0.2579  loss_cls: 0.106  loss_box_reg: 0.1006  loss_rpn_cls: 0.0299  loss_rpn_loc: 0.009055    time: 0.3868  last_time: 0.1240  data_time: 0.0039  last_data_time: 0.0047   lr: 0.001608  max_mem: 744M
# [03/10 02:56:13 d2.utils.events]:  eta: 0:54:42  iter: 679  total_loss: 0.2852  loss_cls: 0.1299  loss_box_reg: 0.104  loss_rpn_cls: 0.03015  loss_rpn_loc: 0.009823    time: 0.3790  last_time: 0.1246  data_time: 0.0042  last_data_time: 0.0042   lr: 0.0016568  max_mem: 744M
# [03/10 02:56:16 d2.utils.events]:  eta: 0:53:57  iter: 699  total_loss: 0.2507  loss_cls: 0.1132  loss_box_reg: 0.1147  loss_rpn_cls: 0.02532  loss_rpn_loc: 0.008256    time: 0.3718  last_time: 0.1296  data_time: 0.0044  last_data_time: 0.0130   lr: 0.0017055  max_mem: 744M
# [03/10 02:56:19 d2.utils.events]:  eta: 0:53:19  iter: 719  total_loss: 0.2837  loss_cls: 0.1253  loss_box_reg: 0.1063  loss_rpn_cls: 0.04025  loss_rpn_loc: 0.009572    time: 0.3654  last_time: 0.1594  data_time: 0.0081  last_data_time: 0.0156   lr: 0.0017542  max_mem: 744M
# [03/10 02:56:21 d2.utils.events]:  eta: 0:52:50  iter: 739  total_loss: 0.2517  loss_cls: 0.116  loss_box_reg: 0.1044  loss_rpn_cls: 0.02523  loss_rpn_loc: 0.00794    time: 0.3590  last_time: 0.1308  data_time: 0.0045  last_data_time: 0.0041   lr: 0.0018029  max_mem: 744M
# [03/10 02:56:24 d2.utils.events]:  eta: 0:52:13  iter: 759  total_loss: 0.2294  loss_cls: 0.09805  loss_box_reg: 0.1052  loss_rpn_cls: 0.03202  loss_rpn_loc: 0.009429    time: 0.3529  last_time: 0.1205  data_time: 0.0039  last_data_time: 0.0041   lr: 0.0018517  max_mem: 744M
# [03/10 02:56:26 d2.utils.events]:  eta: 0:51:49  iter: 779  total_loss: 0.2337  loss_cls: 0.1002  loss_box_reg: 0.1038  loss_rpn_cls: 0.0313  loss_rpn_loc: 0.006991    time: 0.3471  last_time: 0.1231  data_time: 0.0039  last_data_time: 0.0039   lr: 0.0019004  max_mem: 744M
# [03/10 02:56:29 d2.utils.events]:  eta: 0:51:25  iter: 799  total_loss: 0.2337  loss_cls: 0.09928  loss_box_reg: 0.1019  loss_rpn_cls: 0.02416  loss_rpn_loc: 0.007168    time: 0.3417  last_time: 0.1306  data_time: 0.0042  last_data_time: 0.0038   lr: 0.0019491  max_mem: 744M
# [03/10 02:56:32 d2.utils.events]:  eta: 0:50:28  iter: 819  total_loss: 0.276  loss_cls: 0.1234  loss_box_reg: 0.1138  loss_rpn_cls: 0.03193  loss_rpn_loc: 0.009715    time: 0.3369  last_time: 0.1520  data_time: 0.0094  last_data_time: 0.0063   lr: 0.0019978  max_mem: 744M
# [03/10 02:56:35 d2.utils.events]:  eta: 0:49:45  iter: 839  total_loss: 0.2655  loss_cls: 0.1117  loss_box_reg: 0.1131  loss_rpn_cls: 0.02701  loss_rpn_loc: 0.008655    time: 0.3320  last_time: 0.1258  data_time: 0.0077  last_data_time: 0.0042   lr: 0.0020466  max_mem: 744M
# [03/10 02:56:37 d2.utils.events]:  eta: 0:49:23  iter: 859  total_loss: 0.2438  loss_cls: 0.1043  loss_box_reg: 0.1102  loss_rpn_cls: 0.0205  loss_rpn_loc: 0.006459    time: 0.3272  last_time: 0.1379  data_time: 0.0040  last_data_time: 0.0053   lr: 0.0020953  max_mem: 744M
# [03/10 02:56:40 d2.utils.events]:  eta: 0:49:02  iter: 879  total_loss: 0.2981  loss_cls: 0.1055  loss_box_reg: 0.1195  loss_rpn_cls: 0.02666  loss_rpn_loc: 0.00951    time: 0.3226  last_time: 0.1246  data_time: 0.0039  last_data_time: 0.0041   lr: 0.002144  max_mem: 744M
# [03/10 02:56:42 d2.utils.events]:  eta: 0:48:34  iter: 899  total_loss: 0.2775  loss_cls: 0.1168  loss_box_reg: 0.1109  loss_rpn_cls: 0.03345  loss_rpn_loc: 0.01098    time: 0.3182  last_time: 0.1244  data_time: 0.0042  last_data_time: 0.0042   lr: 0.0021928  max_mem: 744M
# [03/10 02:56:45 d2.utils.events]:  eta: 0:48:02  iter: 919  total_loss: 0.3052  loss_cls: 0.1167  loss_box_reg: 0.1262  loss_rpn_cls: 0.03239  loss_rpn_loc: 0.009474    time: 0.3144  last_time: 0.1541  data_time: 0.0072  last_data_time: 0.0045   lr: 0.0022415  max_mem: 744M
# [03/10 02:56:48 d2.utils.events]:  eta: 0:47:32  iter: 939  total_loss: 0.2113  loss_cls: 0.08348  loss_box_reg: 0.09963  loss_rpn_cls: 0.02165  loss_rpn_loc: 0.007206    time: 0.3104  last_time: 0.1292  data_time: 0.0040  last_data_time: 0.0035   lr: 0.0022902  max_mem: 744M
# [03/10 02:56:50 d2.utils.events]:  eta: 0:47:10  iter: 959  total_loss: 0.2377  loss_cls: 0.09152  loss_box_reg: 0.1041  loss_rpn_cls: 0.02313  loss_rpn_loc: 0.009219    time: 0.3066  last_time: 0.1285  data_time: 0.0041  last_data_time: 0.0037   lr: 0.0023389  max_mem: 744M
# [03/10 02:56:53 d2.utils.events]:  eta: 0:46:40  iter: 979  total_loss: 0.2585  loss_cls: 0.1086  loss_box_reg: 0.1188  loss_rpn_cls: 0.02182  loss_rpn_loc: 0.009058    time: 0.3030  last_time: 0.1374  data_time: 0.0044  last_data_time: 0.0172   lr: 0.0023877  max_mem: 744M
# [03/10 02:56:55 d2.utils.events]:  eta: 0:46:11  iter: 999  total_loss: 0.2635  loss_cls: 0.1247  loss_box_reg: 0.1124  loss_rpn_cls: 0.02357  loss_rpn_loc: 0.006839    time: 0.2994  last_time: 0.1260  data_time: 0.0042  last_data_time: 0.0037   lr: 0.0024364  max_mem: 744M
# [03/10 02:56:58 d2.utils.events]:  eta: 0:45:33  iter: 1019  total_loss: 0.2659  loss_cls: 0.1151  loss_box_reg: 0.1116  loss_rpn_cls: 0.02088  loss_rpn_loc: 0.006957    time: 0.2964  last_time: 0.1419  data_time: 0.0106  last_data_time: 0.0054   lr: 0.0024365  max_mem: 744M
# [03/10 02:57:01 d2.utils.events]:  eta: 0:44:47  iter: 1039  total_loss: 0.2285  loss_cls: 0.1033  loss_box_reg: 0.09969  loss_rpn_cls: 0.01936  loss_rpn_loc: 0.008794    time: 0.2932  last_time: 0.1279  data_time: 0.0042  last_data_time: 0.0036   lr: 0.002434  max_mem: 744M
# [03/10 02:57:03 d2.utils.events]:  eta: 0:43:42  iter: 1059  total_loss: 0.2486  loss_cls: 0.1008  loss_box_reg: 0.1032  loss_rpn_cls: 0.02683  loss_rpn_loc: 0.0119    time: 0.2900  last_time: 0.1218  data_time: 0.0041  last_data_time: 0.0035   lr: 0.0024315  max_mem: 744M
# [03/10 02:57:06 d2.utils.events]:  eta: 0:42:35  iter: 1079  total_loss: 0.257  loss_cls: 0.09753  loss_box_reg: 0.1065  loss_rpn_cls: 0.02161  loss_rpn_loc: 0.00655    time: 0.2870  last_time: 0.1252  data_time: 0.0039  last_data_time: 0.0040   lr: 0.0024289  max_mem: 744M
# [03/10 02:57:08 d2.utils.events]:  eta: 0:41:06  iter: 1099  total_loss: 0.236  loss_cls: 0.09614  loss_box_reg: 0.1048  loss_rpn_cls: 0.02444  loss_rpn_loc: 0.008112    time: 0.2840  last_time: 0.1261  data_time: 0.0040  last_data_time: 0.0045   lr: 0.0024262  max_mem: 744M
# [03/10 02:57:11 d2.utils.events]:  eta: 0:38:47  iter: 1119  total_loss: 0.2086  loss_cls: 0.08803  loss_box_reg: 0.1043  loss_rpn_cls: 0.01396  loss_rpn_loc: 0.006673    time: 0.2816  last_time: 0.1609  data_time: 0.0106  last_data_time: 0.0266   lr: 0.0024236  max_mem: 744M
# [03/10 02:57:14 d2.utils.events]:  eta: 0:24:05  iter: 1139  total_loss: 0.2368  loss_cls: 0.09843  loss_box_reg: 0.1191  loss_rpn_cls: 0.01683  loss_rpn_loc: 0.007101    time: 0.2789  last_time: 0.1348  data_time: 0.0040  last_data_time: 0.0045   lr: 0.0024208  max_mem: 744M
# [03/10 02:57:16 d2.utils.events]:  eta: 0:22:36  iter: 1159  total_loss: 0.2402  loss_cls: 0.0978  loss_box_reg: 0.1156  loss_rpn_cls: 0.02209  loss_rpn_loc: 0.006176    time: 0.2763  last_time: 0.1221  data_time: 0.0039  last_data_time: 0.0032   lr: 0.0024181  max_mem: 744M
# [03/10 02:57:19 d2.utils.events]:  eta: 0:21:47  iter: 1179  total_loss: 0.1947  loss_cls: 0.0826  loss_box_reg: 0.09656  loss_rpn_cls: 0.01593  loss_rpn_loc: 0.004903    time: 0.2737  last_time: 0.1247  data_time: 0.0044  last_data_time: 0.0044   lr: 0.0024152  max_mem: 744M
# [03/10 02:57:21 d2.utils.events]:  eta: 0:21:15  iter: 1199  total_loss: 0.2445  loss_cls: 0.1105  loss_box_reg: 0.1136  loss_rpn_cls: 0.02085  loss_rpn_loc: 0.007179    time: 0.2712  last_time: 0.1202  data_time: 0.0038  last_data_time: 0.0038   lr: 0.0024124  max_mem: 744M
# [03/10 02:57:24 d2.utils.events]:  eta: 0:21:07  iter: 1219  total_loss: 0.2058  loss_cls: 0.09183  loss_box_reg: 0.09567  loss_rpn_cls: 0.01793  loss_rpn_loc: 0.007313    time: 0.2692  last_time: 0.1471  data_time: 0.0056  last_data_time: 0.0073   lr: 0.0024095  max_mem: 744M
# [03/10 02:57:27 d2.utils.events]:  eta: 0:20:37  iter: 1239  total_loss: 0.2156  loss_cls: 0.09002  loss_box_reg: 0.09837  loss_rpn_cls: 0.01445  loss_rpn_loc: 0.009916    time: 0.2669  last_time: 0.1227  data_time: 0.0060  last_data_time: 0.0038   lr: 0.0024065  max_mem: 744M
# [03/10 02:57:29 d2.utils.events]:  eta: 0:20:03  iter: 1259  total_loss: 0.2585  loss_cls: 0.09947  loss_box_reg: 0.09814  loss_rpn_cls: 0.02436  loss_rpn_loc: 0.008636    time: 0.2646  last_time: 0.1200  data_time: 0.0040  last_data_time: 0.0041   lr: 0.0024035  max_mem: 744M
# [03/10 02:57:32 d2.utils.events]:  eta: 0:19:35  iter: 1279  total_loss: 0.2261  loss_cls: 0.1034  loss_box_reg: 0.1046  loss_rpn_cls: 0.02117  loss_rpn_loc: 0.007627    time: 0.2624  last_time: 0.1334  data_time: 0.0048  last_data_time: 0.0035   lr: 0.0024004  max_mem: 744M
# [03/10 02:57:34 d2.utils.events]:  eta: 0:19:19  iter: 1299  total_loss: 0.2008  loss_cls: 0.0793  loss_box_reg: 0.09558  loss_rpn_cls: 0.01518  loss_rpn_loc: 0.006245    time: 0.2603  last_time: 0.1178  data_time: 0.0039  last_data_time: 0.0042   lr: 0.0023973  max_mem: 744M
# [03/10 02:57:37 d2.utils.events]:  eta: 0:19:14  iter: 1319  total_loss: 0.2342  loss_cls: 0.09061  loss_box_reg: 0.115  loss_rpn_cls: 0.02065  loss_rpn_loc: 0.007037    time: 0.2585  last_time: 0.1403  data_time: 0.0090  last_data_time: 0.0066   lr: 0.0023942  max_mem: 744M
# [03/10 02:57:40 d2.utils.events]:  eta: 0:19:08  iter: 1339  total_loss: 0.2461  loss_cls: 0.1133  loss_box_reg: 0.1093  loss_rpn_cls: 0.01947  loss_rpn_loc: 0.008561    time: 0.2566  last_time: 0.1228  data_time: 0.0065  last_data_time: 0.0036   lr: 0.002391  max_mem: 744M
# [03/10 02:57:42 d2.utils.events]:  eta: 0:18:57  iter: 1359  total_loss: 0.2376  loss_cls: 0.09535  loss_box_reg: 0.1106  loss_rpn_cls: 0.02405  loss_rpn_loc: 0.01136    time: 0.2547  last_time: 0.1264  data_time: 0.0040  last_data_time: 0.0039   lr: 0.0023878  max_mem: 744M
# [03/10 02:57:45 d2.utils.events]:  eta: 0:18:49  iter: 1379  total_loss: 0.243  loss_cls: 0.1084  loss_box_reg: 0.08346  loss_rpn_cls: 0.02715  loss_rpn_loc: 0.006991    time: 0.2527  last_time: 0.1229  data_time: 0.0038  last_data_time: 0.0036   lr: 0.0023845  max_mem: 744M
# [03/10 02:57:47 d2.utils.events]:  eta: 0:18:40  iter: 1399  total_loss: 0.2221  loss_cls: 0.09312  loss_box_reg: 0.1101  loss_rpn_cls: 0.01905  loss_rpn_loc: 0.007955    time: 0.2509  last_time: 0.1220  data_time: 0.0039  last_data_time: 0.0035   lr: 0.0023812  max_mem: 744M
# [03/10 02:57:50 d2.utils.events]:  eta: 0:18:37  iter: 1419  total_loss: 0.2288  loss_cls: 0.09646  loss_box_reg: 0.1105  loss_rpn_cls: 0.01327  loss_rpn_loc: 0.00667    time: 0.2493  last_time: 0.1496  data_time: 0.0065  last_data_time: 0.0043   lr: 0.0023778  max_mem: 744M
# [03/10 02:57:53 d2.utils.events]:  eta: 0:18:27  iter: 1439  total_loss: 0.1985  loss_cls: 0.09072  loss_box_reg: 0.09312  loss_rpn_cls: 0.01851  loss_rpn_loc: 0.006704    time: 0.2477  last_time: 0.1338  data_time: 0.0047  last_data_time: 0.0045   lr: 0.0023744  max_mem: 744M
# [03/10 02:57:55 d2.utils.events]:  eta: 0:18:21  iter: 1459  total_loss: 0.2431  loss_cls: 0.1021  loss_box_reg: 0.1168  loss_rpn_cls: 0.01673  loss_rpn_loc: 0.008024    time: 0.2461  last_time: 0.1226  data_time: 0.0041  last_data_time: 0.0050   lr: 0.002371  max_mem: 744M
# [03/10 02:57:58 d2.utils.events]:  eta: 0:18:14  iter: 1479  total_loss: 0.2212  loss_cls: 0.1012  loss_box_reg: 0.1126  loss_rpn_cls: 0.0153  loss_rpn_loc: 0.007792    time: 0.2444  last_time: 0.1274  data_time: 0.0042  last_data_time: 0.0057   lr: 0.0023675  max_mem: 744M
# [03/10 02:58:00 d2.utils.events]:  eta: 0:18:09  iter: 1499  total_loss: 0.1866  loss_cls: 0.08292  loss_box_reg: 0.08784  loss_rpn_cls: 0.01714  loss_rpn_loc: 0.005985    time: 0.2428  last_time: 0.1257  data_time: 0.0041  last_data_time: 0.0040   lr: 0.0023639  max_mem: 744M
# [03/10 02:58:03 d2.utils.events]:  eta: 0:18:06  iter: 1519  total_loss: 0.2336  loss_cls: 0.1058  loss_box_reg: 0.1123  loss_rpn_cls: 0.0144  loss_rpn_loc: 0.006373    time: 0.2415  last_time: 0.1459  data_time: 0.0063  last_data_time: 0.0072   lr: 0.0023604  max_mem: 744M
# [03/10 02:58:06 d2.utils.events]:  eta: 0:18:01  iter: 1539  total_loss: 0.2023  loss_cls: 0.08735  loss_box_reg: 0.09339  loss_rpn_cls: 0.01845  loss_rpn_loc: 0.006735    time: 0.2400  last_time: 0.1246  data_time: 0.0060  last_data_time: 0.0042   lr: 0.0023567  max_mem: 744M
# [03/10 02:58:08 d2.utils.events]:  eta: 0:17:57  iter: 1559  total_loss: 0.2297  loss_cls: 0.09779  loss_box_reg: 0.1147  loss_rpn_cls: 0.01107  loss_rpn_loc: 0.007998    time: 0.2386  last_time: 0.1362  data_time: 0.0039  last_data_time: 0.0044   lr: 0.002353  max_mem: 744M
# [03/10 02:58:11 d2.utils.events]:  eta: 0:17:53  iter: 1579  total_loss: 0.1907  loss_cls: 0.07726  loss_box_reg: 0.0951  loss_rpn_cls: 0.01313  loss_rpn_loc: 0.005968    time: 0.2372  last_time: 0.1288  data_time: 0.0039  last_data_time: 0.0039   lr: 0.0023493  max_mem: 744M
# [03/10 02:58:13 d2.utils.events]:  eta: 0:17:48  iter: 1599  total_loss: 0.2234  loss_cls: 0.09868  loss_box_reg: 0.1146  loss_rpn_cls: 0.01327  loss_rpn_loc: 0.009197    time: 0.2358  last_time: 0.1264  data_time: 0.0043  last_data_time: 0.0050   lr: 0.0023456  max_mem: 744M
# [03/10 02:58:16 d2.utils.events]:  eta: 0:17:45  iter: 1619  total_loss: 0.2329  loss_cls: 0.09322  loss_box_reg: 0.1223  loss_rpn_cls: 0.01488  loss_rpn_loc: 0.006154    time: 0.2346  last_time: 0.1472  data_time: 0.0053  last_data_time: 0.0037   lr: 0.0023418  max_mem: 744M
# [03/10 02:58:19 d2.utils.events]:  eta: 0:17:42  iter: 1639  total_loss: 0.2348  loss_cls: 0.09332  loss_box_reg: 0.1243  loss_rpn_cls: 0.0116  loss_rpn_loc: 0.007759    time: 0.2334  last_time: 0.1333  data_time: 0.0052  last_data_time: 0.0039   lr: 0.0023379  max_mem: 744M
# [03/10 02:58:21 d2.utils.events]:  eta: 0:17:39  iter: 1659  total_loss: 0.3022  loss_cls: 0.1218  loss_box_reg: 0.14  loss_rpn_cls: 0.03263  loss_rpn_loc: 0.007486    time: 0.2321  last_time: 0.1231  data_time: 0.0040  last_data_time: 0.0042   lr: 0.002334  max_mem: 745M
# [03/10 02:58:24 d2.utils.events]:  eta: 0:17:37  iter: 1679  total_loss: 0.2479  loss_cls: 0.09811  loss_box_reg: 0.1132  loss_rpn_cls: 0.01937  loss_rpn_loc: 0.007567    time: 0.2308  last_time: 0.1219  data_time: 0.0040  last_data_time: 0.0034   lr: 0.0023301  max_mem: 745M
# [03/10 02:58:27 d2.utils.events]:  eta: 0:17:35  iter: 1699  total_loss: 0.2213  loss_cls: 0.09435  loss_box_reg: 0.1045  loss_rpn_cls: 0.01635  loss_rpn_loc: 0.006773    time: 0.2296  last_time: 0.1229  data_time: 0.0039  last_data_time: 0.0042   lr: 0.0023261  max_mem: 745M
# [03/10 02:58:29 d2.utils.events]:  eta: 0:17:32  iter: 1719  total_loss: 0.2453  loss_cls: 0.09124  loss_box_reg: 0.1115  loss_rpn_cls: 0.0182  loss_rpn_loc: 0.007654    time: 0.2285  last_time: 0.1423  data_time: 0.0048  last_data_time: 0.0087   lr: 0.0023221  max_mem: 745M
# [03/10 02:58:32 d2.utils.events]:  eta: 0:17:30  iter: 1739  total_loss: 0.2177  loss_cls: 0.1  loss_box_reg: 0.1074  loss_rpn_cls: 0.01935  loss_rpn_loc: 0.006652    time: 0.2275  last_time: 0.1261  data_time: 0.0113  last_data_time: 0.0042   lr: 0.0023181  max_mem: 745M
# [03/10 02:58:35 d2.utils.events]:  eta: 0:17:27  iter: 1759  total_loss: 0.234  loss_cls: 0.101  loss_box_reg: 0.101  loss_rpn_cls: 0.01772  loss_rpn_loc: 0.006763    time: 0.2263  last_time: 0.1226  data_time: 0.0042  last_data_time: 0.0042   lr: 0.0023139  max_mem: 745M
# [03/10 02:58:37 d2.utils.events]:  eta: 0:17:24  iter: 1779  total_loss: 0.2274  loss_cls: 0.0954  loss_box_reg: 0.1112  loss_rpn_cls: 0.01246  loss_rpn_loc: 0.005958    time: 0.2252  last_time: 0.1205  data_time: 0.0042  last_data_time: 0.0039   lr: 0.0023098  max_mem: 745M
# [03/10 02:58:40 d2.utils.events]:  eta: 0:17:20  iter: 1799  total_loss: 0.2012  loss_cls: 0.07602  loss_box_reg: 0.1031  loss_rpn_cls: 0.01106  loss_rpn_loc: 0.0062    time: 0.2241  last_time: 0.1299  data_time: 0.0038  last_data_time: 0.0046   lr: 0.0023056  max_mem: 745M
# [03/10 02:58:42 d2.utils.events]:  eta: 0:17:16  iter: 1819  total_loss: 0.2517  loss_cls: 0.08149  loss_box_reg: 0.1154  loss_rpn_cls: 0.02291  loss_rpn_loc: 0.006279    time: 0.2231  last_time: 0.1509  data_time: 0.0058  last_data_time: 0.0038   lr: 0.0023014  max_mem: 745M
# [03/10 02:58:45 d2.utils.events]:  eta: 0:17:14  iter: 1839  total_loss: 0.2185  loss_cls: 0.08259  loss_box_reg: 0.1065  loss_rpn_cls: 0.01052  loss_rpn_loc: 0.007406    time: 0.2222  last_time: 0.1257  data_time: 0.0071  last_data_time: 0.0043   lr: 0.0022971  max_mem: 745M
# [03/10 02:58:48 d2.utils.events]:  eta: 0:17:12  iter: 1859  total_loss: 0.2496  loss_cls: 0.09806  loss_box_reg: 0.1229  loss_rpn_cls: 0.01651  loss_rpn_loc: 0.007587    time: 0.2211  last_time: 0.1217  data_time: 0.0039  last_data_time: 0.0038   lr: 0.0022928  max_mem: 745M
# [03/10 02:58:50 d2.utils.events]:  eta: 0:17:09  iter: 1879  total_loss: 0.2129  loss_cls: 0.08453  loss_box_reg: 0.1103  loss_rpn_cls: 0.01304  loss_rpn_loc: 0.006603    time: 0.2201  last_time: 0.1266  data_time: 0.0040  last_data_time: 0.0039   lr: 0.0022885  max_mem: 745M
# [03/10 02:58:53 d2.utils.events]:  eta: 0:17:07  iter: 1899  total_loss: 0.2375  loss_cls: 0.09858  loss_box_reg: 0.111  loss_rpn_cls: 0.02072  loss_rpn_loc: 0.005876    time: 0.2191  last_time: 0.1185  data_time: 0.0040  last_data_time: 0.0039   lr: 0.0022841  max_mem: 745M
# [03/10 02:58:55 d2.utils.events]:  eta: 0:17:03  iter: 1919  total_loss: 0.203  loss_cls: 0.08165  loss_box_reg: 0.1093  loss_rpn_cls: 0.01425  loss_rpn_loc: 0.005773    time: 0.2182  last_time: 0.1429  data_time: 0.0048  last_data_time: 0.0042   lr: 0.0022796  max_mem: 745M
# [03/10 02:58:58 d2.utils.events]:  eta: 0:17:01  iter: 1939  total_loss: 0.2185  loss_cls: 0.09646  loss_box_reg: 0.09511  loss_rpn_cls: 0.01007  loss_rpn_loc: 0.007153    time: 0.2174  last_time: 0.1220  data_time: 0.0079  last_data_time: 0.0039   lr: 0.0022752  max_mem: 745M
# [03/10 02:59:01 d2.utils.events]:  eta: 0:16:58  iter: 1959  total_loss: 0.2197  loss_cls: 0.0989  loss_box_reg: 0.1142  loss_rpn_cls: 0.0137  loss_rpn_loc: 0.005738    time: 0.2165  last_time: 0.1229  data_time: 0.0047  last_data_time: 0.0048   lr: 0.0022707  max_mem: 745M
# [03/10 02:59:03 d2.utils.events]:  eta: 0:16:56  iter: 1979  total_loss: 0.2107  loss_cls: 0.0824  loss_box_reg: 0.1007  loss_rpn_cls: 0.00941  loss_rpn_loc: 0.005587    time: 0.2155  last_time: 0.1281  data_time: 0.0041  last_data_time: 0.0038   lr: 0.0022661  max_mem: 745M
# [03/10 02:59:05 d2.utils.events]:  eta: 0:16:52  iter: 1999  total_loss: 0.2033  loss_cls: 0.08268  loss_box_reg: 0.08151  loss_rpn_cls: 0.01809  loss_rpn_loc: 0.006822    time: 0.2146  last_time: 0.1201  data_time: 0.0039  last_data_time: 0.0038   lr: 0.0022615  max_mem: 745M
# [03/10 02:59:08 d2.utils.events]:  eta: 0:16:48  iter: 2019  total_loss: 0.2452  loss_cls: 0.09262  loss_box_reg: 0.113  loss_rpn_cls: 0.01669  loss_rpn_loc: 0.006364    time: 0.2138  last_time: 0.1533  data_time: 0.0082  last_data_time: 0.0056   lr: 0.0022569  max_mem: 745M
# [03/10 02:59:11 d2.utils.events]:  eta: 0:16:46  iter: 2039  total_loss: 0.1892  loss_cls: 0.07728  loss_box_reg: 0.09756  loss_rpn_cls: 0.007192  loss_rpn_loc: 0.005695    time: 0.2131  last_time: 0.1329  data_time: 0.0112  last_data_time: 0.0036   lr: 0.0022522  max_mem: 745M
# [03/10 02:59:14 d2.utils.events]:  eta: 0:16:43  iter: 2059  total_loss: 0.2366  loss_cls: 0.106  loss_box_reg: 0.1196  loss_rpn_cls: 0.01099  loss_rpn_loc: 0.007108    time: 0.2123  last_time: 0.1267  data_time: 0.0038  last_data_time: 0.0035   lr: 0.0022475  max_mem: 745M
# [03/10 02:59:16 d2.utils.events]:  eta: 0:16:40  iter: 2079  total_loss: 0.1926  loss_cls: 0.08164  loss_box_reg: 0.09821  loss_rpn_cls: 0.01271  loss_rpn_loc: 0.005607    time: 0.2114  last_time: 0.1241  data_time: 0.0040  last_data_time: 0.0041   lr: 0.0022427  max_mem: 745M
# [03/10 02:59:19 d2.utils.events]:  eta: 0:16:38  iter: 2099  total_loss: 0.1735  loss_cls: 0.05968  loss_box_reg: 0.09551  loss_rpn_cls: 0.01012  loss_rpn_loc: 0.005266    time: 0.2106  last_time: 0.1347  data_time: 0.0041  last_data_time: 0.0045   lr: 0.0022379  max_mem: 745M
# [03/10 02:59:21 d2.utils.events]:  eta: 0:16:35  iter: 2119  total_loss: 0.2472  loss_cls: 0.1072  loss_box_reg: 0.1229  loss_rpn_cls: 0.0155  loss_rpn_loc: 0.005844    time: 0.2099  last_time: 0.1677  data_time: 0.0095  last_data_time: 0.0202   lr: 0.0022331  max_mem: 745M
# [03/10 02:59:24 d2.utils.events]:  eta: 0:16:33  iter: 2139  total_loss: 0.2257  loss_cls: 0.08034  loss_box_reg: 0.1265  loss_rpn_cls: 0.0146  loss_rpn_loc: 0.006274    time: 0.2092  last_time: 0.1285  data_time: 0.0058  last_data_time: 0.0037   lr: 0.0022282  max_mem: 745M
# [03/10 02:59:27 d2.utils.events]:  eta: 0:16:30  iter: 2159  total_loss: 0.2028  loss_cls: 0.07895  loss_box_reg: 0.09927  loss_rpn_cls: 0.01371  loss_rpn_loc: 0.006627    time: 0.2085  last_time: 0.1232  data_time: 0.0037  last_data_time: 0.0032   lr: 0.0022233  max_mem: 745M
# [03/10 02:59:29 d2.utils.events]:  eta: 0:16:27  iter: 2179  total_loss: 0.2747  loss_cls: 0.1068  loss_box_reg: 0.1207  loss_rpn_cls: 0.01896  loss_rpn_loc: 0.0104    time: 0.2077  last_time: 0.1223  data_time: 0.0040  last_data_time: 0.0040   lr: 0.0022184  max_mem: 745M
# [03/10 02:59:32 d2.utils.events]:  eta: 0:16:25  iter: 2199  total_loss: 0.2061  loss_cls: 0.08648  loss_box_reg: 0.107  loss_rpn_cls: 0.01085  loss_rpn_loc: 0.005934    time: 0.2069  last_time: 0.1349  data_time: 0.0040  last_data_time: 0.0042   lr: 0.0022134  max_mem: 745M
# [03/10 02:59:34 d2.utils.events]:  eta: 0:16:21  iter: 2219  total_loss: 0.2891  loss_cls: 0.11  loss_box_reg: 0.1119  loss_rpn_cls: 0.02301  loss_rpn_loc: 0.009259    time: 0.2063  last_time: 0.1505  data_time: 0.0044  last_data_time: 0.0035   lr: 0.0022084  max_mem: 745M
# [03/10 02:59:37 d2.utils.events]:  eta: 0:16:20  iter: 2239  total_loss: 0.1921  loss_cls: 0.0732  loss_box_reg: 0.09316  loss_rpn_cls: 0.008854  loss_rpn_loc: 0.006613    time: 0.2057  last_time: 0.1231  data_time: 0.0071  last_data_time: 0.0040   lr: 0.0022033  max_mem: 745M
# [03/10 02:59:40 d2.utils.events]:  eta: 0:16:18  iter: 2259  total_loss: 0.2143  loss_cls: 0.09699  loss_box_reg: 0.1108  loss_rpn_cls: 0.01126  loss_rpn_loc: 0.007605    time: 0.2050  last_time: 0.1252  data_time: 0.0044  last_data_time: 0.0047   lr: 0.0021982  max_mem: 745M
# [03/10 02:59:42 d2.utils.events]:  eta: 0:16:15  iter: 2279  total_loss: 0.2222  loss_cls: 0.1022  loss_box_reg: 0.1109  loss_rpn_cls: 0.008695  loss_rpn_loc: 0.006111    time: 0.2043  last_time: 0.1210  data_time: 0.0041  last_data_time: 0.0039   lr: 0.0021931  max_mem: 745M
# [03/10 02:59:45 d2.utils.events]:  eta: 0:16:13  iter: 2299  total_loss: 0.2406  loss_cls: 0.1041  loss_box_reg: 0.0968  loss_rpn_cls: 0.01682  loss_rpn_loc: 0.005271    time: 0.2036  last_time: 0.1222  data_time: 0.0039  last_data_time: 0.0037   lr: 0.0021879  max_mem: 745M
# [03/10 02:59:47 d2.utils.events]:  eta: 0:16:09  iter: 2319  total_loss: 0.1957  loss_cls: 0.06728  loss_box_reg: 0.0927  loss_rpn_cls: 0.01141  loss_rpn_loc: 0.007328    time: 0.2029  last_time: 0.1499  data_time: 0.0037  last_data_time: 0.0041   lr: 0.0021827  max_mem: 745M
# [03/10 02:59:50 d2.utils.events]:  eta: 0:16:07  iter: 2339  total_loss: 0.2031  loss_cls: 0.08568  loss_box_reg: 0.1079  loss_rpn_cls: 0.01134  loss_rpn_loc: 0.006051    time: 0.2024  last_time: 0.1220  data_time: 0.0137  last_data_time: 0.0038   lr: 0.0021774  max_mem: 745M
# [03/10 02:59:52 d2.utils.events]:  eta: 0:16:04  iter: 2359  total_loss: 0.2217  loss_cls: 0.1  loss_box_reg: 0.1072  loss_rpn_cls: 0.009046  loss_rpn_loc: 0.004975    time: 0.2017  last_time: 0.1235  data_time: 0.0045  last_data_time: 0.0041   lr: 0.0021722  max_mem: 745M
# ...
# [03/10 03:15:29 d2.utils.events]:  eta: 0:01:39  iter: 9199  total_loss: 0.1488  loss_cls: 0.05446  loss_box_reg: 0.08893  loss_rpn_cls: 0.00365  loss_rpn_loc: 0.00542    time: 0.1468  last_time: 0.1268  data_time: 0.0040  last_data_time: 0.0037   lr: 3.9369e-05  max_mem: 748M
# [03/10 03:15:32 d2.utils.events]:  eta: 0:01:36  iter: 9219  total_loss: 0.1194  loss_cls: 0.04157  loss_box_reg: 0.07175  loss_rpn_cls: 0.00389  loss_rpn_loc: 0.003941    time: 0.1468  last_time: 0.1414  data_time: 0.0048  last_data_time: 0.0054   lr: 3.7437e-05  max_mem: 748M
# [03/10 03:15:34 d2.utils.events]:  eta: 0:01:34  iter: 9239  total_loss: 0.1471  loss_cls: 0.04873  loss_box_reg: 0.08611  loss_rpn_cls: 0.003166  loss_rpn_loc: 0.004449    time: 0.1467  last_time: 0.1196  data_time: 0.0093  last_data_time: 0.0038   lr: 3.5553e-05  max_mem: 748M
# [03/10 03:15:37 d2.utils.events]:  eta: 0:01:31  iter: 9259  total_loss: 0.1419  loss_cls: 0.05371  loss_box_reg: 0.08591  loss_rpn_cls: 0.002645  loss_rpn_loc: 0.004701    time: 0.1467  last_time: 0.1184  data_time: 0.0043  last_data_time: 0.0034   lr: 3.3717e-05  max_mem: 748M
# [03/10 03:15:39 d2.utils.events]:  eta: 0:01:29  iter: 9279  total_loss: 0.1599  loss_cls: 0.05629  loss_box_reg: 0.09041  loss_rpn_cls: 0.003648  loss_rpn_loc: 0.003676    time: 0.1466  last_time: 0.1229  data_time: 0.0039  last_data_time: 0.0032   lr: 3.193e-05  max_mem: 748M
# [03/10 03:15:42 d2.utils.events]:  eta: 0:01:26  iter: 9299  total_loss: 0.1339  loss_cls: 0.04654  loss_box_reg: 0.07615  loss_rpn_cls: 0.004094  loss_rpn_loc: 0.004025    time: 0.1466  last_time: 0.1319  data_time: 0.0040  last_data_time: 0.0038   lr: 3.019e-05  max_mem: 748M
# [03/10 03:15:44 d2.utils.events]:  eta: 0:01:24  iter: 9319  total_loss: 0.1326  loss_cls: 0.04683  loss_box_reg: 0.0806  loss_rpn_cls: 0.002241  loss_rpn_loc: 0.00354    time: 0.1466  last_time: 0.1403  data_time: 0.0069  last_data_time: 0.0254   lr: 2.8498e-05  max_mem: 748M
# [03/10 03:15:47 d2.utils.events]:  eta: 0:01:21  iter: 9339  total_loss: 0.1546  loss_cls: 0.04906  loss_box_reg: 0.08787  loss_rpn_cls: 0.006207  loss_rpn_loc: 0.004903    time: 0.1465  last_time: 0.1300  data_time: 0.0145  last_data_time: 0.0038   lr: 2.6855e-05  max_mem: 748M
# [03/10 03:15:50 d2.utils.events]:  eta: 0:01:19  iter: 9359  total_loss: 0.1826  loss_cls: 0.06827  loss_box_reg: 0.1089  loss_rpn_cls: 0.002191  loss_rpn_loc: 0.004994    time: 0.1465  last_time: 0.1314  data_time: 0.0040  last_data_time: 0.0035   lr: 2.526e-05  max_mem: 748M
# [03/10 03:15:52 d2.utils.events]:  eta: 0:01:16  iter: 9379  total_loss: 0.112  loss_cls: 0.03474  loss_box_reg: 0.07344  loss_rpn_cls: 0.001737  loss_rpn_loc: 0.003072    time: 0.1464  last_time: 0.1323  data_time: 0.0039  last_data_time: 0.0038   lr: 2.3713e-05  max_mem: 748M
# [03/10 03:15:55 d2.utils.events]:  eta: 0:01:14  iter: 9399  total_loss: 0.1289  loss_cls: 0.04451  loss_box_reg: 0.07924  loss_rpn_cls: 0.002572  loss_rpn_loc: 0.003841    time: 0.1464  last_time: 0.1169  data_time: 0.0038  last_data_time: 0.0034   lr: 2.2215e-05  max_mem: 748M
# [03/10 03:15:57 d2.utils.events]:  eta: 0:01:11  iter: 9419  total_loss: 0.1288  loss_cls: 0.04127  loss_box_reg: 0.07859  loss_rpn_cls: 0.002545  loss_rpn_loc: 0.004548    time: 0.1463  last_time: 0.1384  data_time: 0.0049  last_data_time: 0.0049   lr: 2.0765e-05  max_mem: 748M
# [03/10 03:16:00 d2.utils.events]:  eta: 0:01:09  iter: 9439  total_loss: 0.1551  loss_cls: 0.05462  loss_box_reg: 0.08277  loss_rpn_cls: 0.002987  loss_rpn_loc: 0.004137    time: 0.1463  last_time: 0.1471  data_time: 0.0128  last_data_time: 0.0073   lr: 1.9363e-05  max_mem: 748M
# [03/10 03:16:03 d2.utils.events]:  eta: 0:01:06  iter: 9459  total_loss: 0.1228  loss_cls: 0.04827  loss_box_reg: 0.07278  loss_rpn_cls: 0.002987  loss_rpn_loc: 0.003594    time: 0.1463  last_time: 0.1191  data_time: 0.0042  last_data_time: 0.0050   lr: 1.8011e-05  max_mem: 748M
# [03/10 03:16:05 d2.utils.events]:  eta: 0:01:04  iter: 9479  total_loss: 0.1267  loss_cls: 0.04336  loss_box_reg: 0.07977  loss_rpn_cls: 0.001685  loss_rpn_loc: 0.004792    time: 0.1462  last_time: 0.1208  data_time: 0.0042  last_data_time: 0.0038   lr: 1.6706e-05  max_mem: 748M
# [03/10 03:16:07 d2.utils.events]:  eta: 0:01:01  iter: 9499  total_loss: 0.1243  loss_cls: 0.03866  loss_box_reg: 0.06563  loss_rpn_cls: 0.002753  loss_rpn_loc: 0.003692    time: 0.1462  last_time: 0.1164  data_time: 0.0038  last_data_time: 0.0041   lr: 1.5451e-05  max_mem: 748M
# [03/10 03:16:10 d2.utils.events]:  eta: 0:00:59  iter: 9519  total_loss: 0.1386  loss_cls: 0.04904  loss_box_reg: 0.07995  loss_rpn_cls: 0.002387  loss_rpn_loc: 0.003248    time: 0.1461  last_time: 0.1312  data_time: 0.0049  last_data_time: 0.0242   lr: 1.4244e-05  max_mem: 748M
# [03/10 03:16:13 d2.utils.events]:  eta: 0:00:56  iter: 9539  total_loss: 0.1182  loss_cls: 0.03874  loss_box_reg: 0.07613  loss_rpn_cls: 0.003467  loss_rpn_loc: 0.00329    time: 0.1461  last_time: 0.1500  data_time: 0.0076  last_data_time: 0.0041   lr: 1.3086e-05  max_mem: 748M
# [03/10 03:16:15 d2.utils.events]:  eta: 0:00:54  iter: 9559  total_loss: 0.1337  loss_cls: 0.04579  loss_box_reg: 0.08089  loss_rpn_cls: 0.008139  loss_rpn_loc: 0.004531    time: 0.1461  last_time: 0.1196  data_time: 0.0042  last_data_time: 0.0038   lr: 1.1977e-05  max_mem: 748M
# [03/10 03:16:18 d2.utils.events]:  eta: 0:00:51  iter: 9579  total_loss: 0.1062  loss_cls: 0.03509  loss_box_reg: 0.06855  loss_rpn_cls: 0.001838  loss_rpn_loc: 0.003302    time: 0.1460  last_time: 0.1159  data_time: 0.0038  last_data_time: 0.0033   lr: 1.0917e-05  max_mem: 748M
# [03/10 03:16:20 d2.utils.events]:  eta: 0:00:49  iter: 9599  total_loss: 0.1653  loss_cls: 0.06105  loss_box_reg: 0.09517  loss_rpn_cls: 0.004815  loss_rpn_loc: 0.003646    time: 0.1460  last_time: 0.1257  data_time: 0.0039  last_data_time: 0.0039   lr: 9.9059e-06  max_mem: 748M
# [03/10 03:16:23 d2.utils.events]:  eta: 0:00:46  iter: 9619  total_loss: 0.1433  loss_cls: 0.04305  loss_box_reg: 0.08407  loss_rpn_cls: 0.001797  loss_rpn_loc: 0.004172    time: 0.1459  last_time: 0.1216  data_time: 0.0039  last_data_time: 0.0041   lr: 8.9436e-06  max_mem: 748M
# [03/10 03:16:25 d2.utils.events]:  eta: 0:00:44  iter: 9639  total_loss: 0.1122  loss_cls: 0.03791  loss_box_reg: 0.07128  loss_rpn_cls: 0.002503  loss_rpn_loc: 0.003624    time: 0.1459  last_time: 0.1359  data_time: 0.0070  last_data_time: 0.0047   lr: 8.0302e-06  max_mem: 748M
# [03/10 03:16:28 d2.utils.events]:  eta: 0:00:41  iter: 9659  total_loss: 0.1486  loss_cls: 0.05099  loss_box_reg: 0.09438  loss_rpn_cls: 0.005269  loss_rpn_loc: 0.004627    time: 0.1459  last_time: 0.1261  data_time: 0.0089  last_data_time: 0.0040   lr: 7.1659e-06  max_mem: 748M
# [03/10 03:16:30 d2.utils.events]:  eta: 0:00:39  iter: 9679  total_loss: 0.1217  loss_cls: 0.03725  loss_box_reg: 0.07446  loss_rpn_cls: 0.004285  loss_rpn_loc: 0.004926    time: 0.1458  last_time: 0.1191  data_time: 0.0046  last_data_time: 0.0038   lr: 6.3507e-06  max_mem: 748M
# [03/10 03:16:33 d2.utils.events]:  eta: 0:00:37  iter: 9699  total_loss: 0.1265  loss_cls: 0.04328  loss_box_reg: 0.07379  loss_rpn_cls: 0.003309  loss_rpn_loc: 0.004121    time: 0.1458  last_time: 0.1284  data_time: 0.0043  last_data_time: 0.0040   lr: 5.5846e-06  max_mem: 748M
# [03/10 03:16:35 d2.utils.events]:  eta: 0:00:34  iter: 9719  total_loss: 0.1322  loss_cls: 0.04213  loss_box_reg: 0.08017  loss_rpn_cls: 0.003172  loss_rpn_loc: 0.003847    time: 0.1457  last_time: 0.1215  data_time: 0.0039  last_data_time: 0.0037   lr: 4.8675e-06  max_mem: 748M
# [03/10 03:16:38 d2.utils.events]:  eta: 0:00:32  iter: 9739  total_loss: 0.09674  loss_cls: 0.02912  loss_box_reg: 0.06421  loss_rpn_cls: 0.0009478  loss_rpn_loc: 0.004471    time: 0.1457  last_time: 0.1385  data_time: 0.0057  last_data_time: 0.0044   lr: 4.1997e-06  max_mem: 748M
# [03/10 03:16:41 d2.utils.events]:  eta: 0:00:29  iter: 9759  total_loss: 0.1436  loss_cls: 0.05099  loss_box_reg: 0.0807  loss_rpn_cls: 0.004343  loss_rpn_loc: 0.003523    time: 0.1457  last_time: 0.1215  data_time: 0.0054  last_data_time: 0.0035   lr: 3.581e-06  max_mem: 748M
# [03/10 03:16:43 d2.utils.events]:  eta: 0:00:27  iter: 9779  total_loss: 0.1339  loss_cls: 0.04948  loss_box_reg: 0.08095  loss_rpn_cls: 0.003366  loss_rpn_loc: 0.004287    time: 0.1457  last_time: 0.1226  data_time: 0.0039  last_data_time: 0.0040   lr: 3.0115e-06  max_mem: 748M
# [03/10 03:16:46 d2.utils.events]:  eta: 0:00:24  iter: 9799  total_loss: 0.1451  loss_cls: 0.04539  loss_box_reg: 0.09122  loss_rpn_cls: 0.004541  loss_rpn_loc: 0.006211    time: 0.1456  last_time: 0.1201  data_time: 0.0041  last_data_time: 0.0036   lr: 2.4913e-06  max_mem: 748M
# [03/10 03:16:48 d2.utils.events]:  eta: 0:00:22  iter: 9819  total_loss: 0.1479  loss_cls: 0.0517  loss_box_reg: 0.08026  loss_rpn_cls: 0.003188  loss_rpn_loc: 0.004138    time: 0.1456  last_time: 0.1239  data_time: 0.0039  last_data_time: 0.0036   lr: 2.0203e-06  max_mem: 748M
# [03/10 03:16:51 d2.utils.events]:  eta: 0:00:19  iter: 9839  total_loss: 0.1152  loss_cls: 0.03922  loss_box_reg: 0.07442  loss_rpn_cls: 0.001635  loss_rpn_loc: 0.003303    time: 0.1455  last_time: 0.1356  data_time: 0.0082  last_data_time: 0.0049   lr: 1.5986e-06  max_mem: 748M
# [03/10 03:16:53 d2.utils.events]:  eta: 0:00:17  iter: 9859  total_loss: 0.1305  loss_cls: 0.04056  loss_box_reg: 0.08002  loss_rpn_cls: 0.004902  loss_rpn_loc: 0.004596    time: 0.1455  last_time: 0.1174  data_time: 0.0049  last_data_time: 0.0035   lr: 1.2262e-06  max_mem: 748M
# [03/10 03:16:56 d2.utils.events]:  eta: 0:00:14  iter: 9879  total_loss: 0.123  loss_cls: 0.04333  loss_box_reg: 0.07408  loss_rpn_cls: 0.003021  loss_rpn_loc: 0.004042    time: 0.1455  last_time: 0.1194  data_time: 0.0041  last_data_time: 0.0035   lr: 9.0302e-07  max_mem: 748M
# [03/10 03:16:58 d2.utils.events]:  eta: 0:00:12  iter: 9899  total_loss: 0.1363  loss_cls: 0.04767  loss_box_reg: 0.07977  loss_rpn_cls: 0.005103  loss_rpn_loc: 0.004089    time: 0.1454  last_time: 0.1425  data_time: 0.0042  last_data_time: 0.0099   lr: 6.292e-07  max_mem: 748M
# [03/10 03:17:01 d2.utils.events]:  eta: 0:00:09  iter: 9919  total_loss: 0.177  loss_cls: 0.06226  loss_box_reg: 0.09353  loss_rpn_cls: 0.003888  loss_rpn_loc: 0.007256    time: 0.1454  last_time: 0.1197  data_time: 0.0039  last_data_time: 0.0037   lr: 4.0469e-07  max_mem: 748M
# [03/10 03:17:03 d2.utils.events]:  eta: 0:00:07  iter: 9939  total_loss: 0.1533  loss_cls: 0.04583  loss_box_reg: 0.09415  loss_rpn_cls: 0.003022  loss_rpn_loc: 0.004297    time: 0.1453  last_time: 0.1335  data_time: 0.0039  last_data_time: 0.0037   lr: 2.2952e-07  max_mem: 748M
# [03/10 03:17:06 d2.utils.events]:  eta: 0:00:04  iter: 9959  total_loss: 0.1258  loss_cls: 0.03245  loss_box_reg: 0.07867  loss_rpn_cls: 0.003632  loss_rpn_loc: 0.003847    time: 0.1453  last_time: 0.1265  data_time: 0.0152  last_data_time: 0.0041   lr: 1.0369e-07  max_mem: 748M
# [03/10 03:17:09 d2.utils.events]:  eta: 0:00:02  iter: 9979  total_loss: 0.1302  loss_cls: 0.03575  loss_box_reg: 0.07795  loss_rpn_cls: 0.003836  loss_rpn_loc: 0.003673    time: 0.1453  last_time: 0.1225  data_time: 0.0047  last_data_time: 0.0038   lr: 2.7203e-08  max_mem: 748M
# [03/10 03:17:13 d2.utils.events]:  eta: 0:00:00  iter: 9999  total_loss: 0.1099  loss_cls: 0.03244  loss_box_reg: 0.0741  loss_rpn_cls: 0.003043  loss_rpn_loc: 0.003733    time: 0.1452  last_time: 0.1205  data_time: 0.0037  last_data_time: 0.0034   lr: 6.1685e-11  max_mem: 748M
# [03/10 03:17:13 d2.engine.hooks]: Overall training speed: 9998 iterations in 0:24:11 (0.1452 s / it)
# [03/10 03:17:13 d2.engine.hooks]: Total training time: 0:25:21 (0:01:09 on hooks)
# [03/10 03:17:13 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(256, 256), max_size=1333, sample_style='choice')]
# [03/10 03:17:13 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [03/10 03:17:13 d2.data.common]: Serializing 319 elements to byte tensors and concatenating them all ...
# [03/10 03:17:13 d2.data.common]: Serialized dataset takes 0.10 MiB
# WARNING [03/10 03:17:13 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [03/10 03:17:13 d2.evaluation.evaluator]: Start inference on 319 batches
# [03/10 03:17:14 d2.evaluation.evaluator]: Inference done 11/319. Dataloading: 0.0007 s/iter. Inference: 0.0345 s/iter. Eval: 0.0002 s/iter. Total: 0.0354 s/iter. ETA=0:00:10
# [03/10 03:17:19 d2.evaluation.evaluator]: Inference done 148/319. Dataloading: 0.0012 s/iter. Inference: 0.0352 s/iter. Eval: 0.0002 s/iter. Total: 0.0367 s/iter. ETA=0:00:06
# [03/10 03:17:24 d2.evaluation.evaluator]: Inference done 236/319. Dataloading: 0.0014 s/iter. Inference: 0.0428 s/iter. Eval: 0.0003 s/iter. Total: 0.0446 s/iter. ETA=0:00:03
# [03/10 03:17:27 d2.evaluation.evaluator]: Total inference time: 0:00:13.514508 (0.043040 s / iter per device, on 1 devices)
# [03/10 03:17:27 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:12 (0.041241 s / iter per device, on 1 devices)
# [03/10 03:17:27 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [03/10 03:17:27 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v44/coco_instances_results.json
# [03/10 03:17:27 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [03/10 03:17:27 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [03/10 03:17:27 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [03/10 03:17:27 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [03/10 03:17:27 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.316
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.655
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.263
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.248
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.494
# [03/10 03:17:27 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 31.626 | 65.532 | 26.317 | 21.984 | 31.862 | 35.068 |
# [03/10 03:17:27 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | ulcer      | 15.224 | polyp      | 40.079 | cancer     | 39.576 |
# [03/10 03:17:27 d2.engine.defaults]: Evaluation results for colonoscopy_val in csv format:
# [03/10 03:17:27 d2.evaluation.testing]: copypaste: Task: bbox
# [03/10 03:17:27 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [03/10 03:17:27 d2.evaluation.testing]: copypaste: 31.6263,65.5315,26.3169,21.9836,31.8624,35.0677

# %% [markdown]
# result

# %%
import pandas as pd

metrics_path = "/content/drive/MyDrive/Endoscope Detection/colonoscopy/Detectron2/experiment/v4/metrics.json"
metrics = pd.read_json(metrics_path, orient='records', lines=True)
metrics = metrics.sort_values(by=['iteration'])

print('Shape of Metrics: ', metrics.shape)
metrics.head()
# Out:
# Shape of Metrics:  (500, 18)
#    data_time  eta_seconds  fast_rcnn/cls_accuracy  fast_rcnn/false_negative  \
# 0   0.004608  1375.451978                0.706055                  0.547619
# 1   0.007186  1416.108328                0.987305                  1.000000
# 2   0.004446  1379.955807                0.986328                  1.000000
# 3   0.004408  1375.929499                0.989258                  1.000000
# 4   0.004163  1364.523351                0.980957                  1.000000
#
#    fast_rcnn/fg_cls_accuracy  iteration  loss_box_reg  loss_cls  loss_rpn_cls  \
# 0                        0.0         19      0.020742  3.228227      0.669357
# 1                        0.0         39      0.047861  0.158537      0.572044
# 2                        0.0         59      0.053079  0.138939      0.375784
# 3                        0.0         79      0.034749  0.173219      0.203498
# 4                        0.0         99      0.073024  0.228212      0.134821
#
#    loss_rpn_loc        lr  rank_data_time  roi_head/num_bg_samples  \
# 0      0.009987  0.000049        0.004608                   508.75
# 1      0.011072  0.000098        0.007186                   505.50
# 2      0.013248  0.000146        0.004446                   505.00
# 3      0.013664  0.000195        0.004408                   506.50
# 4      0.013054  0.000244        0.004163                   502.25
#
#    roi_head/num_fg_samples  rpn/num_neg_anchors  rpn/num_pos_anchors  \
# 0                     3.25               252.25                 3.75
# 1                     6.50               252.50                 3.50
# 2                     7.00               251.75                 4.25
# 3                     5.50               251.25                 4.75
# 4                     9.75               251.25                 4.75
#
#        time  total_loss
# 0  0.137821    3.939882
# 1  0.161771    0.808402
# 2  0.137269    0.592596
# 3  0.137159    0.459622
# 4  0.135486    0.428241

# %%
import matplotlib.pyplot as plt

plt.style.use('default')
plt.figure(figsize=(12,6))

tmp = metrics[~metrics['lr'].isna()]

plt.plot(tmp['iteration'], tmp['lr'])
plt.xlabel('iterations')
plt.ylabel('Learning Rate')

plt.show()

# %%
plt.style.use('Solarize_Light2')
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('RPN Fraction Ratio')
tmp = metrics[~metrics['rpn/num_neg_anchors'].isna()]
tmp = tmp[~tmp['rpn/num_pos_anchors'].isna()]
plt.plot(tmp['iteration'], tmp['rpn/num_neg_anchors'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_neg_anchors'].mean(), tmp['rpn/num_neg_anchors'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['rpn/num_pos_anchors'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['rpn/num_pos_anchors'].mean(),tmp['rpn/num_pos_anchors'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.title('ROI Head Fraction Ratio')
tmp = metrics[~metrics['roi_head/num_bg_samples'].isna()]
tmp = tmp[~tmp['roi_head/num_fg_samples'].isna()]
plt.plot(tmp['iteration'], tmp['roi_head/num_bg_samples'], color='red', label='background')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_bg_samples'].mean(), tmp['roi_head/num_bg_samples'].mean()], '--', color='red')
plt.plot(tmp['iteration'], tmp['roi_head/num_fg_samples'], color='blue', label='foreground')
plt.plot([0,tmp['iteration'].max()], [tmp['roi_head/num_fg_samples'].mean(),tmp['roi_head/num_fg_samples'].mean()], '--', color='blue')

plt.grid(True)
plt.legend()


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(metrics["total_loss"], label="Final Loss", color="red", linewidth=1.5)
plt.xlabel("Iteration")
plt.ylabel("Loss Value")
plt.title("Final Loss Over Iterations")
plt.legend()
plt.grid(True)
plt.show()
